# %%
import numpy as np
import os
import gc
import time
import matplotlib.pyplot as plt
import seaborn as sns

import tensorflow as tf
from tensorflow.keras import layers, models

from sklearn.metrics import (
    confusion_matrix,
    classification_report,
    roc_curve,
    auc,
    precision_recall_curve,
    f1_score
)

import pandas as pd
import time
from tensorflow.keras.callbacks import Callback, EarlyStopping, ModelCheckpoint
from tensorflow.keras.callbacks import ReduceLROnPlateau, CSVLogger
# Out:
# 2026-05-23 01:10:29.520774: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-05-23 01:10:29.532881: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1779473429.548156  711243 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1779473429.553081  711243 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1779473429.564447  711243 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1779473429.564470  711243 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1779473429.564472  711243 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1779473429.564473  711243 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-05-23 01:10:29.568366: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
Load_Path = "/home/dani/Documents/tugas akhir/TugasAkhir/codeTugasAkhirku2026/tow_ids/Preprocessing/Preprocessingbaru/imgsize256lv3/norm/dwt/"
ukuran = 32

# %%
train_data = np.load(os.path.join(Load_Path, "tow_ids_train_dwt.npz"))
test_data  = np.load(os.path.join(Load_Path, "tow_ids_test_dwt.npz"))
validation_data = np.load(os.path.join(Load_Path, "tow_ids_eval_dwt.npz"))

X_train = train_data["X"]
y_train = train_data["y"]

X_val = validation_data["X"]
y_val = validation_data["y"]

X_test  = test_data["X"]
y_test  = test_data["y"]

print(X_train.shape, y_train.shape)
print(X_val.shape, y_val.shape)
print(X_test.shape, y_test.shape)
# Out:
# (3291, 32, 32, 3) (3291,)
# (1410, 32, 32, 3) (1410,)
# (3092, 32, 32, 3) (3092,)

# %%
print("Train label distribution:", np.unique(y_train, return_counts=True))
print("Test label distribution :", np.unique(y_test, return_counts=True))
print("Validation label distribution :", np.unique(y_val, return_counts=True))

print("Min value:", X_train.min())
print("Max value:", X_train.max())
# Out:
# Train label distribution: (array([0, 1]), array([1524, 1767]))
# Test label distribution : (array([0, 1]), array([1600, 1492]))
# Validation label distribution : (array([0, 1]), array([ 382, 1028]))
# Min value: -0.8601289
# Max value: 8.30175

# %%
import tensorflow as tf
from tensorflow.keras import layers, models


def composite_conv(x, filters, kernel_size):
    x = layers.Conv2D(
        filters,
        kernel_size,
        padding="same",
        use_bias=False
    )(x)

    x = layers.BatchNormalization()(x)

    x = layers.ReLU()(x)

    return x


def SE_block(x, ratio=16):
    channels = x.shape[-1]

    se = layers.GlobalAveragePooling2D()(x)

    se = layers.Dense(
        max(channels // ratio, 4),
        activation="relu"
    )(se)

    se = layers.Dense(
        channels,
        activation="sigmoid"
    )(se)

    se = layers.Reshape((1, 1, channels))(se)

    out = layers.Multiply()([x, se])

    return out


def DPDB_block(x, filters, pool=True):
    shortcut = x

    h = composite_conv(x, filters // 2, (1, 3))

    v = composite_conv(x, filters // 2, (3, 1))

    concat = layers.Concatenate()([h, v])

    fusion = composite_conv(concat, filters, (1, 1))

    fusion = SE_block(fusion)

    if pool:
        fusion = layers.MaxPooling2D((2, 2))(fusion)

    shortcut = layers.Conv2D(
        filters,
        (1, 1),
        padding="same",
        use_bias=False
    )(shortcut)

    shortcut = layers.BatchNormalization()(shortcut)

    if pool:
        shortcut = layers.MaxPooling2D((2, 2))(shortcut)

    out = layers.Add()([fusion, shortcut])

    out = layers.ReLU()(out)

    return out


input_layer = layers.Input(shape=(ukuran, ukuran, 3))

x = composite_conv(input_layer, 16, (1, 3))

x = composite_conv(x, 16, (3, 1))

x = DPDB_block(x, 32, pool=True)

x = DPDB_block(x, 64, pool=False)

x = composite_conv(x, 48, (1, 1))

x = layers.GlobalAveragePooling2D()(x)

x = layers.Dense(
    64,
    activation="relu"
)(x)

x = layers.Dropout(0.5)(x)

output_layer = layers.Dense(
    1,
    activation="sigmoid"
)(x)

model = models.Model(
    inputs=input_layer,
    outputs=output_layer
)

model.compile(

    optimizer=tf.keras.optimizers.AdamW(
        learning_rate=1e-4,
        weight_decay=1e-5
    ),

    loss=tf.keras.losses.BinaryFocalCrossentropy(
        apply_class_balancing=True,
        alpha=0.75,
        gamma=2.0
    ),

    metrics=[

        tf.keras.metrics.BinaryAccuracy(
            name="accuracy"
        ),

        tf.keras.metrics.Precision(
            name="precision"
        ),

        tf.keras.metrics.Recall(
            name="recall"
        ),

        tf.keras.metrics.AUC(
            name="auc"
        ),

        tf.keras.metrics.AUC(
            curve="PR",
            name="pr_auc"
        )
    ]
)

model.summary()
# Out:
# I0000 00:00:1779473430.994305  711243 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 4144 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 32, 32, 3) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 32, 32,    │        144 │ input_layer[0][0] │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 32, 32,    │         64 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu (ReLU)        │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 32, 32,    │        768 │ re_lu[0][0]       │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │         64 │ conv2d_1[0][0]    │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_1 (ReLU)      │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 32, 32,    │        768 │ re_lu_1[0][0]     │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 32, 32,    │        768 │ re_lu_1[0][0]     │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │         64 │ conv2d_2[0][0]    │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │         64 │ conv2d_3[0][0]    │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_2 (ReLU)      │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_3 (ReLU)      │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 32, 32,    │          0 │ re_lu_2[0][0],    │
# │ (Concatenate)       │ 32)               │            │ re_lu_3[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 32, 32,    │      1,024 │ concatenate[0][0] │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        128 │ conv2d_4[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_4 (ReLU)      │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 32)        │          0 │ re_lu_4[0][0]     │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 4)         │        132 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 32)        │        160 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape (Reshape)   │ (None, 1, 1, 32)  │          0 │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 32, 32,    │        512 │ re_lu_1[0][0]     │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply (Multiply) │ (None, 32, 32,    │          0 │ re_lu_4[0][0],    │
# │                     │ 32)               │            │ reshape[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        128 │ conv2d_5[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 16, 16,    │          0 │ multiply[0][0]    │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 16, 16,    │          0 │ max_pooling2d[0]… │
# │                     │ 32)               │            │ max_pooling2d_1[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_5 (ReLU)      │ (None, 16, 16,    │          0 │ add[0][0]         │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 16, 16,    │      3,072 │ re_lu_5[0][0]     │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 16, 16,    │      3,072 │ re_lu_5[0][0]     │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        128 │ conv2d_6[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        128 │ conv2d_7[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_6 (ReLU)      │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_7 (ReLU)      │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 16, 16,    │          0 │ re_lu_6[0][0],    │
# │ (Concatenate)       │ 64)               │            │ re_lu_7[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 16, 16,    │      4,096 │ concatenate_1[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        256 │ conv2d_8[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_8 (ReLU)      │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 64)        │          0 │ re_lu_8[0][0]     │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 4)         │        260 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 64)        │        320 │ dense_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_1 (Reshape) │ (None, 1, 1, 64)  │          0 │ dense_3[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 16, 16,    │      2,048 │ re_lu_5[0][0]     │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_1          │ (None, 16, 16,    │          0 │ re_lu_8[0][0],    │
# │ (Multiply)          │ 64)               │            │ reshape_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        256 │ conv2d_9[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 16, 16,    │          0 │ multiply_1[0][0], │
# │                     │ 64)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_9 (ReLU)      │ (None, 16, 16,    │          0 │ add_1[0][0]       │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 16, 16,    │      3,072 │ re_lu_9[0][0]     │
# │                     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        192 │ conv2d_10[0][0]   │
# │ (BatchNormalizatio… │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_10 (ReLU)     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 48)        │          0 │ re_lu_10[0][0]    │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_4 (Dense)     │ (None, 64)        │      3,136 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 64)        │          0 │ dense_4[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_5 (Dense)     │ (None, 1)         │         65 │ dropout[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 24,889 (97.22 KB)
#  Trainable params: 24,153 (94.35 KB)
#  Non-trainable params: 736 (2.88 KB)

# %%
print("TensorFlow version:", tf.__version__)
print("GPU available:", tf.config.list_physical_devices('GPU'))

tf.debugging.set_log_device_placement(True)
# Out:
# TensorFlow version: 2.19.1
# GPU available: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
class TrainingLogger(Callback):

    def on_train_begin(self, logs=None):
        print("\nTraining started")
        print("-"*70)
        print("{:<8} {:<12} {:<12} {:<12} {:<12}".format(
            "Epoch","Loss","Accuracy","Val_Loss","Val_Acc"))
        print("-"*70)

    def on_epoch_end(self, epoch, logs=None):

        print("{:<8} {:<12.4f} {:<12.4f} {:<12.4f} {:<12.4f}".format(
            epoch+1,
            logs["loss"],
            logs["accuracy"],
            logs["val_loss"],
            logs["val_accuracy"]
        ))

# %%
checkpoint = ModelCheckpoint(
    "best_model_tow_idsIMGSIZE64.keras",
    monitor="val_accuracy",
    save_best_only=True,
    verbose=0
)

# %%
print("\nDataset summary")
print("-"*40)
print("Train samples :", X_train.shape[0])
print("Test samples  :", X_test.shape[0])
print("Validation samples  :", X_val.shape[0])
print("Image shape   :", X_train.shape[1:])
print("Batch size    :", 32)
print("Epochs        :", 50)
print("-"*40)
# Out:
# Dataset summary
# ----------------------------------------
# Train samples : 3291
# Test samples  : 3092
# Validation samples  : 1410
# Image shape   : (32, 32, 3)
# Batch size    : 32
# Epochs        : 50
# ----------------------------------------

# %%
history = model.fit(
    X_train, y_train,
    epochs=50,
    batch_size=32,
    validation_data=(X_val, y_val),
    verbose=1,
    callbacks=[checkpoint]
    
)
# Out:
# Epoch 1/50
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1779473435.877229  725455 service.cc:152] XLA service 0x7efdb00032a0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1779473435.877246  725455 service.cc:160]   StreamExecutor device (0): NVIDIA GeForce RTX 3060 Laptop GPU, Compute Capability 8.6
# 2026-05-23 01:10:36.019699: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1779473436.754147  725455 cuda_dnn.cc:529] Loaded cuDNN version 91701
#  32/103 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.5504 - auc: 0.5188 - loss: 0.0845 - pr_auc: 0.5999 - precision: 0.5794 - recall: 0.7874
# I0000 00:00:1779473443.935920  725455 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 25s 128ms/step - accuracy: 0.6338 - auc: 0.7586 - loss: 0.0617 - pr_auc: 0.7973 - precision: 0.6070 - recall: 0.9021 - val_accuracy: 0.7291 - val_auc: 0.9685 - val_loss: 0.0518 - val_pr_auc: 0.9835 - val_precision: 0.7291 - val_recall: 1.0000
# Epoch 2/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8304 - auc: 0.9549 - loss: 0.0351 - pr_auc: 0.9595 - precision: 0.7727 - recall: 0.9694 - val_accuracy: 0.7291 - val_auc: 0.9819 - val_loss: 0.0412 - val_pr_auc: 0.9891 - val_precision: 0.7291 - val_recall: 1.0000
# Epoch 3/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9143 - auc: 0.9804 - loss: 0.0238 - pr_auc: 0.9794 - precision: 0.8802 - recall: 0.9728 - val_accuracy: 0.8837 - val_auc: 0.9876 - val_loss: 0.0198 - val_pr_auc: 0.9920 - val_precision: 0.8624 - val_recall: 1.0000
# Epoch 4/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9462 - auc: 0.9871 - loss: 0.0184 - pr_auc: 0.9834 - precision: 0.9215 - recall: 0.9836 - val_accuracy: 0.9695 - val_auc: 0.9911 - val_loss: 0.0121 - val_pr_auc: 0.9946 - val_precision: 0.9633 - val_recall: 0.9961
# Epoch 5/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9532 - auc: 0.9908 - loss: 0.0149 - pr_auc: 0.9870 - precision: 0.9334 - recall: 0.9830 - val_accuracy: 0.9752 - val_auc: 0.9926 - val_loss: 0.0100 - val_pr_auc: 0.9953 - val_precision: 0.9724 - val_recall: 0.9942
# Epoch 6/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9651 - auc: 0.9916 - loss: 0.0130 - pr_auc: 0.9917 - precision: 0.9504 - recall: 0.9864 - val_accuracy: 0.9780 - val_auc: 0.9935 - val_loss: 0.0089 - val_pr_auc: 0.9958 - val_precision: 0.9770 - val_recall: 0.9932
# Epoch 7/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9681 - auc: 0.9930 - loss: 0.0119 - pr_auc: 0.9906 - precision: 0.9526 - recall: 0.9898 - val_accuracy: 0.9773 - val_auc: 0.9941 - val_loss: 0.0088 - val_pr_auc: 0.9967 - val_precision: 0.9807 - val_recall: 0.9883
# Epoch 8/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9717 - auc: 0.9955 - loss: 0.0096 - pr_auc: 0.9933 - precision: 0.9589 - recall: 0.9898 - val_accuracy: 0.9745 - val_auc: 0.9943 - val_loss: 0.0089 - val_pr_auc: 0.9969 - val_precision: 0.9825 - val_recall: 0.9825
# Epoch 9/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9769 - auc: 0.9959 - loss: 0.0086 - pr_auc: 0.9949 - precision: 0.9653 - recall: 0.9926 - val_accuracy: 0.9752 - val_auc: 0.9947 - val_loss: 0.0093 - val_pr_auc: 0.9973 - val_precision: 0.9853 - val_recall: 0.9805
# Epoch 10/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9778 - auc: 0.9963 - loss: 0.0080 - pr_auc: 0.9937 - precision: 0.9685 - recall: 0.9909 - val_accuracy: 0.9745 - val_auc: 0.9950 - val_loss: 0.0101 - val_pr_auc: 0.9975 - val_precision: 0.9882 - val_recall: 0.9767
# Epoch 11/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9736 - auc: 0.9958 - loss: 0.0088 - pr_auc: 0.9939 - precision: 0.9626 - recall: 0.9892 - val_accuracy: 0.9794 - val_auc: 0.9951 - val_loss: 0.0071 - val_pr_auc: 0.9973 - val_precision: 0.9808 - val_recall: 0.9912
# Epoch 12/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9778 - auc: 0.9964 - loss: 0.0079 - pr_auc: 0.9956 - precision: 0.9685 - recall: 0.9909 - val_accuracy: 0.9801 - val_auc: 0.9954 - val_loss: 0.0068 - val_pr_auc: 0.9977 - val_precision: 0.9817 - val_recall: 0.9912
# Epoch 13/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9824 - auc: 0.9974 - loss: 0.0066 - pr_auc: 0.9964 - precision: 0.9739 - recall: 0.9938 - val_accuracy: 0.9752 - val_auc: 0.9956 - val_loss: 0.0091 - val_pr_auc: 0.9978 - val_precision: 0.9892 - val_recall: 0.9767
# Epoch 14/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9793 - auc: 0.9969 - loss: 0.0071 - pr_auc: 0.9953 - precision: 0.9706 - recall: 0.9915 - val_accuracy: 0.9787 - val_auc: 0.9958 - val_loss: 0.0080 - val_pr_auc: 0.9980 - val_precision: 0.9883 - val_recall: 0.9825
# Epoch 15/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9799 - auc: 0.9975 - loss: 0.0066 - pr_auc: 0.9951 - precision: 0.9701 - recall: 0.9932 - val_accuracy: 0.9816 - val_auc: 0.9958 - val_loss: 0.0072 - val_pr_auc: 0.9978 - val_precision: 0.9883 - val_recall: 0.9864
# Epoch 16/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9796 - auc: 0.9968 - loss: 0.0071 - pr_auc: 0.9965 - precision: 0.9707 - recall: 0.9921 - val_accuracy: 0.9794 - val_auc: 0.9956 - val_loss: 0.0079 - val_pr_auc: 0.9976 - val_precision: 0.9892 - val_recall: 0.9825
# Epoch 17/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9793 - auc: 0.9970 - loss: 0.0069 - pr_auc: 0.9962 - precision: 0.9696 - recall: 0.9926 - val_accuracy: 0.9745 - val_auc: 0.9963 - val_loss: 0.0093 - val_pr_auc: 0.9983 - val_precision: 0.9892 - val_recall: 0.9757
# Epoch 18/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9827 - auc: 0.9980 - loss: 0.0057 - pr_auc: 0.9979 - precision: 0.9745 - recall: 0.9938 - val_accuracy: 0.9837 - val_auc: 0.9962 - val_loss: 0.0061 - val_pr_auc: 0.9983 - val_precision: 0.9846 - val_recall: 0.9932
# Epoch 19/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9818 - auc: 0.9976 - loss: 0.0063 - pr_auc: 0.9977 - precision: 0.9755 - recall: 0.9909 - val_accuracy: 0.9830 - val_auc: 0.9962 - val_loss: 0.0056 - val_pr_auc: 0.9980 - val_precision: 0.9799 - val_recall: 0.9971
# Epoch 20/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9812 - auc: 0.9976 - loss: 0.0061 - pr_auc: 0.9974 - precision: 0.9733 - recall: 0.9921 - val_accuracy: 0.9844 - val_auc: 0.9963 - val_loss: 0.0062 - val_pr_auc: 0.9981 - val_precision: 0.9883 - val_recall: 0.9903
# Epoch 21/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9857 - auc: 0.9989 - loss: 0.0047 - pr_auc: 0.9989 - precision: 0.9783 - recall: 0.9955 - val_accuracy: 0.9794 - val_auc: 0.9960 - val_loss: 0.0074 - val_pr_auc: 0.9978 - val_precision: 0.9892 - val_recall: 0.9825
# Epoch 22/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9854 - auc: 0.9982 - loss: 0.0055 - pr_auc: 0.9984 - precision: 0.9794 - recall: 0.9938 - val_accuracy: 0.9830 - val_auc: 0.9962 - val_loss: 0.0069 - val_pr_auc: 0.9981 - val_precision: 0.9893 - val_recall: 0.9874
# Epoch 23/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9860 - auc: 0.9985 - loss: 0.0048 - pr_auc: 0.9986 - precision: 0.9799 - recall: 0.9943 - val_accuracy: 0.9830 - val_auc: 0.9963 - val_loss: 0.0063 - val_pr_auc: 0.9982 - val_precision: 0.9883 - val_recall: 0.9883
# Epoch 24/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9854 - auc: 0.9986 - loss: 0.0048 - pr_auc: 0.9985 - precision: 0.9794 - recall: 0.9938 - val_accuracy: 0.9752 - val_auc: 0.9970 - val_loss: 0.0095 - val_pr_auc: 0.9988 - val_precision: 0.9901 - val_recall: 0.9757
# Epoch 25/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9872 - auc: 0.9986 - loss: 0.0048 - pr_auc: 0.9986 - precision: 0.9827 - recall: 0.9938 - val_accuracy: 0.9780 - val_auc: 0.9966 - val_loss: 0.0075 - val_pr_auc: 0.9984 - val_precision: 0.9892 - val_recall: 0.9805
# Epoch 26/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9839 - auc: 0.9985 - loss: 0.0048 - pr_auc: 0.9983 - precision: 0.9766 - recall: 0.9938 - val_accuracy: 0.9780 - val_auc: 0.9968 - val_loss: 0.0078 - val_pr_auc: 0.9986 - val_precision: 0.9892 - val_recall: 0.9805
# Epoch 27/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9921 - auc: 0.9990 - loss: 0.0039 - pr_auc: 0.9992 - precision: 0.9877 - recall: 0.9977 - val_accuracy: 0.9830 - val_auc: 0.9963 - val_loss: 0.0063 - val_pr_auc: 0.9980 - val_precision: 0.9893 - val_recall: 0.9874
# Epoch 28/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9878 - auc: 0.9990 - loss: 0.0041 - pr_auc: 0.9991 - precision: 0.9827 - recall: 0.9949 - val_accuracy: 0.9773 - val_auc: 0.9968 - val_loss: 0.0083 - val_pr_auc: 0.9986 - val_precision: 0.9902 - val_recall: 0.9786
# Epoch 29/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9891 - auc: 0.9994 - loss: 0.0036 - pr_auc: 0.9994 - precision: 0.9838 - recall: 0.9960 - val_accuracy: 0.9752 - val_auc: 0.9971 - val_loss: 0.0093 - val_pr_auc: 0.9988 - val_precision: 0.9901 - val_recall: 0.9757
# Epoch 30/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - accuracy: 0.9863 - auc: 0.9993 - loss: 0.0040 - pr_auc: 0.9994 - precision: 0.9826 - recall: 0.9921 - val_accuracy: 0.9865 - val_auc: 0.9965 - val_loss: 0.0054 - val_pr_auc: 0.9982 - val_precision: 0.9856 - val_recall: 0.9961
# Epoch 31/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9903 - auc: 0.9993 - loss: 0.0037 - pr_auc: 0.9994 - precision: 0.9855 - recall: 0.9966 - val_accuracy: 0.9766 - val_auc: 0.9966 - val_loss: 0.0096 - val_pr_auc: 0.9984 - val_precision: 0.9901 - val_recall: 0.9776
# Epoch 32/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9878 - auc: 0.9991 - loss: 0.0039 - pr_auc: 0.9992 - precision: 0.9811 - recall: 0.9966 - val_accuracy: 0.9801 - val_auc: 0.9969 - val_loss: 0.0069 - val_pr_auc: 0.9986 - val_precision: 0.9892 - val_recall: 0.9835
# Epoch 33/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9894 - auc: 0.9994 - loss: 0.0033 - pr_auc: 0.9995 - precision: 0.9849 - recall: 0.9955 - val_accuracy: 0.9773 - val_auc: 0.9973 - val_loss: 0.0100 - val_pr_auc: 0.9989 - val_precision: 0.9921 - val_recall: 0.9767
# Epoch 34/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9897 - auc: 0.9995 - loss: 0.0036 - pr_auc: 0.9996 - precision: 0.9849 - recall: 0.9960 - val_accuracy: 0.9688 - val_auc: 0.9974 - val_loss: 0.0150 - val_pr_auc: 0.9990 - val_precision: 0.9930 - val_recall: 0.9640
# Epoch 35/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9906 - auc: 0.9997 - loss: 0.0028 - pr_auc: 0.9997 - precision: 0.9860 - recall: 0.9966 - val_accuracy: 0.9780 - val_auc: 0.9973 - val_loss: 0.0082 - val_pr_auc: 0.9989 - val_precision: 0.9892 - val_recall: 0.9805
# Epoch 36/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9915 - auc: 0.9997 - loss: 0.0028 - pr_auc: 0.9997 - precision: 0.9871 - recall: 0.9972 - val_accuracy: 0.9823 - val_auc: 0.9973 - val_loss: 0.0061 - val_pr_auc: 0.9989 - val_precision: 0.9827 - val_recall: 0.9932
# Epoch 37/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9888 - auc: 0.9992 - loss: 0.0038 - pr_auc: 0.9993 - precision: 0.9827 - recall: 0.9966 - val_accuracy: 0.9816 - val_auc: 0.9974 - val_loss: 0.0068 - val_pr_auc: 0.9989 - val_precision: 0.9874 - val_recall: 0.9874
# Epoch 38/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9903 - auc: 0.9995 - loss: 0.0031 - pr_auc: 0.9996 - precision: 0.9849 - recall: 0.9972 - val_accuracy: 0.9801 - val_auc: 0.9974 - val_loss: 0.0075 - val_pr_auc: 0.9989 - val_precision: 0.9902 - val_recall: 0.9825
# Epoch 39/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9912 - auc: 0.9997 - loss: 0.0026 - pr_auc: 0.9998 - precision: 0.9866 - recall: 0.9972 - val_accuracy: 0.9823 - val_auc: 0.9973 - val_loss: 0.0062 - val_pr_auc: 0.9988 - val_precision: 0.9893 - val_recall: 0.9864
# Epoch 40/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9945 - auc: 0.9998 - loss: 0.0024 - pr_auc: 0.9998 - precision: 0.9921 - recall: 0.9977 - val_accuracy: 0.9816 - val_auc: 0.9973 - val_loss: 0.0065 - val_pr_auc: 0.9987 - val_precision: 0.9893 - val_recall: 0.9854
# Epoch 41/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9912 - auc: 0.9998 - loss: 0.0026 - pr_auc: 0.9998 - precision: 0.9866 - recall: 0.9972 - val_accuracy: 0.9801 - val_auc: 0.9976 - val_loss: 0.0079 - val_pr_auc: 0.9990 - val_precision: 0.9912 - val_recall: 0.9815
# Epoch 42/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9921 - auc: 0.9998 - loss: 0.0023 - pr_auc: 0.9999 - precision: 0.9888 - recall: 0.9966 - val_accuracy: 0.9787 - val_auc: 0.9976 - val_loss: 0.0086 - val_pr_auc: 0.9990 - val_precision: 0.9902 - val_recall: 0.9805
# Epoch 43/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9927 - auc: 0.9995 - loss: 0.0027 - pr_auc: 0.9996 - precision: 0.9899 - recall: 0.9966 - val_accuracy: 0.9809 - val_auc: 0.9974 - val_loss: 0.0080 - val_pr_auc: 0.9988 - val_precision: 0.9912 - val_recall: 0.9825
# Epoch 44/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9909 - auc: 0.9995 - loss: 0.0028 - pr_auc: 0.9994 - precision: 0.9860 - recall: 0.9972 - val_accuracy: 0.9837 - val_auc: 0.9975 - val_loss: 0.0054 - val_pr_auc: 0.9989 - val_precision: 0.9883 - val_recall: 0.9893
# Epoch 45/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9933 - auc: 0.9997 - loss: 0.0025 - pr_auc: 0.9998 - precision: 0.9904 - recall: 0.9972 - val_accuracy: 0.9830 - val_auc: 0.9972 - val_loss: 0.0060 - val_pr_auc: 0.9987 - val_precision: 0.9902 - val_recall: 0.9864
# Epoch 46/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9924 - auc: 0.9998 - loss: 0.0024 - pr_auc: 0.9998 - precision: 0.9893 - recall: 0.9966 - val_accuracy: 0.9787 - val_auc: 0.9976 - val_loss: 0.0087 - val_pr_auc: 0.9990 - val_precision: 0.9911 - val_recall: 0.9796
# Epoch 47/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9942 - auc: 0.9999 - loss: 0.0019 - pr_auc: 0.9999 - precision: 0.9910 - recall: 0.9983 - val_accuracy: 0.9794 - val_auc: 0.9976 - val_loss: 0.0084 - val_pr_auc: 0.9989 - val_precision: 0.9912 - val_recall: 0.9805
# Epoch 48/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9945 - auc: 0.9999 - loss: 0.0019 - pr_auc: 0.9999 - precision: 0.9921 - recall: 0.9977 - val_accuracy: 0.9773 - val_auc: 0.9978 - val_loss: 0.0089 - val_pr_auc: 0.9991 - val_precision: 0.9911 - val_recall: 0.9776
# Epoch 49/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9936 - auc: 0.9999 - loss: 0.0018 - pr_auc: 0.9999 - precision: 0.9916 - recall: 0.9966 - val_accuracy: 0.9823 - val_auc: 0.9979 - val_loss: 0.0065 - val_pr_auc: 0.9991 - val_precision: 0.9902 - val_recall: 0.9854
# Epoch 50/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9951 - auc: 0.9999 - loss: 0.0015 - pr_auc: 1.0000 - precision: 0.9916 - recall: 0.9994 - val_accuracy: 0.9837 - val_auc: 0.9975 - val_loss: 0.0064 - val_pr_auc: 0.9988 - val_precision: 0.9902 - val_recall: 0.9874

# %%
# =========================
# CELL 1
# =========================

import numpy as np
from sklearn.metrics import roc_curve

# prediksi probabilitas
y_prob = model.predict(X_test).ravel()

# label asli
y_true = y_test

# =========================
# EVALUASI DEFAULT THRESHOLD 0.5
# =========================

default_threshold = 0.5
y_pred_default = (y_prob >= default_threshold).astype(int)

# =========================
# CARI THRESHOLD TERBAIK
# =========================
# strategi:
# cari threshold dengan F1 tertinggi

thresholds = np.arange(0.1, 0.91, 0.01)

best_threshold = 0.5
best_f1 = 0

for th in thresholds:

    y_pred_temp = (y_prob >= th).astype(int)

    TP = np.sum((y_true == 1) & (y_pred_temp == 1))
    TN = np.sum((y_true == 0) & (y_pred_temp == 0))
    FP = np.sum((y_true == 0) & (y_pred_temp == 1))
    FN = np.sum((y_true == 1) & (y_pred_temp == 0))

    precision = TP / (TP + FP + 1e-12)
    recall = TP / (TP + FN + 1e-12)

    f1 = 2 * precision * recall / (precision + recall + 1e-12)

    if f1 > best_f1:
        best_f1 = f1
        best_threshold = th

print("Best Threshold:", best_threshold)
print("Best F1 Score :", best_f1)

# prediksi final threshold terbaik
y_pred_best = (y_prob >= best_threshold).astype(int)
# Out:
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 4s 27ms/step
# Best Threshold: 0.5799999999999997
# Best F1 Score : 0.9735343383579583

# %%
# =========================
# CELL 2
# =========================

from sklearn.metrics import confusion_matrix

# ===== DEFAULT 0.5 =====
cm_default = confusion_matrix(y_true, y_pred_default)

TN_d, FP_d, FN_d, TP_d = cm_default.ravel()

print("=== Confusion Matrix (Threshold = 0.5) ===")
print(cm_default)

# ===== BEST THRESHOLD =====
cm_best = confusion_matrix(y_true, y_pred_best)

TN_b, FP_b, FN_b, TP_b = cm_best.ravel()

print("\n=== Confusion Matrix (Best Threshold) ===")
print(cm_best)
# Out:
# === Confusion Matrix (Threshold = 0.5) ===
# [[1543   57]
#  [  34 1458]]
#
# === Confusion Matrix (Best Threshold) ===
# [[1560   40]
#  [  39 1453]]

# %%
# =========================
# CELL 3
# =========================

def calculate_metrics(TN, FP, FN, TP):

    accuracy = (TP + TN) / (TP + TN + FP + FN)

    precision = TP / (TP + FP + 1e-12)

    recall = TP / (TP + FN + 1e-12)

    f1 = 2 * precision * recall / (precision + recall + 1e-12)

    FPR = FP / (FP + TN + 1e-12)

    FNR = FN / (FN + TP + 1e-12)

    return accuracy, precision, recall, f1, FPR, FNR


# ===== DEFAULT =====
metrics_default = calculate_metrics(TN_d, FP_d, FN_d, TP_d)

# ===== BEST =====
metrics_best = calculate_metrics(TN_b, FP_b, FN_b, TP_b)

# %%
# =========================
# CELL 4
# =========================

metric_names = [
    "Accuracy",
    "Precision",
    "Recall",
    "F1-score",
    "FPR",
    "FNR"
]

print("========================================")
print("THRESHOLD = 0.5")
print("========================================")

for name, value in zip(metric_names, metrics_default):
    print(f"{name:10}: {value:.6f}")

print("\n")

print("========================================")
print(f"BEST THRESHOLD = {best_threshold:.2f}")
print("========================================")

for name, value in zip(metric_names, metrics_best):
    print(f"{name:10}: {value:.6f}")
# Out:
# ========================================
# THRESHOLD = 0.5
# ========================================
# Accuracy  : 0.970569
# Precision : 0.962376
# Recall    : 0.977212
# F1-score  : 0.969737
# FPR       : 0.035625
# FNR       : 0.022788
#
#
# ========================================
# BEST THRESHOLD = 0.58
# ========================================
# Accuracy  : 0.974450
# Precision : 0.973208
# Recall    : 0.973861
# F1-score  : 0.973534
# FPR       : 0.025000
# FNR       : 0.026139

# %%
# =========================
# CELL 5
# =========================

import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

fpr, tpr, _ = roc_curve(y_true, y_prob)

roc_auc = auc(fpr, tpr)

plt.figure(figsize=(6,6))

plt.plot(fpr, tpr, label="AUC = %0.4f" % roc_auc)

plt.plot([0,1],[0,1],'--')

plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")

plt.title("ROC Curve")

plt.legend()

plt.grid(True)

plt.show()
