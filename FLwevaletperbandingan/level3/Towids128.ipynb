# %%
import numpy as np
import os
import gc
import time
import matplotlib.pyplot as plt
import seaborn as sns

import tensorflow as tf
from tensorflow.keras import layers, models

from sklearn.metrics import (
    confusion_matrix,
    classification_report,
    roc_curve,
    auc,
    precision_recall_curve,
    f1_score
)
# Out:
# 2026-05-22 23:08:40.575144: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-05-22 23:08:40.586153: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1779466120.598820  518973 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1779466120.603157  518973 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1779466120.613018  518973 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1779466120.613036  518973 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1779466120.613037  518973 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1779466120.613038  518973 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-05-22 23:08:40.616224: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
import numpy as np
import os
import gc
import time
import matplotlib.pyplot as plt
import seaborn as sns

import tensorflow as tf
from tensorflow.keras import layers, models

from sklearn.metrics import (
    confusion_matrix,
    classification_report,
    roc_curve,
    auc,
    precision_recall_curve,
    f1_score
)

# %%
BASE_PATHHASIL = "/home/dani/Documents/tugas akhir/TugasAkhir/codeTugasAkhirku2026/tow_ids/Preprocessing/Preprocessingbaru/imgsize128lv3/norm/dwt/"

# %%
import tensorflow as tf
from tensorflow.keras import layers, models


def build_cnn_tow_ids(input_shape=(16, 16, 3)):

    inputs = layers.Input(shape=input_shape)

    # =========================================================
    # Block A
    # SeparableConv + ReLU
    # SeparableConv + ReLU
    # BatchNorm
    # MaxPooling
    # =========================================================

    x = layers.SeparableConv2D(
        32, (3,3),
        padding="same",
        use_bias=False
    )(inputs)
    x = layers.ReLU()(x)

    x = layers.SeparableConv2D(
        32, (3,3),
        padding="same",
        use_bias=False
    )(x)
    x = layers.ReLU()(x)

    x = layers.BatchNormalization()(x)

    x = layers.MaxPooling2D((2,2))(x)

    # =========================================================
    # Block B (Residual Block)
    #
    # shortcut:
    # Conv1x1 + BN
    #
    # main:
    # SepConv + ReLU
    # SepConv + ReLU
    # BN
    #
    # output:
    # Add + ReLU
    # =========================================================

    shortcut = layers.Conv2D(
        64,
        (1,1),
        padding="same",
        use_bias=False
    )(x)

    shortcut = layers.BatchNormalization()(shortcut)

    y = layers.SeparableConv2D(
        64,
        (3,3),
        padding="same",
        use_bias=False
    )(x)
    y = layers.ReLU()(y)

    y = layers.SeparableConv2D(
        64,
        (3,3),
        padding="same",
        use_bias=False
    )(y)
    y = layers.ReLU()(y)

    y = layers.BatchNormalization()(y)

    x = layers.Add()([y, shortcut])
    x = layers.ReLU()(x)

    # =========================================================
    # Block C
    #
    # SepConv + ReLU
    # GlobalAveragePooling
    # Dense + ReLU
    # Dense + ReLU
    # Dropout
    # Dense + Sigmoid
    # =========================================================

    x = layers.SeparableConv2D(
        128,
        (3,3),
        padding="same",
        use_bias=False
    )(x)
    x = layers.ReLU()(x)

    x = layers.GlobalAveragePooling2D()(x)

    x = layers.Dense(512, activation="relu")(x)

    x = layers.Dense(256, activation="relu")(x)

    x = layers.Dropout(0.5)(x)

    outputs = layers.Dense(
        1,
        activation="sigmoid"
    )(x)

    model = models.Model(inputs, outputs)

    model.compile(
        optimizer=tf.keras.optimizers.Adam(1e-3),
        loss="binary_crossentropy",
        metrics=[
            "accuracy",
            tf.keras.metrics.Precision(name="precision"),
            tf.keras.metrics.Recall(name="recall")
        ]
    )

    return model

# %%
train_data = np.load(os.path.join(BASE_PATHHASIL, "tow_ids_train_dwt.npz"))
test_data  = np.load(os.path.join(BASE_PATHHASIL, "tow_ids_test_dwt.npz"))
val_data   = np.load(os.path.join(BASE_PATHHASIL, "tow_ids_eval_dwt.npz"))

X_train = train_data["X"]
y_train = train_data["y"]

X_test  = test_data["X"]
y_test  = test_data["y"]

X_val   = val_data["X"]
y_val   = val_data["y"]

print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
print(X_val.shape, y_val.shape)
# Out:
# (6582, 16, 16, 3) (6582,)
# (6184, 16, 16, 3) (6184,)
# (2821, 16, 16, 3) (2821,)

# %%
tf.keras.backend.clear_session()

model = build_cnn_tow_ids()
model.summary()
# Out:
# I0000 00:00:1779466122.115217  518973 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 4144 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 16, 16, 3) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d    │ (None, 16, 16,    │        123 │ input_layer[0][0] │
# │ (SeparableConv2D)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu (ReLU)        │ (None, 16, 16,    │          0 │ separable_conv2d… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_1  │ (None, 16, 16,    │      1,312 │ re_lu[0][0]       │
# │ (SeparableConv2D)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_1 (ReLU)      │ (None, 16, 16,    │          0 │ separable_conv2d… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 16, 16,    │        128 │ re_lu_1[0][0]     │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 8, 8, 32)  │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_2  │ (None, 8, 8, 64)  │      2,336 │ max_pooling2d[0]… │
# │ (SeparableConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_2 (ReLU)      │ (None, 8, 8, 64)  │          0 │ separable_conv2d… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_3  │ (None, 8, 8, 64)  │      4,672 │ re_lu_2[0][0]     │
# │ (SeparableConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_3 (ReLU)      │ (None, 8, 8, 64)  │          0 │ separable_conv2d… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 8, 8, 64)  │      2,048 │ max_pooling2d[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 64)  │        256 │ re_lu_3[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 64)  │        256 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 8, 8, 64)  │          0 │ batch_normalizat… │
# │                     │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_4 (ReLU)      │ (None, 8, 8, 64)  │          0 │ add[0][0]         │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_4  │ (None, 8, 8, 128) │      8,768 │ re_lu_4[0][0]     │
# │ (SeparableConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_5 (ReLU)      │ (None, 8, 8, 128) │          0 │ separable_conv2d… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 128)       │          0 │ re_lu_5[0][0]     │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 512)       │     66,048 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 256)       │    131,328 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 256)       │          0 │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 1)         │        257 │ dropout[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 217,532 (849.73 KB)
#  Trainable params: 217,212 (848.48 KB)
#  Non-trainable params: 320 (1.25 KB)

# %%
history = model.fit(
    X_train, y_train,
    epochs=50,
    batch_size=32,
    validation_data=(X_val, y_val),
    verbose=1,
    
)
# Out:
# Epoch 1/50
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1779466124.531139  519114 service.cc:152] XLA service 0x7182e0003050 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1779466124.531160  519114 service.cc:160]   StreamExecutor device (0): NVIDIA GeForce RTX 3060 Laptop GPU, Compute Capability 8.6
# 2026-05-22 23:08:44.586660: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1779466124.935536  519114 cuda_dnn.cc:529] Loaded cuDNN version 91701
# 2026-05-22 23:08:46.582112: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1485_0', 44 bytes spill stores, 44 bytes spill loads
#
# 2026-05-22 23:08:46.868297: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2263', 32 bytes spill stores, 32 bytes spill loads
#
# 2026-05-22 23:08:46.872879: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1485', 484 bytes spill stores, 484 bytes spill loads
#
# 2026-05-22 23:08:46.912747: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2263', 36 bytes spill stores, 44 bytes spill loads
#
# 2026-05-22 23:08:47.696602: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2261', 36 bytes spill stores, 44 bytes spill loads
#
# 2026-05-22 23:08:47.896540: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2263', 32 bytes spill stores, 32 bytes spill loads
#
# I0000 00:00:1779466132.008367  519114 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 196/206 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.7613 - loss: 0.4402 - precision: 0.7529 - recall: 0.8541
# 2026-05-22 23:08:54.150011: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1485', 488 bytes spill stores, 488 bytes spill loads
#
# 2026-05-22 23:08:55.043287: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1485_0', 36 bytes spill stores, 36 bytes spill loads
#
# 2026-05-22 23:08:55.105085: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2261', 28 bytes spill stores, 32 bytes spill loads
#
# 2026-05-22 23:08:55.227286: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2263', 32 bytes spill stores, 32 bytes spill loads
#
# 2026-05-22 23:08:55.608786: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2263', 28 bytes spill stores, 32 bytes spill loads
#
# 2026-05-22 23:08:56.152661: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2263', 32 bytes spill stores, 32 bytes spill loads
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 0s 38ms/step - accuracy: 0.7663 - loss: 0.4338 - precision: 0.7586 - recall: 0.8550
# 2026-05-22 23:09:02.294860: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_176', 64 bytes spill stores, 64 bytes spill loads
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 23s 63ms/step - accuracy: 0.8660 - loss: 0.3083 - precision: 0.8713 - recall: 0.8729 - val_accuracy: 0.6856 - val_loss: 1.0206 - val_precision: 0.6856 - val_recall: 1.0000
# Epoch 2/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9474 - loss: 0.1613 - precision: 0.9731 - recall: 0.9251 - val_accuracy: 0.6856 - val_loss: 1.1399 - val_precision: 0.6856 - val_recall: 1.0000
# Epoch 3/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9531 - loss: 0.1357 - precision: 0.9740 - recall: 0.9353 - val_accuracy: 0.9103 - val_loss: 0.2251 - val_precision: 0.9435 - val_recall: 0.9245
# Epoch 4/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9553 - loss: 0.1257 - precision: 0.9764 - recall: 0.9373 - val_accuracy: 0.6994 - val_loss: 0.7264 - val_precision: 0.7377 - val_recall: 0.8713
# Epoch 5/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9629 - loss: 0.1142 - precision: 0.9816 - recall: 0.9469 - val_accuracy: 0.4023 - val_loss: 2.2915 - val_precision: 0.9960 - val_recall: 0.1287
# Epoch 6/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9620 - loss: 0.1120 - precision: 0.9787 - recall: 0.9480 - val_accuracy: 0.8798 - val_loss: 0.2898 - val_precision: 0.8829 - val_recall: 0.9509
# Epoch 7/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9669 - loss: 0.0997 - precision: 0.9824 - recall: 0.9538 - val_accuracy: 0.9082 - val_loss: 0.2504 - val_precision: 0.9729 - val_recall: 0.8909
# Epoch 8/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9722 - loss: 0.0884 - precision: 0.9869 - recall: 0.9597 - val_accuracy: 0.4647 - val_loss: 2.5410 - val_precision: 0.9609 - val_recall: 0.2285
# Epoch 9/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9708 - loss: 0.0908 - precision: 0.9851 - recall: 0.9588 - val_accuracy: 0.8011 - val_loss: 0.4756 - val_precision: 0.9326 - val_recall: 0.7653
# Epoch 10/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9742 - loss: 0.0831 - precision: 0.9887 - recall: 0.9617 - val_accuracy: 0.5016 - val_loss: 2.0736 - val_precision: 0.9681 - val_recall: 0.2823
# Epoch 11/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9760 - loss: 0.0779 - precision: 0.9881 - recall: 0.9657 - val_accuracy: 0.6445 - val_loss: 1.2475 - val_precision: 0.9989 - val_recall: 0.4819
# Epoch 12/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9749 - loss: 0.0782 - precision: 0.9901 - recall: 0.9617 - val_accuracy: 0.5119 - val_loss: 1.6231 - val_precision: 0.9372 - val_recall: 0.3087
# Epoch 13/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9784 - loss: 0.0733 - precision: 0.9914 - recall: 0.9672 - val_accuracy: 0.4123 - val_loss: 3.6528 - val_precision: 0.9894 - val_recall: 0.1443
# Epoch 14/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9804 - loss: 0.0627 - precision: 0.9937 - recall: 0.9687 - val_accuracy: 0.6388 - val_loss: 1.1857 - val_precision: 0.9692 - val_recall: 0.4886
# Epoch 15/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9813 - loss: 0.0610 - precision: 0.9941 - recall: 0.9701 - val_accuracy: 0.3807 - val_loss: 3.2494 - val_precision: 0.9947 - val_recall: 0.0972
# Epoch 16/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9796 - loss: 0.0722 - precision: 0.9926 - recall: 0.9684 - val_accuracy: 0.4311 - val_loss: 3.3634 - val_precision: 0.9768 - val_recall: 0.1743
# Epoch 17/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9809 - loss: 0.0651 - precision: 0.9917 - recall: 0.9716 - val_accuracy: 0.6519 - val_loss: 1.2387 - val_precision: 0.9887 - val_recall: 0.4979
# Epoch 18/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9834 - loss: 0.0554 - precision: 0.9947 - recall: 0.9736 - val_accuracy: 0.3928 - val_loss: 4.6523 - val_precision: 0.9868 - val_recall: 0.1158
# Epoch 19/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9831 - loss: 0.0549 - precision: 0.9941 - recall: 0.9736 - val_accuracy: 0.8688 - val_loss: 0.4220 - val_precision: 0.8938 - val_recall: 0.9178
# Epoch 20/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9822 - loss: 0.0590 - precision: 0.9932 - recall: 0.9727 - val_accuracy: 0.6473 - val_loss: 2.0686 - val_precision: 0.9916 - val_recall: 0.4897
# Epoch 21/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9837 - loss: 0.0541 - precision: 0.9923 - recall: 0.9765 - val_accuracy: 0.9096 - val_loss: 0.3757 - val_precision: 0.9299 - val_recall: 0.9390
# Epoch 22/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9857 - loss: 0.0473 - precision: 0.9944 - recall: 0.9782 - val_accuracy: 0.4101 - val_loss: 5.0545 - val_precision: 0.9754 - val_recall: 0.1432
# Epoch 23/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9881 - loss: 0.0390 - precision: 0.9965 - recall: 0.9808 - val_accuracy: 0.6615 - val_loss: 1.4644 - val_precision: 0.9794 - val_recall: 0.5171
# Epoch 24/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9868 - loss: 0.0433 - precision: 0.9947 - recall: 0.9800 - val_accuracy: 0.8862 - val_loss: 0.4129 - val_precision: 0.9172 - val_recall: 0.9168
# Epoch 25/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9853 - loss: 0.0466 - precision: 0.9938 - recall: 0.9779 - val_accuracy: 0.7239 - val_loss: 1.1951 - val_precision: 0.9558 - val_recall: 0.6262
# Epoch 26/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9862 - loss: 0.0396 - precision: 0.9935 - recall: 0.9800 - val_accuracy: 0.4112 - val_loss: 7.0579 - val_precision: 0.9858 - val_recall: 0.1432
# Epoch 27/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9869 - loss: 0.0395 - precision: 0.9947 - recall: 0.9803 - val_accuracy: 0.5870 - val_loss: 2.7398 - val_precision: 0.9886 - val_recall: 0.4023
# Epoch 28/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9872 - loss: 0.0386 - precision: 0.9930 - recall: 0.9826 - val_accuracy: 0.6533 - val_loss: 2.5165 - val_precision: 0.9535 - val_recall: 0.5196
# Epoch 29/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9880 - loss: 0.0363 - precision: 0.9953 - recall: 0.9817 - val_accuracy: 0.7239 - val_loss: 1.1923 - val_precision: 0.7692 - val_recall: 0.8532
# Epoch 30/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9885 - loss: 0.0375 - precision: 0.9944 - recall: 0.9835 - val_accuracy: 0.6990 - val_loss: 1.4831 - val_precision: 0.9721 - val_recall: 0.5776
# Epoch 31/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9912 - loss: 0.0267 - precision: 0.9953 - recall: 0.9878 - val_accuracy: 0.4807 - val_loss: 4.2224 - val_precision: 0.9776 - val_recall: 0.2482
# Epoch 32/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9880 - loss: 0.0353 - precision: 0.9935 - recall: 0.9835 - val_accuracy: 0.7306 - val_loss: 2.4550 - val_precision: 0.7246 - val_recall: 0.9793
# Epoch 33/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9912 - loss: 0.0259 - precision: 0.9947 - recall: 0.9884 - val_accuracy: 0.7682 - val_loss: 0.9916 - val_precision: 0.9360 - val_recall: 0.7104
# Epoch 34/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9889 - loss: 0.0315 - precision: 0.9933 - recall: 0.9855 - val_accuracy: 0.4282 - val_loss: 4.8970 - val_precision: 0.9350 - val_recall: 0.1784
# Epoch 35/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9907 - loss: 0.0303 - precision: 0.9953 - recall: 0.9869 - val_accuracy: 0.8036 - val_loss: 1.0420 - val_precision: 0.9733 - val_recall: 0.7337
# Epoch 36/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9915 - loss: 0.0282 - precision: 0.9962 - recall: 0.9875 - val_accuracy: 0.5413 - val_loss: 4.0446 - val_precision: 0.9720 - val_recall: 0.3407
# Epoch 37/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9889 - loss: 0.0289 - precision: 0.9933 - recall: 0.9855 - val_accuracy: 0.4449 - val_loss: 7.3662 - val_precision: 0.9694 - val_recall: 0.1965
# Epoch 38/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9907 - loss: 0.0253 - precision: 0.9953 - recall: 0.9869 - val_accuracy: 0.7522 - val_loss: 1.6993 - val_precision: 0.9874 - val_recall: 0.6468
# Epoch 39/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9929 - loss: 0.0189 - precision: 0.9953 - recall: 0.9910 - val_accuracy: 0.8688 - val_loss: 0.5676 - val_precision: 0.9479 - val_recall: 0.8557
# Epoch 40/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9892 - loss: 0.0323 - precision: 0.9941 - recall: 0.9852 - val_accuracy: 0.5675 - val_loss: 4.0498 - val_precision: 0.9508 - val_recall: 0.3893
# Epoch 41/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9930 - loss: 0.0203 - precision: 0.9953 - recall: 0.9913 - val_accuracy: 0.4867 - val_loss: 4.9297 - val_precision: 0.9880 - val_recall: 0.2544
# Epoch 42/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9891 - loss: 0.0257 - precision: 0.9918 - recall: 0.9872 - val_accuracy: 0.5211 - val_loss: 4.5506 - val_precision: 0.9834 - val_recall: 0.3066
# Epoch 43/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9921 - loss: 0.0217 - precision: 0.9956 - recall: 0.9893 - val_accuracy: 0.4552 - val_loss: 10.1774 - val_precision: 0.9901 - val_recall: 0.2073
# Epoch 44/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9935 - loss: 0.0140 - precision: 0.9959 - recall: 0.9916 - val_accuracy: 0.5406 - val_loss: 5.5147 - val_precision: 0.9570 - val_recall: 0.3454
# Epoch 45/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9906 - loss: 0.0256 - precision: 0.9930 - recall: 0.9890 - val_accuracy: 0.6235 - val_loss: 3.0453 - val_precision: 0.9855 - val_recall: 0.4576
# Epoch 46/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9957 - loss: 0.0130 - precision: 0.9974 - recall: 0.9945 - val_accuracy: 0.5151 - val_loss: 4.9103 - val_precision: 0.9829 - val_recall: 0.2978
# Epoch 47/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9919 - loss: 0.0218 - precision: 0.9956 - recall: 0.9890 - val_accuracy: 0.6069 - val_loss: 2.5795 - val_precision: 0.9769 - val_recall: 0.4369
# Epoch 48/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9950 - loss: 0.0129 - precision: 0.9971 - recall: 0.9933 - val_accuracy: 0.7200 - val_loss: 2.1413 - val_precision: 0.9807 - val_recall: 0.6034
# Epoch 49/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9960 - loss: 0.0119 - precision: 0.9980 - recall: 0.9945 - val_accuracy: 0.4644 - val_loss: 8.2937 - val_precision: 0.9669 - val_recall: 0.2265
# Epoch 50/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9930 - loss: 0.0205 - precision: 0.9953 - recall: 0.9913 - val_accuracy: 0.5608 - val_loss: 3.6584 - val_precision: 0.9793 - val_recall: 0.3671

# %%
# =========================
# CELL 1
# =========================

import numpy as np
from sklearn.metrics import roc_curve

# prediksi probabilitas
y_prob = model.predict(X_test).ravel()

# label asli
y_true = y_test

# =========================
# EVALUASI DEFAULT THRESHOLD 0.5
# =========================

default_threshold = 0.5
y_pred_default = (y_prob >= default_threshold).astype(int)

# =========================
# CARI THRESHOLD TERBAIK
# =========================
# strategi:
# cari threshold dengan F1 tertinggi

thresholds = np.arange(0.1, 0.91, 0.01)

best_threshold = 0.5
best_f1 = 0

for th in thresholds:

    y_pred_temp = (y_prob >= th).astype(int)

    TP = np.sum((y_true == 1) & (y_pred_temp == 1))
    TN = np.sum((y_true == 0) & (y_pred_temp == 0))
    FP = np.sum((y_true == 0) & (y_pred_temp == 1))
    FN = np.sum((y_true == 1) & (y_pred_temp == 0))

    precision = TP / (TP + FP + 1e-12)
    recall = TP / (TP + FN + 1e-12)

    f1 = 2 * precision * recall / (precision + recall + 1e-12)

    if f1 > best_f1:
        best_f1 = f1
        best_threshold = th

print("Best Threshold:", best_threshold)
print("Best F1 Score :", best_f1)

# prediksi final threshold terbaik
y_pred_best = (y_prob >= best_threshold).astype(int)
# Out:
# 184/194 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2026-05-22 23:09:43.237540: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_138', 64 bytes spill stores, 64 bytes spill loads
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step
# Best Threshold: 0.2599999999999999
# Best F1 Score : 0.8457969938759172

# %%
# =========================
# CELL 2
# =========================

from sklearn.metrics import confusion_matrix

# ===== DEFAULT 0.5 =====
cm_default = confusion_matrix(y_true, y_pred_default)

TN_d, FP_d, FN_d, TP_d = cm_default.ravel()

print("=== Confusion Matrix (Threshold = 0.5) ===")
print(cm_default)

# ===== BEST THRESHOLD =====
cm_best = confusion_matrix(y_true, y_pred_best)

TN_b, FP_b, FN_b, TP_b = cm_best.ravel()

print("\n=== Confusion Matrix (Best Threshold) ===")
print(cm_best)
# Out:
# === Confusion Matrix (Threshold = 0.5) ===
# [[3124  172]
#  [ 668 2220]]
#
# === Confusion Matrix (Best Threshold) ===
# [[3074  222]
#  [ 609 2279]]

# %%
# =========================
# CELL 3
# =========================

def calculate_metrics(TN, FP, FN, TP):

    accuracy = (TP + TN) / (TP + TN + FP + FN)

    precision = TP / (TP + FP + 1e-12)

    recall = TP / (TP + FN + 1e-12)

    f1 = 2 * precision * recall / (precision + recall + 1e-12)

    FPR = FP / (FP + TN + 1e-12)

    FNR = FN / (FN + TP + 1e-12)

    return accuracy, precision, recall, f1, FPR, FNR


# ===== DEFAULT =====
metrics_default = calculate_metrics(TN_d, FP_d, FN_d, TP_d)

# ===== BEST =====
metrics_best = calculate_metrics(TN_b, FP_b, FN_b, TP_b)

# %%
# =========================
# CELL 4
# =========================

metric_names = [
    "Accuracy",
    "Precision",
    "Recall",
    "F1-score",
    "FPR",
    "FNR"
]

print("========================================")
print("THRESHOLD = 0.5")
print("========================================")

for name, value in zip(metric_names, metrics_default):
    print(f"{name:10}: {value:.6f}")

print("\n")

print("========================================")
print(f"BEST THRESHOLD = {best_threshold:.2f}")
print("========================================")

for name, value in zip(metric_names, metrics_best):
    print(f"{name:10}: {value:.6f}")
# Out:
# ========================================
# THRESHOLD = 0.5
# ========================================
# Accuracy  : 0.864166
# Precision : 0.928094
# Recall    : 0.768698
# F1-score  : 0.840909
# FPR       : 0.052184
# FNR       : 0.231302
#
#
# ========================================
# BEST THRESHOLD = 0.26
# ========================================
# Accuracy  : 0.865621
# Precision : 0.911236
# Recall    : 0.789127
# F1-score  : 0.845797
# FPR       : 0.067354
# FNR       : 0.210873

# %%
# =========================
# CELL 5
# =========================

import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

fpr, tpr, _ = roc_curve(y_true, y_prob)

roc_auc = auc(fpr, tpr)

plt.figure(figsize=(6,6))

plt.plot(fpr, tpr, label="AUC = %0.4f" % roc_auc)

plt.plot([0,1],[0,1],'--')

plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")

plt.title("ROC Curve")

plt.legend()

plt.grid(True)

plt.show()
