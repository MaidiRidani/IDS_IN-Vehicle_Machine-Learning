# %%
import numpy as np
import os
import gc
import time
import matplotlib.pyplot as plt
import seaborn as sns

import tensorflow as tf
from tensorflow.keras import layers, models

from sklearn.metrics import (
    confusion_matrix,
    classification_report,
    roc_curve,
    auc,
    precision_recall_curve,
    f1_score
)

import pandas as pd
import time
from tensorflow.keras.callbacks import Callback, EarlyStopping, ModelCheckpoint
from tensorflow.keras.callbacks import ReduceLROnPlateau, CSVLogger
# Out:
# 2026-05-23 00:58:08.265743: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-05-23 00:58:08.277362: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1779472688.291812  689254 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1779472688.296411  689254 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1779472688.307511  689254 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1779472688.307532  689254 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1779472688.307534  689254 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1779472688.307536  689254 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-05-23 00:58:08.311024: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
Load_Path = "/home/dani/Documents/tugas akhir/TugasAkhir/codeTugasAkhirku2026/tow_ids/Preprocessing/Preprocessingbaru/imgsize64lv2/norm/dwt/"
ukuran = 16

# %%
train_data = np.load(os.path.join(Load_Path, "tow_ids_train_dwt.npz"))
test_data  = np.load(os.path.join(Load_Path, "tow_ids_test_dwt.npz"))
validation_data = np.load(os.path.join(Load_Path, "tow_ids_eval_dwt.npz"))

X_train = train_data["X"]
y_train = train_data["y"]

X_val = validation_data["X"]
y_val = validation_data["y"]

X_test  = test_data["X"]
y_test  = test_data["y"]

print(X_train.shape, y_train.shape)
print(X_val.shape, y_val.shape)
print(X_test.shape, y_test.shape)
# Out:
# (13165, 16, 16, 3) (13165,)
# (5642, 16, 16, 3) (5642,)
# (12368, 16, 16, 3) (12368,)

# %%
print("Train label distribution:", np.unique(y_train, return_counts=True))
print("Test label distribution :", np.unique(y_test, return_counts=True))
print("Validation label distribution :", np.unique(y_val, return_counts=True))

print("Min value:", X_train.min())
print("Max value:", X_train.max())
# Out:
# Train label distribution: (array([0, 1]), array([6563, 6602]))
# Test label distribution : (array([0, 1]), array([6846, 5522]))
# Validation label distribution : (array([0, 1]), array([2012, 3630]))
# Min value: -0.72018355
# Max value: 3.8157082

# %%
import tensorflow as tf
from tensorflow.keras import layers, models


def composite_conv(x, filters, kernel_size):
    x = layers.Conv2D(
        filters,
        kernel_size,
        padding="same",
        use_bias=False
    )(x)

    x = layers.BatchNormalization()(x)

    x = layers.ReLU()(x)

    return x


def SE_block(x, ratio=16):
    channels = x.shape[-1]

    se = layers.GlobalAveragePooling2D()(x)

    se = layers.Dense(
        max(channels // ratio, 4),
        activation="relu"
    )(se)

    se = layers.Dense(
        channels,
        activation="sigmoid"
    )(se)

    se = layers.Reshape((1, 1, channels))(se)

    out = layers.Multiply()([x, se])

    return out


def DPDB_block(x, filters, pool=True):
    shortcut = x

    h = composite_conv(x, filters // 2, (1, 3))

    v = composite_conv(x, filters // 2, (3, 1))

    concat = layers.Concatenate()([h, v])

    fusion = composite_conv(concat, filters, (1, 1))

    fusion = SE_block(fusion)

    if pool:
        fusion = layers.MaxPooling2D((2, 2))(fusion)

    shortcut = layers.Conv2D(
        filters,
        (1, 1),
        padding="same",
        use_bias=False
    )(shortcut)

    shortcut = layers.BatchNormalization()(shortcut)

    if pool:
        shortcut = layers.MaxPooling2D((2, 2))(shortcut)

    out = layers.Add()([fusion, shortcut])

    out = layers.ReLU()(out)

    return out


input_layer = layers.Input(shape=(ukuran, ukuran, 3))

x = composite_conv(input_layer, 16, (1, 3))

x = composite_conv(x, 16, (3, 1))

x = DPDB_block(x, 32, pool=True)

x = DPDB_block(x, 64, pool=False)

x = composite_conv(x, 48, (1, 1))

x = layers.GlobalAveragePooling2D()(x)

x = layers.Dense(
    64,
    activation="relu"
)(x)

x = layers.Dropout(0.5)(x)

output_layer = layers.Dense(
    1,
    activation="sigmoid"
)(x)

model = models.Model(
    inputs=input_layer,
    outputs=output_layer
)

model.compile(

    optimizer=tf.keras.optimizers.AdamW(
        learning_rate=1e-4,
        weight_decay=1e-5
    ),

    loss=tf.keras.losses.BinaryFocalCrossentropy(
        apply_class_balancing=True,
        alpha=0.75,
        gamma=2.0
    ),

    metrics=[

        tf.keras.metrics.BinaryAccuracy(
            name="accuracy"
        ),

        tf.keras.metrics.Precision(
            name="precision"
        ),

        tf.keras.metrics.Recall(
            name="recall"
        ),

        tf.keras.metrics.AUC(
            name="auc"
        ),

        tf.keras.metrics.AUC(
            curve="PR",
            name="pr_auc"
        )
    ]
)

model.summary()
# Out:
# I0000 00:00:1779472689.841219  689254 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 4144 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 16, 16, 3) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 16, 16,    │        144 │ input_layer[0][0] │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 16, 16,    │         64 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu (ReLU)        │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 16, 16,    │        768 │ re_lu[0][0]       │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │         64 │ conv2d_1[0][0]    │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_1 (ReLU)      │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 16, 16,    │        768 │ re_lu_1[0][0]     │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 16, 16,    │        768 │ re_lu_1[0][0]     │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │         64 │ conv2d_2[0][0]    │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │         64 │ conv2d_3[0][0]    │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_2 (ReLU)      │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_3 (ReLU)      │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 16, 16,    │          0 │ re_lu_2[0][0],    │
# │ (Concatenate)       │ 32)               │            │ re_lu_3[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 16, 16,    │      1,024 │ concatenate[0][0] │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        128 │ conv2d_4[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_4 (ReLU)      │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 32)        │          0 │ re_lu_4[0][0]     │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 4)         │        132 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 32)        │        160 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape (Reshape)   │ (None, 1, 1, 32)  │          0 │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 16, 16,    │        512 │ re_lu_1[0][0]     │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply (Multiply) │ (None, 16, 16,    │          0 │ re_lu_4[0][0],    │
# │                     │ 32)               │            │ reshape[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        128 │ conv2d_5[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 8, 8, 32)  │          0 │ multiply[0][0]    │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 8, 8, 32)  │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 8, 8, 32)  │          0 │ max_pooling2d[0]… │
# │                     │                   │            │ max_pooling2d_1[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_5 (ReLU)      │ (None, 8, 8, 32)  │          0 │ add[0][0]         │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 8, 8, 32)  │      3,072 │ re_lu_5[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 8, 8, 32)  │      3,072 │ re_lu_5[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 32)  │        128 │ conv2d_6[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 32)  │        128 │ conv2d_7[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_6 (ReLU)      │ (None, 8, 8, 32)  │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_7 (ReLU)      │ (None, 8, 8, 32)  │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 8, 8, 64)  │          0 │ re_lu_6[0][0],    │
# │ (Concatenate)       │                   │            │ re_lu_7[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 8, 8, 64)  │      4,096 │ concatenate_1[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 64)  │        256 │ conv2d_8[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_8 (ReLU)      │ (None, 8, 8, 64)  │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 64)        │          0 │ re_lu_8[0][0]     │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 4)         │        260 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 64)        │        320 │ dense_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_1 (Reshape) │ (None, 1, 1, 64)  │          0 │ dense_3[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 8, 8, 64)  │      2,048 │ re_lu_5[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_1          │ (None, 8, 8, 64)  │          0 │ re_lu_8[0][0],    │
# │ (Multiply)          │                   │            │ reshape_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 64)  │        256 │ conv2d_9[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 8, 8, 64)  │          0 │ multiply_1[0][0], │
# │                     │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_9 (ReLU)      │ (None, 8, 8, 64)  │          0 │ add_1[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 8, 8, 48)  │      3,072 │ re_lu_9[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 48)  │        192 │ conv2d_10[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_10 (ReLU)     │ (None, 8, 8, 48)  │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 48)        │          0 │ re_lu_10[0][0]    │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_4 (Dense)     │ (None, 64)        │      3,136 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 64)        │          0 │ dense_4[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_5 (Dense)     │ (None, 1)         │         65 │ dropout[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 24,889 (97.22 KB)
#  Trainable params: 24,153 (94.35 KB)
#  Non-trainable params: 736 (2.88 KB)

# %%
print("TensorFlow version:", tf.__version__)
print("GPU available:", tf.config.list_physical_devices('GPU'))

tf.debugging.set_log_device_placement(True)
# Out:
# TensorFlow version: 2.19.1
# GPU available: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
class TrainingLogger(Callback):

    def on_train_begin(self, logs=None):
        print("\nTraining started")
        print("-"*70)
        print("{:<8} {:<12} {:<12} {:<12} {:<12}".format(
            "Epoch","Loss","Accuracy","Val_Loss","Val_Acc"))
        print("-"*70)

    def on_epoch_end(self, epoch, logs=None):

        print("{:<8} {:<12.4f} {:<12.4f} {:<12.4f} {:<12.4f}".format(
            epoch+1,
            logs["loss"],
            logs["accuracy"],
            logs["val_loss"],
            logs["val_accuracy"]
        ))

# %%
checkpoint = ModelCheckpoint(
    "best_model_tow_idsIMGSIZE64.keras",
    monitor="val_accuracy",
    save_best_only=True,
    verbose=0
)

# %%
print("\nDataset summary")
print("-"*40)
print("Train samples :", X_train.shape[0])
print("Test samples  :", X_test.shape[0])
print("Validation samples  :", X_val.shape[0])
print("Image shape   :", X_train.shape[1:])
print("Batch size    :", 32)
print("Epochs        :", 50)
print("-"*40)
# Out:
# Dataset summary
# ----------------------------------------
# Train samples : 13165
# Test samples  : 12368
# Validation samples  : 5642
# Image shape   : (16, 16, 3)
# Batch size    : 32
# Epochs        : 50
# ----------------------------------------

# %%
history = model.fit(
    X_train, y_train,
    epochs=50,
    batch_size=32,
    validation_data=(X_val, y_val),
    verbose=1,
    callbacks=[checkpoint]
    
)
# Out:
# Epoch 1/50
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1779472694.697034  689418 service.cc:152] XLA service 0x716748003b40 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1779472694.697063  689418 service.cc:160]   StreamExecutor device (0): NVIDIA GeForce RTX 3060 Laptop GPU, Compute Capability 8.6
# 2026-05-23 00:58:14.830143: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1779472695.583076  689418 cuda_dnn.cc:529] Loaded cuDNN version 91701
#  44/412 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.4886 - auc: 0.5427 - loss: 0.1189 - pr_auc: 0.5628 - precision: 0.5333 - recall: 0.3523
# I0000 00:00:1779472702.554214  689418 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 25s 31ms/step - accuracy: 0.5971 - auc: 0.7219 - loss: 0.0671 - pr_auc: 0.7594 - precision: 0.5663 - recall: 0.8402 - val_accuracy: 0.7512 - val_auc: 0.9433 - val_loss: 0.0568 - val_pr_auc: 0.9710 - val_precision: 0.7282 - val_recall: 0.9785
# Epoch 2/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.8169 - auc: 0.9446 - loss: 0.0359 - pr_auc: 0.9560 - precision: 0.7569 - recall: 0.9353 - val_accuracy: 0.9124 - val_auc: 0.9709 - val_loss: 0.0288 - val_pr_auc: 0.9845 - val_precision: 0.9115 - val_recall: 0.9567
# Epoch 3/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9363 - auc: 0.9836 - loss: 0.0200 - pr_auc: 0.9874 - precision: 0.9124 - recall: 0.9658 - val_accuracy: 0.9206 - val_auc: 0.9738 - val_loss: 0.0421 - val_pr_auc: 0.9843 - val_precision: 0.9807 - val_recall: 0.8942
# Epoch 4/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9576 - auc: 0.9899 - loss: 0.0145 - pr_auc: 0.9923 - precision: 0.9461 - recall: 0.9708 - val_accuracy: 0.8196 - val_auc: 0.9651 - val_loss: 0.0685 - val_pr_auc: 0.9756 - val_precision: 0.9801 - val_recall: 0.7344
# Epoch 5/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9633 - auc: 0.9910 - loss: 0.0132 - pr_auc: 0.9933 - precision: 0.9540 - recall: 0.9738 - val_accuracy: 0.6143 - val_auc: 0.9449 - val_loss: 0.1519 - val_pr_auc: 0.9623 - val_precision: 0.9796 - val_recall: 0.4091
# Epoch 6/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9671 - auc: 0.9928 - loss: 0.0119 - pr_auc: 0.9942 - precision: 0.9607 - recall: 0.9743 - val_accuracy: 0.8018 - val_auc: 0.9484 - val_loss: 0.0742 - val_pr_auc: 0.9664 - val_precision: 0.9711 - val_recall: 0.7132
# Epoch 7/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9705 - auc: 0.9936 - loss: 0.0109 - pr_auc: 0.9950 - precision: 0.9641 - recall: 0.9776 - val_accuracy: 0.6705 - val_auc: 0.9187 - val_loss: 0.1346 - val_pr_auc: 0.9505 - val_precision: 0.9789 - val_recall: 0.4986
# Epoch 8/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9711 - auc: 0.9940 - loss: 0.0103 - pr_auc: 0.9954 - precision: 0.9639 - recall: 0.9789 - val_accuracy: 0.6608 - val_auc: 0.9195 - val_loss: 0.1397 - val_pr_auc: 0.9511 - val_precision: 0.9788 - val_recall: 0.4832
# Epoch 9/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9743 - auc: 0.9948 - loss: 0.0097 - pr_auc: 0.9959 - precision: 0.9696 - recall: 0.9796 - val_accuracy: 0.6792 - val_auc: 0.8876 - val_loss: 0.1341 - val_pr_auc: 0.9326 - val_precision: 0.9605 - val_recall: 0.5229
# Epoch 10/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9737 - auc: 0.9955 - loss: 0.0093 - pr_auc: 0.9964 - precision: 0.9681 - recall: 0.9799 - val_accuracy: 0.7240 - val_auc: 0.8993 - val_loss: 0.1144 - val_pr_auc: 0.9393 - val_precision: 0.9572 - val_recall: 0.5978
# Epoch 11/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9751 - auc: 0.9953 - loss: 0.0092 - pr_auc: 0.9963 - precision: 0.9693 - recall: 0.9814 - val_accuracy: 0.5510 - val_auc: 0.8383 - val_loss: 0.2404 - val_pr_auc: 0.9083 - val_precision: 0.9724 - val_recall: 0.3110
# Epoch 12/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9746 - auc: 0.9954 - loss: 0.0090 - pr_auc: 0.9965 - precision: 0.9683 - recall: 0.9814 - val_accuracy: 0.6154 - val_auc: 0.8807 - val_loss: 0.1871 - val_pr_auc: 0.9310 - val_precision: 0.9784 - val_recall: 0.4113
# Epoch 13/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9776 - auc: 0.9964 - loss: 0.0082 - pr_auc: 0.9972 - precision: 0.9724 - recall: 0.9832 - val_accuracy: 0.5505 - val_auc: 0.8251 - val_loss: 0.2667 - val_pr_auc: 0.9014 - val_precision: 0.9724 - val_recall: 0.3102
# Epoch 14/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9777 - auc: 0.9967 - loss: 0.0077 - pr_auc: 0.9974 - precision: 0.9734 - recall: 0.9823 - val_accuracy: 0.5737 - val_auc: 0.8404 - val_loss: 0.2576 - val_pr_auc: 0.9084 - val_precision: 0.9715 - val_recall: 0.3477
# Epoch 15/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9797 - auc: 0.9971 - loss: 0.0072 - pr_auc: 0.9977 - precision: 0.9758 - recall: 0.9839 - val_accuracy: 0.4920 - val_auc: 0.7974 - val_loss: 0.3773 - val_pr_auc: 0.8882 - val_precision: 0.9787 - val_recall: 0.2152
# Epoch 16/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9799 - auc: 0.9972 - loss: 0.0072 - pr_auc: 0.9977 - precision: 0.9744 - recall: 0.9859 - val_accuracy: 0.5899 - val_auc: 0.8277 - val_loss: 0.2406 - val_pr_auc: 0.9032 - val_precision: 0.9647 - val_recall: 0.3763
# Epoch 17/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9828 - auc: 0.9976 - loss: 0.0067 - pr_auc: 0.9980 - precision: 0.9784 - recall: 0.9876 - val_accuracy: 0.6163 - val_auc: 0.8399 - val_loss: 0.2283 - val_pr_auc: 0.9098 - val_precision: 0.9645 - val_recall: 0.4190
# Epoch 18/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9803 - auc: 0.9976 - loss: 0.0067 - pr_auc: 0.9981 - precision: 0.9748 - recall: 0.9862 - val_accuracy: 0.5179 - val_auc: 0.7845 - val_loss: 0.3560 - val_pr_auc: 0.8802 - val_precision: 0.9691 - val_recall: 0.2590
# Epoch 19/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9825 - auc: 0.9980 - loss: 0.0061 - pr_auc: 0.9984 - precision: 0.9772 - recall: 0.9882 - val_accuracy: 0.5266 - val_auc: 0.7769 - val_loss: 0.3508 - val_pr_auc: 0.8735 - val_precision: 0.9615 - val_recall: 0.2752
# Epoch 20/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9810 - auc: 0.9978 - loss: 0.0064 - pr_auc: 0.9982 - precision: 0.9746 - recall: 0.9879 - val_accuracy: 0.4702 - val_auc: 0.7061 - val_loss: 0.5461 - val_pr_auc: 0.8375 - val_precision: 0.9720 - val_recall: 0.1818
# Epoch 21/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9834 - auc: 0.9983 - loss: 0.0058 - pr_auc: 0.9986 - precision: 0.9793 - recall: 0.9877 - val_accuracy: 0.4695 - val_auc: 0.6900 - val_loss: 0.5642 - val_pr_auc: 0.8285 - val_precision: 0.9691 - val_recall: 0.1813
# Epoch 22/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9834 - auc: 0.9982 - loss: 0.0058 - pr_auc: 0.9985 - precision: 0.9788 - recall: 0.9883 - val_accuracy: 0.5105 - val_auc: 0.7597 - val_loss: 0.3964 - val_pr_auc: 0.8675 - val_precision: 0.9697 - val_recall: 0.2468
# Epoch 23/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9847 - auc: 0.9984 - loss: 0.0055 - pr_auc: 0.9987 - precision: 0.9815 - recall: 0.9880 - val_accuracy: 0.5835 - val_auc: 0.7613 - val_loss: 0.2973 - val_pr_auc: 0.8663 - val_precision: 0.9366 - val_recall: 0.3782
# Epoch 24/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9850 - auc: 0.9985 - loss: 0.0053 - pr_auc: 0.9988 - precision: 0.9805 - recall: 0.9897 - val_accuracy: 0.4598 - val_auc: 0.6705 - val_loss: 0.6026 - val_pr_auc: 0.8161 - val_precision: 0.9739 - val_recall: 0.1647
# Epoch 25/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9870 - auc: 0.9987 - loss: 0.0048 - pr_auc: 0.9990 - precision: 0.9830 - recall: 0.9912 - val_accuracy: 0.5197 - val_auc: 0.7604 - val_loss: 0.4376 - val_pr_auc: 0.8668 - val_precision: 0.9694 - val_recall: 0.2617
# Epoch 26/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9864 - auc: 0.9989 - loss: 0.0046 - pr_auc: 0.9991 - precision: 0.9814 - recall: 0.9917 - val_accuracy: 0.5016 - val_auc: 0.7069 - val_loss: 0.4980 - val_pr_auc: 0.8393 - val_precision: 0.9627 - val_recall: 0.2344
# Epoch 27/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9869 - auc: 0.9990 - loss: 0.0046 - pr_auc: 0.9991 - precision: 0.9826 - recall: 0.9914 - val_accuracy: 0.4917 - val_auc: 0.6914 - val_loss: 0.5282 - val_pr_auc: 0.8289 - val_precision: 0.9681 - val_recall: 0.2171
# Epoch 28/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9866 - auc: 0.9987 - loss: 0.0047 - pr_auc: 0.9989 - precision: 0.9820 - recall: 0.9915 - val_accuracy: 0.5393 - val_auc: 0.6923 - val_loss: 0.3989 - val_pr_auc: 0.8305 - val_precision: 0.9194 - val_recall: 0.3113
# Epoch 29/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9877 - auc: 0.9990 - loss: 0.0043 - pr_auc: 0.9992 - precision: 0.9832 - recall: 0.9924 - val_accuracy: 0.4614 - val_auc: 0.5792 - val_loss: 0.7598 - val_pr_auc: 0.7648 - val_precision: 0.9639 - val_recall: 0.1691
# Epoch 30/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9889 - auc: 0.9992 - loss: 0.0039 - pr_auc: 0.9993 - precision: 0.9850 - recall: 0.9930 - val_accuracy: 0.4759 - val_auc: 0.6084 - val_loss: 0.6819 - val_pr_auc: 0.7864 - val_precision: 0.9654 - val_recall: 0.1923
# Epoch 31/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9883 - auc: 0.9992 - loss: 0.0040 - pr_auc: 0.9993 - precision: 0.9838 - recall: 0.9930 - val_accuracy: 0.4211 - val_auc: 0.5862 - val_loss: 1.0373 - val_pr_auc: 0.7646 - val_precision: 0.9815 - val_recall: 0.1022
# Epoch 32/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9883 - auc: 0.9990 - loss: 0.0041 - pr_auc: 0.9992 - precision: 0.9844 - recall: 0.9924 - val_accuracy: 0.4576 - val_auc: 0.5785 - val_loss: 0.7581 - val_pr_auc: 0.7678 - val_precision: 0.9597 - val_recall: 0.1639
# Epoch 33/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9911 - auc: 0.9995 - loss: 0.0032 - pr_auc: 0.9996 - precision: 0.9883 - recall: 0.9941 - val_accuracy: 0.4754 - val_auc: 0.6437 - val_loss: 0.7075 - val_pr_auc: 0.8039 - val_precision: 0.9653 - val_recall: 0.1915
# Epoch 34/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9913 - auc: 0.9994 - loss: 0.0033 - pr_auc: 0.9995 - precision: 0.9884 - recall: 0.9944 - val_accuracy: 0.5884 - val_auc: 0.7069 - val_loss: 0.3613 - val_pr_auc: 0.8370 - val_precision: 0.8884 - val_recall: 0.4121
# Epoch 35/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9900 - auc: 0.9995 - loss: 0.0031 - pr_auc: 0.9996 - precision: 0.9871 - recall: 0.9932 - val_accuracy: 0.5200 - val_auc: 0.6939 - val_loss: 0.5334 - val_pr_auc: 0.8322 - val_precision: 0.9502 - val_recall: 0.2680
# Epoch 36/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9921 - auc: 0.9997 - loss: 0.0027 - pr_auc: 0.9997 - precision: 0.9889 - recall: 0.9955 - val_accuracy: 0.5142 - val_auc: 0.6478 - val_loss: 0.5322 - val_pr_auc: 0.8041 - val_precision: 0.9166 - val_recall: 0.2694
# Epoch 37/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9894 - auc: 0.9995 - loss: 0.0033 - pr_auc: 0.9996 - precision: 0.9853 - recall: 0.9936 - val_accuracy: 0.5557 - val_auc: 0.6772 - val_loss: 0.4482 - val_pr_auc: 0.8212 - val_precision: 0.8991 - val_recall: 0.3485
# Epoch 38/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9915 - auc: 0.9996 - loss: 0.0028 - pr_auc: 0.9997 - precision: 0.9883 - recall: 0.9949 - val_accuracy: 0.5528 - val_auc: 0.6751 - val_loss: 0.4876 - val_pr_auc: 0.8216 - val_precision: 0.9067 - val_recall: 0.3399
# Epoch 39/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9929 - auc: 0.9997 - loss: 0.0025 - pr_auc: 0.9997 - precision: 0.9898 - recall: 0.9962 - val_accuracy: 0.4910 - val_auc: 0.6286 - val_loss: 0.7411 - val_pr_auc: 0.7942 - val_precision: 0.9512 - val_recall: 0.2201
# Epoch 40/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9929 - auc: 0.9997 - loss: 0.0025 - pr_auc: 0.9997 - precision: 0.9899 - recall: 0.9961 - val_accuracy: 0.6186 - val_auc: 0.7394 - val_loss: 0.3183 - val_pr_auc: 0.8542 - val_precision: 0.8790 - val_recall: 0.4722
# Epoch 41/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9932 - auc: 0.9997 - loss: 0.0024 - pr_auc: 0.9998 - precision: 0.9910 - recall: 0.9955 - val_accuracy: 0.4431 - val_auc: 0.4980 - val_loss: 1.2409 - val_pr_auc: 0.7225 - val_precision: 0.9710 - val_recall: 0.1386
# Epoch 42/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9940 - auc: 0.9997 - loss: 0.0022 - pr_auc: 0.9998 - precision: 0.9916 - recall: 0.9965 - val_accuracy: 0.4835 - val_auc: 0.5873 - val_loss: 0.9001 - val_pr_auc: 0.7749 - val_precision: 0.9566 - val_recall: 0.2066
# Epoch 43/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9936 - auc: 0.9998 - loss: 0.0022 - pr_auc: 0.9998 - precision: 0.9916 - recall: 0.9958 - val_accuracy: 0.5301 - val_auc: 0.6715 - val_loss: 0.6206 - val_pr_auc: 0.8202 - val_precision: 0.9298 - val_recall: 0.2917
# Epoch 44/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9945 - auc: 0.9999 - loss: 0.0018 - pr_auc: 0.9999 - precision: 0.9922 - recall: 0.9970 - val_accuracy: 0.4754 - val_auc: 0.5723 - val_loss: 1.0309 - val_pr_auc: 0.7652 - val_precision: 0.9527 - val_recall: 0.1942
# Epoch 45/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9931 - auc: 0.9998 - loss: 0.0022 - pr_auc: 0.9998 - precision: 0.9904 - recall: 0.9959 - val_accuracy: 0.5661 - val_auc: 0.6829 - val_loss: 0.5201 - val_pr_auc: 0.8268 - val_precision: 0.8919 - val_recall: 0.3705
# Epoch 46/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9933 - auc: 0.9998 - loss: 0.0021 - pr_auc: 0.9998 - precision: 0.9907 - recall: 0.9961 - val_accuracy: 0.4594 - val_auc: 0.5318 - val_loss: 1.1360 - val_pr_auc: 0.7432 - val_precision: 0.9574 - val_recall: 0.1672
# Epoch 47/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9945 - auc: 0.9998 - loss: 0.0018 - pr_auc: 0.9999 - precision: 0.9920 - recall: 0.9970 - val_accuracy: 0.4291 - val_auc: 0.4220 - val_loss: 1.5223 - val_pr_auc: 0.6794 - val_precision: 0.9745 - val_recall: 0.1157
# Epoch 48/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9955 - auc: 0.9999 - loss: 0.0016 - pr_auc: 0.9999 - precision: 0.9932 - recall: 0.9979 - val_accuracy: 0.6014 - val_auc: 0.6905 - val_loss: 0.3924 - val_pr_auc: 0.8270 - val_precision: 0.8413 - val_recall: 0.4689
# Epoch 49/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9942 - auc: 0.9999 - loss: 0.0015 - pr_auc: 0.9999 - precision: 0.9916 - recall: 0.9970 - val_accuracy: 0.4435 - val_auc: 0.5353 - val_loss: 1.2961 - val_pr_auc: 0.7420 - val_precision: 0.9730 - val_recall: 0.1388
# Epoch 50/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9936 - auc: 0.9998 - loss: 0.0019 - pr_auc: 0.9999 - precision: 0.9911 - recall: 0.9962 - val_accuracy: 0.4825 - val_auc: 0.5795 - val_loss: 1.0031 - val_pr_auc: 0.7694 - val_precision: 0.9563 - val_recall: 0.2050

# %%
# =========================
# CELL 1
# =========================

import numpy as np
from sklearn.metrics import roc_curve

# prediksi probabilitas
y_prob = model.predict(X_test).ravel()

# label asli
y_true = y_test

# =========================
# EVALUASI DEFAULT THRESHOLD 0.5
# =========================

default_threshold = 0.5
y_pred_default = (y_prob >= default_threshold).astype(int)

# =========================
# CARI THRESHOLD TERBAIK
# =========================
# strategi:
# cari threshold dengan F1 tertinggi

thresholds = np.arange(0.1, 0.91, 0.01)

best_threshold = 0.5
best_f1 = 0

for th in thresholds:

    y_pred_temp = (y_prob >= th).astype(int)

    TP = np.sum((y_true == 1) & (y_pred_temp == 1))
    TN = np.sum((y_true == 0) & (y_pred_temp == 0))
    FP = np.sum((y_true == 0) & (y_pred_temp == 1))
    FN = np.sum((y_true == 1) & (y_pred_temp == 0))

    precision = TP / (TP + FP + 1e-12)
    recall = TP / (TP + FN + 1e-12)

    f1 = 2 * precision * recall / (precision + recall + 1e-12)

    if f1 > best_f1:
        best_f1 = f1
        best_threshold = th

print("Best Threshold:", best_threshold)
print("Best F1 Score :", best_f1)

# prediksi final threshold terbaik
y_pred_best = (y_prob >= best_threshold).astype(int)
# Out:
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step
# Best Threshold: 0.5599999999999997
# Best F1 Score : 0.8528886241805647

# %%
# =========================
# CELL 2
# =========================

from sklearn.metrics import confusion_matrix

# ===== DEFAULT 0.5 =====
cm_default = confusion_matrix(y_true, y_pred_default)

TN_d, FP_d, FN_d, TP_d = cm_default.ravel()

print("=== Confusion Matrix (Threshold = 0.5) ===")
print(cm_default)

# ===== BEST THRESHOLD =====
cm_best = confusion_matrix(y_true, y_pred_best)

TN_b, FP_b, FN_b, TP_b = cm_best.ravel()

print("\n=== Confusion Matrix (Best Threshold) ===")
print(cm_best)
# Out:
# === Confusion Matrix (Threshold = 0.5) ===
# [[6523  323]
#  [1200 4322]]
#
# === Confusion Matrix (Best Threshold) ===
# [[6590  256]
#  [1226 4296]]

# %%
# =========================
# CELL 3
# =========================

def calculate_metrics(TN, FP, FN, TP):

    accuracy = (TP + TN) / (TP + TN + FP + FN)

    precision = TP / (TP + FP + 1e-12)

    recall = TP / (TP + FN + 1e-12)

    f1 = 2 * precision * recall / (precision + recall + 1e-12)

    FPR = FP / (FP + TN + 1e-12)

    FNR = FN / (FN + TP + 1e-12)

    return accuracy, precision, recall, f1, FPR, FNR


# ===== DEFAULT =====
metrics_default = calculate_metrics(TN_d, FP_d, FN_d, TP_d)

# ===== BEST =====
metrics_best = calculate_metrics(TN_b, FP_b, FN_b, TP_b)

# %%
# =========================
# CELL 4
# =========================

metric_names = [
    "Accuracy",
    "Precision",
    "Recall",
    "F1-score",
    "FPR",
    "FNR"
]

print("========================================")
print("THRESHOLD = 0.5")
print("========================================")

for name, value in zip(metric_names, metrics_default):
    print(f"{name:10}: {value:.6f}")

print("\n")

print("========================================")
print(f"BEST THRESHOLD = {best_threshold:.2f}")
print("========================================")

for name, value in zip(metric_names, metrics_best):
    print(f"{name:10}: {value:.6f}")
# Out:
# ========================================
# THRESHOLD = 0.5
# ========================================
# Accuracy  : 0.876860
# Precision : 0.930463
# Recall    : 0.782687
# F1-score  : 0.850202
# FPR       : 0.047181
# FNR       : 0.217313
#
#
# ========================================
# BEST THRESHOLD = 0.56
# ========================================
# Accuracy  : 0.880175
# Precision : 0.943761
# Recall    : 0.777979
# F1-score  : 0.852889
# FPR       : 0.037394
# FNR       : 0.222021

# %%
# =========================
# CELL 5
# =========================

import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

fpr, tpr, _ = roc_curve(y_true, y_prob)

roc_auc = auc(fpr, tpr)

plt.figure(figsize=(6,6))

plt.plot(fpr, tpr, label="AUC = %0.4f" % roc_auc)

plt.plot([0,1],[0,1],'--')

plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")

plt.title("ROC Curve")

plt.legend()

plt.grid(True)

plt.show()
