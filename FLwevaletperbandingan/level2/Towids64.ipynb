# %%
import numpy as np
import os
import gc
import time
import matplotlib.pyplot as plt
import seaborn as sns

import tensorflow as tf
from tensorflow.keras import layers, models

from sklearn.metrics import (
    confusion_matrix,
    classification_report,
    roc_curve,
    auc,
    precision_recall_curve,
    f1_score
)
# Out:
# 2026-05-22 22:59:12.286518: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-05-22 22:59:12.296823: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1779465552.308845  490911 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1779465552.312545  490911 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1779465552.321499  490911 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1779465552.321509  490911 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1779465552.321511  490911 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1779465552.321512  490911 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-05-22 22:59:12.324555: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
import numpy as np
import os
import gc
import time
import matplotlib.pyplot as plt
import seaborn as sns

import tensorflow as tf
from tensorflow.keras import layers, models

from sklearn.metrics import (
    confusion_matrix,
    classification_report,
    roc_curve,
    auc,
    precision_recall_curve,
    f1_score
)

# %%
BASE_PATHHASIL = "/home/dani/Documents/tugas akhir/TugasAkhir/codeTugasAkhirku2026/tow_ids/Preprocessing/Preprocessingbaru/imgsize64lv2/norm/dwt/"

# %%
import tensorflow as tf
from tensorflow.keras import layers, models


def build_cnn_tow_ids(input_shape=(16, 16, 3)):

    inputs = layers.Input(shape=input_shape)

    # =========================================================
    # Block A
    # SeparableConv + ReLU
    # SeparableConv + ReLU
    # BatchNorm
    # MaxPooling
    # =========================================================

    x = layers.SeparableConv2D(
        32, (3,3),
        padding="same",
        use_bias=False
    )(inputs)
    x = layers.ReLU()(x)

    x = layers.SeparableConv2D(
        32, (3,3),
        padding="same",
        use_bias=False
    )(x)
    x = layers.ReLU()(x)

    x = layers.BatchNormalization()(x)

    x = layers.MaxPooling2D((2,2))(x)

    # =========================================================
    # Block B (Residual Block)
    #
    # shortcut:
    # Conv1x1 + BN
    #
    # main:
    # SepConv + ReLU
    # SepConv + ReLU
    # BN
    #
    # output:
    # Add + ReLU
    # =========================================================

    shortcut = layers.Conv2D(
        64,
        (1,1),
        padding="same",
        use_bias=False
    )(x)

    shortcut = layers.BatchNormalization()(shortcut)

    y = layers.SeparableConv2D(
        64,
        (3,3),
        padding="same",
        use_bias=False
    )(x)
    y = layers.ReLU()(y)

    y = layers.SeparableConv2D(
        64,
        (3,3),
        padding="same",
        use_bias=False
    )(y)
    y = layers.ReLU()(y)

    y = layers.BatchNormalization()(y)

    x = layers.Add()([y, shortcut])
    x = layers.ReLU()(x)

    # =========================================================
    # Block C
    #
    # SepConv + ReLU
    # GlobalAveragePooling
    # Dense + ReLU
    # Dense + ReLU
    # Dropout
    # Dense + Sigmoid
    # =========================================================

    x = layers.SeparableConv2D(
        128,
        (3,3),
        padding="same",
        use_bias=False
    )(x)
    x = layers.ReLU()(x)

    x = layers.GlobalAveragePooling2D()(x)

    x = layers.Dense(512, activation="relu")(x)

    x = layers.Dense(256, activation="relu")(x)

    x = layers.Dropout(0.5)(x)

    outputs = layers.Dense(
        1,
        activation="sigmoid"
    )(x)

    model = models.Model(inputs, outputs)

    model.compile(
        optimizer=tf.keras.optimizers.Adam(1e-3),
        loss="binary_crossentropy",
        metrics=[
            "accuracy",
            tf.keras.metrics.Precision(name="precision"),
            tf.keras.metrics.Recall(name="recall")
        ]
    )

    return model

# %%
train_data = np.load(os.path.join(BASE_PATHHASIL, "tow_ids_train_dwt.npz"))
test_data  = np.load(os.path.join(BASE_PATHHASIL, "tow_ids_test_dwt.npz"))
val_data   = np.load(os.path.join(BASE_PATHHASIL, "tow_ids_eval_dwt.npz"))

X_train = train_data["X"]
y_train = train_data["y"]

X_test  = test_data["X"]
y_test  = test_data["y"]

X_val   = val_data["X"]
y_val   = val_data["y"]

print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
print(X_val.shape, y_val.shape)
# Out:
# (13165, 16, 16, 3) (13165,)
# (12368, 16, 16, 3) (12368,)
# (5642, 16, 16, 3) (5642,)

# %%
tf.keras.backend.clear_session()

model = build_cnn_tow_ids()
model.summary()
# Out:
# I0000 00:00:1779465553.684359  490911 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 4144 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 16, 16, 3) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d    │ (None, 16, 16,    │        123 │ input_layer[0][0] │
# │ (SeparableConv2D)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu (ReLU)        │ (None, 16, 16,    │          0 │ separable_conv2d… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_1  │ (None, 16, 16,    │      1,312 │ re_lu[0][0]       │
# │ (SeparableConv2D)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_1 (ReLU)      │ (None, 16, 16,    │          0 │ separable_conv2d… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 16, 16,    │        128 │ re_lu_1[0][0]     │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 8, 8, 32)  │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_2  │ (None, 8, 8, 64)  │      2,336 │ max_pooling2d[0]… │
# │ (SeparableConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_2 (ReLU)      │ (None, 8, 8, 64)  │          0 │ separable_conv2d… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_3  │ (None, 8, 8, 64)  │      4,672 │ re_lu_2[0][0]     │
# │ (SeparableConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_3 (ReLU)      │ (None, 8, 8, 64)  │          0 │ separable_conv2d… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 8, 8, 64)  │      2,048 │ max_pooling2d[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 64)  │        256 │ re_lu_3[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 8, 8, 64)  │        256 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 8, 8, 64)  │          0 │ batch_normalizat… │
# │                     │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_4 (ReLU)      │ (None, 8, 8, 64)  │          0 │ add[0][0]         │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_4  │ (None, 8, 8, 128) │      8,768 │ re_lu_4[0][0]     │
# │ (SeparableConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_5 (ReLU)      │ (None, 8, 8, 128) │          0 │ separable_conv2d… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 128)       │          0 │ re_lu_5[0][0]     │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 512)       │     66,048 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 256)       │    131,328 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 256)       │          0 │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 1)         │        257 │ dropout[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 217,532 (849.73 KB)
#  Trainable params: 217,212 (848.48 KB)
#  Non-trainable params: 320 (1.25 KB)

# %%
history = model.fit(
    X_train, y_train,
    epochs=50,
    batch_size=32,
    validation_data=(X_val, y_val),
    verbose=1,
    
)
# Out:
# Epoch 1/50
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1779465556.091756  491047 service.cc:152] XLA service 0x7c464c0047f0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1779465556.091770  491047 service.cc:160]   StreamExecutor device (0): NVIDIA GeForce RTX 3060 Laptop GPU, Compute Capability 8.6
# 2026-05-22 22:59:16.146275: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1779465556.514510  491047 cuda_dnn.cc:529] Loaded cuDNN version 91701
# 2026-05-22 22:59:17.484652: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1485_0', 44 bytes spill stores, 44 bytes spill loads
#
# 2026-05-22 22:59:17.714675: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2261', 36 bytes spill stores, 44 bytes spill loads
#
# 2026-05-22 22:59:18.544003: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1485', 484 bytes spill stores, 484 bytes spill loads
#
# 2026-05-22 22:59:19.446003: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2263', 36 bytes spill stores, 44 bytes spill loads
#
# 2026-05-22 22:59:19.564151: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2263', 32 bytes spill stores, 32 bytes spill loads
#
# 2026-05-22 22:59:19.580297: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2263', 32 bytes spill stores, 32 bytes spill loads
#
# I0000 00:00:1779465563.178078  491047 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 388/412 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8039 - loss: 0.3987 - precision: 0.8809 - recall: 0.6813
# 2026-05-22 22:59:25.546457: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1485', 64 bytes spill stores, 64 bytes spill loads
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.8095 - loss: 0.3896 - precision: 0.8851 - recall: 0.6907
# 2026-05-22 22:59:33.935146: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_176', 64 bytes spill stores, 64 bytes spill loads
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 22s 31ms/step - accuracy: 0.9019 - loss: 0.2383 - precision: 0.9540 - recall: 0.8452 - val_accuracy: 0.6434 - val_loss: 0.7223 - val_precision: 0.6434 - val_recall: 1.0000
# Epoch 2/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9703 - loss: 0.0925 - precision: 0.9823 - recall: 0.9580 - val_accuracy: 0.5588 - val_loss: 1.3073 - val_precision: 0.9719 - val_recall: 0.3237
# Epoch 3/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9726 - loss: 0.0844 - precision: 0.9819 - recall: 0.9630 - val_accuracy: 0.3995 - val_loss: 2.8344 - val_precision: 0.9802 - val_recall: 0.0680
# Epoch 4/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9756 - loss: 0.0746 - precision: 0.9849 - recall: 0.9662 - val_accuracy: 0.6760 - val_loss: 0.6500 - val_precision: 0.9500 - val_recall: 0.5240
# Epoch 5/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9782 - loss: 0.0695 - precision: 0.9860 - recall: 0.9703 - val_accuracy: 0.4142 - val_loss: 3.4414 - val_precision: 0.9851 - val_recall: 0.0909
# Epoch 6/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9772 - loss: 0.0686 - precision: 0.9849 - recall: 0.9694 - val_accuracy: 0.6756 - val_loss: 0.8218 - val_precision: 0.8254 - val_recall: 0.6289
# Epoch 7/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9792 - loss: 0.0647 - precision: 0.9865 - recall: 0.9718 - val_accuracy: 0.4165 - val_loss: 4.7460 - val_precision: 0.9801 - val_recall: 0.0950
# Epoch 8/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9800 - loss: 0.0599 - precision: 0.9866 - recall: 0.9733 - val_accuracy: 0.4367 - val_loss: 4.1877 - val_precision: 0.9650 - val_recall: 0.1292
# Epoch 9/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9824 - loss: 0.0552 - precision: 0.9891 - recall: 0.9756 - val_accuracy: 0.4979 - val_loss: 1.6822 - val_precision: 0.9147 - val_recall: 0.2421
# Epoch 10/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9824 - loss: 0.0575 - precision: 0.9873 - recall: 0.9774 - val_accuracy: 0.4440 - val_loss: 2.7134 - val_precision: 0.9660 - val_recall: 0.1408
# Epoch 11/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9833 - loss: 0.0536 - precision: 0.9882 - recall: 0.9783 - val_accuracy: 0.4465 - val_loss: 3.8783 - val_precision: 0.9703 - val_recall: 0.1441
# Epoch 12/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9828 - loss: 0.0559 - precision: 0.9888 - recall: 0.9767 - val_accuracy: 0.4543 - val_loss: 2.1231 - val_precision: 0.9408 - val_recall: 0.1620
# Epoch 13/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9838 - loss: 0.0501 - precision: 0.9896 - recall: 0.9780 - val_accuracy: 0.4872 - val_loss: 2.4045 - val_precision: 0.9320 - val_recall: 0.2190
# Epoch 14/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9842 - loss: 0.0500 - precision: 0.9888 - recall: 0.9796 - val_accuracy: 0.4564 - val_loss: 2.7787 - val_precision: 0.9622 - val_recall: 0.1614
# Epoch 15/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9865 - loss: 0.0451 - precision: 0.9893 - recall: 0.9836 - val_accuracy: 0.4449 - val_loss: 2.7878 - val_precision: 0.9663 - val_recall: 0.1421
# Epoch 16/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9857 - loss: 0.0455 - precision: 0.9901 - recall: 0.9814 - val_accuracy: 0.4243 - val_loss: 2.5586 - val_precision: 0.9848 - val_recall: 0.1069
# Epoch 17/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9838 - loss: 0.0523 - precision: 0.9881 - recall: 0.9796 - val_accuracy: 0.4325 - val_loss: 1.9922 - val_precision: 0.9798 - val_recall: 0.1204
# Epoch 18/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9866 - loss: 0.0414 - precision: 0.9907 - recall: 0.9824 - val_accuracy: 0.4326 - val_loss: 3.5108 - val_precision: 0.9756 - val_recall: 0.1212
# Epoch 19/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9877 - loss: 0.0399 - precision: 0.9910 - recall: 0.9844 - val_accuracy: 0.4335 - val_loss: 5.6685 - val_precision: 0.9759 - val_recall: 0.1226
# Epoch 20/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9875 - loss: 0.0393 - precision: 0.9925 - recall: 0.9826 - val_accuracy: 0.4401 - val_loss: 3.6671 - val_precision: 0.9701 - val_recall: 0.1339
# Epoch 21/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9893 - loss: 0.0371 - precision: 0.9930 - recall: 0.9856 - val_accuracy: 0.4373 - val_loss: 3.9410 - val_precision: 0.9671 - val_recall: 0.1298
# Epoch 22/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9878 - loss: 0.0369 - precision: 0.9921 - recall: 0.9836 - val_accuracy: 0.4373 - val_loss: 3.4285 - val_precision: 0.9872 - val_recall: 0.1270
# Epoch 23/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9875 - loss: 0.0376 - precision: 0.9901 - recall: 0.9849 - val_accuracy: 0.4302 - val_loss: 3.2046 - val_precision: 0.9770 - val_recall: 0.1171
# Epoch 24/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9870 - loss: 0.0407 - precision: 0.9917 - recall: 0.9823 - val_accuracy: 0.4410 - val_loss: 2.9545 - val_precision: 0.9630 - val_recall: 0.1364
# Epoch 25/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9881 - loss: 0.0344 - precision: 0.9927 - recall: 0.9835 - val_accuracy: 0.4474 - val_loss: 3.1985 - val_precision: 0.9588 - val_recall: 0.1474
# Epoch 26/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9897 - loss: 0.0326 - precision: 0.9937 - recall: 0.9858 - val_accuracy: 0.4332 - val_loss: 4.4321 - val_precision: 0.9821 - val_recall: 0.1212
# Epoch 27/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9911 - loss: 0.0283 - precision: 0.9948 - recall: 0.9874 - val_accuracy: 0.4312 - val_loss: 5.0397 - val_precision: 0.9773 - val_recall: 0.1187
# Epoch 28/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9915 - loss: 0.0273 - precision: 0.9942 - recall: 0.9888 - val_accuracy: 0.4300 - val_loss: 4.0011 - val_precision: 0.9929 - val_recall: 0.1149
# Epoch 29/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9921 - loss: 0.0268 - precision: 0.9957 - recall: 0.9885 - val_accuracy: 0.4312 - val_loss: 4.0262 - val_precision: 0.9884 - val_recall: 0.1174
# Epoch 30/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9906 - loss: 0.0275 - precision: 0.9941 - recall: 0.9871 - val_accuracy: 0.4463 - val_loss: 8.0000 - val_precision: 0.9486 - val_recall: 0.1474
# Epoch 31/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9920 - loss: 0.0250 - precision: 0.9945 - recall: 0.9895 - val_accuracy: 0.4484 - val_loss: 5.3473 - val_precision: 0.9360 - val_recall: 0.1532
# Epoch 32/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9902 - loss: 0.0299 - precision: 0.9922 - recall: 0.9882 - val_accuracy: 0.4435 - val_loss: 3.1701 - val_precision: 0.9730 - val_recall: 0.1388
# Epoch 33/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9925 - loss: 0.0230 - precision: 0.9947 - recall: 0.9903 - val_accuracy: 0.4403 - val_loss: 5.3772 - val_precision: 0.9758 - val_recall: 0.1333
# Epoch 34/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9927 - loss: 0.0242 - precision: 0.9950 - recall: 0.9905 - val_accuracy: 0.4387 - val_loss: 3.3906 - val_precision: 0.9813 - val_recall: 0.1300
# Epoch 35/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9920 - loss: 0.0251 - precision: 0.9945 - recall: 0.9895 - val_accuracy: 0.4576 - val_loss: 2.1705 - val_precision: 0.9672 - val_recall: 0.1625
# Epoch 36/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9931 - loss: 0.0202 - precision: 0.9947 - recall: 0.9915 - val_accuracy: 0.4470 - val_loss: 5.5254 - val_precision: 0.9705 - val_recall: 0.1449
# Epoch 37/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9921 - loss: 0.0207 - precision: 0.9942 - recall: 0.9900 - val_accuracy: 0.4504 - val_loss: 4.8269 - val_precision: 0.9600 - val_recall: 0.1521
# Epoch 38/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9929 - loss: 0.0238 - precision: 0.9953 - recall: 0.9905 - val_accuracy: 0.4708 - val_loss: 5.9862 - val_precision: 0.9387 - val_recall: 0.1898
# Epoch 39/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9908 - loss: 0.0283 - precision: 0.9941 - recall: 0.9876 - val_accuracy: 0.4337 - val_loss: 3.9074 - val_precision: 0.9888 - val_recall: 0.1212
# Epoch 40/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9942 - loss: 0.0165 - precision: 0.9962 - recall: 0.9921 - val_accuracy: 0.4638 - val_loss: 4.3250 - val_precision: 0.9675 - val_recall: 0.1725
# Epoch 41/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9940 - loss: 0.0175 - precision: 0.9953 - recall: 0.9927 - val_accuracy: 0.4518 - val_loss: 4.5450 - val_precision: 0.9590 - val_recall: 0.1545
# Epoch 42/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9938 - loss: 0.0187 - precision: 0.9957 - recall: 0.9920 - val_accuracy: 0.4532 - val_loss: 5.4526 - val_precision: 0.9580 - val_recall: 0.1570
# Epoch 43/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9951 - loss: 0.0165 - precision: 0.9962 - recall: 0.9939 - val_accuracy: 0.4412 - val_loss: 5.5188 - val_precision: 0.9799 - val_recall: 0.1342
# Epoch 44/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9951 - loss: 0.0138 - precision: 0.9965 - recall: 0.9938 - val_accuracy: 0.4383 - val_loss: 6.6838 - val_precision: 0.9873 - val_recall: 0.1287
# Epoch 45/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9942 - loss: 0.0173 - precision: 0.9956 - recall: 0.9929 - val_accuracy: 0.4358 - val_loss: 6.8069 - val_precision: 0.9806 - val_recall: 0.1256
# Epoch 46/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9930 - loss: 0.0169 - precision: 0.9945 - recall: 0.9915 - val_accuracy: 0.4917 - val_loss: 3.5785 - val_precision: 0.8969 - val_recall: 0.2372
# Epoch 47/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9956 - loss: 0.0125 - precision: 0.9970 - recall: 0.9942 - val_accuracy: 0.3898 - val_loss: 8.2062 - val_precision: 0.9895 - val_recall: 0.0521
# Epoch 48/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9950 - loss: 0.0137 - precision: 0.9962 - recall: 0.9938 - val_accuracy: 0.4399 - val_loss: 6.2699 - val_precision: 0.9519 - val_recall: 0.1364
# Epoch 49/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9949 - loss: 0.0143 - precision: 0.9962 - recall: 0.9936 - val_accuracy: 0.4511 - val_loss: 8.1365 - val_precision: 0.9750 - val_recall: 0.1507
# Epoch 50/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9951 - loss: 0.0131 - precision: 0.9967 - recall: 0.9936 - val_accuracy: 0.4428 - val_loss: 7.6381 - val_precision: 0.9728 - val_recall: 0.1377

# %%
# =========================
# CELL 1
# =========================

import numpy as np
from sklearn.metrics import roc_curve

# prediksi probabilitas
y_prob = model.predict(X_test).ravel()

# label asli
y_true = y_test

# =========================
# EVALUASI DEFAULT THRESHOLD 0.5
# =========================

default_threshold = 0.5
y_pred_default = (y_prob >= default_threshold).astype(int)

# =========================
# CARI THRESHOLD TERBAIK
# =========================
# strategi:
# cari threshold dengan F1 tertinggi

thresholds = np.arange(0.1, 0.91, 0.01)

best_threshold = 0.5
best_f1 = 0

for th in thresholds:

    y_pred_temp = (y_prob >= th).astype(int)

    TP = np.sum((y_true == 1) & (y_pred_temp == 1))
    TN = np.sum((y_true == 0) & (y_pred_temp == 0))
    FP = np.sum((y_true == 0) & (y_pred_temp == 1))
    FN = np.sum((y_true == 1) & (y_pred_temp == 0))

    precision = TP / (TP + FP + 1e-12)
    recall = TP / (TP + FN + 1e-12)

    f1 = 2 * precision * recall / (precision + recall + 1e-12)

    if f1 > best_f1:
        best_f1 = f1
        best_threshold = th

print("Best Threshold:", best_threshold)
print("Best F1 Score :", best_f1)

# prediksi final threshold terbaik
y_pred_best = (y_prob >= best_threshold).astype(int)
# Out:
# 380/387 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2026-05-22 23:00:43.921811: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_138', 52 bytes spill stores, 52 bytes spill loads
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 5s 11ms/step
# Best Threshold: 0.6299999999999997
# Best F1 Score : 0.8577542286524524

# %%
# =========================
# CELL 2
# =========================

from sklearn.metrics import confusion_matrix

# ===== DEFAULT 0.5 =====
cm_default = confusion_matrix(y_true, y_pred_default)

TN_d, FP_d, FN_d, TP_d = cm_default.ravel()

print("=== Confusion Matrix (Threshold = 0.5) ===")
print(cm_default)

# ===== BEST THRESHOLD =====
cm_best = confusion_matrix(y_true, y_pred_best)

TN_b, FP_b, FN_b, TP_b = cm_best.ravel()

print("\n=== Confusion Matrix (Best Threshold) ===")
print(cm_best)
# Out:
# === Confusion Matrix (Threshold = 0.5) ===
# [[6739  107]
#  [1300 4222]]
#
# === Confusion Matrix (Best Threshold) ===
# [[6763   83]
#  [1313 4209]]

# %%
# =========================
# CELL 3
# =========================

def calculate_metrics(TN, FP, FN, TP):

    accuracy = (TP + TN) / (TP + TN + FP + FN)

    precision = TP / (TP + FP + 1e-12)

    recall = TP / (TP + FN + 1e-12)

    f1 = 2 * precision * recall / (precision + recall + 1e-12)

    FPR = FP / (FP + TN + 1e-12)

    FNR = FN / (FN + TP + 1e-12)

    return accuracy, precision, recall, f1, FPR, FNR


# ===== DEFAULT =====
metrics_default = calculate_metrics(TN_d, FP_d, FN_d, TP_d)

# ===== BEST =====
metrics_best = calculate_metrics(TN_b, FP_b, FN_b, TP_b)

# %%
# =========================
# CELL 4
# =========================

metric_names = [
    "Accuracy",
    "Precision",
    "Recall",
    "F1-score",
    "FPR",
    "FNR"
]

print("========================================")
print("THRESHOLD = 0.5")
print("========================================")

for name, value in zip(metric_names, metrics_default):
    print(f"{name:10}: {value:.6f}")

print("\n")

print("========================================")
print(f"BEST THRESHOLD = {best_threshold:.2f}")
print("========================================")

for name, value in zip(metric_names, metrics_best):
    print(f"{name:10}: {value:.6f}")
# Out:
# ========================================
# THRESHOLD = 0.5
# ========================================
# Accuracy  : 0.886239
# Precision : 0.975283
# Recall    : 0.764578
# F1-score  : 0.857172
# FPR       : 0.015630
# FNR       : 0.235422
#
#
# ========================================
# BEST THRESHOLD = 0.63
# ========================================
# Accuracy  : 0.887128
# Precision : 0.980662
# Recall    : 0.762224
# F1-score  : 0.857754
# FPR       : 0.012124
# FNR       : 0.237776

# %%
# =========================
# CELL 5
# =========================

import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

fpr, tpr, _ = roc_curve(y_true, y_prob)

roc_auc = auc(fpr, tpr)

plt.figure(figsize=(6,6))

plt.plot(fpr, tpr, label="AUC = %0.4f" % roc_auc)

plt.plot([0,1],[0,1],'--')

plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")

plt.title("ROC Curve")

plt.legend()

plt.grid(True)

plt.show()
