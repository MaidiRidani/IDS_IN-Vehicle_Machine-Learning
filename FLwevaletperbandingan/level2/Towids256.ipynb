# %%
import numpy as np
import os
import gc
import time
import matplotlib.pyplot as plt
import seaborn as sns

import tensorflow as tf
from tensorflow.keras import layers, models

from sklearn.metrics import (
    confusion_matrix,
    classification_report,
    roc_curve,
    auc,
    precision_recall_curve,
    f1_score
)
# Out:
# 2026-05-22 23:03:22.220557: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-05-22 23:03:22.231989: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1779465802.245601  504403 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1779465802.250041  504403 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1779465802.260361  504403 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1779465802.260378  504403 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1779465802.260379  504403 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1779465802.260381  504403 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-05-22 23:03:22.263820: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
import numpy as np
import os
import gc
import time
import matplotlib.pyplot as plt
import seaborn as sns

import tensorflow as tf
from tensorflow.keras import layers, models

from sklearn.metrics import (
    confusion_matrix,
    classification_report,
    roc_curve,
    auc,
    precision_recall_curve,
    f1_score
)

# %%
BASE_PATHHASIL = "/home/dani/Documents/tugas akhir/TugasAkhir/codeTugasAkhirku2026/tow_ids/Preprocessing/Preprocessingbaru/imgsize256lv2/norm/dwt/"

# %%
import tensorflow as tf
from tensorflow.keras import layers, models


def build_cnn_tow_ids(input_shape=(64, 64, 3)):

    inputs = layers.Input(shape=input_shape)

    # =========================================================
    # Block A
    # SeparableConv + ReLU
    # SeparableConv + ReLU
    # BatchNorm
    # MaxPooling
    # =========================================================

    x = layers.SeparableConv2D(
        32, (3,3),
        padding="same",
        use_bias=False
    )(inputs)
    x = layers.ReLU()(x)

    x = layers.SeparableConv2D(
        32, (3,3),
        padding="same",
        use_bias=False
    )(x)
    x = layers.ReLU()(x)

    x = layers.BatchNormalization()(x)

    x = layers.MaxPooling2D((2,2))(x)

    # =========================================================
    # Block B (Residual Block)
    #
    # shortcut:
    # Conv1x1 + BN
    #
    # main:
    # SepConv + ReLU
    # SepConv + ReLU
    # BN
    #
    # output:
    # Add + ReLU
    # =========================================================

    shortcut = layers.Conv2D(
        64,
        (1,1),
        padding="same",
        use_bias=False
    )(x)

    shortcut = layers.BatchNormalization()(shortcut)

    y = layers.SeparableConv2D(
        64,
        (3,3),
        padding="same",
        use_bias=False
    )(x)
    y = layers.ReLU()(y)

    y = layers.SeparableConv2D(
        64,
        (3,3),
        padding="same",
        use_bias=False
    )(y)
    y = layers.ReLU()(y)

    y = layers.BatchNormalization()(y)

    x = layers.Add()([y, shortcut])
    x = layers.ReLU()(x)

    # =========================================================
    # Block C
    #
    # SepConv + ReLU
    # GlobalAveragePooling
    # Dense + ReLU
    # Dense + ReLU
    # Dropout
    # Dense + Sigmoid
    # =========================================================

    x = layers.SeparableConv2D(
        128,
        (3,3),
        padding="same",
        use_bias=False
    )(x)
    x = layers.ReLU()(x)

    x = layers.GlobalAveragePooling2D()(x)

    x = layers.Dense(512, activation="relu")(x)

    x = layers.Dense(256, activation="relu")(x)

    x = layers.Dropout(0.5)(x)

    outputs = layers.Dense(
        1,
        activation="sigmoid"
    )(x)

    model = models.Model(inputs, outputs)

    model.compile(
        optimizer=tf.keras.optimizers.Adam(1e-3),
        loss="binary_crossentropy",
        metrics=[
            "accuracy",
            tf.keras.metrics.Precision(name="precision"),
            tf.keras.metrics.Recall(name="recall")
        ]
    )

    return model

# %%
train_data = np.load(os.path.join(BASE_PATHHASIL, "tow_ids_train_dwt.npz"))
test_data  = np.load(os.path.join(BASE_PATHHASIL, "tow_ids_test_dwt.npz"))
val_data   = np.load(os.path.join(BASE_PATHHASIL, "tow_ids_eval_dwt.npz"))

X_train = train_data["X"]
y_train = train_data["y"]

X_test  = test_data["X"]
y_test  = test_data["y"]

X_val   = val_data["X"]
y_val   = val_data["y"]

print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
print(X_val.shape, y_val.shape)
# Out:
# (3291, 64, 64, 3) (3291,)
# (3092, 64, 64, 3) (3092,)
# (1410, 64, 64, 3) (1410,)

# %%
tf.keras.backend.clear_session()

model = build_cnn_tow_ids()
model.summary()
# Out:
# I0000 00:00:1779465803.976165  504403 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 4144 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 64, 64, 3) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d    │ (None, 64, 64,    │        123 │ input_layer[0][0] │
# │ (SeparableConv2D)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu (ReLU)        │ (None, 64, 64,    │          0 │ separable_conv2d… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_1  │ (None, 64, 64,    │      1,312 │ re_lu[0][0]       │
# │ (SeparableConv2D)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_1 (ReLU)      │ (None, 64, 64,    │          0 │ separable_conv2d… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 64, 64,    │        128 │ re_lu_1[0][0]     │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_2  │ (None, 32, 32,    │      2,336 │ max_pooling2d[0]… │
# │ (SeparableConv2D)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_2 (ReLU)      │ (None, 32, 32,    │          0 │ separable_conv2d… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_3  │ (None, 32, 32,    │      4,672 │ re_lu_2[0][0]     │
# │ (SeparableConv2D)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_3 (ReLU)      │ (None, 32, 32,    │          0 │ separable_conv2d… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 32, 32,    │      2,048 │ max_pooling2d[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ re_lu_3[0][0]     │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 64)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_4 (ReLU)      │ (None, 32, 32,    │          0 │ add[0][0]         │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_4  │ (None, 32, 32,    │      8,768 │ re_lu_4[0][0]     │
# │ (SeparableConv2D)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_5 (ReLU)      │ (None, 32, 32,    │          0 │ separable_conv2d… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 128)       │          0 │ re_lu_5[0][0]     │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 512)       │     66,048 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 256)       │    131,328 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 256)       │          0 │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 1)         │        257 │ dropout[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 217,532 (849.73 KB)
#  Trainable params: 217,212 (848.48 KB)
#  Non-trainable params: 320 (1.25 KB)

# %%
history = model.fit(
    X_train, y_train,
    epochs=50,
    batch_size=32,
    validation_data=(X_val, y_val),
    verbose=1,
    
)
# Out:
# Epoch 1/50
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1779465806.715447  504642 service.cc:152] XLA service 0x737e800176b0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1779465806.715464  504642 service.cc:160]   StreamExecutor device (0): NVIDIA GeForce RTX 3060 Laptop GPU, Compute Capability 8.6
# 2026-05-22 23:03:26.776599: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1779465807.199626  504642 cuda_dnn.cc:529] Loaded cuDNN version 91701
# 2026-05-22 23:03:28.169780: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1485_0', 44 bytes spill stores, 44 bytes spill loads
#
# 2026-05-22 23:03:28.750481: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2261', 36 bytes spill stores, 44 bytes spill loads
#
# 2026-05-22 23:03:29.751364: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1485', 484 bytes spill stores, 484 bytes spill loads
#
# 2026-05-22 23:03:30.257198: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2263', 32 bytes spill stores, 32 bytes spill loads
#
# 2026-05-22 23:03:30.257361: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2263', 36 bytes spill stores, 44 bytes spill loads
#
# 2026-05-22 23:03:30.344108: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2263', 32 bytes spill stores, 32 bytes spill loads
#
# I0000 00:00:1779465815.417183  504642 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
#  97/103 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.7211 - loss: 0.5165 - precision: 0.7728 - recall: 0.6528
# 2026-05-22 23:03:38.567780: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1485_0', 36 bytes spill stores, 36 bytes spill loads
#
# 2026-05-22 23:03:38.820216: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1485', 488 bytes spill stores, 488 bytes spill loads
#
# 2026-05-22 23:03:39.104235: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2261', 28 bytes spill stores, 32 bytes spill loads
#
# 2026-05-22 23:03:39.815200: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2263', 32 bytes spill stores, 32 bytes spill loads
#
# 2026-05-22 23:03:39.930447: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2263', 32 bytes spill stores, 32 bytes spill loads
#
# 2026-05-22 23:03:40.868033: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2263', 28 bytes spill stores, 32 bytes spill loads
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 100ms/step - accuracy: 0.7284 - loss: 0.5062 - precision: 0.7796 - recall: 0.6622
# 2026-05-22 23:03:49.455666: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_176', 64 bytes spill stores, 64 bytes spill loads
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 28s 156ms/step - accuracy: 0.8499 - loss: 0.3326 - precision: 0.8931 - recall: 0.8183 - val_accuracy: 0.7291 - val_loss: 0.5700 - val_precision: 0.7291 - val_recall: 1.0000
# Epoch 2/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9666 - loss: 0.0969 - precision: 0.9683 - recall: 0.9694 - val_accuracy: 0.7291 - val_loss: 0.5977 - val_precision: 0.7291 - val_recall: 1.0000
# Epoch 3/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9748 - loss: 0.0793 - precision: 0.9736 - recall: 0.9796 - val_accuracy: 0.7291 - val_loss: 0.6403 - val_precision: 0.7291 - val_recall: 1.0000
# Epoch 4/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9754 - loss: 0.0816 - precision: 0.9763 - recall: 0.9779 - val_accuracy: 0.7291 - val_loss: 0.5033 - val_precision: 0.7291 - val_recall: 1.0000
# Epoch 5/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9790 - loss: 0.0672 - precision: 0.9791 - recall: 0.9819 - val_accuracy: 0.9355 - val_loss: 0.1816 - val_precision: 0.9209 - val_recall: 0.9971
# Epoch 6/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9857 - loss: 0.0477 - precision: 0.9864 - recall: 0.9870 - val_accuracy: 0.9610 - val_loss: 0.1266 - val_precision: 0.9492 - val_recall: 1.0000
# Epoch 7/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9860 - loss: 0.0477 - precision: 0.9842 - recall: 0.9898 - val_accuracy: 0.9631 - val_loss: 0.0912 - val_precision: 0.9919 - val_recall: 0.9572
# Epoch 8/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9848 - loss: 0.0383 - precision: 0.9853 - recall: 0.9864 - val_accuracy: 0.8844 - val_loss: 0.3366 - val_precision: 0.9977 - val_recall: 0.8434
# Epoch 9/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9845 - loss: 0.0433 - precision: 0.9831 - recall: 0.9881 - val_accuracy: 0.9844 - val_loss: 0.0740 - val_precision: 0.9837 - val_recall: 0.9951
# Epoch 10/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9833 - loss: 0.0502 - precision: 0.9842 - recall: 0.9847 - val_accuracy: 0.8617 - val_loss: 0.3793 - val_precision: 0.9976 - val_recall: 0.8123
# Epoch 11/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9900 - loss: 0.0348 - precision: 0.9904 - recall: 0.9909 - val_accuracy: 0.9780 - val_loss: 0.0572 - val_precision: 0.9911 - val_recall: 0.9786
# Epoch 12/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9906 - loss: 0.0296 - precision: 0.9898 - recall: 0.9926 - val_accuracy: 0.8489 - val_loss: 0.5960 - val_precision: 0.9988 - val_recall: 0.7938
# Epoch 13/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9918 - loss: 0.0258 - precision: 0.9910 - recall: 0.9938 - val_accuracy: 0.9887 - val_loss: 0.0515 - val_precision: 0.9875 - val_recall: 0.9971
# Epoch 14/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9897 - loss: 0.0348 - precision: 0.9909 - recall: 0.9898 - val_accuracy: 0.9837 - val_loss: 0.0457 - val_precision: 0.9931 - val_recall: 0.9844
# Epoch 15/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9948 - loss: 0.0194 - precision: 0.9955 - recall: 0.9949 - val_accuracy: 0.9631 - val_loss: 0.1114 - val_precision: 0.9949 - val_recall: 0.9543
# Epoch 16/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9918 - loss: 0.0280 - precision: 0.9938 - recall: 0.9909 - val_accuracy: 0.9766 - val_loss: 0.1263 - val_precision: 0.9698 - val_recall: 0.9990
# Epoch 17/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9918 - loss: 0.0229 - precision: 0.9932 - recall: 0.9915 - val_accuracy: 0.9872 - val_loss: 0.0644 - val_precision: 0.9846 - val_recall: 0.9981
# Epoch 18/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9851 - loss: 0.0445 - precision: 0.9853 - recall: 0.9870 - val_accuracy: 0.9596 - val_loss: 0.1006 - val_precision: 0.9939 - val_recall: 0.9504
# Epoch 19/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9951 - loss: 0.0170 - precision: 0.9960 - recall: 0.9949 - val_accuracy: 0.8681 - val_loss: 0.5273 - val_precision: 0.9988 - val_recall: 0.8200
# Epoch 20/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9945 - loss: 0.0179 - precision: 0.9955 - recall: 0.9943 - val_accuracy: 0.9844 - val_loss: 0.0615 - val_precision: 0.9827 - val_recall: 0.9961
# Epoch 21/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9912 - loss: 0.0281 - precision: 0.9910 - recall: 0.9926 - val_accuracy: 0.9624 - val_loss: 0.1009 - val_precision: 0.9959 - val_recall: 0.9523
# Epoch 22/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9930 - loss: 0.0179 - precision: 0.9938 - recall: 0.9932 - val_accuracy: 0.8830 - val_loss: 0.4648 - val_precision: 1.0000 - val_recall: 0.8395
# Epoch 23/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9909 - loss: 0.0248 - precision: 0.9915 - recall: 0.9915 - val_accuracy: 0.9440 - val_loss: 0.1486 - val_precision: 0.9969 - val_recall: 0.9261
# Epoch 24/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9957 - loss: 0.0119 - precision: 0.9955 - recall: 0.9966 - val_accuracy: 0.9887 - val_loss: 0.0590 - val_precision: 0.9847 - val_recall: 1.0000
# Epoch 25/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9942 - loss: 0.0176 - precision: 0.9955 - recall: 0.9938 - val_accuracy: 0.9865 - val_loss: 0.0436 - val_precision: 0.9932 - val_recall: 0.9883
# Epoch 26/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9951 - loss: 0.0138 - precision: 0.9955 - recall: 0.9955 - val_accuracy: 0.9298 - val_loss: 0.2538 - val_precision: 0.9968 - val_recall: 0.9066
# Epoch 27/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9954 - loss: 0.0122 - precision: 0.9949 - recall: 0.9966 - val_accuracy: 0.9887 - val_loss: 0.0762 - val_precision: 0.9875 - val_recall: 0.9971
# Epoch 28/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9942 - loss: 0.0168 - precision: 0.9949 - recall: 0.9943 - val_accuracy: 0.9901 - val_loss: 0.0401 - val_precision: 0.9884 - val_recall: 0.9981
# Epoch 29/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9957 - loss: 0.0091 - precision: 0.9960 - recall: 0.9960 - val_accuracy: 0.9787 - val_loss: 0.0935 - val_precision: 0.9960 - val_recall: 0.9747
# Epoch 30/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 10ms/step - accuracy: 0.9976 - loss: 0.0074 - precision: 0.9972 - recall: 0.9983 - val_accuracy: 0.9872 - val_loss: 0.0421 - val_precision: 0.9922 - val_recall: 0.9903
# Epoch 31/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9948 - loss: 0.0149 - precision: 0.9955 - recall: 0.9949 - val_accuracy: 0.9830 - val_loss: 0.0605 - val_precision: 0.9951 - val_recall: 0.9815
# Epoch 32/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9973 - loss: 0.0118 - precision: 0.9972 - recall: 0.9977 - val_accuracy: 0.9865 - val_loss: 0.0546 - val_precision: 0.9970 - val_recall: 0.9844
# Epoch 33/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9976 - loss: 0.0067 - precision: 0.9977 - recall: 0.9977 - val_accuracy: 0.9560 - val_loss: 0.1668 - val_precision: 0.9969 - val_recall: 0.9426
# Epoch 34/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9921 - loss: 0.0249 - precision: 0.9926 - recall: 0.9926 - val_accuracy: 0.9340 - val_loss: 0.1766 - val_precision: 0.9979 - val_recall: 0.9115
# Epoch 35/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9970 - loss: 0.0074 - precision: 0.9977 - recall: 0.9966 - val_accuracy: 0.9730 - val_loss: 0.0889 - val_precision: 0.9970 - val_recall: 0.9660
# Epoch 36/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9973 - loss: 0.0083 - precision: 0.9977 - recall: 0.9972 - val_accuracy: 0.9872 - val_loss: 0.0987 - val_precision: 0.9828 - val_recall: 1.0000
# Epoch 37/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9942 - loss: 0.0145 - precision: 0.9938 - recall: 0.9955 - val_accuracy: 0.9887 - val_loss: 0.0373 - val_precision: 0.9932 - val_recall: 0.9912
# Epoch 38/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9948 - loss: 0.0167 - precision: 0.9960 - recall: 0.9943 - val_accuracy: 0.9908 - val_loss: 0.0411 - val_precision: 0.9894 - val_recall: 0.9981
# Epoch 39/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9964 - loss: 0.0106 - precision: 0.9955 - recall: 0.9977 - val_accuracy: 0.9908 - val_loss: 0.0411 - val_precision: 0.9913 - val_recall: 0.9961
# Epoch 40/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9970 - loss: 0.0089 - precision: 0.9960 - recall: 0.9983 - val_accuracy: 0.9858 - val_loss: 0.0461 - val_precision: 0.9932 - val_recall: 0.9874
# Epoch 41/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9979 - loss: 0.0049 - precision: 0.9977 - recall: 0.9983 - val_accuracy: 0.9702 - val_loss: 0.1260 - val_precision: 0.9970 - val_recall: 0.9621
# Epoch 42/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9954 - loss: 0.0117 - precision: 0.9960 - recall: 0.9955 - val_accuracy: 0.9837 - val_loss: 0.0473 - val_precision: 0.9922 - val_recall: 0.9854
# Epoch 43/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9964 - loss: 0.0084 - precision: 0.9960 - recall: 0.9972 - val_accuracy: 0.9901 - val_loss: 0.0664 - val_precision: 0.9884 - val_recall: 0.9981
# Epoch 44/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9976 - loss: 0.0049 - precision: 0.9977 - recall: 0.9977 - val_accuracy: 0.9539 - val_loss: 0.1804 - val_precision: 0.9990 - val_recall: 0.9377
# Epoch 45/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9982 - loss: 0.0035 - precision: 0.9989 - recall: 0.9977 - val_accuracy: 0.9716 - val_loss: 0.1170 - val_precision: 0.9970 - val_recall: 0.9640
# Epoch 46/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 1.0000 - loss: 5.6361e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9908 - val_loss: 0.0425 - val_precision: 0.9913 - val_recall: 0.9961
# Epoch 47/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 1.0000 - loss: 5.4985e-04 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9858 - val_loss: 0.0591 - val_precision: 0.9961 - val_recall: 0.9844
# Epoch 48/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9991 - loss: 0.0022 - precision: 0.9989 - recall: 0.9994 - val_accuracy: 0.8383 - val_loss: 1.3631 - val_precision: 0.9988 - val_recall: 0.7792
# Epoch 49/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 0.9960 - loss: 0.0109 - precision: 0.9960 - recall: 0.9966 - val_accuracy: 0.9865 - val_loss: 0.0587 - val_precision: 0.9961 - val_recall: 0.9854
# Epoch 50/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 11ms/step - accuracy: 1.0000 - loss: 0.0015 - precision: 1.0000 - recall: 1.0000 - val_accuracy: 0.9858 - val_loss: 0.0666 - val_precision: 0.9941 - val_recall: 0.9864

# %%
# =========================
# CELL 1
# =========================

import numpy as np
from sklearn.metrics import roc_curve

# prediksi probabilitas
y_prob = model.predict(X_test).ravel()

# label asli
y_true = y_test

# =========================
# EVALUASI DEFAULT THRESHOLD 0.5
# =========================

default_threshold = 0.5
y_pred_default = (y_prob >= default_threshold).astype(int)

# =========================
# CARI THRESHOLD TERBAIK
# =========================
# strategi:
# cari threshold dengan F1 tertinggi

thresholds = np.arange(0.1, 0.91, 0.01)

best_threshold = 0.5
best_f1 = 0

for th in thresholds:

    y_pred_temp = (y_prob >= th).astype(int)

    TP = np.sum((y_true == 1) & (y_pred_temp == 1))
    TN = np.sum((y_true == 0) & (y_pred_temp == 0))
    FP = np.sum((y_true == 0) & (y_pred_temp == 1))
    FN = np.sum((y_true == 1) & (y_pred_temp == 0))

    precision = TP / (TP + FP + 1e-12)
    recall = TP / (TP + FN + 1e-12)

    f1 = 2 * precision * recall / (precision + recall + 1e-12)

    if f1 > best_f1:
        best_f1 = f1
        best_threshold = th

print("Best Threshold:", best_threshold)
print("Best F1 Score :", best_f1)

# prediksi final threshold terbaik
y_pred_best = (y_prob >= best_threshold).astype(int)
# Out:
# 83/97 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# 2026-05-22 23:04:49.882053: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_138_0', 36 bytes spill stores, 36 bytes spill loads
#
# 2026-05-22 23:04:50.094923: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_138', 488 bytes spill stores, 488 bytes spill loads
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 6s 51ms/step
# Best Threshold: 0.6499999999999997
# Best F1 Score : 0.9805369127511773

# %%
# =========================
# CELL 2
# =========================

from sklearn.metrics import confusion_matrix

# ===== DEFAULT 0.5 =====
cm_default = confusion_matrix(y_true, y_pred_default)

TN_d, FP_d, FN_d, TP_d = cm_default.ravel()

print("=== Confusion Matrix (Threshold = 0.5) ===")
print(cm_default)

# ===== BEST THRESHOLD =====
cm_best = confusion_matrix(y_true, y_pred_best)

TN_b, FP_b, FN_b, TP_b = cm_best.ravel()

print("\n=== Confusion Matrix (Best Threshold) ===")
print(cm_best)
# Out:
# === Confusion Matrix (Threshold = 0.5) ===
# [[1571   29]
#  [  31 1461]]
#
# === Confusion Matrix (Best Threshold) ===
# [[1573   27]
#  [  31 1461]]

# %%
# =========================
# CELL 3
# =========================

def calculate_metrics(TN, FP, FN, TP):

    accuracy = (TP + TN) / (TP + TN + FP + FN)

    precision = TP / (TP + FP + 1e-12)

    recall = TP / (TP + FN + 1e-12)

    f1 = 2 * precision * recall / (precision + recall + 1e-12)

    FPR = FP / (FP + TN + 1e-12)

    FNR = FN / (FN + TP + 1e-12)

    return accuracy, precision, recall, f1, FPR, FNR


# ===== DEFAULT =====
metrics_default = calculate_metrics(TN_d, FP_d, FN_d, TP_d)

# ===== BEST =====
metrics_best = calculate_metrics(TN_b, FP_b, FN_b, TP_b)

# %%
# =========================
# CELL 4
# =========================

metric_names = [
    "Accuracy",
    "Precision",
    "Recall",
    "F1-score",
    "FPR",
    "FNR"
]

print("========================================")
print("THRESHOLD = 0.5")
print("========================================")

for name, value in zip(metric_names, metrics_default):
    print(f"{name:10}: {value:.6f}")

print("\n")

print("========================================")
print(f"BEST THRESHOLD = {best_threshold:.2f}")
print("========================================")

for name, value in zip(metric_names, metrics_best):
    print(f"{name:10}: {value:.6f}")
# Out:
# ========================================
# THRESHOLD = 0.5
# ========================================
# Accuracy  : 0.980595
# Precision : 0.980537
# Recall    : 0.979223
# F1-score  : 0.979879
# FPR       : 0.018125
# FNR       : 0.020777
#
#
# ========================================
# BEST THRESHOLD = 0.65
# ========================================
# Accuracy  : 0.981242
# Precision : 0.981855
# Recall    : 0.979223
# F1-score  : 0.980537
# FPR       : 0.016875
# FNR       : 0.020777

# %%
# =========================
# CELL 5
# =========================

import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

fpr, tpr, _ = roc_curve(y_true, y_prob)

roc_auc = auc(fpr, tpr)

plt.figure(figsize=(6,6))

plt.plot(fpr, tpr, label="AUC = %0.4f" % roc_auc)

plt.plot([0,1],[0,1],'--')

plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")

plt.title("ROC Curve")

plt.legend()

plt.grid(True)

plt.show()
