# %%
import numpy as np
import os
import gc
import time
import matplotlib.pyplot as plt
import seaborn as sns

import tensorflow as tf
from tensorflow.keras import layers, models

from sklearn.metrics import (
    confusion_matrix,
    classification_report,
    roc_curve,
    auc,
    precision_recall_curve,
    f1_score
)

import pandas as pd
import time
from tensorflow.keras.callbacks import Callback, EarlyStopping, ModelCheckpoint
from tensorflow.keras.callbacks import ReduceLROnPlateau, CSVLogger
# Out:
# 2026-05-23 01:00:28.647035: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-05-23 01:00:28.659212: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1779472828.673460  696358 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1779472828.678090  696358 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1779472828.689179  696358 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1779472828.689198  696358 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1779472828.689200  696358 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1779472828.689201  696358 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-05-23 01:00:28.693249: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
Load_Path = "/home/dani/Documents/tugas akhir/TugasAkhir/codeTugasAkhirku2026/tow_ids/Preprocessing/Preprocessingbaru/imgsize128lv2/norm/dwt/"
ukuran = 32

# %%
train_data = np.load(os.path.join(Load_Path, "tow_ids_train_dwt.npz"))
test_data  = np.load(os.path.join(Load_Path, "tow_ids_test_dwt.npz"))
validation_data = np.load(os.path.join(Load_Path, "tow_ids_eval_dwt.npz"))

X_train = train_data["X"]
y_train = train_data["y"]

X_val = validation_data["X"]
y_val = validation_data["y"]

X_test  = test_data["X"]
y_test  = test_data["y"]

print(X_train.shape, y_train.shape)
print(X_val.shape, y_val.shape)
print(X_test.shape, y_test.shape)
# Out:
# (6582, 32, 32, 3) (6582,)
# (2821, 32, 32, 3) (2821,)
# (6184, 32, 32, 3) (6184,)

# %%
print("Train label distribution:", np.unique(y_train, return_counts=True))
print("Test label distribution :", np.unique(y_test, return_counts=True))
print("Validation label distribution :", np.unique(y_val, return_counts=True))

print("Min value:", X_train.min())
print("Max value:", X_train.max())
# Out:
# Train label distribution: (array([0, 1]), array([3137, 3445]))
# Test label distribution : (array([0, 1]), array([3296, 2888]))
# Validation label distribution : (array([0, 1]), array([ 887, 1934]))
# Min value: -0.72264206
# Max value: 4.4470997

# %%
import tensorflow as tf
from tensorflow.keras import layers, models


def composite_conv(x, filters, kernel_size):
    x = layers.Conv2D(
        filters,
        kernel_size,
        padding="same",
        use_bias=False
    )(x)

    x = layers.BatchNormalization()(x)

    x = layers.ReLU()(x)

    return x


def SE_block(x, ratio=16):
    channels = x.shape[-1]

    se = layers.GlobalAveragePooling2D()(x)

    se = layers.Dense(
        max(channels // ratio, 4),
        activation="relu"
    )(se)

    se = layers.Dense(
        channels,
        activation="sigmoid"
    )(se)

    se = layers.Reshape((1, 1, channels))(se)

    out = layers.Multiply()([x, se])

    return out


def DPDB_block(x, filters, pool=True):
    shortcut = x

    h = composite_conv(x, filters // 2, (1, 3))

    v = composite_conv(x, filters // 2, (3, 1))

    concat = layers.Concatenate()([h, v])

    fusion = composite_conv(concat, filters, (1, 1))

    fusion = SE_block(fusion)

    if pool:
        fusion = layers.MaxPooling2D((2, 2))(fusion)

    shortcut = layers.Conv2D(
        filters,
        (1, 1),
        padding="same",
        use_bias=False
    )(shortcut)

    shortcut = layers.BatchNormalization()(shortcut)

    if pool:
        shortcut = layers.MaxPooling2D((2, 2))(shortcut)

    out = layers.Add()([fusion, shortcut])

    out = layers.ReLU()(out)

    return out


input_layer = layers.Input(shape=(ukuran, ukuran, 3))

x = composite_conv(input_layer, 16, (1, 3))

x = composite_conv(x, 16, (3, 1))

x = DPDB_block(x, 32, pool=True)

x = DPDB_block(x, 64, pool=False)

x = composite_conv(x, 48, (1, 1))

x = layers.GlobalAveragePooling2D()(x)

x = layers.Dense(
    64,
    activation="relu"
)(x)

x = layers.Dropout(0.5)(x)

output_layer = layers.Dense(
    1,
    activation="sigmoid"
)(x)

model = models.Model(
    inputs=input_layer,
    outputs=output_layer
)

model.compile(

    optimizer=tf.keras.optimizers.AdamW(
        learning_rate=1e-4,
        weight_decay=1e-5
    ),

    loss=tf.keras.losses.BinaryFocalCrossentropy(
        apply_class_balancing=True,
        alpha=0.75,
        gamma=2.0
    ),

    metrics=[

        tf.keras.metrics.BinaryAccuracy(
            name="accuracy"
        ),

        tf.keras.metrics.Precision(
            name="precision"
        ),

        tf.keras.metrics.Recall(
            name="recall"
        ),

        tf.keras.metrics.AUC(
            name="auc"
        ),

        tf.keras.metrics.AUC(
            curve="PR",
            name="pr_auc"
        )
    ]
)

model.summary()
# Out:
# I0000 00:00:1779472830.264021  696358 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 4144 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 32, 32, 3) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 32, 32,    │        144 │ input_layer[0][0] │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 32, 32,    │         64 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu (ReLU)        │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 32, 32,    │        768 │ re_lu[0][0]       │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │         64 │ conv2d_1[0][0]    │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_1 (ReLU)      │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 32, 32,    │        768 │ re_lu_1[0][0]     │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 32, 32,    │        768 │ re_lu_1[0][0]     │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │         64 │ conv2d_2[0][0]    │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │         64 │ conv2d_3[0][0]    │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_2 (ReLU)      │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_3 (ReLU)      │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 32, 32,    │          0 │ re_lu_2[0][0],    │
# │ (Concatenate)       │ 32)               │            │ re_lu_3[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 32, 32,    │      1,024 │ concatenate[0][0] │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        128 │ conv2d_4[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_4 (ReLU)      │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 32)        │          0 │ re_lu_4[0][0]     │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 4)         │        132 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 32)        │        160 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape (Reshape)   │ (None, 1, 1, 32)  │          0 │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 32, 32,    │        512 │ re_lu_1[0][0]     │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply (Multiply) │ (None, 32, 32,    │          0 │ re_lu_4[0][0],    │
# │                     │ 32)               │            │ reshape[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        128 │ conv2d_5[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 16, 16,    │          0 │ multiply[0][0]    │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 16, 16,    │          0 │ max_pooling2d[0]… │
# │                     │ 32)               │            │ max_pooling2d_1[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_5 (ReLU)      │ (None, 16, 16,    │          0 │ add[0][0]         │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 16, 16,    │      3,072 │ re_lu_5[0][0]     │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 16, 16,    │      3,072 │ re_lu_5[0][0]     │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        128 │ conv2d_6[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        128 │ conv2d_7[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_6 (ReLU)      │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_7 (ReLU)      │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 16, 16,    │          0 │ re_lu_6[0][0],    │
# │ (Concatenate)       │ 64)               │            │ re_lu_7[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 16, 16,    │      4,096 │ concatenate_1[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        256 │ conv2d_8[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_8 (ReLU)      │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 64)        │          0 │ re_lu_8[0][0]     │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 4)         │        260 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 64)        │        320 │ dense_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_1 (Reshape) │ (None, 1, 1, 64)  │          0 │ dense_3[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 16, 16,    │      2,048 │ re_lu_5[0][0]     │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_1          │ (None, 16, 16,    │          0 │ re_lu_8[0][0],    │
# │ (Multiply)          │ 64)               │            │ reshape_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        256 │ conv2d_9[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 16, 16,    │          0 │ multiply_1[0][0], │
# │                     │ 64)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_9 (ReLU)      │ (None, 16, 16,    │          0 │ add_1[0][0]       │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 16, 16,    │      3,072 │ re_lu_9[0][0]     │
# │                     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        192 │ conv2d_10[0][0]   │
# │ (BatchNormalizatio… │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_10 (ReLU)     │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 48)        │          0 │ re_lu_10[0][0]    │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_4 (Dense)     │ (None, 64)        │      3,136 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 64)        │          0 │ dense_4[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_5 (Dense)     │ (None, 1)         │         65 │ dropout[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 24,889 (97.22 KB)
#  Trainable params: 24,153 (94.35 KB)
#  Non-trainable params: 736 (2.88 KB)

# %%
print("TensorFlow version:", tf.__version__)
print("GPU available:", tf.config.list_physical_devices('GPU'))

tf.debugging.set_log_device_placement(True)
# Out:
# TensorFlow version: 2.19.1
# GPU available: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
class TrainingLogger(Callback):

    def on_train_begin(self, logs=None):
        print("\nTraining started")
        print("-"*70)
        print("{:<8} {:<12} {:<12} {:<12} {:<12}".format(
            "Epoch","Loss","Accuracy","Val_Loss","Val_Acc"))
        print("-"*70)

    def on_epoch_end(self, epoch, logs=None):

        print("{:<8} {:<12.4f} {:<12.4f} {:<12.4f} {:<12.4f}".format(
            epoch+1,
            logs["loss"],
            logs["accuracy"],
            logs["val_loss"],
            logs["val_accuracy"]
        ))

# %%
checkpoint = ModelCheckpoint(
    "best_model_tow_idsIMGSIZE64.keras",
    monitor="val_accuracy",
    save_best_only=True,
    verbose=0
)

# %%
print("\nDataset summary")
print("-"*40)
print("Train samples :", X_train.shape[0])
print("Test samples  :", X_test.shape[0])
print("Validation samples  :", X_val.shape[0])
print("Image shape   :", X_train.shape[1:])
print("Batch size    :", 32)
print("Epochs        :", 50)
print("-"*40)
# Out:
# Dataset summary
# ----------------------------------------
# Train samples : 6582
# Test samples  : 6184
# Validation samples  : 2821
# Image shape   : (32, 32, 3)
# Batch size    : 32
# Epochs        : 50
# ----------------------------------------

# %%
history = model.fit(
    X_train, y_train,
    epochs=50,
    batch_size=32,
    validation_data=(X_val, y_val),
    verbose=1,
    callbacks=[checkpoint]
    
)
# Out:
# Epoch 1/50
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1779472835.626341  696497 service.cc:152] XLA service 0x7ea1d8002b90 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1779472835.626361  696497 service.cc:160]   StreamExecutor device (0): NVIDIA GeForce RTX 3060 Laptop GPU, Compute Capability 8.6
# 2026-05-23 01:00:35.769123: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1779472836.558381  696497 cuda_dnn.cc:529] Loaded cuDNN version 91701
#  28/206 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5340 - auc: 0.5509 - loss: 0.0760 - pr_auc: 0.5511 - precision: 0.5248 - recall: 0.8664
# I0000 00:00:1779472844.216221  696497 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 28s 73ms/step - accuracy: 0.6035 - auc: 0.7835 - loss: 0.0595 - pr_auc: 0.8177 - precision: 0.5731 - recall: 0.9507 - val_accuracy: 0.6856 - val_auc: 0.8190 - val_loss: 0.0557 - val_pr_auc: 0.9278 - val_precision: 0.6856 - val_recall: 1.0000
# Epoch 2/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7256 - auc: 0.9088 - loss: 0.0446 - pr_auc: 0.9281 - precision: 0.6670 - recall: 0.9501 - val_accuracy: 0.7551 - val_auc: 0.9413 - val_loss: 0.0371 - val_pr_auc: 0.9764 - val_precision: 0.7475 - val_recall: 0.9705
# Epoch 3/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8136 - auc: 0.9384 - loss: 0.0372 - pr_auc: 0.9523 - precision: 0.7612 - recall: 0.9382 - val_accuracy: 0.8568 - val_auc: 0.9519 - val_loss: 0.0314 - val_pr_auc: 0.9804 - val_precision: 0.8548 - val_recall: 0.9529
# Epoch 4/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8475 - auc: 0.9497 - loss: 0.0333 - pr_auc: 0.9605 - precision: 0.8025 - recall: 0.9399 - val_accuracy: 0.8430 - val_auc: 0.9598 - val_loss: 0.0274 - val_pr_auc: 0.9842 - val_precision: 0.8345 - val_recall: 0.9617
# Epoch 5/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8815 - auc: 0.9631 - loss: 0.0289 - pr_auc: 0.9705 - precision: 0.8469 - recall: 0.9443 - val_accuracy: 0.8614 - val_auc: 0.9635 - val_loss: 0.0255 - val_pr_auc: 0.9860 - val_precision: 0.8580 - val_recall: 0.9560
# Epoch 6/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9094 - auc: 0.9740 - loss: 0.0244 - pr_auc: 0.9810 - precision: 0.8839 - recall: 0.9521 - val_accuracy: 0.8798 - val_auc: 0.9694 - val_loss: 0.0235 - val_pr_auc: 0.9880 - val_precision: 0.8735 - val_recall: 0.9643
# Epoch 7/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9356 - auc: 0.9811 - loss: 0.0205 - pr_auc: 0.9863 - precision: 0.9220 - recall: 0.9579 - val_accuracy: 0.9199 - val_auc: 0.9696 - val_loss: 0.0246 - val_pr_auc: 0.9871 - val_precision: 0.9309 - val_recall: 0.9540
# Epoch 8/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9436 - auc: 0.9838 - loss: 0.0184 - pr_auc: 0.9890 - precision: 0.9349 - recall: 0.9591 - val_accuracy: 0.9295 - val_auc: 0.9729 - val_loss: 0.0259 - val_pr_auc: 0.9888 - val_precision: 0.9502 - val_recall: 0.9467
# Epoch 9/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9473 - auc: 0.9876 - loss: 0.0163 - pr_auc: 0.9914 - precision: 0.9344 - recall: 0.9672 - val_accuracy: 0.9167 - val_auc: 0.9716 - val_loss: 0.0401 - val_pr_auc: 0.9879 - val_precision: 0.9824 - val_recall: 0.8945
# Epoch 10/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9570 - auc: 0.9891 - loss: 0.0148 - pr_auc: 0.9926 - precision: 0.9515 - recall: 0.9672 - val_accuracy: 0.9273 - val_auc: 0.9717 - val_loss: 0.0321 - val_pr_auc: 0.9881 - val_precision: 0.9670 - val_recall: 0.9255
# Epoch 11/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9575 - auc: 0.9903 - loss: 0.0141 - pr_auc: 0.9932 - precision: 0.9497 - recall: 0.9701 - val_accuracy: 0.8561 - val_auc: 0.9690 - val_loss: 0.0612 - val_pr_auc: 0.9864 - val_precision: 0.9891 - val_recall: 0.7989
# Epoch 12/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9619 - auc: 0.9903 - loss: 0.0135 - pr_auc: 0.9933 - precision: 0.9581 - recall: 0.9695 - val_accuracy: 0.8859 - val_auc: 0.9619 - val_loss: 0.0467 - val_pr_auc: 0.9828 - val_precision: 0.9702 - val_recall: 0.8599
# Epoch 13/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9599 - auc: 0.9910 - loss: 0.0134 - pr_auc: 0.9936 - precision: 0.9530 - recall: 0.9713 - val_accuracy: 0.7476 - val_auc: 0.9532 - val_loss: 0.0922 - val_pr_auc: 0.9779 - val_precision: 0.9857 - val_recall: 0.6412
# Epoch 14/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9670 - auc: 0.9924 - loss: 0.0121 - pr_auc: 0.9947 - precision: 0.9638 - recall: 0.9736 - val_accuracy: 0.7086 - val_auc: 0.9420 - val_loss: 0.1067 - val_pr_auc: 0.9734 - val_precision: 0.9886 - val_recall: 0.5817
# Epoch 15/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9638 - auc: 0.9930 - loss: 0.0118 - pr_auc: 0.9949 - precision: 0.9599 - recall: 0.9716 - val_accuracy: 0.6803 - val_auc: 0.9251 - val_loss: 0.1231 - val_pr_auc: 0.9652 - val_precision: 0.9859 - val_recall: 0.5414
# Epoch 16/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9686 - auc: 0.9937 - loss: 0.0110 - pr_auc: 0.9956 - precision: 0.9634 - recall: 0.9771 - val_accuracy: 0.7249 - val_auc: 0.9007 - val_loss: 0.1050 - val_pr_auc: 0.9514 - val_precision: 0.9617 - val_recall: 0.6236
# Epoch 17/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9698 - auc: 0.9944 - loss: 0.0103 - pr_auc: 0.9960 - precision: 0.9645 - recall: 0.9782 - val_accuracy: 0.6693 - val_auc: 0.9192 - val_loss: 0.1286 - val_pr_auc: 0.9602 - val_precision: 0.9762 - val_recall: 0.5305
# Epoch 18/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9663 - auc: 0.9938 - loss: 0.0109 - pr_auc: 0.9956 - precision: 0.9616 - recall: 0.9745 - val_accuracy: 0.7352 - val_auc: 0.8773 - val_loss: 0.0936 - val_pr_auc: 0.9395 - val_precision: 0.9361 - val_recall: 0.6587
# Epoch 19/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9672 - auc: 0.9946 - loss: 0.0105 - pr_auc: 0.9961 - precision: 0.9601 - recall: 0.9779 - val_accuracy: 0.5257 - val_auc: 0.8413 - val_loss: 0.2265 - val_pr_auc: 0.9250 - val_precision: 0.9806 - val_recall: 0.3144
# Epoch 20/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9711 - auc: 0.9949 - loss: 0.0099 - pr_auc: 0.9963 - precision: 0.9654 - recall: 0.9800 - val_accuracy: 0.4594 - val_auc: 0.7672 - val_loss: 0.3427 - val_pr_auc: 0.8884 - val_precision: 0.9789 - val_recall: 0.2161
# Epoch 21/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9702 - auc: 0.9947 - loss: 0.0099 - pr_auc: 0.9963 - precision: 0.9643 - recall: 0.9794 - val_accuracy: 0.4924 - val_auc: 0.7700 - val_loss: 0.2756 - val_pr_auc: 0.8905 - val_precision: 0.9614 - val_recall: 0.2704
# Epoch 22/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9743 - auc: 0.9959 - loss: 0.0089 - pr_auc: 0.9970 - precision: 0.9696 - recall: 0.9817 - val_accuracy: 0.4445 - val_auc: 0.7380 - val_loss: 0.3928 - val_pr_auc: 0.8769 - val_precision: 0.9791 - val_recall: 0.1939
# Epoch 23/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9736 - auc: 0.9956 - loss: 0.0089 - pr_auc: 0.9969 - precision: 0.9693 - recall: 0.9806 - val_accuracy: 0.5051 - val_auc: 0.7686 - val_loss: 0.2690 - val_pr_auc: 0.8900 - val_precision: 0.9590 - val_recall: 0.2906
# Epoch 24/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9730 - auc: 0.9964 - loss: 0.0087 - pr_auc: 0.9972 - precision: 0.9676 - recall: 0.9811 - val_accuracy: 0.4853 - val_auc: 0.6969 - val_loss: 0.3036 - val_pr_auc: 0.8545 - val_precision: 0.9430 - val_recall: 0.2653
# Epoch 25/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9742 - auc: 0.9964 - loss: 0.0082 - pr_auc: 0.9975 - precision: 0.9701 - recall: 0.9808 - val_accuracy: 0.4428 - val_auc: 0.6110 - val_loss: 0.4473 - val_pr_auc: 0.8171 - val_precision: 0.9665 - val_recall: 0.1939
# Epoch 26/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9751 - auc: 0.9964 - loss: 0.0084 - pr_auc: 0.9972 - precision: 0.9702 - recall: 0.9826 - val_accuracy: 0.4392 - val_auc: 0.5664 - val_loss: 0.5229 - val_pr_auc: 0.7933 - val_precision: 0.9706 - val_recall: 0.1877
# Epoch 27/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9745 - auc: 0.9967 - loss: 0.0080 - pr_auc: 0.9975 - precision: 0.9702 - recall: 0.9814 - val_accuracy: 0.4385 - val_auc: 0.6065 - val_loss: 0.4888 - val_pr_auc: 0.8139 - val_precision: 0.9730 - val_recall: 0.1861
# Epoch 28/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9781 - auc: 0.9966 - loss: 0.0080 - pr_auc: 0.9976 - precision: 0.9744 - recall: 0.9840 - val_accuracy: 0.4456 - val_auc: 0.5123 - val_loss: 0.5175 - val_pr_auc: 0.7683 - val_precision: 0.9447 - val_recall: 0.2032
# Epoch 29/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9745 - auc: 0.9968 - loss: 0.0078 - pr_auc: 0.9976 - precision: 0.9672 - recall: 0.9846 - val_accuracy: 0.4342 - val_auc: 0.4634 - val_loss: 0.5800 - val_pr_auc: 0.7473 - val_precision: 0.9721 - val_recall: 0.1799
# Epoch 30/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9802 - auc: 0.9973 - loss: 0.0070 - pr_auc: 0.9980 - precision: 0.9759 - recall: 0.9866 - val_accuracy: 0.4428 - val_auc: 0.6325 - val_loss: 0.4832 - val_pr_auc: 0.8272 - val_precision: 0.9763 - val_recall: 0.1918
# Epoch 31/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9798 - auc: 0.9977 - loss: 0.0067 - pr_auc: 0.9983 - precision: 0.9745 - recall: 0.9872 - val_accuracy: 0.4346 - val_auc: 0.5133 - val_loss: 0.5792 - val_pr_auc: 0.7717 - val_precision: 0.9802 - val_recall: 0.1789
# Epoch 32/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9804 - auc: 0.9977 - loss: 0.0067 - pr_auc: 0.9983 - precision: 0.9751 - recall: 0.9878 - val_accuracy: 0.4300 - val_auc: 0.4979 - val_loss: 0.6532 - val_pr_auc: 0.7638 - val_precision: 0.9851 - val_recall: 0.1711
# Epoch 33/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9801 - auc: 0.9979 - loss: 0.0064 - pr_auc: 0.9984 - precision: 0.9767 - recall: 0.9855 - val_accuracy: 0.4342 - val_auc: 0.4294 - val_loss: 0.6617 - val_pr_auc: 0.7309 - val_precision: 0.9774 - val_recall: 0.1789
# Epoch 34/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9813 - auc: 0.9984 - loss: 0.0059 - pr_auc: 0.9988 - precision: 0.9759 - recall: 0.9887 - val_accuracy: 0.4371 - val_auc: 0.5171 - val_loss: 0.6248 - val_pr_auc: 0.7725 - val_precision: 0.9832 - val_recall: 0.1820
# Epoch 35/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9839 - auc: 0.9982 - loss: 0.0059 - pr_auc: 0.9986 - precision: 0.9791 - recall: 0.9904 - val_accuracy: 0.4300 - val_auc: 0.3900 - val_loss: 0.8037 - val_pr_auc: 0.7125 - val_precision: 0.9822 - val_recall: 0.1717
# Epoch 36/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9812 - auc: 0.9985 - loss: 0.0056 - pr_auc: 0.9988 - precision: 0.9759 - recall: 0.9884 - val_accuracy: 0.4467 - val_auc: 0.4766 - val_loss: 0.5632 - val_pr_auc: 0.7511 - val_precision: 0.8894 - val_recall: 0.2203
# Epoch 37/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9801 - auc: 0.9983 - loss: 0.0059 - pr_auc: 0.9987 - precision: 0.9748 - recall: 0.9875 - val_accuracy: 0.4420 - val_auc: 0.4535 - val_loss: 0.6736 - val_pr_auc: 0.7418 - val_precision: 0.9478 - val_recall: 0.1970
# Epoch 38/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9828 - auc: 0.9984 - loss: 0.0057 - pr_auc: 0.9987 - precision: 0.9785 - recall: 0.9890 - val_accuracy: 0.4335 - val_auc: 0.3938 - val_loss: 0.8152 - val_pr_auc: 0.7133 - val_precision: 0.9719 - val_recall: 0.1789
# Epoch 39/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9807 - auc: 0.9981 - loss: 0.0060 - pr_auc: 0.9986 - precision: 0.9754 - recall: 0.9881 - val_accuracy: 0.4403 - val_auc: 0.4240 - val_loss: 0.6794 - val_pr_auc: 0.7291 - val_precision: 0.9494 - val_recall: 0.1939
# Epoch 40/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9848 - auc: 0.9990 - loss: 0.0049 - pr_auc: 0.9992 - precision: 0.9810 - recall: 0.9901 - val_accuracy: 0.4279 - val_auc: 0.3231 - val_loss: 1.0343 - val_pr_auc: 0.6815 - val_precision: 0.9819 - val_recall: 0.1686
# Epoch 41/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9834 - auc: 0.9988 - loss: 0.0050 - pr_auc: 0.9990 - precision: 0.9782 - recall: 0.9904 - val_accuracy: 0.4328 - val_auc: 0.3174 - val_loss: 0.9077 - val_pr_auc: 0.6796 - val_precision: 0.9489 - val_recall: 0.1825
# Epoch 42/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9862 - auc: 0.9989 - loss: 0.0049 - pr_auc: 0.9991 - precision: 0.9841 - recall: 0.9896 - val_accuracy: 0.3687 - val_auc: 0.2827 - val_loss: 1.7122 - val_pr_auc: 0.6595 - val_precision: 1.0000 - val_recall: 0.0791
# Epoch 43/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9842 - auc: 0.9988 - loss: 0.0049 - pr_auc: 0.9991 - precision: 0.9802 - recall: 0.9898 - val_accuracy: 0.4392 - val_auc: 0.4308 - val_loss: 0.6822 - val_pr_auc: 0.7289 - val_precision: 0.9074 - val_recall: 0.2027
# Epoch 44/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9845 - auc: 0.9990 - loss: 0.0047 - pr_auc: 0.9992 - precision: 0.9796 - recall: 0.9910 - val_accuracy: 0.4364 - val_auc: 0.3338 - val_loss: 0.9762 - val_pr_auc: 0.6867 - val_precision: 0.9674 - val_recall: 0.1841
# Epoch 45/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9857 - auc: 0.9993 - loss: 0.0041 - pr_auc: 0.9994 - precision: 0.9819 - recall: 0.9910 - val_accuracy: 0.4311 - val_auc: 0.3266 - val_loss: 1.0177 - val_pr_auc: 0.6835 - val_precision: 0.9741 - val_recall: 0.1748
# Epoch 46/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9837 - auc: 0.9984 - loss: 0.0054 - pr_auc: 0.9988 - precision: 0.9796 - recall: 0.9896 - val_accuracy: 0.4328 - val_auc: 0.3035 - val_loss: 0.9838 - val_pr_auc: 0.6731 - val_precision: 0.9613 - val_recall: 0.1799
# Epoch 47/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9877 - auc: 0.9993 - loss: 0.0040 - pr_auc: 0.9994 - precision: 0.9825 - recall: 0.9942 - val_accuracy: 0.4342 - val_auc: 0.3399 - val_loss: 0.8458 - val_pr_auc: 0.6899 - val_precision: 0.8789 - val_recall: 0.2027
# Epoch 48/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9881 - auc: 0.9993 - loss: 0.0039 - pr_auc: 0.9994 - precision: 0.9850 - recall: 0.9925 - val_accuracy: 0.4350 - val_auc: 0.3308 - val_loss: 0.9119 - val_pr_auc: 0.6878 - val_precision: 0.8455 - val_recall: 0.2151
# Epoch 49/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9892 - auc: 0.9996 - loss: 0.0032 - pr_auc: 0.9997 - precision: 0.9848 - recall: 0.9948 - val_accuracy: 0.4342 - val_auc: 0.3209 - val_loss: 0.9531 - val_pr_auc: 0.6813 - val_precision: 0.9005 - val_recall: 0.1965
# Epoch 50/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9872 - auc: 0.9994 - loss: 0.0037 - pr_auc: 0.9995 - precision: 0.9850 - recall: 0.9907 - val_accuracy: 0.4346 - val_auc: 0.3109 - val_loss: 1.0613 - val_pr_auc: 0.6773 - val_precision: 0.9206 - val_recall: 0.1918

# %%
# =========================
# CELL 1
# =========================

import numpy as np
from sklearn.metrics import roc_curve

# prediksi probabilitas
y_prob = model.predict(X_test).ravel()

# label asli
y_true = y_test

# =========================
# EVALUASI DEFAULT THRESHOLD 0.5
# =========================

default_threshold = 0.5
y_pred_default = (y_prob >= default_threshold).astype(int)

# =========================
# CARI THRESHOLD TERBAIK
# =========================
# strategi:
# cari threshold dengan F1 tertinggi

thresholds = np.arange(0.1, 0.91, 0.01)

best_threshold = 0.5
best_f1 = 0

for th in thresholds:

    y_pred_temp = (y_prob >= th).astype(int)

    TP = np.sum((y_true == 1) & (y_pred_temp == 1))
    TN = np.sum((y_true == 0) & (y_pred_temp == 0))
    FP = np.sum((y_true == 0) & (y_pred_temp == 1))
    FN = np.sum((y_true == 1) & (y_pred_temp == 0))

    precision = TP / (TP + FP + 1e-12)
    recall = TP / (TP + FN + 1e-12)

    f1 = 2 * precision * recall / (precision + recall + 1e-12)

    if f1 > best_f1:
        best_f1 = f1
        best_threshold = th

print("Best Threshold:", best_threshold)
print("Best F1 Score :", best_f1)

# prediksi final threshold terbaik
y_pred_best = (y_prob >= best_threshold).astype(int)
# Out:
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 4s 14ms/step
# Best Threshold: 0.6699999999999997
# Best F1 Score : 0.8534516004622906

# %%
# =========================
# CELL 2
# =========================

from sklearn.metrics import confusion_matrix

# ===== DEFAULT 0.5 =====
cm_default = confusion_matrix(y_true, y_pred_default)

TN_d, FP_d, FN_d, TP_d = cm_default.ravel()

print("=== Confusion Matrix (Threshold = 0.5) ===")
print(cm_default)

# ===== BEST THRESHOLD =====
cm_best = confusion_matrix(y_true, y_pred_best)

TN_b, FP_b, FN_b, TP_b = cm_best.ravel()

print("\n=== Confusion Matrix (Best Threshold) ===")
print(cm_best)
# Out:
# === Confusion Matrix (Threshold = 0.5) ===
# [[3094  202]
#  [ 643 2245]]
#
# === Confusion Matrix (Best Threshold) ===
# [[3211   85]
#  [ 675 2213]]

# %%
# =========================
# CELL 3
# =========================

def calculate_metrics(TN, FP, FN, TP):

    accuracy = (TP + TN) / (TP + TN + FP + FN)

    precision = TP / (TP + FP + 1e-12)

    recall = TP / (TP + FN + 1e-12)

    f1 = 2 * precision * recall / (precision + recall + 1e-12)

    FPR = FP / (FP + TN + 1e-12)

    FNR = FN / (FN + TP + 1e-12)

    return accuracy, precision, recall, f1, FPR, FNR


# ===== DEFAULT =====
metrics_default = calculate_metrics(TN_d, FP_d, FN_d, TP_d)

# ===== BEST =====
metrics_best = calculate_metrics(TN_b, FP_b, FN_b, TP_b)

# %%
# =========================
# CELL 4
# =========================

metric_names = [
    "Accuracy",
    "Precision",
    "Recall",
    "F1-score",
    "FPR",
    "FNR"
]

print("========================================")
print("THRESHOLD = 0.5")
print("========================================")

for name, value in zip(metric_names, metrics_default):
    print(f"{name:10}: {value:.6f}")

print("\n")

print("========================================")
print(f"BEST THRESHOLD = {best_threshold:.2f}")
print("========================================")

for name, value in zip(metric_names, metrics_best):
    print(f"{name:10}: {value:.6f}")
# Out:
# ========================================
# THRESHOLD = 0.5
# ========================================
# Accuracy  : 0.863357
# Precision : 0.917450
# Recall    : 0.777355
# F1-score  : 0.841612
# FPR       : 0.061286
# FNR       : 0.222645
#
#
# ========================================
# BEST THRESHOLD = 0.67
# ========================================
# Accuracy  : 0.877102
# Precision : 0.963011
# Recall    : 0.766274
# F1-score  : 0.853452
# FPR       : 0.025789
# FNR       : 0.233726

# %%
# =========================
# CELL 5
# =========================

import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

fpr, tpr, _ = roc_curve(y_true, y_prob)

roc_auc = auc(fpr, tpr)

plt.figure(figsize=(6,6))

plt.plot(fpr, tpr, label="AUC = %0.4f" % roc_auc)

plt.plot([0,1],[0,1],'--')

plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")

plt.title("ROC Curve")

plt.legend()

plt.grid(True)

plt.show()
