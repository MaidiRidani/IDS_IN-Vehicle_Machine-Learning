# %%
import numpy as np
import os
import gc
import time
import matplotlib.pyplot as plt
import seaborn as sns

import tensorflow as tf
from tensorflow.keras import layers, models

from sklearn.metrics import (
    confusion_matrix,
    classification_report,
    roc_curve,
    auc,
    precision_recall_curve,
    f1_score
)

import pandas as pd
import time
from tensorflow.keras.callbacks import Callback, EarlyStopping, ModelCheckpoint
from tensorflow.keras.callbacks import ReduceLROnPlateau, CSVLogger
# Out:
# 2026-05-23 02:45:04.521388: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-05-23 02:45:04.532401: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1779479104.545599  840779 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1779479104.549824  840779 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1779479104.559690  840779 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1779479104.559710  840779 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1779479104.559711  840779 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1779479104.559712  840779 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-05-23 02:45:04.562878: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
Load_Path = "/home/dani/Documents/tugas akhir/TugasAkhir/codeTugasAkhirku2026/tow_ids/Preprocessing/Preprocessingbaru/imgsize256lv6/norm/dwt/"
ukuran = 4

# %%
train_data = np.load(os.path.join(Load_Path, "tow_ids_train_dwt.npz"))
test_data  = np.load(os.path.join(Load_Path, "tow_ids_test_dwt.npz"))
validation_data = np.load(os.path.join(Load_Path, "tow_ids_eval_dwt.npz"))

X_train = train_data["X"]
y_train = train_data["y"]

X_val = validation_data["X"]
y_val = validation_data["y"]

X_test  = test_data["X"]
y_test  = test_data["y"]

print(X_train.shape, y_train.shape)
print(X_val.shape, y_val.shape)
print(X_test.shape, y_test.shape)
# Out:
# (3291, 4, 4, 3) (3291,)
# (1410, 4, 4, 3) (1410,)
# (3092, 4, 4, 3) (3092,)

# %%
print("Train label distribution:", np.unique(y_train, return_counts=True))
print("Test label distribution :", np.unique(y_test, return_counts=True))
print("Validation label distribution :", np.unique(y_val, return_counts=True))

print("Min value:", X_train.min())
print("Max value:", X_train.max())
# Out:
# Train label distribution: (array([0, 1]), array([1524, 1767]))
# Test label distribution : (array([0, 1]), array([1600, 1492]))
# Validation label distribution : (array([0, 1]), array([ 382, 1028]))
# Min value: -1.1155049
# Max value: 58.16121

# %%
import tensorflow as tf
from tensorflow.keras import layers, models


def composite_conv(x, filters, kernel_size):
    x = layers.Conv2D(
        filters,
        kernel_size,
        padding="same",
        use_bias=False
    )(x)

    x = layers.BatchNormalization()(x)

    x = layers.ReLU()(x)

    return x


def SE_block(x, ratio=16):
    channels = x.shape[-1]

    se = layers.GlobalAveragePooling2D()(x)

    se = layers.Dense(
        max(channels // ratio, 4),
        activation="relu"
    )(se)

    se = layers.Dense(
        channels,
        activation="sigmoid"
    )(se)

    se = layers.Reshape((1, 1, channels))(se)

    out = layers.Multiply()([x, se])

    return out


def DPDB_block(x, filters, pool=True):
    shortcut = x

    h = composite_conv(x, filters // 2, (1, 3))

    v = composite_conv(x, filters // 2, (3, 1))

    concat = layers.Concatenate()([h, v])

    fusion = composite_conv(concat, filters, (1, 1))

    fusion = SE_block(fusion)

    if pool:
        fusion = layers.MaxPooling2D((2, 2))(fusion)

    shortcut = layers.Conv2D(
        filters,
        (1, 1),
        padding="same",
        use_bias=False
    )(shortcut)

    shortcut = layers.BatchNormalization()(shortcut)

    if pool:
        shortcut = layers.MaxPooling2D((2, 2))(shortcut)

    out = layers.Add()([fusion, shortcut])

    out = layers.ReLU()(out)

    return out


input_layer = layers.Input(shape=(ukuran, ukuran, 3))

x = composite_conv(input_layer, 16, (1, 3))

x = composite_conv(x, 16, (3, 1))

x = DPDB_block(x, 32, pool=True)

x = DPDB_block(x, 64, pool=False)

x = composite_conv(x, 48, (1, 1))

x = layers.GlobalAveragePooling2D()(x)

x = layers.Dense(
    64,
    activation="relu"
)(x)

x = layers.Dropout(0.5)(x)

output_layer = layers.Dense(
    1,
    activation="sigmoid"
)(x)

model = models.Model(
    inputs=input_layer,
    outputs=output_layer
)

model.compile(

    optimizer=tf.keras.optimizers.AdamW(
        learning_rate=1e-4,
        weight_decay=1e-5
    ),

    loss=tf.keras.losses.BinaryFocalCrossentropy(
        apply_class_balancing=True,
        alpha=0.75,
        gamma=2.0
    ),

    metrics=[

        tf.keras.metrics.BinaryAccuracy(
            name="accuracy"
        ),

        tf.keras.metrics.Precision(
            name="precision"
        ),

        tf.keras.metrics.Recall(
            name="recall"
        ),

        tf.keras.metrics.AUC(
            name="auc"
        ),

        tf.keras.metrics.AUC(
            curve="PR",
            name="pr_auc"
        )
    ]
)

model.summary()
# Out:
# I0000 00:00:1779479105.922848  840779 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 1171 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 4, 4, 3)   │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 4, 4, 16)  │        144 │ input_layer[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 4, 4, 16)  │         64 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu (ReLU)        │ (None, 4, 4, 16)  │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 4, 4, 16)  │        768 │ re_lu[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 4, 4, 16)  │         64 │ conv2d_1[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_1 (ReLU)      │ (None, 4, 4, 16)  │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 4, 4, 16)  │        768 │ re_lu_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 4, 4, 16)  │        768 │ re_lu_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 4, 4, 16)  │         64 │ conv2d_2[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 4, 4, 16)  │         64 │ conv2d_3[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_2 (ReLU)      │ (None, 4, 4, 16)  │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_3 (ReLU)      │ (None, 4, 4, 16)  │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 4, 4, 32)  │          0 │ re_lu_2[0][0],    │
# │ (Concatenate)       │                   │            │ re_lu_3[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 4, 4, 32)  │      1,024 │ concatenate[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 4, 4, 32)  │        128 │ conv2d_4[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_4 (ReLU)      │ (None, 4, 4, 32)  │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 32)        │          0 │ re_lu_4[0][0]     │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 4)         │        132 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 32)        │        160 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape (Reshape)   │ (None, 1, 1, 32)  │          0 │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 4, 4, 32)  │        512 │ re_lu_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply (Multiply) │ (None, 4, 4, 32)  │          0 │ re_lu_4[0][0],    │
# │                     │                   │            │ reshape[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 4, 4, 32)  │        128 │ conv2d_5[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 2, 2, 32)  │          0 │ multiply[0][0]    │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 2, 2, 32)  │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 2, 2, 32)  │          0 │ max_pooling2d[0]… │
# │                     │                   │            │ max_pooling2d_1[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_5 (ReLU)      │ (None, 2, 2, 32)  │          0 │ add[0][0]         │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 2, 2, 32)  │      3,072 │ re_lu_5[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 2, 2, 32)  │      3,072 │ re_lu_5[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 2, 2, 32)  │        128 │ conv2d_6[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 2, 2, 32)  │        128 │ conv2d_7[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_6 (ReLU)      │ (None, 2, 2, 32)  │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_7 (ReLU)      │ (None, 2, 2, 32)  │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 2, 2, 64)  │          0 │ re_lu_6[0][0],    │
# │ (Concatenate)       │                   │            │ re_lu_7[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 2, 2, 64)  │      4,096 │ concatenate_1[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 2, 2, 64)  │        256 │ conv2d_8[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_8 (ReLU)      │ (None, 2, 2, 64)  │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 64)        │          0 │ re_lu_8[0][0]     │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 4)         │        260 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 64)        │        320 │ dense_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_1 (Reshape) │ (None, 1, 1, 64)  │          0 │ dense_3[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 2, 2, 64)  │      2,048 │ re_lu_5[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_1          │ (None, 2, 2, 64)  │          0 │ re_lu_8[0][0],    │
# │ (Multiply)          │                   │            │ reshape_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 2, 2, 64)  │        256 │ conv2d_9[0][0]    │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 2, 2, 64)  │          0 │ multiply_1[0][0], │
# │                     │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_9 (ReLU)      │ (None, 2, 2, 64)  │          0 │ add_1[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 2, 2, 48)  │      3,072 │ re_lu_9[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 2, 2, 48)  │        192 │ conv2d_10[0][0]   │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_10 (ReLU)     │ (None, 2, 2, 48)  │          0 │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 48)        │          0 │ re_lu_10[0][0]    │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_4 (Dense)     │ (None, 64)        │      3,136 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 64)        │          0 │ dense_4[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_5 (Dense)     │ (None, 1)         │         65 │ dropout[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 24,889 (97.22 KB)
#  Trainable params: 24,153 (94.35 KB)
#  Non-trainable params: 736 (2.88 KB)

# %%
print("TensorFlow version:", tf.__version__)
print("GPU available:", tf.config.list_physical_devices('GPU'))

tf.debugging.set_log_device_placement(True)
# Out:
# TensorFlow version: 2.19.1
# GPU available: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
class TrainingLogger(Callback):

    def on_train_begin(self, logs=None):
        print("\nTraining started")
        print("-"*70)
        print("{:<8} {:<12} {:<12} {:<12} {:<12}".format(
            "Epoch","Loss","Accuracy","Val_Loss","Val_Acc"))
        print("-"*70)

    def on_epoch_end(self, epoch, logs=None):

        print("{:<8} {:<12.4f} {:<12.4f} {:<12.4f} {:<12.4f}".format(
            epoch+1,
            logs["loss"],
            logs["accuracy"],
            logs["val_loss"],
            logs["val_accuracy"]
        ))

# %%
checkpoint = ModelCheckpoint(
    "best_model_tow_idsIMGSIZE64.keras",
    monitor="val_accuracy",
    save_best_only=True,
    verbose=0
)

# %%
print("\nDataset summary")
print("-"*40)
print("Train samples :", X_train.shape[0])
print("Test samples  :", X_test.shape[0])
print("Validation samples  :", X_val.shape[0])
print("Image shape   :", X_train.shape[1:])
print("Batch size    :", 32)
print("Epochs        :", 50)
print("-"*40)
# Out:
# Dataset summary
# ----------------------------------------
# Train samples : 3291
# Test samples  : 3092
# Validation samples  : 1410
# Image shape   : (4, 4, 3)
# Batch size    : 32
# Epochs        : 50
# ----------------------------------------

# %%
history = model.fit(
    X_train, y_train,
    epochs=50,
    batch_size=32,
    validation_data=(X_val, y_val),
    verbose=1,
    callbacks=[checkpoint]
    
)
# Out:
# Epoch 1/50
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1779479110.779299  840910 service.cc:152] XLA service 0x7f9df002ab40 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1779479110.779320  840910 service.cc:160]   StreamExecutor device (0): NVIDIA GeForce RTX 3060 Laptop GPU, Compute Capability 8.6
# 2026-05-23 02:45:10.911411: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1779479111.675349  840910 cuda_dnn.cc:529] Loaded cuDNN version 91701
#  47/103 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5403 - auc: 0.5232 - loss: 0.0882 - pr_auc: 0.5596 - precision: 0.5522 - recall: 0.7496
# I0000 00:00:1779479118.511649  840910 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 25s 127ms/step - accuracy: 0.5713 - auc: 0.6250 - loss: 0.0753 - pr_auc: 0.6621 - precision: 0.5672 - recall: 0.8506 - val_accuracy: 0.4730 - val_auc: 0.4168 - val_loss: 0.1074 - val_pr_auc: 0.7039 - val_precision: 0.7176 - val_recall: 0.4572
# Epoch 2/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.6813 - auc: 0.8191 - loss: 0.0559 - pr_auc: 0.8422 - precision: 0.6436 - recall: 0.9106 - val_accuracy: 0.6525 - val_auc: 0.8258 - val_loss: 0.1010 - val_pr_auc: 0.9177 - val_precision: 0.9076 - val_recall: 0.5827
# Epoch 3/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.7505 - auc: 0.8794 - loss: 0.0479 - pr_auc: 0.8906 - precision: 0.7018 - recall: 0.9310 - val_accuracy: 0.8638 - val_auc: 0.9319 - val_loss: 0.0575 - val_pr_auc: 0.9733 - val_precision: 0.9718 - val_recall: 0.8375
# Epoch 4/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.7724 - auc: 0.9057 - loss: 0.0430 - pr_auc: 0.9187 - precision: 0.7240 - recall: 0.9310 - val_accuracy: 0.8816 - val_auc: 0.9384 - val_loss: 0.0402 - val_pr_auc: 0.9770 - val_precision: 0.9434 - val_recall: 0.8911
# Epoch 5/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8010 - auc: 0.9158 - loss: 0.0407 - pr_auc: 0.9288 - precision: 0.7543 - recall: 0.9332 - val_accuracy: 0.8865 - val_auc: 0.9463 - val_loss: 0.0350 - val_pr_auc: 0.9813 - val_precision: 0.9411 - val_recall: 0.9008
# Epoch 6/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8225 - auc: 0.9263 - loss: 0.0386 - pr_auc: 0.9375 - precision: 0.7797 - recall: 0.9332 - val_accuracy: 0.8766 - val_auc: 0.9426 - val_loss: 0.0314 - val_pr_auc: 0.9802 - val_precision: 0.9044 - val_recall: 0.9290
# Epoch 7/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8308 - auc: 0.9368 - loss: 0.0360 - pr_auc: 0.9453 - precision: 0.7851 - recall: 0.9428 - val_accuracy: 0.8695 - val_auc: 0.9429 - val_loss: 0.0301 - val_pr_auc: 0.9804 - val_precision: 0.8857 - val_recall: 0.9426
# Epoch 8/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8405 - auc: 0.9428 - loss: 0.0342 - pr_auc: 0.9532 - precision: 0.7971 - recall: 0.9428 - val_accuracy: 0.8809 - val_auc: 0.9472 - val_loss: 0.0309 - val_pr_auc: 0.9819 - val_precision: 0.9135 - val_recall: 0.9241
# Epoch 9/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8414 - auc: 0.9388 - loss: 0.0355 - pr_auc: 0.9519 - precision: 0.8023 - recall: 0.9349 - val_accuracy: 0.8794 - val_auc: 0.9437 - val_loss: 0.0314 - val_pr_auc: 0.9807 - val_precision: 0.9070 - val_recall: 0.9300
# Epoch 10/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8444 - auc: 0.9430 - loss: 0.0339 - pr_auc: 0.9538 - precision: 0.8045 - recall: 0.9383 - val_accuracy: 0.8809 - val_auc: 0.9486 - val_loss: 0.0294 - val_pr_auc: 0.9824 - val_precision: 0.9034 - val_recall: 0.9368
# Epoch 11/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8575 - auc: 0.9507 - loss: 0.0323 - pr_auc: 0.9605 - precision: 0.8172 - recall: 0.9462 - val_accuracy: 0.8801 - val_auc: 0.9498 - val_loss: 0.0292 - val_pr_auc: 0.9828 - val_precision: 0.9056 - val_recall: 0.9329
# Epoch 12/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8541 - auc: 0.9496 - loss: 0.0322 - pr_auc: 0.9597 - precision: 0.8156 - recall: 0.9411 - val_accuracy: 0.8858 - val_auc: 0.9484 - val_loss: 0.0303 - val_pr_auc: 0.9824 - val_precision: 0.9117 - val_recall: 0.9339
# Epoch 13/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8633 - auc: 0.9531 - loss: 0.0312 - pr_auc: 0.9618 - precision: 0.8274 - recall: 0.9417 - val_accuracy: 0.8745 - val_auc: 0.9450 - val_loss: 0.0305 - val_pr_auc: 0.9812 - val_precision: 0.8943 - val_recall: 0.9387
# Epoch 14/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8566 - auc: 0.9524 - loss: 0.0313 - pr_auc: 0.9609 - precision: 0.8169 - recall: 0.9445 - val_accuracy: 0.8979 - val_auc: 0.9520 - val_loss: 0.0307 - val_pr_auc: 0.9837 - val_precision: 0.9308 - val_recall: 0.9290
# Epoch 15/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8657 - auc: 0.9544 - loss: 0.0306 - pr_auc: 0.9636 - precision: 0.8308 - recall: 0.9417 - val_accuracy: 0.8943 - val_auc: 0.9508 - val_loss: 0.0320 - val_pr_auc: 0.9829 - val_precision: 0.9305 - val_recall: 0.9241
# Epoch 16/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8648 - auc: 0.9551 - loss: 0.0307 - pr_auc: 0.9637 - precision: 0.8295 - recall: 0.9417 - val_accuracy: 0.8879 - val_auc: 0.9505 - val_loss: 0.0304 - val_pr_auc: 0.9834 - val_precision: 0.9175 - val_recall: 0.9300
# Epoch 17/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8733 - auc: 0.9568 - loss: 0.0301 - pr_auc: 0.9652 - precision: 0.8409 - recall: 0.9423 - val_accuracy: 0.8929 - val_auc: 0.9522 - val_loss: 0.0298 - val_pr_auc: 0.9836 - val_precision: 0.9204 - val_recall: 0.9339
# Epoch 18/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8727 - auc: 0.9575 - loss: 0.0297 - pr_auc: 0.9658 - precision: 0.8373 - recall: 0.9468 - val_accuracy: 0.8965 - val_auc: 0.9527 - val_loss: 0.0309 - val_pr_auc: 0.9838 - val_precision: 0.9290 - val_recall: 0.9290
# Epoch 19/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8739 - auc: 0.9585 - loss: 0.0294 - pr_auc: 0.9672 - precision: 0.8367 - recall: 0.9508 - val_accuracy: 0.8879 - val_auc: 0.9481 - val_loss: 0.0317 - val_pr_auc: 0.9823 - val_precision: 0.9151 - val_recall: 0.9329
# Epoch 20/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8736 - auc: 0.9587 - loss: 0.0293 - pr_auc: 0.9680 - precision: 0.8372 - recall: 0.9491 - val_accuracy: 0.8950 - val_auc: 0.9473 - val_loss: 0.0333 - val_pr_auc: 0.9822 - val_precision: 0.9322 - val_recall: 0.9232
# Epoch 21/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8897 - auc: 0.9640 - loss: 0.0279 - pr_auc: 0.9705 - precision: 0.8556 - recall: 0.9559 - val_accuracy: 0.8965 - val_auc: 0.9529 - val_loss: 0.0320 - val_pr_auc: 0.9841 - val_precision: 0.9366 - val_recall: 0.9202
# Epoch 22/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8748 - auc: 0.9604 - loss: 0.0289 - pr_auc: 0.9664 - precision: 0.8389 - recall: 0.9491 - val_accuracy: 0.8979 - val_auc: 0.9520 - val_loss: 0.0325 - val_pr_auc: 0.9835 - val_precision: 0.9316 - val_recall: 0.9280
# Epoch 23/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.8797 - auc: 0.9628 - loss: 0.0280 - pr_auc: 0.9705 - precision: 0.8457 - recall: 0.9491 - val_accuracy: 0.9000 - val_auc: 0.9549 - val_loss: 0.0310 - val_pr_auc: 0.9849 - val_precision: 0.9369 - val_recall: 0.9251
# Epoch 24/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8921 - auc: 0.9662 - loss: 0.0268 - pr_auc: 0.9728 - precision: 0.8587 - recall: 0.9564 - val_accuracy: 0.8901 - val_auc: 0.9497 - val_loss: 0.0313 - val_pr_auc: 0.9829 - val_precision: 0.9153 - val_recall: 0.9358
# Epoch 25/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8864 - auc: 0.9653 - loss: 0.0271 - pr_auc: 0.9724 - precision: 0.8574 - recall: 0.9457 - val_accuracy: 0.8688 - val_auc: 0.9453 - val_loss: 0.0321 - val_pr_auc: 0.9815 - val_precision: 0.8878 - val_recall: 0.9387
# Epoch 26/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8927 - auc: 0.9649 - loss: 0.0272 - pr_auc: 0.9710 - precision: 0.8633 - recall: 0.9508 - val_accuracy: 0.9000 - val_auc: 0.9533 - val_loss: 0.0326 - val_pr_auc: 0.9840 - val_precision: 0.9395 - val_recall: 0.9222
# Epoch 27/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8903 - auc: 0.9657 - loss: 0.0269 - pr_auc: 0.9722 - precision: 0.8583 - recall: 0.9530 - val_accuracy: 0.8915 - val_auc: 0.9519 - val_loss: 0.0302 - val_pr_auc: 0.9836 - val_precision: 0.9147 - val_recall: 0.9387
# Epoch 28/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8912 - auc: 0.9646 - loss: 0.0274 - pr_auc: 0.9714 - precision: 0.8593 - recall: 0.9536 - val_accuracy: 0.9085 - val_auc: 0.9598 - val_loss: 0.0305 - val_pr_auc: 0.9864 - val_precision: 0.9455 - val_recall: 0.9280
# Epoch 29/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8946 - auc: 0.9692 - loss: 0.0256 - pr_auc: 0.9759 - precision: 0.8626 - recall: 0.9559 - val_accuracy: 0.8993 - val_auc: 0.9528 - val_loss: 0.0330 - val_pr_auc: 0.9839 - val_precision: 0.9335 - val_recall: 0.9280
# Epoch 30/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8949 - auc: 0.9691 - loss: 0.0255 - pr_auc: 0.9763 - precision: 0.8657 - recall: 0.9519 - val_accuracy: 0.8532 - val_auc: 0.9466 - val_loss: 0.0311 - val_pr_auc: 0.9820 - val_precision: 0.8591 - val_recall: 0.9553
# Epoch 31/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8909 - auc: 0.9676 - loss: 0.0261 - pr_auc: 0.9749 - precision: 0.8610 - recall: 0.9502 - val_accuracy: 0.8986 - val_auc: 0.9517 - val_loss: 0.0346 - val_pr_auc: 0.9837 - val_precision: 0.9394 - val_recall: 0.9202
# Epoch 32/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9009 - auc: 0.9699 - loss: 0.0255 - pr_auc: 0.9761 - precision: 0.8727 - recall: 0.9547 - val_accuracy: 0.8887 - val_auc: 0.9507 - val_loss: 0.0324 - val_pr_auc: 0.9834 - val_precision: 0.9192 - val_recall: 0.9290
# Epoch 33/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9012 - auc: 0.9693 - loss: 0.0256 - pr_auc: 0.9754 - precision: 0.8728 - recall: 0.9553 - val_accuracy: 0.9085 - val_auc: 0.9571 - val_loss: 0.0311 - val_pr_auc: 0.9854 - val_precision: 0.9429 - val_recall: 0.9309
# Epoch 34/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8991 - auc: 0.9679 - loss: 0.0261 - pr_auc: 0.9734 - precision: 0.8723 - recall: 0.9513 - val_accuracy: 0.9035 - val_auc: 0.9553 - val_loss: 0.0296 - val_pr_auc: 0.9847 - val_precision: 0.9272 - val_recall: 0.9416
# Epoch 35/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9049 - auc: 0.9703 - loss: 0.0252 - pr_auc: 0.9754 - precision: 0.8783 - recall: 0.9553 - val_accuracy: 0.9043 - val_auc: 0.9541 - val_loss: 0.0334 - val_pr_auc: 0.9843 - val_precision: 0.9425 - val_recall: 0.9251
# Epoch 36/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8964 - auc: 0.9703 - loss: 0.0250 - pr_auc: 0.9769 - precision: 0.8649 - recall: 0.9564 - val_accuracy: 0.9106 - val_auc: 0.9574 - val_loss: 0.0324 - val_pr_auc: 0.9855 - val_precision: 0.9501 - val_recall: 0.9261
# Epoch 37/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9055 - auc: 0.9742 - loss: 0.0234 - pr_auc: 0.9795 - precision: 0.8772 - recall: 0.9581 - val_accuracy: 0.9085 - val_auc: 0.9571 - val_loss: 0.0336 - val_pr_auc: 0.9854 - val_precision: 0.9473 - val_recall: 0.9261
# Epoch 38/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.8997 - auc: 0.9692 - loss: 0.0255 - pr_auc: 0.9759 - precision: 0.8706 - recall: 0.9553 - val_accuracy: 0.9057 - val_auc: 0.9570 - val_loss: 0.0351 - val_pr_auc: 0.9853 - val_precision: 0.9516 - val_recall: 0.9173
# Epoch 39/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9025 - auc: 0.9737 - loss: 0.0237 - pr_auc: 0.9798 - precision: 0.8754 - recall: 0.9542 - val_accuracy: 0.9092 - val_auc: 0.9570 - val_loss: 0.0318 - val_pr_auc: 0.9856 - val_precision: 0.9447 - val_recall: 0.9300
# Epoch 40/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9034 - auc: 0.9699 - loss: 0.0251 - pr_auc: 0.9762 - precision: 0.8760 - recall: 0.9553 - val_accuracy: 0.9043 - val_auc: 0.9531 - val_loss: 0.0343 - val_pr_auc: 0.9842 - val_precision: 0.9443 - val_recall: 0.9232
# Epoch 41/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9113 - auc: 0.9738 - loss: 0.0237 - pr_auc: 0.9799 - precision: 0.8867 - recall: 0.9570 - val_accuracy: 0.8965 - val_auc: 0.9531 - val_loss: 0.0324 - val_pr_auc: 0.9840 - val_precision: 0.9282 - val_recall: 0.9300
# Epoch 42/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9058 - auc: 0.9731 - loss: 0.0239 - pr_auc: 0.9787 - precision: 0.8757 - recall: 0.9610 - val_accuracy: 0.9057 - val_auc: 0.9554 - val_loss: 0.0326 - val_pr_auc: 0.9851 - val_precision: 0.9366 - val_recall: 0.9339
# Epoch 43/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9110 - auc: 0.9731 - loss: 0.0236 - pr_auc: 0.9791 - precision: 0.8875 - recall: 0.9553 - val_accuracy: 0.9035 - val_auc: 0.9516 - val_loss: 0.0349 - val_pr_auc: 0.9837 - val_precision: 0.9373 - val_recall: 0.9300
# Epoch 44/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9134 - auc: 0.9744 - loss: 0.0233 - pr_auc: 0.9796 - precision: 0.8855 - recall: 0.9632 - val_accuracy: 0.8936 - val_auc: 0.9503 - val_loss: 0.0333 - val_pr_auc: 0.9832 - val_precision: 0.9229 - val_recall: 0.9319
# Epoch 45/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9046 - auc: 0.9718 - loss: 0.0245 - pr_auc: 0.9778 - precision: 0.8798 - recall: 0.9525 - val_accuracy: 0.9014 - val_auc: 0.9583 - val_loss: 0.0309 - val_pr_auc: 0.9860 - val_precision: 0.9303 - val_recall: 0.9348
# Epoch 46/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.8994 - auc: 0.9709 - loss: 0.0248 - pr_auc: 0.9774 - precision: 0.8709 - recall: 0.9542 - val_accuracy: 0.8936 - val_auc: 0.9519 - val_loss: 0.0348 - val_pr_auc: 0.9836 - val_precision: 0.9373 - val_recall: 0.9154
# Epoch 47/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9028 - auc: 0.9726 - loss: 0.0241 - pr_auc: 0.9788 - precision: 0.8747 - recall: 0.9559 - val_accuracy: 0.9043 - val_auc: 0.9554 - val_loss: 0.0316 - val_pr_auc: 0.9849 - val_precision: 0.9339 - val_recall: 0.9348
# Epoch 48/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9125 - auc: 0.9750 - loss: 0.0231 - pr_auc: 0.9805 - precision: 0.8890 - recall: 0.9564 - val_accuracy: 0.9043 - val_auc: 0.9581 - val_loss: 0.0312 - val_pr_auc: 0.9857 - val_precision: 0.9331 - val_recall: 0.9358
# Epoch 49/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 0.9170 - auc: 0.9757 - loss: 0.0228 - pr_auc: 0.9811 - precision: 0.8919 - recall: 0.9621 - val_accuracy: 0.8837 - val_auc: 0.9477 - val_loss: 0.0344 - val_pr_auc: 0.9821 - val_precision: 0.9114 - val_recall: 0.9309
# Epoch 50/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9107 - auc: 0.9739 - loss: 0.0236 - pr_auc: 0.9799 - precision: 0.8846 - recall: 0.9587 - val_accuracy: 0.9121 - val_auc: 0.9577 - val_loss: 0.0346 - val_pr_auc: 0.9857 - val_precision: 0.9520 - val_recall: 0.9261

# %%
# =========================
# CELL 1
# =========================

import numpy as np
from sklearn.metrics import roc_curve

# prediksi probabilitas
y_prob = model.predict(X_test).ravel()

# label asli
y_true = y_test

# =========================
# EVALUASI DEFAULT THRESHOLD 0.5
# =========================

default_threshold = 0.5
y_pred_default = (y_prob >= default_threshold).astype(int)

# =========================
# CARI THRESHOLD TERBAIK
# =========================
# strategi:
# cari threshold dengan F1 tertinggi

thresholds = np.arange(0.1, 0.91, 0.01)

best_threshold = 0.5
best_f1 = 0

for th in thresholds:

    y_pred_temp = (y_prob >= th).astype(int)

    TP = np.sum((y_true == 1) & (y_pred_temp == 1))
    TN = np.sum((y_true == 0) & (y_pred_temp == 0))
    FP = np.sum((y_true == 0) & (y_pred_temp == 1))
    FN = np.sum((y_true == 1) & (y_pred_temp == 0))

    precision = TP / (TP + FP + 1e-12)
    recall = TP / (TP + FN + 1e-12)

    f1 = 2 * precision * recall / (precision + recall + 1e-12)

    if f1 > best_f1:
        best_f1 = f1
        best_threshold = th

print("Best Threshold:", best_threshold)
print("Best F1 Score :", best_f1)

# prediksi final threshold terbaik
y_pred_best = (y_prob >= best_threshold).astype(int)
# Out:
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step
# Best Threshold: 0.5499999999999998
# Best F1 Score : 0.8624740843118703

# %%
# =========================
# CELL 2
# =========================

from sklearn.metrics import confusion_matrix

# ===== DEFAULT 0.5 =====
cm_default = confusion_matrix(y_true, y_pred_default)

TN_d, FP_d, FN_d, TP_d = cm_default.ravel()

print("=== Confusion Matrix (Threshold = 0.5) ===")
print(cm_default)

# ===== BEST THRESHOLD =====
cm_best = confusion_matrix(y_true, y_pred_best)

TN_b, FP_b, FN_b, TP_b = cm_best.ravel()

print("\n=== Confusion Matrix (Best Threshold) ===")
print(cm_best)
# Out:
# === Confusion Matrix (Threshold = 0.5) ===
# [[1400  200]
#  [ 218 1274]]
#
# === Confusion Matrix (Best Threshold) ===
# [[1446  154]
#  [ 244 1248]]

# %%
# =========================
# CELL 3
# =========================

def calculate_metrics(TN, FP, FN, TP):

    accuracy = (TP + TN) / (TP + TN + FP + FN)

    precision = TP / (TP + FP + 1e-12)

    recall = TP / (TP + FN + 1e-12)

    f1 = 2 * precision * recall / (precision + recall + 1e-12)

    FPR = FP / (FP + TN + 1e-12)

    FNR = FN / (FN + TP + 1e-12)

    return accuracy, precision, recall, f1, FPR, FNR


# ===== DEFAULT =====
metrics_default = calculate_metrics(TN_d, FP_d, FN_d, TP_d)

# ===== BEST =====
metrics_best = calculate_metrics(TN_b, FP_b, FN_b, TP_b)

# %%
# =========================
# CELL 4
# =========================

metric_names = [
    "Accuracy",
    "Precision",
    "Recall",
    "F1-score",
    "FPR",
    "FNR"
]

print("========================================")
print("THRESHOLD = 0.5")
print("========================================")

for name, value in zip(metric_names, metrics_default):
    print(f"{name:10}: {value:.6f}")

print("\n")

print("========================================")
print(f"BEST THRESHOLD = {best_threshold:.2f}")
print("========================================")

for name, value in zip(metric_names, metrics_best):
    print(f"{name:10}: {value:.6f}")
# Out:
# ========================================
# THRESHOLD = 0.5
# ========================================
# Accuracy  : 0.864812
# Precision : 0.864315
# Recall    : 0.853887
# F1-score  : 0.859069
# FPR       : 0.125000
# FNR       : 0.146113
#
#
# ========================================
# BEST THRESHOLD = 0.55
# ========================================
# Accuracy  : 0.871281
# Precision : 0.890157
# Recall    : 0.836461
# F1-score  : 0.862474
# FPR       : 0.096250
# FNR       : 0.163539

# %%
# =========================
# CELL 5
# =========================

import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

fpr, tpr, _ = roc_curve(y_true, y_prob)

roc_auc = auc(fpr, tpr)

plt.figure(figsize=(6,6))

plt.plot(fpr, tpr, label="AUC = %0.4f" % roc_auc)

plt.plot([0,1],[0,1],'--')

plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")

plt.title("ROC Curve")

plt.legend()

plt.grid(True)

plt.show()
