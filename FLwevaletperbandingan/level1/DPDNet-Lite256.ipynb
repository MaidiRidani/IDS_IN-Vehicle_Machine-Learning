# %%
import numpy as np
import os
import gc
import time
import matplotlib.pyplot as plt
import seaborn as sns

import tensorflow as tf
from tensorflow.keras import layers, models

from sklearn.metrics import (
    confusion_matrix,
    classification_report,
    roc_curve,
    auc,
    precision_recall_curve,
    f1_score
)

import pandas as pd
import time
from tensorflow.keras.callbacks import Callback, EarlyStopping, ModelCheckpoint
from tensorflow.keras.callbacks import ReduceLROnPlateau, CSVLogger
# Out:
# 2026-05-23 00:43:02.424652: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-05-23 00:43:02.435787: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1779471782.449267  603977 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1779471782.453773  603977 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1779471782.464427  603977 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1779471782.464445  603977 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1779471782.464447  603977 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1779471782.464448  603977 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-05-23 00:43:02.467916: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
Load_Path = "/home/dani/Documents/tugas akhir/TugasAkhir/codeTugasAkhirku2026/tow_ids/Preprocessing/Preprocessingbaru/imgsize256lv1/norm/dwt/"

# %%
train_data = np.load(os.path.join(Load_Path, "tow_ids_train_dwt.npz"))
test_data  = np.load(os.path.join(Load_Path, "tow_ids_test_dwt.npz"))
validation_data = np.load(os.path.join(Load_Path, "tow_ids_eval_dwt.npz"))

X_train = train_data["X"]
y_train = train_data["y"]

X_val = validation_data["X"]
y_val = validation_data["y"]

X_test  = test_data["X"]
y_test  = test_data["y"]

print(X_train.shape, y_train.shape)
print(X_val.shape, y_val.shape)
print(X_test.shape, y_test.shape)
# Out:
# (3291, 128, 128, 3) (3291,)
# (1410, 128, 128, 3) (1410,)
# (3092, 128, 128, 3) (3092,)

# %%
print("Train label distribution:", np.unique(y_train, return_counts=True))
print("Test label distribution :", np.unique(y_test, return_counts=True))
print("Validation label distribution :", np.unique(y_val, return_counts=True))

print("Min value:", X_train.min())
print("Max value:", X_train.max())
# Out:
# Train label distribution: (array([0, 1]), array([1524, 1767]))
# Test label distribution : (array([0, 1]), array([1600, 1492]))
# Validation label distribution : (array([0, 1]), array([ 382, 1028]))
# Min value: -0.43898103
# Max value: 2.4145703

# %%
import tensorflow as tf
from tensorflow.keras import layers, models


def composite_conv(x, filters, kernel_size):
    x = layers.Conv2D(
        filters,
        kernel_size,
        padding="same",
        use_bias=False
    )(x)

    x = layers.BatchNormalization()(x)

    x = layers.ReLU()(x)

    return x


def SE_block(x, ratio=16):
    channels = x.shape[-1]

    se = layers.GlobalAveragePooling2D()(x)

    se = layers.Dense(
        max(channels // ratio, 4),
        activation="relu"
    )(se)

    se = layers.Dense(
        channels,
        activation="sigmoid"
    )(se)

    se = layers.Reshape((1, 1, channels))(se)

    out = layers.Multiply()([x, se])

    return out


def DPDB_block(x, filters, pool=True):
    shortcut = x

    h = composite_conv(x, filters // 2, (1, 3))

    v = composite_conv(x, filters // 2, (3, 1))

    concat = layers.Concatenate()([h, v])

    fusion = composite_conv(concat, filters, (1, 1))

    fusion = SE_block(fusion)

    if pool:
        fusion = layers.MaxPooling2D((2, 2))(fusion)

    shortcut = layers.Conv2D(
        filters,
        (1, 1),
        padding="same",
        use_bias=False
    )(shortcut)

    shortcut = layers.BatchNormalization()(shortcut)

    if pool:
        shortcut = layers.MaxPooling2D((2, 2))(shortcut)

    out = layers.Add()([fusion, shortcut])

    out = layers.ReLU()(out)

    return out


input_layer = layers.Input(shape=(128, 128, 3))

x = composite_conv(input_layer, 16, (1, 3))

x = composite_conv(x, 16, (3, 1))

x = DPDB_block(x, 32, pool=True)

x = DPDB_block(x, 64, pool=False)

x = composite_conv(x, 48, (1, 1))

x = layers.GlobalAveragePooling2D()(x)

x = layers.Dense(
    64,
    activation="relu"
)(x)

x = layers.Dropout(0.5)(x)

output_layer = layers.Dense(
    1,
    activation="sigmoid"
)(x)

model = models.Model(
    inputs=input_layer,
    outputs=output_layer
)

model.compile(

    optimizer=tf.keras.optimizers.AdamW(
        learning_rate=1e-4,
        weight_decay=1e-5
    ),

    loss=tf.keras.losses.BinaryFocalCrossentropy(
        apply_class_balancing=True,
        alpha=0.75,
        gamma=2.0
    ),

    metrics=[

        tf.keras.metrics.BinaryAccuracy(
            name="accuracy"
        ),

        tf.keras.metrics.Precision(
            name="precision"
        ),

        tf.keras.metrics.Recall(
            name="recall"
        ),

        tf.keras.metrics.AUC(
            name="auc"
        ),

        tf.keras.metrics.AUC(
            curve="PR",
            name="pr_auc"
        )
    ]
)

model.summary()
# Out:
# I0000 00:00:1779471784.735419  603977 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 4144 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 128, 128,  │        144 │ input_layer[0][0] │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 128, 128,  │         64 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu (ReLU)        │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 128, 128,  │        768 │ re_lu[0][0]       │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │         64 │ conv2d_1[0][0]    │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_1 (ReLU)      │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 128, 128,  │        768 │ re_lu_1[0][0]     │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 128, 128,  │        768 │ re_lu_1[0][0]     │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │         64 │ conv2d_2[0][0]    │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │         64 │ conv2d_3[0][0]    │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_2 (ReLU)      │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_3 (ReLU)      │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 128, 128,  │          0 │ re_lu_2[0][0],    │
# │ (Concatenate)       │ 32)               │            │ re_lu_3[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 128, 128,  │      1,024 │ concatenate[0][0] │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_4[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_4 (ReLU)      │ (None, 128, 128,  │          0 │ batch_normalizat… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 32)        │          0 │ re_lu_4[0][0]     │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 4)         │        132 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 32)        │        160 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape (Reshape)   │ (None, 1, 1, 32)  │          0 │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 128, 128,  │        512 │ re_lu_1[0][0]     │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply (Multiply) │ (None, 128, 128,  │          0 │ re_lu_4[0][0],    │
# │                     │ 32)               │            │ reshape[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 128, 128,  │        128 │ conv2d_5[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 64, 64,    │          0 │ multiply[0][0]    │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 64, 64,    │          0 │ max_pooling2d[0]… │
# │                     │ 32)               │            │ max_pooling2d_1[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_5 (ReLU)      │ (None, 64, 64,    │          0 │ add[0][0]         │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 64, 64,    │      3,072 │ re_lu_5[0][0]     │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 64, 64,    │      3,072 │ re_lu_5[0][0]     │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        128 │ conv2d_6[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        128 │ conv2d_7[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_6 (ReLU)      │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_7 (ReLU)      │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 64, 64,    │          0 │ re_lu_6[0][0],    │
# │ (Concatenate)       │ 64)               │            │ re_lu_7[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 64, 64,    │      4,096 │ concatenate_1[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_8[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_8 (ReLU)      │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 64)        │          0 │ re_lu_8[0][0]     │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 4)         │        260 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 64)        │        320 │ dense_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_1 (Reshape) │ (None, 1, 1, 64)  │          0 │ dense_3[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 64, 64,    │      2,048 │ re_lu_5[0][0]     │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_1          │ (None, 64, 64,    │          0 │ re_lu_8[0][0],    │
# │ (Multiply)          │ 64)               │            │ reshape_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ conv2d_9[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 64, 64,    │          0 │ multiply_1[0][0], │
# │                     │ 64)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_9 (ReLU)      │ (None, 64, 64,    │          0 │ add_1[0][0]       │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 64, 64,    │      3,072 │ re_lu_9[0][0]     │
# │                     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        192 │ conv2d_10[0][0]   │
# │ (BatchNormalizatio… │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_10 (ReLU)     │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 48)        │          0 │ re_lu_10[0][0]    │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_4 (Dense)     │ (None, 64)        │      3,136 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 64)        │          0 │ dense_4[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_5 (Dense)     │ (None, 1)         │         65 │ dropout[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 24,889 (97.22 KB)
#  Trainable params: 24,153 (94.35 KB)
#  Non-trainable params: 736 (2.88 KB)

# %%
print("TensorFlow version:", tf.__version__)
print("GPU available:", tf.config.list_physical_devices('GPU'))

tf.debugging.set_log_device_placement(True)
# Out:
# TensorFlow version: 2.19.1
# GPU available: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
class TrainingLogger(Callback):

    def on_train_begin(self, logs=None):
        print("\nTraining started")
        print("-"*70)
        print("{:<8} {:<12} {:<12} {:<12} {:<12}".format(
            "Epoch","Loss","Accuracy","Val_Loss","Val_Acc"))
        print("-"*70)

    def on_epoch_end(self, epoch, logs=None):

        print("{:<8} {:<12.4f} {:<12.4f} {:<12.4f} {:<12.4f}".format(
            epoch+1,
            logs["loss"],
            logs["accuracy"],
            logs["val_loss"],
            logs["val_accuracy"]
        ))

# %%
checkpoint = ModelCheckpoint(
    "best_model_tow_idsIMGSIZE64.keras",
    monitor="val_accuracy",
    save_best_only=True,
    verbose=0
)

# %%
print("\nDataset summary")
print("-"*40)
print("Train samples :", X_train.shape[0])
print("Test samples  :", X_test.shape[0])
print("Validation samples  :", X_val.shape[0])
print("Image shape   :", X_train.shape[1:])
print("Batch size    :", 32)
print("Epochs        :", 50)
print("-"*40)
# Out:
# Dataset summary
# ----------------------------------------
# Train samples : 3291
# Test samples  : 3092
# Validation samples  : 1410
# Image shape   : (128, 128, 3)
# Batch size    : 32
# Epochs        : 50
# ----------------------------------------

# %%
history = model.fit(
    X_train, y_train,
    epochs=50,
    batch_size=32,
    validation_data=(X_val, y_val),
    verbose=1,
    callbacks=[checkpoint]
    
)
# Out:
# Epoch 1/50
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1779471790.529747  666204 service.cc:152] XLA service 0x76b9ac002e50 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1779471790.529765  666204 service.cc:160]   StreamExecutor device (0): NVIDIA GeForce RTX 3060 Laptop GPU, Compute Capability 8.6
# 2026-05-23 00:43:10.672981: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1779471791.515214  666204 cuda_dnn.cc:529] Loaded cuDNN version 91701
#   5/103 ━━━━━━━━━━━━━━━━━━━━ 3s 37ms/step - accuracy: 0.4098 - auc: 0.4365 - loss: 0.1220 - pr_auc: 0.5361 - precision: 0.4856 - recall: 0.3130
# I0000 00:00:1779471801.974163  666204 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 36s 198ms/step - accuracy: 0.5393 - auc: 0.5616 - loss: 0.0799 - pr_auc: 0.6038 - precision: 0.5489 - recall: 0.7974 - val_accuracy: 0.7291 - val_auc: 0.6836 - val_loss: 0.0823 - val_pr_auc: 0.8949 - val_precision: 0.7291 - val_recall: 1.0000
# Epoch 2/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 5s 46ms/step - accuracy: 0.5722 - auc: 0.7064 - loss: 0.0649 - pr_auc: 0.7380 - precision: 0.5591 - recall: 0.9604 - val_accuracy: 0.7291 - val_auc: 0.7133 - val_loss: 0.0633 - val_pr_auc: 0.9101 - val_precision: 0.7291 - val_recall: 1.0000
# Epoch 3/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 5s 47ms/step - accuracy: 0.6305 - auc: 0.8250 - loss: 0.0566 - pr_auc: 0.8545 - precision: 0.5954 - recall: 0.9728 - val_accuracy: 0.7291 - val_auc: 0.7765 - val_loss: 0.0560 - val_pr_auc: 0.9295 - val_precision: 0.7291 - val_recall: 1.0000
# Epoch 4/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 5s 48ms/step - accuracy: 0.6770 - auc: 0.8907 - loss: 0.0500 - pr_auc: 0.9088 - precision: 0.6279 - recall: 0.9779 - val_accuracy: 0.9121 - val_auc: 0.9755 - val_loss: 0.0580 - val_pr_auc: 0.9907 - val_precision: 0.9036 - val_recall: 0.9844
# Epoch 5/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 5s 47ms/step - accuracy: 0.7405 - auc: 0.9272 - loss: 0.0440 - pr_auc: 0.9417 - precision: 0.6805 - recall: 0.9740 - val_accuracy: 0.8908 - val_auc: 0.9844 - val_loss: 0.0690 - val_pr_auc: 0.9925 - val_precision: 0.9877 - val_recall: 0.8609
# Epoch 6/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 5s 47ms/step - accuracy: 0.8110 - auc: 0.9504 - loss: 0.0380 - pr_auc: 0.9598 - precision: 0.7492 - recall: 0.9740 - val_accuracy: 0.8184 - val_auc: 0.9855 - val_loss: 0.0750 - val_pr_auc: 0.9925 - val_precision: 0.9911 - val_recall: 0.7578
# Epoch 7/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 5s 47ms/step - accuracy: 0.8371 - auc: 0.9602 - loss: 0.0338 - pr_auc: 0.9678 - precision: 0.7820 - recall: 0.9660 - val_accuracy: 0.6702 - val_auc: 0.9811 - val_loss: 0.0994 - val_pr_auc: 0.9870 - val_precision: 0.9879 - val_recall: 0.5545
# Epoch 8/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 5s 47ms/step - accuracy: 0.8693 - auc: 0.9686 - loss: 0.0301 - pr_auc: 0.9734 - precision: 0.8215 - recall: 0.9666 - val_accuracy: 0.7468 - val_auc: 0.9900 - val_loss: 0.0842 - val_pr_auc: 0.9949 - val_precision: 0.9956 - val_recall: 0.6556
# Epoch 9/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 5s 50ms/step - accuracy: 0.8979 - auc: 0.9780 - loss: 0.0257 - pr_auc: 0.9815 - precision: 0.8590 - recall: 0.9689 - val_accuracy: 0.9496 - val_auc: 0.9896 - val_loss: 0.0378 - val_pr_auc: 0.9944 - val_precision: 0.9878 - val_recall: 0.9426
# Epoch 10/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 5s 51ms/step - accuracy: 0.9098 - auc: 0.9803 - loss: 0.0234 - pr_auc: 0.9821 - precision: 0.8769 - recall: 0.9677 - val_accuracy: 0.9099 - val_auc: 0.9872 - val_loss: 0.0501 - val_pr_auc: 0.9918 - val_precision: 0.9891 - val_recall: 0.8862
# Epoch 11/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 5s 51ms/step - accuracy: 0.9237 - auc: 0.9849 - loss: 0.0207 - pr_auc: 0.9845 - precision: 0.8911 - recall: 0.9774 - val_accuracy: 0.9702 - val_auc: 0.9924 - val_loss: 0.0222 - val_pr_auc: 0.9963 - val_precision: 0.9891 - val_recall: 0.9698
# Epoch 12/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 6s 58ms/step - accuracy: 0.9407 - auc: 0.9891 - loss: 0.0180 - pr_auc: 0.9875 - precision: 0.9199 - recall: 0.9745 - val_accuracy: 0.9809 - val_auc: 0.9948 - val_loss: 0.0113 - val_pr_auc: 0.9978 - val_precision: 0.9789 - val_recall: 0.9951
# Epoch 13/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 6s 61ms/step - accuracy: 0.9359 - auc: 0.9874 - loss: 0.0179 - pr_auc: 0.9864 - precision: 0.9108 - recall: 0.9762 - val_accuracy: 0.9837 - val_auc: 0.9945 - val_loss: 0.0107 - val_pr_auc: 0.9976 - val_precision: 0.9874 - val_recall: 0.9903
# Epoch 14/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 6s 61ms/step - accuracy: 0.9444 - auc: 0.9894 - loss: 0.0164 - pr_auc: 0.9887 - precision: 0.9222 - recall: 0.9791 - val_accuracy: 0.9865 - val_auc: 0.9949 - val_loss: 0.0093 - val_pr_auc: 0.9978 - val_precision: 0.9865 - val_recall: 0.9951
# Epoch 15/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 6s 62ms/step - accuracy: 0.9493 - auc: 0.9907 - loss: 0.0150 - pr_auc: 0.9902 - precision: 0.9283 - recall: 0.9813 - val_accuracy: 0.9745 - val_auc: 0.9942 - val_loss: 0.0097 - val_pr_auc: 0.9977 - val_precision: 0.9688 - val_recall: 0.9971
# Epoch 16/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 6s 60ms/step - accuracy: 0.9517 - auc: 0.9920 - loss: 0.0140 - pr_auc: 0.9922 - precision: 0.9327 - recall: 0.9808 - val_accuracy: 0.9702 - val_auc: 0.9948 - val_loss: 0.0084 - val_pr_auc: 0.9977 - val_precision: 0.9607 - val_recall: 1.0000
# Epoch 17/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 6s 63ms/step - accuracy: 0.9529 - auc: 0.9918 - loss: 0.0137 - pr_auc: 0.9885 - precision: 0.9329 - recall: 0.9830 - val_accuracy: 0.9730 - val_auc: 0.9934 - val_loss: 0.0103 - val_pr_auc: 0.9974 - val_precision: 0.9723 - val_recall: 0.9912
# Epoch 18/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 7s 67ms/step - accuracy: 0.9575 - auc: 0.9922 - loss: 0.0133 - pr_auc: 0.9928 - precision: 0.9428 - recall: 0.9802 - val_accuracy: 0.9652 - val_auc: 0.9943 - val_loss: 0.0091 - val_pr_auc: 0.9977 - val_precision: 0.9553 - val_recall: 0.9990
# Epoch 19/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 8s 73ms/step - accuracy: 0.9553 - auc: 0.9914 - loss: 0.0136 - pr_auc: 0.9910 - precision: 0.9417 - recall: 0.9774 - val_accuracy: 0.9851 - val_auc: 0.9953 - val_loss: 0.0080 - val_pr_auc: 0.9981 - val_precision: 0.9837 - val_recall: 0.9961
# Epoch 20/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 8s 76ms/step - accuracy: 0.9538 - auc: 0.9928 - loss: 0.0127 - pr_auc: 0.9913 - precision: 0.9334 - recall: 0.9842 - val_accuracy: 0.9809 - val_auc: 0.9958 - val_loss: 0.0101 - val_pr_auc: 0.9983 - val_precision: 0.9892 - val_recall: 0.9844
# Epoch 21/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 9s 83ms/step - accuracy: 0.9638 - auc: 0.9946 - loss: 0.0110 - pr_auc: 0.9921 - precision: 0.9478 - recall: 0.9870 - val_accuracy: 0.9823 - val_auc: 0.9957 - val_loss: 0.0079 - val_pr_auc: 0.9983 - val_precision: 0.9845 - val_recall: 0.9912
# Epoch 22/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 8s 83ms/step - accuracy: 0.9669 - auc: 0.9938 - loss: 0.0113 - pr_auc: 0.9926 - precision: 0.9565 - recall: 0.9830 - val_accuracy: 0.9596 - val_auc: 0.9951 - val_loss: 0.0095 - val_pr_auc: 0.9980 - val_precision: 0.9475 - val_recall: 1.0000
# Epoch 23/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 9s 90ms/step - accuracy: 0.9644 - auc: 0.9949 - loss: 0.0106 - pr_auc: 0.9936 - precision: 0.9503 - recall: 0.9853 - val_accuracy: 0.9766 - val_auc: 0.9956 - val_loss: 0.0072 - val_pr_auc: 0.9982 - val_precision: 0.9698 - val_recall: 0.9990
# Epoch 24/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 8s 76ms/step - accuracy: 0.9672 - auc: 0.9948 - loss: 0.0105 - pr_auc: 0.9946 - precision: 0.9535 - recall: 0.9870 - val_accuracy: 0.9624 - val_auc: 0.9953 - val_loss: 0.0089 - val_pr_auc: 0.9981 - val_precision: 0.9518 - val_recall: 0.9990
# Epoch 25/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 7s 67ms/step - accuracy: 0.9666 - auc: 0.9940 - loss: 0.0108 - pr_auc: 0.9920 - precision: 0.9545 - recall: 0.9847 - val_accuracy: 0.8106 - val_auc: 0.9943 - val_loss: 0.0326 - val_pr_auc: 0.9975 - val_precision: 0.7938 - val_recall: 1.0000
# Epoch 26/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 7s 68ms/step - accuracy: 0.9666 - auc: 0.9952 - loss: 0.0099 - pr_auc: 0.9946 - precision: 0.9525 - recall: 0.9870 - val_accuracy: 0.9574 - val_auc: 0.9942 - val_loss: 0.0090 - val_pr_auc: 0.9969 - val_precision: 0.9449 - val_recall: 1.0000
# Epoch 27/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 7s 68ms/step - accuracy: 0.9720 - auc: 0.9955 - loss: 0.0094 - pr_auc: 0.9935 - precision: 0.9614 - recall: 0.9875 - val_accuracy: 0.9730 - val_auc: 0.9956 - val_loss: 0.0077 - val_pr_auc: 0.9982 - val_precision: 0.9661 - val_recall: 0.9981
# Epoch 28/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 7s 71ms/step - accuracy: 0.9745 - auc: 0.9967 - loss: 0.0083 - pr_auc: 0.9952 - precision: 0.9616 - recall: 0.9921 - val_accuracy: 0.9638 - val_auc: 0.9958 - val_loss: 0.0086 - val_pr_auc: 0.9983 - val_precision: 0.9527 - val_recall: 1.0000
# Epoch 29/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 7s 70ms/step - accuracy: 0.9802 - auc: 0.9969 - loss: 0.0075 - pr_auc: 0.9955 - precision: 0.9738 - recall: 0.9898 - val_accuracy: 0.9652 - val_auc: 0.9932 - val_loss: 0.0084 - val_pr_auc: 0.9952 - val_precision: 0.9545 - val_recall: 1.0000
# Epoch 30/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 8s 73ms/step - accuracy: 0.9754 - auc: 0.9968 - loss: 0.0077 - pr_auc: 0.9949 - precision: 0.9637 - recall: 0.9915 - val_accuracy: 0.9766 - val_auc: 0.9962 - val_loss: 0.0067 - val_pr_auc: 0.9985 - val_precision: 0.9707 - val_recall: 0.9981
# Epoch 31/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 7s 67ms/step - accuracy: 0.9763 - auc: 0.9980 - loss: 0.0070 - pr_auc: 0.9982 - precision: 0.9658 - recall: 0.9909 - val_accuracy: 0.9610 - val_auc: 0.9961 - val_loss: 0.0092 - val_pr_auc: 0.9984 - val_precision: 0.9492 - val_recall: 1.0000
# Epoch 32/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 7s 66ms/step - accuracy: 0.9796 - auc: 0.9968 - loss: 0.0074 - pr_auc: 0.9948 - precision: 0.9691 - recall: 0.9938 - val_accuracy: 0.9865 - val_auc: 0.9942 - val_loss: 0.0047 - val_pr_auc: 0.9963 - val_precision: 0.9846 - val_recall: 0.9971
# Epoch 33/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 8s 73ms/step - accuracy: 0.9821 - auc: 0.9974 - loss: 0.0064 - pr_auc: 0.9971 - precision: 0.9744 - recall: 0.9926 - val_accuracy: 0.9837 - val_auc: 0.9964 - val_loss: 0.0052 - val_pr_auc: 0.9984 - val_precision: 0.9809 - val_recall: 0.9971
# Epoch 34/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 8s 81ms/step - accuracy: 0.9815 - auc: 0.9976 - loss: 0.0066 - pr_auc: 0.9976 - precision: 0.9749 - recall: 0.9909 - val_accuracy: 0.9383 - val_auc: 0.9967 - val_loss: 0.0120 - val_pr_auc: 0.9986 - val_precision: 0.9220 - val_recall: 1.0000
# Epoch 35/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 8s 79ms/step - accuracy: 0.9836 - auc: 0.9974 - loss: 0.0062 - pr_auc: 0.9968 - precision: 0.9766 - recall: 0.9932 - val_accuracy: 0.9865 - val_auc: 0.9973 - val_loss: 0.0052 - val_pr_auc: 0.9989 - val_precision: 0.9856 - val_recall: 0.9961
# Epoch 36/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 7s 69ms/step - accuracy: 0.9827 - auc: 0.9980 - loss: 0.0055 - pr_auc: 0.9965 - precision: 0.9729 - recall: 0.9955 - val_accuracy: 0.9766 - val_auc: 0.9975 - val_loss: 0.0102 - val_pr_auc: 0.9990 - val_precision: 0.9931 - val_recall: 0.9747
# Epoch 37/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 7s 72ms/step - accuracy: 0.9860 - auc: 0.9979 - loss: 0.0054 - pr_auc: 0.9961 - precision: 0.9805 - recall: 0.9938 - val_accuracy: 0.9872 - val_auc: 0.9961 - val_loss: 0.0049 - val_pr_auc: 0.9980 - val_precision: 0.9837 - val_recall: 0.9990
# Epoch 38/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 8s 80ms/step - accuracy: 0.9848 - auc: 0.9978 - loss: 0.0059 - pr_auc: 0.9981 - precision: 0.9804 - recall: 0.9915 - val_accuracy: 0.9383 - val_auc: 0.9953 - val_loss: 0.0125 - val_pr_auc: 0.9974 - val_precision: 0.9220 - val_recall: 1.0000
# Epoch 39/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 9s 83ms/step - accuracy: 0.9875 - auc: 0.9986 - loss: 0.0045 - pr_auc: 0.9976 - precision: 0.9827 - recall: 0.9943 - val_accuracy: 0.9872 - val_auc: 0.9978 - val_loss: 0.0062 - val_pr_auc: 0.9991 - val_precision: 0.9912 - val_recall: 0.9912
# Epoch 40/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 8s 77ms/step - accuracy: 0.9863 - auc: 0.9976 - loss: 0.0056 - pr_auc: 0.9971 - precision: 0.9799 - recall: 0.9949 - val_accuracy: 0.9872 - val_auc: 0.9977 - val_loss: 0.0044 - val_pr_auc: 0.9990 - val_precision: 0.9837 - val_recall: 0.9990
# Epoch 41/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 8s 74ms/step - accuracy: 0.9888 - auc: 0.9979 - loss: 0.0049 - pr_auc: 0.9965 - precision: 0.9843 - recall: 0.9949 - val_accuracy: 0.9872 - val_auc: 0.9975 - val_loss: 0.0068 - val_pr_auc: 0.9989 - val_precision: 0.9932 - val_recall: 0.9893
# Epoch 42/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 9s 87ms/step - accuracy: 0.9903 - auc: 0.9985 - loss: 0.0041 - pr_auc: 0.9978 - precision: 0.9849 - recall: 0.9972 - val_accuracy: 0.9879 - val_auc: 0.9972 - val_loss: 0.0042 - val_pr_auc: 0.9987 - val_precision: 0.9847 - val_recall: 0.9990
# Epoch 43/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 9s 91ms/step - accuracy: 0.9875 - auc: 0.9983 - loss: 0.0043 - pr_auc: 0.9975 - precision: 0.9821 - recall: 0.9949 - val_accuracy: 0.9809 - val_auc: 0.9969 - val_loss: 0.0053 - val_pr_auc: 0.9985 - val_precision: 0.9744 - val_recall: 1.0000
# Epoch 44/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 9s 87ms/step - accuracy: 0.9885 - auc: 0.9991 - loss: 0.0035 - pr_auc: 0.9991 - precision: 0.9816 - recall: 0.9972 - val_accuracy: 0.9887 - val_auc: 0.9969 - val_loss: 0.0064 - val_pr_auc: 0.9985 - val_precision: 0.9932 - val_recall: 0.9912
# Epoch 45/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 9s 89ms/step - accuracy: 0.9900 - auc: 0.9985 - loss: 0.0041 - pr_auc: 0.9982 - precision: 0.9854 - recall: 0.9960 - val_accuracy: 0.9794 - val_auc: 0.9922 - val_loss: 0.0065 - val_pr_auc: 0.9940 - val_precision: 0.9735 - val_recall: 0.9990
# Epoch 46/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 9s 87ms/step - accuracy: 0.9903 - auc: 0.9982 - loss: 0.0046 - pr_auc: 0.9974 - precision: 0.9855 - recall: 0.9966 - val_accuracy: 0.9596 - val_auc: 0.9919 - val_loss: 0.0101 - val_pr_auc: 0.9940 - val_precision: 0.9475 - val_recall: 1.0000
# Epoch 47/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 9s 85ms/step - accuracy: 0.9924 - auc: 0.9991 - loss: 0.0031 - pr_auc: 0.9982 - precision: 0.9888 - recall: 0.9972 - val_accuracy: 0.9844 - val_auc: 0.9980 - val_loss: 0.0046 - val_pr_auc: 0.9992 - val_precision: 0.9790 - val_recall: 1.0000
# Epoch 48/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 9s 85ms/step - accuracy: 0.9933 - auc: 0.9985 - loss: 0.0037 - pr_auc: 0.9963 - precision: 0.9899 - recall: 0.9977 - val_accuracy: 0.9894 - val_auc: 0.9980 - val_loss: 0.0054 - val_pr_auc: 0.9992 - val_precision: 0.9913 - val_recall: 0.9942
# Epoch 49/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 8s 80ms/step - accuracy: 0.9891 - auc: 0.9984 - loss: 0.0042 - pr_auc: 0.9975 - precision: 0.9838 - recall: 0.9960 - val_accuracy: 0.9908 - val_auc: 0.9956 - val_loss: 0.0078 - val_pr_auc: 0.9972 - val_precision: 0.9942 - val_recall: 0.9932
# Epoch 50/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 9s 85ms/step - accuracy: 0.9912 - auc: 0.9991 - loss: 0.0036 - pr_auc: 0.9992 - precision: 0.9866 - recall: 0.9972 - val_accuracy: 0.9879 - val_auc: 0.9985 - val_loss: 0.0050 - val_pr_auc: 0.9994 - val_precision: 0.9903 - val_recall: 0.9932

# %%
# =========================
# CELL 1
# =========================

import numpy as np
from sklearn.metrics import roc_curve

# prediksi probabilitas
y_prob = model.predict(X_test).ravel()

# label asli
y_true = y_test

# =========================
# EVALUASI DEFAULT THRESHOLD 0.5
# =========================

default_threshold = 0.5
y_pred_default = (y_prob >= default_threshold).astype(int)

# =========================
# CARI THRESHOLD TERBAIK
# =========================
# strategi:
# cari threshold dengan F1 tertinggi

thresholds = np.arange(0.1, 0.91, 0.01)

best_threshold = 0.5
best_f1 = 0

for th in thresholds:

    y_pred_temp = (y_prob >= th).astype(int)

    TP = np.sum((y_true == 1) & (y_pred_temp == 1))
    TN = np.sum((y_true == 0) & (y_pred_temp == 0))
    FP = np.sum((y_true == 0) & (y_pred_temp == 1))
    FN = np.sum((y_true == 1) & (y_pred_temp == 0))

    precision = TP / (TP + FP + 1e-12)
    recall = TP / (TP + FN + 1e-12)

    f1 = 2 * precision * recall / (precision + recall + 1e-12)

    if f1 > best_f1:
        best_f1 = f1
        best_threshold = th

print("Best Threshold:", best_threshold)
print("Best F1 Score :", best_f1)

# prediksi final threshold terbaik
y_pred_best = (y_prob >= best_threshold).astype(int)
# Out:
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 6s 48ms/step
# Best Threshold: 0.4999999999999998
# Best F1 Score : 0.9809682804669451

# %%
# =========================
# CELL 2
# =========================

from sklearn.metrics import confusion_matrix

# ===== DEFAULT 0.5 =====
cm_default = confusion_matrix(y_true, y_pred_default)

TN_d, FP_d, FN_d, TP_d = cm_default.ravel()

print("=== Confusion Matrix (Threshold = 0.5) ===")
print(cm_default)

# ===== BEST THRESHOLD =====
cm_best = confusion_matrix(y_true, y_pred_best)

TN_b, FP_b, FN_b, TP_b = cm_best.ravel()

print("\n=== Confusion Matrix (Best Threshold) ===")
print(cm_best)
# Out:
# === Confusion Matrix (Threshold = 0.5) ===
# [[1566   34]
#  [  23 1469]]
#
# === Confusion Matrix (Best Threshold) ===
# [[1566   34]
#  [  23 1469]]

# %%
# =========================
# CELL 3
# =========================

def calculate_metrics(TN, FP, FN, TP):

    accuracy = (TP + TN) / (TP + TN + FP + FN)

    precision = TP / (TP + FP + 1e-12)

    recall = TP / (TP + FN + 1e-12)

    f1 = 2 * precision * recall / (precision + recall + 1e-12)

    FPR = FP / (FP + TN + 1e-12)

    FNR = FN / (FN + TP + 1e-12)

    return accuracy, precision, recall, f1, FPR, FNR


# ===== DEFAULT =====
metrics_default = calculate_metrics(TN_d, FP_d, FN_d, TP_d)

# ===== BEST =====
metrics_best = calculate_metrics(TN_b, FP_b, FN_b, TP_b)

# %%
# =========================
# CELL 4
# =========================

metric_names = [
    "Accuracy",
    "Precision",
    "Recall",
    "F1-score",
    "FPR",
    "FNR"
]

print("========================================")
print("THRESHOLD = 0.5")
print("========================================")

for name, value in zip(metric_names, metrics_default):
    print(f"{name:10}: {value:.6f}")

print("\n")

print("========================================")
print(f"BEST THRESHOLD = {best_threshold:.2f}")
print("========================================")

for name, value in zip(metric_names, metrics_best):
    print(f"{name:10}: {value:.6f}")
# Out:
# ========================================
# THRESHOLD = 0.5
# ========================================
# Accuracy  : 0.981565
# Precision : 0.977379
# Recall    : 0.984584
# F1-score  : 0.980968
# FPR       : 0.021250
# FNR       : 0.015416
#
#
# ========================================
# BEST THRESHOLD = 0.50
# ========================================
# Accuracy  : 0.981565
# Precision : 0.977379
# Recall    : 0.984584
# F1-score  : 0.980968
# FPR       : 0.021250
# FNR       : 0.015416

# %%
# =========================
# CELL 5
# =========================

import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

fpr, tpr, _ = roc_curve(y_true, y_prob)

roc_auc = auc(fpr, tpr)

plt.figure(figsize=(6,6))

plt.plot(fpr, tpr, label="AUC = %0.4f" % roc_auc)

plt.plot([0,1],[0,1],'--')

plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")

plt.title("ROC Curve")

plt.legend()

plt.grid(True)

plt.show()
