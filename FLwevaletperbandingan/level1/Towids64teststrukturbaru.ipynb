# %%
import numpy as np
import os
import gc
import time
import matplotlib.pyplot as plt
import seaborn as sns

import tensorflow as tf
from tensorflow.keras import layers, models

from sklearn.metrics import (
    confusion_matrix,
    classification_report,
    roc_curve,
    auc,
    precision_recall_curve,
    f1_score
)

# %%
import numpy as np
import os
import gc
import time
import matplotlib.pyplot as plt
import seaborn as sns

import tensorflow as tf
from tensorflow.keras import layers, models

from sklearn.metrics import (
    confusion_matrix,
    classification_report,
    roc_curve,
    auc,
    precision_recall_curve,
    f1_score
)

# %%
BASE_PATHHASIL = "/home/dani/Documents/tugas akhir/TugasAkhir/codeTugasAkhirku2026/tow_ids/Preprocessing/Preprocessingbaru/imgsize64lv1/norm/dwt/"

# %%
import tensorflow as tf
from tensorflow.keras import layers, models


def build_cnn_tow_ids(input_shape=(32, 32, 3)):

    inputs = layers.Input(shape=input_shape)

    # =========================================================
    # Block A
    # SeparableConv + ReLU
    # SeparableConv + ReLU
    # BatchNorm
    # MaxPooling
    # =========================================================

    x = layers.SeparableConv2D(
        32, (3,3),
        padding="same",
        use_bias=False
    )(inputs)
    x = layers.ReLU()(x)

    x = layers.SeparableConv2D(
        32, (3,3),
        padding="same",
        use_bias=False
    )(x)
    x = layers.ReLU()(x)

    x = layers.BatchNormalization()(x)

    x = layers.MaxPooling2D((2,2))(x)

    # =========================================================
    # Block B (Residual Block)
    #
    # shortcut:
    # Conv1x1 + BN
    #
    # main:
    # SepConv + ReLU
    # SepConv + ReLU
    # BN
    #
    # output:
    # Add + ReLU
    # =========================================================

    shortcut = layers.Conv2D(
        64,
        (1,1),
        padding="same",
        use_bias=False
    )(x)

    shortcut = layers.BatchNormalization()(shortcut)

    y = layers.SeparableConv2D(
        64,
        (3,3),
        padding="same",
        use_bias=False
    )(x)
    y = layers.ReLU()(y)

    y = layers.SeparableConv2D(
        64,
        (3,3),
        padding="same",
        use_bias=False
    )(y)
    y = layers.ReLU()(y)

    y = layers.BatchNormalization()(y)

    x = layers.Add()([y, shortcut])
    x = layers.ReLU()(x)

    # =========================================================
    # Block C
    #
    # SepConv + ReLU
    # GlobalAveragePooling
    # Dense + ReLU
    # Dense + ReLU
    # Dropout
    # Dense + Sigmoid
    # =========================================================

    x = layers.SeparableConv2D(
        128,
        (3,3),
        padding="same",
        use_bias=False
    )(x)
    x = layers.ReLU()(x)

    x = layers.GlobalAveragePooling2D()(x)

    x = layers.Dense(512, activation="relu")(x)

    x = layers.Dense(256, activation="relu")(x)

    x = layers.Dropout(0.5)(x)

    outputs = layers.Dense(
        1,
        activation="sigmoid"
    )(x)

    model = models.Model(inputs, outputs)

    model.compile(
        optimizer=tf.keras.optimizers.Adam(1e-3),
        loss="binary_crossentropy",
        metrics=[
            "accuracy",
            tf.keras.metrics.Precision(name="precision"),
            tf.keras.metrics.Recall(name="recall")
        ]
    )

    return model

# %%
train_data = np.load(os.path.join(BASE_PATHHASIL, "tow_ids_train_dwt.npz"))
test_data  = np.load(os.path.join(BASE_PATHHASIL, "tow_ids_test_dwt.npz"))
val_data   = np.load(os.path.join(BASE_PATHHASIL, "tow_ids_eval_dwt.npz"))

X_train = train_data["X"]
y_train = train_data["y"]

X_test  = test_data["X"]
y_test  = test_data["y"]

X_val   = val_data["X"]
y_val   = val_data["y"]

print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
print(X_val.shape, y_val.shape)
# Out:
# (13165, 32, 32, 3) (13165,)
# (12368, 32, 32, 3) (12368,)
# (5642, 32, 32, 3) (5642,)

# %%
tf.keras.backend.clear_session()

model = build_cnn_tow_ids()
model.summary()
# Out:
# I0000 00:00:1779461010.644816  396935 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 4144 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 32, 32, 3) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d    │ (None, 32, 32,    │        123 │ input_layer[0][0] │
# │ (SeparableConv2D)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu (ReLU)        │ (None, 32, 32,    │          0 │ separable_conv2d… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_1  │ (None, 32, 32,    │      1,312 │ re_lu[0][0]       │
# │ (SeparableConv2D)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_1 (ReLU)      │ (None, 32, 32,    │          0 │ separable_conv2d… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 32, 32,    │        128 │ re_lu_1[0][0]     │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_2  │ (None, 16, 16,    │      2,336 │ max_pooling2d[0]… │
# │ (SeparableConv2D)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_2 (ReLU)      │ (None, 16, 16,    │          0 │ separable_conv2d… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_3  │ (None, 16, 16,    │      4,672 │ re_lu_2[0][0]     │
# │ (SeparableConv2D)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_3 (ReLU)      │ (None, 16, 16,    │          0 │ separable_conv2d… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 16, 16,    │      2,048 │ max_pooling2d[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        256 │ re_lu_3[0][0]     │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        256 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 64)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_4 (ReLU)      │ (None, 16, 16,    │          0 │ add[0][0]         │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_4  │ (None, 16, 16,    │      8,768 │ re_lu_4[0][0]     │
# │ (SeparableConv2D)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_5 (ReLU)      │ (None, 16, 16,    │          0 │ separable_conv2d… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 128)       │          0 │ re_lu_5[0][0]     │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 512)       │     66,048 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 256)       │    131,328 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 256)       │          0 │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 1)         │        257 │ dropout[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 217,532 (849.73 KB)
#  Trainable params: 217,212 (848.48 KB)
#  Non-trainable params: 320 (1.25 KB)

# %%
history = model.fit(
    X_train, y_train,
    epochs=50,
    batch_size=32,
    validation_data=(X_val, y_val),
    verbose=1,
    
)
# Out:
# Epoch 1/50
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1779461013.108619  397502 service.cc:152] XLA service 0x7c47e4002910 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1779461013.108634  397502 service.cc:160]   StreamExecutor device (0): NVIDIA GeForce RTX 3060 Laptop GPU, Compute Capability 8.6
# 2026-05-22 21:43:33.157997: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1779461013.493420  397502 cuda_dnn.cc:529] Loaded cuDNN version 91701
# 2026-05-22 21:43:34.802991: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1485_0', 44 bytes spill stores, 44 bytes spill loads
#
# 2026-05-22 21:43:35.005634: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1485', 484 bytes spill stores, 484 bytes spill loads
#
# 2026-05-22 21:43:35.929469: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2263', 32 bytes spill stores, 32 bytes spill loads
#
# 2026-05-22 21:43:35.939503: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2263', 36 bytes spill stores, 44 bytes spill loads
#
# 2026-05-22 21:43:36.203495: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2263', 32 bytes spill stores, 32 bytes spill loads
#
# 2026-05-22 21:43:36.357321: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2261', 36 bytes spill stores, 44 bytes spill loads
#
# I0000 00:00:1779461020.655678  397502 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 409/412 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.8010 - loss: 0.3841 - precision: 0.7987 - recall: 0.8359
# 2026-05-22 21:43:45.020320: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1485', 64 bytes spill stores, 64 bytes spill loads
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - accuracy: 0.8017 - loss: 0.3829 - precision: 0.7995 - recall: 0.8363
# 2026-05-22 21:43:54.018002: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_176', 64 bytes spill stores, 64 bytes spill loads
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 25s 36ms/step - accuracy: 0.9063 - loss: 0.2158 - precision: 0.9134 - recall: 0.8982 - val_accuracy: 0.6434 - val_loss: 1.3026 - val_precision: 0.6434 - val_recall: 1.0000
# Epoch 2/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9753 - loss: 0.0784 - precision: 0.9859 - recall: 0.9646 - val_accuracy: 0.9513 - val_loss: 0.1519 - val_precision: 0.9861 - val_recall: 0.9375
# Epoch 3/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9794 - loss: 0.0667 - precision: 0.9883 - recall: 0.9705 - val_accuracy: 0.5604 - val_loss: 1.3747 - val_precision: 0.9983 - val_recall: 0.3174
# Epoch 4/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9818 - loss: 0.0600 - precision: 0.9888 - recall: 0.9747 - val_accuracy: 0.9449 - val_loss: 0.1708 - val_precision: 0.9501 - val_recall: 0.9650
# Epoch 5/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9840 - loss: 0.0491 - precision: 0.9902 - recall: 0.9779 - val_accuracy: 0.5617 - val_loss: 1.3217 - val_precision: 0.9983 - val_recall: 0.3193
# Epoch 6/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9853 - loss: 0.0497 - precision: 0.9905 - recall: 0.9800 - val_accuracy: 0.9176 - val_loss: 0.1972 - val_precision: 0.9883 - val_recall: 0.8824
# Epoch 7/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9878 - loss: 0.0399 - precision: 0.9922 - recall: 0.9833 - val_accuracy: 0.7125 - val_loss: 0.7722 - val_precision: 0.9767 - val_recall: 0.5667
# Epoch 8/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9889 - loss: 0.0381 - precision: 0.9924 - recall: 0.9855 - val_accuracy: 0.5849 - val_loss: 1.5795 - val_precision: 0.9924 - val_recall: 0.3576
# Epoch 9/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9906 - loss: 0.0337 - precision: 0.9939 - recall: 0.9873 - val_accuracy: 0.8229 - val_loss: 0.4498 - val_precision: 0.9885 - val_recall: 0.7333
# Epoch 10/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9914 - loss: 0.0335 - precision: 0.9944 - recall: 0.9885 - val_accuracy: 0.5374 - val_loss: 2.1413 - val_precision: 0.9990 - val_recall: 0.2813
# Epoch 11/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9919 - loss: 0.0292 - precision: 0.9947 - recall: 0.9891 - val_accuracy: 0.7380 - val_loss: 0.7520 - val_precision: 0.9936 - val_recall: 0.5967
# Epoch 12/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9918 - loss: 0.0290 - precision: 0.9945 - recall: 0.9891 - val_accuracy: 0.8963 - val_loss: 0.2929 - val_precision: 0.9903 - val_recall: 0.8471
# Epoch 13/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9931 - loss: 0.0256 - precision: 0.9956 - recall: 0.9906 - val_accuracy: 0.6326 - val_loss: 1.1551 - val_precision: 0.9820 - val_recall: 0.4369
# Epoch 14/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9931 - loss: 0.0271 - precision: 0.9960 - recall: 0.9902 - val_accuracy: 0.6882 - val_loss: 1.1645 - val_precision: 0.9984 - val_recall: 0.5163
# Epoch 15/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9940 - loss: 0.0229 - precision: 0.9965 - recall: 0.9915 - val_accuracy: 0.5482 - val_loss: 1.4898 - val_precision: 0.9945 - val_recall: 0.2994
# Epoch 16/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9936 - loss: 0.0233 - precision: 0.9962 - recall: 0.9911 - val_accuracy: 0.4982 - val_loss: 2.0185 - val_precision: 0.9926 - val_recall: 0.2218
# Epoch 17/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9938 - loss: 0.0212 - precision: 0.9962 - recall: 0.9915 - val_accuracy: 0.5822 - val_loss: 1.3978 - val_precision: 0.9789 - val_recall: 0.3584
# Epoch 18/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9948 - loss: 0.0207 - precision: 0.9964 - recall: 0.9932 - val_accuracy: 0.6730 - val_loss: 1.1752 - val_precision: 0.9837 - val_recall: 0.5000
# Epoch 19/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9945 - loss: 0.0196 - precision: 0.9960 - recall: 0.9930 - val_accuracy: 0.4805 - val_loss: 2.9245 - val_precision: 0.9957 - val_recall: 0.1934
# Epoch 20/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9956 - loss: 0.0180 - precision: 0.9973 - recall: 0.9939 - val_accuracy: 0.4887 - val_loss: 2.3411 - val_precision: 0.9960 - val_recall: 0.2061
# Epoch 21/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9949 - loss: 0.0187 - precision: 0.9967 - recall: 0.9932 - val_accuracy: 0.5454 - val_loss: 1.9794 - val_precision: 0.9784 - val_recall: 0.3000
# Epoch 22/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9942 - loss: 0.0185 - precision: 0.9950 - recall: 0.9933 - val_accuracy: 0.4915 - val_loss: 2.5327 - val_precision: 0.9922 - val_recall: 0.2113
# Epoch 23/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9966 - loss: 0.0127 - precision: 0.9976 - recall: 0.9956 - val_accuracy: 0.4706 - val_loss: 3.0187 - val_precision: 0.9923 - val_recall: 0.1785
# Epoch 24/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9957 - loss: 0.0155 - precision: 0.9971 - recall: 0.9944 - val_accuracy: 0.4293 - val_loss: 3.0260 - val_precision: 1.0000 - val_recall: 0.1129
# Epoch 25/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9961 - loss: 0.0142 - precision: 0.9974 - recall: 0.9949 - val_accuracy: 0.5987 - val_loss: 2.1646 - val_precision: 0.9985 - val_recall: 0.3769
# Epoch 26/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9960 - loss: 0.0157 - precision: 0.9971 - recall: 0.9949 - val_accuracy: 0.5486 - val_loss: 2.3213 - val_precision: 0.9822 - val_recall: 0.3039
# Epoch 27/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9954 - loss: 0.0161 - precision: 0.9965 - recall: 0.9944 - val_accuracy: 0.5606 - val_loss: 2.8526 - val_precision: 0.9974 - val_recall: 0.3179
# Epoch 28/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9972 - loss: 0.0111 - precision: 0.9982 - recall: 0.9962 - val_accuracy: 0.5360 - val_loss: 2.9005 - val_precision: 0.9922 - val_recall: 0.2810
# Epoch 29/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9965 - loss: 0.0130 - precision: 0.9979 - recall: 0.9952 - val_accuracy: 0.5177 - val_loss: 3.1481 - val_precision: 0.9914 - val_recall: 0.2526
# Epoch 30/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9968 - loss: 0.0116 - precision: 0.9976 - recall: 0.9961 - val_accuracy: 0.4686 - val_loss: 3.1486 - val_precision: 0.9953 - val_recall: 0.1749
# Epoch 31/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9969 - loss: 0.0125 - precision: 0.9983 - recall: 0.9955 - val_accuracy: 0.5432 - val_loss: 2.6250 - val_precision: 0.9981 - val_recall: 0.2906
# Epoch 32/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9953 - loss: 0.0170 - precision: 0.9970 - recall: 0.9936 - val_accuracy: 0.5034 - val_loss: 2.4896 - val_precision: 0.9929 - val_recall: 0.2298
# Epoch 33/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9958 - loss: 0.0151 - precision: 0.9976 - recall: 0.9941 - val_accuracy: 0.5622 - val_loss: 1.5662 - val_precision: 0.9866 - val_recall: 0.3240
# Epoch 34/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9974 - loss: 0.0096 - precision: 0.9985 - recall: 0.9964 - val_accuracy: 0.4816 - val_loss: 3.2735 - val_precision: 0.9944 - val_recall: 0.1953
# Epoch 35/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9970 - loss: 0.0103 - precision: 0.9983 - recall: 0.9958 - val_accuracy: 0.4438 - val_loss: 3.1286 - val_precision: 0.9843 - val_recall: 0.1377
# Epoch 36/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9980 - loss: 0.0075 - precision: 0.9991 - recall: 0.9970 - val_accuracy: 0.5073 - val_loss: 4.0836 - val_precision: 0.9953 - val_recall: 0.2353
# Epoch 37/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9973 - loss: 0.0085 - precision: 0.9982 - recall: 0.9964 - val_accuracy: 0.5170 - val_loss: 3.2636 - val_precision: 0.9935 - val_recall: 0.2510
# Epoch 38/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9983 - loss: 0.0057 - precision: 0.9988 - recall: 0.9979 - val_accuracy: 0.4658 - val_loss: 4.5458 - val_precision: 1.0000 - val_recall: 0.1697
# Epoch 39/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9977 - loss: 0.0071 - precision: 0.9986 - recall: 0.9968 - val_accuracy: 0.4897 - val_loss: 5.2765 - val_precision: 0.9974 - val_recall: 0.2074
# Epoch 40/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9969 - loss: 0.0103 - precision: 0.9977 - recall: 0.9961 - val_accuracy: 0.4903 - val_loss: 3.7176 - val_precision: 0.9961 - val_recall: 0.2085
# Epoch 41/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9976 - loss: 0.0067 - precision: 0.9979 - recall: 0.9973 - val_accuracy: 0.4114 - val_loss: 7.0041 - val_precision: 0.9936 - val_recall: 0.0857
# Epoch 42/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9983 - loss: 0.0061 - precision: 0.9986 - recall: 0.9980 - val_accuracy: 0.5245 - val_loss: 2.5523 - val_precision: 0.9886 - val_recall: 0.2639
# Epoch 43/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9975 - loss: 0.0077 - precision: 0.9980 - recall: 0.9970 - val_accuracy: 0.4536 - val_loss: 3.5183 - val_precision: 0.9982 - val_recall: 0.1510
# Epoch 44/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9979 - loss: 0.0053 - precision: 0.9988 - recall: 0.9971 - val_accuracy: 0.5872 - val_loss: 3.4661 - val_precision: 0.9902 - val_recall: 0.3620
# Epoch 45/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9964 - loss: 0.0114 - precision: 0.9971 - recall: 0.9956 - val_accuracy: 0.4757 - val_loss: 4.1506 - val_precision: 0.9855 - val_recall: 0.1879
# Epoch 46/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9980 - loss: 0.0059 - precision: 0.9982 - recall: 0.9979 - val_accuracy: 0.5315 - val_loss: 3.7561 - val_precision: 0.9843 - val_recall: 0.2763
# Epoch 47/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9984 - loss: 0.0059 - precision: 0.9977 - recall: 0.9991 - val_accuracy: 0.4768 - val_loss: 3.6567 - val_precision: 0.9971 - val_recall: 0.1873
# Epoch 48/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9976 - loss: 0.0062 - precision: 0.9980 - recall: 0.9973 - val_accuracy: 0.5151 - val_loss: 4.7774 - val_precision: 0.9901 - val_recall: 0.2488
# Epoch 49/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9979 - loss: 0.0069 - precision: 0.9982 - recall: 0.9976 - val_accuracy: 0.4784 - val_loss: 3.6545 - val_precision: 0.9886 - val_recall: 0.1915
# Epoch 50/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - accuracy: 0.9983 - loss: 0.0055 - precision: 0.9982 - recall: 0.9985 - val_accuracy: 0.6694 - val_loss: 2.1893 - val_precision: 0.9911 - val_recall: 0.4906

# %%
# =========================
# CELL 1
# =========================

import numpy as np
from sklearn.metrics import roc_curve

# prediksi probabilitas
y_prob = model.predict(X_test).ravel()

# label asli
y_true = y_test

# =========================
# EVALUASI DEFAULT THRESHOLD 0.5
# =========================

default_threshold = 0.5
y_pred_default = (y_prob >= default_threshold).astype(int)

# =========================
# CARI THRESHOLD TERBAIK
# =========================
# strategi:
# cari threshold dengan F1 tertinggi

thresholds = np.arange(0.1, 0.91, 0.01)

best_threshold = 0.5
best_f1 = 0

for th in thresholds:

    y_pred_temp = (y_prob >= th).astype(int)

    TP = np.sum((y_true == 1) & (y_pred_temp == 1))
    TN = np.sum((y_true == 0) & (y_pred_temp == 0))
    FP = np.sum((y_true == 0) & (y_pred_temp == 1))
    FN = np.sum((y_true == 1) & (y_pred_temp == 0))

    precision = TP / (TP + FP + 1e-12)
    recall = TP / (TP + FN + 1e-12)

    f1 = 2 * precision * recall / (precision + recall + 1e-12)

    if f1 > best_f1:
        best_f1 = f1
        best_threshold = th

print("Best Threshold:", best_threshold)
print("Best F1 Score :", best_f1)

# prediksi final threshold terbaik
y_pred_best = (y_prob >= best_threshold).astype(int)
# Out:
# 373/387 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2026-05-22 21:45:36.366800: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_138', 52 bytes spill stores, 52 bytes spill loads
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step
# Best Threshold: 0.23999999999999994
# Best F1 Score : 0.9169092104022796

# %%
# =========================
# CELL 2
# =========================

from sklearn.metrics import confusion_matrix

# ===== DEFAULT 0.5 =====
cm_default = confusion_matrix(y_true, y_pred_default)

TN_d, FP_d, FN_d, TP_d = cm_default.ravel()

print("=== Confusion Matrix (Threshold = 0.5) ===")
print(cm_default)

# ===== BEST THRESHOLD =====
cm_best = confusion_matrix(y_true, y_pred_best)

TN_b, FP_b, FN_b, TP_b = cm_best.ravel()

print("\n=== Confusion Matrix (Best Threshold) ===")
print(cm_best)
# Out:
# === Confusion Matrix (Threshold = 0.5) ===
# [[6714  132]
#  [ 759 4763]]
#
# === Confusion Matrix (Best Threshold) ===
# [[6600  246]
#  [ 639 4883]]

# %%
# =========================
# CELL 3
# =========================

def calculate_metrics(TN, FP, FN, TP):

    accuracy = (TP + TN) / (TP + TN + FP + FN)

    precision = TP / (TP + FP + 1e-12)

    recall = TP / (TP + FN + 1e-12)

    f1 = 2 * precision * recall / (precision + recall + 1e-12)

    FPR = FP / (FP + TN + 1e-12)

    FNR = FN / (FN + TP + 1e-12)

    return accuracy, precision, recall, f1, FPR, FNR


# ===== DEFAULT =====
metrics_default = calculate_metrics(TN_d, FP_d, FN_d, TP_d)

# ===== BEST =====
metrics_best = calculate_metrics(TN_b, FP_b, FN_b, TP_b)

# %%
# =========================
# CELL 4
# =========================

metric_names = [
    "Accuracy",
    "Precision",
    "Recall",
    "F1-score",
    "FPR",
    "FNR"
]

print("========================================")
print("THRESHOLD = 0.5")
print("========================================")

for name, value in zip(metric_names, metrics_default):
    print(f"{name:10}: {value:.6f}")

print("\n")

print("========================================")
print(f"BEST THRESHOLD = {best_threshold:.2f}")
print("========================================")

for name, value in zip(metric_names, metrics_best):
    print(f"{name:10}: {value:.6f}")
# Out:
# ========================================
# THRESHOLD = 0.5
# ========================================
# Accuracy  : 0.927959
# Precision : 0.973034
# Recall    : 0.862550
# F1-score  : 0.914467
# FPR       : 0.019281
# FNR       : 0.137450
#
#
# ========================================
# BEST THRESHOLD = 0.24
# ========================================
# Accuracy  : 0.928444
# Precision : 0.952037
# Recall    : 0.884281
# F1-score  : 0.916909
# FPR       : 0.035933
# FNR       : 0.115719

# %%
# =========================
# CELL 5
# =========================

import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

fpr, tpr, _ = roc_curve(y_true, y_prob)

roc_auc = auc(fpr, tpr)

plt.figure(figsize=(6,6))

plt.plot(fpr, tpr, label="AUC = %0.4f" % roc_auc)

plt.plot([0,1],[0,1],'--')

plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")

plt.title("ROC Curve")

plt.legend()

plt.grid(True)

plt.show()
