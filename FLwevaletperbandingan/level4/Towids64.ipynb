# %%
import numpy as np
import os
import gc
import time
import matplotlib.pyplot as plt
import seaborn as sns

import tensorflow as tf
from tensorflow.keras import layers, models

from sklearn.metrics import (
    confusion_matrix,
    classification_report,
    roc_curve,
    auc,
    precision_recall_curve,
    f1_score
)
# Out:
# 2026-05-23 01:25:01.359222: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-05-23 01:25:01.369359: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1779474301.382222  694765 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1779474301.386181  694765 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1779474301.396224  694765 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1779474301.396240  694765 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1779474301.396242  694765 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1779474301.396243  694765 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-05-23 01:25:01.399371: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
import numpy as np
import os
import gc
import time
import matplotlib.pyplot as plt
import seaborn as sns

import tensorflow as tf
from tensorflow.keras import layers, models

from sklearn.metrics import (
    confusion_matrix,
    classification_report,
    roc_curve,
    auc,
    precision_recall_curve,
    f1_score
)

# %%
BASE_PATHHASIL = "/home/dani/Documents/tugas akhir/TugasAkhir/codeTugasAkhirku2026/tow_ids/Preprocessing/Preprocessingbaru/imgsize64lv4/norm/dwt/"

# %%
import tensorflow as tf
from tensorflow.keras import layers, models


def build_cnn_tow_ids(input_shape=(4, 4, 3)):

    inputs = layers.Input(shape=input_shape)

    # =========================================================
    # Block A
    # SeparableConv + ReLU
    # SeparableConv + ReLU
    # BatchNorm
    # MaxPooling
    # =========================================================

    x = layers.SeparableConv2D(
        32, (3,3),
        padding="same",
        use_bias=False
    )(inputs)
    x = layers.ReLU()(x)

    x = layers.SeparableConv2D(
        32, (3,3),
        padding="same",
        use_bias=False
    )(x)
    x = layers.ReLU()(x)

    x = layers.BatchNormalization()(x)

    x = layers.MaxPooling2D((2,2))(x)

    # =========================================================
    # Block B (Residual Block)
    #
    # shortcut:
    # Conv1x1 + BN
    #
    # main:
    # SepConv + ReLU
    # SepConv + ReLU
    # BN
    #
    # output:
    # Add + ReLU
    # =========================================================

    shortcut = layers.Conv2D(
        64,
        (1,1),
        padding="same",
        use_bias=False
    )(x)

    shortcut = layers.BatchNormalization()(shortcut)

    y = layers.SeparableConv2D(
        64,
        (3,3),
        padding="same",
        use_bias=False
    )(x)
    y = layers.ReLU()(y)

    y = layers.SeparableConv2D(
        64,
        (3,3),
        padding="same",
        use_bias=False
    )(y)
    y = layers.ReLU()(y)

    y = layers.BatchNormalization()(y)

    x = layers.Add()([y, shortcut])
    x = layers.ReLU()(x)

    # =========================================================
    # Block C
    #
    # SepConv + ReLU
    # GlobalAveragePooling
    # Dense + ReLU
    # Dense + ReLU
    # Dropout
    # Dense + Sigmoid
    # =========================================================

    x = layers.SeparableConv2D(
        128,
        (3,3),
        padding="same",
        use_bias=False
    )(x)
    x = layers.ReLU()(x)

    x = layers.GlobalAveragePooling2D()(x)

    x = layers.Dense(512, activation="relu")(x)

    x = layers.Dense(256, activation="relu")(x)

    x = layers.Dropout(0.5)(x)

    outputs = layers.Dense(
        1,
        activation="sigmoid"
    )(x)

    model = models.Model(inputs, outputs)

    model.compile(
        optimizer=tf.keras.optimizers.Adam(1e-3),
        loss="binary_crossentropy",
        metrics=[
            "accuracy",
            tf.keras.metrics.Precision(name="precision"),
            tf.keras.metrics.Recall(name="recall")
        ]
    )

    return model

# %%
train_data = np.load(os.path.join(BASE_PATHHASIL, "tow_ids_train_dwt.npz"))
test_data  = np.load(os.path.join(BASE_PATHHASIL, "tow_ids_test_dwt.npz"))
val_data   = np.load(os.path.join(BASE_PATHHASIL, "tow_ids_eval_dwt.npz"))

X_train = train_data["X"]
y_train = train_data["y"]

X_test  = test_data["X"]
y_test  = test_data["y"]

X_val   = val_data["X"]
y_val   = val_data["y"]

print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
print(X_val.shape, y_val.shape)
# Out:
# (13165, 4, 4, 3) (13165,)
# (12368, 4, 4, 3) (12368,)
# (5642, 4, 4, 3) (5642,)

# %%
tf.keras.backend.clear_session()

model = build_cnn_tow_ids()
model.summary()
# Out:
# I0000 00:00:1779474302.876481  694765 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 4144 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 4, 4, 3)   │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d    │ (None, 4, 4, 32)  │        123 │ input_layer[0][0] │
# │ (SeparableConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu (ReLU)        │ (None, 4, 4, 32)  │          0 │ separable_conv2d… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_1  │ (None, 4, 4, 32)  │      1,312 │ re_lu[0][0]       │
# │ (SeparableConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_1 (ReLU)      │ (None, 4, 4, 32)  │          0 │ separable_conv2d… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 4, 4, 32)  │        128 │ re_lu_1[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 2, 2, 32)  │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_2  │ (None, 2, 2, 64)  │      2,336 │ max_pooling2d[0]… │
# │ (SeparableConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_2 (ReLU)      │ (None, 2, 2, 64)  │          0 │ separable_conv2d… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_3  │ (None, 2, 2, 64)  │      4,672 │ re_lu_2[0][0]     │
# │ (SeparableConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_3 (ReLU)      │ (None, 2, 2, 64)  │          0 │ separable_conv2d… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 2, 2, 64)  │      2,048 │ max_pooling2d[0]… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 2, 2, 64)  │        256 │ re_lu_3[0][0]     │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 2, 2, 64)  │        256 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 2, 2, 64)  │          0 │ batch_normalizat… │
# │                     │                   │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_4 (ReLU)      │ (None, 2, 2, 64)  │          0 │ add[0][0]         │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_4  │ (None, 2, 2, 128) │      8,768 │ re_lu_4[0][0]     │
# │ (SeparableConv2D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_5 (ReLU)      │ (None, 2, 2, 128) │          0 │ separable_conv2d… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 128)       │          0 │ re_lu_5[0][0]     │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 512)       │     66,048 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 256)       │    131,328 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 256)       │          0 │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 1)         │        257 │ dropout[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 217,532 (849.73 KB)
#  Trainable params: 217,212 (848.48 KB)
#  Non-trainable params: 320 (1.25 KB)

# %%
history = model.fit(
    X_train, y_train,
    epochs=50,
    batch_size=32,
    validation_data=(X_val, y_val),
    verbose=1,
    
)
# Out:
# Epoch 1/50
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1779474305.191933  742839 service.cc:152] XLA service 0x76d654017900 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1779474305.191948  742839 service.cc:160]   StreamExecutor device (0): NVIDIA GeForce RTX 3060 Laptop GPU, Compute Capability 8.6
# 2026-05-23 01:25:05.245217: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1779474305.597733  742839 cuda_dnn.cc:529] Loaded cuDNN version 91701
# 2026-05-23 01:25:07.074159: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1485_0', 44 bytes spill stores, 44 bytes spill loads
#
# 2026-05-23 01:25:07.232159: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1485', 484 bytes spill stores, 484 bytes spill loads
#
# 2026-05-23 01:25:07.667994: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2263', 36 bytes spill stores, 44 bytes spill loads
#
# 2026-05-23 01:25:07.951003: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2261', 36 bytes spill stores, 44 bytes spill loads
#
# 2026-05-23 01:25:08.061744: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2263', 32 bytes spill stores, 32 bytes spill loads
#
# 2026-05-23 01:25:08.491116: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2263', 32 bytes spill stores, 32 bytes spill loads
#  22/412 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4619 - loss: 0.6945 - precision: 0.4570 - recall: 0.5007
# I0000 00:00:1779474312.520971  742839 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 399/412 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5817 - loss: 0.6462 - precision: 0.6110 - recall: 0.4851
# 2026-05-23 01:25:15.556271: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1485', 64 bytes spill stores, 64 bytes spill loads
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.5829 - loss: 0.6455 - precision: 0.6129 - recall: 0.4851
# 2026-05-23 01:25:21.965258: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_176', 64 bytes spill stores, 64 bytes spill loads
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 21s 28ms/step - accuracy: 0.6225 - loss: 0.6231 - precision: 0.6706 - recall: 0.4858 - val_accuracy: 0.6177 - val_loss: 0.6592 - val_precision: 0.6358 - val_recall: 0.9501
# Epoch 2/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6632 - loss: 0.5994 - precision: 0.6972 - recall: 0.5806 - val_accuracy: 0.7508 - val_loss: 0.4625 - val_precision: 0.9546 - val_recall: 0.6433
# Epoch 3/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6694 - loss: 0.5912 - precision: 0.6930 - recall: 0.6116 - val_accuracy: 0.7297 - val_loss: 0.4470 - val_precision: 0.8135 - val_recall: 0.7523
# Epoch 4/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6750 - loss: 0.5869 - precision: 0.7112 - recall: 0.5927 - val_accuracy: 0.7398 - val_loss: 0.4106 - val_precision: 0.7674 - val_recall: 0.8545
# Epoch 5/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6727 - loss: 0.5886 - precision: 0.7052 - recall: 0.5968 - val_accuracy: 0.8095 - val_loss: 0.3605 - val_precision: 0.8666 - val_recall: 0.8320
# Epoch 6/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6811 - loss: 0.5760 - precision: 0.7082 - recall: 0.6194 - val_accuracy: 0.7214 - val_loss: 0.4827 - val_precision: 0.8469 - val_recall: 0.6920
# Epoch 7/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6833 - loss: 0.5760 - precision: 0.7138 - recall: 0.6150 - val_accuracy: 0.5503 - val_loss: 0.5399 - val_precision: 0.6221 - val_recall: 0.7672
# Epoch 8/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6856 - loss: 0.5738 - precision: 0.7166 - recall: 0.6171 - val_accuracy: 0.7364 - val_loss: 0.5158 - val_precision: 0.7702 - val_recall: 0.8413
# Epoch 9/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6912 - loss: 0.5693 - precision: 0.7325 - recall: 0.6054 - val_accuracy: 0.7357 - val_loss: 0.5143 - val_precision: 0.9600 - val_recall: 0.6149
# Epoch 10/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6907 - loss: 0.5650 - precision: 0.7227 - recall: 0.6218 - val_accuracy: 0.8235 - val_loss: 0.3474 - val_precision: 0.8604 - val_recall: 0.8661
# Epoch 11/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.6940 - loss: 0.5620 - precision: 0.7358 - recall: 0.6083 - val_accuracy: 0.6797 - val_loss: 0.5519 - val_precision: 0.7323 - val_recall: 0.7915
# Epoch 12/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6984 - loss: 0.5618 - precision: 0.7376 - recall: 0.6188 - val_accuracy: 0.8283 - val_loss: 0.3946 - val_precision: 0.9358 - val_recall: 0.7871
# Epoch 13/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6966 - loss: 0.5598 - precision: 0.7353 - recall: 0.6172 - val_accuracy: 0.6517 - val_loss: 0.4645 - val_precision: 0.6489 - val_recall: 0.9994
# Epoch 14/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6977 - loss: 0.5613 - precision: 0.7330 - recall: 0.6247 - val_accuracy: 0.7809 - val_loss: 0.4562 - val_precision: 0.8692 - val_recall: 0.7763
# Epoch 15/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6981 - loss: 0.5591 - precision: 0.7407 - recall: 0.6122 - val_accuracy: 0.5824 - val_loss: 0.6604 - val_precision: 0.7594 - val_recall: 0.5138
# Epoch 16/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7016 - loss: 0.5571 - precision: 0.7436 - recall: 0.6180 - val_accuracy: 0.6834 - val_loss: 0.5064 - val_precision: 0.7394 - val_recall: 0.7846
# Epoch 17/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6995 - loss: 0.5558 - precision: 0.7386 - recall: 0.6203 - val_accuracy: 0.7302 - val_loss: 0.4721 - val_precision: 0.8109 - val_recall: 0.7573
# Epoch 18/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7040 - loss: 0.5523 - precision: 0.7424 - recall: 0.6274 - val_accuracy: 0.7754 - val_loss: 0.6532 - val_precision: 0.7795 - val_recall: 0.9077
# Epoch 19/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7022 - loss: 0.5522 - precision: 0.7480 - recall: 0.6124 - val_accuracy: 0.7465 - val_loss: 0.4607 - val_precision: 0.8553 - val_recall: 0.7295
# Epoch 20/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7008 - loss: 0.5534 - precision: 0.7467 - recall: 0.6104 - val_accuracy: 0.6498 - val_loss: 1.1315 - val_precision: 0.6495 - val_recall: 0.9895
# Epoch 21/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7099 - loss: 0.5481 - precision: 0.7573 - recall: 0.6204 - val_accuracy: 0.7161 - val_loss: 0.4878 - val_precision: 0.7267 - val_recall: 0.8953
# Epoch 22/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7084 - loss: 0.5469 - precision: 0.7511 - recall: 0.6259 - val_accuracy: 0.6060 - val_loss: 0.6080 - val_precision: 0.6819 - val_recall: 0.7264
# Epoch 23/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7068 - loss: 0.5446 - precision: 0.7475 - recall: 0.6272 - val_accuracy: 0.8378 - val_loss: 0.4802 - val_precision: 0.8388 - val_recall: 0.9259
# Epoch 24/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7060 - loss: 0.5472 - precision: 0.7495 - recall: 0.6216 - val_accuracy: 0.5723 - val_loss: 0.6546 - val_precision: 0.6504 - val_recall: 0.7248
# Epoch 25/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7091 - loss: 0.5440 - precision: 0.7602 - recall: 0.6133 - val_accuracy: 0.8534 - val_loss: 0.3758 - val_precision: 0.9711 - val_recall: 0.7959
# Epoch 26/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7053 - loss: 0.5421 - precision: 0.7482 - recall: 0.6215 - val_accuracy: 0.7572 - val_loss: 0.8226 - val_precision: 0.7561 - val_recall: 0.9190
# Epoch 27/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7078 - loss: 0.5437 - precision: 0.7444 - recall: 0.6356 - val_accuracy: 0.8603 - val_loss: 0.3440 - val_precision: 0.9402 - val_recall: 0.8361
# Epoch 28/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7138 - loss: 0.5360 - precision: 0.7518 - recall: 0.6409 - val_accuracy: 0.6072 - val_loss: 0.5850 - val_precision: 0.6799 - val_recall: 0.7361
# Epoch 29/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7146 - loss: 0.5372 - precision: 0.7506 - recall: 0.6454 - val_accuracy: 0.6588 - val_loss: 0.5611 - val_precision: 0.7482 - val_recall: 0.7080
# Epoch 30/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7151 - loss: 0.5382 - precision: 0.7504 - recall: 0.6471 - val_accuracy: 0.4186 - val_loss: 1.2438 - val_precision: 0.5407 - val_recall: 0.6402
# Epoch 31/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7146 - loss: 0.5374 - precision: 0.7463 - recall: 0.6528 - val_accuracy: 0.6973 - val_loss: 0.5797 - val_precision: 0.8339 - val_recall: 0.6612
# Epoch 32/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7136 - loss: 0.5353 - precision: 0.7465 - recall: 0.6493 - val_accuracy: 0.8093 - val_loss: 0.3962 - val_precision: 0.8083 - val_recall: 0.9223
# Epoch 33/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7154 - loss: 0.5367 - precision: 0.7542 - recall: 0.6415 - val_accuracy: 0.4149 - val_loss: 0.9263 - val_precision: 0.5440 - val_recall: 0.5601
# Epoch 34/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7174 - loss: 0.5323 - precision: 0.7517 - recall: 0.6516 - val_accuracy: 0.6033 - val_loss: 0.6319 - val_precision: 0.7032 - val_recall: 0.6636
# Epoch 35/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7155 - loss: 0.5306 - precision: 0.7457 - recall: 0.6568 - val_accuracy: 0.7175 - val_loss: 0.6398 - val_precision: 0.9148 - val_recall: 0.6185
# Epoch 36/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7199 - loss: 0.5283 - precision: 0.7494 - recall: 0.6634 - val_accuracy: 0.5464 - val_loss: 0.7144 - val_precision: 0.6476 - val_recall: 0.6474
# Epoch 37/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7207 - loss: 0.5284 - precision: 0.7571 - recall: 0.6524 - val_accuracy: 0.6024 - val_loss: 0.6160 - val_precision: 0.6704 - val_recall: 0.7515
# Epoch 38/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7199 - loss: 0.5252 - precision: 0.7466 - recall: 0.6684 - val_accuracy: 0.5181 - val_loss: 0.7929 - val_precision: 0.6168 - val_recall: 0.6625
# Epoch 39/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7206 - loss: 0.5247 - precision: 0.7504 - recall: 0.6636 - val_accuracy: 0.6319 - val_loss: 0.7139 - val_precision: 0.8413 - val_recall: 0.5273
# Epoch 40/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7203 - loss: 0.5286 - precision: 0.7513 - recall: 0.6612 - val_accuracy: 0.4376 - val_loss: 1.2912 - val_precision: 0.6258 - val_recall: 0.3132
# Epoch 41/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7200 - loss: 0.5249 - precision: 0.7533 - recall: 0.6568 - val_accuracy: 0.7639 - val_loss: 0.4547 - val_precision: 0.8344 - val_recall: 0.7898
# Epoch 42/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7171 - loss: 0.5271 - precision: 0.7510 - recall: 0.6521 - val_accuracy: 0.5457 - val_loss: 1.1444 - val_precision: 0.6052 - val_recall: 0.8455
# Epoch 43/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7218 - loss: 0.5237 - precision: 0.7477 - recall: 0.6721 - val_accuracy: 0.7056 - val_loss: 0.5693 - val_precision: 0.6957 - val_recall: 0.9642
# Epoch 44/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7260 - loss: 0.5207 - precision: 0.7589 - recall: 0.6648 - val_accuracy: 0.4839 - val_loss: 0.8417 - val_precision: 0.5789 - val_recall: 0.7253
# Epoch 45/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7214 - loss: 0.5236 - precision: 0.7532 - recall: 0.6610 - val_accuracy: 0.8300 - val_loss: 0.4067 - val_precision: 0.8993 - val_recall: 0.8287
# Epoch 46/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7271 - loss: 0.5186 - precision: 0.7554 - recall: 0.6740 - val_accuracy: 0.7104 - val_loss: 0.4617 - val_precision: 0.7253 - val_recall: 0.8851
# Epoch 47/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7210 - loss: 0.5222 - precision: 0.7425 - recall: 0.6792 - val_accuracy: 0.6285 - val_loss: 1.1070 - val_precision: 0.7743 - val_recall: 0.5964
# Epoch 48/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7256 - loss: 0.5196 - precision: 0.7522 - recall: 0.6751 - val_accuracy: 0.7786 - val_loss: 0.6909 - val_precision: 0.8941 - val_recall: 0.7441
# Epoch 49/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7334 - loss: 0.5150 - precision: 0.7558 - recall: 0.6919 - val_accuracy: 0.3837 - val_loss: 1.1427 - val_precision: 0.5215 - val_recall: 0.5107
# Epoch 50/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7299 - loss: 0.5180 - precision: 0.7606 - recall: 0.6733 - val_accuracy: 0.6955 - val_loss: 0.6006 - val_precision: 0.7714 - val_recall: 0.7485

# %%
# =========================
# CELL 1
# =========================

import numpy as np
from sklearn.metrics import roc_curve

# prediksi probabilitas
y_prob = model.predict(X_test).ravel()

# label asli
y_true = y_test

# =========================
# EVALUASI DEFAULT THRESHOLD 0.5
# =========================

default_threshold = 0.5
y_pred_default = (y_prob >= default_threshold).astype(int)

# =========================
# CARI THRESHOLD TERBAIK
# =========================
# strategi:
# cari threshold dengan F1 tertinggi

thresholds = np.arange(0.1, 0.91, 0.01)

best_threshold = 0.5
best_f1 = 0

for th in thresholds:

    y_pred_temp = (y_prob >= th).astype(int)

    TP = np.sum((y_true == 1) & (y_pred_temp == 1))
    TN = np.sum((y_true == 0) & (y_pred_temp == 0))
    FP = np.sum((y_true == 0) & (y_pred_temp == 1))
    FN = np.sum((y_true == 1) & (y_pred_temp == 0))

    precision = TP / (TP + FP + 1e-12)
    recall = TP / (TP + FN + 1e-12)

    f1 = 2 * precision * recall / (precision + recall + 1e-12)

    if f1 > best_f1:
        best_f1 = f1
        best_threshold = th

print("Best Threshold:", best_threshold)
print("Best F1 Score :", best_f1)

# prediksi final threshold terbaik
y_pred_best = (y_prob >= best_threshold).astype(int)
# Out:
# 336/387 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# 2026-05-23 01:26:29.527235: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_138', 52 bytes spill stores, 52 bytes spill loads
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step
# Best Threshold: 0.43999999999999984
# Best F1 Score : 0.6439288476406552

# %%
# =========================
# CELL 2
# =========================

from sklearn.metrics import confusion_matrix

# ===== DEFAULT 0.5 =====
cm_default = confusion_matrix(y_true, y_pred_default)

TN_d, FP_d, FN_d, TP_d = cm_default.ravel()

print("=== Confusion Matrix (Threshold = 0.5) ===")
print(cm_default)

# ===== BEST THRESHOLD =====
cm_best = confusion_matrix(y_true, y_pred_best)

TN_b, FP_b, FN_b, TP_b = cm_best.ravel()

print("\n=== Confusion Matrix (Best Threshold) ===")
print(cm_best)
# Out:
# === Confusion Matrix (Threshold = 0.5) ===
# [[4232 2614]
#  [1698 3824]]
#
# === Confusion Matrix (Best Threshold) ===
# [[3601 3245]
#  [1359 4163]]

# %%
# =========================
# CELL 3
# =========================

def calculate_metrics(TN, FP, FN, TP):

    accuracy = (TP + TN) / (TP + TN + FP + FN)

    precision = TP / (TP + FP + 1e-12)

    recall = TP / (TP + FN + 1e-12)

    f1 = 2 * precision * recall / (precision + recall + 1e-12)

    FPR = FP / (FP + TN + 1e-12)

    FNR = FN / (FN + TP + 1e-12)

    return accuracy, precision, recall, f1, FPR, FNR


# ===== DEFAULT =====
metrics_default = calculate_metrics(TN_d, FP_d, FN_d, TP_d)

# ===== BEST =====
metrics_best = calculate_metrics(TN_b, FP_b, FN_b, TP_b)

# %%
# =========================
# CELL 4
# =========================

metric_names = [
    "Accuracy",
    "Precision",
    "Recall",
    "F1-score",
    "FPR",
    "FNR"
]

print("========================================")
print("THRESHOLD = 0.5")
print("========================================")

for name, value in zip(metric_names, metrics_default):
    print(f"{name:10}: {value:.6f}")

print("\n")

print("========================================")
print(f"BEST THRESHOLD = {best_threshold:.2f}")
print("========================================")

for name, value in zip(metric_names, metrics_best):
    print(f"{name:10}: {value:.6f}")
# Out:
# ========================================
# THRESHOLD = 0.5
# ========================================
# Accuracy  : 0.651358
# Precision : 0.593973
# Recall    : 0.692503
# F1-score  : 0.639465
# FPR       : 0.381829
# FNR       : 0.307497
#
#
# ========================================
# BEST THRESHOLD = 0.44
# ========================================
# Accuracy  : 0.627749
# Precision : 0.561960
# Recall    : 0.753894
# F1-score  : 0.643929
# FPR       : 0.473999
# FNR       : 0.246106

# %%
# =========================
# CELL 5
# =========================

import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

fpr, tpr, _ = roc_curve(y_true, y_prob)

roc_auc = auc(fpr, tpr)

plt.figure(figsize=(6,6))

plt.plot(fpr, tpr, label="AUC = %0.4f" % roc_auc)

plt.plot([0,1],[0,1],'--')

plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")

plt.title("ROC Curve")

plt.legend()

plt.grid(True)

plt.show()
