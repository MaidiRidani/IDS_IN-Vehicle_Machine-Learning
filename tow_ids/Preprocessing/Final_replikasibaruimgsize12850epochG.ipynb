# %%
import numpy as np
import os
import gc
import time
import matplotlib.pyplot as plt
import seaborn as sns

import tensorflow as tf
from tensorflow.keras import layers, models

from sklearn.metrics import (
    confusion_matrix,
    classification_report,
    roc_curve,
    auc,
    precision_recall_curve,
    f1_score
)

# %%
import numpy as np
import os
import gc
import time
import matplotlib.pyplot as plt
import seaborn as sns

import tensorflow as tf
from tensorflow.keras import layers, models

from sklearn.metrics import (
    confusion_matrix,
    classification_report,
    roc_curve,
    auc,
    precision_recall_curve,
    f1_score
)

# %%
BASE_PATHHASIL = "/home/dani/Documents/tugas akhir/TugasAkhir/codeTugasAkhirku2026/tow_ids/Preprocessing/Preprocessingbaru/imgsize128/norm/dwt/"

# %%
import tensorflow as tf
from tensorflow.keras import layers, models

def build_cnn_tow_ids():

    inputs = layers.Input(shape=(64, 64, 3))

    # ===== Block A =====
    x = layers.SeparableConv2D(32, (3,3), padding="same")(inputs)
    x = layers.ReLU()(x)
    x = layers.BatchNormalization()(x)
    x = layers.MaxPooling2D((2,2))(x)

    # ===== Block B (Residual) =====
    shortcut = layers.Conv2D(64, (1,1), padding="same")(x)

    x = layers.SeparableConv2D(64, (3,3), padding="same")(x)
    x = layers.ReLU()(x)
    x = layers.BatchNormalization()(x)

    x = layers.Add()([x, shortcut])
    x = layers.ReLU()(x)

    # ===== Block C =====
    x = layers.SeparableConv2D(128, (3,3), padding="same")(x)
    x = layers.ReLU()(x)
    x = layers.BatchNormalization()(x)

    x = layers.GlobalAveragePooling2D()(x)

    # ===== Dense Head =====
    x = layers.Dense(512, activation="relu")(x)
    x = layers.Dense(256, activation="relu")(x)
    x = layers.Dense(64, activation="relu")(x)
    x = layers.Dropout(0.5)(x)

    outputs = layers.Dense(1, activation="sigmoid")(x)

    model = models.Model(inputs, outputs)

    model.compile(
        optimizer=tf.keras.optimizers.Adam(1e-3),
        loss="binary_crossentropy",
        metrics=["accuracy"]
    )

    return model

# %%
train_data = np.load(os.path.join(BASE_PATHHASIL, "tow_ids_train_dwt.npz"))
test_data  = np.load(os.path.join(BASE_PATHHASIL, "tow_ids_test_dwt.npz"))
val_data   = np.load(os.path.join(BASE_PATHHASIL, "tow_ids_eval_dwt.npz"))

X_train = train_data["X"]
y_train = train_data["y"]

X_test  = test_data["X"]
y_test  = test_data["y"]

X_val   = val_data["X"]
y_val   = val_data["y"]

print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
print(X_val.shape, y_val.shape)
# Out:
# (6582, 64, 64, 3) (6582,)
# (6184, 64, 64, 3) (6184,)
# (2821, 64, 64, 3) (2821,)

# %%
tf.keras.backend.clear_session()

model = build_cnn_tow_ids()
model.summary()
# Out:
# I0000 00:00:1778984818.418942   23540 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 4144 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 64, 64, 3) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d    │ (None, 64, 64,    │        155 │ input_layer[0][0] │
# │ (SeparableConv2D)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu (ReLU)        │ (None, 64, 64,    │          0 │ separable_conv2d… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 64, 64,    │        128 │ re_lu[0][0]       │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_1  │ (None, 32, 32,    │      2,400 │ max_pooling2d[0]… │
# │ (SeparableConv2D)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_1 (ReLU)      │ (None, 32, 32,    │          0 │ separable_conv2d… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ re_lu_1[0][0]     │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 32, 32,    │      2,112 │ max_pooling2d[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 64)               │            │ conv2d[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_2 (ReLU)      │ (None, 32, 32,    │          0 │ add[0][0]         │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_2  │ (None, 32, 32,    │      8,896 │ re_lu_2[0][0]     │
# │ (SeparableConv2D)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_3 (ReLU)      │ (None, 32, 32,    │          0 │ separable_conv2d… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        512 │ re_lu_3[0][0]     │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 128)       │          0 │ batch_normalizat… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 512)       │     66,048 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 256)       │    131,328 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 64)        │     16,448 │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 64)        │          0 │ dense_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 1)         │         65 │ dropout[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 228,348 (891.98 KB)
#  Trainable params: 227,900 (890.23 KB)
#  Non-trainable params: 448 (1.75 KB)

# %% [markdown]
#  Total params: 228,348 (891.98 KB)
#  Trainable params: 227,900 (890.23 KB)
#  Non-trainable params: 448 (1.75 KB)

# %%
history = model.fit(
    X_train, y_train,
    epochs=50,
    batch_size=32,
    validation_data=(X_val, y_val),
    verbose=1,
    
)
# Out:
# Epoch 1/50
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1778984820.870721   23778 service.cc:152] XLA service 0x715108017d00 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1778984820.870745   23778 service.cc:160]   StreamExecutor device (0): NVIDIA GeForce RTX 3060 Laptop GPU, Compute Capability 8.6
# 2026-05-17 09:27:00.922157: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1778984821.274221   23778 cuda_dnn.cc:529] Loaded cuDNN version 91701
# 2026-05-17 09:27:02.489098: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1332_0', 44 bytes spill stores, 44 bytes spill loads
#
# 2026-05-17 09:27:02.817684: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1332', 484 bytes spill stores, 484 bytes spill loads
#
# 2026-05-17 09:27:03.857695: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2187', 32 bytes spill stores, 32 bytes spill loads
#
# 2026-05-17 09:27:04.085113: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2185', 36 bytes spill stores, 44 bytes spill loads
#
# 2026-05-17 09:27:04.403766: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2183', 36 bytes spill stores, 44 bytes spill loads
#
# 2026-05-17 09:27:04.429810: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2185', 32 bytes spill stores, 32 bytes spill loads
#
# 2026-05-17 09:27:04.477016: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2185', 32 bytes spill stores, 32 bytes spill loads
#
# I0000 00:00:1778984828.729983   23778 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 201/206 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step - accuracy: 0.8572 - loss: 0.3474
# 2026-05-17 09:27:11.273854: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1332_0', 36 bytes spill stores, 36 bytes spill loads
#
# 2026-05-17 09:27:12.049052: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1332', 488 bytes spill stores, 488 bytes spill loads
#
# 2026-05-17 09:27:13.503321: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2185', 32 bytes spill stores, 32 bytes spill loads
#
# 2026-05-17 09:27:14.239363: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2185', 28 bytes spill stores, 32 bytes spill loads
#
# 2026-05-17 09:27:14.326936: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2185', 32 bytes spill stores, 32 bytes spill loads
#
# 2026-05-17 09:27:14.532405: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2183', 28 bytes spill stores, 32 bytes spill loads
#
# 2026-05-17 09:27:14.542556: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2187', 32 bytes spill stores, 32 bytes spill loads
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.8585 - loss: 0.3448
# 2026-05-17 09:27:21.236993: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_151', 64 bytes spill stores, 64 bytes spill loads
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 25s 72ms/step - accuracy: 0.9098 - loss: 0.2389 - val_accuracy: 0.6856 - val_loss: 3.8138
# Epoch 2/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9711 - loss: 0.0972 - val_accuracy: 0.6856 - val_loss: 6.1719
# Epoch 3/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9766 - loss: 0.0753 - val_accuracy: 0.6866 - val_loss: 2.3948
# Epoch 4/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9775 - loss: 0.0694 - val_accuracy: 0.8040 - val_loss: 0.7266
# Epoch 5/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9810 - loss: 0.0662 - val_accuracy: 0.4101 - val_loss: 4.4387
# Epoch 6/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9842 - loss: 0.0589 - val_accuracy: 0.8529 - val_loss: 0.4103
# Epoch 7/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9839 - loss: 0.0550 - val_accuracy: 0.5172 - val_loss: 2.4574
# Epoch 8/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9839 - loss: 0.0546 - val_accuracy: 0.4899 - val_loss: 1.8901
# Epoch 9/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.9848 - loss: 0.0491 - val_accuracy: 0.7143 - val_loss: 0.7604
# Epoch 10/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9869 - loss: 0.0439 - val_accuracy: 0.4991 - val_loss: 2.0349
# Epoch 11/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9913 - loss: 0.0337 - val_accuracy: 0.6526 - val_loss: 1.3180
# Epoch 12/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9895 - loss: 0.0345 - val_accuracy: 0.4768 - val_loss: 2.6194
# Epoch 13/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9889 - loss: 0.0340 - val_accuracy: 0.9142 - val_loss: 0.3862
# Epoch 14/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9900 - loss: 0.0298 - val_accuracy: 0.3875 - val_loss: 6.1677
# Epoch 15/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9907 - loss: 0.0306 - val_accuracy: 0.3761 - val_loss: 4.1585
# Epoch 16/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9941 - loss: 0.0229 - val_accuracy: 0.6388 - val_loss: 1.7935
# Epoch 17/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9904 - loss: 0.0249 - val_accuracy: 0.4690 - val_loss: 3.2044
# Epoch 18/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9936 - loss: 0.0196 - val_accuracy: 0.8961 - val_loss: 0.3641
# Epoch 19/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9960 - loss: 0.0115 - val_accuracy: 0.8954 - val_loss: 0.3317
# Epoch 20/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9950 - loss: 0.0128 - val_accuracy: 0.9656 - val_loss: 0.1720
# Epoch 21/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9968 - loss: 0.0082 - val_accuracy: 0.5874 - val_loss: 1.2951
# Epoch 22/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9948 - loss: 0.0167 - val_accuracy: 0.9475 - val_loss: 0.2481
# Epoch 23/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9939 - loss: 0.0171 - val_accuracy: 0.7923 - val_loss: 1.2154
# Epoch 24/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9962 - loss: 0.0124 - val_accuracy: 0.9348 - val_loss: 0.3629
# Epoch 25/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9956 - loss: 0.0120 - val_accuracy: 0.9319 - val_loss: 0.4494
# Epoch 26/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9982 - loss: 0.0060 - val_accuracy: 0.6643 - val_loss: 1.7247
# Epoch 27/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9964 - loss: 0.0109 - val_accuracy: 0.8841 - val_loss: 0.4127
# Epoch 28/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9951 - loss: 0.0128 - val_accuracy: 0.6168 - val_loss: 1.3530
# Epoch 29/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9968 - loss: 0.0113 - val_accuracy: 0.9163 - val_loss: 0.5543
# Epoch 30/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9980 - loss: 0.0043 - val_accuracy: 0.6774 - val_loss: 2.1872
# Epoch 31/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9976 - loss: 0.0076 - val_accuracy: 0.8802 - val_loss: 0.9051
# Epoch 32/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9964 - loss: 0.0150 - val_accuracy: 0.9231 - val_loss: 0.3591
# Epoch 33/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9974 - loss: 0.0075 - val_accuracy: 0.9617 - val_loss: 0.2451
# Epoch 34/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9988 - loss: 0.0044 - val_accuracy: 0.9337 - val_loss: 0.2587
# Epoch 35/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9973 - loss: 0.0053 - val_accuracy: 0.5711 - val_loss: 4.7180
# Epoch 36/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9954 - loss: 0.0191 - val_accuracy: 0.8398 - val_loss: 0.6920
# Epoch 37/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9979 - loss: 0.0097 - val_accuracy: 0.8873 - val_loss: 0.3747
# Epoch 38/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9977 - loss: 0.0066 - val_accuracy: 0.9326 - val_loss: 0.2635
# Epoch 39/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9989 - loss: 0.0063 - val_accuracy: 0.8189 - val_loss: 0.8313
# Epoch 40/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9980 - loss: 0.0062 - val_accuracy: 0.6565 - val_loss: 1.4897
# Epoch 41/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9980 - loss: 0.0048 - val_accuracy: 0.6111 - val_loss: 2.1104
# Epoch 42/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9974 - loss: 0.0094 - val_accuracy: 0.4644 - val_loss: 3.6278
# Epoch 43/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9986 - loss: 0.0049 - val_accuracy: 0.3896 - val_loss: 16.8874
# Epoch 44/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9980 - loss: 0.0066 - val_accuracy: 0.8288 - val_loss: 1.0490
# Epoch 45/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9973 - loss: 0.0081 - val_accuracy: 0.6661 - val_loss: 2.2882
# Epoch 46/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9986 - loss: 0.0031 - val_accuracy: 0.6363 - val_loss: 3.0884
# Epoch 47/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9956 - loss: 0.0144 - val_accuracy: 0.4874 - val_loss: 2.7546
# Epoch 48/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9983 - loss: 0.0056 - val_accuracy: 0.9362 - val_loss: 0.2683
# Epoch 49/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9985 - loss: 0.0053 - val_accuracy: 0.7465 - val_loss: 1.8136
# Epoch 50/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - accuracy: 0.9977 - loss: 0.0067 - val_accuracy: 0.5005 - val_loss: 3.6767

# %%
# === TEST ===
test_loss, test_acc = model.evaluate(X_test, y_test, verbose=1)

print("\n=== TEST RESULT ===")
print("Loss :", test_loss)
print("Acc  :", test_acc)
# Out:
# 190/194 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9490 - loss: 0.2919
# 2026-05-17 09:28:42.258365: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_151', 64 bytes spill stores, 64 bytes spill loads
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 4s 23ms/step - accuracy: 0.8863 - loss: 0.6629
#
# === TEST RESULT ===
# Loss : 0.6629288196563721
# Acc  : 0.8863195180892944

# %% [markdown]
# Threshold 0.5

# %%
y_prob = model.predict(X_test)
y_pred = (y_prob >= 0.5).astype(int)
# Out:
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step

# %% [markdown]
# Confusion Matrix + Nilai Dasar

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, y_pred)
tn, fp, fn, tp = cm.ravel()

print("TP:", tp)
print("FP:", fp)
print("TN:", tn)
print("FN:", fn)
# Out:
# TP: 2385
# FP: 200
# TN: 3096
# FN: 503

# %% [markdown]
# Hitung Semua Metric Sesuai Persamaan Paper

# %%
accuracy  = (tp + tn) / (tp + tn + fp + fn)
recall    = tp / (tp + fn)
precision = tp / (tp + fp)
fmeasure  = 2 * precision * recall / (precision + recall)

print("\n=== Metrics (Threshold 0.5) ===")
print(f"Accuracy : {accuracy:.6f}")
print(f"Recall   : {recall:.6f}")
print(f"Precision: {precision:.6f}")
print(f"F-measure: {fmeasure:.6f}")
# Out:
# === Metrics (Threshold 0.5) ===
# Accuracy : 0.886320
# Recall   : 0.825831
# Precision: 0.922631
# F-measure: 0.871551

# %%
# === Confusion values sudah ada ===
# tp, tn, fp, fn

accuracy  = (tp + tn) / (tp + tn + fp + fn)
recall    = tp / (tp + fn + 1e-12)
precision = tp / (tp + fp + 1e-12)
f1        = 2 * precision * recall / (precision + recall + 1e-12)

# tambahan
fpr = fp / (fp + tn + 1e-12)
fnr = fn / (fn + tp + 1e-12)

print("\n=== Metrics (Threshold 0.5) ===")
print(f"Accuracy  : {accuracy:.6f}")
print(f"Precision : {precision:.6f}")
print(f"Recall    : {recall:.6f}")
print(f"F1        : {f1:.6f}")
print(f"FPR       : {fpr:.6f}")
print(f"FNR       : {fnr:.6f}")
print(f"FP        : {fp}")
print(f"FN        : {fn}")
# Out:
# === Metrics (Threshold 0.5) ===
# Accuracy  : 0.886320
# Precision : 0.922631
# Recall    : 0.825831
# F1        : 0.871551
# FPR       : 0.060680
# FNR       : 0.174169
# FP        : 200
# FN        : 503

# %% [markdown]
# === Metrics (Threshold 0.5) ===
# Accuracy  : 0.981726
# Precision : 0.968790
# Recall    : 0.992911
# F1        : 0.980702
# FPR       : 0.028101
# FNR       : 0.007089
# FP        : 370
# FN        : 82

# %% [markdown]
# ROC Curve + AUC (Persamaan 13)

# %%
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

fpr, tpr, thresholds = roc_curve(y_test, y_prob)
roc_auc = auc(fpr, tpr)

print(f"AUC: {roc_auc:.6f}")
# Out:
# AUC: 0.949780

# %% [markdown]
# Plot ROC

# %%
plt.figure(figsize=(6,5))
plt.plot(fpr, tpr, label=f"AUC = {roc_auc:.4f}")
plt.plot([0,1], [0,1], linestyle='--')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve - TOW IDS CNN")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# Plot Confusion Matrix

# %%
import seaborn as sns

plt.figure(figsize=(5,4))
sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    cmap="Blues",
    xticklabels=["Normal", "Attack"],
    yticklabels=["Normal", "Attack"]
)
plt.xlabel("Predicted")                                                                                         
plt.ylabel("Actual")
plt.title("Confusion Matrix (Threshold=0.5)")
plt.show()

# %% [markdown]
# Plot Confusion Matrix

# %%
plt.figure(figsize=(5,4))
plt.bar(["False Positive", "False Negative"], [fp, fn])
plt.title("FP vs FN")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# Plot FP vs FN

# %%
import numpy as np

youden_index = tpr - fpr
best_idx = np.argmax(youden_index)
best_threshold = thresholds[best_idx]

print("Best Threshold (Youden):", best_threshold)
# Out:
# Best Threshold (Youden): 0.73379344

# %%
youden_index = tpr - fpr
best_idx = np.argmax(youden_index)
best_threshold = thresholds[best_idx]

print("Best Threshold:", best_threshold)
# Out:
# Best Threshold: 0.73379344

# %%
y_pred_opt = (y_prob >= best_threshold).astype(int)

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, y_pred_opt)
tn, fp, fn, tp = cm.ravel()

# %%
accuracy  = (tp + tn) / (tp + tn + fp + fn)
recall    = tp / (tp + fn)
precision = tp / (tp + fp)
fmeasure  = 2 * precision * recall / (precision + recall)

print("\n=== Metrics BEST THRESHOLD ===")
print(f"Accuracy : {accuracy:.6f}")
print(f"Recall   : {recall:.6f}")
print(f"Precision: {precision:.6f}")
print(f"F-measure: {fmeasure:.6f}")
# Out:
# === Metrics BEST THRESHOLD ===
# Accuracy : 0.889230
# Recall   : 0.816828
# Precision: 0.937972
# F-measure: 0.873219

# %% [markdown]
# Threshold Optimization (Youden Index)

# %%
y_pred_opt = (y_prob >= best_threshold).astype(int)
cm_opt = confusion_matrix(y_test, y_pred_opt)

tn2, fp2, fn2, tp2 = cm_opt.ravel()

acc_opt = (tp2 + tn2) / (tp2 + tn2 + fp2 + fn2)

print("\nAccuracy Optimal:", acc_opt)
# Out:
# Accuracy Optimal: 0.8892302716688227

# %% [markdown]
# Detection Speed

# %%
import time

start = time.time()
_ = model.predict(X_test[:256])
latency = (time.time() - start) / 256

print("Inference time per sample:", latency)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Inference time per sample: 0.0003880513831973076
