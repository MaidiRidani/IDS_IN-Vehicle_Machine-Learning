# %%
import numpy as np
import os
import gc
import time
import matplotlib.pyplot as plt
import seaborn as sns

import tensorflow as tf
from tensorflow.keras import layers, models

from sklearn.metrics import (
    confusion_matrix,
    classification_report,
    roc_curve,
    auc,
    precision_recall_curve,
    f1_score
)
# Out:
# 2026-05-17 09:34:25.881947: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-05-17 09:34:25.892172: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1778985265.904627   37240 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1778985265.908464   37240 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1778985265.918074   37240 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1778985265.918091   37240 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1778985265.918092   37240 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1778985265.918093   37240 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-05-17 09:34:25.921631: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
import numpy as np
import os
import gc
import time
import matplotlib.pyplot as plt
import seaborn as sns

import tensorflow as tf
from tensorflow.keras import layers, models

from sklearn.metrics import (
    confusion_matrix,
    classification_report,
    roc_curve,
    auc,
    precision_recall_curve,
    f1_score
)

# %%
BASE_PATHHASIL = "/home/dani/Documents/tugas akhir/TugasAkhir/codeTugasAkhirku2026/tow_ids/Preprocessing/Preprocessingbaru/imgsize64/norm/dwt/"

# %%
import tensorflow as tf
from tensorflow.keras import layers, models

def build_cnn_tow_ids():

    inputs = layers.Input(shape=(32, 32, 3))

    # ===== Block A =====
    x = layers.SeparableConv2D(32, (3,3), padding="same")(inputs)
    x = layers.ReLU()(x)
    x = layers.BatchNormalization()(x)
    x = layers.MaxPooling2D((2,2))(x)

    # ===== Block B (Residual) =====
    shortcut = layers.Conv2D(64, (1,1), padding="same")(x)

    x = layers.SeparableConv2D(64, (3,3), padding="same")(x)
    x = layers.ReLU()(x)
    x = layers.BatchNormalization()(x)

    x = layers.Add()([x, shortcut])
    x = layers.ReLU()(x)

    # ===== Block C =====
    x = layers.SeparableConv2D(128, (3,3), padding="same")(x)
    x = layers.ReLU()(x)
    x = layers.BatchNormalization()(x)

    x = layers.GlobalAveragePooling2D()(x)

    # ===== Dense Head =====
    x = layers.Dense(512, activation="relu")(x)
    x = layers.Dense(256, activation="relu")(x)
    x = layers.Dense(64, activation="relu")(x)
    x = layers.Dropout(0.5)(x)

    outputs = layers.Dense(1, activation="sigmoid")(x)

    model = models.Model(inputs, outputs)

    model.compile(
        optimizer=tf.keras.optimizers.Adam(1e-3),
        loss="binary_crossentropy",
        metrics=["accuracy"]
    )

    return model

# %%
train_data = np.load(os.path.join(BASE_PATHHASIL, "tow_ids_train_dwt.npz"))
test_data  = np.load(os.path.join(BASE_PATHHASIL, "tow_ids_test_dwt.npz"))
val_data   = np.load(os.path.join(BASE_PATHHASIL, "tow_ids_eval_dwt.npz"))

X_train = train_data["X"]
y_train = train_data["y"]

X_test  = test_data["X"]
y_test  = test_data["y"]

X_val   = val_data["X"]
y_val   = val_data["y"]

print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
print(X_val.shape, y_val.shape)
# Out:
# (13165, 32, 32, 3) (13165,)
# (12368, 32, 32, 3) (12368,)
# (5642, 32, 32, 3) (5642,)

# %%
tf.keras.backend.clear_session()

model = build_cnn_tow_ids()
model.summary()
# Out:
# I0000 00:00:1778985267.565785   37240 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 4144 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 32, 32, 3) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d    │ (None, 32, 32,    │        155 │ input_layer[0][0] │
# │ (SeparableConv2D)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu (ReLU)        │ (None, 32, 32,    │          0 │ separable_conv2d… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 32, 32,    │        128 │ re_lu[0][0]       │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_1  │ (None, 16, 16,    │      2,400 │ max_pooling2d[0]… │
# │ (SeparableConv2D)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_1 (ReLU)      │ (None, 16, 16,    │          0 │ separable_conv2d… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        256 │ re_lu_1[0][0]     │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 16, 16,    │      2,112 │ max_pooling2d[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 64)               │            │ conv2d[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_2 (ReLU)      │ (None, 16, 16,    │          0 │ add[0][0]         │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_2  │ (None, 16, 16,    │      8,896 │ re_lu_2[0][0]     │
# │ (SeparableConv2D)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_3 (ReLU)      │ (None, 16, 16,    │          0 │ separable_conv2d… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        512 │ re_lu_3[0][0]     │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 128)       │          0 │ batch_normalizat… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 512)       │     66,048 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 256)       │    131,328 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 64)        │     16,448 │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 64)        │          0 │ dense_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 1)         │         65 │ dropout[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 228,348 (891.98 KB)
#  Trainable params: 227,900 (890.23 KB)
#  Non-trainable params: 448 (1.75 KB)

# %% [markdown]
#  Total params: 228,348 (891.98 KB)
#  227,900

# %%
history = model.fit(
    X_train, y_train,
    epochs=50,
    batch_size=32,
    validation_data=(X_val, y_val),
    verbose=1,
    
)
# Out:
# Epoch 1/50
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1778985269.985020   37373 service.cc:152] XLA service 0x760a90028fe0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1778985269.985040   37373 service.cc:160]   StreamExecutor device (0): NVIDIA GeForce RTX 3060 Laptop GPU, Compute Capability 8.6
# 2026-05-17 09:34:30.041693: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1778985270.390509   37373 cuda_dnn.cc:529] Loaded cuDNN version 91701
# 2026-05-17 09:34:31.630485: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1332_0', 44 bytes spill stores, 44 bytes spill loads
#
# 2026-05-17 09:34:32.810988: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1332', 484 bytes spill stores, 484 bytes spill loads
#
# 2026-05-17 09:34:33.402042: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2183', 36 bytes spill stores, 44 bytes spill loads
#
# 2026-05-17 09:34:33.582367: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2185', 32 bytes spill stores, 32 bytes spill loads
#
# 2026-05-17 09:34:34.054001: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2185', 36 bytes spill stores, 44 bytes spill loads
#
# 2026-05-17 09:34:34.115655: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2185', 32 bytes spill stores, 32 bytes spill loads
#
# 2026-05-17 09:34:34.172753: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2187', 32 bytes spill stores, 32 bytes spill loads
#
# I0000 00:00:1778985277.654708   37373 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 404/412 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9055 - loss: 0.2343
# 2026-05-17 09:34:41.341965: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1332', 64 bytes spill stores, 64 bytes spill loads
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9064 - loss: 0.2324
# 2026-05-17 09:34:48.783232: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_151', 64 bytes spill stores, 64 bytes spill loads
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 23s 32ms/step - accuracy: 0.9532 - loss: 0.1335 - val_accuracy: 0.6434 - val_loss: 4.5542
# Epoch 2/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9774 - loss: 0.0714 - val_accuracy: 0.9438 - val_loss: 0.1767
# Epoch 3/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9811 - loss: 0.0614 - val_accuracy: 0.6978 - val_loss: 0.8277
# Epoch 4/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9841 - loss: 0.0493 - val_accuracy: 0.9603 - val_loss: 0.1230
# Epoch 5/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9860 - loss: 0.0440 - val_accuracy: 0.7246 - val_loss: 0.7765
# Epoch 6/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9874 - loss: 0.0405 - val_accuracy: 0.9201 - val_loss: 0.2480
# Epoch 7/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9899 - loss: 0.0352 - val_accuracy: 0.8756 - val_loss: 0.4568
# Epoch 8/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9897 - loss: 0.0332 - val_accuracy: 0.5395 - val_loss: 2.3348
# Epoch 9/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9905 - loss: 0.0312 - val_accuracy: 0.8391 - val_loss: 0.4740
# Epoch 10/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9910 - loss: 0.0294 - val_accuracy: 0.9264 - val_loss: 0.2248
# Epoch 11/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9913 - loss: 0.0293 - val_accuracy: 0.9227 - val_loss: 0.2769
# Epoch 12/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9942 - loss: 0.0204 - val_accuracy: 0.9752 - val_loss: 0.1452
# Epoch 13/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9924 - loss: 0.0267 - val_accuracy: 0.8882 - val_loss: 0.4252
# Epoch 14/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9922 - loss: 0.0240 - val_accuracy: 0.9599 - val_loss: 0.1243
# Epoch 15/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9932 - loss: 0.0208 - val_accuracy: 0.8424 - val_loss: 0.8702
# Epoch 16/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9942 - loss: 0.0160 - val_accuracy: 0.9633 - val_loss: 0.1354
# Epoch 17/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9945 - loss: 0.0183 - val_accuracy: 0.8827 - val_loss: 0.9416
# Epoch 18/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9938 - loss: 0.0175 - val_accuracy: 0.9069 - val_loss: 0.3793
# Epoch 19/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9953 - loss: 0.0155 - val_accuracy: 0.8692 - val_loss: 0.6035
# Epoch 20/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9957 - loss: 0.0121 - val_accuracy: 0.9754 - val_loss: 0.1218
# Epoch 21/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9956 - loss: 0.0129 - val_accuracy: 0.5170 - val_loss: 5.6035
# Epoch 22/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9948 - loss: 0.0144 - val_accuracy: 0.9488 - val_loss: 0.3574
# Epoch 23/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9958 - loss: 0.0135 - val_accuracy: 0.9752 - val_loss: 0.1199
# Epoch 24/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9976 - loss: 0.0073 - val_accuracy: 0.8006 - val_loss: 2.3100
# Epoch 25/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9948 - loss: 0.0150 - val_accuracy: 0.7870 - val_loss: 0.8653
# Epoch 26/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9967 - loss: 0.0117 - val_accuracy: 0.9467 - val_loss: 0.4566
# Epoch 27/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9949 - loss: 0.0159 - val_accuracy: 0.9264 - val_loss: 0.1993
# Epoch 28/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9970 - loss: 0.0085 - val_accuracy: 0.9429 - val_loss: 0.1693
# Epoch 29/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9960 - loss: 0.0114 - val_accuracy: 0.8878 - val_loss: 0.3359
# Epoch 30/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9964 - loss: 0.0114 - val_accuracy: 0.8346 - val_loss: 1.0813
# Epoch 31/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9973 - loss: 0.0090 - val_accuracy: 0.8967 - val_loss: 0.8096
# Epoch 32/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9971 - loss: 0.0108 - val_accuracy: 0.5931 - val_loss: 2.6232
# Epoch 33/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9974 - loss: 0.0084 - val_accuracy: 0.9614 - val_loss: 0.2136
# Epoch 34/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9970 - loss: 0.0079 - val_accuracy: 0.9601 - val_loss: 0.2514
# Epoch 35/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9973 - loss: 0.0072 - val_accuracy: 0.9731 - val_loss: 0.1408
# Epoch 36/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9961 - loss: 0.0128 - val_accuracy: 0.8708 - val_loss: 0.9631
# Epoch 37/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9975 - loss: 0.0083 - val_accuracy: 0.9741 - val_loss: 0.2022
# Epoch 38/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9980 - loss: 0.0070 - val_accuracy: 0.9433 - val_loss: 0.2345
# Epoch 39/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9978 - loss: 0.0065 - val_accuracy: 0.9729 - val_loss: 0.1380
# Epoch 40/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9974 - loss: 0.0085 - val_accuracy: 0.5046 - val_loss: 5.4226
# Epoch 41/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9956 - loss: 0.0167 - val_accuracy: 0.8447 - val_loss: 1.0626
# Epoch 42/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9973 - loss: 0.0081 - val_accuracy: 0.4913 - val_loss: 8.8609
# Epoch 43/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9973 - loss: 0.0063 - val_accuracy: 0.9075 - val_loss: 0.6884
# Epoch 44/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9978 - loss: 0.0074 - val_accuracy: 0.9332 - val_loss: 0.5038
# Epoch 45/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9978 - loss: 0.0088 - val_accuracy: 0.9404 - val_loss: 0.5541
# Epoch 46/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9967 - loss: 0.0081 - val_accuracy: 0.9564 - val_loss: 0.2574
# Epoch 47/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9979 - loss: 0.0073 - val_accuracy: 0.9651 - val_loss: 0.1208
# Epoch 48/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9981 - loss: 0.0052 - val_accuracy: 0.9741 - val_loss: 0.1778
# Epoch 49/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9983 - loss: 0.0053 - val_accuracy: 0.9273 - val_loss: 0.5072
# Epoch 50/50
# 412/412 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - accuracy: 0.9983 - loss: 0.0034 - val_accuracy: 0.9389 - val_loss: 0.5344

# %% [markdown]
# Threshold 0.5

# %%
# === TEST ===
test_loss, test_acc = model.evaluate(X_test, y_test, verbose=1)

print("\n=== TEST RESULT ===")
print("Loss :", test_loss)
print("Acc  :", test_acc)
# Out:
# 364/387 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8742 - loss: 1.2714
# 2026-05-17 09:36:09.648047: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_151', 52 bytes spill stores, 52 bytes spill loads
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.8989 - loss: 0.9631
#
# === TEST RESULT ===
# Loss : 0.9630549550056458
# Acc  : 0.8989327549934387

# %%
y_prob = model.predict(X_test)
y_pred = (y_prob >= 0.5).astype(int)
# Out:
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step

# %% [markdown]
# Confusion Matrix + Nilai Dasar

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, y_pred)
tn, fp, fn, tp = cm.ravel()

print("TP:", tp)
print("FP:", fp)
print("TN:", tn)
print("FN:", fn)
# Out:
# TP: 4423
# FP: 151
# TN: 6695
# FN: 1099

# %% [markdown]
# Hitung Semua Metric Sesuai Persamaan Paper

# %%
accuracy  = (tp + tn) / (tp + tn + fp + fn)
recall    = tp / (tp + fn)
precision = tp / (tp + fp)
fmeasure  = 2 * precision * recall / (precision + recall)

print("\n=== Metrics (Threshold 0.5) ===")
print(f"Accuracy : {accuracy:.6f}")
print(f"Recall   : {recall:.6f}")
print(f"Precision: {precision:.6f}")
print(f"F-measure: {fmeasure:.6f}")
# Out:
# === Metrics (Threshold 0.5) ===
# Accuracy : 0.898933
# Recall   : 0.800978
# Precision: 0.966987
# F-measure: 0.876189

# %%
# === Confusion values sudah ada ===
# tp, tn, fp, fn

accuracy  = (tp + tn) / (tp + tn + fp + fn)
recall    = tp / (tp + fn + 1e-12)
precision = tp / (tp + fp + 1e-12)
f1        = 2 * precision * recall / (precision + recall + 1e-12)

# tambahan
fpr = fp / (fp + tn + 1e-12)
fnr = fn / (fn + tp + 1e-12)

print("\n=== Metrics (Threshold 0.5) ===")
print(f"Accuracy  : {accuracy:.6f}")
print(f"Precision : {precision:.6f}")
print(f"Recall    : {recall:.6f}")
print(f"F1        : {f1:.6f}")
print(f"FPR       : {fpr:.6f}")
print(f"FNR       : {fnr:.6f}")
print(f"FP        : {fp}")
print(f"FN        : {fn}")
# Out:
# === Metrics (Threshold 0.5) ===
# Accuracy  : 0.898933
# Precision : 0.966987
# Recall    : 0.800978
# F1        : 0.876189
# FPR       : 0.022057
# FNR       : 0.199022
# FP        : 151
# FN        : 1099

# %% [markdown]
# === Metrics (Threshold 0.5) ===
# Accuracy  : 0.955207
# Precision : 0.939981
# Recall    : 0.961081
# F1        : 0.950414
# FPR       : 0.049534
# FNR       : 0.038919
# FP        : 1356
# FN        : 860

# %% [markdown]
# ROC Curve + AUC (Persamaan 13)

# %%
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

fpr, tpr, thresholds = roc_curve(y_test, y_prob)
roc_auc = auc(fpr, tpr)

print(f"AUC: {roc_auc:.6f}")
# Out:
# AUC: 0.943942

# %% [markdown]
# Plot ROC

# %%
plt.figure(figsize=(6,5))
plt.plot(fpr, tpr, label=f"AUC = {roc_auc:.4f}")
plt.plot([0,1], [0,1], linestyle='--')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve - TOW IDS CNN")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# Plot Confusion Matrix

# %%
import seaborn as sns

plt.figure(figsize=(5,4))
sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    cmap="Blues",
    xticklabels=["Normal", "Attack"],
    yticklabels=["Normal", "Attack"]
)
plt.xlabel("Predicted")                                                                                         
plt.ylabel("Actual")
plt.title("Confusion Matrix (Threshold=0.5)")
plt.show()

# %% [markdown]
# Plot Confusion Matrix

# %%
plt.figure(figsize=(5,4))
plt.bar(["False Positive", "False Negative"], [fp, fn])
plt.title("FP vs FN")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# Plot FP vs FN

# %%
import numpy as np

youden_index = tpr - fpr
best_idx = np.argmax(youden_index)
best_threshold = thresholds[best_idx]

print("Best Threshold (Youden):", best_threshold)
# Out:
# Best Threshold (Youden): 0.059618026

# %%
youden_index = tpr - fpr
best_idx = np.argmax(youden_index)
best_threshold = thresholds[best_idx]

print("Best Threshold:", best_threshold)
# Out:
# Best Threshold: 0.059618026

# %%
y_pred_opt = (y_prob >= best_threshold).astype(int)

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, y_pred_opt)
tn, fp, fn, tp = cm.ravel()

# %% [markdown]
# Threshold Optimization (Youden Index)

# %%
accuracy  = (tp + tn) / (tp + tn + fp + fn)
recall    = tp / (tp + fn)
precision = tp / (tp + fp)
fmeasure  = 2 * precision * recall / (precision + recall)

print("\n=== Metrics BEST THRESHOLD ===")
print(f"Accuracy : {accuracy:.6f}")
print(f"Recall   : {recall:.6f}")
print(f"Precision: {precision:.6f}")
print(f"F-measure: {fmeasure:.6f}")
# Out:
# === Metrics BEST THRESHOLD ===
# Accuracy : 0.898609
# Recall   : 0.842267
# Precision: 0.923917
# F-measure: 0.881205

# %% [markdown]
# Detection Speed

# %%
import time

start = time.time()
_ = model.predict(X_test[:256])
latency = (time.time() - start) / 256

print("Inference time per sample:", latency)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# Inference time per sample: 0.00029704347252845764
