# %%
import numpy as np
import os
import gc
import time
import matplotlib.pyplot as plt
import seaborn as sns

import tensorflow as tf
from tensorflow.keras import layers, models

from sklearn.metrics import (
    confusion_matrix,
    classification_report,
    roc_curve,
    auc,
    precision_recall_curve,
    f1_score
)
# Out:
# 2026-05-17 09:06:08.741168: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-05-17 09:06:08.848387: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1778983568.894869    8690 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1778983568.908658    8690 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1778983569.003252    8690 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1778983569.003292    8690 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1778983569.003296    8690 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1778983569.003299    8690 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-05-17 09:06:09.016157: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
import numpy as np
import os
import gc
import time
import matplotlib.pyplot as plt
import seaborn as sns

import tensorflow as tf
from tensorflow.keras import layers, models

from sklearn.metrics import (
    confusion_matrix,
    classification_report,
    roc_curve,
    auc,
    precision_recall_curve,
    f1_score
)

# %%
BASE_PATHHASIL = "/home/dani/Documents/tugas akhir/TugasAkhir/codeTugasAkhirku2026/tow_ids/Preprocessing/Preprocessingbaru/imgsize256/norm/dwt/"

# %%
import tensorflow as tf
from tensorflow.keras import layers, models

def build_cnn_tow_ids():

    inputs = layers.Input(shape=(128, 128, 3))

    # ===== Block A =====
    x = layers.SeparableConv2D(32, (3,3), padding="same")(inputs)
    x = layers.ReLU()(x)
    x = layers.BatchNormalization()(x)
    x = layers.MaxPooling2D((2,2))(x)

    # ===== Block B (Residual) =====
    shortcut = layers.Conv2D(64, (1,1), padding="same")(x)

    x = layers.SeparableConv2D(64, (3,3), padding="same")(x)
    x = layers.ReLU()(x)
    x = layers.BatchNormalization()(x)

    x = layers.Add()([x, shortcut])
    x = layers.ReLU()(x)

    # ===== Block C =====
    x = layers.SeparableConv2D(128, (3,3), padding="same")(x)
    x = layers.ReLU()(x)
    x = layers.BatchNormalization()(x)

    x = layers.GlobalAveragePooling2D()(x)

    # ===== Dense Head =====
    x = layers.Dense(512, activation="relu")(x)
    x = layers.Dense(256, activation="relu")(x)
    x = layers.Dense(64, activation="relu")(x)
    x = layers.Dropout(0.5)(x)

    outputs = layers.Dense(1, activation="sigmoid")(x)

    model = models.Model(inputs, outputs)

    model.compile(
        optimizer=tf.keras.optimizers.Adam(1e-3),
        loss="binary_crossentropy",
        metrics=["accuracy"]
    )

    return model

# %%
train_data = np.load(os.path.join(BASE_PATHHASIL, "tow_ids_train_dwt.npz"))
test_data  = np.load(os.path.join(BASE_PATHHASIL, "tow_ids_test_dwt.npz"))
val_data   = np.load(os.path.join(BASE_PATHHASIL, "tow_ids_eval_dwt.npz"))

X_train = train_data["X"]
y_train = train_data["y"]

X_test  = test_data["X"]
y_test  = test_data["y"]

X_val   = val_data["X"]
y_val   = val_data["y"]

print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
print(X_val.shape, y_val.shape)
# Out:
# (3291, 128, 128, 3) (3291,)
# (3092, 128, 128, 3) (3092,)
# (1410, 128, 128, 3) (1410,)

# %%
tf.keras.backend.clear_session()

model = build_cnn_tow_ids()
model.summary()
# Out:
# I0000 00:00:1778983574.313962    8690 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 4144 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 128, 128,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d    │ (None, 128, 128,  │        155 │ input_layer[0][0] │
# │ (SeparableConv2D)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu (ReLU)        │ (None, 128, 128,  │          0 │ separable_conv2d… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 128, 128,  │        128 │ re_lu[0][0]       │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_1  │ (None, 64, 64,    │      2,400 │ max_pooling2d[0]… │
# │ (SeparableConv2D)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_1 (ReLU)      │ (None, 64, 64,    │          0 │ separable_conv2d… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        256 │ re_lu_1[0][0]     │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 64, 64,    │      2,112 │ max_pooling2d[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 64)               │            │ conv2d[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_2 (ReLU)      │ (None, 64, 64,    │          0 │ add[0][0]         │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_2  │ (None, 64, 64,    │      8,896 │ re_lu_2[0][0]     │
# │ (SeparableConv2D)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_3 (ReLU)      │ (None, 64, 64,    │          0 │ separable_conv2d… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        512 │ re_lu_3[0][0]     │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 128)       │          0 │ batch_normalizat… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 512)       │     66,048 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 256)       │    131,328 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 64)        │     16,448 │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 64)        │          0 │ dense_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 1)         │         65 │ dropout[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 228,348 (891.98 KB)
#  Trainable params: 227,900 (890.23 KB)
#  Non-trainable params: 448 (1.75 KB)

# %%
history = model.fit(
    X_train, y_train,
    epochs=50,
    batch_size=32,
    validation_data=(X_val, y_val),
    verbose=1,
    
)
# Out:
# Epoch 1/50
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1778983577.174328    8844 service.cc:152] XLA service 0x77fa14013af0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1778983577.174345    8844 service.cc:160]   StreamExecutor device (0): NVIDIA GeForce RTX 3060 Laptop GPU, Compute Capability 8.6
# 2026-05-17 09:06:17.235048: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1778983577.680501    8844 cuda_dnn.cc:529] Loaded cuDNN version 91701
# 2026-05-17 09:06:19.850613: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2185', 32 bytes spill stores, 32 bytes spill loads
#
# 2026-05-17 09:06:19.865146: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1332_0', 44 bytes spill stores, 44 bytes spill loads
#
# 2026-05-17 09:06:20.017049: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1332', 484 bytes spill stores, 484 bytes spill loads
#
# 2026-05-17 09:06:20.076293: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2183', 36 bytes spill stores, 44 bytes spill loads
#
# 2026-05-17 09:06:20.624995: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2185', 36 bytes spill stores, 44 bytes spill loads
#
# 2026-05-17 09:06:20.862222: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2185', 32 bytes spill stores, 32 bytes spill loads
#
# 2026-05-17 09:06:21.261113: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2187', 32 bytes spill stores, 32 bytes spill loads
#
# I0000 00:00:1778983587.248683    8844 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 100/103 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8819 - loss: 0.3214
# 2026-05-17 09:06:31.084910: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2187', 32 bytes spill stores, 32 bytes spill loads
#
# 2026-05-17 09:06:31.491299: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1332_0', 36 bytes spill stores, 36 bytes spill loads
#
# 2026-05-17 09:06:31.694310: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1332', 488 bytes spill stores, 488 bytes spill loads
#
# 2026-05-17 09:06:32.647728: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2185', 32 bytes spill stores, 32 bytes spill loads
#
# 2026-05-17 09:06:33.580412: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2185', 32 bytes spill stores, 32 bytes spill loads
#
# 2026-05-17 09:06:33.723089: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2183', 28 bytes spill stores, 32 bytes spill loads
#
# 2026-05-17 09:06:33.848561: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2185', 28 bytes spill stores, 32 bytes spill loads
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 114ms/step - accuracy: 0.8831 - loss: 0.3185
# 2026-05-17 09:06:42.562882: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_151', 64 bytes spill stores, 64 bytes spill loads
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 29s 165ms/step - accuracy: 0.9210 - loss: 0.2206 - val_accuracy: 0.7291 - val_loss: 1.0069
# Epoch 2/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.9562 - loss: 0.1400 - val_accuracy: 0.7291 - val_loss: 3.1793
# Epoch 3/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.9714 - loss: 0.0902 - val_accuracy: 0.7291 - val_loss: 3.0161
# Epoch 4/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.9812 - loss: 0.0750 - val_accuracy: 0.7291 - val_loss: 5.1334
# Epoch 5/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.9918 - loss: 0.0321 - val_accuracy: 0.7291 - val_loss: 5.6467
# Epoch 6/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.9960 - loss: 0.0192 - val_accuracy: 0.7291 - val_loss: 4.5031
# Epoch 7/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.9951 - loss: 0.0215 - val_accuracy: 0.9879 - val_loss: 0.0399
# Epoch 8/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.9930 - loss: 0.0243 - val_accuracy: 0.9858 - val_loss: 0.0398
# Epoch 9/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.9970 - loss: 0.0157 - val_accuracy: 0.9461 - val_loss: 0.1425
# Epoch 10/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.9933 - loss: 0.0203 - val_accuracy: 0.9504 - val_loss: 0.2039
# Epoch 11/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.9964 - loss: 0.0157 - val_accuracy: 0.9915 - val_loss: 0.0283
# Epoch 12/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.9964 - loss: 0.0115 - val_accuracy: 0.9816 - val_loss: 0.0686
# Epoch 13/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.9985 - loss: 0.0073 - val_accuracy: 0.9851 - val_loss: 0.0631
# Epoch 14/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.9924 - loss: 0.0283 - val_accuracy: 0.9936 - val_loss: 0.0156
# Epoch 15/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.9967 - loss: 0.0118 - val_accuracy: 0.9333 - val_loss: 0.2593
# Epoch 16/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.9967 - loss: 0.0144 - val_accuracy: 0.9887 - val_loss: 0.0410
# Epoch 17/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.9976 - loss: 0.0086 - val_accuracy: 0.9766 - val_loss: 0.0780
# Epoch 18/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.9979 - loss: 0.0068 - val_accuracy: 0.8695 - val_loss: 0.3023
# Epoch 19/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.9982 - loss: 0.0076 - val_accuracy: 0.9950 - val_loss: 0.0195
# Epoch 20/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.9964 - loss: 0.0131 - val_accuracy: 0.7291 - val_loss: 2.1500
# Epoch 21/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.9964 - loss: 0.0119 - val_accuracy: 0.8447 - val_loss: 0.8325
# Epoch 22/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.9939 - loss: 0.0189 - val_accuracy: 0.9929 - val_loss: 0.0160
# Epoch 23/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.9982 - loss: 0.0055 - val_accuracy: 0.9894 - val_loss: 0.0630
# Epoch 24/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.9967 - loss: 0.0147 - val_accuracy: 0.9674 - val_loss: 0.1203
# Epoch 25/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.9976 - loss: 0.0064 - val_accuracy: 0.9624 - val_loss: 0.1350
# Epoch 26/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.9979 - loss: 0.0092 - val_accuracy: 0.9064 - val_loss: 0.3593
# Epoch 27/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.9985 - loss: 0.0040 - val_accuracy: 0.9943 - val_loss: 0.0280
# Epoch 28/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.9976 - loss: 0.0054 - val_accuracy: 0.9929 - val_loss: 0.0365
# Epoch 29/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.9991 - loss: 0.0020 - val_accuracy: 0.9901 - val_loss: 0.0422
# Epoch 30/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.9982 - loss: 0.0072 - val_accuracy: 0.9199 - val_loss: 0.3470
# Epoch 31/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.9964 - loss: 0.0121 - val_accuracy: 0.8156 - val_loss: 0.8467
# Epoch 32/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.9964 - loss: 0.0138 - val_accuracy: 0.9426 - val_loss: 0.2277
# Epoch 33/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.9973 - loss: 0.0123 - val_accuracy: 0.9908 - val_loss: 0.0352
# Epoch 34/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.9960 - loss: 0.0079 - val_accuracy: 0.9787 - val_loss: 0.0497
# Epoch 35/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.9973 - loss: 0.0104 - val_accuracy: 0.9965 - val_loss: 0.0074
# Epoch 36/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.9991 - loss: 0.0032 - val_accuracy: 0.9957 - val_loss: 0.0126
# Epoch 37/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.9979 - loss: 0.0038 - val_accuracy: 0.9603 - val_loss: 0.1164
# Epoch 38/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.9985 - loss: 0.0062 - val_accuracy: 0.9823 - val_loss: 0.0820
# Epoch 39/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.9991 - loss: 0.0037 - val_accuracy: 0.9950 - val_loss: 0.0202
# Epoch 40/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.9976 - loss: 0.0061 - val_accuracy: 0.8532 - val_loss: 0.2159
# Epoch 41/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.9970 - loss: 0.0116 - val_accuracy: 0.5660 - val_loss: 1.4396
# Epoch 42/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.9976 - loss: 0.0074 - val_accuracy: 0.9170 - val_loss: 0.4840
# Epoch 43/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.9997 - loss: 6.7910e-04 - val_accuracy: 0.9965 - val_loss: 0.0051
# Epoch 44/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 20ms/step - accuracy: 0.9997 - loss: 7.8183e-04 - val_accuracy: 0.9972 - val_loss: 0.0164
# Epoch 45/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.9985 - loss: 0.0029 - val_accuracy: 0.7227 - val_loss: 4.5134
# Epoch 46/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.9954 - loss: 0.0179 - val_accuracy: 0.9092 - val_loss: 0.2976
# Epoch 47/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.9988 - loss: 0.0045 - val_accuracy: 0.9901 - val_loss: 0.0354
# Epoch 48/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.9982 - loss: 0.0039 - val_accuracy: 0.9936 - val_loss: 0.0322
# Epoch 49/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.9991 - loss: 0.0028 - val_accuracy: 0.9943 - val_loss: 0.0236
# Epoch 50/50
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 2s 21ms/step - accuracy: 0.9991 - loss: 0.0058 - val_accuracy: 0.9950 - val_loss: 0.0221

# %% [markdown]
# Threshold 0.5

# %%
# === TEST ===
test_loss, test_acc = model.evaluate(X_test, y_test, verbose=1)

print("\n=== TEST RESULT ===")
print("Loss :", test_loss)
print("Acc  :", test_acc)
# Out:
# 91/97 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.8714 - loss: 0.8744
# 2026-05-17 09:08:31.638859: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_151', 488 bytes spill stores, 488 bytes spill loads
#
# 2026-05-17 09:08:31.690109: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_151_0', 36 bytes spill stores, 36 bytes spill loads
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 5s 51ms/step - accuracy: 0.9120 - loss: 0.4858
#
# === TEST RESULT ===
# Loss : 0.48582765460014343
# Acc  : 0.9120310544967651

# %%
y_prob = model.predict(X_test)
y_pred = (y_prob >= 0.5).astype(int)
# Out:
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 3s 19ms/step

# %% [markdown]
# Confusion Matrix + Nilai Dasar

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, y_pred)
tn, fp, fn, tp = cm.ravel()

print("TP:", tp)
print("FP:", fp)
print("TN:", tn)
print("FN:", fn)
# Out:
# TP: 1238
# FP: 18
# TN: 1582
# FN: 254

# %% [markdown]
# Hitung Semua Metric Sesuai Persamaan Paper

# %%
accuracy  = (tp + tn) / (tp + tn + fp + fn)
recall    = tp / (tp + fn)
precision = tp / (tp + fp)
fmeasure  = 2 * precision * recall / (precision + recall)

print("\n=== Metrics (Threshold 0.5) ===")
print(f"Accuracy : {accuracy:.6f}")
print(f"Recall   : {recall:.6f}")
print(f"Precision: {precision:.6f}")
print(f"F-measure: {fmeasure:.6f}")
# Out:
# === Metrics (Threshold 0.5) ===
# Accuracy : 0.912031
# Recall   : 0.829759
# Precision: 0.985669
# F-measure: 0.901019

# %%
# === Confusion values sudah ada ===
# tp, tn, fp, fn

accuracy  = (tp + tn) / (tp + tn + fp + fn)
recall    = tp / (tp + fn + 1e-12)
precision = tp / (tp + fp + 1e-12)
f1        = 2 * precision * recall / (precision + recall + 1e-12)

# tambahan
fpr = fp / (fp + tn + 1e-12)
fnr = fn / (fn + tp + 1e-12)

print("\n=== Metrics (Threshold 0.5) ===")
print(f"Accuracy  : {accuracy:.6f}")
print(f"Precision : {precision:.6f}")
print(f"Recall    : {recall:.6f}")
print(f"F1        : {f1:.6f}")
print(f"FPR       : {fpr:.6f}")
print(f"FNR       : {fnr:.6f}")
print(f"FP        : {fp}")
print(f"FN        : {fn}")
# Out:
# === Metrics (Threshold 0.5) ===
# Accuracy  : 0.912031
# Precision : 0.985669
# Recall    : 0.829759
# F1        : 0.901019
# FPR       : 0.011250
# FNR       : 0.170241
# FP        : 18
# FN        : 254

# %% [markdown]
# ROC Curve + AUC (Persamaan 13)

# %%
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

fpr, tpr, thresholds = roc_curve(y_test, y_prob)
roc_auc = auc(fpr, tpr)

print(f"AUC: {roc_auc:.6f}")
# Out:
# AUC: 0.991522

# %% [markdown]
# Plot ROC

# %%
plt.figure(figsize=(6,5))
plt.plot(fpr, tpr, label=f"AUC = {roc_auc:.4f}")
plt.plot([0,1], [0,1], linestyle='--')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve - TOW IDS CNN")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# Plot Confusion Matrix

# %%
import seaborn as sns

plt.figure(figsize=(5,4))
sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    cmap="Blues",
    xticklabels=["Normal", "Attack"],
    yticklabels=["Normal", "Attack"]
)
plt.xlabel("Predicted")                                                                                         
plt.ylabel("Actual")
plt.title("Confusion Matrix (Threshold=0.5)")
plt.show()

# %% [markdown]
# Plot Confusion Matrix

# %%
plt.figure(figsize=(5,4))
plt.bar(["False Positive", "False Negative"], [fp, fn])
plt.title("FP vs FN")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# Plot FP vs FN

# %%
import numpy as np

youden_index = tpr - fpr
best_idx = np.argmax(youden_index)
best_threshold = thresholds[best_idx]

print("Best Threshold (Youden):", best_threshold)
# Out:
# Best Threshold (Youden): 7.0166294e-05

# %%
youden_index = tpr - fpr
best_idx = np.argmax(youden_index)
best_threshold = thresholds[best_idx]

print("Best Threshold:", best_threshold)
# Out:
# Best Threshold: 7.0166294e-05

# %%
y_pred_opt = (y_prob >= best_threshold).astype(int)

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, y_pred_opt)
tn, fp, fn, tp = cm.ravel()

# %%
accuracy  = (tp + tn) / (tp + tn + fp + fn)
recall    = tp / (tp + fn)
precision = tp / (tp + fp)
fmeasure  = 2 * precision * recall / (precision + recall)

print("\n=== Metrics BEST THRESHOLD ===")
print(f"Accuracy : {accuracy:.6f}")
print(f"Recall   : {recall:.6f}")
print(f"Precision: {precision:.6f}")
print(f"F-measure: {fmeasure:.6f}")
# Out:
# === Metrics BEST THRESHOLD ===
# Accuracy : 0.969599
# Recall   : 0.979893
# Precision: 0.958060
# F-measure: 0.968854

# %% [markdown]
# Threshold Optimization (Youden Index)

# %%
y_pred_opt = (y_prob >= best_threshold).astype(int)
cm_opt = confusion_matrix(y_test, y_pred_opt)

tn2, fp2, fn2, tp2 = cm_opt.ravel()

acc_opt = (tp2 + tn2) / (tp2 + tn2 + fp2 + fn2)

print("\nAccuracy Optimal:", acc_opt)
# Out:
# Accuracy Optimal: 0.9695989650711514

# %% [markdown]
# Detection Speed

# %%
import time

start = time.time()
_ = model.predict(X_test[:256])
latency = (time.time() - start) / 256

print("Inference time per sample:", latency)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Inference time per sample: 0.000529174692928791
