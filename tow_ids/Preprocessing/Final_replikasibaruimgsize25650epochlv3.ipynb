# %%
import numpy as np
import os
import gc
import time
import matplotlib.pyplot as plt
import seaborn as sns

import tensorflow as tf
from tensorflow.keras import layers, models

from sklearn.metrics import (
    confusion_matrix,
    classification_report,
    roc_curve,
    auc,
    precision_recall_curve,
    f1_score
)
# Out:
# 2026-05-17 16:04:21.199880: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-05-17 16:04:21.210389: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1779008661.223027   90018 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1779008661.227195   90018 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1779008661.237186   90018 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1779008661.237202   90018 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1779008661.237204   90018 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1779008661.237205   90018 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-05-17 16:04:21.240449: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
import numpy as np
import os
import gc
import time
import matplotlib.pyplot as plt
import seaborn as sns

import tensorflow as tf
from tensorflow.keras import layers, models

from sklearn.metrics import (
    confusion_matrix,
    classification_report,
    roc_curve,
    auc,
    precision_recall_curve,
    f1_score
)

# %%
BASE_PATHHASIL = "/home/dani/Documents/tugas akhir/TugasAkhir/codeTugasAkhirku2026/tow_ids/Preprocessing/Preprocessingbaru/imgsize256lv3/norm/dwt/"

# %%
import tensorflow as tf
from tensorflow.keras import layers, models

def build_cnn_tow_ids():

    inputs = layers.Input(shape=(32, 32, 3))

    # ===== Block A =====
    x = layers.SeparableConv2D(32, (3,3), padding="same")(inputs)
    x = layers.ReLU()(x)
    x = layers.BatchNormalization()(x)
    x = layers.MaxPooling2D((2,2))(x)

    # ===== Block B (Residual) =====
    shortcut = layers.Conv2D(64, (1,1), padding="same")(x)

    x = layers.SeparableConv2D(64, (3,3), padding="same")(x)
    x = layers.ReLU()(x)
    x = layers.BatchNormalization()(x)

    x = layers.Add()([x, shortcut])
    x = layers.ReLU()(x)

    # ===== Block C =====
    x = layers.SeparableConv2D(128, (3,3), padding="same")(x)
    x = layers.ReLU()(x)
    x = layers.BatchNormalization()(x)

    x = layers.GlobalAveragePooling2D()(x)

    # ===== Dense Head =====
    x = layers.Dense(512, activation="relu")(x)
    x = layers.Dense(256, activation="relu")(x)
    x = layers.Dense(64, activation="relu")(x)
    x = layers.Dropout(0.5)(x)

    outputs = layers.Dense(1, activation="sigmoid")(x)

    model = models.Model(inputs, outputs)

    model.compile(
        optimizer=tf.keras.optimizers.Adam(1e-3),
        loss="binary_crossentropy",
        metrics=["accuracy"]
    )

    return model

# %%
train_data = np.load(os.path.join(BASE_PATHHASIL, "tow_ids_train_dwt.npz"))
test_data  = np.load(os.path.join(BASE_PATHHASIL, "tow_ids_test_dwt.npz"))
val_data   = np.load(os.path.join(BASE_PATHHASIL, "tow_ids_eval_dwt.npz"))

X_train = train_data["X"]
y_train = train_data["y"]

X_test  = test_data["X"]
y_test  = test_data["y"]

X_val   = val_data["X"]
y_val   = val_data["y"]

print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
print(X_val.shape, y_val.shape)
# Out:
# (3291, 32, 32, 3) (3291,)
# (3092, 32, 32, 3) (3092,)
# (1410, 32, 32, 3) (1410,)

# %%
tf.keras.backend.clear_session()

model = build_cnn_tow_ids()
model.summary()
# Out:
# I0000 00:00:1779008662.646547   90018 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 1173 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 32, 32, 3) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d    │ (None, 32, 32,    │        155 │ input_layer[0][0] │
# │ (SeparableConv2D)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu (ReLU)        │ (None, 32, 32,    │          0 │ separable_conv2d… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 32, 32,    │        128 │ re_lu[0][0]       │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_1  │ (None, 16, 16,    │      2,400 │ max_pooling2d[0]… │
# │ (SeparableConv2D)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_1 (ReLU)      │ (None, 16, 16,    │          0 │ separable_conv2d… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        256 │ re_lu_1[0][0]     │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 16, 16,    │      2,112 │ max_pooling2d[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 16, 16,    │          0 │ batch_normalizat… │
# │                     │ 64)               │            │ conv2d[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_2 (ReLU)      │ (None, 16, 16,    │          0 │ add[0][0]         │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_2  │ (None, 16, 16,    │      8,896 │ re_lu_2[0][0]     │
# │ (SeparableConv2D)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_3 (ReLU)      │ (None, 16, 16,    │          0 │ separable_conv2d… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 16, 16,    │        512 │ re_lu_3[0][0]     │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 128)       │          0 │ batch_normalizat… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 512)       │     66,048 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 256)       │    131,328 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 64)        │     16,448 │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 64)        │          0 │ dense_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 1)         │         65 │ dropout[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 228,348 (891.98 KB)
#  Trainable params: 227,900 (890.23 KB)
#  Non-trainable params: 448 (1.75 KB)

# %%
history = model.fit(
    X_train, y_train,
    epochs=100,
    batch_size=32,
    validation_data=(X_val, y_val),
    verbose=1,
    
)
# Out:
# Epoch 1/100
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1779008664.841129   90148 service.cc:152] XLA service 0x7795c4017630 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1779008664.841146   90148 service.cc:160]   StreamExecutor device (0): NVIDIA GeForce RTX 3060 Laptop GPU, Compute Capability 8.6
# 2026-05-17 16:04:24.888572: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1779008665.245944   90148 cuda_dnn.cc:529] Loaded cuDNN version 91701
# 2026-05-17 16:04:26.924044: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1332_0', 44 bytes spill stores, 44 bytes spill loads
#
# 2026-05-17 16:04:27.091508: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1332', 484 bytes spill stores, 484 bytes spill loads
#
# 2026-05-17 16:04:28.219000: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2185', 36 bytes spill stores, 44 bytes spill loads
#
# 2026-05-17 16:04:28.469906: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2185', 32 bytes spill stores, 32 bytes spill loads
#
# 2026-05-17 16:04:28.700214: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2183', 36 bytes spill stores, 44 bytes spill loads
#
# 2026-05-17 16:04:28.798658: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2187', 32 bytes spill stores, 32 bytes spill loads
#
# 2026-05-17 16:04:28.952462: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2185', 32 bytes spill stores, 32 bytes spill loads
#
# I0000 00:00:1779008672.816200   90148 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
#  89/103 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9073 - loss: 0.2668
# 2026-05-17 16:04:34.867252: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1332', 488 bytes spill stores, 488 bytes spill loads
#
# 2026-05-17 16:04:34.975570: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1332_0', 36 bytes spill stores, 36 bytes spill loads
#
# 2026-05-17 16:04:36.303435: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2183', 28 bytes spill stores, 32 bytes spill loads
#
# 2026-05-17 16:04:37.051217: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2187', 32 bytes spill stores, 32 bytes spill loads
#
# 2026-05-17 16:04:37.192289: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2185', 32 bytes spill stores, 32 bytes spill loads
#
# 2026-05-17 16:04:37.253025: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2185', 32 bytes spill stores, 32 bytes spill loads
#
# 2026-05-17 16:04:37.595982: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2185', 28 bytes spill stores, 32 bytes spill loads
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step - accuracy: 0.9129 - loss: 0.2524
# 2026-05-17 16:04:44.283233: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_151', 64 bytes spill stores, 64 bytes spill loads
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 23s 127ms/step - accuracy: 0.9511 - loss: 0.1548 - val_accuracy: 0.7291 - val_loss: 0.5966
# Epoch 2/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9775 - loss: 0.0860 - val_accuracy: 0.7390 - val_loss: 0.4640
# Epoch 3/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9830 - loss: 0.0605 - val_accuracy: 0.9702 - val_loss: 0.2845
# Epoch 4/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9830 - loss: 0.0574 - val_accuracy: 0.9681 - val_loss: 0.1240
# Epoch 5/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9885 - loss: 0.0405 - val_accuracy: 0.9794 - val_loss: 0.0634
# Epoch 6/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9863 - loss: 0.0485 - val_accuracy: 0.9241 - val_loss: 0.2688
# Epoch 7/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9903 - loss: 0.0364 - val_accuracy: 0.9702 - val_loss: 0.1167
# Epoch 8/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9891 - loss: 0.0346 - val_accuracy: 0.8872 - val_loss: 0.4371
# Epoch 9/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9897 - loss: 0.0327 - val_accuracy: 0.9830 - val_loss: 0.1053
# Epoch 10/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9906 - loss: 0.0322 - val_accuracy: 0.9780 - val_loss: 0.1077
# Epoch 11/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9885 - loss: 0.0339 - val_accuracy: 0.4270 - val_loss: 2.1669
# Epoch 12/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9918 - loss: 0.0235 - val_accuracy: 0.9326 - val_loss: 0.2591
# Epoch 13/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9964 - loss: 0.0136 - val_accuracy: 0.9702 - val_loss: 0.1328
# Epoch 14/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9936 - loss: 0.0216 - val_accuracy: 0.9716 - val_loss: 0.1007
# Epoch 15/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9945 - loss: 0.0171 - val_accuracy: 0.9553 - val_loss: 0.1989
# Epoch 16/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9970 - loss: 0.0118 - val_accuracy: 0.9723 - val_loss: 0.2012
# Epoch 17/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9957 - loss: 0.0098 - val_accuracy: 0.9801 - val_loss: 0.0811
# Epoch 18/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9921 - loss: 0.0251 - val_accuracy: 0.9674 - val_loss: 0.1679
# Epoch 19/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9939 - loss: 0.0114 - val_accuracy: 0.9128 - val_loss: 0.4644
# Epoch 20/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9951 - loss: 0.0119 - val_accuracy: 0.9716 - val_loss: 0.1963
# Epoch 21/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9942 - loss: 0.0178 - val_accuracy: 0.9872 - val_loss: 0.0876
# Epoch 22/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9970 - loss: 0.0079 - val_accuracy: 0.9624 - val_loss: 0.1849
# Epoch 23/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9957 - loss: 0.0155 - val_accuracy: 0.9184 - val_loss: 0.2459
# Epoch 24/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9945 - loss: 0.0166 - val_accuracy: 0.8752 - val_loss: 0.6214
# Epoch 25/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9918 - loss: 0.0260 - val_accuracy: 0.9199 - val_loss: 0.3713
# Epoch 26/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9930 - loss: 0.0168 - val_accuracy: 0.9830 - val_loss: 0.1574
# Epoch 27/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9970 - loss: 0.0093 - val_accuracy: 0.9333 - val_loss: 0.3704
# Epoch 28/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9967 - loss: 0.0149 - val_accuracy: 0.8993 - val_loss: 0.4818
# Epoch 29/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9964 - loss: 0.0116 - val_accuracy: 0.9787 - val_loss: 0.1135
# Epoch 30/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9967 - loss: 0.0121 - val_accuracy: 0.9709 - val_loss: 0.1291
# Epoch 31/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9979 - loss: 0.0090 - val_accuracy: 0.8723 - val_loss: 0.8546
# Epoch 32/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9967 - loss: 0.0097 - val_accuracy: 0.9638 - val_loss: 0.2694
# Epoch 33/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9985 - loss: 0.0032 - val_accuracy: 0.9518 - val_loss: 0.3016
# Epoch 34/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9976 - loss: 0.0060 - val_accuracy: 0.8099 - val_loss: 2.5586
# Epoch 35/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9945 - loss: 0.0109 - val_accuracy: 0.9858 - val_loss: 0.1701
# Epoch 36/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9973 - loss: 0.0121 - val_accuracy: 0.9823 - val_loss: 0.1756
# Epoch 37/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9991 - loss: 0.0043 - val_accuracy: 0.9773 - val_loss: 0.2074
# Epoch 38/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9964 - loss: 0.0146 - val_accuracy: 0.9099 - val_loss: 0.7128
# Epoch 39/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9954 - loss: 0.0161 - val_accuracy: 0.9830 - val_loss: 0.1709
# Epoch 40/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9988 - loss: 0.0059 - val_accuracy: 0.9809 - val_loss: 0.1038
# Epoch 41/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9991 - loss: 0.0038 - val_accuracy: 0.9376 - val_loss: 0.3156
# Epoch 42/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9985 - loss: 0.0028 - val_accuracy: 0.9823 - val_loss: 0.3044
# Epoch 43/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9948 - loss: 0.0210 - val_accuracy: 0.9674 - val_loss: 0.1539
# Epoch 44/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9988 - loss: 0.0055 - val_accuracy: 0.8915 - val_loss: 0.9450
# Epoch 45/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9939 - loss: 0.0230 - val_accuracy: 0.9844 - val_loss: 0.1518
# Epoch 46/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9964 - loss: 0.0108 - val_accuracy: 0.8809 - val_loss: 0.6536
# Epoch 47/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9951 - loss: 0.0082 - val_accuracy: 0.9851 - val_loss: 0.1577
# Epoch 48/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9997 - loss: 0.0016 - val_accuracy: 0.9780 - val_loss: 0.1295
# Epoch 49/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9976 - loss: 0.0103 - val_accuracy: 0.9539 - val_loss: 0.3305
# Epoch 50/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9991 - loss: 0.0038 - val_accuracy: 0.9418 - val_loss: 0.3605
# Epoch 51/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9985 - loss: 0.0041 - val_accuracy: 0.9553 - val_loss: 0.4186
# Epoch 52/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9970 - loss: 0.0093 - val_accuracy: 0.9858 - val_loss: 0.2124
# Epoch 53/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9973 - loss: 0.0057 - val_accuracy: 0.9837 - val_loss: 0.1885
# Epoch 54/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9957 - loss: 0.0162 - val_accuracy: 0.9752 - val_loss: 0.1929
# Epoch 55/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9985 - loss: 0.0041 - val_accuracy: 0.9830 - val_loss: 0.1462
# Epoch 56/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9976 - loss: 0.0111 - val_accuracy: 0.9057 - val_loss: 0.5830
# Epoch 57/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9957 - loss: 0.0134 - val_accuracy: 0.9716 - val_loss: 0.1386
# Epoch 58/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9997 - loss: 0.0017 - val_accuracy: 0.9617 - val_loss: 0.2602
# Epoch 59/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9991 - loss: 0.0043 - val_accuracy: 0.9780 - val_loss: 0.2058
# Epoch 60/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 5.8047e-04 - val_accuracy: 0.9688 - val_loss: 0.2853
# Epoch 61/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9997 - loss: 4.3174e-04 - val_accuracy: 0.9809 - val_loss: 0.2277
# Epoch 62/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9988 - loss: 0.0059 - val_accuracy: 0.9667 - val_loss: 0.2472
# Epoch 63/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9948 - loss: 0.0159 - val_accuracy: 0.9383 - val_loss: 0.2914
# Epoch 64/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9988 - loss: 0.0094 - val_accuracy: 0.9759 - val_loss: 0.1929
# Epoch 65/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9970 - loss: 0.0101 - val_accuracy: 0.9369 - val_loss: 0.5513
# Epoch 66/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9976 - loss: 0.0058 - val_accuracy: 0.9738 - val_loss: 0.2060
# Epoch 67/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 4.3472e-04 - val_accuracy: 0.9723 - val_loss: 0.2376
# Epoch 68/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9997 - loss: 0.0012 - val_accuracy: 0.9021 - val_loss: 1.0253
# Epoch 69/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9985 - loss: 0.0080 - val_accuracy: 0.9681 - val_loss: 0.4303
# Epoch 70/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9970 - loss: 0.0123 - val_accuracy: 0.9582 - val_loss: 0.2973
# Epoch 71/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9970 - loss: 0.0106 - val_accuracy: 0.9560 - val_loss: 0.3459
# Epoch 72/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9991 - loss: 0.0031 - val_accuracy: 0.9532 - val_loss: 0.4229
# Epoch 73/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9973 - loss: 0.0119 - val_accuracy: 0.8376 - val_loss: 0.7525
# Epoch 74/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9979 - loss: 0.0078 - val_accuracy: 0.9362 - val_loss: 0.3478
# Epoch 75/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9982 - loss: 0.0058 - val_accuracy: 0.9511 - val_loss: 0.3590
# Epoch 76/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9976 - loss: 0.0121 - val_accuracy: 0.8220 - val_loss: 3.7116
# Epoch 77/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9951 - loss: 0.0196 - val_accuracy: 0.7291 - val_loss: 9.1623
# Epoch 78/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9982 - loss: 0.0062 - val_accuracy: 0.9844 - val_loss: 0.1567
# Epoch 79/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9967 - loss: 0.0103 - val_accuracy: 0.9475 - val_loss: 0.2426
# Epoch 80/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9997 - loss: 0.0018 - val_accuracy: 0.9759 - val_loss: 0.1772
# Epoch 81/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9994 - loss: 0.0021 - val_accuracy: 0.9610 - val_loss: 0.2873
# Epoch 82/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9988 - loss: 0.0052 - val_accuracy: 0.9610 - val_loss: 0.2545
# Epoch 83/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9973 - loss: 0.0115 - val_accuracy: 0.9709 - val_loss: 0.1756
# Epoch 84/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9988 - loss: 0.0049 - val_accuracy: 0.9816 - val_loss: 0.1744
# Epoch 85/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9970 - loss: 0.0080 - val_accuracy: 0.9823 - val_loss: 0.2221
# Epoch 86/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9988 - loss: 0.0045 - val_accuracy: 0.9262 - val_loss: 0.7824
# Epoch 87/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9976 - loss: 0.0077 - val_accuracy: 0.9787 - val_loss: 0.2126
# Epoch 88/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 1.0000 - loss: 6.7088e-04 - val_accuracy: 0.9674 - val_loss: 0.2991
# Epoch 89/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9976 - loss: 0.0102 - val_accuracy: 0.8348 - val_loss: 1.5216
# Epoch 90/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9976 - loss: 0.0068 - val_accuracy: 0.9369 - val_loss: 0.3333
# Epoch 91/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9988 - loss: 0.0060 - val_accuracy: 0.9482 - val_loss: 0.4067
# Epoch 92/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9994 - loss: 0.0012 - val_accuracy: 0.9681 - val_loss: 0.3032
# Epoch 93/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9997 - loss: 0.0032 - val_accuracy: 0.9787 - val_loss: 0.2219
# Epoch 94/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9973 - loss: 0.0072 - val_accuracy: 0.8929 - val_loss: 1.2555
# Epoch 95/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9976 - loss: 0.0067 - val_accuracy: 0.9837 - val_loss: 0.1546
# Epoch 96/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9988 - loss: 0.0030 - val_accuracy: 0.9823 - val_loss: 0.1823
# Epoch 97/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9997 - loss: 7.7550e-04 - val_accuracy: 0.9702 - val_loss: 0.2593
# Epoch 98/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9997 - loss: 8.6341e-04 - val_accuracy: 0.9738 - val_loss: 0.3117
# Epoch 99/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9964 - loss: 0.0123 - val_accuracy: 0.7291 - val_loss: 7.2055
# Epoch 100/100
# 103/103 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.9973 - loss: 0.0109 - val_accuracy: 0.9674 - val_loss: 0.1450

# %% [markdown]
# Threshold 0.5

# %%
# === TEST ===
test_loss, test_acc = model.evaluate(X_test, y_test, verbose=1)

print("\n=== TEST RESULT ===")
print("Loss :", test_loss)
print("Acc  :", test_acc)
# Out:
# 86/97 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9537 - loss: 1.6558
# 2026-05-17 16:05:30.119505: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_151_0', 36 bytes spill stores, 36 bytes spill loads
#
# 2026-05-17 16:05:31.396033: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_151', 488 bytes spill stores, 488 bytes spill loads
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 5s 48ms/step - accuracy: 0.9615 - loss: 0.4976
#
# === TEST RESULT ===
# Loss : 0.4976193904876709
# Acc  : 0.9615135788917542

# %%
y_prob = model.predict(X_test)
y_pred = (y_prob >= 0.5).astype(int)
# Out:
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step

# %% [markdown]
# Confusion Matrix + Nilai Dasar

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, y_pred)
tn, fp, fn, tp = cm.ravel()

print("TP:", tp)
print("FP:", fp)
print("TN:", tn)
print("FN:", fn)
# Out:
# TP: 1434
# FP: 61
# TN: 1539
# FN: 58

# %% [markdown]
# Hitung Semua Metric Sesuai Persamaan Paper

# %%
accuracy  = (tp + tn) / (tp + tn + fp + fn)
recall    = tp / (tp + fn)
precision = tp / (tp + fp)
fmeasure  = 2 * precision * recall / (precision + recall)

print("\n=== Metrics (Threshold 0.5) ===")
print(f"Accuracy : {accuracy:.6f}")
print(f"Recall   : {recall:.6f}")
print(f"Precision: {precision:.6f}")
print(f"F-measure: {fmeasure:.6f}")
# Out:
# === Metrics (Threshold 0.5) ===
# Accuracy : 0.961514
# Recall   : 0.961126
# Precision: 0.959197
# F-measure: 0.960161

# %%
# === Confusion values sudah ada ===
# tp, tn, fp, fn

accuracy  = (tp + tn) / (tp + tn + fp + fn)
recall    = tp / (tp + fn + 1e-12)
precision = tp / (tp + fp + 1e-12)
f1        = 2 * precision * recall / (precision + recall + 1e-12)

# tambahan
fpr = fp / (fp + tn + 1e-12)
fnr = fn / (fn + tp + 1e-12)

print("\n=== Metrics (Threshold 0.5) ===")
print(f"Accuracy  : {accuracy:.6f}")
print(f"Precision : {precision:.6f}")
print(f"Recall    : {recall:.6f}")
print(f"F1        : {f1:.6f}")
print(f"FPR       : {fpr:.6f}")
print(f"FNR       : {fnr:.6f}")
print(f"FP        : {fp}")
print(f"FN        : {fn}")
# Out:
# === Metrics (Threshold 0.5) ===
# Accuracy  : 0.961514
# Precision : 0.959197
# Recall    : 0.961126
# F1        : 0.960161
# FPR       : 0.038125
# FNR       : 0.038874
# FP        : 61
# FN        : 58

# %% [markdown]
# ROC Curve + AUC (Persamaan 13)

# %%
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

fpr, tpr, thresholds = roc_curve(y_test, y_prob)
roc_auc = auc(fpr, tpr)

print(f"AUC: {roc_auc:.6f}")
# Out:
# AUC: 0.989091

# %% [markdown]
# Plot ROC

# %%
plt.figure(figsize=(6,5))
plt.plot(fpr, tpr, label=f"AUC = {roc_auc:.4f}")
plt.plot([0,1], [0,1], linestyle='--')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve - TOW IDS CNN")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# Plot Confusion Matrix

# %%
import seaborn as sns

plt.figure(figsize=(5,4))
sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    cmap="Blues",
    xticklabels=["Normal", "Attack"],
    yticklabels=["Normal", "Attack"]
)
plt.xlabel("Predicted")                                                                                         
plt.ylabel("Actual")
plt.title("Confusion Matrix (Threshold=0.5)")
plt.show()

# %% [markdown]
# Plot Confusion Matrix

# %%
plt.figure(figsize=(5,4))
plt.bar(["False Positive", "False Negative"], [fp, fn])
plt.title("FP vs FN")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# Plot FP vs FN

# %%
import numpy as np
import time
import matplotlib.pyplot as plt

from sklearn.metrics import (
    roc_curve,
    auc,
    confusion_matrix
)

# =========================================
# PREDICT PROBABILITY
# =========================================

y_prob = model.predict(X_test).ravel()
y_true = y_test

# =========================================
# ROC CURVE
# =========================================

fpr, tpr, thresholds = roc_curve(y_true, y_prob)

roc_auc = auc(fpr, tpr)

# =========================================
# YOU DEN INDEX
# =========================================

youden_index = tpr - fpr

best_idx = np.argmax(youden_index)

best_threshold = thresholds[best_idx]
# Out:
# 97/97 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step

# %%
print("========================================")
print("BEST THRESHOLD SEARCH")
print("========================================")
print(f"Best Threshold (Youden Index): {best_threshold:.6f}")

# =========================================
# PREDICTION WITH BEST THRESHOLD
# =========================================

y_pred_opt = (y_prob >= best_threshold).astype(int)

# =========================================
# CONFUSION MATRIX
# =========================================

cm_opt = confusion_matrix(y_true, y_pred_opt)

TN, FP, FN, TP = cm_opt.ravel()
# Out:
# ========================================
# BEST THRESHOLD SEARCH
# ========================================
# Best Threshold (Youden Index): 0.185081

# %%
# =========================================
# METRICS
# =========================================

accuracy = (TP + TN) / (TP + TN + FP + FN)

precision = TP / (TP + FP + 1e-12)

recall = TP / (TP + FN + 1e-12)

f1 = 2 * precision * recall / (precision + recall + 1e-12)

FPR = FP / (FP + TN + 1e-12)

FNR = FN / (FN + TP + 1e-12)

# specificity opsional
specificity = TN / (TN + FP + 1e-12)

# =========================================
# PRINT METRICS
# =========================================

print("\n========================================")
print("EVALUATION METRICS")
print("========================================")

print(f"Accuracy   : {accuracy:.6f}")
print(f"Precision  : {precision:.6f}")
print(f"Recall     : {recall:.6f}")
print(f"F1-score   : {f1:.6f}")

print("\n========================================")
print("IDS SPECIFIC METRICS")
print("========================================")

print(f"FPR        : {FPR:.6f}")
print(f"FNR        : {FNR:.6f}")
print(f"Specificity: {specificity:.6f}")
# Out:
# ========================================
# EVALUATION METRICS
# ========================================
# Accuracy   : 0.965071
# Precision  : 0.952880
# Recall     : 0.975871
# F1-score   : 0.964238
#
# ========================================
# IDS SPECIFIC METRICS
# ========================================
# FPR        : 0.045000
# FNR        : 0.024129
# Specificity: 0.955000

# %%
# =========================================
# ROC-AUC
# =========================================

print("\n========================================")
print("ROC-AUC")
print("========================================")

print(f"AUC Score  : {roc_auc:.6f}")
# Out:
# ========================================
# ROC-AUC
# ========================================
# AUC Score  : 0.989091

# %%
# =========================================
# INFERENCE LATENCY
# =========================================

start = time.time()

_ = model.predict(X_test[:256], verbose=0)

latency = (time.time() - start) / 256

print("\n========================================")
print("INFERENCE PERFORMANCE")
print("========================================")

print(f"Inference time per sample: {latency:.6f} sec")
# Out:
# ========================================
# INFERENCE PERFORMANCE
# ========================================
# Inference time per sample: 0.000300 sec

# %% [markdown]
# Threshold Optimization (Youden Index)

# %%
# =========================================
# ROC CURVE PLOT
# =========================================

plt.figure(figsize=(6,6))

plt.plot(fpr, tpr, label=f"AUC = {roc_auc:.4f}")

plt.plot([0,1], [0,1], '--')

plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")

plt.title("ROC Curve")

plt.legend()

plt.grid(True)

plt.show()
