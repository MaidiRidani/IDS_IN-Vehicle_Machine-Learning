# %%
import numpy as np
import os
import gc
import time
import matplotlib.pyplot as plt
import seaborn as sns

import tensorflow as tf
from tensorflow.keras import layers, models

from sklearn.metrics import (
    confusion_matrix,
    classification_report,
    roc_curve,
    auc,
    precision_recall_curve,
    f1_score
)
# Out:
# 2026-02-19 00:51:53.135791: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-02-19 00:51:53.155431: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1771437113.167009  174011 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1771437113.170759  174011 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1771437113.180025  174011 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771437113.180040  174011 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771437113.180041  174011 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771437113.180043  174011 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-02-19 00:51:53.183193: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
import numpy as np
import os
import gc
import time
import matplotlib.pyplot as plt
import seaborn as sns

import tensorflow as tf
from tensorflow.keras import layers, models

from sklearn.metrics import (
    confusion_matrix,
    classification_report,
    roc_curve,
    auc,
    precision_recall_curve,
    f1_score
)

# %%
DWT_TRAIN_DIR = "/home/dani/Documents/tugas akhir/TugasAkhirku2026/tow_ids/Preprocessing/hasil/imgsize60/norm/dwt/"
DWT_TEST_DIR  = "/home/dani/Documents/tugas akhir/TugasAkhirku2026/tow_ids/Preprocessing/hasil/imgsize60/norm/dwt/"

# %%
import tensorflow as tf
from tensorflow.keras import layers, models

def build_cnn_tow_ids():

    inputs = layers.Input(shape=(60, 60, 3))

    # ===== Block A =====
    x = layers.SeparableConv2D(32, (3,3), padding="same")(inputs)
    x = layers.ReLU()(x)
    x = layers.BatchNormalization()(x)
    x = layers.MaxPooling2D((2,2))(x)

    # ===== Block B (Residual) =====
    shortcut = layers.Conv2D(64, (1,1), padding="same")(x)

    x = layers.SeparableConv2D(64, (3,3), padding="same")(x)
    x = layers.ReLU()(x)
    x = layers.BatchNormalization()(x)

    x = layers.Add()([x, shortcut])
    x = layers.ReLU()(x)

    # ===== Block C =====
    x = layers.SeparableConv2D(128, (3,3), padding="same")(x)
    x = layers.ReLU()(x)
    x = layers.BatchNormalization()(x)

    x = layers.GlobalAveragePooling2D()(x)

    # ===== Dense Head =====
    x = layers.Dense(512, activation="relu")(x)
    x = layers.Dense(256, activation="relu")(x)
    x = layers.Dense(64, activation="relu")(x)
    x = layers.Dropout(0.5)(x)

    outputs = layers.Dense(1, activation="sigmoid")(x)

    model = models.Model(inputs, outputs)

    model.compile(
        optimizer=tf.keras.optimizers.Adam(1e-3),
        loss="binary_crossentropy",
        metrics=["accuracy"]
    )

    return model

# %%
train_data = np.load(os.path.join(DWT_TRAIN_DIR, "tow_ids_train_dwt.npz"))
test_data  = np.load(os.path.join(DWT_TEST_DIR, "tow_ids_test_dwt.npz"))

X_train = train_data["X"]
y_train = train_data["y"]

X_test  = test_data["X"]
y_test  = test_data["y"]

print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (40121, 60, 60, 3) (40121,)
# (26384, 60, 60, 3) (26384,)

# %%
tf.keras.backend.clear_session()

model = build_cnn_tow_ids()
model.summary()
# Out:
# I0000 00:00:1771437115.652740  174011 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 4144 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 60, 60, 3) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d    │ (None, 60, 60,    │        155 │ input_layer[0][0] │
# │ (SeparableConv2D)   │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu (ReLU)        │ (None, 60, 60,    │          0 │ separable_conv2d… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 60, 60,    │        128 │ re_lu[0][0]       │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 30, 30,    │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_1  │ (None, 30, 30,    │      2,400 │ max_pooling2d[0]… │
# │ (SeparableConv2D)   │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_1 (ReLU)      │ (None, 30, 30,    │          0 │ separable_conv2d… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 30, 30,    │        256 │ re_lu_1[0][0]     │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 30, 30,    │      2,112 │ max_pooling2d[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 30, 30,    │          0 │ batch_normalizat… │
# │                     │ 64)               │            │ conv2d[0][0]      │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_2 (ReLU)      │ (None, 30, 30,    │          0 │ add[0][0]         │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ separable_conv2d_2  │ (None, 30, 30,    │      8,896 │ re_lu_2[0][0]     │
# │ (SeparableConv2D)   │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_3 (ReLU)      │ (None, 30, 30,    │          0 │ separable_conv2d… │
# │                     │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 30, 30,    │        512 │ re_lu_3[0][0]     │
# │ (BatchNormalizatio… │ 128)              │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 128)       │          0 │ batch_normalizat… │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 512)       │     66,048 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 256)       │    131,328 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 64)        │     16,448 │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 64)        │          0 │ dense_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 1)         │         65 │ dropout[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 228,348 (891.98 KB)
#  Trainable params: 227,900 (890.23 KB)
#  Non-trainable params: 448 (1.75 KB)

# %%
history = model.fit(
    X_train, y_train,
    epochs=100,
    batch_size=32,
    validation_data=(X_test, y_test),
    verbose=1,
    
)
# Out:
# Epoch 1/100
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1771437118.959115  174172 service.cc:152] XLA service 0x7cc47c017a00 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1771437118.959135  174172 service.cc:160]   StreamExecutor device (0): NVIDIA GeForce RTX 3060 Laptop GPU, Compute Capability 8.6
# 2026-02-19 00:51:59.004226: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1771437119.340917  174172 cuda_dnn.cc:529] Loaded cuDNN version 91701
# 2026-02-19 00:52:00.289878: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1332_0', 44 bytes spill stores, 44 bytes spill loads
#
# 2026-02-19 00:52:00.438584: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1332', 484 bytes spill stores, 484 bytes spill loads
#
# 2026-02-19 00:52:01.310774: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2183', 36 bytes spill stores, 44 bytes spill loads
#
# 2026-02-19 00:52:01.789061: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2185', 36 bytes spill stores, 44 bytes spill loads
#
# 2026-02-19 00:52:02.116939: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2185', 32 bytes spill stores, 32 bytes spill loads
#
# 2026-02-19 00:52:02.420410: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2187', 32 bytes spill stores, 32 bytes spill loads
#
# 2026-02-19 00:52:02.456867: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2185', 32 bytes spill stores, 32 bytes spill loads
#
# I0000 00:00:1771437126.064784  174172 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 1249/1254 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - accuracy: 0.9147 - loss: 0.2195
# 2026-02-19 00:52:14.898325: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1332', 488 bytes spill stores, 488 bytes spill loads
#
# 2026-02-19 00:52:15.095740: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2183', 28 bytes spill stores, 32 bytes spill loads
#
# 2026-02-19 00:52:15.136019: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_1332_0', 36 bytes spill stores, 36 bytes spill loads
#
# 2026-02-19 00:52:15.571825: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2185', 32 bytes spill stores, 32 bytes spill loads
#
# 2026-02-19 00:52:15.715594: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2185', 28 bytes spill stores, 32 bytes spill loads
#
# 2026-02-19 00:52:15.937141: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2187', 32 bytes spill stores, 32 bytes spill loads
#
# 2026-02-19 00:52:16.131728: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_2185', 32 bytes spill stores, 32 bytes spill loads
# 1254/1254 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9148 - loss: 0.2192
# 2026-02-19 00:52:25.213399: I external/local_xla/xla/stream_executor/cuda/subprocess_compilation.cc:346] ptxas warning : Registers are spilled to local memory in function 'gemm_fusion_dot_151', 52 bytes spill stores, 52 bytes spill loads
# 1254/1254 ━━━━━━━━━━━━━━━━━━━━ 29s 16ms/step - accuracy: 0.9505 - loss: 0.1367 - val_accuracy: 0.9330 - val_loss: 0.1942
# Epoch 2/100
# 1254/1254 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9820 - loss: 0.0596 - val_accuracy: 0.9372 - val_loss: 0.1725
# Epoch 3/100
# 1254/1254 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9880 - loss: 0.0440 - val_accuracy: 0.9909 - val_loss: 0.0352
# Epoch 4/100
# 1254/1254 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9902 - loss: 0.0358 - val_accuracy: 0.9282 - val_loss: 0.1980
# Epoch 5/100
# 1254/1254 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9921 - loss: 0.0310 - val_accuracy: 0.9858 - val_loss: 0.0449
# Epoch 6/100
# 1254/1254 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9922 - loss: 0.0297 - val_accuracy: 0.9915 - val_loss: 0.0392
# Epoch 7/100
# 1254/1254 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9929 - loss: 0.0268 - val_accuracy: 0.9850 - val_loss: 0.0532
# Epoch 8/100
# 1254/1254 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9933 - loss: 0.0258 - val_accuracy: 0.9868 - val_loss: 0.0637
# Epoch 9/100
# 1254/1254 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9940 - loss: 0.0229 - val_accuracy: 0.9476 - val_loss: 0.1879
# Epoch 10/100
# 1254/1254 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9943 - loss: 0.0216 - val_accuracy: 0.9923 - val_loss: 0.0272
# Epoch 11/100
# 1254/1254 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9948 - loss: 0.0191 - val_accuracy: 0.9858 - val_loss: 0.0652
# Epoch 12/100
# 1254/1254 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9953 - loss: 0.0185 - val_accuracy: 0.9844 - val_loss: 0.0646
# Epoch 13/100
# 1254/1254 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9953 - loss: 0.0183 - val_accuracy: 0.9919 - val_loss: 0.0497
# Epoch 14/100
# 1254/1254 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9956 - loss: 0.0173 - val_accuracy: 0.9168 - val_loss: 0.2374
# Epoch 15/100
# 1254/1254 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9960 - loss: 0.0148 - val_accuracy: 0.9879 - val_loss: 0.0442
# Epoch 16/100
# 1254/1254 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9960 - loss: 0.0147 - val_accuracy: 0.9805 - val_loss: 0.0678
# Epoch 17/100
# 1254/1254 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9962 - loss: 0.0145 - val_accuracy: 0.9847 - val_loss: 0.0654
# Epoch 18/100
# 1254/1254 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9968 - loss: 0.0120 - val_accuracy: 0.9854 - val_loss: 0.0988
# Epoch 19/100
# 1254/1254 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9964 - loss: 0.0125 - val_accuracy: 0.9924 - val_loss: 0.0613
# Epoch 20/100
# 1254/1254 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9969 - loss: 0.0120 - val_accuracy: 0.9939 - val_loss: 0.0300
# Epoch 21/100
# 1254/1254 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9969 - loss: 0.0115 - val_accuracy: 0.9879 - val_loss: 0.0828
# Epoch 22/100
# 1254/1254 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9965 - loss: 0.0127 - val_accuracy: 0.9903 - val_loss: 0.0574
# Epoch 23/100
# 1254/1254 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9970 - loss: 0.0098 - val_accuracy: 0.9277 - val_loss: 0.5651
# Epoch 24/100
# 1254/1254 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9971 - loss: 0.0101 - val_accuracy: 0.9447 - val_loss: 0.2514
# Epoch 25/100
# 1254/1254 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9975 - loss: 0.0095 - val_accuracy: 0.9890 - val_loss: 0.0656
# Epoch 26/100
# 1254/1254 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9971 - loss: 0.0094 - val_accuracy: 0.9884 - val_loss: 0.0699
# Epoch 27/100
# 1254/1254 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9972 - loss: 0.0095 - val_accuracy: 0.9788 - val_loss: 0.0784
# Epoch 28/100
# 1254/1254 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9975 - loss: 0.0073 - val_accuracy: 0.9847 - val_loss: 0.0899
# Epoch 29/100
# 1254/1254 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9974 - loss: 0.0070 - val_accuracy: 0.9919 - val_loss: 0.0405
# Epoch 30/100
# 1254/1254 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9976 - loss: 0.0093 - val_accuracy: 0.9906 - val_loss: 0.0865
# Epoch 31/100
# 1254/1254 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9975 - loss: 0.0080 - val_accuracy: 0.9930 - val_loss: 0.0661
# Epoch 32/100
# 1254/1254 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9982 - loss: 0.0060 - val_accuracy: 0.9893 - val_loss: 0.0671
# Epoch 33/100
# 1254/1254 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9974 - loss: 0.0073 - val_accuracy: 0.9934 - val_loss: 0.0590
# Epoch 34/100
# 1254/1254 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9976 - loss: 0.0087 - val_accuracy: 0.9735 - val_loss: 0.1189
# Epoch 35/100
# 1254/1254 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9979 - loss: 0.0061 - val_accuracy: 0.9941 - val_loss: 0.0359
# Epoch 36/100
# 1254/1254 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9981 - loss: 0.0064 - val_accuracy: 0.9916 - val_loss: 0.0637
# Epoch 37/100
# 1254/1254 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9981 - loss: 0.0070 - val_accuracy: 0.9935 - val_loss: 0.0341
# Epoch 38/100
# 1254/1254 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9982 - loss: 0.0054 - val_accuracy: 0.9939 - val_loss: 0.0606
# Epoch 39/100
# 1254/1254 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9982 - loss: 0.0068 - val_accuracy: 0.9900 - val_loss: 0.0590
# Epoch 40/100
# 1254/1254 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9978 - loss: 0.0066 - val_accuracy: 0.9792 - val_loss: 0.2032
# Epoch 41/100
# 1254/1254 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9983 - loss: 0.0056 - val_accuracy: 0.9895 - val_loss: 0.0592
# Epoch 42/100
# 1254/1254 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9983 - loss: 0.0061 - val_accuracy: 0.9929 - val_loss: 0.0594
# Epoch 43/100
# 1254/1254 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9985 - loss: 0.0055 - val_accuracy: 0.9865 - val_loss: 0.1135
# Epoch 44/100
# 1254/1254 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9981 - loss: 0.0052 - val_accuracy: 0.8974 - val_loss: 0.8680
# Epoch 45/100
# 1254/1254 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9986 - loss: 0.0043 - val_accuracy: 0.9856 - val_loss: 0.1511
# Epoch 46/100
# 1254/1254 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9982 - loss: 0.0064 - val_accuracy: 0.9917 - val_loss: 0.0715
# Epoch 47/100
# 1254/1254 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9988 - loss: 0.0044 - val_accuracy: 0.9897 - val_loss: 0.0806
# Epoch 48/100
# 1254/1254 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9985 - loss: 0.0051 - val_accuracy: 0.9911 - val_loss: 0.1148
# Epoch 49/100
# 1254/1254 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9985 - loss: 0.0056 - val_accuracy: 0.9806 - val_loss: 0.1771
# Epoch 50/100
# 1254/1254 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9981 - loss: 0.0062 - val_accuracy: 0.9903 - val_loss: 0.0952
# Epoch 51/100
# 1254/1254 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9983 - loss: 0.0057 - val_accuracy: 0.9815 - val_loss: 0.1407
# Epoch 52/100
# 1254/1254 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9987 - loss: 0.0046 - val_accuracy: 0.9836 - val_loss: 0.1573
# Epoch 53/100
# 1254/1254 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9986 - loss: 0.0080 - val_accuracy: 0.9938 - val_loss: 0.0939
# Epoch 54/100
# 1254/1254 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9983 - loss: 0.0063 - val_accuracy: 0.9792 - val_loss: 0.1436
# Epoch 55/100
# 1254/1254 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9985 - loss: 0.0052 - val_accuracy: 0.9821 - val_loss: 0.1175
# Epoch 56/100
# 1254/1254 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9988 - loss: 0.0038 - val_accuracy: 0.9869 - val_loss: 0.1118
# Epoch 57/100
# 1254/1254 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - accuracy: 0.9982 - loss: 0.0065 - val_accuracy: 0.9823 - val_loss: 0.1302
# Epoch 58/100
# 1254/1254 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9989 - loss: 0.0034 - val_accuracy: 0.9812 - val_loss: 0.1922
# Epoch 59/100
# 1254/1254 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - accuracy: 0.9988 - loss: 0.0041 - val_accuracy: 0.9916 - val_loss: 0.0943
# Epoch 60/100
# 1254/1254 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9987 - loss: 0.0051 - val_accuracy: 0.9887 - val_loss: 0.1096
# Epoch 61/100
# 1254/1254 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - accuracy: 0.9986 - loss: 0.0053 - val_accuracy: 0.9897 - val_loss: 0.0733
# Epoch 62/100
# 1254/1254 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9989 - loss: 0.0045 - val_accuracy: 0.9911 - val_loss: 0.0566
# Epoch 63/100
# 1254/1254 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9987 - loss: 0.0038 - val_accuracy: 0.9826 - val_loss: 0.1104
# Epoch 64/100
# 1254/1254 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9988 - loss: 0.0041 - val_accuracy: 0.9929 - val_loss: 0.1086
# Epoch 65/100
# 1254/1254 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9987 - loss: 0.0046 - val_accuracy: 0.9867 - val_loss: 0.0938
# Epoch 66/100
# 1254/1254 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - accuracy: 0.9986 - loss: 0.0042 - val_accuracy: 0.9471 - val_loss: 0.6032
# Epoch 67/100
# 1254/1254 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9988 - loss: 0.0043 - val_accuracy: 0.9877 - val_loss: 0.2109
# Epoch 68/100
# 1254/1254 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9983 - loss: 0.0061 - val_accuracy: 0.9926 - val_loss: 0.0588
# Epoch 69/100
# 1254/1254 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9991 - loss: 0.0030 - val_accuracy: 0.9823 - val_loss: 0.3001
# Epoch 70/100
# 1254/1254 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - accuracy: 0.9986 - loss: 0.0046 - val_accuracy: 0.9837 - val_loss: 0.1680
# Epoch 71/100
# 1254/1254 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - accuracy: 0.9988 - loss: 0.0048 - val_accuracy: 0.9795 - val_loss: 0.0703
# Epoch 72/100
# 1254/1254 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9985 - loss: 0.0048 - val_accuracy: 0.9850 - val_loss: 0.1887
# Epoch 73/100
# 1254/1254 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - accuracy: 0.9992 - loss: 0.0024 - val_accuracy: 0.9932 - val_loss: 0.0544
# Epoch 74/100
# 1254/1254 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9987 - loss: 0.0048 - val_accuracy: 0.9928 - val_loss: 0.0945
# Epoch 75/100
# 1254/1254 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9991 - loss: 0.0029 - val_accuracy: 0.9924 - val_loss: 0.0762
# Epoch 76/100
# 1254/1254 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9988 - loss: 0.0039 - val_accuracy: 0.9917 - val_loss: 0.1244
# Epoch 77/100
# 1254/1254 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - accuracy: 0.9990 - loss: 0.0031 - val_accuracy: 0.9851 - val_loss: 0.1074
# Epoch 78/100
# 1254/1254 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9985 - loss: 0.0062 - val_accuracy: 0.9931 - val_loss: 0.0668
# Epoch 79/100
# 1254/1254 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9990 - loss: 0.0042 - val_accuracy: 0.9879 - val_loss: 0.1525
# Epoch 80/100
# 1254/1254 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - accuracy: 0.9990 - loss: 0.0035 - val_accuracy: 0.9925 - val_loss: 0.0652
# Epoch 81/100
# 1254/1254 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9990 - loss: 0.0041 - val_accuracy: 0.9879 - val_loss: 0.0799
# Epoch 82/100
# 1254/1254 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9989 - loss: 0.0041 - val_accuracy: 0.9886 - val_loss: 0.1098
# Epoch 83/100
# 1254/1254 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9993 - loss: 0.0026 - val_accuracy: 0.9876 - val_loss: 0.2026
# Epoch 84/100
# 1254/1254 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - accuracy: 0.9987 - loss: 0.0046 - val_accuracy: 0.9937 - val_loss: 0.0604
# Epoch 85/100
# 1254/1254 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - accuracy: 0.9994 - loss: 0.0029 - val_accuracy: 0.9869 - val_loss: 0.1182
# Epoch 86/100
# 1254/1254 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9987 - loss: 0.0053 - val_accuracy: 0.9730 - val_loss: 0.4387
# Epoch 87/100
# 1254/1254 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - accuracy: 0.9994 - loss: 0.0025 - val_accuracy: 0.9757 - val_loss: 0.5400
# Epoch 88/100
# 1254/1254 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9987 - loss: 0.0047 - val_accuracy: 0.9922 - val_loss: 0.1269
# Epoch 89/100
# 1254/1254 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9987 - loss: 0.0035 - val_accuracy: 0.9920 - val_loss: 0.1268
# Epoch 90/100
# 1254/1254 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - accuracy: 0.9992 - loss: 0.0028 - val_accuracy: 0.9933 - val_loss: 0.0989
# Epoch 91/100
# 1254/1254 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9988 - loss: 0.0038 - val_accuracy: 0.9925 - val_loss: 0.1462
# Epoch 92/100
# 1254/1254 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9988 - loss: 0.0041 - val_accuracy: 0.9938 - val_loss: 0.1593
# Epoch 93/100
# 1254/1254 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9991 - loss: 0.0045 - val_accuracy: 0.9891 - val_loss: 0.2385
# Epoch 94/100
# 1254/1254 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9990 - loss: 0.0032 - val_accuracy: 0.9842 - val_loss: 0.1089
# Epoch 95/100
# 1254/1254 ━━━━━━━━━━━━━━━━━━━━ 8s 7ms/step - accuracy: 0.9989 - loss: 0.0037 - val_accuracy: 0.9878 - val_loss: 0.2312
# Epoch 96/100
# 1254/1254 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9989 - loss: 0.0041 - val_accuracy: 0.9890 - val_loss: 0.1172
# Epoch 97/100
# 1254/1254 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9991 - loss: 0.0031 - val_accuracy: 0.9632 - val_loss: 0.7934
# Epoch 98/100
# 1254/1254 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9992 - loss: 0.0027 - val_accuracy: 0.9871 - val_loss: 0.1660
# Epoch 99/100
# 1254/1254 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9989 - loss: 0.0048 - val_accuracy: 0.8838 - val_loss: 5.8921
# Epoch 100/100
# 1254/1254 ━━━━━━━━━━━━━━━━━━━━ 8s 6ms/step - accuracy: 0.9987 - loss: 0.0058 - val_accuracy: 0.9851 - val_loss: 0.1156

# %% [markdown]
# Threshold 0.5

# %%
y_prob = model.predict(X_test)
y_pred = (y_prob >= 0.5).astype(int)
# Out:
# 825/825 ━━━━━━━━━━━━━━━━━━━━ 4s 3ms/step

# %% [markdown]
# Confusion Matrix + Nilai Dasar

# %%
from sklearn.metrics import confusion_matrix

cm = confusion_matrix(y_test, y_pred)
tn, fp, fn, tp = cm.ravel()

print("TP:", tp)
print("FP:", fp)
print("TN:", tn)
print("FN:", fn)
# Out:
# TP: 12146
# FP: 274
# TN: 13844
# FN: 120

# %% [markdown]
# Hitung Semua Metric Sesuai Persamaan Paper

# %%
accuracy  = (tp + tn) / (tp + tn + fp + fn)
recall    = tp / (tp + fn)
precision = tp / (tp + fp)
fmeasure  = 2 * precision * recall / (precision + recall)

print("\n=== Metrics (Threshold 0.5) ===")
print(f"Accuracy : {accuracy:.6f}")
print(f"Recall   : {recall:.6f}")
print(f"Precision: {precision:.6f}")
print(f"F-measure: {fmeasure:.6f}")
# Out:
# === Metrics (Threshold 0.5) ===
# Accuracy : 0.985067
# Recall   : 0.990217
# Precision: 0.977939
# F-measure: 0.984040

# %%
# === Confusion values sudah ada ===
# tp, tn, fp, fn

accuracy  = (tp + tn) / (tp + tn + fp + fn)
recall    = tp / (tp + fn + 1e-12)
precision = tp / (tp + fp + 1e-12)
f1        = 2 * precision * recall / (precision + recall + 1e-12)

# tambahan
fpr = fp / (fp + tn + 1e-12)
fnr = fn / (fn + tp + 1e-12)

print("\n=== Metrics (Threshold 0.5) ===")
print(f"Accuracy  : {accuracy:.6f}")
print(f"Precision : {precision:.6f}")
print(f"Recall    : {recall:.6f}")
print(f"F1        : {f1:.6f}")
print(f"FPR       : {fpr:.6f}")
print(f"FNR       : {fnr:.6f}")
print(f"FP        : {fp}")
print(f"FN        : {fn}")
# Out:
# === Metrics (Threshold 0.5) ===
# Accuracy  : 0.985067
# Precision : 0.977939
# Recall    : 0.990217
# F1        : 0.984040
# FPR       : 0.019408
# FNR       : 0.009783
# FP        : 274
# FN        : 120

# %% [markdown]
# ROC Curve + AUC (Persamaan 13)

# %%
from sklearn.metrics import roc_curve, auc
import matplotlib.pyplot as plt

fpr, tpr, thresholds = roc_curve(y_test, y_prob)
roc_auc = auc(fpr, tpr)

print(f"AUC: {roc_auc:.6f}")
# Out:
# AUC: 0.996667

# %% [markdown]
# Plot ROC

# %%
plt.figure(figsize=(6,5))
plt.plot(fpr, tpr, label=f"AUC = {roc_auc:.4f}")
plt.plot([0,1], [0,1], linestyle='--')
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve - TOW IDS CNN")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# Plot Confusion Matrix

# %%
import seaborn as sns

plt.figure(figsize=(5,4))
sns.heatmap(
    cm,
    annot=True,
    fmt="d",
    cmap="Blues",
    xticklabels=["Normal", "Attack"],
    yticklabels=["Normal", "Attack"]
)
plt.xlabel("Predicted")                                                                                         
plt.ylabel("Actual")
plt.title("Confusion Matrix (Threshold=0.5)")
plt.show()

# %% [markdown]
# Plot Confusion Matrix

# %%
plt.figure(figsize=(5,4))
plt.bar(["False Positive", "False Negative"], [fp, fn])
plt.title("FP vs FN")
plt.ylabel("Count")
plt.show()

# %% [markdown]
# Plot FP vs FN

# %%
import numpy as np

youden_index = tpr - fpr
best_idx = np.argmax(youden_index)
best_threshold = thresholds[best_idx]

print("Best Threshold (Youden):", best_threshold)
# Out:
# Best Threshold (Youden): 0.9961657

# %% [markdown]
# Threshold Optimization (Youden Index)

# %%
y_pred_opt = (y_prob >= best_threshold).astype(int)
cm_opt = confusion_matrix(y_test, y_pred_opt)

tn2, fp2, fn2, tp2 = cm_opt.ravel()

acc_opt = (tp2 + tn2) / (tp2 + tn2 + fp2 + fn2)

print("\nAccuracy Optimal:", acc_opt)
# Out:
# Accuracy Optimal: 0.9903729533050334

# %% [markdown]
# Detection Speed

# %%
import time

start = time.time()
_ = model.predict(X_test[:256])
latency = (time.time() - start) / 256

print("Inference time per sample:", latency)
# Out:
# 8/8 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step
# Inference time per sample: 0.0003162585198879242
