# %%
import numpy as np
import os
import gc
import time
import matplotlib.pyplot as plt
import seaborn as sns

import tensorflow as tf
from tensorflow.keras import layers, models

from sklearn.metrics import (
    confusion_matrix,
    classification_report,
    roc_curve,
    auc,
    precision_recall_curve,
    f1_score
)
# Out:
# 2026-02-17 23:37:33.845483: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-02-17 23:37:33.855245: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1771346253.866643  253454 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1771346253.870200  253454 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1771346253.879255  253454 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771346253.879269  253454 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771346253.879271  253454 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1771346253.879271  253454 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-02-17 23:37:33.882364: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
DWT_TRAIN_DIR = "/home/dani/Documents/tugas akhir/TugasAkhirku2026/tow_ids/Preprocessing/hasil/dwt/train"
DWT_TEST_DIR  = "/home/dani/Documents/tugas akhir/TugasAkhirku2026/tow_ids/Preprocessing/hasil/dwt/test"

# %%
import tensorflow as tf
from tensorflow.keras import layers, models

def build_cnn_tow_ids():

    model = models.Sequential([
        layers.Input(shape=(32, 32, 3)),

        layers.Conv2D(32, (3, 3), padding="same", activation="relu"),
        layers.MaxPooling2D((2, 2)),

        layers.Conv2D(64, (3, 3), padding="same", activation="relu"),
        layers.MaxPooling2D((2, 2)),

        layers.Flatten(),
        layers.Dense(128, activation="relu"),
        layers.Dense(1, activation="sigmoid")
    ])

    model.compile(
        optimizer=tf.keras.optimizers.Adam(learning_rate=1e-3),
        loss="binary_crossentropy",
        metrics=["accuracy"]
    )
    return model

# %%
# total = 438070 + 353478

# class_weight = {
#     0: total / (2 * 438070),  # Normal
#     1: total / (2 * 353478)   # Attack
# }

# class_weight

# %%
import os

DWT_TRAIN_DIR = "/home/dani/Documents/tugas akhir/TugasAkhirku2026/tow_ids/Preprocessing/hasil/dwt/train"

train_parts = sorted([
    f for f in os.listdir(DWT_TRAIN_DIR)
    if f.endswith(".npz")
])

print("Jumlah train part:", len(train_parts))
print("Contoh part:", train_parts[:3])
# Out:
# Jumlah train part: 85
# Contoh part: ['train_dwt_part_001.npz', 'train_dwt_part_002.npz', 'train_dwt_part_003.npz']

# %%
import os, gc, random
import numpy as np

EPOCHS = 1        # GLOBAL epoch (dikunci)
BATCH_SIZE = 32

model = build_cnn_tow_ids()

# pastikan train_parts sudah berisi daftar file .npz
for epoch in range(EPOCHS):
    print(f"\nGlobal Epoch {epoch+1}/{EPOCHS}")
    random.shuffle(train_parts)

    for i, part in enumerate(train_parts, 1):
        print(f"  Training part {i}/{len(train_parts)}: {part}")

        data = np.load(os.path.join(DWT_TRAIN_DIR, part))
        X = data["X"]
        y = data["y"]

        idx = np.random.permutation(len(X))
        X = X[idx]
        y = y[idx]

        history = model.fit(
            X, y,
            epochs=1,
            batch_size=BATCH_SIZE,
            # class_weight=class_weight,
            shuffle=False,
            verbose=0
        )

        print(
            f"    loss={history.history['loss'][0]:.4f}, "
            f"acc={history.history['accuracy'][0]:.4f}"
        )

        del X, y, data
        gc.collect()
# Out:
# I0000 00:00:1771346255.161880  253454 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 4144 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6
# Global Epoch 1/1
#   Training part 1/85: train_dwt_part_074.npz
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1771346256.423529  254443 service.cc:152] XLA service 0x790b5c009c60 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1771346256.423544  254443 service.cc:160]   StreamExecutor device (0): NVIDIA GeForce RTX 3060 Laptop GPU, Compute Capability 8.6
# 2026-02-17 23:37:36.439404: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1771346256.566553  254443 cuda_dnn.cc:529] Loaded cuDNN version 91701
# I0000 00:00:1771346257.348102  254443 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
#     loss=0.0222, acc=0.9938
#   Training part 2/85: train_dwt_part_027.npz
#     loss=0.1159, acc=0.9472
#   Training part 3/85: train_dwt_part_029.npz
#     loss=0.0003, acc=0.9999
#   Training part 4/85: train_dwt_part_056.npz
#     loss=0.1891, acc=0.9348
#   Training part 5/85: train_dwt_part_014.npz
#     loss=0.0186, acc=0.9949
#   Training part 6/85: train_dwt_part_002.npz
#     loss=0.3149, acc=0.9819
#   Training part 7/85: train_dwt_part_022.npz
#     loss=0.6265, acc=0.9751
#   Training part 8/85: train_dwt_part_044.npz
#     loss=0.7924, acc=0.6493
#   Training part 9/85: train_dwt_part_078.npz
#     loss=0.6021, acc=0.7299
#   Training part 10/85: train_dwt_part_049.npz
#     loss=0.7935, acc=0.2888
#   Training part 11/85: train_dwt_part_065.npz
#     loss=0.6981, acc=0.4499
#   Training part 12/85: train_dwt_part_084.npz
#     loss=0.5450, acc=0.9616
#   Training part 13/85: train_dwt_part_054.npz
#     loss=0.8527, acc=0.0306
#   Training part 14/85: train_dwt_part_041.npz
#     loss=0.5984, acc=0.9277
#   Training part 15/85: train_dwt_part_052.npz
#     loss=0.7844, acc=0.1707
#   Training part 16/85: train_dwt_part_067.npz
#     loss=0.5602, acc=1.0000
#   Training part 17/85: train_dwt_part_032.npz
#     loss=0.8213, acc=0.0170
#   Training part 18/85: train_dwt_part_058.npz
#     loss=0.6912, acc=0.5544
#   Training part 19/85: train_dwt_part_042.npz
#     loss=0.5586, acc=1.0000
#   Training part 20/85: train_dwt_part_075.npz
#     loss=0.4020, acc=1.0000
#   Training part 21/85: train_dwt_part_037.npz
#     loss=1.0206, acc=0.0000
#   Training part 22/85: train_dwt_part_064.npz
#     loss=0.6871, acc=0.5555
#   Training part 23/85: train_dwt_part_050.npz
#     loss=0.6899, acc=0.5368
#   Training part 24/85: train_dwt_part_021.npz
#     loss=0.7060, acc=0.4690
#   Training part 25/85: train_dwt_part_059.npz
#     loss=0.6895, acc=0.5442
#   Training part 26/85: train_dwt_part_053.npz
#     loss=0.6670, acc=0.6226
#   Training part 27/85: train_dwt_part_020.npz
#     loss=0.7263, acc=0.3944
#   Training part 28/85: train_dwt_part_061.npz
#     loss=0.6881, acc=0.5502
#   Training part 29/85: train_dwt_part_060.npz
#     loss=0.6858, acc=0.5614
#   Training part 30/85: train_dwt_part_005.npz
#     loss=0.6443, acc=0.6927
#   Training part 31/85: train_dwt_part_008.npz
#     loss=0.4349, acc=1.0000
#   Training part 32/85: train_dwt_part_071.npz
#     loss=0.8953, acc=0.2251
#   Training part 33/85: train_dwt_part_070.npz
#     loss=0.4579, acc=1.0000
#   Training part 34/85: train_dwt_part_034.npz
#     loss=0.8649, acc=0.2517
#   Training part 35/85: train_dwt_part_004.npz
#     loss=0.4628, acc=1.0000
#   Training part 36/85: train_dwt_part_035.npz
#     loss=0.3359, acc=1.0000
#   Training part 37/85: train_dwt_part_057.npz
#     loss=0.8456, acc=0.4480
#   Training part 38/85: train_dwt_part_039.npz
#     loss=0.3305, acc=1.0000
#   Training part 39/85: train_dwt_part_019.npz
#     loss=1.1400, acc=0.0000
#   Training part 40/85: train_dwt_part_017.npz
#     loss=0.7774, acc=0.1752
#   Training part 41/85: train_dwt_part_026.npz
#     loss=0.6356, acc=0.7898
#   Training part 42/85: train_dwt_part_011.npz
#     loss=0.7473, acc=0.2859
#   Training part 43/85: train_dwt_part_009.npz
#     loss=0.6565, acc=0.6882
#   Training part 44/85: train_dwt_part_069.npz
#     loss=0.4868, acc=1.0000
#   Training part 45/85: train_dwt_part_038.npz
#     loss=0.3697, acc=1.0000
#   Training part 46/85: train_dwt_part_077.npz
#     loss=1.0752, acc=0.0000
#   Training part 47/85: train_dwt_part_082.npz
#     loss=0.7602, acc=0.2249
#   Training part 48/85: train_dwt_part_036.npz
#     loss=0.6461, acc=0.7447
#   Training part 49/85: train_dwt_part_015.npz
#     loss=0.7374, acc=0.3221
#   Training part 50/85: train_dwt_part_051.npz
#     loss=0.6632, acc=0.6565
#   Training part 51/85: train_dwt_part_028.npz
#     loss=0.7227, acc=0.3876
#   Training part 52/85: train_dwt_part_012.npz
#     loss=0.5324, acc=1.0000
#   Training part 53/85: train_dwt_part_046.npz
#     loss=0.4023, acc=1.0000
#   Training part 54/85: train_dwt_part_068.npz
#     loss=1.0223, acc=0.0000
#   Training part 55/85: train_dwt_part_055.npz
#     loss=0.7357, acc=0.2751
#   Training part 56/85: train_dwt_part_073.npz
#     loss=0.6261, acc=0.8260
#   Training part 57/85: train_dwt_part_031.npz
#     loss=0.4611, acc=1.0000
#   Training part 58/85: train_dwt_part_072.npz
#     loss=0.3490, acc=1.0000
#   Training part 59/85: train_dwt_part_085.npz
#     loss=0.7998, acc=0.4931
#   Training part 60/85: train_dwt_part_010.npz
#     loss=0.9127, acc=0.0963
#   Training part 61/85: train_dwt_part_043.npz
#     loss=0.5165, acc=1.0000
#   Training part 62/85: train_dwt_part_024.npz
#     loss=0.8698, acc=0.0000
#   Training part 63/85: train_dwt_part_006.npz
#     loss=0.6140, acc=0.8893
#   Training part 64/85: train_dwt_part_030.npz
#     loss=0.7680, acc=0.2114
#   Training part 65/85: train_dwt_part_003.npz
#     loss=0.6423, acc=0.7559
#   Training part 66/85: train_dwt_part_045.npz
#     loss=0.7205, acc=0.4260
#   Training part 67/85: train_dwt_part_018.npz
#     loss=0.6604, acc=0.6520
#   Training part 68/85: train_dwt_part_062.npz
#     loss=0.7376, acc=0.2825
#   Training part 69/85: train_dwt_part_048.npz
#     loss=0.5653, acc=1.0000
#   Training part 70/85: train_dwt_part_047.npz
#     loss=0.4027, acc=1.0000
#   Training part 71/85: train_dwt_part_079.npz
#     loss=0.6303, acc=0.6780
#   Training part 72/85: train_dwt_part_040.npz
#     loss=0.9668, acc=0.0121
#   Training part 73/85: train_dwt_part_063.npz
#     loss=0.7014, acc=0.4422
#   Training part 74/85: train_dwt_part_033.npz
#     loss=0.5501, acc=1.0000
#   Training part 75/85: train_dwt_part_076.npz
#     loss=0.3878, acc=1.0000
#   Training part 76/85: train_dwt_part_013.npz
#     loss=0.2875, acc=1.0000
#   Training part 77/85: train_dwt_part_066.npz
#     loss=1.2083, acc=0.0339
#   Training part 78/85: train_dwt_part_083.npz
#     loss=0.4062, acc=0.9944
#   Training part 79/85: train_dwt_part_016.npz
#     loss=0.3110, acc=1.0000
#   Training part 80/85: train_dwt_part_023.npz
#     loss=0.7956, acc=0.5250
#   Training part 81/85: train_dwt_part_001.npz
#     loss=1.0038, acc=0.0000
#   Training part 82/85: train_dwt_part_081.npz
#     loss=0.5106, acc=1.0000
#   Training part 83/85: train_dwt_part_007.npz
#     loss=0.8760, acc=0.0000
#   Training part 84/85: train_dwt_part_080.npz
#     loss=0.5730, acc=1.0000
#   Training part 85/85: train_dwt_part_025.npz
#     loss=0.8075, acc=0.0577

# %%
import os

MODEL_DIR = "/home/dani/Documents/tugas akhir/TugasAkhirku2026/tow_ids/Model/modelsave"
os.makedirs(MODEL_DIR, exist_ok=True)

MODEL_PATH = os.path.join(MODEL_DIR, "cnn_tow_ids_replikasi.keras")

model.save(MODEL_PATH)

print("Model berhasil disimpan di:", MODEL_PATH)
# Out:
# Model berhasil disimpan di: /home/dani/Documents/tugas akhir/TugasAkhirku2026/tow_ids/Model/modelsave/cnn_tow_ids_replikasi.keras

# %%
# # load model
# import tensorflow as tf

# MODEL_PATH = "/home/dani/Documents/tugas akhir/TugasAkhirku2026/tow_ids/models/cnn_tow_ids_replikasi.keras"

# model = tf.keras.models.load_model(MODEL_PATH)

# print("Model berhasil dimuat.")

# %%
# y_true = []
# y_prob = []

# for part in test_parts:
#     data = np.load(os.path.join(DWT_TEST_DIR, part))
#     X = data["X"]
#     y = data["y"]

#     probs = model.predict(X, verbose=0).ravel()

#     y_true.extend(y)
#     y_prob.extend(probs)

#     del X, y, data
#     gc.collect()

# y_true = np.array(y_true)
# y_prob = np.array(y_prob)


# PREDIKSI ULANG TANPA TRAINING

# %%
y_true = []
y_prob = []

test_parts = sorted([
    f for f in os.listdir(DWT_TEST_DIR)
    if f.endswith(".npz")
])

for part in test_parts:
    data = np.load(os.path.join(DWT_TEST_DIR, part))
    X = data["X"]
    y = data["y"]

    probs = model.predict(X).ravel()

    y_true.extend(y)
    y_prob.extend(probs)

    del X, y, data
    gc.collect()

y_true = np.array(y_true)
y_prob = np.array(y_prob)
# Out:
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 0s 675us/step
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 0s 670us/step
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 0s 713us/step
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 0s 675us/step
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 0s 731us/step
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 0s 776us/step
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 0s 668us/step
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 0s 797us/step
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 0s 679us/step
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 0s 705us/step
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 0s 685us/step
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 0s 896us/step
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 0s 857us/step
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 0s 828us/step
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 0s 767us/step
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 0s 749us/step
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 0s 741us/step
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 0s 717us/step
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 0s 712us/step
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 0s 684us/step
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 0s 646us/step
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 0s 691us/step
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 0s 696us/step
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 0s 825us/step
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 0s 691us/step
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 0s 655us/step
# 292/292 ━━━━━━━━━━━━━━━━━━━━ 0s 702us/step
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 0s 769us/step
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 0s 701us/step
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 0s 707us/step
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 0s 715us/step
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 0s 732us/step
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 0s 797us/step
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 0s 776us/step
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 0s 694us/step
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 0s 753us/step
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 0s 674us/step
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 0s 677us/step
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 0s 785us/step
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 0s 710us/step
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 0s 718us/step
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 0s 735us/step
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 0s 768us/step
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 0s 695us/step
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 0s 693us/step
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 0s 725us/step
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 0s 746us/step
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 0s 728us/step
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 0s 784us/step
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 0s 689us/step
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 0s 687us/step
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 0s 790us/step
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 0s 804us/step
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 0s 708us/step
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 0s 676us/step
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 0s 719us/step
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 0s 706us/step
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 0s 687us/step
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 0s 748us/step
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 0s 708us/step
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 0s 711us/step
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 0s 642us/step
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 0s 778us/step
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 0s 741us/step
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 0s 773us/step
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 0s 680us/step
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 0s 713us/step
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 0s 672us/step
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 0s 678us/step
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 0s 709us/step
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 0s 767us/step
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 0s 765us/step
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 0s 705us/step
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 0s 738us/step
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 0s 739us/step
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 0s 672us/step
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 0s 683us/step
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 0s 660us/step
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 0s 713us/step
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 0s 682us/step
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 0s 682us/step
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 0s 670us/step
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 0s 638us/step
# 291/291 ━━━━━━━━━━━━━━━━━━━━ 0s 687us/step

# %%
from collections import Counter

# contoh ambil satu part dulu (atau gabungan statistik)
counter = Counter(y_true)  # atau y_train sample
counter
# Out:
# Counter({np.int64(0): 438070, np.int64(1): 353478})

# %%
y_pred_05 = (y_prob >= 0.5).astype(int)

# %%
from sklearn.metrics import confusion_matrix, classification_report

# confusion matrix threshold 0.5
cm_05 = confusion_matrix(y_true, y_pred_05)
tn, fp, fn, tp = cm_05.ravel()

print("=== Threshold 0.5 ===")
print("TP:", tp)
print("FP:", fp)
print("TN:", tn)
print("FN:", fn)

acc_05 = (tp + tn) / (tp + tn + fp + fn)
f1_05  = (2 * tp) / (2 * tp + fp + fn)
fpr_05 = fp / (fp + tn)
fnr_05 = fn / (fn + tp)

print(f"Accuracy : {acc_05:.6f}")
print(f"F1-score : {f1_05:.6f}")
print(f"FPR      : {fpr_05:.6f}")
print(f"FNR      : {fnr_05:.6f}")

print("\nClassification report (0.5):")
print(classification_report(
    y_true, y_pred_05,
    target_names=["Normal", "Attack"]
))
# Out:
# === Threshold 0.5 ===
# TP: 0
# FP: 0
# TN: 438070
# FN: 353478
# Accuracy : 0.553435
# F1-score : 0.000000
# FPR      : 0.000000
# FNR      : 1.000000
#
# Classification report (0.5):
#               precision    recall  f1-score   support
#
#       Normal       0.55      1.00      0.71    438070
#       Attack       0.00      0.00      0.00    353478
#
#     accuracy                           0.55    791548
#    macro avg       0.28      0.50      0.36    791548
# weighted avg       0.31      0.55      0.39    791548
# /home/dani/miniconda3/envs/latihan1/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /home/dani/miniconda3/envs/latihan1/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /home/dani/miniconda3/envs/latihan1/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

cm_05 = confusion_matrix(y_true, y_pred_05)

plt.figure(figsize=(6,5))
sns.heatmap(
    cm_05,
    annot=True,
    fmt="d",
    cmap="Blues",
    xticklabels=["Normal", "Attack"],
    yticklabels=["Normal", "Attack"]
)
plt.title("Confusion Matrix (Threshold = 0.5)")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import roc_curve, auc
import numpy as np

fpr, tpr, thresholds = roc_curve(y_true, y_prob)
roc_auc = auc(fpr, tpr)

# cari titik threshold terdekat ke 0.5
idx_05 = np.argmin(np.abs(thresholds - 0.5))

plt.figure(figsize=(6,5))
plt.plot(fpr, tpr, label=f"ROC (AUC = {roc_auc:.4f})")
plt.scatter(
    fpr[idx_05],
    tpr[idx_05],
    color="red",
    label="Threshold = 0.5",
    zorder=5
)
plt.plot([0,1], [0,1], linestyle="--", color="gray")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve with Threshold = 0.5")
plt.legend()
plt.tight_layout()
plt.show()

# %%
from sklearn.metrics import precision_recall_curve

precision, recall, pr_thresholds = precision_recall_curve(y_true, y_prob)

# cari threshold terdekat 0.5 di PR curve
idx_05_pr = np.argmin(np.abs(pr_thresholds - 0.5))

plt.figure(figsize=(6,5))
plt.plot(recall, precision, label="PR Curve")
plt.scatter(
    recall[idx_05_pr],
    precision[idx_05_pr],
    color="red",
    label="Threshold = 0.5",
    zorder=5
)
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title("Precision–Recall Curve with Threshold = 0.5")
plt.legend()
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(7,5))
plt.hist(
    y_prob[y_true == 1],
    bins=50,
    alpha=0.7,
    label="Attack",
    color="red"
)
plt.hist(
    y_prob[y_true == 0],
    bins=50,
    alpha=0.7,
    label="Normal",
    color="blue"
)

plt.axvline(
    0.5,
    color="black",
    linestyle="--",
    linewidth=2,
    label="Threshold = 0.5"
)

plt.xlabel("Predicted Probability (Attack)")
plt.ylabel("Frequency")
plt.title("Prediction Probability Distribution (Threshold = 0.5)")
plt.legend()
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(5,4))
plt.bar(
    ["False Positive", "False Negative"],
    [fp, fn],
    color=["orange", "red"]
)
plt.title("FP vs FN (Threshold = 0.5)")
plt.ylabel("Count")
plt.tight_layout()
plt.show()

# %%
PRED_PATH = os.path.join(MODEL_DIR, "cnn_tow_ids_predictions.npz")

np.savez(PRED_PATH, y_true=y_true, y_prob=y_prob)

print("Prediksi disimpan.")
# Out:
# Prediksi disimpan.

# %%
# # load PREDIKSI 

# data = np.load(PRED_PATH)
# y_true = data["y_true"]
# y_prob = data["y_prob"]

# %%
import sys
print(sys.executable)
# Out:
# /home/dani/miniconda3/envs/latihan1/bin/python

# %%
import tensorflow as tf
print("TF version:", tf.__version__)
# Out:
# TF version: 2.19.1

# %%
print("Built with CUDA:", tf.test.is_built_with_cuda())
print("GPU devices:", tf.config.list_physical_devices("GPU"))
# Out:
# Built with CUDA: True
# GPU devices: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
print(tf.sysconfig.get_build_info())
# Out:
# OrderedDict({'cpu_compiler': '/usr/lib/llvm-18/bin/clang', 'cuda_compute_capabilities': ['sm_60', 'sm_70', 'sm_80', 'sm_89', 'compute_90'], 'cuda_version': '12.5.1', 'cudnn_version': '9', 'is_cuda_build': True, 'is_rocm_build': False, 'is_tensorrt_build': False})

# %%
import os
print(os.environ.get("LD_LIBRARY_PATH"))
# Out:
# /home/dani/miniconda3/envs/latihan1/lib/python3.12/site-packages/cv2/../../lib64:/usr/lib/x

# %%
import numpy as np
print("True:", np.unique(y_true, return_counts=True))
# Out:
# True: (array([0, 1]), array([438070, 353478]))

# %%
print([v for v in globals() if "y" in v.lower()])
# Out:
# ['get_ipython', '__vsc_ipynb_file__', 'layers', 'history', 'y_true', 'y_prob', 'y_pred_05', 'sys']

# %%
print("Pred:", np.unique(y_pred_05, return_counts=True))
# Out:
# Pred: (array([0]), array([791548]))

# %%
print("Prob mean:", y_prob.mean())
print("Prob min/max:", y_prob.min(), y_prob.max())
# Out:
# Prob mean: 0.49349695
# Prob min/max: 0.49349734 0.49349734

# %%
from sklearn.metrics import confusion_matrix
print(confusion_matrix(y_true, y_pred_05))
# Out:
# [[438070      0]
#  [353478      0]]

# %%
print(history.history["loss"][:5])
print(history.history["val_loss"][:5])
# Out:
# [0.8075411319732666]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[32], line 2
#       1 print(history.history["loss"][:5])
# ----> 2 print(history.history["val_loss"][:5])
#
# KeyError: 'val_loss'
