# %%
import numpy as np
import os
import gc
import time
import matplotlib.pyplot as plt
import seaborn as sns

import tensorflow as tf
from tensorflow.keras import layers, models

from sklearn.metrics import (
    confusion_matrix,
    classification_report,
    roc_curve,
    auc,
    precision_recall_curve,
    f1_score
)

import pandas as pd
import time
from tensorflow.keras.callbacks import Callback, EarlyStopping, ModelCheckpoint
from tensorflow.keras.callbacks import ReduceLROnPlateau, CSVLogger
# Out:
# 2026-03-06 21:56:24.487724: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-03-06 21:56:24.580864: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1772808984.619040  149913 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1772808984.630060  149913 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1772808984.704947  149913 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1772808984.704965  149913 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1772808984.704967  149913 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1772808984.704968  149913 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-03-06 21:56:24.715056: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
DWT_TRAIN_DIR = "/home/dani/Documents/tugas akhir/TugasAkhirku2026/tow_ids/Preprocessing/hasil/Final/imgsize64/norm/dwt"
DWT_TEST_DIR  = "/home/dani/Documents/tugas akhir/TugasAkhirku2026/tow_ids/Preprocessing/hasil/Final/imgsize64/norm/dwt/"

# %%
train_data = np.load(os.path.join(DWT_TRAIN_DIR, "tow_ids_train_dwt.npz"))
test_data  = np.load(os.path.join(DWT_TEST_DIR, "tow_ids_test_dwt.npz"))

X_train = train_data["X"]
y_train = train_data["y"]

X_test  = test_data["X"]
y_test  = test_data["y"]

print(X_train.shape, y_train.shape)
print(X_test.shape, y_test.shape)
# Out:
# (10556, 228, 228, 3) (10556,)
# (6940, 228, 228, 3) (6940,)

# %%
print("Train label distribution:", np.unique(y_train, return_counts=True))
print("Test label distribution :", np.unique(y_test, return_counts=True))

print("Min value:", X_train.min())
print("Max value:", X_train.max())
# Out:
# Train label distribution: (array([0, 1]), array([4263, 6293]))
# Test label distribution : (array([0, 1]), array([3580, 3360]))
# Min value: -1.7790204
# Max value: 7.1202116

# %%
def composite_conv(x, filters, kernel_size, groups=1):

    x = layers.Conv2D(
        filters,
        kernel_size,
        padding="same",
        groups=groups
    )(x)

    x = layers.BatchNormalization()(x)

    x = layers.ReLU()(x)

    return x

# %%
def factorized_conv(x, f1, f2):

    x = composite_conv(x, f1, (1,3))

    x = composite_conv(x, f2, (3,1))

    return x

# %%
def DGC_block(x):

    # branch 1
    b1 = composite_conv(x, 16, (1,3))
    b2 = composite_conv(x, 16, (3,1))

    concat = layers.Concatenate()([b1, b2])

    conv = composite_conv(concat, 32, (1,1))

    pool = layers.MaxPooling2D((2,2))(conv)

    g1 = composite_conv(pool, 64, (1,3), groups=4)


    # residual branch
    res = composite_conv(x, 32, (1,1))

    res = layers.MaxPooling2D((2,2))(res)

    g2 = composite_conv(res, 64, (3,1), groups=4)


    out = layers.Add()([g1, g2])

    return out

# %%
input_layer = layers.Input(shape=(228,228,3))

x_factor = factorized_conv(input_layer, 32, 16)

x_max= layers.MaxPooling2D((2,2))(x_factor)

x_dgc1 = DGC_block(x_max)

x_dgc2 = DGC_block(x_dgc1)

x_comconv = composite_conv(x_dgc2, 32, (1,1))

del x_factor, x_max, x_dgc1, x_dgc2

x_average = layers.GlobalAveragePooling2D()(x_comconv)

x_flatten = layers.Flatten()(x_average)

x_fcon = layers.Dense(128, activation="relu")(x_flatten)

output_layer = layers.Dense(1, activation="sigmoid")(x_fcon)

del x_comconv, x_average, x_flatten, x_fcon
# Out:
# I0000 00:00:1772808995.970931  149913 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 4144 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6

# %%
model = models.Model(
    inputs=input_layer,
    outputs=output_layer
)

model.summary()
# Out:
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 228, 228,  │          0 │ -                 │
# │ (InputLayer)        │ 3)                │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 228, 228,  │        320 │ input_layer[0][0] │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 228, 228,  │        128 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu (ReLU)        │ (None, 228, 228,  │          0 │ batch_normalizat… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 228, 228,  │      1,552 │ re_lu[0][0]       │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 228, 228,  │         64 │ conv2d_1[0][0]    │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_1 (ReLU)      │ (None, 228, 228,  │          0 │ batch_normalizat… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 114, 114,  │          0 │ re_lu_1[0][0]     │
# │ (MaxPooling2D)      │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 114, 114,  │        784 │ max_pooling2d[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 114, 114,  │        784 │ max_pooling2d[0]… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 114, 114,  │         64 │ conv2d_2[0][0]    │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 114, 114,  │         64 │ conv2d_3[0][0]    │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_2 (ReLU)      │ (None, 114, 114,  │          0 │ batch_normalizat… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_3 (ReLU)      │ (None, 114, 114,  │          0 │ batch_normalizat… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 114, 114,  │          0 │ re_lu_2[0][0],    │
# │ (Concatenate)       │ 32)               │            │ re_lu_3[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 114, 114,  │      1,056 │ concatenate[0][0] │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 114, 114,  │        544 │ max_pooling2d[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 114, 114,  │        128 │ conv2d_4[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 114, 114,  │        128 │ conv2d_6[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_4 (ReLU)      │ (None, 114, 114,  │          0 │ batch_normalizat… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_6 (ReLU)      │ (None, 114, 114,  │          0 │ batch_normalizat… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 57, 57,    │          0 │ re_lu_4[0][0]     │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_2     │ (None, 57, 57,    │          0 │ re_lu_6[0][0]     │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 57, 57,    │      1,600 │ max_pooling2d_1[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 57, 57,    │      1,600 │ max_pooling2d_2[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 57, 57,    │        256 │ conv2d_5[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 57, 57,    │        256 │ conv2d_7[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_5 (ReLU)      │ (None, 57, 57,    │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_7 (ReLU)      │ (None, 57, 57,    │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 57, 57,    │          0 │ re_lu_5[0][0],    │
# │                     │ 64)               │            │ re_lu_7[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 57, 57,    │      3,088 │ add[0][0]         │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 57, 57,    │      3,088 │ add[0][0]         │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 57, 57,    │         64 │ conv2d_8[0][0]    │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 57, 57,    │         64 │ conv2d_9[0][0]    │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_8 (ReLU)      │ (None, 57, 57,    │          0 │ batch_normalizat… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_9 (ReLU)      │ (None, 57, 57,    │          0 │ batch_normalizat… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 57, 57,    │          0 │ re_lu_8[0][0],    │
# │ (Concatenate)       │ 32)               │            │ re_lu_9[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 57, 57,    │      1,056 │ concatenate_1[0]… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_12 (Conv2D)  │ (None, 57, 57,    │      2,080 │ add[0][0]         │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 57, 57,    │        128 │ conv2d_10[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 57, 57,    │        128 │ conv2d_12[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_10 (ReLU)     │ (None, 57, 57,    │          0 │ batch_normalizat… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_12 (ReLU)     │ (None, 57, 57,    │          0 │ batch_normalizat… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_3     │ (None, 28, 28,    │          0 │ re_lu_10[0][0]    │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_4     │ (None, 28, 28,    │          0 │ re_lu_12[0][0]    │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_11 (Conv2D)  │ (None, 28, 28,    │      1,600 │ max_pooling2d_3[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_13 (Conv2D)  │ (None, 28, 28,    │      1,600 │ max_pooling2d_4[… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 28, 28,    │        256 │ conv2d_11[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 28, 28,    │        256 │ conv2d_13[0][0]   │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_11 (ReLU)     │ (None, 28, 28,    │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_13 (ReLU)     │ (None, 28, 28,    │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 28, 28,    │          0 │ re_lu_11[0][0],   │
# │                     │ 64)               │            │ re_lu_13[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_14 (Conv2D)  │ (None, 28, 28,    │      2,080 │ add_1[0][0]       │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 28, 28,    │        128 │ conv2d_14[0][0]   │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_14 (ReLU)     │ (None, 28, 28,    │          0 │ batch_normalizat… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 32)        │          0 │ re_lu_14[0][0]    │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ flatten (Flatten)   │ (None, 32)        │          0 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 128)       │      4,224 │ flatten[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 1)         │        129 │ dense[0][0]       │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 29,297 (114.44 KB)
#  Trainable params: 28,241 (110.32 KB)
#  Non-trainable params: 1,056 (4.12 KB)

# %%
model.compile(

    optimizer="adam",

    loss="binary_crossentropy",

    metrics=["accuracy"]
)

# %%
print("TensorFlow version:", tf.__version__)
print("GPU available:", tf.config.list_physical_devices('GPU'))

tf.debugging.set_log_device_placement(True)
# Out:
# TensorFlow version: 2.19.1
# GPU available: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
class TrainingLogger(Callback):

    def on_train_begin(self, logs=None):
        print("\nTraining started")
        print("-"*70)
        print("{:<8} {:<12} {:<12} {:<12} {:<12}".format(
            "Epoch","Loss","Accuracy","Val_Loss","Val_Acc"))
        print("-"*70)

    def on_epoch_end(self, epoch, logs=None):

        print("{:<8} {:<12.4f} {:<12.4f} {:<12.4f} {:<12.4f}".format(
            epoch+1,
            logs["loss"],
            logs["accuracy"],
            logs["val_loss"],
            logs["val_accuracy"]
        ))

# %%
checkpoint = ModelCheckpoint(
    "best_model_tow_ids.keras",
    monitor="val_accuracy",
    save_best_only=True,
    verbose=0
)

# %%
print("\nDataset summary")
print("-"*40)
print("Train samples :", X_train.shape[0])
print("Test samples  :", X_test.shape[0])
print("Image shape   :", X_train.shape[1:])
print("Batch size    :", 16)
print("Epochs        :", 100)
print("-"*40)
# Out:
# Dataset summary
# ----------------------------------------
# Train samples : 10556
# Test samples  : 6940
# Image shape   : (228, 228, 3)
# Batch size    : 16
# Epochs        : 100
# ----------------------------------------

# %%
with tf.device('/CPU:0'):
    train_dataset = tf.data.Dataset.from_tensor_slices((X_train, y_train))
    test_dataset  = tf.data.Dataset.from_tensor_slices((X_test, y_test))

train_dataset = (
    train_dataset
    .shuffle(1000)
    .batch(16)
    .prefetch(tf.data.AUTOTUNE)
)

test_dataset = (
    test_dataset
    .batch(16)
    .prefetch(tf.data.AUTOTUNE)
)

# %%
history = model.fit(
    train_dataset,
    validation_data=test_dataset,
    epochs=100,
    verbose=1,
    callbacks=[checkpoint]
)
# Out:
# Epoch 1/100
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1772809013.827037  150132 service.cc:152] XLA service 0x76d41c004520 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1772809013.827398  150132 service.cc:160]   StreamExecutor device (0): NVIDIA GeForce RTX 3060 Laptop GPU, Compute Capability 8.6
# 2026-03-06 21:56:53.983603: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1772809014.810640  150132 cuda_dnn.cc:529] Loaded cuDNN version 91701
#   5/660 ━━━━━━━━━━━━━━━━━━━━ 20s 31ms/step - accuracy: 0.9715 - loss: 0.6197
# I0000 00:00:1772809022.608952  150132 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 660/660 ━━━━━━━━━━━━━━━━━━━━ 50s 50ms/step - accuracy: 0.9722 - loss: 0.0960 - val_accuracy: 0.9610 - val_loss: 0.1123
# Epoch 2/100
# 660/660 ━━━━━━━━━━━━━━━━━━━━ 23s 35ms/step - accuracy: 0.9800 - loss: 0.0723 - val_accuracy: 0.8356 - val_loss: 0.4105
# Epoch 3/100
# 660/660 ━━━━━━━━━━━━━━━━━━━━ 23s 36ms/step - accuracy: 0.9812 - loss: 0.0611 - val_accuracy: 0.9817 - val_loss: 0.0812
# Epoch 4/100
# 660/660 ━━━━━━━━━━━━━━━━━━━━ 24s 36ms/step - accuracy: 0.9861 - loss: 0.0484 - val_accuracy: 0.9826 - val_loss: 0.0697
# Epoch 5/100
# 660/660 ━━━━━━━━━━━━━━━━━━━━ 23s 36ms/step - accuracy: 0.9836 - loss: 0.0531 - val_accuracy: 0.9826 - val_loss: 0.0804
# Epoch 6/100
# 660/660 ━━━━━━━━━━━━━━━━━━━━ 24s 36ms/step - accuracy: 0.9856 - loss: 0.0490 - val_accuracy: 0.9503 - val_loss: 0.1848
# Epoch 7/100
# 660/660 ━━━━━━━━━━━━━━━━━━━━ 24s 36ms/step - accuracy: 0.9901 - loss: 0.0321 - val_accuracy: 0.9759 - val_loss: 0.0715
# Epoch 8/100
# 660/660 ━━━━━━━━━━━━━━━━━━━━ 24s 36ms/step - accuracy: 0.9916 - loss: 0.0273 - val_accuracy: 0.9829 - val_loss: 0.0759
# Epoch 9/100
# 660/660 ━━━━━━━━━━━━━━━━━━━━ 24s 36ms/step - accuracy: 0.9928 - loss: 0.0265 - val_accuracy: 0.9879 - val_loss: 0.0705
# Epoch 10/100
# 660/660 ━━━━━━━━━━━━━━━━━━━━ 24s 36ms/step - accuracy: 0.9927 - loss: 0.0249 - val_accuracy: 0.9906 - val_loss: 0.0481
# Epoch 11/100
# 660/660 ━━━━━━━━━━━━━━━━━━━━ 24s 36ms/step - accuracy: 0.9919 - loss: 0.0285 - val_accuracy: 0.9901 - val_loss: 0.0541
# Epoch 12/100
# 660/660 ━━━━━━━━━━━━━━━━━━━━ 24s 36ms/step - accuracy: 0.9921 - loss: 0.0275 - val_accuracy: 0.9735 - val_loss: 0.1079
# Epoch 13/100
# 660/660 ━━━━━━━━━━━━━━━━━━━━ 24s 36ms/step - accuracy: 0.9927 - loss: 0.0268 - val_accuracy: 0.9866 - val_loss: 0.0749
# Epoch 14/100
# 660/660 ━━━━━━━━━━━━━━━━━━━━ 24s 37ms/step - accuracy: 0.9946 - loss: 0.0188 - val_accuracy: 0.9732 - val_loss: 0.1227
# Epoch 15/100
# 660/660 ━━━━━━━━━━━━━━━━━━━━ 25s 39ms/step - accuracy: 0.9936 - loss: 0.0217 - val_accuracy: 0.9932 - val_loss: 0.0454
# Epoch 16/100
# 660/660 ━━━━━━━━━━━━━━━━━━━━ 27s 41ms/step - accuracy: 0.9960 - loss: 0.0146 - val_accuracy: 0.9921 - val_loss: 0.0440
# Epoch 17/100
# 660/660 ━━━━━━━━━━━━━━━━━━━━ 27s 41ms/step - accuracy: 0.9968 - loss: 0.0141 - val_accuracy: 0.9862 - val_loss: 0.0951
# Epoch 18/100
# 660/660 ━━━━━━━━━━━━━━━━━━━━ 26s 39ms/step - accuracy: 0.9973 - loss: 0.0113 - val_accuracy: 0.9331 - val_loss: 0.2307
# Epoch 19/100
# 660/660 ━━━━━━━━━━━━━━━━━━━━ 24s 37ms/step - accuracy: 0.9974 - loss: 0.0112 - val_accuracy: 0.9759 - val_loss: 0.1258
# Epoch 20/100
# 660/660 ━━━━━━━━━━━━━━━━━━━━ 24s 37ms/step - accuracy: 0.9971 - loss: 0.0098 - val_accuracy: 0.9853 - val_loss: 0.0665
# Epoch 21/100
# 660/660 ━━━━━━━━━━━━━━━━━━━━ 24s 37ms/step - accuracy: 0.9977 - loss: 0.0091 - val_accuracy: 0.8601 - val_loss: 0.3316
# Epoch 22/100
# 660/660 ━━━━━━━━━━━━━━━━━━━━ 24s 37ms/step - accuracy: 0.9981 - loss: 0.0070 - val_accuracy: 0.9951 - val_loss: 0.0272
# Epoch 23/100
# 660/660 ━━━━━━━━━━━━━━━━━━━━ 24s 37ms/step - accuracy: 0.9987 - loss: 0.0059 - val_accuracy: 0.9045 - val_loss: 0.2926
# Epoch 24/100
# 660/660 ━━━━━━━━━━━━━━━━━━━━ 24s 37ms/step - accuracy: 0.9979 - loss: 0.0069 - val_accuracy: 0.9622 - val_loss: 0.1474
# Epoch 25/100
# 660/660 ━━━━━━━━━━━━━━━━━━━━ 24s 37ms/step - accuracy: 0.9982 - loss: 0.0057 - val_accuracy: 0.9820 - val_loss: 0.1221
# Epoch 26/100
# 660/660 ━━━━━━━━━━━━━━━━━━━━ 24s 37ms/step - accuracy: 0.9982 - loss: 0.0072 - val_accuracy: 0.9954 - val_loss: 0.0408
# Epoch 27/100
# 660/660 ━━━━━━━━━━━━━━━━━━━━ 25s 37ms/step - accuracy: 0.9987 - loss: 0.0046 - val_accuracy: 0.9944 - val_loss: 0.0445
# Epoch 28/100
# 660/660 ━━━━━━━━━━━━━━━━━━━━ 25s 38ms/step - accuracy: 0.9991 - loss: 0.0041 - val_accuracy: 0.9918 - val_loss: 0.0987
# Epoch 29/100
# 660/660 ━━━━━━━━━━━━━━━━━━━━ 25s 37ms/step - accuracy: 0.9980 - loss: 0.0056 - val_accuracy: 0.9633 - val_loss: 0.1751
# Epoch 30/100
# 660/660 ━━━━━━━━━━━━━━━━━━━━ 25s 37ms/step - accuracy: 0.9989 - loss: 0.0040 - val_accuracy: 0.9731 - val_loss: 0.1227
# Epoch 31/100
# 660/660 ━━━━━━━━━━━━━━━━━━━━ 25s 37ms/step - accuracy: 0.9991 - loss: 0.0027 - val_accuracy: 0.9914 - val_loss: 0.0654
# Epoch 32/100
# 660/660 ━━━━━━━━━━━━━━━━━━━━ 25s 37ms/step - accuracy: 0.9986 - loss: 0.0042 - val_accuracy: 0.9506 - val_loss: 0.1953
# Epoch 33/100
# 660/660 ━━━━━━━━━━━━━━━━━━━━ 25s 38ms/step - accuracy: 0.9989 - loss: 0.0037 - val_accuracy: 0.8517 - val_loss: 0.5517
# Epoch 34/100
# 660/660 ━━━━━━━━━━━━━━━━━━━━ 24s 37ms/step - accuracy: 0.9991 - loss: 0.0018 - val_accuracy: 0.9682 - val_loss: 0.1478
# Epoch 35/100
# 660/660 ━━━━━━━━━━━━━━━━━━━━ 25s 38ms/step - accuracy: 0.9991 - loss: 0.0030 - val_accuracy: 0.9020 - val_loss: 0.3282
# Epoch 36/100
# 660/660 ━━━━━━━━━━━━━━━━━━━━ 25s 37ms/step - accuracy: 0.9987 - loss: 0.0038 - val_accuracy: 0.9091 - val_loss: 0.4303
# Epoch 37/100
# 660/660 ━━━━━━━━━━━━━━━━━━━━ 25s 37ms/step - accuracy: 0.9988 - loss: 0.0039 - val_accuracy: 0.9921 - val_loss: 0.0911
# Epoch 38/100
# 660/660 ━━━━━━━━━━━━━━━━━━━━ 25s 38ms/step - accuracy: 0.9994 - loss: 0.0027 - val_accuracy: 0.9821 - val_loss: 0.1069
# Epoch 39/100
# 660/660 ━━━━━━━━━━━━━━━━━━━━ 25s 38ms/step - accuracy: 1.0000 - loss: 4.8039e-04 - val_accuracy: 0.9872 - val_loss: 0.1051
# Epoch 40/100
# 660/660 ━━━━━━━━━━━━━━━━━━━━ 24s 37ms/step - accuracy: 0.9996 - loss: 0.0013 - val_accuracy: 0.9801 - val_loss: 0.1305
# Epoch 41/100
# 660/660 ━━━━━━━━━━━━━━━━━━━━ 25s 38ms/step - accuracy: 0.9972 - loss: 0.0098 - val_accuracy: 0.9548 - val_loss: 0.1888
# Epoch 42/100
# 660/660 ━━━━━━━━━━━━━━━━━━━━ 25s 37ms/step - accuracy: 0.9968 - loss: 0.0087 - val_accuracy: 0.9673 - val_loss: 0.1521
# Epoch 43/100
# 660/660 ━━━━━━━━━━━━━━━━━━━━ 25s 38ms/step - accuracy: 0.9996 - loss: 0.0013 - val_accuracy: 0.9916 - val_loss: 0.0745
# Epoch 44/100
# 660/660 ━━━━━━━━━━━━━━━━━━━━ 25s 37ms/step - accuracy: 0.9994 - loss: 0.0015 - val_accuracy: 0.9442 - val_loss: 0.2216
# Epoch 45/100
# 660/660 ━━━━━━━━━━━━━━━━━━━━ 25s 38ms/step - accuracy: 0.9994 - loss: 0.0019 - val_accuracy: 0.8684 - val_loss: 0.7758
# Epoch 46/100
# 660/660 ━━━━━━━━━━━━━━━━━━━━ 25s 38ms/step - accuracy: 0.9996 - loss: 0.0013 - val_accuracy: 0.9709 - val_loss: 0.1434
# Epoch 47/100
# 660/660 ━━━━━━━━━━━━━━━━━━━━ 25s 37ms/step - accuracy: 0.9995 - loss: 0.0018 - val_accuracy: 0.9791 - val_loss: 0.1110
# Epoch 48/100
# 660/660 ━━━━━━━━━━━━━━━━━━━━ 25s 38ms/step - accuracy: 0.9999 - loss: 6.0666e-04 - val_accuracy: 0.9927 - val_loss: 0.0569
# Epoch 49/100
# 660/660 ━━━━━━━━━━━━━━━━━━━━ 25s 38ms/step - accuracy: 0.9989 - loss: 0.0038 - val_accuracy: 0.9761 - val_loss: 0.2057
# Epoch 50/100
# 660/660 ━━━━━━━━━━━━━━━━━━━━ 25s 38ms/step - accuracy: 0.9988 - loss: 0.0046 - val_accuracy: 0.9932 - val_loss: 0.0733
# Epoch 51/100
# 660/660 ━━━━━━━━━━━━━━━━━━━━ 25s 38ms/step - accuracy: 0.9992 - loss: 0.0016 - val_accuracy: 0.9824 - val_loss: 0.1070
# Epoch 52/100
# 660/660 ━━━━━━━━━━━━━━━━━━━━ 25s 38ms/step - accuracy: 0.9999 - loss: 9.4098e-04 - val_accuracy: 0.9452 - val_loss: 0.2100
# Epoch 53/100
# 660/660 ━━━━━━━━━━━━━━━━━━━━ 25s 38ms/step - accuracy: 0.9998 - loss: 5.6586e-04 - val_accuracy: 0.9934 - val_loss: 0.0846
# Epoch 54/100
# 660/660 ━━━━━━━━━━━━━━━━━━━━ 25s 38ms/step - accuracy: 0.9991 - loss: 0.0037 - val_accuracy: 0.8565 - val_loss: 1.6814
# Epoch 55/100
# 660/660 ━━━━━━━━━━━━━━━━━━━━ 25s 38ms/step - accuracy: 0.9995 - loss: 0.0021 - val_accuracy: 0.9692 - val_loss: 0.1477
# Epoch 56/100
# 660/660 ━━━━━━━━━━━━━━━━━━━━ 25s 38ms/step - accuracy: 0.9999 - loss: 5.4189e-04 - val_accuracy: 0.9912 - val_loss: 0.0812
# Epoch 57/100
# 660/660 ━━━━━━━━━━━━━━━━━━━━ 25s 38ms/step - accuracy: 0.9991 - loss: 0.0032 - val_accuracy: 0.9929 - val_loss: 0.0772
# Epoch 58/100
# 660/660 ━━━━━━━━━━━━━━━━━━━━ 25s 38ms/step - accuracy: 0.9995 - loss: 0.0016 - val_accuracy: 0.9954 - val_loss: 0.0479
# Epoch 59/100
# 660/660 ━━━━━━━━━━━━━━━━━━━━ 25s 38ms/step - accuracy: 0.9998 - loss: 6.8374e-04 - val_accuracy: 0.9938 - val_loss: 0.0806
# Epoch 60/100
# 660/660 ━━━━━━━━━━━━━━━━━━━━ 25s 38ms/step - accuracy: 0.9994 - loss: 0.0012 - val_accuracy: 0.9478 - val_loss: 0.5574
# Epoch 61/100
# 660/660 ━━━━━━━━━━━━━━━━━━━━ 25s 38ms/step - accuracy: 0.9993 - loss: 0.0024 - val_accuracy: 0.9829 - val_loss: 0.1011
# Epoch 62/100
# 660/660 ━━━━━━━━━━━━━━━━━━━━ 25s 38ms/step - accuracy: 0.9998 - loss: 6.9825e-04 - val_accuracy: 0.9928 - val_loss: 0.0586
# Epoch 63/100
# 660/660 ━━━━━━━━━━━━━━━━━━━━ 25s 38ms/step - accuracy: 1.0000 - loss: 2.2194e-04 - val_accuracy: 0.9878 - val_loss: 0.1082
# Epoch 64/100
# 660/660 ━━━━━━━━━━━━━━━━━━━━ 25s 38ms/step - accuracy: 0.9991 - loss: 0.0036 - val_accuracy: 0.9892 - val_loss: 0.1008
# Epoch 65/100
# 660/660 ━━━━━━━━━━━━━━━━━━━━ 26s 39ms/step - accuracy: 1.0000 - loss: 3.6344e-04 - val_accuracy: 0.9814 - val_loss: 0.0951
# Epoch 66/100
# 660/660 ━━━━━━━━━━━━━━━━━━━━ 25s 38ms/step - accuracy: 0.9998 - loss: 3.8168e-04 - val_accuracy: 0.9939 - val_loss: 0.0672
# Epoch 67/100
# 660/660 ━━━━━━━━━━━━━━━━━━━━ 26s 39ms/step - accuracy: 0.9993 - loss: 0.0030 - val_accuracy: 0.9810 - val_loss: 0.2155
# Epoch 68/100
# 660/660 ━━━━━━━━━━━━━━━━━━━━ 25s 37ms/step - accuracy: 0.9992 - loss: 0.0020 - val_accuracy: 0.9754 - val_loss: 0.2003
# Epoch 69/100
# 660/660 ━━━━━━━━━━━━━━━━━━━━ 25s 37ms/step - accuracy: 0.9995 - loss: 0.0017 - val_accuracy: 0.9908 - val_loss: 0.0649
# Epoch 70/100
# 660/660 ━━━━━━━━━━━━━━━━━━━━ 25s 38ms/step - accuracy: 0.9996 - loss: 7.7529e-04 - val_accuracy: 0.9929 - val_loss: 0.0866
# Epoch 71/100
# 660/660 ━━━━━━━━━━━━━━━━━━━━ 25s 38ms/step - accuracy: 0.9994 - loss: 0.0021 - val_accuracy: 0.9843 - val_loss: 0.1216
# Epoch 72/100
# 660/660 ━━━━━━━━━━━━━━━━━━━━ 25s 38ms/step - accuracy: 1.0000 - loss: 1.1089e-04 - val_accuracy: 0.9929 - val_loss: 0.0830
# Epoch 73/100
# 660/660 ━━━━━━━━━━━━━━━━━━━━ 25s 38ms/step - accuracy: 1.0000 - loss: 9.5246e-05 - val_accuracy: 0.9909 - val_loss: 0.0875
# Epoch 74/100
# 660/660 ━━━━━━━━━━━━━━━━━━━━ 25s 38ms/step - accuracy: 1.0000 - loss: 4.9918e-05 - val_accuracy: 0.9937 - val_loss: 0.0763
# Epoch 75/100
# 660/660 ━━━━━━━━━━━━━━━━━━━━ 26s 39ms/step - accuracy: 1.0000 - loss: 2.7462e-05 - val_accuracy: 0.9942 - val_loss: 0.0705
# Epoch 76/100
# 660/660 ━━━━━━━━━━━━━━━━━━━━ 26s 39ms/step - accuracy: 1.0000 - loss: 1.6727e-05 - val_accuracy: 0.9902 - val_loss: 0.1187
# Epoch 77/100
# 660/660 ━━━━━━━━━━━━━━━━━━━━ 25s 38ms/step - accuracy: 0.9980 - loss: 0.0090 - val_accuracy: 0.9908 - val_loss: 0.0390
# Epoch 78/100
# 660/660 ━━━━━━━━━━━━━━━━━━━━ 25s 38ms/step - accuracy: 0.9996 - loss: 0.0010 - val_accuracy: 0.9950 - val_loss: 0.0622
# Epoch 79/100
# 660/660 ━━━━━━━━━━━━━━━━━━━━ 25s 38ms/step - accuracy: 0.9996 - loss: 0.0013 - val_accuracy: 0.9960 - val_loss: 0.0618
# Epoch 80/100
# 660/660 ━━━━━━━━━━━━━━━━━━━━ 25s 38ms/step - accuracy: 0.9995 - loss: 0.0012 - val_accuracy: 0.9875 - val_loss: 0.0662
# Epoch 81/100
# 660/660 ━━━━━━━━━━━━━━━━━━━━ 26s 39ms/step - accuracy: 1.0000 - loss: 1.8537e-04 - val_accuracy: 0.9873 - val_loss: 0.0942
# Epoch 82/100
# 660/660 ━━━━━━━━━━━━━━━━━━━━ 25s 38ms/step - accuracy: 0.9991 - loss: 0.0021 - val_accuracy: 0.9679 - val_loss: 0.1499
# Epoch 83/100
# 660/660 ━━━━━━━━━━━━━━━━━━━━ 25s 38ms/step - accuracy: 0.9998 - loss: 0.0010 - val_accuracy: 0.9942 - val_loss: 0.0592
# Epoch 84/100
# 660/660 ━━━━━━━━━━━━━━━━━━━━ 25s 38ms/step - accuracy: 1.0000 - loss: 1.9051e-04 - val_accuracy: 0.9924 - val_loss: 0.0931
# Epoch 85/100
# 660/660 ━━━━━━━━━━━━━━━━━━━━ 25s 38ms/step - accuracy: 0.9999 - loss: 3.5609e-04 - val_accuracy: 0.9939 - val_loss: 0.0796
# Epoch 86/100
# 660/660 ━━━━━━━━━━━━━━━━━━━━ 25s 38ms/step - accuracy: 1.0000 - loss: 5.5068e-05 - val_accuracy: 0.9950 - val_loss: 0.0672
# Epoch 87/100
# 660/660 ━━━━━━━━━━━━━━━━━━━━ 25s 38ms/step - accuracy: 0.9991 - loss: 0.0020 - val_accuracy: 0.9939 - val_loss: 0.0839
# Epoch 88/100
# 660/660 ━━━━━━━━━━━━━━━━━━━━ 26s 39ms/step - accuracy: 0.9988 - loss: 0.0033 - val_accuracy: 0.9938 - val_loss: 0.0794
# Epoch 89/100
# 660/660 ━━━━━━━━━━━━━━━━━━━━ 26s 39ms/step - accuracy: 0.9998 - loss: 7.2859e-04 - val_accuracy: 0.9932 - val_loss: 0.0851
# Epoch 90/100
# 660/660 ━━━━━━━━━━━━━━━━━━━━ 25s 38ms/step - accuracy: 1.0000 - loss: 1.4969e-04 - val_accuracy: 0.9951 - val_loss: 0.0645
# Epoch 91/100
# 660/660 ━━━━━━━━━━━━━━━━━━━━ 25s 38ms/step - accuracy: 0.9992 - loss: 0.0030 - val_accuracy: 0.9707 - val_loss: 0.1458
# Epoch 92/100
# 660/660 ━━━━━━━━━━━━━━━━━━━━ 25s 38ms/step - accuracy: 0.9997 - loss: 6.1029e-04 - val_accuracy: 0.9906 - val_loss: 0.0773
# Epoch 93/100
# 660/660 ━━━━━━━━━━━━━━━━━━━━ 26s 39ms/step - accuracy: 0.9999 - loss: 2.3482e-04 - val_accuracy: 0.9924 - val_loss: 0.0693
# Epoch 94/100
# 660/660 ━━━━━━━━━━━━━━━━━━━━ 26s 39ms/step - accuracy: 0.9999 - loss: 2.2880e-04 - val_accuracy: 0.9918 - val_loss: 0.0840
# Epoch 95/100
# 660/660 ━━━━━━━━━━━━━━━━━━━━ 26s 39ms/step - accuracy: 0.9991 - loss: 0.0032 - val_accuracy: 0.6053 - val_loss: 2.2706
# Epoch 96/100
# 660/660 ━━━━━━━━━━━━━━━━━━━━ 25s 38ms/step - accuracy: 0.9999 - loss: 7.6026e-04 - val_accuracy: 0.9927 - val_loss: 0.0763
# Epoch 97/100
# 660/660 ━━━━━━━━━━━━━━━━━━━━ 25s 38ms/step - accuracy: 0.9998 - loss: 2.9822e-04 - val_accuracy: 0.9676 - val_loss: 0.2190
# Epoch 98/100
# 660/660 ━━━━━━━━━━━━━━━━━━━━ 25s 38ms/step - accuracy: 0.9991 - loss: 0.0037 - val_accuracy: 0.9863 - val_loss: 0.1232
# Epoch 99/100
# 660/660 ━━━━━━━━━━━━━━━━━━━━ 25s 38ms/step - accuracy: 0.9994 - loss: 0.0014 - val_accuracy: 0.9927 - val_loss: 0.0602
# Epoch 100/100
# 660/660 ━━━━━━━━━━━━━━━━━━━━ 26s 39ms/step - accuracy: 0.9997 - loss: 0.0012 - val_accuracy: 0.9903 - val_loss: 0.0979

# %%
import numpy as np
from sklearn.metrics import confusion_matrix

# prediksi probabilitas
y_prob = model.predict(test_dataset)

# konversi menjadi label
y_pred = (y_prob > 0.5).astype(int).flatten()
# Out:
# 434/434 ━━━━━━━━━━━━━━━━━━━━ 6s 11ms/step

# %%
y_true = y_test

# %%
cm = confusion_matrix(y_true, y_pred)

TN, FP, FN, TP = cm.ravel()

print("Confusion Matrix")
print(cm)
# Out:
# Confusion Matrix
# [[3523   57]
#  [  10 3350]]

# %%
accuracy = (TP + TN) / (TP + TN + FP + FN)

precision = TP / (TP + FP + 1e-8)

recall = TP / (TP + FN + 1e-8)

f1 = 2 * precision * recall / (precision + recall + 1e-8)

FPR = FP / (FP + TN + 1e-8)

FNR = FN / (FN + TP + 1e-8)

# %%
print("\nEvaluation Metrics")
print("-------------------")

print("Accuracy :", accuracy)
print("Precision:", precision)
print("Recall   :", recall)
print("F1-score :", f1)

print("\nIDS Specific Metrics")
print("-------------------")

print("FPR:", FPR)
print("FNR:", FNR)
# Out:
# Evaluation Metrics
# -------------------
# Accuracy : 0.9903458213256484
# Precision: 0.9832697387702282
# Recall   : 0.9970238095208422
# F1-score : 0.9900990048983052
#
# IDS Specific Metrics
# -------------------
# FPR: 0.015921787709452732
# FNR: 0.0029761904761816185

# %%
from sklearn.metrics import roc_curve, auc

fpr, tpr, _ = roc_curve(y_true, y_prob)

roc_auc = auc(fpr, tpr)

plt.figure()

plt.plot(fpr, tpr, label="AUC = %0.4f" % roc_auc)

plt.plot([0,1],[0,1],'--')

plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve")

plt.legend()

plt.show()
