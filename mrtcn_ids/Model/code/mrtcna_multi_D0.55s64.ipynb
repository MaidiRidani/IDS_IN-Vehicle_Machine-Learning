# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import (
    Input, Conv1D, BatchNormalization,
    ReLU, Add, GlobalAveragePooling1D, Dense
)
from tensorflow.keras.models import Model
# Out:
# 2025-12-31 13:31:41.461959: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-31 13:31:41.474569: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1767162701.489264  512291 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1767162701.493976  512291 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1767162701.505250  512291 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1767162701.505271  512291 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1767162701.505272  512291 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1767162701.505273  512291 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-12-31 13:31:41.508970: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# !free -h
# Out:
#                total        used        free      shared  buff/cache   available
# Mem:            31Gi       7.4Gi        16Gi       703Mi       8.6Gi        23Gi
# Swap:           14Gi       2.1Gi        12Gi

# %%
# %whos
# Out:
# Variable                 Type        Data/Info
# ----------------------------------------------
# Add                      type        <class 'keras.src.layers.merging.add.Add'>
# BatchNormalization       type        <class 'keras.src.layers.<...>tion.BatchNormalization'>
# Conv1D                   type        <class 'keras.src.layers.<...>olutional.conv1d.Conv1D'>
# Dense                    type        <class 'keras.src.layers.core.dense.Dense'>
# GlobalAveragePooling1D   type        <class 'keras.src.layers.<...>.GlobalAveragePooling1D'>
# Input                    function    <function Input at 0x7840cd6b32e0>
# Model                    type        <class 'keras.src.models.model.Model'>
# ReLU                     type        <class 'keras.src.layers.activations.relu.ReLU'>
# np                       module      <module 'numpy' from '/ho<...>kages/numpy/__init__.py'>
# tf                       module      <module 'tensorflow' from<...>/tensorflow/__init__.py'>

# %%
data = np.load("preprocessingW64S64multifloat32/tow_ids_multi_preprocessedW64S64.npz")

X_train = data["x_train"]
y_train = data["y_train"]
X_val   = data["x_val"]
y_val   = data["y_val"]
X_test  = data["x_test"]
y_test  = data["y_test"]

print(X_train.shape, y_train.shape)
print(X_val.shape, y_val.shape)
print(X_test.shape, y_test.shape)
# Out:
# (13165, 64, 64) (13165,)
# (5643, 64, 64) (5643,)
# (12368, 64, 64) (12368,)

# %%
np.unique(y_test)
# Out:
# array([0, 1, 2, 3, 4, 5])

# %%
def tcn_block(x, filters, kernel_size, dilation):
    shortcut = x

    x = Conv1D(filters, kernel_size,
               padding="causal",
               dilation_rate=dilation)(x)
    x = BatchNormalization()(x)
    x = ReLU()(x)

    x = Conv1D(filters, kernel_size,
               padding="causal",
               dilation_rate=dilation)(x)
    x = BatchNormalization()(x)

    if shortcut.shape[-1] != filters:
        shortcut = Conv1D(filters, 1, padding="same")(shortcut)

    x = Add()([x, shortcut])
    x = ReLU()(x)
    return x

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import (
    Input,
    Conv1D,
    Dropout,
    MaxPooling1D,
    Flatten,
    Dense
)

def build_mr_tcn_multiclass(
    input_shape=(64, 64),
    num_classes=6,
    dropout_rate=0.55
):
    model = Sequential()

    # Explicit Input layer (best practice for paper)
    model.add(Input(shape=input_shape))

    # Conv1D Block 1
    model.add(Conv1D(
        filters=64,
        kernel_size=3,
        strides=1,
        dilation_rate=1,
        padding="same",
        activation="relu"
    ))
    model.add(Dropout(dropout_rate))

    # Conv1D Block 2
    model.add(Conv1D(
        filters=64,
        kernel_size=3,
        strides=1,
        dilation_rate=2,
        padding="same",
        activation="relu"
    ))
    model.add(Dropout(dropout_rate))

    # Conv1D Block 3
    model.add(Conv1D(
        filters=64,
        kernel_size=3,
        strides=1,
        dilation_rate=4,
        padding="same",
        activation="relu"
    ))
    model.add(Dropout(dropout_rate))

    # Temporal Downsampling
    model.add(MaxPooling1D(pool_size=8, strides=8))

    # Flatten
    model.add(Flatten())
    model.add(Dropout(dropout_rate))

    # Multiclass Classification Head
    model.add(Dense(
        num_classes,
        activation="softmax"
    ))

    return model

# %%
model = build_mr_tcn_multiclass(
    input_shape=(64, 64),
    num_classes=6,
    dropout_rate=0.55
)

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-5),
    loss="sparse_categorical_crossentropy",
    metrics=["accuracy"]
)

model.summary()
# Out:
# I0000 00:00:1767162704.672159  512291 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 4136 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d (Conv1D)                 │ (None, 64, 64)         │        12,352 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_1 (Conv1D)               │ (None, 64, 64)         │        12,352 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 64, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_2 (Conv1D)               │ (None, 64, 64)         │        12,352 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 64, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d (MaxPooling1D)    │ (None, 8, 64)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 6)              │         3,078 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 40,134 (156.77 KB)
#  Trainable params: 40,134 (156.77 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

early_stop = EarlyStopping(
    monitor="val_loss",
    patience=30,
    restore_best_weights=True
)

checkpoint = ModelCheckpoint(
    "best_mr_tcn.keras",
    monitor="val_loss",
    save_best_only=True,
    verbose=1
)

# %%
history = model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=700,
    batch_size=64,
    callbacks=[early_stop, checkpoint]
)
# Out:
# Epoch 1/700
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1767162705.995400  512437 service.cc:152] XLA service 0x783f2801c550 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1767162705.995416  512437 service.cc:160]   StreamExecutor device (0): NVIDIA GeForce RTX 3060 Laptop GPU, Compute Capability 8.6
# 2025-12-31 13:31:46.017588: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1767162706.144011  512437 cuda_dnn.cc:529] Loaded cuDNN version 91200
#  82/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.1042 - loss: 3.9070
# I0000 00:00:1767162708.867512  512437 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.1153 - loss: 3.6331
# Epoch 1: val_loss improved from None to 1.81702, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 8s 20ms/step - accuracy: 0.1319 - loss: 3.2533 - val_accuracy: 0.1327 - val_loss: 1.8170
# Epoch 2/700
# 205/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.1792 - loss: 2.5560
# Epoch 2: val_loss improved from 1.81702 to 1.71630, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2011 - loss: 2.4239 - val_accuracy: 0.4299 - val_loss: 1.7163
# Epoch 3/700
# 205/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.2618 - loss: 2.1037
# Epoch 3: val_loss improved from 1.71630 to 1.67933, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.2722 - loss: 2.0776 - val_accuracy: 0.4707 - val_loss: 1.6793
# Epoch 4/700
# 202/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3066 - loss: 1.9733
# Epoch 4: val_loss improved from 1.67933 to 1.66620, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3108 - loss: 1.9492 - val_accuracy: 0.4643 - val_loss: 1.6662
# Epoch 5/700
# 184/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3334 - loss: 1.8876
# Epoch 5: val_loss improved from 1.66620 to 1.66396, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3382 - loss: 1.8713 - val_accuracy: 0.4606 - val_loss: 1.6640
# Epoch 6/700
# 190/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3505 - loss: 1.8062
# Epoch 6: val_loss improved from 1.66396 to 1.66303, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3483 - loss: 1.8074 - val_accuracy: 0.4597 - val_loss: 1.6630
# Epoch 7/700
# 196/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3692 - loss: 1.7665
# Epoch 7: val_loss did not improve from 1.66303
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3676 - loss: 1.7680 - val_accuracy: 0.4590 - val_loss: 1.6641
# Epoch 8/700
# 200/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3613 - loss: 1.7557
# Epoch 8: val_loss did not improve from 1.66303
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3693 - loss: 1.7379 - val_accuracy: 0.4584 - val_loss: 1.6654
# Epoch 9/700
# 199/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3871 - loss: 1.7030
# Epoch 9: val_loss did not improve from 1.66303
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3884 - loss: 1.6952 - val_accuracy: 0.4579 - val_loss: 1.6660
# Epoch 10/700
# 199/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3924 - loss: 1.6709
# Epoch 10: val_loss did not improve from 1.66303
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.3884 - loss: 1.6776 - val_accuracy: 0.4572 - val_loss: 1.6676
# Epoch 11/700
# 198/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.3948 - loss: 1.6554
# Epoch 11: val_loss did not improve from 1.66303
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4010 - loss: 1.6425 - val_accuracy: 0.4570 - val_loss: 1.6672
# Epoch 12/700
# 201/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4038 - loss: 1.6360
# Epoch 12: val_loss did not improve from 1.66303
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4075 - loss: 1.6278 - val_accuracy: 0.4568 - val_loss: 1.6673
# Epoch 13/700
# 179/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4111 - loss: 1.6384
# Epoch 13: val_loss did not improve from 1.66303
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4130 - loss: 1.6242 - val_accuracy: 0.4565 - val_loss: 1.6677
# Epoch 14/700
# 194/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4178 - loss: 1.6203
# Epoch 14: val_loss did not improve from 1.66303
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4228 - loss: 1.6087 - val_accuracy: 0.4565 - val_loss: 1.6685
# Epoch 15/700
# 188/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4184 - loss: 1.6019
# Epoch 15: val_loss did not improve from 1.66303
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4197 - loss: 1.5992 - val_accuracy: 0.4565 - val_loss: 1.6677
# Epoch 16/700
# 198/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4257 - loss: 1.5928
# Epoch 16: val_loss did not improve from 1.66303
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4287 - loss: 1.5968 - val_accuracy: 0.4565 - val_loss: 1.6683
# Epoch 17/700
# 186/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4261 - loss: 1.5892
# Epoch 17: val_loss did not improve from 1.66303
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4328 - loss: 1.5803 - val_accuracy: 0.4565 - val_loss: 1.6682
# Epoch 18/700
# 202/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4303 - loss: 1.5790
# Epoch 18: val_loss did not improve from 1.66303
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4393 - loss: 1.5635 - val_accuracy: 0.4565 - val_loss: 1.6670
# Epoch 19/700
# 195/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4324 - loss: 1.5787
# Epoch 19: val_loss did not improve from 1.66303
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4345 - loss: 1.5749 - val_accuracy: 0.4565 - val_loss: 1.6673
# Epoch 20/700
# 196/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4498 - loss: 1.5578
# Epoch 20: val_loss did not improve from 1.66303
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4430 - loss: 1.5599 - val_accuracy: 0.4565 - val_loss: 1.6664
# Epoch 21/700
# 199/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4482 - loss: 1.5582
# Epoch 21: val_loss did not improve from 1.66303
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4480 - loss: 1.5551 - val_accuracy: 0.4565 - val_loss: 1.6660
# Epoch 22/700
# 188/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4476 - loss: 1.5531
# Epoch 22: val_loss did not improve from 1.66303
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4478 - loss: 1.5505 - val_accuracy: 0.4565 - val_loss: 1.6654
# Epoch 23/700
# 202/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4557 - loss: 1.5375
# Epoch 23: val_loss did not improve from 1.66303
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4494 - loss: 1.5435 - val_accuracy: 0.4565 - val_loss: 1.6648
# Epoch 24/700
# 187/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4500 - loss: 1.5510
# Epoch 24: val_loss did not improve from 1.66303
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4529 - loss: 1.5401 - val_accuracy: 0.4565 - val_loss: 1.6639
# Epoch 25/700
# 192/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4500 - loss: 1.5354
# Epoch 25: val_loss improved from 1.66303 to 1.66290, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4536 - loss: 1.5315 - val_accuracy: 0.4565 - val_loss: 1.6629
# Epoch 26/700
# 193/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4481 - loss: 1.5334
# Epoch 26: val_loss improved from 1.66290 to 1.66233, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4516 - loss: 1.5309 - val_accuracy: 0.4565 - val_loss: 1.6623
# Epoch 27/700
# 189/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4565 - loss: 1.5317
# Epoch 27: val_loss improved from 1.66233 to 1.66158, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4548 - loss: 1.5225 - val_accuracy: 0.4565 - val_loss: 1.6616
# Epoch 28/700
# 197/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4624 - loss: 1.5175
# Epoch 28: val_loss improved from 1.66158 to 1.66018, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4583 - loss: 1.5224 - val_accuracy: 0.4565 - val_loss: 1.6602
# Epoch 29/700
# 186/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4545 - loss: 1.5225
# Epoch 29: val_loss improved from 1.66018 to 1.65959, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4572 - loss: 1.5157 - val_accuracy: 0.4565 - val_loss: 1.6596
# Epoch 30/700
# 198/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4591 - loss: 1.5137
# Epoch 30: val_loss improved from 1.65959 to 1.65760, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4599 - loss: 1.5085 - val_accuracy: 0.4565 - val_loss: 1.6576
# Epoch 31/700
# 195/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4650 - loss: 1.4964
# Epoch 31: val_loss improved from 1.65760 to 1.65588, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4608 - loss: 1.5017 - val_accuracy: 0.4565 - val_loss: 1.6559
# Epoch 32/700
# 196/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4632 - loss: 1.4990
# Epoch 32: val_loss improved from 1.65588 to 1.65433, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4619 - loss: 1.4975 - val_accuracy: 0.4567 - val_loss: 1.6543
# Epoch 33/700
# 200/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4584 - loss: 1.4977
# Epoch 33: val_loss improved from 1.65433 to 1.65380, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4624 - loss: 1.4952 - val_accuracy: 0.4567 - val_loss: 1.6538
# Epoch 34/700
# 204/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4696 - loss: 1.4780
# Epoch 34: val_loss improved from 1.65380 to 1.65301, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.4638 - loss: 1.4890 - val_accuracy: 0.4567 - val_loss: 1.6530
# Epoch 35/700
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4653 - loss: 1.4809
# Epoch 35: val_loss improved from 1.65301 to 1.65057, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4641 - loss: 1.4832 - val_accuracy: 0.4567 - val_loss: 1.6506
# Epoch 36/700
# 176/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4656 - loss: 1.4833
# Epoch 36: val_loss improved from 1.65057 to 1.64814, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4679 - loss: 1.4760 - val_accuracy: 0.4567 - val_loss: 1.6481
# Epoch 37/700
# 195/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4672 - loss: 1.4863
# Epoch 37: val_loss improved from 1.64814 to 1.64713, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4675 - loss: 1.4836 - val_accuracy: 0.4567 - val_loss: 1.6471
# Epoch 38/700
# 204/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4719 - loss: 1.4657
# Epoch 38: val_loss improved from 1.64713 to 1.64541, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4671 - loss: 1.4684 - val_accuracy: 0.4567 - val_loss: 1.6454
# Epoch 39/700
# 176/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4694 - loss: 1.4625
# Epoch 39: val_loss improved from 1.64541 to 1.64315, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.4713 - loss: 1.4595 - val_accuracy: 0.4568 - val_loss: 1.6431
# Epoch 40/700
# 196/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4697 - loss: 1.4675
# Epoch 40: val_loss improved from 1.64315 to 1.64122, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4725 - loss: 1.4566 - val_accuracy: 0.4570 - val_loss: 1.6412
# Epoch 41/700
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4720 - loss: 1.4559
# Epoch 41: val_loss improved from 1.64122 to 1.63928, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4732 - loss: 1.4519 - val_accuracy: 0.4586 - val_loss: 1.6393
# Epoch 42/700
# 199/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4778 - loss: 1.4423
# Epoch 42: val_loss improved from 1.63928 to 1.63752, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4766 - loss: 1.4460 - val_accuracy: 0.4593 - val_loss: 1.6375
# Epoch 43/700
# 190/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4795 - loss: 1.4371
# Epoch 43: val_loss improved from 1.63752 to 1.63537, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4763 - loss: 1.4386 - val_accuracy: 0.4599 - val_loss: 1.6354
# Epoch 44/700
# 197/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4764 - loss: 1.4366
# Epoch 44: val_loss improved from 1.63537 to 1.63389, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4776 - loss: 1.4386 - val_accuracy: 0.4623 - val_loss: 1.6339
# Epoch 45/700
# 191/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4877 - loss: 1.4192
# Epoch 45: val_loss improved from 1.63389 to 1.63088, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4845 - loss: 1.4258 - val_accuracy: 0.4671 - val_loss: 1.6309
# Epoch 46/700
# 195/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4751 - loss: 1.4412
# Epoch 46: val_loss improved from 1.63088 to 1.62741, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4847 - loss: 1.4229 - val_accuracy: 0.4708 - val_loss: 1.6274
# Epoch 47/700
# 204/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4935 - loss: 1.4059
# Epoch 47: val_loss improved from 1.62741 to 1.62499, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4900 - loss: 1.4131 - val_accuracy: 0.4772 - val_loss: 1.6250
# Epoch 48/700
# 191/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4850 - loss: 1.4193
# Epoch 48: val_loss improved from 1.62499 to 1.62125, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4939 - loss: 1.4061 - val_accuracy: 0.4840 - val_loss: 1.6212
# Epoch 49/700
# 193/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4914 - loss: 1.4028
# Epoch 49: val_loss improved from 1.62125 to 1.61814, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4934 - loss: 1.3999 - val_accuracy: 0.4916 - val_loss: 1.6181
# Epoch 50/700
# 197/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4967 - loss: 1.3944
# Epoch 50: val_loss improved from 1.61814 to 1.61611, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4981 - loss: 1.3963 - val_accuracy: 0.4992 - val_loss: 1.6161
# Epoch 51/700
# 186/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4984 - loss: 1.3852
# Epoch 51: val_loss improved from 1.61611 to 1.61160, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5018 - loss: 1.3826 - val_accuracy: 0.5072 - val_loss: 1.6116
# Epoch 52/700
# 186/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5099 - loss: 1.3734
# Epoch 52: val_loss improved from 1.61160 to 1.60834, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5091 - loss: 1.3770 - val_accuracy: 0.5183 - val_loss: 1.6083
# Epoch 53/700
# 205/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5100 - loss: 1.3775
# Epoch 53: val_loss improved from 1.60834 to 1.60379, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5136 - loss: 1.3656 - val_accuracy: 0.5307 - val_loss: 1.6038
# Epoch 54/700
# 189/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5193 - loss: 1.3641
# Epoch 54: val_loss improved from 1.60379 to 1.60057, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5159 - loss: 1.3642 - val_accuracy: 0.5414 - val_loss: 1.6006
# Epoch 55/700
# 191/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5194 - loss: 1.3542
# Epoch 55: val_loss improved from 1.60057 to 1.59663, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5237 - loss: 1.3495 - val_accuracy: 0.5502 - val_loss: 1.5966
# Epoch 56/700
# 200/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5191 - loss: 1.3589
# Epoch 56: val_loss improved from 1.59663 to 1.59089, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5322 - loss: 1.3380 - val_accuracy: 0.5625 - val_loss: 1.5909
# Epoch 57/700
# 201/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5280 - loss: 1.3259
# Epoch 57: val_loss improved from 1.59089 to 1.58665, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5285 - loss: 1.3339 - val_accuracy: 0.5756 - val_loss: 1.5867
# Epoch 58/700
# 196/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5318 - loss: 1.3252
# Epoch 58: val_loss improved from 1.58665 to 1.58225, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5337 - loss: 1.3262 - val_accuracy: 0.5866 - val_loss: 1.5823
# Epoch 59/700
# 186/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5414 - loss: 1.3175
# Epoch 59: val_loss improved from 1.58225 to 1.57611, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5440 - loss: 1.3101 - val_accuracy: 0.5922 - val_loss: 1.5761
# Epoch 60/700
# 204/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5461 - loss: 1.3015
# Epoch 60: val_loss improved from 1.57611 to 1.57083, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5461 - loss: 1.3005 - val_accuracy: 0.6030 - val_loss: 1.5708
# Epoch 61/700
# 203/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5539 - loss: 1.2955
# Epoch 61: val_loss improved from 1.57083 to 1.56421, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5522 - loss: 1.2943 - val_accuracy: 0.6116 - val_loss: 1.5642
# Epoch 62/700
# 204/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5613 - loss: 1.2691
# Epoch 62: val_loss improved from 1.56421 to 1.55816, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5595 - loss: 1.2744 - val_accuracy: 0.6181 - val_loss: 1.5582
# Epoch 63/700
# 205/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5601 - loss: 1.2729
# Epoch 63: val_loss improved from 1.55816 to 1.55203, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5612 - loss: 1.2680 - val_accuracy: 0.6231 - val_loss: 1.5520
# Epoch 64/700
# 196/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5604 - loss: 1.2697
# Epoch 64: val_loss improved from 1.55203 to 1.54464, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5632 - loss: 1.2604 - val_accuracy: 0.6286 - val_loss: 1.5446
# Epoch 65/700
# 190/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5677 - loss: 1.2465
# Epoch 65: val_loss improved from 1.54464 to 1.53819, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5721 - loss: 1.2466 - val_accuracy: 0.6330 - val_loss: 1.5382
# Epoch 66/700
# 190/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5712 - loss: 1.2450
# Epoch 66: val_loss improved from 1.53819 to 1.53125, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5737 - loss: 1.2336 - val_accuracy: 0.6365 - val_loss: 1.5312
# Epoch 67/700
# 187/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5816 - loss: 1.2176
# Epoch 67: val_loss improved from 1.53125 to 1.52432, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5774 - loss: 1.2240 - val_accuracy: 0.6413 - val_loss: 1.5243
# Epoch 68/700
# 184/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5776 - loss: 1.2260
# Epoch 68: val_loss improved from 1.52432 to 1.51706, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5821 - loss: 1.2160 - val_accuracy: 0.6427 - val_loss: 1.5171
# Epoch 69/700
# 201/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5831 - loss: 1.2082
# Epoch 69: val_loss improved from 1.51706 to 1.50931, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5850 - loss: 1.2006 - val_accuracy: 0.6449 - val_loss: 1.5093
# Epoch 70/700
# 193/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5965 - loss: 1.1774
# Epoch 70: val_loss improved from 1.50931 to 1.50047, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5915 - loss: 1.1875 - val_accuracy: 0.6493 - val_loss: 1.5005
# Epoch 71/700
# 192/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5977 - loss: 1.1706
# Epoch 71: val_loss improved from 1.50047 to 1.49213, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5942 - loss: 1.1783 - val_accuracy: 0.6525 - val_loss: 1.4921
# Epoch 72/700
# 198/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5922 - loss: 1.1794
# Epoch 72: val_loss improved from 1.49213 to 1.48360, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5975 - loss: 1.1695 - val_accuracy: 0.6553 - val_loss: 1.4836
# Epoch 73/700
# 191/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5880 - loss: 1.1775
# Epoch 73: val_loss improved from 1.48360 to 1.47453, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6007 - loss: 1.1569 - val_accuracy: 0.6590 - val_loss: 1.4745
# Epoch 74/700
# 201/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6073 - loss: 1.1435
# Epoch 74: val_loss improved from 1.47453 to 1.46703, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6037 - loss: 1.1462 - val_accuracy: 0.6614 - val_loss: 1.4670
# Epoch 75/700
# 193/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6021 - loss: 1.1410
# Epoch 75: val_loss improved from 1.46703 to 1.45823, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6062 - loss: 1.1371 - val_accuracy: 0.6665 - val_loss: 1.4582
# Epoch 76/700
# 186/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6124 - loss: 1.1191
# Epoch 76: val_loss improved from 1.45823 to 1.44965, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6116 - loss: 1.1207 - val_accuracy: 0.6704 - val_loss: 1.4497
# Epoch 77/700
# 191/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6148 - loss: 1.1218
# Epoch 77: val_loss improved from 1.44965 to 1.44286, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6108 - loss: 1.1175 - val_accuracy: 0.6743 - val_loss: 1.4429
# Epoch 78/700
# 198/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6157 - loss: 1.1104
# Epoch 78: val_loss improved from 1.44286 to 1.43178, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6178 - loss: 1.1042 - val_accuracy: 0.6780 - val_loss: 1.4318
# Epoch 79/700
# 184/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6216 - loss: 1.0975
# Epoch 79: val_loss improved from 1.43178 to 1.42259, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6213 - loss: 1.0915 - val_accuracy: 0.6830 - val_loss: 1.4226
# Epoch 80/700
# 185/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6233 - loss: 1.0977
# Epoch 80: val_loss improved from 1.42259 to 1.41477, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6254 - loss: 1.0885 - val_accuracy: 0.6881 - val_loss: 1.4148
# Epoch 81/700
# 197/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6155 - loss: 1.0989
# Epoch 81: val_loss improved from 1.41477 to 1.40608, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6280 - loss: 1.0743 - val_accuracy: 0.6956 - val_loss: 1.4061
# Epoch 82/700
# 195/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6319 - loss: 1.0724
# Epoch 82: val_loss improved from 1.40608 to 1.39669, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6322 - loss: 1.0646 - val_accuracy: 0.6991 - val_loss: 1.3967
# Epoch 83/700
# 203/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6299 - loss: 1.0554
# Epoch 83: val_loss improved from 1.39669 to 1.38831, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6324 - loss: 1.0537 - val_accuracy: 0.7033 - val_loss: 1.3883
# Epoch 84/700
# 185/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6315 - loss: 1.0519
# Epoch 84: val_loss improved from 1.38831 to 1.37987, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6370 - loss: 1.0456 - val_accuracy: 0.7083 - val_loss: 1.3799
# Epoch 85/700
# 186/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6389 - loss: 1.0478
# Epoch 85: val_loss improved from 1.37987 to 1.37292, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6366 - loss: 1.0440 - val_accuracy: 0.7145 - val_loss: 1.3729
# Epoch 86/700
# 196/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6325 - loss: 1.0446
# Epoch 86: val_loss improved from 1.37292 to 1.36089, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6423 - loss: 1.0266 - val_accuracy: 0.7170 - val_loss: 1.3609
# Epoch 87/700
# 189/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6522 - loss: 1.0124
# Epoch 87: val_loss improved from 1.36089 to 1.35443, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6424 - loss: 1.0227 - val_accuracy: 0.7220 - val_loss: 1.3544
# Epoch 88/700
# 199/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6546 - loss: 0.9993
# Epoch 88: val_loss improved from 1.35443 to 1.34682, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6472 - loss: 1.0111 - val_accuracy: 0.7255 - val_loss: 1.3468
# Epoch 89/700
# 194/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6558 - loss: 1.0081
# Epoch 89: val_loss improved from 1.34682 to 1.33754, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6532 - loss: 1.0068 - val_accuracy: 0.7299 - val_loss: 1.3375
# Epoch 90/700
# 192/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6470 - loss: 1.0147
# Epoch 90: val_loss improved from 1.33754 to 1.32823, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6511 - loss: 1.0020 - val_accuracy: 0.7329 - val_loss: 1.3282
# Epoch 91/700
# 198/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6515 - loss: 1.0089
# Epoch 91: val_loss improved from 1.32823 to 1.31928, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6598 - loss: 0.9885 - val_accuracy: 0.7360 - val_loss: 1.3193
# Epoch 92/700
# 181/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6600 - loss: 0.9888
# Epoch 92: val_loss improved from 1.31928 to 1.31291, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6570 - loss: 0.9871 - val_accuracy: 0.7420 - val_loss: 1.3129
# Epoch 93/700
# 189/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6574 - loss: 0.9816
# Epoch 93: val_loss improved from 1.31291 to 1.30494, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6587 - loss: 0.9778 - val_accuracy: 0.7478 - val_loss: 1.3049
# Epoch 94/700
# 202/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6716 - loss: 0.9594
# Epoch 94: val_loss improved from 1.30494 to 1.29770, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6663 - loss: 0.9648 - val_accuracy: 0.7507 - val_loss: 1.2977
# Epoch 95/700
# 187/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6724 - loss: 0.9442
# Epoch 95: val_loss improved from 1.29770 to 1.28996, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6684 - loss: 0.9608 - val_accuracy: 0.7554 - val_loss: 1.2900
# Epoch 96/700
# 196/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6733 - loss: 0.9533
# Epoch 96: val_loss improved from 1.28996 to 1.28162, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6647 - loss: 0.9581 - val_accuracy: 0.7570 - val_loss: 1.2816
# Epoch 97/700
# 197/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6661 - loss: 0.9554
# Epoch 97: val_loss improved from 1.28162 to 1.27262, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6729 - loss: 0.9426 - val_accuracy: 0.7592 - val_loss: 1.2726
# Epoch 98/700
# 201/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6752 - loss: 0.9296
# Epoch 98: val_loss improved from 1.27262 to 1.26704, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6714 - loss: 0.9410 - val_accuracy: 0.7617 - val_loss: 1.2670
# Epoch 99/700
# 184/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6686 - loss: 0.9437
# Epoch 99: val_loss improved from 1.26704 to 1.25935, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6746 - loss: 0.9359 - val_accuracy: 0.7625 - val_loss: 1.2593
# Epoch 100/700
# 193/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6882 - loss: 0.9127
# Epoch 100: val_loss improved from 1.25935 to 1.25059, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6826 - loss: 0.9215 - val_accuracy: 0.7634 - val_loss: 1.2506
# Epoch 101/700
# 197/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6792 - loss: 0.9253
# Epoch 101: val_loss improved from 1.25059 to 1.24615, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6765 - loss: 0.9267 - val_accuracy: 0.7643 - val_loss: 1.2462
# Epoch 102/700
# 201/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6788 - loss: 0.9230
# Epoch 102: val_loss improved from 1.24615 to 1.24023, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6796 - loss: 0.9160 - val_accuracy: 0.7664 - val_loss: 1.2402
# Epoch 103/700
# 198/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6797 - loss: 0.9123
# Epoch 103: val_loss improved from 1.24023 to 1.23047, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6841 - loss: 0.9110 - val_accuracy: 0.7671 - val_loss: 1.2305
# Epoch 104/700
# 200/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6851 - loss: 0.9189
# Epoch 104: val_loss improved from 1.23047 to 1.22627, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6855 - loss: 0.9131 - val_accuracy: 0.7679 - val_loss: 1.2263
# Epoch 105/700
# 184/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6887 - loss: 0.8978
# Epoch 105: val_loss improved from 1.22627 to 1.21624, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6900 - loss: 0.8969 - val_accuracy: 0.7698 - val_loss: 1.2162
# Epoch 106/700
# 191/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6893 - loss: 0.8946
# Epoch 106: val_loss improved from 1.21624 to 1.21240, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6898 - loss: 0.8971 - val_accuracy: 0.7714 - val_loss: 1.2124
# Epoch 107/700
# 193/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6911 - loss: 0.8920
# Epoch 107: val_loss improved from 1.21240 to 1.20728, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6949 - loss: 0.8934 - val_accuracy: 0.7719 - val_loss: 1.2073
# Epoch 108/700
# 186/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6931 - loss: 0.8795
# Epoch 108: val_loss improved from 1.20728 to 1.19829, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6930 - loss: 0.8802 - val_accuracy: 0.7735 - val_loss: 1.1983
# Epoch 109/700
# 200/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6974 - loss: 0.8791
# Epoch 109: val_loss improved from 1.19829 to 1.19233, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7000 - loss: 0.8778 - val_accuracy: 0.7744 - val_loss: 1.1923
# Epoch 110/700
# 195/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7019 - loss: 0.8748
# Epoch 110: val_loss improved from 1.19233 to 1.18935, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6977 - loss: 0.8812 - val_accuracy: 0.7753 - val_loss: 1.1893
# Epoch 111/700
# 201/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6890 - loss: 0.8906
# Epoch 111: val_loss improved from 1.18935 to 1.18213, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6978 - loss: 0.8797 - val_accuracy: 0.7769 - val_loss: 1.1821
# Epoch 112/700
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7028 - loss: 0.8704
# Epoch 112: val_loss improved from 1.18213 to 1.17894, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7034 - loss: 0.8665 - val_accuracy: 0.7776 - val_loss: 1.1789
# Epoch 113/700
# 194/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7110 - loss: 0.8504
# Epoch 113: val_loss improved from 1.17894 to 1.17160, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7052 - loss: 0.8629 - val_accuracy: 0.7792 - val_loss: 1.1716
# Epoch 114/700
# 189/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7135 - loss: 0.8432
# Epoch 114: val_loss improved from 1.17160 to 1.16514, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7091 - loss: 0.8539 - val_accuracy: 0.7794 - val_loss: 1.1651
# Epoch 115/700
# 187/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7107 - loss: 0.8534
# Epoch 115: val_loss improved from 1.16514 to 1.15871, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7099 - loss: 0.8500 - val_accuracy: 0.7808 - val_loss: 1.1587
# Epoch 116/700
# 195/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7100 - loss: 0.8492
# Epoch 116: val_loss improved from 1.15871 to 1.15352, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7098 - loss: 0.8466 - val_accuracy: 0.7817 - val_loss: 1.1535
# Epoch 117/700
# 189/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7089 - loss: 0.8423
# Epoch 117: val_loss improved from 1.15352 to 1.14945, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7086 - loss: 0.8457 - val_accuracy: 0.7829 - val_loss: 1.1495
# Epoch 118/700
# 193/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7113 - loss: 0.8442
# Epoch 118: val_loss improved from 1.14945 to 1.14403, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7131 - loss: 0.8430 - val_accuracy: 0.7840 - val_loss: 1.1440
# Epoch 119/700
# 196/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7162 - loss: 0.8292
# Epoch 119: val_loss improved from 1.14403 to 1.14016, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7142 - loss: 0.8374 - val_accuracy: 0.7850 - val_loss: 1.1402
# Epoch 120/700
# 204/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7145 - loss: 0.8306
# Epoch 120: val_loss improved from 1.14016 to 1.13431, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7144 - loss: 0.8355 - val_accuracy: 0.7847 - val_loss: 1.1343
# Epoch 121/700
# 190/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7092 - loss: 0.8440
# Epoch 121: val_loss improved from 1.13431 to 1.12982, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7153 - loss: 0.8358 - val_accuracy: 0.7850 - val_loss: 1.1298
# Epoch 122/700
# 194/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7108 - loss: 0.8461
# Epoch 122: val_loss improved from 1.12982 to 1.12423, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7205 - loss: 0.8303 - val_accuracy: 0.7852 - val_loss: 1.1242
# Epoch 123/700
# 193/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7211 - loss: 0.8192
# Epoch 123: val_loss improved from 1.12423 to 1.11889, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7237 - loss: 0.8174 - val_accuracy: 0.7854 - val_loss: 1.1189
# Epoch 124/700
# 193/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7206 - loss: 0.8198
# Epoch 124: val_loss improved from 1.11889 to 1.11459, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7187 - loss: 0.8217 - val_accuracy: 0.7861 - val_loss: 1.1146
# Epoch 125/700
# 189/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7200 - loss: 0.8146
# Epoch 125: val_loss improved from 1.11459 to 1.11031, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7225 - loss: 0.8111 - val_accuracy: 0.7863 - val_loss: 1.1103
# Epoch 126/700
# 186/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7276 - loss: 0.8102
# Epoch 126: val_loss improved from 1.11031 to 1.10510, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7210 - loss: 0.8133 - val_accuracy: 0.7866 - val_loss: 1.1051
# Epoch 127/700
# 193/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7329 - loss: 0.7929
# Epoch 127: val_loss improved from 1.10510 to 1.09912, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7270 - loss: 0.8023 - val_accuracy: 0.7870 - val_loss: 1.0991
# Epoch 128/700
# 187/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7267 - loss: 0.8082
# Epoch 128: val_loss improved from 1.09912 to 1.09505, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7298 - loss: 0.8003 - val_accuracy: 0.7872 - val_loss: 1.0950
# Epoch 129/700
# 205/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7242 - loss: 0.7998
# Epoch 129: val_loss improved from 1.09505 to 1.09085, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7258 - loss: 0.7992 - val_accuracy: 0.7875 - val_loss: 1.0909
# Epoch 130/700
# 204/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7351 - loss: 0.7914
# Epoch 130: val_loss did not improve from 1.09085
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7331 - loss: 0.7943 - val_accuracy: 0.7881 - val_loss: 1.0909
# Epoch 131/700
# 188/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7342 - loss: 0.7848
# Epoch 131: val_loss improved from 1.09085 to 1.08586, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7344 - loss: 0.7907 - val_accuracy: 0.7877 - val_loss: 1.0859
# Epoch 132/700
# 203/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7347 - loss: 0.7915
# Epoch 132: val_loss improved from 1.08586 to 1.08136, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7341 - loss: 0.7915 - val_accuracy: 0.7884 - val_loss: 1.0814
# Epoch 133/700
# 199/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7326 - loss: 0.7978
# Epoch 133: val_loss improved from 1.08136 to 1.07927, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7330 - loss: 0.7891 - val_accuracy: 0.7879 - val_loss: 1.0793
# Epoch 134/700
# 202/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7296 - loss: 0.7874
# Epoch 134: val_loss improved from 1.07927 to 1.07458, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7315 - loss: 0.7871 - val_accuracy: 0.7873 - val_loss: 1.0746
# Epoch 135/700
# 199/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7269 - loss: 0.7914
# Epoch 135: val_loss improved from 1.07458 to 1.07147, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7293 - loss: 0.7916 - val_accuracy: 0.7884 - val_loss: 1.0715
# Epoch 136/700
# 190/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7359 - loss: 0.7689
# Epoch 136: val_loss improved from 1.07147 to 1.06517, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7374 - loss: 0.7698 - val_accuracy: 0.7884 - val_loss: 1.0652
# Epoch 137/700
# 198/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7328 - loss: 0.7729
# Epoch 137: val_loss improved from 1.06517 to 1.06280, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7325 - loss: 0.7775 - val_accuracy: 0.7886 - val_loss: 1.0628
# Epoch 138/700
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7320 - loss: 0.7832
# Epoch 138: val_loss improved from 1.06280 to 1.05852, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7384 - loss: 0.7760 - val_accuracy: 0.7891 - val_loss: 1.0585
# Epoch 139/700
# 192/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7394 - loss: 0.7584
# Epoch 139: val_loss improved from 1.05852 to 1.05464, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7408 - loss: 0.7667 - val_accuracy: 0.7895 - val_loss: 1.0546
# Epoch 140/700
# 183/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7454 - loss: 0.7527
# Epoch 140: val_loss improved from 1.05464 to 1.05459, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7411 - loss: 0.7661 - val_accuracy: 0.7884 - val_loss: 1.0546
# Epoch 141/700
# 203/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7410 - loss: 0.7656
# Epoch 141: val_loss improved from 1.05459 to 1.04773, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7455 - loss: 0.7592 - val_accuracy: 0.7893 - val_loss: 1.0477
# Epoch 142/700
# 204/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7395 - loss: 0.7684
# Epoch 142: val_loss improved from 1.04773 to 1.04019, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7397 - loss: 0.7604 - val_accuracy: 0.7900 - val_loss: 1.0402
# Epoch 143/700
# 199/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7426 - loss: 0.7628
# Epoch 143: val_loss improved from 1.04019 to 1.03832, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7454 - loss: 0.7592 - val_accuracy: 0.7897 - val_loss: 1.0383
# Epoch 144/700
# 181/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7439 - loss: 0.7627
# Epoch 144: val_loss improved from 1.03832 to 1.03572, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7410 - loss: 0.7566 - val_accuracy: 0.7911 - val_loss: 1.0357
# Epoch 145/700
# 191/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7535 - loss: 0.7300
# Epoch 145: val_loss did not improve from 1.03572
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7464 - loss: 0.7474 - val_accuracy: 0.7886 - val_loss: 1.0373
# Epoch 146/700
# 201/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7495 - loss: 0.7506
# Epoch 146: val_loss improved from 1.03572 to 1.02982, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7474 - loss: 0.7471 - val_accuracy: 0.7907 - val_loss: 1.0298
# Epoch 147/700
# 186/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7491 - loss: 0.7341
# Epoch 147: val_loss improved from 1.02982 to 1.02917, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7461 - loss: 0.7477 - val_accuracy: 0.7905 - val_loss: 1.0292
# Epoch 148/700
# 192/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7488 - loss: 0.7448
# Epoch 148: val_loss improved from 1.02917 to 1.02417, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7502 - loss: 0.7391 - val_accuracy: 0.7911 - val_loss: 1.0242
# Epoch 149/700
# 186/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7500 - loss: 0.7483
# Epoch 149: val_loss improved from 1.02417 to 1.02083, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7493 - loss: 0.7425 - val_accuracy: 0.7904 - val_loss: 1.0208
# Epoch 150/700
# 187/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7495 - loss: 0.7387
# Epoch 150: val_loss improved from 1.02083 to 1.01707, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7522 - loss: 0.7318 - val_accuracy: 0.7914 - val_loss: 1.0171
# Epoch 151/700
# 195/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7546 - loss: 0.7319
# Epoch 151: val_loss improved from 1.01707 to 1.01640, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7516 - loss: 0.7362 - val_accuracy: 0.7914 - val_loss: 1.0164
# Epoch 152/700
# 198/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7476 - loss: 0.7357
# Epoch 152: val_loss improved from 1.01640 to 1.01182, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7489 - loss: 0.7382 - val_accuracy: 0.7923 - val_loss: 1.0118
# Epoch 153/700
# 205/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7574 - loss: 0.7262
# Epoch 153: val_loss improved from 1.01182 to 1.00747, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7550 - loss: 0.7311 - val_accuracy: 0.7918 - val_loss: 1.0075
# Epoch 154/700
# 205/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7550 - loss: 0.7267
# Epoch 154: val_loss improved from 1.00747 to 1.00555, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7528 - loss: 0.7283 - val_accuracy: 0.7918 - val_loss: 1.0055
# Epoch 155/700
# 177/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7542 - loss: 0.7223
# Epoch 155: val_loss improved from 1.00555 to 1.00423, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7544 - loss: 0.7295 - val_accuracy: 0.7918 - val_loss: 1.0042
# Epoch 156/700
# 183/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7644 - loss: 0.7093
# Epoch 156: val_loss improved from 1.00423 to 0.99794, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7558 - loss: 0.7152 - val_accuracy: 0.7932 - val_loss: 0.9979
# Epoch 157/700
# 202/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7533 - loss: 0.7235
# Epoch 157: val_loss improved from 0.99794 to 0.99711, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7534 - loss: 0.7232 - val_accuracy: 0.7932 - val_loss: 0.9971
# Epoch 158/700
# 184/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7534 - loss: 0.7199
# Epoch 158: val_loss improved from 0.99711 to 0.99467, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7522 - loss: 0.7257 - val_accuracy: 0.7928 - val_loss: 0.9947
# Epoch 159/700
# 194/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7559 - loss: 0.7117
# Epoch 159: val_loss improved from 0.99467 to 0.98889, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7570 - loss: 0.7111 - val_accuracy: 0.7935 - val_loss: 0.9889
# Epoch 160/700
# 198/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7585 - loss: 0.7139
# Epoch 160: val_loss improved from 0.98889 to 0.98605, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7593 - loss: 0.7118 - val_accuracy: 0.7935 - val_loss: 0.9860
# Epoch 161/700
# 182/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7580 - loss: 0.7191
# Epoch 161: val_loss improved from 0.98605 to 0.98507, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7609 - loss: 0.7087 - val_accuracy: 0.7939 - val_loss: 0.9851
# Epoch 162/700
# 198/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7733 - loss: 0.6898
# Epoch 162: val_loss improved from 0.98507 to 0.98084, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7618 - loss: 0.7083 - val_accuracy: 0.7946 - val_loss: 0.9808
# Epoch 163/700
# 204/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7633 - loss: 0.6987
# Epoch 163: val_loss improved from 0.98084 to 0.97947, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7600 - loss: 0.7044 - val_accuracy: 0.7937 - val_loss: 0.9795
# Epoch 164/700
# 200/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7620 - loss: 0.6931
# Epoch 164: val_loss improved from 0.97947 to 0.97619, saving model to best_mr_tcn.keras
# ...
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8884 - loss: 0.3128 - val_accuracy: 0.8837 - val_loss: 0.4639
# Epoch 641/700
# 192/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8833 - loss: 0.3284
# Epoch 641: val_loss did not improve from 0.46391
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8899 - loss: 0.3175 - val_accuracy: 0.8825 - val_loss: 0.4650
# Epoch 642/700
# 189/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8892 - loss: 0.3175
# Epoch 642: val_loss did not improve from 0.46391
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8893 - loss: 0.3208 - val_accuracy: 0.8822 - val_loss: 0.4644
# Epoch 643/700
# 190/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8947 - loss: 0.3099
# Epoch 643: val_loss did not improve from 0.46391
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8888 - loss: 0.3157 - val_accuracy: 0.8823 - val_loss: 0.4640
# Epoch 644/700
# 203/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8856 - loss: 0.3184
# Epoch 644: val_loss did not improve from 0.46391
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8868 - loss: 0.3172 - val_accuracy: 0.8813 - val_loss: 0.4651
# Epoch 645/700
# 182/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8936 - loss: 0.3051
# Epoch 645: val_loss did not improve from 0.46391
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8897 - loss: 0.3163 - val_accuracy: 0.8811 - val_loss: 0.4657
# Epoch 646/700
# 205/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8907 - loss: 0.3217
# Epoch 646: val_loss improved from 0.46391 to 0.46284, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8888 - loss: 0.3185 - val_accuracy: 0.8836 - val_loss: 0.4628
# Epoch 647/700
# 198/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8929 - loss: 0.3093
# Epoch 647: val_loss improved from 0.46284 to 0.45976, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8924 - loss: 0.3073 - val_accuracy: 0.8845 - val_loss: 0.4598
# Epoch 648/700
# 189/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8837 - loss: 0.3140
# Epoch 648: val_loss did not improve from 0.45976
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8853 - loss: 0.3155 - val_accuracy: 0.8799 - val_loss: 0.4642
# Epoch 649/700
# 188/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9002 - loss: 0.2945
# Epoch 649: val_loss did not improve from 0.45976
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8923 - loss: 0.3086 - val_accuracy: 0.8816 - val_loss: 0.4627
# Epoch 650/700
# 188/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8897 - loss: 0.3090
# Epoch 650: val_loss improved from 0.45976 to 0.45951, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8882 - loss: 0.3172 - val_accuracy: 0.8843 - val_loss: 0.4595
# Epoch 651/700
# 194/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8900 - loss: 0.3163
# Epoch 651: val_loss did not improve from 0.45951
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8892 - loss: 0.3150 - val_accuracy: 0.8855 - val_loss: 0.4606
# Epoch 652/700
# 197/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8914 - loss: 0.3071
# Epoch 652: val_loss did not improve from 0.45951
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8879 - loss: 0.3152 - val_accuracy: 0.8799 - val_loss: 0.4620
# Epoch 653/700
# 194/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8911 - loss: 0.3207
# Epoch 653: val_loss did not improve from 0.45951
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8889 - loss: 0.3150 - val_accuracy: 0.8830 - val_loss: 0.4598
# Epoch 654/700
# 187/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8896 - loss: 0.3258
# Epoch 654: val_loss did not improve from 0.45951
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8901 - loss: 0.3147 - val_accuracy: 0.8818 - val_loss: 0.4616
# Epoch 655/700
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8945 - loss: 0.3084
# Epoch 655: val_loss improved from 0.45951 to 0.45800, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8932 - loss: 0.3090 - val_accuracy: 0.8850 - val_loss: 0.4580
# Epoch 656/700
# 193/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8929 - loss: 0.3095
# Epoch 656: val_loss improved from 0.45800 to 0.45645, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8925 - loss: 0.3117 - val_accuracy: 0.8827 - val_loss: 0.4565
# Epoch 657/700
# 194/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8916 - loss: 0.3089
# Epoch 657: val_loss did not improve from 0.45645
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8914 - loss: 0.3133 - val_accuracy: 0.8820 - val_loss: 0.4576
# Epoch 658/700
# 197/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8907 - loss: 0.3087
# Epoch 658: val_loss did not improve from 0.45645
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8921 - loss: 0.3088 - val_accuracy: 0.8843 - val_loss: 0.4570
# Epoch 659/700
# 197/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8906 - loss: 0.3176
# Epoch 659: val_loss did not improve from 0.45645
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8907 - loss: 0.3141 - val_accuracy: 0.8834 - val_loss: 0.4573
# Epoch 660/700
# 193/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8886 - loss: 0.3116
# Epoch 660: val_loss improved from 0.45645 to 0.45540, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8878 - loss: 0.3135 - val_accuracy: 0.8836 - val_loss: 0.4554
# Epoch 661/700
# 204/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8874 - loss: 0.3171
# Epoch 661: val_loss improved from 0.45540 to 0.45520, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8890 - loss: 0.3098 - val_accuracy: 0.8837 - val_loss: 0.4552
# Epoch 662/700
# 194/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8902 - loss: 0.3119
# Epoch 662: val_loss did not improve from 0.45520
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8882 - loss: 0.3177 - val_accuracy: 0.8825 - val_loss: 0.4597
# Epoch 663/700
# 202/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8873 - loss: 0.3198
# Epoch 663: val_loss improved from 0.45520 to 0.45426, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8921 - loss: 0.3055 - val_accuracy: 0.8853 - val_loss: 0.4543
# Epoch 664/700
# 197/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8934 - loss: 0.2998
# Epoch 664: val_loss did not improve from 0.45426
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8920 - loss: 0.3071 - val_accuracy: 0.8846 - val_loss: 0.4560
# Epoch 665/700
# 202/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8893 - loss: 0.3190
# Epoch 665: val_loss improved from 0.45426 to 0.45307, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8905 - loss: 0.3125 - val_accuracy: 0.8845 - val_loss: 0.4531
# Epoch 666/700
# 200/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8859 - loss: 0.3144
# Epoch 666: val_loss improved from 0.45307 to 0.44864, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8891 - loss: 0.3101 - val_accuracy: 0.8882 - val_loss: 0.4486
# Epoch 667/700
# 184/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8969 - loss: 0.2981
# Epoch 667: val_loss did not improve from 0.44864
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8929 - loss: 0.3049 - val_accuracy: 0.8832 - val_loss: 0.4530
# Epoch 668/700
# 189/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8901 - loss: 0.2998
# Epoch 668: val_loss did not improve from 0.44864
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8923 - loss: 0.3009 - val_accuracy: 0.8836 - val_loss: 0.4528
# Epoch 669/700
# 191/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8841 - loss: 0.3141
# Epoch 669: val_loss did not improve from 0.44864
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8890 - loss: 0.3108 - val_accuracy: 0.8866 - val_loss: 0.4494
# Epoch 670/700
# 189/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8856 - loss: 0.3174
# Epoch 670: val_loss did not improve from 0.44864
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8891 - loss: 0.3103 - val_accuracy: 0.8836 - val_loss: 0.4544
# Epoch 671/700
# 190/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8931 - loss: 0.3097
# Epoch 671: val_loss did not improve from 0.44864
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8921 - loss: 0.3055 - val_accuracy: 0.8825 - val_loss: 0.4560
# Epoch 672/700
# 194/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8932 - loss: 0.3123
# Epoch 672: val_loss did not improve from 0.44864
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8902 - loss: 0.3095 - val_accuracy: 0.8827 - val_loss: 0.4550
# Epoch 673/700
# 199/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8935 - loss: 0.3003
# Epoch 673: val_loss did not improve from 0.44864
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8889 - loss: 0.3099 - val_accuracy: 0.8837 - val_loss: 0.4538
# Epoch 674/700
# 202/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8936 - loss: 0.3044
# Epoch 674: val_loss did not improve from 0.44864
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8912 - loss: 0.3043 - val_accuracy: 0.8827 - val_loss: 0.4543
# Epoch 675/700
# 193/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8847 - loss: 0.3072
# Epoch 675: val_loss did not improve from 0.44864
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8891 - loss: 0.3059 - val_accuracy: 0.8832 - val_loss: 0.4531
# Epoch 676/700
# 198/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8993 - loss: 0.2919
# Epoch 676: val_loss did not improve from 0.44864
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8943 - loss: 0.3063 - val_accuracy: 0.8818 - val_loss: 0.4564
# Epoch 677/700
# 186/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8925 - loss: 0.3059
# Epoch 677: val_loss improved from 0.44864 to 0.44776, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8946 - loss: 0.2998 - val_accuracy: 0.8862 - val_loss: 0.4478
# Epoch 678/700
# 201/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8924 - loss: 0.3064
# Epoch 678: val_loss did not improve from 0.44776
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8915 - loss: 0.3069 - val_accuracy: 0.8855 - val_loss: 0.4490
# Epoch 679/700
# 197/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8954 - loss: 0.2969
# Epoch 679: val_loss did not improve from 0.44776
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8896 - loss: 0.3104 - val_accuracy: 0.8827 - val_loss: 0.4537
# Epoch 680/700
# 193/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8913 - loss: 0.3059
# Epoch 680: val_loss improved from 0.44776 to 0.44410, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8937 - loss: 0.3015 - val_accuracy: 0.8887 - val_loss: 0.4441
# Epoch 681/700
# 188/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8952 - loss: 0.3034
# Epoch 681: val_loss did not improve from 0.44410
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8918 - loss: 0.3047 - val_accuracy: 0.8820 - val_loss: 0.4551
# Epoch 682/700
# 190/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8939 - loss: 0.3048
# Epoch 682: val_loss did not improve from 0.44410
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8940 - loss: 0.3041 - val_accuracy: 0.8825 - val_loss: 0.4505
# Epoch 683/700
# 182/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8873 - loss: 0.3102
# Epoch 683: val_loss did not improve from 0.44410
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8922 - loss: 0.3006 - val_accuracy: 0.8829 - val_loss: 0.4491
# Epoch 684/700
# 196/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8914 - loss: 0.3070
# Epoch 684: val_loss did not improve from 0.44410
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8902 - loss: 0.3064 - val_accuracy: 0.8827 - val_loss: 0.4510
# Epoch 685/700
# 183/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8847 - loss: 0.3102
# Epoch 685: val_loss did not improve from 0.44410
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8907 - loss: 0.3018 - val_accuracy: 0.8848 - val_loss: 0.4454
# Epoch 686/700
# 191/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8974 - loss: 0.2941
# Epoch 686: val_loss did not improve from 0.44410
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8943 - loss: 0.3001 - val_accuracy: 0.8853 - val_loss: 0.4454
# Epoch 687/700
# 179/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8951 - loss: 0.2989
# Epoch 687: val_loss did not improve from 0.44410
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8940 - loss: 0.3014 - val_accuracy: 0.8850 - val_loss: 0.4459
# Epoch 688/700
# 198/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8909 - loss: 0.3066
# Epoch 688: val_loss did not improve from 0.44410
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8942 - loss: 0.3034 - val_accuracy: 0.8852 - val_loss: 0.4457
# Epoch 689/700
# 205/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8906 - loss: 0.3148
# Epoch 689: val_loss did not improve from 0.44410
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8926 - loss: 0.3051 - val_accuracy: 0.8836 - val_loss: 0.4493
# Epoch 690/700
# 192/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8963 - loss: 0.2999
# Epoch 690: val_loss did not improve from 0.44410
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8949 - loss: 0.3033 - val_accuracy: 0.8834 - val_loss: 0.4491
# Epoch 691/700
# 195/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8954 - loss: 0.2991
# Epoch 691: val_loss did not improve from 0.44410
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8964 - loss: 0.2954 - val_accuracy: 0.8859 - val_loss: 0.4444
# Epoch 692/700
# 198/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8896 - loss: 0.3105
# Epoch 692: val_loss did not improve from 0.44410
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8927 - loss: 0.3015 - val_accuracy: 0.8843 - val_loss: 0.4448
# Epoch 693/700
# 199/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8892 - loss: 0.3102
# Epoch 693: val_loss did not improve from 0.44410
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8938 - loss: 0.2954 - val_accuracy: 0.8836 - val_loss: 0.4453
# Epoch 694/700
# 202/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8965 - loss: 0.2968
# Epoch 694: val_loss did not improve from 0.44410
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8946 - loss: 0.3005 - val_accuracy: 0.8846 - val_loss: 0.4445
# Epoch 695/700
# 194/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8981 - loss: 0.2920
# Epoch 695: val_loss improved from 0.44410 to 0.44353, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8985 - loss: 0.2936 - val_accuracy: 0.8852 - val_loss: 0.4435
# Epoch 696/700
# 195/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8917 - loss: 0.3019
# Epoch 696: val_loss improved from 0.44353 to 0.43689, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8919 - loss: 0.2995 - val_accuracy: 0.8892 - val_loss: 0.4369
# Epoch 697/700
# 192/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8963 - loss: 0.2943
# Epoch 697: val_loss did not improve from 0.43689
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8949 - loss: 0.2993 - val_accuracy: 0.8852 - val_loss: 0.4436
# Epoch 698/700
# 187/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8905 - loss: 0.3080
# Epoch 698: val_loss did not improve from 0.43689
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8901 - loss: 0.3049 - val_accuracy: 0.8852 - val_loss: 0.4433
# Epoch 699/700
# 190/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8961 - loss: 0.2956
# Epoch 699: val_loss did not improve from 0.43689
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8942 - loss: 0.2985 - val_accuracy: 0.8850 - val_loss: 0.4433
# Epoch 700/700
# 180/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8977 - loss: 0.2941
# Epoch 700: val_loss did not improve from 0.43689
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8924 - loss: 0.3020 - val_accuracy: 0.8852 - val_loss: 0.4430

# %%
test_results = model.evaluate(X_test, y_test, verbose=0)

for name, val in zip(model.metrics_names, test_results):
    print(f"{name}: {val:.4f}")
# Out:
# loss: 0.5113
# compile_metrics: 0.8706

# %%
import matplotlib.pyplot as plt

plt.plot(history.history["loss"], label="train")
plt.plot(history.history["val_loss"], label="val")
plt.legend()
plt.title("Loss")
plt.show()

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

y_pred = np.argmax(model.predict(X_test), axis=1)
cm = confusion_matrix(y_test, y_pred)

ConfusionMatrixDisplay(cm).plot()
# Out:
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step

# %%
from sklearn.metrics import classification_report

print(classification_report(
    y_test, y_pred,
    target_names=['Normal','C_D','P_I','F_I','M_F','C_R']
))
# Out:
#               precision    recall  f1-score   support
#
#       Normal       0.89      0.89      0.89      6846
#          C_D       0.91      0.96      0.93      1356
#          P_I       0.99      1.00      1.00      1192
#          F_I       0.61      0.57      0.59       570
#          M_F       1.00      0.97      0.98       793
#          C_R       0.69      0.69      0.69      1611
#
#     accuracy                           0.87     12368
#    macro avg       0.85      0.84      0.85     12368
# weighted avg       0.87      0.87      0.87     12368

# %%
import numpy as np

y_prob = model.predict(X_test)          # probabilitas
y_pred = np.argmax(y_prob, axis=1)      # label prediksi
# Out:
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 0s 762us/step

# %%
import matplotlib.pyplot as plt

plt.figure()
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training vs Validation Loss')
plt.legend()
plt.show()

plt.figure()
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training vs Validation Accuracy')
plt.legend()
plt.show()
# Gap kecil & kurva sejajar → tidak overfitting.

# %%
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

cm = confusion_matrix(y_test, y_pred)

disp = ConfusionMatrixDisplay(confusion_matrix=cm)
disp.plot()
plt.title('Confusion Matrix')
plt.show()


# FN (Attack → Normal) harus minimal.

# %%
from sklearn.metrics import precision_recall_fscore_support

precision, recall, f1, support = precision_recall_fscore_support(
    y_test, y_pred, average=None
)

classes = np.arange(len(precision))

plt.figure()
plt.bar(classes, precision, label='Precision')
plt.bar(classes, recall, bottom=precision, label='Recall')
plt.xlabel('Class')
plt.ylabel('Score')
plt.title('Precision & Recall per Class')
plt.legend()
plt.show()
# Recall tinggi pada kelas Attack → IDS efektif.

# %%
from sklearn.preprocessing import label_binarize
from sklearn.metrics import roc_curve, auc

n_classes = y_prob.shape[1]
y_test_bin = label_binarize(y_test, classes=range(n_classes))

plt.figure()
for i in range(n_classes):
    fpr, tpr, _ = roc_curve(y_test_bin[:, i], y_prob[:, i])
    roc_auc = auc(fpr, tpr)
    plt.plot(fpr, tpr, label=f'Class {i} (AUC={roc_auc:.3f})')

plt.plot([0,1], [0,1], linestyle='--')
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC Curves (OvR)')
plt.legend()
plt.show()
# AUC → 1 = deteksi sangat kuat.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import f1_score

# Threshold grid halus
thresholds = np.linspace(0.01, 0.99, 500)
f1_scores = []

# Daftar kelas attack
attack_classes = [1, 2, 3, 4, 5]

# Gabungkan probabilitas semua attack
attack_prob = y_prob[:, attack_classes].sum(axis=1)

# Ground truth binary (Normal=0, Attack=1)
y_true_bin = np.isin(y_test, attack_classes).astype(int)

# Hitung F1-score untuk tiap threshold
for t in thresholds:
    y_pred_bin = (attack_prob >= t).astype(int)
    f1_scores.append(f1_score(y_true_bin, y_pred_bin))

f1_scores = np.array(f1_scores)

# Threshold terbaik
best_idx = np.argmax(f1_scores)
best_threshold = thresholds[best_idx]
best_f1 = f1_scores[best_idx]

print(f"Threshold Optimal : {best_threshold:.4f}")
print(f"Best F1-score     : {best_f1:.4f}")

# Plot
plt.figure(figsize=(7,5))
plt.plot(thresholds, f1_scores, label="F1-score", color='blue')
plt.scatter(best_threshold, best_f1, color='red', zorder=5)
plt.axvline(best_threshold, linestyle='--', color='red', label=f"Best Threshold = {best_threshold:.4f}")

# Anotasi angka
plt.text(
    best_threshold, best_f1,
    f"({best_threshold:.4f}, {best_f1:.4f})",
    ha='left', va='bottom'
)

plt.xlabel("Threshold")
plt.ylabel("F1-score (Attack vs Normal)")
plt.title("Threshold Optimization (Multiclass → Binary, Fine-grained)")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# Threshold Optimal : 0.6070
# Best F1-score     : 0.8508

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import time
from sklearn.metrics import roc_curve, auc, confusion_matrix, classification_report, f1_score

# 1. DEFINISI FUNGSI (Multiclass → Binary)
def evaluate_iov_model_multiclass(model, X_test, y_test, attack_classes=[1,2,3,4,5]):
    """
    Evaluasi model IDS IoV untuk multiclass → binary (Normal vs Attack)
    attack_classes: list kelas attack
    """
    print("--- Memulai Proses Evaluasi Multiclass → Binary ---")
    
    # Prediksi probabilitas
    start_time = time.time()
    y_prob = model.predict(X_test)  # bentuk (n_samples, n_classes)
    inference_time = (time.time() - start_time) / len(X_test)
    
    # Gabungkan probabilitas attack menjadi 1
    attack_prob = y_prob[:, attack_classes].sum(axis=1)  # bisa juga max/mean
    y_true_bin = np.isin(y_test, attack_classes).astype(int)
    
    # ROC Curve & Youden Index
    fpr, tpr, thresholds = roc_curve(y_true_bin, attack_prob)
    youden_index = tpr - fpr
    best_threshold = thresholds[np.argmax(youden_index)]
    
    # Klasifikasi berdasarkan threshold
    y_pred_bin = (attack_prob >= best_threshold).astype(int)
    
    # Confusion matrix & FPR
    cm = confusion_matrix(y_true_bin, y_pred_bin)
    tn, fp, fn, tp = cm.ravel()
    fpr_val = fp / (fp + tn)
    
    # Visualisasi
    fig, ax = plt.subplots(1, 2, figsize=(15,5))
    
    # Heatmap Confusion Matrix
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', ax=ax[0])
    ax[0].set_title('Confusion Matrix (Optimized Threshold)')
    ax[0].set_xlabel('Predicted')
    ax[0].set_ylabel('Actual')
    ax[0].set_xticklabels(['Normal','Attack'])
    ax[0].set_yticklabels(['Normal','Attack'])
    
    # ROC Curve
    ax[1].plot(fpr, tpr, label=f'AUC = {auc(fpr, tpr):.4f}')
    ax[1].plot([0,1], [0,1], 'k--')
    ax[1].set_title('ROC Curve')
    ax[1].set_xlabel("False Positive Rate")
    ax[1].set_ylabel("True Positive Rate")
    ax[1].legend()
    
    plt.tight_layout()
    plt.show()
    
    # Cetak hasil
    print("\n" + "="*30)
    print(f"HASIL EVALUASI IDS (IoV)")
    print("="*30)
    print(f"Threshold Optimal : {best_threshold:.4f}")
    print(f"False Positive Rate: {fpr_val:.6f}")
    print(f"Inference Latency : {inference_time:.6f} s/sample")
    print("-" * 30)
    print("Classification Report (Normal vs Attack):")
    print(classification_report(y_true_bin, y_pred_bin, target_names=['Normal','Attack']))
    
    return best_threshold

# ==========================================
# 2. EKSEKUSI FUNGSI
# ==========================================
try:
    best_thr = evaluate_iov_model_multiclass(model, X_test, y_test)
except NameError as e:
    print(f"Error: {e}. Pastikan variabel model dan data Anda sudah didefinisikan sebelumnya.")
# Out:
# --- Memulai Proses Evaluasi Multiclass → Binary ---
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 0s 824us/step
# ==============================
# HASIL EVALUASI IDS (IoV)
# ==============================
# Threshold Optimal : 0.6141
# False Positive Rate: 0.112328
# Inference Latency : 0.000042 s/sample
# ------------------------------
# Classification Report (Normal vs Attack):
#               precision    recall  f1-score   support
#
#       Normal       0.88      0.89      0.88      6846
#       Attack       0.86      0.84      0.85      5522
#
#     accuracy                           0.87     12368
#    macro avg       0.87      0.87      0.87     12368
# weighted avg       0.87      0.87      0.87     12368

# %%
import numpy as np
from sklearn.metrics import (
    confusion_matrix,
    accuracy_score,
    f1_score
)

def compute_ids_metrics_multiclass(y_true, y_pred):
    """
    Multiclass IDS metrics:
    Accuracy, F1-macro, F1-weighted
    """

    cm = confusion_matrix(y_true, y_pred)

    acc = accuracy_score(y_true, y_pred)
    f1_macro = f1_score(y_true, y_pred, average="macro")
    f1_weighted = f1_score(y_true, y_pred, average="weighted")

    return {
        "Accuracy": acc,
        "F1-macro": f1_macro,
        "F1-weighted": f1_weighted,
        "ConfusionMatrix": cm
    }

# %%
metrics = compute_ids_metrics_multiclass(y_test, y_pred)

for k, v in metrics.items():
    if isinstance(v, np.ndarray):
        print(f"{k}:\n{v}")
    else:
        print(f"{k:12s}: {v:.6f}")
# Out:
# Accuracy    : 0.870634
# F1-macro    : 0.846144
# F1-weighted : 0.870165
# ConfusionMatrix:
# [[6075  110    4  168    0  489]
#  [  46 1295    2   10    0    3]
#  [   2    0 1190    0    0    0]
#  [ 227   11    1  323    0    8]
#  [   0    4    1   20  768    0]
#  [ 474    9    0   11    0 1117]]

# %%
from sklearn.metrics import classification_report

report = classification_report(y_test, y_pred, output_dict=True)
print({
    "accuracy": report["accuracy"],
    "macro_f1": report["macro avg"]["f1-score"],
    "weighted_f1": report["weighted avg"]["f1-score"]
})
# Out:
# {'accuracy': 0.8706338939197931, 'macro_f1': 0.8461444114609299, 'weighted_f1': 0.8701654771956613}
