# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import (
    Input, Conv1D, BatchNormalization,
    ReLU, Add, GlobalAveragePooling1D, Dense
)
from tensorflow.keras.models import Model
# Out:
# 2026-04-08 21:59:18.087326: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-04-08 21:59:18.097686: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1775660358.109493  206272 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1775660358.113427  206272 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1775660358.123303  206272 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1775660358.123319  206272 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1775660358.123320  206272 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1775660358.123321  206272 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-04-08 21:59:18.126819: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
pathload = "/home/dani/Documents/tugas akhir/TugasAkhirku2026/mrtcn_ids/Preprocessing/hasil/final/preprocessingimgsize64_s16/preprocessingimgsize64_s16.npz"
data = np.load(
    pathload,
    mmap_mode="r"   # penting: tidak load penuh ke RAM
)

print(data.files)
# Out:
# ['x_train', 'y_train', 'x_val', 'y_val', 'x_test', 'y_test']

# %%
data = np.load(
    pathload,
)

X_train = data["x_train"]
y_train = data["y_train"]
X_val   = data["x_val"]
y_val   = data["y_val"]
X_test  = data["x_test"]
y_test  = data["y_test"]

print(X_train.shape, y_train.shape)
print(X_val.shape, y_val.shape)
print(X_test.shape, y_test.shape)
# Out:
# (52661, 64, 64) (52661,)
# (22569, 64, 64) (22569,)
# (49472, 64, 64) (49472,)

# %%
np.unique(y_train, return_counts=True)
# Out:
# (array([0, 1]), array([24073, 28588]))

# %%
import numpy as np

# Fungsi untuk cek balance
def check_balance_binary(y):
    n_normal = np.sum(y == 0)
    n_attack = np.sum(y == 1)
    total = len(y)
    print(f"Total samples: {total}")
    print(f"Normal: {n_normal} ({n_normal/total*100:.2f}%)")
    print(f"Attack: {n_attack} ({n_attack/total*100:.2f}%)\n")

# Cek balance di masing-masing split
print("=== Train Set ===")
check_balance_binary(y_train)

print("=== Validation Set ===")
check_balance_binary(y_val)

print("=== Test Set ===")
check_balance_binary(y_test)
# Out:
# === Train Set ===
# Total samples: 52661
# Normal: 24073 (45.71%)
# Attack: 28588 (54.29%)
#
# === Validation Set ===
# Total samples: 22569
# Normal: 10317 (45.71%)
# Attack: 12252 (54.29%)
#
# === Test Set ===
# Total samples: 49472
# Normal: 27375 (55.33%)
# Attack: 22097 (44.67%)

# %%
def tcn_block(x, filters, kernel_size, dilation):
    shortcut = x

    x = Conv1D(filters, kernel_size,
               padding="causal",
               dilation_rate=dilation)(x)
    x = BatchNormalization()(x)
    x = ReLU()(x)

    x = Conv1D(filters, kernel_size,
               padding="causal",
               dilation_rate=dilation)(x)
    x = BatchNormalization()(x)

    if shortcut.shape[-1] != filters:
        shortcut = Conv1D(filters, 1, padding="same")(shortcut)

    x = Add()([x, shortcut])
    x = ReLU()(x)
    return x

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, Dropout, MaxPooling1D, Flatten, Dense

def build_mr_tcn(input_shape=(64, 64), dropout_rate=0.00):
    model = Sequential()

    # Conv1D #1
    model.add(Conv1D(
        filters=64,
        kernel_size=3,
        strides=1,
        dilation_rate=1,
        padding="same",
        activation="relu",
        input_shape=input_shape
    ))
    model.add(Dropout(dropout_rate))

    # Conv1D #2
    model.add(Conv1D(
        filters=64,
        kernel_size=3,
        strides=1,
        dilation_rate=2,
        padding="same",
        activation="relu"
    ))
    model.add(Dropout(dropout_rate))

    # Conv1D #3
    model.add(Conv1D(
        filters=64,
        kernel_size=3,
        strides=1,
        dilation_rate=4,
        padding="same",
        activation="relu"
    ))
    model.add(Dropout(dropout_rate))

    # MaxPooling
    model.add(MaxPooling1D(pool_size=8, strides=8))

    # Flatten
    model.add(Flatten())

    # Dropout
    model.add(Dropout(dropout_rate))

    # Linear → Sigmoid
    model.add(Dense(1, activation="sigmoid"))

    return model

# %%
model = build_mr_tcn()

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-5),
    loss="binary_crossentropy",
    metrics=["accuracy"]
)

model.summary()
# Out:
# /home/dani/miniconda3/envs/latihan1/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# I0000 00:00:1775660362.822608  206272 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 4144 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d (Conv1D)                 │ (None, 64, 64)         │        12,352 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_1 (Conv1D)               │ (None, 64, 64)         │        12,352 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 64, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_2 (Conv1D)               │ (None, 64, 64)         │        12,352 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 64, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d (MaxPooling1D)    │ (None, 8, 64)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │           513 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 37,569 (146.75 KB)
#  Trainable params: 37,569 (146.75 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# 37,569

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

early_stop = EarlyStopping(
    monitor="val_loss",
    patience=30,
    restore_best_weights=True
)

checkpoint = ModelCheckpoint(
    "best_mr_tcn.keras",
    monitor="val_loss",
    save_best_only=True,
    verbose=1
)

# %%
history = model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=700,
    batch_size=64,
    callbacks=[early_stop, checkpoint]
)
# Out:
# Epoch 1/700
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1775660364.831451  206414 service.cc:152] XLA service 0x7b5ef400bc00 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1775660364.831473  206414 service.cc:160]   StreamExecutor device (0): NVIDIA GeForce RTX 3060 Laptop GPU, Compute Capability 8.6
# 2026-04-08 21:59:24.855142: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1775660364.997437  206414 cuda_dnn.cc:529] Loaded cuDNN version 91701
#  97/823 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5467 - loss: 0.7115
# I0000 00:00:1775660365.951643  206414 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.5744 - loss: 0.6884
# Epoch 1: val_loss improved from None to 0.63425, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 6s 5ms/step - accuracy: 0.6312 - loss: 0.6694 - val_accuracy: 0.7096 - val_loss: 0.6343
# Epoch 2/700
# 794/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7768 - loss: 0.6141
# Epoch 2: val_loss improved from 0.63425 to 0.53341, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8185 - loss: 0.5892 - val_accuracy: 0.8719 - val_loss: 0.5334
# Epoch 3/700
# 804/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8784 - loss: 0.5030
# Epoch 3: val_loss improved from 0.53341 to 0.40683, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8841 - loss: 0.4705 - val_accuracy: 0.8960 - val_loss: 0.4068
# Epoch 4/700
# 820/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8946 - loss: 0.3865
# Epoch 4: val_loss improved from 0.40683 to 0.32286, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8985 - loss: 0.3637 - val_accuracy: 0.9031 - val_loss: 0.3229
# Epoch 5/700
# 813/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9051 - loss: 0.3101
# Epoch 5: val_loss improved from 0.32286 to 0.27439, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9063 - loss: 0.2987 - val_accuracy: 0.9089 - val_loss: 0.2744
# Epoch 6/700
# 796/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9098 - loss: 0.2693
# Epoch 6: val_loss improved from 0.27439 to 0.24320, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9110 - loss: 0.2599 - val_accuracy: 0.9145 - val_loss: 0.2432
# Epoch 7/700
# 794/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9148 - loss: 0.2403
# Epoch 7: val_loss improved from 0.24320 to 0.21840, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9171 - loss: 0.2320 - val_accuracy: 0.9214 - val_loss: 0.2184
# Epoch 8/700
# 810/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9187 - loss: 0.2173
# Epoch 8: val_loss improved from 0.21840 to 0.19587, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9229 - loss: 0.2081 - val_accuracy: 0.9282 - val_loss: 0.1959
# Epoch 9/700
# 806/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9277 - loss: 0.1911
# Epoch 9: val_loss improved from 0.19587 to 0.17605, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9299 - loss: 0.1865 - val_accuracy: 0.9343 - val_loss: 0.1760
# Epoch 10/700
# 810/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9357 - loss: 0.1715
# Epoch 10: val_loss improved from 0.17605 to 0.15777, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9376 - loss: 0.1674 - val_accuracy: 0.9419 - val_loss: 0.1578
# Epoch 11/700
# 816/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9432 - loss: 0.1542
# Epoch 11: val_loss improved from 0.15777 to 0.14165, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9456 - loss: 0.1498 - val_accuracy: 0.9506 - val_loss: 0.1417
# Epoch 12/700
# 801/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9539 - loss: 0.1354
# Epoch 12: val_loss improved from 0.14165 to 0.12766, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9541 - loss: 0.1343 - val_accuracy: 0.9588 - val_loss: 0.1277
# Epoch 13/700
# 796/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9614 - loss: 0.1235
# Epoch 13: val_loss improved from 0.12766 to 0.11612, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9615 - loss: 0.1209 - val_accuracy: 0.9672 - val_loss: 0.1161
# Epoch 14/700
# 804/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9679 - loss: 0.1092
# Epoch 14: val_loss improved from 0.11612 to 0.10653, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9677 - loss: 0.1097 - val_accuracy: 0.9668 - val_loss: 0.1065
# Epoch 15/700
# 809/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9702 - loss: 0.1042
# Epoch 15: val_loss improved from 0.10653 to 0.09805, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9713 - loss: 0.1006 - val_accuracy: 0.9721 - val_loss: 0.0980
# Epoch 16/700
# 813/823 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9730 - loss: 0.0952
# Epoch 16: val_loss improved from 0.09805 to 0.09203, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9738 - loss: 0.0935 - val_accuracy: 0.9734 - val_loss: 0.0920
# Epoch 17/700
# 809/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9750 - loss: 0.0886
# Epoch 17: val_loss improved from 0.09203 to 0.08695, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9748 - loss: 0.0879 - val_accuracy: 0.9747 - val_loss: 0.0870
# Epoch 18/700
# 794/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9754 - loss: 0.0852
# Epoch 18: val_loss improved from 0.08695 to 0.08299, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9758 - loss: 0.0833 - val_accuracy: 0.9756 - val_loss: 0.0830
# Epoch 19/700
# 805/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9765 - loss: 0.0808
# Epoch 19: val_loss improved from 0.08299 to 0.07964, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9767 - loss: 0.0795 - val_accuracy: 0.9764 - val_loss: 0.0796
# Epoch 20/700
# 806/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9776 - loss: 0.0775
# Epoch 20: val_loss improved from 0.07964 to 0.07698, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9771 - loss: 0.0766 - val_accuracy: 0.9768 - val_loss: 0.0770
# Epoch 21/700
# 807/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9780 - loss: 0.0743
# Epoch 21: val_loss improved from 0.07698 to 0.07466, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9777 - loss: 0.0740 - val_accuracy: 0.9772 - val_loss: 0.0747
# Epoch 22/700
# 808/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9787 - loss: 0.0709
# Epoch 22: val_loss improved from 0.07466 to 0.07303, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9783 - loss: 0.0717 - val_accuracy: 0.9774 - val_loss: 0.0730
# Epoch 23/700
# 817/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9783 - loss: 0.0720
# Epoch 23: val_loss improved from 0.07303 to 0.07129, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9785 - loss: 0.0696 - val_accuracy: 0.9778 - val_loss: 0.0713
# Epoch 24/700
# 793/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9797 - loss: 0.0669
# Epoch 24: val_loss improved from 0.07129 to 0.06927, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9789 - loss: 0.0678 - val_accuracy: 0.9781 - val_loss: 0.0693
# Epoch 25/700
# 794/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9790 - loss: 0.0671
# Epoch 25: val_loss improved from 0.06927 to 0.06772, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9794 - loss: 0.0662 - val_accuracy: 0.9784 - val_loss: 0.0677
# Epoch 26/700
# 818/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9789 - loss: 0.0666
# Epoch 26: val_loss improved from 0.06772 to 0.06651, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9798 - loss: 0.0648 - val_accuracy: 0.9787 - val_loss: 0.0665
# Epoch 27/700
# 815/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9799 - loss: 0.0639
# Epoch 27: val_loss did not improve from 0.06651
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9800 - loss: 0.0634 - val_accuracy: 0.9792 - val_loss: 0.0678
# Epoch 28/700
# 820/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9799 - loss: 0.0629
# Epoch 28: val_loss improved from 0.06651 to 0.06586, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9801 - loss: 0.0623 - val_accuracy: 0.9792 - val_loss: 0.0659
# Epoch 29/700
# 808/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9807 - loss: 0.0605
# Epoch 29: val_loss improved from 0.06586 to 0.06284, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9807 - loss: 0.0612 - val_accuracy: 0.9798 - val_loss: 0.0628
# Epoch 30/700
# 820/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9813 - loss: 0.0609
# Epoch 30: val_loss improved from 0.06284 to 0.06274, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9809 - loss: 0.0601 - val_accuracy: 0.9801 - val_loss: 0.0627
# Epoch 31/700
# 819/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9816 - loss: 0.0568
# Epoch 31: val_loss improved from 0.06274 to 0.06139, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9809 - loss: 0.0590 - val_accuracy: 0.9804 - val_loss: 0.0614
# Epoch 32/700
# 799/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9811 - loss: 0.0595
# Epoch 32: val_loss improved from 0.06139 to 0.06027, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9815 - loss: 0.0582 - val_accuracy: 0.9810 - val_loss: 0.0603
# Epoch 33/700
# 815/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9812 - loss: 0.0573
# Epoch 33: val_loss improved from 0.06027 to 0.05937, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9819 - loss: 0.0573 - val_accuracy: 0.9810 - val_loss: 0.0594
# Epoch 34/700
# 819/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9817 - loss: 0.0572
# Epoch 34: val_loss improved from 0.05937 to 0.05849, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9819 - loss: 0.0566 - val_accuracy: 0.9807 - val_loss: 0.0585
# Epoch 35/700
# 808/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9828 - loss: 0.0552
# Epoch 35: val_loss did not improve from 0.05849
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9821 - loss: 0.0558 - val_accuracy: 0.9809 - val_loss: 0.0586
# Epoch 36/700
# 808/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9825 - loss: 0.0560
# Epoch 36: val_loss improved from 0.05849 to 0.05716, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9826 - loss: 0.0549 - val_accuracy: 0.9811 - val_loss: 0.0572
# Epoch 37/700
# 822/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9839 - loss: 0.0533
# Epoch 37: val_loss improved from 0.05716 to 0.05648, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9829 - loss: 0.0541 - val_accuracy: 0.9815 - val_loss: 0.0565
# Epoch 38/700
# 792/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9821 - loss: 0.0540
# Epoch 38: val_loss improved from 0.05648 to 0.05626, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9830 - loss: 0.0535 - val_accuracy: 0.9815 - val_loss: 0.0563
# Epoch 39/700
# 790/823 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9833 - loss: 0.0524
# Epoch 39: val_loss improved from 0.05626 to 0.05531, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9833 - loss: 0.0527 - val_accuracy: 0.9817 - val_loss: 0.0553
# Epoch 40/700
# 811/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9832 - loss: 0.0538
# Epoch 40: val_loss improved from 0.05531 to 0.05439, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9835 - loss: 0.0521 - val_accuracy: 0.9819 - val_loss: 0.0544
# Epoch 41/700
# 797/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9833 - loss: 0.0525
# Epoch 41: val_loss improved from 0.05439 to 0.05423, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9836 - loss: 0.0514 - val_accuracy: 0.9819 - val_loss: 0.0542
# Epoch 42/700
# 808/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9840 - loss: 0.0495
# Epoch 42: val_loss improved from 0.05423 to 0.05358, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9837 - loss: 0.0507 - val_accuracy: 0.9821 - val_loss: 0.0536
# Epoch 43/700
# 821/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9837 - loss: 0.0518
# Epoch 43: val_loss improved from 0.05358 to 0.05277, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9840 - loss: 0.0501 - val_accuracy: 0.9825 - val_loss: 0.0528
# Epoch 44/700
# 804/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9833 - loss: 0.0524
# Epoch 44: val_loss improved from 0.05277 to 0.05260, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9841 - loss: 0.0495 - val_accuracy: 0.9827 - val_loss: 0.0526
# Epoch 45/700
# 810/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9834 - loss: 0.0502
# Epoch 45: val_loss improved from 0.05260 to 0.05162, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9844 - loss: 0.0491 - val_accuracy: 0.9828 - val_loss: 0.0516
# Epoch 46/700
# 803/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9850 - loss: 0.0471
# Epoch 46: val_loss improved from 0.05162 to 0.05103, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9846 - loss: 0.0484 - val_accuracy: 0.9830 - val_loss: 0.0510
# Epoch 47/700
# 819/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9841 - loss: 0.0480
# Epoch 47: val_loss improved from 0.05103 to 0.05079, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9846 - loss: 0.0479 - val_accuracy: 0.9832 - val_loss: 0.0508
# Epoch 48/700
# 795/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9853 - loss: 0.0470
# Epoch 48: val_loss improved from 0.05079 to 0.05010, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9848 - loss: 0.0473 - val_accuracy: 0.9835 - val_loss: 0.0501
# Epoch 49/700
# 797/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9847 - loss: 0.0479
# Epoch 49: val_loss did not improve from 0.05010
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9849 - loss: 0.0467 - val_accuracy: 0.9838 - val_loss: 0.0502
# Epoch 50/700
# 802/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9853 - loss: 0.0461
# Epoch 50: val_loss improved from 0.05010 to 0.04933, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9853 - loss: 0.0463 - val_accuracy: 0.9834 - val_loss: 0.0493
# Epoch 51/700
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9861 - loss: 0.0453
# Epoch 51: val_loss did not improve from 0.04933
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9856 - loss: 0.0458 - val_accuracy: 0.9834 - val_loss: 0.0494
# Epoch 52/700
# 813/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9870 - loss: 0.0434
# Epoch 52: val_loss improved from 0.04933 to 0.04914, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9855 - loss: 0.0454 - val_accuracy: 0.9835 - val_loss: 0.0491
# Epoch 53/700
# 812/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9862 - loss: 0.0436
# Epoch 53: val_loss improved from 0.04914 to 0.04852, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9857 - loss: 0.0447 - val_accuracy: 0.9835 - val_loss: 0.0485
# Epoch 54/700
# 805/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9862 - loss: 0.0449
# Epoch 54: val_loss improved from 0.04852 to 0.04819, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9859 - loss: 0.0444 - val_accuracy: 0.9837 - val_loss: 0.0482
# Epoch 55/700
# 804/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9856 - loss: 0.0441
# Epoch 55: val_loss improved from 0.04819 to 0.04723, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9862 - loss: 0.0438 - val_accuracy: 0.9842 - val_loss: 0.0472
# Epoch 56/700
# 790/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9856 - loss: 0.0436
# Epoch 56: val_loss improved from 0.04723 to 0.04657, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9861 - loss: 0.0433 - val_accuracy: 0.9847 - val_loss: 0.0466
# Epoch 57/700
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9862 - loss: 0.0423
# Epoch 57: val_loss did not improve from 0.04657
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9861 - loss: 0.0429 - val_accuracy: 0.9843 - val_loss: 0.0471
# Epoch 58/700
# 804/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9863 - loss: 0.0433
# Epoch 58: val_loss did not improve from 0.04657
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9865 - loss: 0.0425 - val_accuracy: 0.9845 - val_loss: 0.0468
# Epoch 59/700
# 809/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9871 - loss: 0.0415
# Epoch 59: val_loss improved from 0.04657 to 0.04582, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9866 - loss: 0.0420 - val_accuracy: 0.9849 - val_loss: 0.0458
# Epoch 60/700
# 805/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9870 - loss: 0.0417
# Epoch 60: val_loss improved from 0.04582 to 0.04568, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9870 - loss: 0.0416 - val_accuracy: 0.9850 - val_loss: 0.0457
# Epoch 61/700
# 807/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9867 - loss: 0.0426
# Epoch 61: val_loss improved from 0.04568 to 0.04474, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9871 - loss: 0.0412 - val_accuracy: 0.9853 - val_loss: 0.0447
# Epoch 62/700
# 812/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9870 - loss: 0.0402
# Epoch 62: val_loss improved from 0.04474 to 0.04437, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9872 - loss: 0.0410 - val_accuracy: 0.9857 - val_loss: 0.0444
# Epoch 63/700
# 793/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9870 - loss: 0.0404
# Epoch 63: val_loss improved from 0.04437 to 0.04434, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9872 - loss: 0.0404 - val_accuracy: 0.9852 - val_loss: 0.0443
# Epoch 64/700
# 798/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9869 - loss: 0.0411
# Epoch 64: val_loss improved from 0.04434 to 0.04386, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9873 - loss: 0.0400 - val_accuracy: 0.9856 - val_loss: 0.0439
# Epoch 65/700
# 822/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9873 - loss: 0.0398
# Epoch 65: val_loss improved from 0.04386 to 0.04350, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9876 - loss: 0.0398 - val_accuracy: 0.9859 - val_loss: 0.0435
# Epoch 66/700
# 820/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9879 - loss: 0.0391
# Epoch 66: val_loss improved from 0.04350 to 0.04319, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9876 - loss: 0.0393 - val_accuracy: 0.9860 - val_loss: 0.0432
# Epoch 67/700
# 813/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9877 - loss: 0.0386
# Epoch 67: val_loss did not improve from 0.04319
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9876 - loss: 0.0390 - val_accuracy: 0.9861 - val_loss: 0.0434
# Epoch 68/700
# 808/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9879 - loss: 0.0384
# Epoch 68: val_loss did not improve from 0.04319
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9878 - loss: 0.0386 - val_accuracy: 0.9856 - val_loss: 0.0434
# Epoch 69/700
# 806/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9884 - loss: 0.0371
# Epoch 69: val_loss did not improve from 0.04319
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9881 - loss: 0.0382 - val_accuracy: 0.9853 - val_loss: 0.0458
# Epoch 70/700
# 805/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9879 - loss: 0.0387
# Epoch 70: val_loss improved from 0.04319 to 0.04282, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9880 - loss: 0.0379 - val_accuracy: 0.9859 - val_loss: 0.0428
# Epoch 71/700
# 807/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9879 - loss: 0.0387
# Epoch 71: val_loss improved from 0.04282 to 0.04233, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9881 - loss: 0.0376 - val_accuracy: 0.9862 - val_loss: 0.0423
# Epoch 72/700
# 794/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9881 - loss: 0.0377
# Epoch 72: val_loss improved from 0.04233 to 0.04143, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9883 - loss: 0.0372 - val_accuracy: 0.9863 - val_loss: 0.0414
# Epoch 73/700
# 810/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9875 - loss: 0.0373
# Epoch 73: val_loss improved from 0.04143 to 0.04127, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9881 - loss: 0.0370 - val_accuracy: 0.9864 - val_loss: 0.0413
# Epoch 74/700
# 799/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9888 - loss: 0.0359
# Epoch 74: val_loss improved from 0.04127 to 0.04079, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9886 - loss: 0.0366 - val_accuracy: 0.9866 - val_loss: 0.0408
# Epoch 75/700
# 804/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9885 - loss: 0.0361
# Epoch 75: val_loss improved from 0.04079 to 0.04053, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9886 - loss: 0.0364 - val_accuracy: 0.9868 - val_loss: 0.0405
# Epoch 76/700
# 815/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9889 - loss: 0.0350
# Epoch 76: val_loss improved from 0.04053 to 0.04035, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9888 - loss: 0.0359 - val_accuracy: 0.9871 - val_loss: 0.0404
# Epoch 77/700
# 821/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9893 - loss: 0.0342
# Epoch 77: val_loss did not improve from 0.04035
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9890 - loss: 0.0357 - val_accuracy: 0.9867 - val_loss: 0.0409
# Epoch 78/700
# 799/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9892 - loss: 0.0337
# Epoch 78: val_loss improved from 0.04035 to 0.03990, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9888 - loss: 0.0354 - val_accuracy: 0.9871 - val_loss: 0.0399
# Epoch 79/700
# 791/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9889 - loss: 0.0367
# Epoch 79: val_loss did not improve from 0.03990
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9892 - loss: 0.0351 - val_accuracy: 0.9866 - val_loss: 0.0410
# Epoch 80/700
# 810/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9883 - loss: 0.0353
# Epoch 80: val_loss improved from 0.03990 to 0.03942, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9889 - loss: 0.0348 - val_accuracy: 0.9873 - val_loss: 0.0394
# Epoch 81/700
# 808/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9893 - loss: 0.0340
# Epoch 81: val_loss improved from 0.03942 to 0.03908, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9892 - loss: 0.0345 - val_accuracy: 0.9870 - val_loss: 0.0391
# Epoch 82/700
# 805/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9898 - loss: 0.0327
# Epoch 82: val_loss did not improve from 0.03908
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9894 - loss: 0.0342 - val_accuracy: 0.9872 - val_loss: 0.0397
# Epoch 83/700
# 809/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9887 - loss: 0.0357
# Epoch 83: val_loss improved from 0.03908 to 0.03893, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9892 - loss: 0.0339 - val_accuracy: 0.9873 - val_loss: 0.0389
# Epoch 84/700
# 816/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9899 - loss: 0.0325
# Epoch 84: val_loss improved from 0.03893 to 0.03843, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9896 - loss: 0.0336 - val_accuracy: 0.9878 - val_loss: 0.0384
# Epoch 85/700
# 815/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9897 - loss: 0.0338
# Epoch 85: val_loss improved from 0.03843 to 0.03825, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9895 - loss: 0.0334 - val_accuracy: 0.9875 - val_loss: 0.0382
# Epoch 86/700
# 799/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9904 - loss: 0.0323
# Epoch 86: val_loss improved from 0.03825 to 0.03798, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9899 - loss: 0.0330 - val_accuracy: 0.9875 - val_loss: 0.0380
# Epoch 87/700
# 805/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9896 - loss: 0.0334
# Epoch 87: val_loss improved from 0.03798 to 0.03779, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9898 - loss: 0.0328 - val_accuracy: 0.9876 - val_loss: 0.0378
# Epoch 88/700
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9903 - loss: 0.0323
# Epoch 88: val_loss improved from 0.03779 to 0.03776, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9898 - loss: 0.0325 - val_accuracy: 0.9875 - val_loss: 0.0378
# Epoch 89/700
# 816/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9898 - loss: 0.0337
# Epoch 89: val_loss improved from 0.03776 to 0.03756, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9899 - loss: 0.0323 - val_accuracy: 0.9878 - val_loss: 0.0376
# Epoch 90/700
# 800/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9894 - loss: 0.0327
# Epoch 90: val_loss improved from 0.03756 to 0.03732, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9898 - loss: 0.0321 - val_accuracy: 0.9876 - val_loss: 0.0373
# Epoch 91/700
# 818/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9905 - loss: 0.0304
# Epoch 91: val_loss did not improve from 0.03732
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9901 - loss: 0.0317 - val_accuracy: 0.9878 - val_loss: 0.0377
# Epoch 92/700
# 800/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9908 - loss: 0.0302
# Epoch 92: val_loss improved from 0.03732 to 0.03724, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9903 - loss: 0.0316 - val_accuracy: 0.9882 - val_loss: 0.0372
# Epoch 93/700
# 798/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9911 - loss: 0.0296
# Epoch 93: val_loss improved from 0.03724 to 0.03716, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9903 - loss: 0.0313 - val_accuracy: 0.9880 - val_loss: 0.0372
# Epoch 94/700
# 800/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9896 - loss: 0.0321
# Epoch 94: val_loss improved from 0.03716 to 0.03675, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9904 - loss: 0.0310 - val_accuracy: 0.9880 - val_loss: 0.0367
# Epoch 95/700
# 807/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9907 - loss: 0.0309
# Epoch 95: val_loss improved from 0.03675 to 0.03641, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9907 - loss: 0.0307 - val_accuracy: 0.9878 - val_loss: 0.0364
# Epoch 96/700
# 813/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9900 - loss: 0.0318
# Epoch 96: val_loss improved from 0.03641 to 0.03627, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9905 - loss: 0.0306 - val_accuracy: 0.9882 - val_loss: 0.0363
# Epoch 97/700
# 820/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9906 - loss: 0.0305
# Epoch 97: val_loss improved from 0.03627 to 0.03614, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9906 - loss: 0.0304 - val_accuracy: 0.9881 - val_loss: 0.0361
# Epoch 98/700
# 811/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9914 - loss: 0.0283
# Epoch 98: val_loss improved from 0.03614 to 0.03591, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9908 - loss: 0.0301 - val_accuracy: 0.9883 - val_loss: 0.0359
# Epoch 99/700
# 793/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9904 - loss: 0.0298
# Epoch 99: val_loss did not improve from 0.03591
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9906 - loss: 0.0300 - val_accuracy: 0.9883 - val_loss: 0.0359
# Epoch 100/700
# 800/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9902 - loss: 0.0311
# Epoch 100: val_loss improved from 0.03591 to 0.03557, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9908 - loss: 0.0296 - val_accuracy: 0.9879 - val_loss: 0.0356
# Epoch 101/700
# 820/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9901 - loss: 0.0304
# Epoch 101: val_loss did not improve from 0.03557
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9909 - loss: 0.0294 - val_accuracy: 0.9880 - val_loss: 0.0359
# Epoch 102/700
# 817/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9901 - loss: 0.0313
# Epoch 102: val_loss improved from 0.03557 to 0.03544, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9908 - loss: 0.0291 - val_accuracy: 0.9883 - val_loss: 0.0354
# Epoch 103/700
# 801/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9905 - loss: 0.0305
# Epoch 103: val_loss improved from 0.03544 to 0.03541, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9911 - loss: 0.0290 - val_accuracy: 0.9883 - val_loss: 0.0354
# Epoch 104/700
# 792/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9909 - loss: 0.0283
# Epoch 104: val_loss did not improve from 0.03541
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9912 - loss: 0.0288 - val_accuracy: 0.9888 - val_loss: 0.0363
# Epoch 105/700
# 814/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9910 - loss: 0.0290
# Epoch 105: val_loss improved from 0.03541 to 0.03482, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9912 - loss: 0.0286 - val_accuracy: 0.9886 - val_loss: 0.0348
# Epoch 106/700
# 820/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9914 - loss: 0.0272
# Epoch 106: val_loss did not improve from 0.03482
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9912 - loss: 0.0285 - val_accuracy: 0.9888 - val_loss: 0.0359
# Epoch 107/700
# 820/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9917 - loss: 0.0269
# Epoch 107: val_loss did not improve from 0.03482
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9913 - loss: 0.0283 - val_accuracy: 0.9885 - val_loss: 0.0349
# Epoch 108/700
# 800/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9913 - loss: 0.0289
# Epoch 108: val_loss improved from 0.03482 to 0.03437, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9915 - loss: 0.0281 - val_accuracy: 0.9885 - val_loss: 0.0344
# Epoch 109/700
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9915 - loss: 0.0271
# Epoch 109: val_loss did not improve from 0.03437
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9916 - loss: 0.0278 - val_accuracy: 0.9884 - val_loss: 0.0345
# Epoch 110/700
# 818/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9918 - loss: 0.0280
# Epoch 110: val_loss improved from 0.03437 to 0.03430, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9917 - loss: 0.0277 - val_accuracy: 0.9889 - val_loss: 0.0343
# Epoch 111/700
# 794/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9913 - loss: 0.0277
# Epoch 111: val_loss improved from 0.03430 to 0.03403, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9916 - loss: 0.0273 - val_accuracy: 0.9886 - val_loss: 0.0340
# Epoch 112/700
# 822/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9912 - loss: 0.0278
# Epoch 112: val_loss improved from 0.03403 to 0.03393, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9915 - loss: 0.0273 - val_accuracy: 0.9887 - val_loss: 0.0339
# Epoch 113/700
# 813/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9921 - loss: 0.0262
# Epoch 113: val_loss did not improve from 0.03393
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9918 - loss: 0.0270 - val_accuracy: 0.9887 - val_loss: 0.0340
# Epoch 114/700
# 804/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9920 - loss: 0.0264
# Epoch 114: val_loss improved from 0.03393 to 0.03384, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9917 - loss: 0.0269 - val_accuracy: 0.9890 - val_loss: 0.0338
# Epoch 115/700
# 795/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9916 - loss: 0.0272
# Epoch 115: val_loss did not improve from 0.03384
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9918 - loss: 0.0267 - val_accuracy: 0.9887 - val_loss: 0.0345
# Epoch 116/700
# 805/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9918 - loss: 0.0264
# Epoch 116: val_loss improved from 0.03384 to 0.03343, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9919 - loss: 0.0266 - val_accuracy: 0.9889 - val_loss: 0.0334
# Epoch 117/700
# 807/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9923 - loss: 0.0260
# Epoch 117: val_loss did not improve from 0.03343
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9922 - loss: 0.0263 - val_accuracy: 0.9888 - val_loss: 0.0334
# Epoch 118/700
# 821/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9922 - loss: 0.0265
# Epoch 118: val_loss improved from 0.03343 to 0.03319, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9921 - loss: 0.0262 - val_accuracy: 0.9891 - val_loss: 0.0332
# Epoch 119/700
# 793/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9921 - loss: 0.0255
# Epoch 119: val_loss did not improve from 0.03319
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9921 - loss: 0.0260 - val_accuracy: 0.9890 - val_loss: 0.0332
# Epoch 120/700
# 790/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9913 - loss: 0.0265
# Epoch 120: val_loss did not improve from 0.03319
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9920 - loss: 0.0259 - val_accuracy: 0.9891 - val_loss: 0.0347
# Epoch 121/700
# 795/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9929 - loss: 0.0252
# Epoch 121: val_loss did not improve from 0.03319
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9924 - loss: 0.0256 - val_accuracy: 0.9890 - val_loss: 0.0335
# Epoch 122/700
# 809/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9918 - loss: 0.0254
# Epoch 122: val_loss did not improve from 0.03319
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9923 - loss: 0.0255 - val_accuracy: 0.9890 - val_loss: 0.0336
# Epoch 123/700
# 816/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9919 - loss: 0.0274
# Epoch 123: val_loss did not improve from 0.03319
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9922 - loss: 0.0253 - val_accuracy: 0.9892 - val_loss: 0.0336
# Epoch 124/700
# 794/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9921 - loss: 0.0251
# Epoch 124: val_loss did not improve from 0.03319
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9924 - loss: 0.0252 - val_accuracy: 0.9893 - val_loss: 0.0332
# Epoch 125/700
# 819/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9925 - loss: 0.0247
# Epoch 125: val_loss did not improve from 0.03319
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9925 - loss: 0.0250 - val_accuracy: 0.9893 - val_loss: 0.0336
# Epoch 126/700
# 808/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9918 - loss: 0.0262
# Epoch 126: val_loss improved from 0.03319 to 0.03250, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9923 - loss: 0.0248 - val_accuracy: 0.9893 - val_loss: 0.0325
# Epoch 127/700
# 796/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9925 - loss: 0.0238
# Epoch 127: val_loss improved from 0.03250 to 0.03239, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9926 - loss: 0.0247 - val_accuracy: 0.9893 - val_loss: 0.0324
# Epoch 128/700
# 801/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9925 - loss: 0.0249
# Epoch 128: val_loss improved from 0.03239 to 0.03235, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9925 - loss: 0.0245 - val_accuracy: 0.9895 - val_loss: 0.0324
# Epoch 129/700
# 793/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9929 - loss: 0.0247
# Epoch 129: val_loss did not improve from 0.03235
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9926 - loss: 0.0244 - val_accuracy: 0.9895 - val_loss: 0.0326
# Epoch 130/700
# 815/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9928 - loss: 0.0246
# Epoch 130: val_loss improved from 0.03235 to 0.03203, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9928 - loss: 0.0242 - val_accuracy: 0.9895 - val_loss: 0.0320
# Epoch 131/700
# 819/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9927 - loss: 0.0254
# Epoch 131: val_loss did not improve from 0.03203
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9928 - loss: 0.0241 - val_accuracy: 0.9892 - val_loss: 0.0333
# Epoch 132/700
# 804/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9929 - loss: 0.0235
# Epoch 132: val_loss did not improve from 0.03203
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9927 - loss: 0.0240 - val_accuracy: 0.9896 - val_loss: 0.0324
# Epoch 133/700
# 796/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9925 - loss: 0.0249
# Epoch 133: val_loss improved from 0.03203 to 0.03202, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9927 - loss: 0.0238 - val_accuracy: 0.9896 - val_loss: 0.0320
# Epoch 134/700
# 806/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9919 - loss: 0.0249
# Epoch 134: val_loss improved from 0.03202 to 0.03195, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9927 - loss: 0.0237 - val_accuracy: 0.9897 - val_loss: 0.0320
# Epoch 135/700
# 800/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9933 - loss: 0.0221
# Epoch 135: val_loss improved from 0.03195 to 0.03189, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9929 - loss: 0.0236 - val_accuracy: 0.9896 - val_loss: 0.0319
# Epoch 136/700
# 797/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9930 - loss: 0.0227
# Epoch 136: val_loss improved from 0.03189 to 0.03160, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9929 - loss: 0.0233 - val_accuracy: 0.9896 - val_loss: 0.0316
# Epoch 137/700
# 799/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9928 - loss: 0.0224
# Epoch 137: val_loss did not improve from 0.03160
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9928 - loss: 0.0233 - val_accuracy: 0.9895 - val_loss: 0.0321
# Epoch 138/700
# 818/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9939 - loss: 0.0220
# Epoch 138: val_loss improved from 0.03160 to 0.03143, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9931 - loss: 0.0233 - val_accuracy: 0.9896 - val_loss: 0.0314
# Epoch 139/700
# 814/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9928 - loss: 0.0236
# Epoch 139: val_loss did not improve from 0.03143
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9932 - loss: 0.0230 - val_accuracy: 0.9896 - val_loss: 0.0321
# Epoch 140/700
# 804/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9935 - loss: 0.0227
# Epoch 140: val_loss improved from 0.03143 to 0.03137, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9931 - loss: 0.0227 - val_accuracy: 0.9900 - val_loss: 0.0314
# Epoch 141/700
# 821/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9934 - loss: 0.0227
# Epoch 141: val_loss did not improve from 0.03137
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9933 - loss: 0.0227 - val_accuracy: 0.9893 - val_loss: 0.0340
# Epoch 142/700
# 808/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9928 - loss: 0.0225
# Epoch 142: val_loss improved from 0.03137 to 0.03125, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9932 - loss: 0.0226 - val_accuracy: 0.9897 - val_loss: 0.0313
# Epoch 143/700
# 818/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9931 - loss: 0.0226
# Epoch 143: val_loss improved from 0.03125 to 0.03125, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9932 - loss: 0.0224 - val_accuracy: 0.9897 - val_loss: 0.0313
# Epoch 144/700
# 796/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9935 - loss: 0.0218
# Epoch 144: val_loss improved from 0.03125 to 0.03109, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9933 - loss: 0.0223 - val_accuracy: 0.9899 - val_loss: 0.0311
# Epoch 145/700
# 801/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9932 - loss: 0.0223
# Epoch 145: val_loss improved from 0.03109 to 0.03108, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9933 - loss: 0.0222 - val_accuracy: 0.9901 - val_loss: 0.0311
# Epoch 146/700
# 818/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9936 - loss: 0.0204
# Epoch 146: val_loss improved from 0.03108 to 0.03088, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9932 - loss: 0.0221 - val_accuracy: 0.9899 - val_loss: 0.0309
# Epoch 147/700
# 802/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9944 - loss: 0.0214
# Epoch 147: val_loss did not improve from 0.03088
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9934 - loss: 0.0220 - val_accuracy: 0.9892 - val_loss: 0.0317
# Epoch 148/700
# 799/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9940 - loss: 0.0210
# Epoch 148: val_loss did not improve from 0.03088
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9934 - loss: 0.0218 - val_accuracy: 0.9899 - val_loss: 0.0310
# Epoch 149/700
# 816/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9933 - loss: 0.0227
# Epoch 149: val_loss did not improve from 0.03088
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9935 - loss: 0.0216 - val_accuracy: 0.9896 - val_loss: 0.0316
# Epoch 150/700
# 792/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9938 - loss: 0.0211
# Epoch 150: val_loss did not improve from 0.03088
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9935 - loss: 0.0216 - val_accuracy: 0.9899 - val_loss: 0.0310
# Epoch 151/700
# 804/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9929 - loss: 0.0224
# Epoch 151: val_loss did not improve from 0.03088
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9935 - loss: 0.0214 - val_accuracy: 0.9898 - val_loss: 0.0311
# Epoch 152/700
# 814/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9935 - loss: 0.0210
# Epoch 152: val_loss did not improve from 0.03088
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9935 - loss: 0.0213 - val_accuracy: 0.9895 - val_loss: 0.0318
# Epoch 153/700
# 812/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9941 - loss: 0.0197
# Epoch 153: val_loss improved from 0.03088 to 0.03051, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9936 - loss: 0.0211 - val_accuracy: 0.9902 - val_loss: 0.0305
# Epoch 154/700
# 796/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9944 - loss: 0.0199
# Epoch 154: val_loss improved from 0.03051 to 0.03039, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9937 - loss: 0.0211 - val_accuracy: 0.9902 - val_loss: 0.0304
# Epoch 155/700
# 820/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9940 - loss: 0.0209
# Epoch 155: val_loss did not improve from 0.03039
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9939 - loss: 0.0209 - val_accuracy: 0.9901 - val_loss: 0.0304
# Epoch 156/700
# 800/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9934 - loss: 0.0217
# Epoch 156: val_loss improved from 0.03039 to 0.03025, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9937 - loss: 0.0208 - val_accuracy: 0.9903 - val_loss: 0.0303
# Epoch 157/700
# 815/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9937 - loss: 0.0214
# Epoch 157: val_loss did not improve from 0.03025
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9938 - loss: 0.0207 - val_accuracy: 0.9897 - val_loss: 0.0309
# Epoch 158/700
# 812/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9936 - loss: 0.0212
# Epoch 158: val_loss did not improve from 0.03025
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9936 - loss: 0.0206 - val_accuracy: 0.9894 - val_loss: 0.0319
# Epoch 159/700
# 805/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9940 - loss: 0.0207
# Epoch 159: val_loss improved from 0.03025 to 0.03008, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9939 - loss: 0.0205 - val_accuracy: 0.9901 - val_loss: 0.0301
# Epoch 160/700
# 809/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9938 - loss: 0.0205
# Epoch 160: val_loss did not improve from 0.03008
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9939 - loss: 0.0204 - val_accuracy: 0.9902 - val_loss: 0.0302
# Epoch 161/700
# 793/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9946 - loss: 0.0191
# Epoch 161: val_loss did not improve from 0.03008
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9941 - loss: 0.0203 - val_accuracy: 0.9901 - val_loss: 0.0301
# Epoch 162/700
# 812/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9941 - loss: 0.0194
# Epoch 162: val_loss did not improve from 0.03008
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9941 - loss: 0.0200 - val_accuracy: 0.9902 - val_loss: 0.0301
# Epoch 163/700
# 810/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9941 - loss: 0.0196
# Epoch 163: val_loss did not improve from 0.03008
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9939 - loss: 0.0200 - val_accuracy: 0.9899 - val_loss: 0.0302
# Epoch 164/700
# 803/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9939 - loss: 0.0208
# Epoch 164: val_loss did not improve from 0.03008
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9941 - loss: 0.0198 - val_accuracy: 0.9897 - val_loss: 0.0311
# Epoch 165/700
# 802/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9939 - loss: 0.0205
# Epoch 165: val_loss did not improve from 0.03008
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9941 - loss: 0.0199 - val_accuracy: 0.9900 - val_loss: 0.0304
# Epoch 166/700
# 815/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9941 - loss: 0.0203
# Epoch 166: val_loss improved from 0.03008 to 0.02982, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9944 - loss: 0.0196 - val_accuracy: 0.9899 - val_loss: 0.0298
# Epoch 167/700
# 805/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9946 - loss: 0.0187
# Epoch 167: val_loss did not improve from 0.02982
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9943 - loss: 0.0196 - val_accuracy: 0.9897 - val_loss: 0.0314
# Epoch 168/700
# 821/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9943 - loss: 0.0195
# Epoch 168: val_loss improved from 0.02982 to 0.02971, saving model to best_mr_tcn.keras
# ...
# 817/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9968 - loss: 0.0124
# Epoch 256: val_loss did not improve from 0.02733
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9967 - loss: 0.0124 - val_accuracy: 0.9910 - val_loss: 0.0278
# Epoch 257/700
# 812/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9969 - loss: 0.0123
# Epoch 257: val_loss did not improve from 0.02733
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9968 - loss: 0.0124 - val_accuracy: 0.9900 - val_loss: 0.0315
# Epoch 258/700
# 820/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9968 - loss: 0.0116
# Epoch 258: val_loss did not improve from 0.02733
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9968 - loss: 0.0124 - val_accuracy: 0.9905 - val_loss: 0.0275
# Epoch 259/700
# 806/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9965 - loss: 0.0123
# Epoch 259: val_loss did not improve from 0.02733
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9966 - loss: 0.0123 - val_accuracy: 0.9911 - val_loss: 0.0276
# Epoch 260/700
# 804/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9963 - loss: 0.0136
# Epoch 260: val_loss did not improve from 0.02733
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9966 - loss: 0.0122 - val_accuracy: 0.9903 - val_loss: 0.0275
# Epoch 261/700
# 805/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9965 - loss: 0.0128
# Epoch 261: val_loss did not improve from 0.02733
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9967 - loss: 0.0122 - val_accuracy: 0.9911 - val_loss: 0.0279
# Epoch 262/700
# 819/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9968 - loss: 0.0122
# Epoch 262: val_loss improved from 0.02733 to 0.02727, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9967 - loss: 0.0121 - val_accuracy: 0.9905 - val_loss: 0.0273
# Epoch 263/700
# 818/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9968 - loss: 0.0125
# Epoch 263: val_loss did not improve from 0.02727
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9969 - loss: 0.0120 - val_accuracy: 0.9909 - val_loss: 0.0276
# Epoch 264/700
# 811/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9958 - loss: 0.0136
# Epoch 264: val_loss did not improve from 0.02727
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9966 - loss: 0.0121 - val_accuracy: 0.9910 - val_loss: 0.0283
# Epoch 265/700
# 805/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9966 - loss: 0.0123
# Epoch 265: val_loss did not improve from 0.02727
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9967 - loss: 0.0120 - val_accuracy: 0.9910 - val_loss: 0.0286
# Epoch 266/700
# 795/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9972 - loss: 0.0114
# Epoch 266: val_loss did not improve from 0.02727
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9968 - loss: 0.0119 - val_accuracy: 0.9912 - val_loss: 0.0279
# Epoch 267/700
# 805/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9970 - loss: 0.0117
# Epoch 267: val_loss did not improve from 0.02727
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9970 - loss: 0.0118 - val_accuracy: 0.9907 - val_loss: 0.0276
# Epoch 268/700
# 806/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9970 - loss: 0.0120
# Epoch 268: val_loss did not improve from 0.02727
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9969 - loss: 0.0118 - val_accuracy: 0.9903 - val_loss: 0.0277
# Epoch 269/700
# 797/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9969 - loss: 0.0122
# Epoch 269: val_loss did not improve from 0.02727
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9968 - loss: 0.0117 - val_accuracy: 0.9909 - val_loss: 0.0281
# Epoch 270/700
# 821/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9970 - loss: 0.0113
# Epoch 270: val_loss did not improve from 0.02727
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9970 - loss: 0.0116 - val_accuracy: 0.9909 - val_loss: 0.0274
# Epoch 271/700
# 821/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9970 - loss: 0.0118
# Epoch 271: val_loss did not improve from 0.02727
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9970 - loss: 0.0116 - val_accuracy: 0.9909 - val_loss: 0.0276
# Epoch 272/700
# 811/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9970 - loss: 0.0115
# Epoch 272: val_loss improved from 0.02727 to 0.02723, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9970 - loss: 0.0116 - val_accuracy: 0.9905 - val_loss: 0.0272
# Epoch 273/700
# 812/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9969 - loss: 0.0119
# Epoch 273: val_loss did not improve from 0.02723
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9971 - loss: 0.0114 - val_accuracy: 0.9896 - val_loss: 0.0330
# Epoch 274/700
# 821/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9969 - loss: 0.0121
# Epoch 274: val_loss did not improve from 0.02723
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9968 - loss: 0.0115 - val_accuracy: 0.9906 - val_loss: 0.0273
# Epoch 275/700
# 796/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9971 - loss: 0.0114
# Epoch 275: val_loss did not improve from 0.02723
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9970 - loss: 0.0113 - val_accuracy: 0.9911 - val_loss: 0.0289
# Epoch 276/700
# 795/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9968 - loss: 0.0112
# Epoch 276: val_loss did not improve from 0.02723
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9971 - loss: 0.0112 - val_accuracy: 0.9912 - val_loss: 0.0281
# Epoch 277/700
# 812/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9971 - loss: 0.0105
# Epoch 277: val_loss did not improve from 0.02723
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9971 - loss: 0.0111 - val_accuracy: 0.9909 - val_loss: 0.0272
# Epoch 278/700
# 817/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9973 - loss: 0.0107
# Epoch 278: val_loss did not improve from 0.02723
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9970 - loss: 0.0113 - val_accuracy: 0.9905 - val_loss: 0.0275
# Epoch 279/700
# 805/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9975 - loss: 0.0109
# Epoch 279: val_loss improved from 0.02723 to 0.02711, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9972 - loss: 0.0110 - val_accuracy: 0.9906 - val_loss: 0.0271
# Epoch 280/700
# 790/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9972 - loss: 0.0105
# Epoch 280: val_loss improved from 0.02711 to 0.02704, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9971 - loss: 0.0110 - val_accuracy: 0.9906 - val_loss: 0.0270
# Epoch 281/700
# 800/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9969 - loss: 0.0112
# Epoch 281: val_loss did not improve from 0.02704
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9971 - loss: 0.0110 - val_accuracy: 0.9904 - val_loss: 0.0273
# Epoch 282/700
# 822/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9972 - loss: 0.0111
# Epoch 282: val_loss did not improve from 0.02704
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9972 - loss: 0.0110 - val_accuracy: 0.9905 - val_loss: 0.0273
# Epoch 283/700
# 798/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9967 - loss: 0.0120
# Epoch 283: val_loss did not improve from 0.02704
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9972 - loss: 0.0109 - val_accuracy: 0.9910 - val_loss: 0.0276
# Epoch 284/700
# 802/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9972 - loss: 0.0104
# Epoch 284: val_loss did not improve from 0.02704
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9972 - loss: 0.0109 - val_accuracy: 0.9911 - val_loss: 0.0279
# Epoch 285/700
# 820/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9973 - loss: 0.0107
# Epoch 285: val_loss did not improve from 0.02704
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9973 - loss: 0.0108 - val_accuracy: 0.9905 - val_loss: 0.0272
# Epoch 286/700
# 795/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9974 - loss: 0.0105
# Epoch 286: val_loss did not improve from 0.02704
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9972 - loss: 0.0107 - val_accuracy: 0.9903 - val_loss: 0.0281
# Epoch 287/700
# 816/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9974 - loss: 0.0103
# Epoch 287: val_loss improved from 0.02704 to 0.02703, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9972 - loss: 0.0106 - val_accuracy: 0.9905 - val_loss: 0.0270
# Epoch 288/700
# 794/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9976 - loss: 0.0108
# Epoch 288: val_loss did not improve from 0.02703
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9972 - loss: 0.0106 - val_accuracy: 0.9905 - val_loss: 0.0272
# Epoch 289/700
# 817/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9972 - loss: 0.0108
# Epoch 289: val_loss did not improve from 0.02703
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9971 - loss: 0.0106 - val_accuracy: 0.9910 - val_loss: 0.0282
# Epoch 290/700
# 814/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9969 - loss: 0.0108
# Epoch 290: val_loss did not improve from 0.02703
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9973 - loss: 0.0104 - val_accuracy: 0.9906 - val_loss: 0.0270
# Epoch 291/700
# 818/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9975 - loss: 0.0104
# Epoch 291: val_loss did not improve from 0.02703
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9973 - loss: 0.0104 - val_accuracy: 0.9910 - val_loss: 0.0275
# Epoch 292/700
# 814/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9975 - loss: 0.0106
# Epoch 292: val_loss did not improve from 0.02703
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9974 - loss: 0.0104 - val_accuracy: 0.9910 - val_loss: 0.0282
# Epoch 293/700
# 815/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9972 - loss: 0.0101
# Epoch 293: val_loss did not improve from 0.02703
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9973 - loss: 0.0104 - val_accuracy: 0.9908 - val_loss: 0.0294
# Epoch 294/700
# 819/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9974 - loss: 0.0100
# Epoch 294: val_loss did not improve from 0.02703
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9973 - loss: 0.0103 - val_accuracy: 0.9910 - val_loss: 0.0272
# Epoch 295/700
# 815/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9973 - loss: 0.0098
# Epoch 295: val_loss did not improve from 0.02703
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9974 - loss: 0.0102 - val_accuracy: 0.9908 - val_loss: 0.0273
# Epoch 296/700
# 821/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9975 - loss: 0.0100
# Epoch 296: val_loss did not improve from 0.02703
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9973 - loss: 0.0103 - val_accuracy: 0.9907 - val_loss: 0.0274
# Epoch 297/700
# 814/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9973 - loss: 0.0103
# Epoch 297: val_loss did not improve from 0.02703
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9974 - loss: 0.0101 - val_accuracy: 0.9914 - val_loss: 0.0280
# Epoch 298/700
# 800/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9974 - loss: 0.0101
# Epoch 298: val_loss did not improve from 0.02703
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9975 - loss: 0.0100 - val_accuracy: 0.9903 - val_loss: 0.0283
# Epoch 299/700
# 817/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9973 - loss: 0.0098
# Epoch 299: val_loss did not improve from 0.02703
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9974 - loss: 0.0100 - val_accuracy: 0.9910 - val_loss: 0.0276
# Epoch 300/700
# 820/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9979 - loss: 0.0088
# Epoch 300: val_loss did not improve from 0.02703
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9976 - loss: 0.0098 - val_accuracy: 0.9910 - val_loss: 0.0275
# Epoch 301/700
# 822/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9975 - loss: 0.0105
# Epoch 301: val_loss did not improve from 0.02703
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9975 - loss: 0.0100 - val_accuracy: 0.9911 - val_loss: 0.0275
# Epoch 302/700
# 800/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9974 - loss: 0.0102
# Epoch 302: val_loss did not improve from 0.02703
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9974 - loss: 0.0099 - val_accuracy: 0.9909 - val_loss: 0.0278
# Epoch 303/700
# 815/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9978 - loss: 0.0092
# Epoch 303: val_loss did not improve from 0.02703
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9975 - loss: 0.0098 - val_accuracy: 0.9910 - val_loss: 0.0284
# Epoch 304/700
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9976 - loss: 0.0096
# Epoch 304: val_loss did not improve from 0.02703
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9975 - loss: 0.0097 - val_accuracy: 0.9910 - val_loss: 0.0275
# Epoch 305/700
# 801/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9976 - loss: 0.0092
# Epoch 305: val_loss did not improve from 0.02703
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9974 - loss: 0.0096 - val_accuracy: 0.9906 - val_loss: 0.0271
# Epoch 306/700
# 807/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9979 - loss: 0.0090
# Epoch 306: val_loss did not improve from 0.02703
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9977 - loss: 0.0096 - val_accuracy: 0.9910 - val_loss: 0.0277
# Epoch 307/700
# 800/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9978 - loss: 0.0095
# Epoch 307: val_loss did not improve from 0.02703
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9976 - loss: 0.0097 - val_accuracy: 0.9910 - val_loss: 0.0276
# Epoch 308/700
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9979 - loss: 0.0092
# Epoch 308: val_loss did not improve from 0.02703
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9976 - loss: 0.0095 - val_accuracy: 0.9903 - val_loss: 0.0278
# Epoch 309/700
# 810/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9980 - loss: 0.0090
# Epoch 309: val_loss did not improve from 0.02703
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9977 - loss: 0.0096 - val_accuracy: 0.9910 - val_loss: 0.0281
# Epoch 310/700
# 812/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9976 - loss: 0.0090
# Epoch 310: val_loss did not improve from 0.02703
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9975 - loss: 0.0095 - val_accuracy: 0.9908 - val_loss: 0.0301
# Epoch 311/700
# 814/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9976 - loss: 0.0097
# Epoch 311: val_loss did not improve from 0.02703
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9977 - loss: 0.0094 - val_accuracy: 0.9906 - val_loss: 0.0305
# Epoch 312/700
# 817/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9979 - loss: 0.0086
# Epoch 312: val_loss did not improve from 0.02703
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9976 - loss: 0.0094 - val_accuracy: 0.9903 - val_loss: 0.0278
# Epoch 313/700
# 815/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9975 - loss: 0.0087
# Epoch 313: val_loss did not improve from 0.02703
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9977 - loss: 0.0093 - val_accuracy: 0.9909 - val_loss: 0.0276
# Epoch 314/700
# 819/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9977 - loss: 0.0092
# Epoch 314: val_loss did not improve from 0.02703
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9977 - loss: 0.0092 - val_accuracy: 0.9910 - val_loss: 0.0276
# Epoch 315/700
# 795/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9974 - loss: 0.0101
# Epoch 315: val_loss did not improve from 0.02703
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9976 - loss: 0.0094 - val_accuracy: 0.9914 - val_loss: 0.0285
# Epoch 316/700
# 796/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9979 - loss: 0.0088
# Epoch 316: val_loss did not improve from 0.02703
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9977 - loss: 0.0092 - val_accuracy: 0.9911 - val_loss: 0.0285
# Epoch 317/700
# 822/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9977 - loss: 0.0094
# Epoch 317: val_loss did not improve from 0.02703
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9978 - loss: 0.0090 - val_accuracy: 0.9909 - val_loss: 0.0275

# %%
test_results = model.evaluate(X_test, y_test, verbose=0)

for name, val in zip(model.metrics_names, test_results):
    print(f"{name}: {val:.4f}")
# Out:
# loss: 0.2878
# compile_metrics: 0.8921

# %%
import matplotlib.pyplot as plt

plt.plot(history.history["loss"], label="train")
plt.plot(history.history["val_loss"], label="val")
plt.legend()
plt.title("Loss")
plt.show()

# %%
# ===== EVALUASI MODEL (TEST SET) =====

import numpy as np
from sklearn.metrics import roc_curve, confusion_matrix, classification_report

# 1. Ambil probabilitas output model
y_prob = model.predict(X_test).ravel()

# 2. Hitung ROC curve
fpr, tpr, thresholds = roc_curve(y_test, y_prob)

# 3. Hitung Youden Index
youden_index = tpr - fpr
best_threshold = thresholds[np.argmax(youden_index)]

print("Best threshold (Youden):", best_threshold)

# 4. Prediksi final menggunakan threshold Youden
y_pred = (y_prob >= best_threshold).astype(int)

# 5. Evaluasi
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))

print("\nClassification Report:")
print(classification_report(y_test, y_pred, target_names=["Normal", "Attack"]))
# Out:
# 1546/1546 ━━━━━━━━━━━━━━━━━━━━ 1s 786us/step
# Best threshold (Youden): 0.70641494
# Confusion Matrix:
# [[25931  1444]
#  [ 3584 18513]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#       Normal       0.88      0.95      0.91     27375
#       Attack       0.93      0.84      0.88     22097
#
#     accuracy                           0.90     49472
#    macro avg       0.90      0.89      0.90     49472
# weighted avg       0.90      0.90      0.90     49472

# %%
y_pred = (y_prob >= best_threshold)

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred, target_names=["Normal","Attack"]))
# Out:
#               precision    recall  f1-score   support
#
#       Normal       0.88      0.95      0.91     27375
#       Attack       0.93      0.84      0.88     22097
#
#     accuracy                           0.90     49472
#    macro avg       0.90      0.89      0.90     49472
# weighted avg       0.90      0.90      0.90     49472

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import time
from sklearn.metrics import roc_curve, auc, confusion_matrix, classification_report

# 1. DEFINISI FUNGSI (Mesin Evaluasi)
def evaluate_iov_model(model, X_test, y_test):
    print("--- Memulai Proses Evaluasi ---")
    
    # Prediksi
    start_time = time.time()
    y_prob = model.predict(X_test).ravel()
    inference_time = (time.time() - start_time) / len(X_test)
    
    # Mencari Threshold Terbaik (Youden Index)
    fpr, tpr, thresholds = roc_curve(y_test, y_prob)
    youden_index = tpr - fpr
    best_threshold = thresholds[np.argmax(youden_index)]
    
    # Klasifikasi Berdasarkan Threshold
    y_pred = (y_prob >= best_threshold).astype(int)
    
    # Hitung Metrik
    cm = confusion_matrix(y_test, y_pred)
    tn, fp, fn, tp = cm.ravel()
    fpr_val = fp / (fp + tn)
    
    # VISUALISASI
    fig, ax = plt.subplots(1, 2, figsize=(15, 5))
    
    # Heatmap Confusion Matrix
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', ax=ax[0])
    ax[0].set_title('Confusion Matrix (Optimized Threshold)')
    ax[0].set_xlabel('Predicted')
    ax[0].set_ylabel('Actual')
    
    # ROC Curve
    ax[1].plot(fpr, tpr, label=f'AUC = {auc(fpr, tpr):.44f}')
    ax[1].plot([0, 1], [0, 1], 'k--')
    ax[1].set_title('ROC Curve')
    ax[1].legend()
    
    plt.show() # Ini akan memunculkan gambar
    
    # CETAK HASIL KE KONSOL
    print("\n" + "="*30)
    print(f"HASIL EVALUASI IDS (IoV)")
    print("="*30)
    print(f"Threshold Optimal : {best_threshold:.4f}")
    print(f"False Positive Rate: {fpr_val:.6f}")
    print(f"Inference Latency : {inference_time:.6f} s/sample")
    print("-" * 30)
    print(classification_report(y_test, y_pred, target_names=['Normal', 'Attack']))
    
    return best_threshold

# ==========================================
# 2. EKSEKUSI FUNGSI (Panggil di sini)
# ==========================================
# Ganti 'model_anda', 'X_test_anda', 'y_test_anda' 
# dengan nama variabel yang Anda miliki.

try:
    # Contoh: jika model Anda bernama 'global_model'
    best_thr = evaluate_iov_model(model, X_test, y_test)
except NameError as e:
    print(f"Error: {e}. Pastikan variabel model dan data Anda sudah didefinisikan sebelumnya.")
# Out:
# --- Memulai Proses Evaluasi ---
# 1546/1546 ━━━━━━━━━━━━━━━━━━━━ 1s 674us/step
# ==============================
# HASIL EVALUASI IDS (IoV)
# ==============================
# Threshold Optimal : 0.7064
# False Positive Rate: 0.052749
# Inference Latency : 0.000033 s/sample
# ------------------------------
#               precision    recall  f1-score   support
#
#       Normal       0.88      0.95      0.91     27375
#       Attack       0.93      0.84      0.88     22097
#
#     accuracy                           0.90     49472
#    macro avg       0.90      0.89      0.90     49472
# weighted avg       0.90      0.90      0.90     49472

# %%
from sklearn.metrics import confusion_matrix

# 1. Dapatkan prediksi dari model (berupa probabilitas)
y_prob = model.predict(X_test) 

# 2. Ubah probabilitas menjadi kelas (0 atau 1) 
# Gunakan threshold, misalnya 0.5 atau hasil Youden Index
y_pred = (y_prob > best_threshold).astype(int)

# 3. Munculkan Confusion Matrix
cm = confusion_matrix(y_test, y_pred)

# 4. Ekstrak TP, FP, TN, FN dari matriks
# Matriks sklearn memiliki format: [[TN, FP], [FN, TP]]
tn, fp, fn, tp = cm.ravel()

# 5. Cetak ke layar
print(f"--- Hasil Deteksi Serangan ---")
print(f"True Negatives (TN)  : {tn} (Trafik normal terdeteksi normal)")
print(f"False Positives (FP) : {fp} (ALARM PALSU - Normal dianggap serangan)")
print(f"False Negatives (FN) : {fn} (LOLOS - Serangan dianggap normal)")
print(f"True Positives (TP)  : {tp} (Berhasil mendeteksi serangan)")
# Out:
# 1546/1546 ━━━━━━━━━━━━━━━━━━━━ 1s 709us/step
# --- Hasil Deteksi Serangan ---
# True Negatives (TN)  : 25931 (Trafik normal terdeteksi normal)
# False Positives (FP) : 1444 (ALARM PALSU - Normal dianggap serangan)
# False Negatives (FN) : 3585 (LOLOS - Serangan dianggap normal)
# True Positives (TP)  : 18512 (Berhasil mendeteksi serangan)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Reds', 
            xticklabels=['Normal', 'Attack'], 
            yticklabels=['Normal', 'Attack'])
plt.title('Confusion Matrix: Deteksi Serangan IoV')
plt.ylabel('Kondisi Aktual')
plt.xlabel('Prediksi Model')
plt.show()

# %% [markdown]
# batas

# %%
import numpy as np

y_prob = model.predict(X_test).ravel()      # probabilitas Attack
y_pred = (y_prob > best_threshold).astype(int)         # label prediksi (threshold default)
# Out:
# 1546/1546 ━━━━━━━━━━━━━━━━━━━━ 1s 641us/step

# %%
# Fungsi: deteksi overfitting dan stabilitas training.
import matplotlib.pyplot as plt

plt.figure()
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training vs Validation Loss')
plt.legend()
plt.show()

plt.figure()
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training vs Validation Accuracy')
plt.legend()
plt.show()

# %%
# Fungsi: melihat False Negative (serangan lolos).
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

cm = confusion_matrix(y_test, y_pred)

disp = ConfusionMatrixDisplay(
    confusion_matrix=cm,
    display_labels=["Normal", "Attack"]
)
disp.plot()
plt.title("Confusion Matrix")
plt.show()
# 📌 Interpretasi IDS

# FN (Attack → Normal) harus minimal

# FP tinggi → false alarm

# %%
# Fungsi: menilai kualitas deteksi Attack.
from sklearn.metrics import precision_recall_fscore_support

precision, recall, f1, _ = precision_recall_fscore_support(
    y_test, y_pred, average=None
)

labels = ["Normal", "Attack"]

plt.figure()
plt.bar(labels, precision, label="Precision")
plt.bar(labels, recall, bottom=precision, label="Recall")
plt.ylabel("Score")
plt.title("Precision & Recall per Class")
plt.legend()
plt.show()
# Fokus laporan: Recall kelas Attack

# %%
# Fungsi: evaluasi threshold-independent.
from sklearn.metrics import roc_curve, auc

fpr, tpr, _ = roc_curve(y_test, y_prob)
roc_auc = auc(fpr, tpr)

plt.figure()
plt.plot(fpr, tpr, label=f"AUC = {roc_auc:.4f}")
plt.plot([0,1], [0,1], linestyle="--")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve")
plt.legend()
plt.show()

# AUC mendekati 1 → IDS sangat kuat

# %%
# Lebih relevan dari ROC untuk IDS.
from sklearn.metrics import precision_recall_curve

prec, rec, _ = precision_recall_curve(y_test, y_prob)

plt.figure()
plt.plot(rec, prec)
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title("Precision–Recall Curve")
plt.show()

# %%
from sklearn.metrics import f1_score
import matplotlib.pyplot as plt
import numpy as np

# ==========================================
# ASUMSI:
# - y_prob SUDAH dihitung di evaluate_iov_model
# - best_thr didapat dari return fungsi
# ==========================================

# Gunakan ulang y_prob & y_test (TIDAK buat baru)
y_pred = (y_prob >= best_thr).astype(int)

# Hitung F1-score untuk threshold yang SAMA
f1 = f1_score(y_test, y_pred)

print("\n" + "="*30)
print("F1-SCORE (FOLLOW YOUDEN THRESHOLD)")
print("="*30)
print(f"Threshold digunakan : {best_thr:.4f}")
print(f"F1-score           : {f1:.6f}")
# Out:
# ==============================
# F1-SCORE (FOLLOW YOUDEN THRESHOLD)
# ==============================
# Threshold digunakan : 0.7064
# F1-score           : 0.880439

# %%
plt.figure(figsize=(6,4))
plt.scatter(best_thr, f1, color='red', zorder=5)
plt.axvline(best_thr, linestyle='--', label=f"Threshold = {best_thr:.4f}")

plt.text(
    best_thr, f1,
    f"({best_thr:.4f}, {f1:.4f})",
    ha='left', va='bottom'
)

plt.xlabel("Threshold")
plt.ylabel("F1-score")
plt.title("F1-score at Optimized Youden Threshold")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Fungsi: lihat separasi Normal vs Attack.
plt.figure()
plt.hist(y_prob[y_test == 1], bins=50, alpha=0.7, label="Attack")
plt.hist(y_prob[y_test == 0], bins=50, alpha=0.7, label="Normal")
plt.xlabel("Predicted Probability (Attack)")
plt.ylabel("Frequency")
plt.title("Prediction Confidence Distribution")
plt.legend()
plt.show()
# 📌 Distribusi terpisah jelas → model robust.

# %%
from sklearn.metrics import classification_report

print(classification_report(
    y_test, y_pred,
    target_names=["Normal", "Attack"]
))
# Out:
#               precision    recall  f1-score   support
#
#       Normal       0.88      0.95      0.91     27375
#       Attack       0.93      0.84      0.88     22097
#
#     accuracy                           0.90     49472
#    macro avg       0.90      0.89      0.90     49472
# weighted avg       0.90      0.90      0.90     49472

# %%
import numpy as np
from sklearn.metrics import confusion_matrix

def compute_ids_metrics(y_true, y_pred):
    """
    Compute IDS metrics:
    Accuracy, Precision, Recall, F1, FPR, FNR
    """

    # Confusion Matrix
    tn, fp, fn, tp = confusion_matrix(y_true, y_pred).ravel()

    # Basic metrics
    acc = (tp + tn) / (tp + tn + fp + fn)

    precision = tp / (tp + fp) if (tp + fp) > 0 else 0.0
    recall    = tp / (tp + fn) if (tp + fn) > 0 else 0.0

    f1 = (2 * precision * recall) / (precision + recall) if (precision + recall) > 0 else 0.0

    # IDS-specific metrics
    fpr = fp / (fp + tn) if (fp + tn) > 0 else 0.0
    fnr = fn / (fn + tp) if (fn + tp) > 0 else 0.0

    return {
        "TP": tp,
        "FP": fp,
        "TN": tn,
        "FN": fn,
        "Accuracy": acc,
        "Precision": precision,
        "Recall": recall,
        "F1-score": f1,
        "FPR": fpr,
        "FNR": fnr,
    }

# %%
# Hitung metrik IDS
metrics = compute_ids_metrics(y_test, y_pred)

for k, v in metrics.items():
    print(f"{k:10s}: {v:.6f}" if isinstance(v, float) else f"{k:10s}: {v}")
# Out:
# TP        : 18513
# FP        : 1444
# TN        : 25931
# FN        : 3584
# Accuracy  : 0.898367
# Precision : 0.927644
# Recall    : 0.837806
# F1-score  : 0.880439
# FPR       : 0.052749
# FNR       : 0.162194

# %% [markdown]
# TP        : 18106
# FP        : 1457
# TN        : 25918
# FN        : 3991
# Accuracy  : 0.889877
# F1-score  : 0.869227
# FPR       : 0.053224
# FNR       : 0.180613

# %% [markdown]
# TP        : 18513
# FP        : 1444
# TN        : 25931
# FN        : 3584
# Accuracy  : 0.898367
# Precision : 0.927644
# Recall    : 0.837806
# F1-score  : 0.880439
# FPR       : 0.052749
# FNR       : 0.162194
