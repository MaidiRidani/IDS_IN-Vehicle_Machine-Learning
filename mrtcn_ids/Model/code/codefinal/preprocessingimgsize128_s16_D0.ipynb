# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import (
    Input, Conv1D, BatchNormalization,
    ReLU, Add, GlobalAveragePooling1D, Dense
)
from tensorflow.keras.models import Model
# Out:
# 2026-04-08 22:20:22.602140: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-04-08 22:20:22.612981: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1775661622.625449  247453 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1775661622.629239  247453 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1775661622.638966  247453 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1775661622.638982  247453 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1775661622.638983  247453 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1775661622.638984  247453 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-04-08 22:20:22.642522: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
pathload = "/home/dani/Documents/tugas akhir/TugasAkhirku2026/mrtcn_ids/Preprocessing/hasil/final/preprocessingimgsize128_s16/preprocessingimgsize128_s16.npz"
data = np.load(
    pathload,
    mmap_mode="r"   # penting: tidak load penuh ke RAM
)

print(data.files)
# Out:
# ['x_train', 'y_train', 'x_val', 'y_val', 'x_test', 'y_test']

# %%
data = np.load(
    pathload,
)

X_train = data["x_train"]
y_train = data["y_train"]
X_val   = data["x_val"]
y_val   = data["y_val"]
X_test  = data["x_test"]
y_test  = data["y_test"]

print(X_train.shape, y_train.shape)
print(X_val.shape, y_val.shape)
print(X_test.shape, y_test.shape)
# Out:
# (26329, 128, 128) (26329,)
# (11284, 128, 128) (11284,)
# (24734, 128, 128) (24734,)

# %%
np.unique(y_train, return_counts=True)
# Out:
# (array([0, 1]), array([11283, 15046]))

# %%
import numpy as np

# Fungsi untuk cek balance
def check_balance_binary(y):
    n_normal = np.sum(y == 0)
    n_attack = np.sum(y == 1)
    total = len(y)
    print(f"Total samples: {total}")
    print(f"Normal: {n_normal} ({n_normal/total*100:.2f}%)")
    print(f"Attack: {n_attack} ({n_attack/total*100:.2f}%)\n")

# Cek balance di masing-masing split
print("=== Train Set ===")
check_balance_binary(y_train)

print("=== Validation Set ===")
check_balance_binary(y_val)

print("=== Test Set ===")
check_balance_binary(y_test)
# Out:
# === Train Set ===
# Total samples: 26329
# Normal: 11283 (42.85%)
# Attack: 15046 (57.15%)
#
# === Validation Set ===
# Total samples: 11284
# Normal: 4835 (42.85%)
# Attack: 6449 (57.15%)
#
# === Test Set ===
# Total samples: 24734
# Normal: 13167 (53.23%)
# Attack: 11567 (46.77%)

# %%
def tcn_block(x, filters, kernel_size, dilation):
    shortcut = x

    x = Conv1D(filters, kernel_size,
               padding="causal",
               dilation_rate=dilation)(x)
    x = BatchNormalization()(x)
    x = ReLU()(x)

    x = Conv1D(filters, kernel_size,
               padding="causal",
               dilation_rate=dilation)(x)
    x = BatchNormalization()(x)

    if shortcut.shape[-1] != filters:
        shortcut = Conv1D(filters, 1, padding="same")(shortcut)

    x = Add()([x, shortcut])
    x = ReLU()(x)
    return x

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, Dropout, MaxPooling1D, Flatten, Dense

def build_mr_tcn(input_shape=(128, 128), dropout_rate=0.00):
    model = Sequential()

    # Conv1D #1
    model.add(Conv1D(
        filters=64,
        kernel_size=3,
        strides=1,
        dilation_rate=1,
        padding="same",
        activation="relu",
        input_shape=input_shape
    ))
    model.add(Dropout(dropout_rate))

    # Conv1D #2
    model.add(Conv1D(
        filters=64,
        kernel_size=3,
        strides=1,
        dilation_rate=2,
        padding="same",
        activation="relu"
    ))
    model.add(Dropout(dropout_rate))

    # Conv1D #3
    model.add(Conv1D(
        filters=64,
        kernel_size=3,
        strides=1,
        dilation_rate=4,
        padding="same",
        activation="relu"
    ))
    model.add(Dropout(dropout_rate))

    # MaxPooling
    model.add(MaxPooling1D(pool_size=8, strides=8))

    # Flatten
    model.add(Flatten())

    # Dropout
    model.add(Dropout(dropout_rate))

    # Linear → Sigmoid
    model.add(Dense(1, activation="sigmoid"))

    return model

# %%
model = build_mr_tcn()

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-5),
    loss="binary_crossentropy",
    metrics=["accuracy"]
)

model.summary()
# Out:
# /home/dani/miniconda3/envs/latihan1/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# I0000 00:00:1775661630.800183  247453 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 4144 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d (Conv1D)                 │ (None, 128, 64)        │        24,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128, 64)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_1 (Conv1D)               │ (None, 128, 64)        │        12,352 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128, 64)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_2 (Conv1D)               │ (None, 128, 64)        │        12,352 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 128, 64)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d (MaxPooling1D)    │ (None, 16, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │         1,025 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 50,369 (196.75 KB)
#  Trainable params: 50,369 (196.75 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
#  Total params: 50,369 (196.75 KB)

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

early_stop = EarlyStopping(
    monitor="val_loss",
    patience=30,
    restore_best_weights=True
)

checkpoint = ModelCheckpoint(
    "best_mr_tcn.keras",
    monitor="val_loss",
    save_best_only=True,
    verbose=1
)

# %%
history = model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=700,
    batch_size=16,
    callbacks=[early_stop, checkpoint]
)
# Out:
# Epoch 1/700
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1775661633.267283  247763 service.cc:152] XLA service 0x7781e800b550 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1775661633.267301  247763 service.cc:160]   StreamExecutor device (0): NVIDIA GeForce RTX 3060 Laptop GPU, Compute Capability 8.6
# 2026-04-08 22:20:33.286978: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1775661633.422970  247763 cuda_dnn.cc:529] Loaded cuDNN version 91701
# 2026-04-08 22:20:33.750396: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:310] Allocator (GPU_0_bfc) ran out of memory trying to allocate 4.05GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
#   92/1646 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.4615 - loss: 0.7017
# I0000 00:00:1775661634.470677  247763 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5703 - loss: 0.6736
# Epoch 1: val_loss improved from None to 0.61094, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 7s 3ms/step - accuracy: 0.6144 - loss: 0.6538 - val_accuracy: 0.6671 - val_loss: 0.6109
# Epoch 2/700
# 1620/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7635 - loss: 0.5810
# Epoch 2: val_loss improved from 0.61094 to 0.45895, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8140 - loss: 0.5411 - val_accuracy: 0.8691 - val_loss: 0.4590
# Epoch 3/700
# 1617/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8899 - loss: 0.4176
# Epoch 3: val_loss improved from 0.45895 to 0.31103, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9007 - loss: 0.3798 - val_accuracy: 0.9166 - val_loss: 0.3110
# Epoch 4/700
# 1641/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9189 - loss: 0.2898
# Epoch 4: val_loss improved from 0.31103 to 0.23973, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9216 - loss: 0.2703 - val_accuracy: 0.9246 - val_loss: 0.2397
# Epoch 5/700
# 1618/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9267 - loss: 0.2289
# Epoch 5: val_loss improved from 0.23973 to 0.20777, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9278 - loss: 0.2214 - val_accuracy: 0.9295 - val_loss: 0.2078
# Epoch 6/700
# 1628/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9298 - loss: 0.2036
# Epoch 6: val_loss improved from 0.20777 to 0.18884, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9325 - loss: 0.1959 - val_accuracy: 0.9334 - val_loss: 0.1888
# Epoch 7/700
# 1641/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9336 - loss: 0.1832
# Epoch 7: val_loss improved from 0.18884 to 0.17406, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9361 - loss: 0.1789 - val_accuracy: 0.9379 - val_loss: 0.1741
# Epoch 8/700
# 1627/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9392 - loss: 0.1693
# Epoch 8: val_loss improved from 0.17406 to 0.16366, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9405 - loss: 0.1658 - val_accuracy: 0.9427 - val_loss: 0.1637
# Epoch 9/700
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9452 - loss: 0.1551
# Epoch 9: val_loss improved from 0.16366 to 0.15659, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9433 - loss: 0.1559 - val_accuracy: 0.9452 - val_loss: 0.1566
# Epoch 10/700
# 1616/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9477 - loss: 0.1446
# Epoch 10: val_loss improved from 0.15659 to 0.14755, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9462 - loss: 0.1473 - val_accuracy: 0.9487 - val_loss: 0.1475
# Epoch 11/700
# 1613/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9446 - loss: 0.1489
# Epoch 11: val_loss improved from 0.14755 to 0.14151, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9489 - loss: 0.1400 - val_accuracy: 0.9494 - val_loss: 0.1415
# Epoch 12/700
# 1625/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9504 - loss: 0.1388
# Epoch 12: val_loss improved from 0.14151 to 0.13756, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9519 - loss: 0.1341 - val_accuracy: 0.9525 - val_loss: 0.1376
# Epoch 13/700
# 1622/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9527 - loss: 0.1298
# Epoch 13: val_loss improved from 0.13756 to 0.13188, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9539 - loss: 0.1284 - val_accuracy: 0.9534 - val_loss: 0.1319
# Epoch 14/700
# 1645/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9562 - loss: 0.1208
# Epoch 14: val_loss improved from 0.13188 to 0.12827, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9556 - loss: 0.1234 - val_accuracy: 0.9533 - val_loss: 0.1283
# Epoch 15/700
# 1614/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9570 - loss: 0.1193
# Epoch 15: val_loss improved from 0.12827 to 0.12378, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9568 - loss: 0.1187 - val_accuracy: 0.9563 - val_loss: 0.1238
# Epoch 16/700
# 1645/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9585 - loss: 0.1143
# Epoch 16: val_loss improved from 0.12378 to 0.12004, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9581 - loss: 0.1148 - val_accuracy: 0.9589 - val_loss: 0.1200
# Epoch 17/700
# 1618/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9580 - loss: 0.1158
# Epoch 17: val_loss improved from 0.12004 to 0.11667, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9599 - loss: 0.1112 - val_accuracy: 0.9591 - val_loss: 0.1167
# Epoch 18/700
# 1622/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9613 - loss: 0.1068
# Epoch 18: val_loss improved from 0.11667 to 0.11499, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9606 - loss: 0.1074 - val_accuracy: 0.9596 - val_loss: 0.1150
# Epoch 19/700
# 1628/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9626 - loss: 0.1037
# Epoch 19: val_loss improved from 0.11499 to 0.11108, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9616 - loss: 0.1040 - val_accuracy: 0.9619 - val_loss: 0.1111
# Epoch 20/700
# 1635/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9643 - loss: 0.0978
# Epoch 20: val_loss did not improve from 0.11108
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9632 - loss: 0.1007 - val_accuracy: 0.9630 - val_loss: 0.1113
# Epoch 21/700
# 1611/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9633 - loss: 0.1016
# Epoch 21: val_loss improved from 0.11108 to 0.10663, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9647 - loss: 0.0979 - val_accuracy: 0.9628 - val_loss: 0.1066
# Epoch 22/700
# 1627/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9673 - loss: 0.0915
# Epoch 22: val_loss improved from 0.10663 to 0.10362, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9660 - loss: 0.0951 - val_accuracy: 0.9641 - val_loss: 0.1036
# Epoch 23/700
# 1625/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9653 - loss: 0.0945
# Epoch 23: val_loss improved from 0.10362 to 0.10166, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9674 - loss: 0.0922 - val_accuracy: 0.9642 - val_loss: 0.1017
# Epoch 24/700
# 1628/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9676 - loss: 0.0884
# Epoch 24: val_loss improved from 0.10166 to 0.09987, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9673 - loss: 0.0897 - val_accuracy: 0.9666 - val_loss: 0.0999
# Epoch 25/700
# 1623/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9679 - loss: 0.0892
# Epoch 25: val_loss improved from 0.09987 to 0.09831, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9688 - loss: 0.0874 - val_accuracy: 0.9674 - val_loss: 0.0983
# Epoch 26/700
# 1633/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9693 - loss: 0.0873
# Epoch 26: val_loss improved from 0.09831 to 0.09568, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9703 - loss: 0.0850 - val_accuracy: 0.9677 - val_loss: 0.0957
# Epoch 27/700
# 1624/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9685 - loss: 0.0854
# Epoch 27: val_loss improved from 0.09568 to 0.09403, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9699 - loss: 0.0828 - val_accuracy: 0.9686 - val_loss: 0.0940
# Epoch 28/700
# 1616/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9707 - loss: 0.0810
# Epoch 28: val_loss improved from 0.09403 to 0.09234, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9714 - loss: 0.0806 - val_accuracy: 0.9672 - val_loss: 0.0923
# Epoch 29/700
# 1619/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9725 - loss: 0.0788
# Epoch 29: val_loss improved from 0.09234 to 0.09059, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9725 - loss: 0.0786 - val_accuracy: 0.9685 - val_loss: 0.0906
# Epoch 30/700
# 1639/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9735 - loss: 0.0769
# Epoch 30: val_loss improved from 0.09059 to 0.08885, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9730 - loss: 0.0764 - val_accuracy: 0.9703 - val_loss: 0.0889
# Epoch 31/700
# 1637/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9731 - loss: 0.0751
# Epoch 31: val_loss improved from 0.08885 to 0.08684, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9741 - loss: 0.0748 - val_accuracy: 0.9696 - val_loss: 0.0868
# Epoch 32/700
# 1629/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9756 - loss: 0.0705
# Epoch 32: val_loss improved from 0.08684 to 0.08652, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9748 - loss: 0.0729 - val_accuracy: 0.9708 - val_loss: 0.0865
# Epoch 33/700
# 1611/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9749 - loss: 0.0727
# Epoch 33: val_loss improved from 0.08652 to 0.08442, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9754 - loss: 0.0714 - val_accuracy: 0.9703 - val_loss: 0.0844
# Epoch 34/700
# 1630/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9750 - loss: 0.0721
# Epoch 34: val_loss improved from 0.08442 to 0.08295, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9759 - loss: 0.0694 - val_accuracy: 0.9714 - val_loss: 0.0830
# Epoch 35/700
# 1621/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9761 - loss: 0.0678
# Epoch 35: val_loss improved from 0.08295 to 0.08224, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9767 - loss: 0.0676 - val_accuracy: 0.9704 - val_loss: 0.0822
# Epoch 36/700
# 1620/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9777 - loss: 0.0660
# Epoch 36: val_loss improved from 0.08224 to 0.08219, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9777 - loss: 0.0661 - val_accuracy: 0.9725 - val_loss: 0.0822
# Epoch 37/700
# 1636/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9794 - loss: 0.0637
# Epoch 37: val_loss improved from 0.08219 to 0.07945, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9781 - loss: 0.0650 - val_accuracy: 0.9719 - val_loss: 0.0794
# Epoch 38/700
# 1621/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9767 - loss: 0.0631
# Epoch 38: val_loss improved from 0.07945 to 0.07816, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9779 - loss: 0.0632 - val_accuracy: 0.9735 - val_loss: 0.0782
# Epoch 39/700
# 1615/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9773 - loss: 0.0662
# Epoch 39: val_loss improved from 0.07816 to 0.07768, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9790 - loss: 0.0619 - val_accuracy: 0.9728 - val_loss: 0.0777
# Epoch 40/700
# 1629/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9806 - loss: 0.0588
# Epoch 40: val_loss improved from 0.07768 to 0.07636, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9797 - loss: 0.0605 - val_accuracy: 0.9753 - val_loss: 0.0764
# Epoch 41/700
# 1645/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9809 - loss: 0.0570
# Epoch 41: val_loss did not improve from 0.07636
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9799 - loss: 0.0593 - val_accuracy: 0.9744 - val_loss: 0.0773
# Epoch 42/700
# 1636/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9801 - loss: 0.0592
# Epoch 42: val_loss improved from 0.07636 to 0.07464, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9804 - loss: 0.0580 - val_accuracy: 0.9739 - val_loss: 0.0746
# Epoch 43/700
# 1625/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9816 - loss: 0.0566
# Epoch 43: val_loss improved from 0.07464 to 0.07374, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9814 - loss: 0.0567 - val_accuracy: 0.9741 - val_loss: 0.0737
# Epoch 44/700
# 1622/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9799 - loss: 0.0591
# Epoch 44: val_loss improved from 0.07374 to 0.07233, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9809 - loss: 0.0554 - val_accuracy: 0.9754 - val_loss: 0.0723
# Epoch 45/700
# 1627/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9810 - loss: 0.0551
# Epoch 45: val_loss did not improve from 0.07233
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9820 - loss: 0.0542 - val_accuracy: 0.9764 - val_loss: 0.0731
# Epoch 46/700
# 1645/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9823 - loss: 0.0521
# Epoch 46: val_loss did not improve from 0.07233
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9817 - loss: 0.0531 - val_accuracy: 0.9765 - val_loss: 0.0732
# Epoch 47/700
# 1642/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9837 - loss: 0.0505
# Epoch 47: val_loss improved from 0.07233 to 0.06993, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9827 - loss: 0.0519 - val_accuracy: 0.9761 - val_loss: 0.0699
# Epoch 48/700
# 1630/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9820 - loss: 0.0519
# Epoch 48: val_loss did not improve from 0.06993
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9831 - loss: 0.0511 - val_accuracy: 0.9755 - val_loss: 0.0701
# Epoch 49/700
# 1631/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9836 - loss: 0.0521
# Epoch 49: val_loss did not improve from 0.06993
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9837 - loss: 0.0500 - val_accuracy: 0.9765 - val_loss: 0.0717
# Epoch 50/700
# 1632/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9839 - loss: 0.0498
# Epoch 50: val_loss did not improve from 0.06993
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9838 - loss: 0.0489 - val_accuracy: 0.9737 - val_loss: 0.0735
# Epoch 51/700
# 1631/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9846 - loss: 0.0479
# Epoch 51: val_loss improved from 0.06993 to 0.06700, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9846 - loss: 0.0479 - val_accuracy: 0.9770 - val_loss: 0.0670
# Epoch 52/700
# 1628/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9857 - loss: 0.0467
# Epoch 52: val_loss improved from 0.06700 to 0.06643, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9850 - loss: 0.0472 - val_accuracy: 0.9775 - val_loss: 0.0664
# Epoch 53/700
# 1615/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9865 - loss: 0.0463
# Epoch 53: val_loss did not improve from 0.06643
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9853 - loss: 0.0463 - val_accuracy: 0.9782 - val_loss: 0.0673
# Epoch 54/700
# 1636/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9856 - loss: 0.0454
# Epoch 54: val_loss improved from 0.06643 to 0.06513, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9854 - loss: 0.0453 - val_accuracy: 0.9781 - val_loss: 0.0651
# Epoch 55/700
# 1645/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9858 - loss: 0.0433
# Epoch 55: val_loss improved from 0.06513 to 0.06469, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9856 - loss: 0.0444 - val_accuracy: 0.9788 - val_loss: 0.0647
# Epoch 56/700
# 1616/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9853 - loss: 0.0432
# Epoch 56: val_loss improved from 0.06469 to 0.06379, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9858 - loss: 0.0437 - val_accuracy: 0.9789 - val_loss: 0.0638
# Epoch 57/700
# 1615/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9873 - loss: 0.0405
# Epoch 57: val_loss improved from 0.06379 to 0.06338, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9861 - loss: 0.0430 - val_accuracy: 0.9787 - val_loss: 0.0634
# Epoch 58/700
# 1627/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9867 - loss: 0.0426
# Epoch 58: val_loss did not improve from 0.06338
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9868 - loss: 0.0418 - val_accuracy: 0.9783 - val_loss: 0.0643
# Epoch 59/700
# 1623/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9881 - loss: 0.0388
# Epoch 59: val_loss did not improve from 0.06338
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9869 - loss: 0.0414 - val_accuracy: 0.9785 - val_loss: 0.0642
# Epoch 60/700
# 1639/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9864 - loss: 0.0413
# Epoch 60: val_loss improved from 0.06338 to 0.06301, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9871 - loss: 0.0405 - val_accuracy: 0.9786 - val_loss: 0.0630
# Epoch 61/700
# 1632/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9869 - loss: 0.0404
# Epoch 61: val_loss improved from 0.06301 to 0.06177, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9876 - loss: 0.0396 - val_accuracy: 0.9796 - val_loss: 0.0618
# Epoch 62/700
# 1641/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9873 - loss: 0.0389
# Epoch 62: val_loss did not improve from 0.06177
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9876 - loss: 0.0394 - val_accuracy: 0.9797 - val_loss: 0.0618
# Epoch 63/700
# 1633/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9877 - loss: 0.0385
# Epoch 63: val_loss improved from 0.06177 to 0.06053, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9878 - loss: 0.0383 - val_accuracy: 0.9796 - val_loss: 0.0605
# Epoch 64/700
# 1630/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9881 - loss: 0.0387
# Epoch 64: val_loss improved from 0.06053 to 0.06003, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9882 - loss: 0.0378 - val_accuracy: 0.9797 - val_loss: 0.0600
# Epoch 65/700
# 1617/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9897 - loss: 0.0367
# Epoch 65: val_loss improved from 0.06003 to 0.05953, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9893 - loss: 0.0369 - val_accuracy: 0.9798 - val_loss: 0.0595
# Epoch 66/700
# 1633/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9888 - loss: 0.0363
# Epoch 66: val_loss did not improve from 0.05953
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9887 - loss: 0.0366 - val_accuracy: 0.9804 - val_loss: 0.0598
# Epoch 67/700
# 1630/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9894 - loss: 0.0348
# Epoch 67: val_loss improved from 0.05953 to 0.05879, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9893 - loss: 0.0358 - val_accuracy: 0.9805 - val_loss: 0.0588
# Epoch 68/700
# 1616/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9893 - loss: 0.0348
# Epoch 68: val_loss did not improve from 0.05879
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9891 - loss: 0.0348 - val_accuracy: 0.9795 - val_loss: 0.0629
# Epoch 69/700
# 1644/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9886 - loss: 0.0354
# Epoch 69: val_loss did not improve from 0.05879
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9893 - loss: 0.0343 - val_accuracy: 0.9794 - val_loss: 0.0630
# Epoch 70/700
# 1626/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9883 - loss: 0.0356
# Epoch 70: val_loss improved from 0.05879 to 0.05840, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9899 - loss: 0.0337 - val_accuracy: 0.9807 - val_loss: 0.0584
# Epoch 71/700
# 1632/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9908 - loss: 0.0317
# Epoch 71: val_loss improved from 0.05840 to 0.05784, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9897 - loss: 0.0332 - val_accuracy: 0.9809 - val_loss: 0.0578
# Epoch 72/700
# 1624/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9875 - loss: 0.0360
# Epoch 72: val_loss improved from 0.05784 to 0.05758, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9900 - loss: 0.0326 - val_accuracy: 0.9808 - val_loss: 0.0576
# Epoch 73/700
# 1642/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9906 - loss: 0.0314
# Epoch 73: val_loss improved from 0.05758 to 0.05695, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9902 - loss: 0.0320 - val_accuracy: 0.9809 - val_loss: 0.0570
# Epoch 74/700
# 1614/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9895 - loss: 0.0323
# Epoch 74: val_loss did not improve from 0.05695
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9901 - loss: 0.0316 - val_accuracy: 0.9809 - val_loss: 0.0580
# Epoch 75/700
# 1628/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9911 - loss: 0.0300
# Epoch 75: val_loss did not improve from 0.05695
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9910 - loss: 0.0309 - val_accuracy: 0.9809 - val_loss: 0.0582
# Epoch 76/700
# 1623/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9912 - loss: 0.0287
# Epoch 76: val_loss improved from 0.05695 to 0.05598, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9905 - loss: 0.0305 - val_accuracy: 0.9814 - val_loss: 0.0560
# Epoch 77/700
# 1631/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9903 - loss: 0.0321
# Epoch 77: val_loss did not improve from 0.05598
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9910 - loss: 0.0298 - val_accuracy: 0.9814 - val_loss: 0.0560
# Epoch 78/700
# 1631/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9910 - loss: 0.0298
# Epoch 78: val_loss improved from 0.05598 to 0.05572, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9906 - loss: 0.0296 - val_accuracy: 0.9814 - val_loss: 0.0557
# Epoch 79/700
# 1621/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9917 - loss: 0.0272
# Epoch 79: val_loss did not improve from 0.05572
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9912 - loss: 0.0288 - val_accuracy: 0.9815 - val_loss: 0.0565
# Epoch 80/700
# 1635/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9915 - loss: 0.0281
# Epoch 80: val_loss did not improve from 0.05572
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9918 - loss: 0.0283 - val_accuracy: 0.9818 - val_loss: 0.0559
# Epoch 81/700
# 1616/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9914 - loss: 0.0274
# Epoch 81: val_loss improved from 0.05572 to 0.05557, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9916 - loss: 0.0280 - val_accuracy: 0.9814 - val_loss: 0.0556
# Epoch 82/700
# 1611/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9918 - loss: 0.0274
# Epoch 82: val_loss improved from 0.05557 to 0.05496, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9916 - loss: 0.0274 - val_accuracy: 0.9816 - val_loss: 0.0550
# Epoch 83/700
# 1643/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9909 - loss: 0.0277
# Epoch 83: val_loss did not improve from 0.05496
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9919 - loss: 0.0268 - val_accuracy: 0.9817 - val_loss: 0.0553
# Epoch 84/700
# 1625/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9922 - loss: 0.0269
# Epoch 84: val_loss did not improve from 0.05496
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9923 - loss: 0.0263 - val_accuracy: 0.9818 - val_loss: 0.0554
# Epoch 85/700
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9914 - loss: 0.0276
# Epoch 85: val_loss did not improve from 0.05496
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9923 - loss: 0.0260 - val_accuracy: 0.9812 - val_loss: 0.0567
# Epoch 86/700
# 1619/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9917 - loss: 0.0258
# Epoch 86: val_loss improved from 0.05496 to 0.05394, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9924 - loss: 0.0255 - val_accuracy: 0.9825 - val_loss: 0.0539
# Epoch 87/700
# 1636/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9931 - loss: 0.0249
# Epoch 87: val_loss did not improve from 0.05394
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9930 - loss: 0.0250 - val_accuracy: 0.9825 - val_loss: 0.0543
# Epoch 88/700
# 1618/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9920 - loss: 0.0256
# Epoch 88: val_loss improved from 0.05394 to 0.05371, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9924 - loss: 0.0244 - val_accuracy: 0.9824 - val_loss: 0.0537
# Epoch 89/700
# 1630/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9941 - loss: 0.0224
# Epoch 89: val_loss improved from 0.05371 to 0.05335, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9928 - loss: 0.0241 - val_accuracy: 0.9823 - val_loss: 0.0534
# Epoch 90/700
# 1620/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9939 - loss: 0.0233
# Epoch 90: val_loss did not improve from 0.05335
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9930 - loss: 0.0235 - val_accuracy: 0.9826 - val_loss: 0.0551
# Epoch 91/700
# 1624/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9936 - loss: 0.0221
# Epoch 91: val_loss did not improve from 0.05335
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9932 - loss: 0.0233 - val_accuracy: 0.9826 - val_loss: 0.0534
# Epoch 92/700
# 1624/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9928 - loss: 0.0252
# Epoch 92: val_loss did not improve from 0.05335
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9934 - loss: 0.0228 - val_accuracy: 0.9824 - val_loss: 0.0536
# Epoch 93/700
# 1643/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9933 - loss: 0.0224
# Epoch 93: val_loss did not improve from 0.05335
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9936 - loss: 0.0224 - val_accuracy: 0.9825 - val_loss: 0.0555
# Epoch 94/700
# 1618/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9948 - loss: 0.0213
# Epoch 94: val_loss did not improve from 0.05335
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9940 - loss: 0.0219 - val_accuracy: 0.9825 - val_loss: 0.0567
# Epoch 95/700
# 1616/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9944 - loss: 0.0203
# Epoch 95: val_loss improved from 0.05335 to 0.05284, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9940 - loss: 0.0215 - val_accuracy: 0.9827 - val_loss: 0.0528
# Epoch 96/700
# 1641/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9945 - loss: 0.0208
# Epoch 96: val_loss did not improve from 0.05284
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9943 - loss: 0.0210 - val_accuracy: 0.9829 - val_loss: 0.0535
# Epoch 97/700
# 1635/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9934 - loss: 0.0238
# Epoch 97: val_loss did not improve from 0.05284
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9943 - loss: 0.0208 - val_accuracy: 0.9833 - val_loss: 0.0533
# Epoch 98/700
# 1627/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9941 - loss: 0.0199
# Epoch 98: val_loss did not improve from 0.05284
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9942 - loss: 0.0203 - val_accuracy: 0.9831 - val_loss: 0.0531
# Epoch 99/700
# 1623/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9939 - loss: 0.0213
# Epoch 99: val_loss improved from 0.05284 to 0.05210, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9942 - loss: 0.0202 - val_accuracy: 0.9833 - val_loss: 0.0521
# Epoch 100/700
# 1643/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9952 - loss: 0.0197
# Epoch 100: val_loss did not improve from 0.05210
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9948 - loss: 0.0196 - val_accuracy: 0.9823 - val_loss: 0.0540
# Epoch 101/700
# 1638/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9949 - loss: 0.0192
# Epoch 101: val_loss did not improve from 0.05210
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9946 - loss: 0.0194 - val_accuracy: 0.9837 - val_loss: 0.0547
# Epoch 102/700
# 1614/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9944 - loss: 0.0189
# Epoch 102: val_loss did not improve from 0.05210
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9947 - loss: 0.0189 - val_accuracy: 0.9833 - val_loss: 0.0521
# Epoch 103/700
# 1639/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9954 - loss: 0.0190
# Epoch 103: val_loss did not improve from 0.05210
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9949 - loss: 0.0186 - val_accuracy: 0.9835 - val_loss: 0.0525
# Epoch 104/700
# 1620/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9955 - loss: 0.0166
# Epoch 104: val_loss did not improve from 0.05210
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9950 - loss: 0.0181 - val_accuracy: 0.9836 - val_loss: 0.0532
# Epoch 105/700
# 1618/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9957 - loss: 0.0179
# Epoch 105: val_loss did not improve from 0.05210
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9957 - loss: 0.0179 - val_accuracy: 0.9838 - val_loss: 0.0521
# Epoch 106/700
# 1635/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9942 - loss: 0.0192
# Epoch 106: val_loss did not improve from 0.05210
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9953 - loss: 0.0175 - val_accuracy: 0.9836 - val_loss: 0.0543
# Epoch 107/700
# 1618/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9957 - loss: 0.0171
# Epoch 107: val_loss did not improve from 0.05210
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9956 - loss: 0.0172 - val_accuracy: 0.9831 - val_loss: 0.0528
# Epoch 108/700
# 1626/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9962 - loss: 0.0158
# Epoch 108: val_loss did not improve from 0.05210
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9954 - loss: 0.0172 - val_accuracy: 0.9834 - val_loss: 0.0526
# Epoch 109/700
# 1640/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9958 - loss: 0.0152
# Epoch 109: val_loss did not improve from 0.05210
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9957 - loss: 0.0163 - val_accuracy: 0.9828 - val_loss: 0.0523
# Epoch 110/700
# 1638/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9964 - loss: 0.0153
# Epoch 110: val_loss did not improve from 0.05210
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9958 - loss: 0.0161 - val_accuracy: 0.9837 - val_loss: 0.0555
# Epoch 111/700
# 1637/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9958 - loss: 0.0161
# Epoch 111: val_loss did not improve from 0.05210
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9959 - loss: 0.0159 - val_accuracy: 0.9834 - val_loss: 0.0526
# Epoch 112/700
# 1637/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9966 - loss: 0.0150
# Epoch 112: val_loss did not improve from 0.05210
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9962 - loss: 0.0155 - val_accuracy: 0.9819 - val_loss: 0.0556
# Epoch 113/700
# 1631/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9968 - loss: 0.0153
# Epoch 113: val_loss did not improve from 0.05210
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9962 - loss: 0.0153 - val_accuracy: 0.9833 - val_loss: 0.0524
# Epoch 114/700
# 1620/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9964 - loss: 0.0138
# Epoch 114: val_loss did not improve from 0.05210
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9961 - loss: 0.0151 - val_accuracy: 0.9833 - val_loss: 0.0557
# Epoch 115/700
# 1639/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9970 - loss: 0.0138
# Epoch 115: val_loss did not improve from 0.05210
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9967 - loss: 0.0146 - val_accuracy: 0.9837 - val_loss: 0.0537
# Epoch 116/700
# 1632/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9969 - loss: 0.0142
# Epoch 116: val_loss did not improve from 0.05210
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9970 - loss: 0.0142 - val_accuracy: 0.9840 - val_loss: 0.0524
# Epoch 117/700
# 1620/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9972 - loss: 0.0128
# Epoch 117: val_loss did not improve from 0.05210
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9967 - loss: 0.0142 - val_accuracy: 0.9833 - val_loss: 0.0527
# Epoch 118/700
# 1623/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9974 - loss: 0.0135
# Epoch 118: val_loss did not improve from 0.05210
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9966 - loss: 0.0138 - val_accuracy: 0.9833 - val_loss: 0.0566
# Epoch 119/700
# 1618/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9968 - loss: 0.0134
# Epoch 119: val_loss improved from 0.05210 to 0.05197, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9971 - loss: 0.0134 - val_accuracy: 0.9835 - val_loss: 0.0520
# Epoch 120/700
# 1629/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9971 - loss: 0.0133
# Epoch 120: val_loss did not improve from 0.05197
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9970 - loss: 0.0130 - val_accuracy: 0.9841 - val_loss: 0.0536
# Epoch 121/700
# 1626/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9978 - loss: 0.0124
# Epoch 121: val_loss did not improve from 0.05197
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9975 - loss: 0.0129 - val_accuracy: 0.9840 - val_loss: 0.0530
# Epoch 122/700
# 1635/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9969 - loss: 0.0137
# Epoch 122: val_loss did not improve from 0.05197
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9973 - loss: 0.0126 - val_accuracy: 0.9840 - val_loss: 0.0527
# Epoch 123/700
# 1626/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9974 - loss: 0.0131
# Epoch 123: val_loss did not improve from 0.05197
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9973 - loss: 0.0125 - val_accuracy: 0.9841 - val_loss: 0.0531
# Epoch 124/700
# 1612/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9975 - loss: 0.0126
# Epoch 124: val_loss did not improve from 0.05197
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9975 - loss: 0.0120 - val_accuracy: 0.9839 - val_loss: 0.0526
# Epoch 125/700
# 1625/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9974 - loss: 0.0123
# Epoch 125: val_loss did not improve from 0.05197
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9972 - loss: 0.0122 - val_accuracy: 0.9837 - val_loss: 0.0523
# Epoch 126/700
# 1641/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9983 - loss: 0.0111
# Epoch 126: val_loss did not improve from 0.05197
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9978 - loss: 0.0116 - val_accuracy: 0.9840 - val_loss: 0.0535
# Epoch 127/700
# 1625/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9977 - loss: 0.0115
# Epoch 127: val_loss did not improve from 0.05197
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9978 - loss: 0.0112 - val_accuracy: 0.9838 - val_loss: 0.0539
# Epoch 128/700
# 1628/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9984 - loss: 0.0110
# Epoch 128: val_loss did not improve from 0.05197
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9980 - loss: 0.0110 - val_accuracy: 0.9840 - val_loss: 0.0531
# Epoch 129/700
# 1640/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9970 - loss: 0.0110
# Epoch 129: val_loss did not improve from 0.05197
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9977 - loss: 0.0109 - val_accuracy: 0.9845 - val_loss: 0.0524
# Epoch 130/700
# 1638/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9984 - loss: 0.0106
# Epoch 130: val_loss did not improve from 0.05197
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9982 - loss: 0.0105 - val_accuracy: 0.9834 - val_loss: 0.0568
# Epoch 131/700
# 1623/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9980 - loss: 0.0105
# Epoch 131: val_loss did not improve from 0.05197
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9980 - loss: 0.0103 - val_accuracy: 0.9840 - val_loss: 0.0537
# Epoch 132/700
# 1634/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9991 - loss: 0.0093
# Epoch 132: val_loss did not improve from 0.05197
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9985 - loss: 0.0099 - val_accuracy: 0.9839 - val_loss: 0.0538
# Epoch 133/700
# 1630/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9982 - loss: 0.0099
# Epoch 133: val_loss did not improve from 0.05197
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9982 - loss: 0.0100 - val_accuracy: 0.9838 - val_loss: 0.0534
# Epoch 134/700
# 1625/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9984 - loss: 0.0090
# Epoch 134: val_loss did not improve from 0.05197
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9983 - loss: 0.0098 - val_accuracy: 0.9839 - val_loss: 0.0532
# Epoch 135/700
# 1615/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9986 - loss: 0.0101
# Epoch 135: val_loss did not improve from 0.05197
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9986 - loss: 0.0094 - val_accuracy: 0.9840 - val_loss: 0.0531
# Epoch 136/700
# 1641/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9990 - loss: 0.0086
# Epoch 136: val_loss did not improve from 0.05197
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9985 - loss: 0.0092 - val_accuracy: 0.9840 - val_loss: 0.0530
# Epoch 137/700
# 1633/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9988 - loss: 0.0086
# Epoch 137: val_loss did not improve from 0.05197
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9984 - loss: 0.0090 - val_accuracy: 0.9842 - val_loss: 0.0537
# Epoch 138/700
# 1636/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9987 - loss: 0.0088
# Epoch 138: val_loss did not improve from 0.05197
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9987 - loss: 0.0088 - val_accuracy: 0.9840 - val_loss: 0.0545
# Epoch 139/700
# 1616/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9985 - loss: 0.0093
# Epoch 139: val_loss did not improve from 0.05197
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9990 - loss: 0.0085 - val_accuracy: 0.9841 - val_loss: 0.0557
# Epoch 140/700
# 1629/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9988 - loss: 0.0083
# Epoch 140: val_loss did not improve from 0.05197
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9988 - loss: 0.0083 - val_accuracy: 0.9838 - val_loss: 0.0544
# Epoch 141/700
# 1631/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9992 - loss: 0.0068
# Epoch 141: val_loss did not improve from 0.05197
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9986 - loss: 0.0082 - val_accuracy: 0.9841 - val_loss: 0.0552
# Epoch 142/700
# 1635/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9985 - loss: 0.0088
# Epoch 142: val_loss did not improve from 0.05197
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9989 - loss: 0.0078 - val_accuracy: 0.9844 - val_loss: 0.0557
# Epoch 143/700
# 1629/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9991 - loss: 0.0070
# Epoch 143: val_loss did not improve from 0.05197
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9989 - loss: 0.0076 - val_accuracy: 0.9825 - val_loss: 0.0565
# Epoch 144/700
# 1645/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9987 - loss: 0.0077
# Epoch 144: val_loss did not improve from 0.05197
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9991 - loss: 0.0075 - val_accuracy: 0.9843 - val_loss: 0.0553
# Epoch 145/700
# 1628/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step - accuracy: 0.9991 - loss: 0.0070
# Epoch 145: val_loss did not improve from 0.05197
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9991 - loss: 0.0073 - val_accuracy: 0.9824 - val_loss: 0.0570
# Epoch 146/700
# 1634/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9994 - loss: 0.0067
# Epoch 146: val_loss did not improve from 0.05197
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9991 - loss: 0.0072 - val_accuracy: 0.9833 - val_loss: 0.0559
# Epoch 147/700
# 1614/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9994 - loss: 0.0066
# Epoch 147: val_loss did not improve from 0.05197
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9992 - loss: 0.0069 - val_accuracy: 0.9835 - val_loss: 0.0568
# Epoch 148/700
# 1641/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9997 - loss: 0.0061
# Epoch 148: val_loss did not improve from 0.05197
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9994 - loss: 0.0067 - val_accuracy: 0.9839 - val_loss: 0.0572
# Epoch 149/700
# 1634/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9995 - loss: 0.0064
# Epoch 149: val_loss did not improve from 0.05197
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9993 - loss: 0.0066 - val_accuracy: 0.9841 - val_loss: 0.0552

# %%
test_results = model.evaluate(X_test, y_test, verbose=0)

for name, val in zip(model.metrics_names, test_results):
    print(f"{name}: {val:.4f}")
# Out:
# loss: 0.2037
# compile_metrics: 0.9267

# %%
import matplotlib.pyplot as plt

plt.plot(history.history["loss"], label="train")
plt.plot(history.history["val_loss"], label="val")
plt.legend()
plt.title("Loss")
plt.show()

# %%
# ===== EVALUASI MODEL (TEST SET) =====

import numpy as np
from sklearn.metrics import roc_curve, confusion_matrix, classification_report

# 1. Ambil probabilitas output model
y_prob = model.predict(X_test).ravel()

# 2. Hitung ROC curve
fpr, tpr, thresholds = roc_curve(y_test, y_prob)

# 3. Hitung Youden Index
youden_index = tpr - fpr
best_threshold = thresholds[np.argmax(youden_index)]

print("Best threshold (Youden):", best_threshold)

# 4. Prediksi final menggunakan threshold Youden
y_pred = (y_prob >= best_threshold).astype(int)

# 5. Evaluasi
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))

print("\nClassification Report:")
print(classification_report(y_test, y_pred, target_names=["Normal", "Attack"]))
# Out:
# 773/773 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# Best threshold (Youden): 0.7196962
# Confusion Matrix:
# [[12463   704]
#  [  950 10617]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#       Normal       0.93      0.95      0.94     13167
#       Attack       0.94      0.92      0.93     11567
#
#     accuracy                           0.93     24734
#    macro avg       0.93      0.93      0.93     24734
# weighted avg       0.93      0.93      0.93     24734

# %%
y_pred = (y_prob >= best_threshold)

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred, target_names=["Normal","Attack"]))
# Out:
#               precision    recall  f1-score   support
#
#       Normal       0.93      0.95      0.94     13167
#       Attack       0.94      0.92      0.93     11567
#
#     accuracy                           0.93     24734
#    macro avg       0.93      0.93      0.93     24734
# weighted avg       0.93      0.93      0.93     24734

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import time
from sklearn.metrics import roc_curve, auc, confusion_matrix, classification_report

# 1. DEFINISI FUNGSI (Mesin Evaluasi)
def evaluate_iov_model(model, X_test, y_test):
    print("--- Memulai Proses Evaluasi ---")
    
    # Prediksi
    start_time = time.time()
    y_prob = model.predict(X_test).ravel()
    inference_time = (time.time() - start_time) / len(X_test)
    
    # Mencari Threshold Terbaik (Youden Index)
    fpr, tpr, thresholds = roc_curve(y_test, y_prob)
    youden_index = tpr - fpr
    best_threshold = thresholds[np.argmax(youden_index)]
    
    # Klasifikasi Berdasarkan Threshold
    y_pred = (y_prob >= best_threshold).astype(int)
    
    # Hitung Metrik
    cm = confusion_matrix(y_test, y_pred)
    tn, fp, fn, tp = cm.ravel()
    fpr_val = fp / (fp + tn)
    
    # VISUALISASI
    fig, ax = plt.subplots(1, 2, figsize=(15, 5))
    
    # Heatmap Confusion Matrix
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', ax=ax[0])
    ax[0].set_title('Confusion Matrix (Optimized Threshold)')
    ax[0].set_xlabel('Predicted')
    ax[0].set_ylabel('Actual')
    
    # ROC Curve
    ax[1].plot(fpr, tpr, label=f'AUC = {auc(fpr, tpr):.44f}')
    ax[1].plot([0, 1], [0, 1], 'k--')
    ax[1].set_title('ROC Curve')
    ax[1].legend()
    
    plt.show() # Ini akan memunculkan gambar
    
    # CETAK HASIL KE KONSOL
    print("\n" + "="*30)
    print(f"HASIL EVALUASI IDS (IoV)")
    print("="*30)
    print(f"Threshold Optimal : {best_threshold:.4f}")
    print(f"False Positive Rate: {fpr_val:.6f}")
    print(f"Inference Latency : {inference_time:.6f} s/sample")
    print("-" * 30)
    print(classification_report(y_test, y_pred, target_names=['Normal', 'Attack']))
    
    return best_threshold

# ==========================================
# 2. EKSEKUSI FUNGSI (Panggil di sini)
# ==========================================
# Ganti 'model_anda', 'X_test_anda', 'y_test_anda' 
# dengan nama variabel yang Anda miliki.

try:
    # Contoh: jika model Anda bernama 'global_model'
    best_thr = evaluate_iov_model(model, X_test, y_test)
except NameError as e:
    print(f"Error: {e}. Pastikan variabel model dan data Anda sudah didefinisikan sebelumnya.")
# Out:
# --- Memulai Proses Evaluasi ---
# 773/773 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# ==============================
# HASIL EVALUASI IDS (IoV)
# ==============================
# Threshold Optimal : 0.7197
# False Positive Rate: 0.053467
# Inference Latency : 0.000072 s/sample
# ------------------------------
#               precision    recall  f1-score   support
#
#       Normal       0.93      0.95      0.94     13167
#       Attack       0.94      0.92      0.93     11567
#
#     accuracy                           0.93     24734
#    macro avg       0.93      0.93      0.93     24734
# weighted avg       0.93      0.93      0.93     24734

# %%
from sklearn.metrics import confusion_matrix

# 1. Dapatkan prediksi dari model (berupa probabilitas)
y_prob = model.predict(X_test) 

# 2. Ubah probabilitas menjadi kelas (0 atau 1) 
# Gunakan threshold, misalnya 0.5 atau hasil Youden Index
y_pred = (y_prob > best_threshold).astype(int)

# 3. Munculkan Confusion Matrix
cm = confusion_matrix(y_test, y_pred)

# 4. Ekstrak TP, FP, TN, FN dari matriks
# Matriks sklearn memiliki format: [[TN, FP], [FN, TP]]
tn, fp, fn, tp = cm.ravel()

# 5. Cetak ke layar
print(f"--- Hasil Deteksi Serangan ---")
print(f"True Negatives (TN)  : {tn} (Trafik normal terdeteksi normal)")
print(f"False Positives (FP) : {fp} (ALARM PALSU - Normal dianggap serangan)")
print(f"False Negatives (FN) : {fn} (LOLOS - Serangan dianggap normal)")
print(f"True Positives (TP)  : {tp} (Berhasil mendeteksi serangan)")
# Out:
# 773/773 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# --- Hasil Deteksi Serangan ---
# True Negatives (TN)  : 12463 (Trafik normal terdeteksi normal)
# False Positives (FP) : 704 (ALARM PALSU - Normal dianggap serangan)
# False Negatives (FN) : 951 (LOLOS - Serangan dianggap normal)
# True Positives (TP)  : 10616 (Berhasil mendeteksi serangan)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Reds', 
            xticklabels=['Normal', 'Attack'], 
            yticklabels=['Normal', 'Attack'])
plt.title('Confusion Matrix: Deteksi Serangan IoV')
plt.ylabel('Kondisi Aktual')
plt.xlabel('Prediksi Model')
plt.show()

# %% [markdown]
# batas

# %%
import numpy as np

y_prob = model.predict(X_test).ravel()      # probabilitas Attack
y_pred = (y_prob > best_threshold).astype(int)         # label prediksi (threshold default)
# Out:
# 773/773 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step

# %%
# Fungsi: deteksi overfitting dan stabilitas training.
import matplotlib.pyplot as plt

plt.figure()
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training vs Validation Loss')
plt.legend()
plt.show()

plt.figure()
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training vs Validation Accuracy')
plt.legend()
plt.show()

# %%
# Fungsi: melihat False Negative (serangan lolos).
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

cm = confusion_matrix(y_test, y_pred)

disp = ConfusionMatrixDisplay(
    confusion_matrix=cm,
    display_labels=["Normal", "Attack"]
)
disp.plot()
plt.title("Confusion Matrix")
plt.show()
# 📌 Interpretasi IDS

# FN (Attack → Normal) harus minimal

# FP tinggi → false alarm

# %%
# Fungsi: menilai kualitas deteksi Attack.
from sklearn.metrics import precision_recall_fscore_support

precision, recall, f1, _ = precision_recall_fscore_support(
    y_test, y_pred, average=None
)

labels = ["Normal", "Attack"]

plt.figure()
plt.bar(labels, precision, label="Precision")
plt.bar(labels, recall, bottom=precision, label="Recall")
plt.ylabel("Score")
plt.title("Precision & Recall per Class")
plt.legend()
plt.show()
# Fokus laporan: Recall kelas Attack

# %%
# Fungsi: evaluasi threshold-independent.
from sklearn.metrics import roc_curve, auc

fpr, tpr, _ = roc_curve(y_test, y_prob)
roc_auc = auc(fpr, tpr)

plt.figure()
plt.plot(fpr, tpr, label=f"AUC = {roc_auc:.4f}")
plt.plot([0,1], [0,1], linestyle="--")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve")
plt.legend()
plt.show()

# AUC mendekati 1 → IDS sangat kuat

# %%
# Lebih relevan dari ROC untuk IDS.
from sklearn.metrics import precision_recall_curve

prec, rec, _ = precision_recall_curve(y_test, y_prob)

plt.figure()
plt.plot(rec, prec)
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title("Precision–Recall Curve")
plt.show()

# %%
from sklearn.metrics import f1_score
import matplotlib.pyplot as plt
import numpy as np

# ==========================================
# ASUMSI:
# - y_prob SUDAH dihitung di evaluate_iov_model
# - best_thr didapat dari return fungsi
# ==========================================

# Gunakan ulang y_prob & y_test (TIDAK buat baru)
y_pred = (y_prob >= best_thr).astype(int)

# Hitung F1-score untuk threshold yang SAMA
f1 = f1_score(y_test, y_pred)

print("\n" + "="*30)
print("F1-SCORE (FOLLOW YOUDEN THRESHOLD)")
print("="*30)
print(f"Threshold digunakan : {best_thr:.4f}")
print(f"F1-score           : {f1:.6f}")
# Out:
# ==============================
# F1-SCORE (FOLLOW YOUDEN THRESHOLD)
# ==============================
# Threshold digunakan : 0.7197
# F1-score           : 0.927735

# %%
plt.figure(figsize=(6,4))
plt.scatter(best_thr, f1, color='red', zorder=5)
plt.axvline(best_thr, linestyle='--', label=f"Threshold = {best_thr:.4f}")

plt.text(
    best_thr, f1,
    f"({best_thr:.4f}, {f1:.4f})",
    ha='left', va='bottom'
)

plt.xlabel("Threshold")
plt.ylabel("F1-score")
plt.title("F1-score at Optimized Youden Threshold")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Fungsi: lihat separasi Normal vs Attack.
plt.figure()
plt.hist(y_prob[y_test == 1], bins=50, alpha=0.7, label="Attack")
plt.hist(y_prob[y_test == 0], bins=50, alpha=0.7, label="Normal")
plt.xlabel("Predicted Probability (Attack)")
plt.ylabel("Frequency")
plt.title("Prediction Confidence Distribution")
plt.legend()
plt.show()
# 📌 Distribusi terpisah jelas → model robust.

# %%
from sklearn.metrics import classification_report

print(classification_report(
    y_test, y_pred,
    target_names=["Normal", "Attack"]
))
# Out:
#               precision    recall  f1-score   support
#
#       Normal       0.93      0.95      0.94     13167
#       Attack       0.94      0.92      0.93     11567
#
#     accuracy                           0.93     24734
#    macro avg       0.93      0.93      0.93     24734
# weighted avg       0.93      0.93      0.93     24734

# %%
import numpy as np
from sklearn.metrics import confusion_matrix

def compute_ids_metrics(y_true, y_pred):
    """
    Compute IDS metrics:
    Accuracy, Precision, Recall, F1, FPR, FNR
    """

    # Confusion Matrix
    tn, fp, fn, tp = confusion_matrix(y_true, y_pred).ravel()

    # Basic metrics
    acc = (tp + tn) / (tp + tn + fp + fn)

    precision = tp / (tp + fp) if (tp + fp) > 0 else 0.0
    recall    = tp / (tp + fn) if (tp + fn) > 0 else 0.0

    f1 = (2 * precision * recall) / (precision + recall) if (precision + recall) > 0 else 0.0

    # IDS-specific metrics
    fpr = fp / (fp + tn) if (fp + tn) > 0 else 0.0
    fnr = fn / (fn + tp) if (fn + tp) > 0 else 0.0

    return {
        "TP": tp,
        "FP": fp,
        "TN": tn,
        "FN": fn,
        "Accuracy": acc,
        "Precision": precision,
        "Recall": recall,
        "F1-score": f1,
        "FPR": fpr,
        "FNR": fnr,
    }

# %%
# Hitung metrik IDS
metrics = compute_ids_metrics(y_test, y_pred)

for k, v in metrics.items():
    print(f"{k:10s}: {v:.6f}" if isinstance(v, float) else f"{k:10s}: {v}")
# Out:
# TP        : 10617
# FP        : 704
# TN        : 12463
# FN        : 950
# Accuracy  : 0.933128
# Precision : 0.937815
# Recall    : 0.917870
# F1-score  : 0.927735
# FPR       : 0.053467
# FNR       : 0.082130

# %% [markdown]
# TP        : 10617
# FP        : 704
# TN        : 12463
# FN        : 950
# Accuracy  : 0.933128
# Precision : 0.937815
# Recall    : 0.917870
# F1-score  : 0.927735
# FPR       : 0.053467
# FNR       : 0.082130
