# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import (
    Input, Conv1D, BatchNormalization,
    ReLU, Add, GlobalAveragePooling1D, Dense
)
from tensorflow.keras.models import Model
# Out:
# 2026-04-08 22:32:16.363015: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-04-08 22:32:16.372740: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1775662336.383718  269098 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1775662336.387522  269098 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1775662336.396909  269098 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1775662336.396927  269098 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1775662336.396929  269098 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1775662336.396930  269098 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-04-08 22:32:16.400531: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
pathload = "/home/dani/Documents/tugas akhir/TugasAkhirku2026/mrtcn_ids/Preprocessing/hasil/final/preprocessingimgsize128_s16/preprocessingimgsize128_s16.npz"
data = np.load(
    pathload,
    mmap_mode="r"   # penting: tidak load penuh ke RAM
)

print(data.files)
# Out:
# ['x_train', 'y_train', 'x_val', 'y_val', 'x_test', 'y_test']

# %%
data = np.load(
    pathload,
)

X_train = data["x_train"]
y_train = data["y_train"]
X_val   = data["x_val"]
y_val   = data["y_val"]
X_test  = data["x_test"]
y_test  = data["y_test"]

print(X_train.shape, y_train.shape)
print(X_val.shape, y_val.shape)
print(X_test.shape, y_test.shape)
# Out:
# (26329, 128, 128) (26329,)
# (11284, 128, 128) (11284,)
# (24734, 128, 128) (24734,)

# %%
np.unique(y_train, return_counts=True)
# Out:
# (array([0, 1]), array([11283, 15046]))

# %%
import numpy as np

# Fungsi untuk cek balance
def check_balance_binary(y):
    n_normal = np.sum(y == 0)
    n_attack = np.sum(y == 1)
    total = len(y)
    print(f"Total samples: {total}")
    print(f"Normal: {n_normal} ({n_normal/total*100:.2f}%)")
    print(f"Attack: {n_attack} ({n_attack/total*100:.2f}%)\n")

# Cek balance di masing-masing split
print("=== Train Set ===")
check_balance_binary(y_train)

print("=== Validation Set ===")
check_balance_binary(y_val)

print("=== Test Set ===")
check_balance_binary(y_test)
# Out:
# === Train Set ===
# Total samples: 26329
# Normal: 11283 (42.85%)
# Attack: 15046 (57.15%)
#
# === Validation Set ===
# Total samples: 11284
# Normal: 4835 (42.85%)
# Attack: 6449 (57.15%)
#
# === Test Set ===
# Total samples: 24734
# Normal: 13167 (53.23%)
# Attack: 11567 (46.77%)

# %%
def tcn_block(x, filters, kernel_size, dilation):
    shortcut = x

    x = Conv1D(filters, kernel_size,
               padding="causal",
               dilation_rate=dilation)(x)
    x = BatchNormalization()(x)
    x = ReLU()(x)

    x = Conv1D(filters, kernel_size,
               padding="causal",
               dilation_rate=dilation)(x)
    x = BatchNormalization()(x)

    if shortcut.shape[-1] != filters:
        shortcut = Conv1D(filters, 1, padding="same")(shortcut)

    x = Add()([x, shortcut])
    x = ReLU()(x)
    return x

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, Dropout, MaxPooling1D, Flatten, Dense

def build_mr_tcn(input_shape=(128, 128), dropout_rate=0.55):
    model = Sequential()

    # Conv1D #1
    model.add(Conv1D(
        filters=64,
        kernel_size=3,
        strides=1,
        dilation_rate=1,
        padding="same",
        activation="relu",
        input_shape=input_shape
    ))
    model.add(Dropout(dropout_rate))

    # Conv1D #2
    model.add(Conv1D(
        filters=64,
        kernel_size=3,
        strides=1,
        dilation_rate=2,
        padding="same",
        activation="relu"
    ))
    model.add(Dropout(dropout_rate))

    # Conv1D #3
    model.add(Conv1D(
        filters=64,
        kernel_size=3,
        strides=1,
        dilation_rate=4,
        padding="same",
        activation="relu"
    ))
    model.add(Dropout(dropout_rate))

    # MaxPooling
    model.add(MaxPooling1D(pool_size=8, strides=8))

    # Flatten
    model.add(Flatten())

    # Dropout
    model.add(Dropout(dropout_rate))

    # Linear → Sigmoid
    model.add(Dense(1, activation="sigmoid"))

    return model

# %%
model = build_mr_tcn()

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-5),
    loss="binary_crossentropy",
    metrics=["accuracy"]
)

model.summary()
# Out:
# /home/dani/miniconda3/envs/latihan1/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# I0000 00:00:1775662344.426850  269098 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 4144 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d (Conv1D)                 │ (None, 128, 64)        │        24,640 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128, 64)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_1 (Conv1D)               │ (None, 128, 64)        │        12,352 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128, 64)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_2 (Conv1D)               │ (None, 128, 64)        │        12,352 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 128, 64)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d (MaxPooling1D)    │ (None, 16, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 1024)           │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │         1,025 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 50,369 (196.75 KB)
#  Trainable params: 50,369 (196.75 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
#  Total params: 50,369 (196.75 KB)

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

early_stop = EarlyStopping(
    monitor="val_loss",
    patience=30,
    restore_best_weights=True
)

checkpoint = ModelCheckpoint(
    "best_mr_tcn.keras",
    monitor="val_loss",
    save_best_only=True,
    verbose=1
)

# %%
history = model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=700,
    batch_size=16,
    callbacks=[early_stop, checkpoint]
)
# Out:
# Epoch 1/700
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1775662346.899203  269489 service.cc:152] XLA service 0x70ff7800bdd0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1775662346.899220  269489 service.cc:160]   StreamExecutor device (0): NVIDIA GeForce RTX 3060 Laptop GPU, Compute Capability 8.6
# 2026-04-08 22:32:26.922457: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1775662347.067661  269489 cuda_dnn.cc:529] Loaded cuDNN version 91701
# 2026-04-08 22:32:27.511031: W external/local_xla/xla/tsl/framework/bfc_allocator.cc:310] Allocator (GPU_0_bfc) ran out of memory trying to allocate 4.05GiB with freed_by_count=0. The caller indicates that this is not a failure, but this may mean that there could be performance gains if more memory were available.
#  100/1646 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.4323 - loss: 1.4506
# I0000 00:00:1775662348.831645  269489 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.4937 - loss: 1.0703
# Epoch 1: val_loss improved from None to 0.68250, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 9s 4ms/step - accuracy: 0.5106 - loss: 0.9361 - val_accuracy: 0.5727 - val_loss: 0.6825
# Epoch 2/700
# 1629/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5292 - loss: 0.7885
# Epoch 2: val_loss improved from 0.68250 to 0.67701, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.5328 - loss: 0.7670 - val_accuracy: 0.5876 - val_loss: 0.6770
# Epoch 3/700
# 1640/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5504 - loss: 0.7305
# Epoch 3: val_loss improved from 0.67701 to 0.67170, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.5521 - loss: 0.7197 - val_accuracy: 0.6043 - val_loss: 0.6717
# Epoch 4/700
# 1618/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5749 - loss: 0.6881
# Epoch 4: val_loss improved from 0.67170 to 0.66142, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.5847 - loss: 0.6790 - val_accuracy: 0.6367 - val_loss: 0.6614
# Epoch 5/700
# 1624/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6174 - loss: 0.6516
# Epoch 5: val_loss improved from 0.66142 to 0.63949, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.6352 - loss: 0.6393 - val_accuracy: 0.7100 - val_loss: 0.6395
# Epoch 6/700
# 1624/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6929 - loss: 0.5898
# Epoch 6: val_loss improved from 0.63949 to 0.59237, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.7140 - loss: 0.5705 - val_accuracy: 0.8376 - val_loss: 0.5924
# Epoch 7/700
# 1628/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7867 - loss: 0.4924
# Epoch 7: val_loss improved from 0.59237 to 0.51789, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.8068 - loss: 0.4621 - val_accuracy: 0.8789 - val_loss: 0.5179
# Epoch 8/700
# 1638/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8561 - loss: 0.3853
# Epoch 8: val_loss improved from 0.51789 to 0.44949, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8654 - loss: 0.3665 - val_accuracy: 0.8996 - val_loss: 0.4495
# Epoch 9/700
# 1615/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8855 - loss: 0.3233
# Epoch 9: val_loss improved from 0.44949 to 0.40445, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.8902 - loss: 0.3114 - val_accuracy: 0.9093 - val_loss: 0.4044
# Epoch 10/700
# 1618/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9014 - loss: 0.2833
# Epoch 10: val_loss improved from 0.40445 to 0.38055, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9022 - loss: 0.2801 - val_accuracy: 0.9133 - val_loss: 0.3805
# Epoch 11/700
# 1638/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9104 - loss: 0.2643
# Epoch 11: val_loss improved from 0.38055 to 0.36282, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9119 - loss: 0.2595 - val_accuracy: 0.9165 - val_loss: 0.3628
# Epoch 12/700
# 1614/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9125 - loss: 0.2542
# Epoch 12: val_loss improved from 0.36282 to 0.35203, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9134 - loss: 0.2482 - val_accuracy: 0.9172 - val_loss: 0.3520
# Epoch 13/700
# 1640/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9174 - loss: 0.2315
# Epoch 13: val_loss improved from 0.35203 to 0.34317, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9178 - loss: 0.2330 - val_accuracy: 0.9186 - val_loss: 0.3432
# Epoch 14/700
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9215 - loss: 0.2255
# Epoch 14: val_loss improved from 0.34317 to 0.33603, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9213 - loss: 0.2236 - val_accuracy: 0.9202 - val_loss: 0.3360
# Epoch 15/700
# 1631/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9226 - loss: 0.2134
# Epoch 15: val_loss improved from 0.33603 to 0.32783, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9221 - loss: 0.2142 - val_accuracy: 0.9211 - val_loss: 0.3278
# Epoch 16/700
# 1644/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9236 - loss: 0.2090
# Epoch 16: val_loss improved from 0.32783 to 0.32082, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9244 - loss: 0.2065 - val_accuracy: 0.9225 - val_loss: 0.3208
# Epoch 17/700
# 1636/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9251 - loss: 0.2068
# Epoch 17: val_loss improved from 0.32082 to 0.31466, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9264 - loss: 0.2008 - val_accuracy: 0.9240 - val_loss: 0.3147
# Epoch 18/700
# 1638/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9277 - loss: 0.1993
# Epoch 18: val_loss improved from 0.31466 to 0.30695, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9282 - loss: 0.1945 - val_accuracy: 0.9262 - val_loss: 0.3069
# Epoch 19/700
# 1621/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9301 - loss: 0.1888
# Epoch 19: val_loss improved from 0.30695 to 0.30098, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9317 - loss: 0.1879 - val_accuracy: 0.9267 - val_loss: 0.3010
# Epoch 20/700
# 1635/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9341 - loss: 0.1808
# Epoch 20: val_loss improved from 0.30098 to 0.29487, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9330 - loss: 0.1814 - val_accuracy: 0.9278 - val_loss: 0.2949
# Epoch 21/700
# 1620/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9364 - loss: 0.1735
# Epoch 21: val_loss improved from 0.29487 to 0.28963, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9354 - loss: 0.1762 - val_accuracy: 0.9288 - val_loss: 0.2896
# Epoch 22/700
# 1629/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9353 - loss: 0.1725
# Epoch 22: val_loss improved from 0.28963 to 0.28455, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9359 - loss: 0.1726 - val_accuracy: 0.9303 - val_loss: 0.2846
# Epoch 23/700
# 1643/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9389 - loss: 0.1643
# Epoch 23: val_loss improved from 0.28455 to 0.28117, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9377 - loss: 0.1691 - val_accuracy: 0.9303 - val_loss: 0.2812
# Epoch 24/700
# 1635/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9400 - loss: 0.1637
# Epoch 24: val_loss improved from 0.28117 to 0.27786, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9384 - loss: 0.1653 - val_accuracy: 0.9313 - val_loss: 0.2779
# Epoch 25/700
# 1630/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9370 - loss: 0.1676
# Epoch 25: val_loss improved from 0.27786 to 0.27284, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9404 - loss: 0.1619 - val_accuracy: 0.9328 - val_loss: 0.2728
# Epoch 26/700
# 1626/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9412 - loss: 0.1576
# Epoch 26: val_loss improved from 0.27284 to 0.26903, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9409 - loss: 0.1583 - val_accuracy: 0.9343 - val_loss: 0.2690
# Epoch 27/700
# 1620/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9443 - loss: 0.1511
# Epoch 27: val_loss improved from 0.26903 to 0.26702, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9427 - loss: 0.1547 - val_accuracy: 0.9349 - val_loss: 0.2670
# Epoch 28/700
# 1631/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9434 - loss: 0.1506
# Epoch 28: val_loss improved from 0.26702 to 0.26252, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9419 - loss: 0.1530 - val_accuracy: 0.9369 - val_loss: 0.2625
# Epoch 29/700
# 1617/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9409 - loss: 0.1572
# Epoch 29: val_loss improved from 0.26252 to 0.26016, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9427 - loss: 0.1517 - val_accuracy: 0.9375 - val_loss: 0.2602
# Epoch 30/700
# 1632/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9430 - loss: 0.1510
# Epoch 30: val_loss improved from 0.26016 to 0.25819, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9437 - loss: 0.1486 - val_accuracy: 0.9377 - val_loss: 0.2582
# Epoch 31/700
# 1619/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9453 - loss: 0.1499
# Epoch 31: val_loss improved from 0.25819 to 0.25538, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9463 - loss: 0.1458 - val_accuracy: 0.9384 - val_loss: 0.2554
# Epoch 32/700
# 1629/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9451 - loss: 0.1422
# Epoch 32: val_loss improved from 0.25538 to 0.25049, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9465 - loss: 0.1422 - val_accuracy: 0.9402 - val_loss: 0.2505
# Epoch 33/700
# 1630/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9467 - loss: 0.1422
# Epoch 33: val_loss did not improve from 0.25049
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9466 - loss: 0.1421 - val_accuracy: 0.9396 - val_loss: 0.2511
# Epoch 34/700
# 1641/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9468 - loss: 0.1427
# Epoch 34: val_loss improved from 0.25049 to 0.24904, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9483 - loss: 0.1413 - val_accuracy: 0.9402 - val_loss: 0.2490
# Epoch 35/700
# 1629/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9472 - loss: 0.1381
# Epoch 35: val_loss improved from 0.24904 to 0.24724, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9479 - loss: 0.1387 - val_accuracy: 0.9407 - val_loss: 0.2472
# Epoch 36/700
# 1640/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9530 - loss: 0.1321
# Epoch 36: val_loss improved from 0.24724 to 0.24290, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9508 - loss: 0.1339 - val_accuracy: 0.9416 - val_loss: 0.2429
# Epoch 37/700
# 1633/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9507 - loss: 0.1309
# Epoch 37: val_loss improved from 0.24290 to 0.24146, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9498 - loss: 0.1332 - val_accuracy: 0.9415 - val_loss: 0.2415
# Epoch 38/700
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9517 - loss: 0.1300
# Epoch 38: val_loss improved from 0.24146 to 0.23818, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9507 - loss: 0.1316 - val_accuracy: 0.9427 - val_loss: 0.2382
# Epoch 39/700
# 1645/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9522 - loss: 0.1305
# Epoch 39: val_loss improved from 0.23818 to 0.23616, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9517 - loss: 0.1290 - val_accuracy: 0.9426 - val_loss: 0.2362
# Epoch 40/700
# 1624/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9541 - loss: 0.1253
# Epoch 40: val_loss improved from 0.23616 to 0.23513, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9530 - loss: 0.1278 - val_accuracy: 0.9423 - val_loss: 0.2351
# Epoch 41/700
# 1616/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9533 - loss: 0.1251
# Epoch 41: val_loss improved from 0.23513 to 0.23265, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9532 - loss: 0.1267 - val_accuracy: 0.9443 - val_loss: 0.2326
# Epoch 42/700
# 1640/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9524 - loss: 0.1266
# Epoch 42: val_loss improved from 0.23265 to 0.23097, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9541 - loss: 0.1242 - val_accuracy: 0.9435 - val_loss: 0.2310
# Epoch 43/700
# 1624/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9559 - loss: 0.1194
# Epoch 43: val_loss improved from 0.23097 to 0.22859, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9548 - loss: 0.1233 - val_accuracy: 0.9439 - val_loss: 0.2286
# Epoch 44/700
# 1634/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9539 - loss: 0.1227
# Epoch 44: val_loss improved from 0.22859 to 0.22520, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9547 - loss: 0.1212 - val_accuracy: 0.9456 - val_loss: 0.2252
# Epoch 45/700
# 1630/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9562 - loss: 0.1199
# Epoch 45: val_loss did not improve from 0.22520
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9553 - loss: 0.1198 - val_accuracy: 0.9449 - val_loss: 0.2254
# Epoch 46/700
# 1623/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9559 - loss: 0.1204
# Epoch 46: val_loss improved from 0.22520 to 0.22364, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9561 - loss: 0.1200 - val_accuracy: 0.9457 - val_loss: 0.2236
# Epoch 47/700
# 1614/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9559 - loss: 0.1177
# Epoch 47: val_loss improved from 0.22364 to 0.22335, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9559 - loss: 0.1174 - val_accuracy: 0.9450 - val_loss: 0.2233
# Epoch 48/700
# 1627/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9550 - loss: 0.1212
# Epoch 48: val_loss improved from 0.22335 to 0.22064, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9573 - loss: 0.1174 - val_accuracy: 0.9467 - val_loss: 0.2206
# Epoch 49/700
# 1641/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9599 - loss: 0.1087
# Epoch 49: val_loss improved from 0.22064 to 0.21827, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9580 - loss: 0.1144 - val_accuracy: 0.9466 - val_loss: 0.2183
# Epoch 50/700
# 1642/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9620 - loss: 0.1054
# Epoch 50: val_loss did not improve from 0.21827
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9588 - loss: 0.1145 - val_accuracy: 0.9464 - val_loss: 0.2188
# Epoch 51/700
# 1640/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9589 - loss: 0.1132
# Epoch 51: val_loss improved from 0.21827 to 0.21521, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9578 - loss: 0.1134 - val_accuracy: 0.9472 - val_loss: 0.2152
# Epoch 52/700
# 1639/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9562 - loss: 0.1105
# Epoch 52: val_loss did not improve from 0.21521
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9577 - loss: 0.1125 - val_accuracy: 0.9465 - val_loss: 0.2159
# Epoch 53/700
# 1622/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9623 - loss: 0.1080
# Epoch 53: val_loss did not improve from 0.21521
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9605 - loss: 0.1110 - val_accuracy: 0.9463 - val_loss: 0.2155
# Epoch 54/700
# 1617/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9604 - loss: 0.1110
# Epoch 54: val_loss improved from 0.21521 to 0.21246, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9597 - loss: 0.1096 - val_accuracy: 0.9468 - val_loss: 0.2125
# Epoch 55/700
# 1631/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9593 - loss: 0.1099
# Epoch 55: val_loss improved from 0.21246 to 0.20874, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9615 - loss: 0.1070 - val_accuracy: 0.9475 - val_loss: 0.2087
# Epoch 56/700
# 1638/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9602 - loss: 0.1074
# Epoch 56: val_loss improved from 0.20874 to 0.20799, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9608 - loss: 0.1084 - val_accuracy: 0.9479 - val_loss: 0.2080
# Epoch 57/700
# 1637/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9609 - loss: 0.1072
# Epoch 57: val_loss did not improve from 0.20799
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9613 - loss: 0.1057 - val_accuracy: 0.9473 - val_loss: 0.2084
# Epoch 58/700
# 1616/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9647 - loss: 0.0964
# Epoch 58: val_loss improved from 0.20799 to 0.20764, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9614 - loss: 0.1032 - val_accuracy: 0.9472 - val_loss: 0.2076
# Epoch 59/700
# 1644/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9636 - loss: 0.0978
# Epoch 59: val_loss improved from 0.20764 to 0.20579, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9611 - loss: 0.1034 - val_accuracy: 0.9479 - val_loss: 0.2058
# Epoch 60/700
# 1615/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9625 - loss: 0.1016
# Epoch 60: val_loss improved from 0.20579 to 0.20399, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9627 - loss: 0.1016 - val_accuracy: 0.9482 - val_loss: 0.2040
# Epoch 61/700
# 1627/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9649 - loss: 0.0986
# Epoch 61: val_loss improved from 0.20399 to 0.20232, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9627 - loss: 0.1021 - val_accuracy: 0.9485 - val_loss: 0.2023
# Epoch 62/700
# 1645/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9641 - loss: 0.0976
# Epoch 62: val_loss improved from 0.20232 to 0.20202, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9637 - loss: 0.1002 - val_accuracy: 0.9481 - val_loss: 0.2020
# Epoch 63/700
# 1632/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9635 - loss: 0.0993
# Epoch 63: val_loss improved from 0.20202 to 0.20060, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9627 - loss: 0.0986 - val_accuracy: 0.9481 - val_loss: 0.2006
# Epoch 64/700
# 1635/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9640 - loss: 0.0961
# Epoch 64: val_loss improved from 0.20060 to 0.19889, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9643 - loss: 0.0981 - val_accuracy: 0.9481 - val_loss: 0.1989
# Epoch 65/700
# 1644/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9625 - loss: 0.1014
# Epoch 65: val_loss improved from 0.19889 to 0.19824, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9638 - loss: 0.0974 - val_accuracy: 0.9480 - val_loss: 0.1982
# Epoch 66/700
# 1631/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9627 - loss: 0.0989
# Epoch 66: val_loss improved from 0.19824 to 0.19759, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9641 - loss: 0.0969 - val_accuracy: 0.9478 - val_loss: 0.1976
# Epoch 67/700
# 1618/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9650 - loss: 0.0951
# Epoch 67: val_loss did not improve from 0.19759
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9656 - loss: 0.0952 - val_accuracy: 0.9474 - val_loss: 0.1979
# Epoch 68/700
# 1637/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9648 - loss: 0.0933
# Epoch 68: val_loss improved from 0.19759 to 0.19464, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9655 - loss: 0.0941 - val_accuracy: 0.9490 - val_loss: 0.1946
# Epoch 69/700
# 1626/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9662 - loss: 0.0895
# Epoch 69: val_loss improved from 0.19464 to 0.19281, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9657 - loss: 0.0926 - val_accuracy: 0.9485 - val_loss: 0.1928
# Epoch 70/700
# 1615/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9666 - loss: 0.0912
# Epoch 70: val_loss improved from 0.19281 to 0.19256, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9660 - loss: 0.0916 - val_accuracy: 0.9476 - val_loss: 0.1926
# Epoch 71/700
# 1642/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9674 - loss: 0.0851
# Epoch 71: val_loss did not improve from 0.19256
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9662 - loss: 0.0914 - val_accuracy: 0.9466 - val_loss: 0.1942
# Epoch 72/700
# 1623/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9674 - loss: 0.0904
# Epoch 72: val_loss improved from 0.19256 to 0.19122, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9668 - loss: 0.0909 - val_accuracy: 0.9476 - val_loss: 0.1912
# Epoch 73/700
# 1623/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9666 - loss: 0.0896
# Epoch 73: val_loss did not improve from 0.19122
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9660 - loss: 0.0912 - val_accuracy: 0.9475 - val_loss: 0.1913
# Epoch 74/700
# 1636/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9667 - loss: 0.0904
# Epoch 74: val_loss improved from 0.19122 to 0.18776, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9667 - loss: 0.0894 - val_accuracy: 0.9479 - val_loss: 0.1878
# Epoch 75/700
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9675 - loss: 0.0888
# Epoch 75: val_loss did not improve from 0.18776
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9674 - loss: 0.0885 - val_accuracy: 0.9474 - val_loss: 0.1878
# Epoch 76/700
# 1635/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9657 - loss: 0.0927
# Epoch 76: val_loss improved from 0.18776 to 0.18775, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9681 - loss: 0.0894 - val_accuracy: 0.9472 - val_loss: 0.1877
# Epoch 77/700
# 1625/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9706 - loss: 0.0870
# Epoch 77: val_loss improved from 0.18775 to 0.18617, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9688 - loss: 0.0871 - val_accuracy: 0.9476 - val_loss: 0.1862
# Epoch 78/700
# 1641/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9693 - loss: 0.0848
# Epoch 78: val_loss improved from 0.18617 to 0.18413, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9682 - loss: 0.0866 - val_accuracy: 0.9480 - val_loss: 0.1841
# Epoch 79/700
# 1618/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9687 - loss: 0.0877
# Epoch 79: val_loss improved from 0.18413 to 0.18161, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9691 - loss: 0.0848 - val_accuracy: 0.9487 - val_loss: 0.1816
# Epoch 80/700
# 1627/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9698 - loss: 0.0827
# Epoch 80: val_loss did not improve from 0.18161
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9694 - loss: 0.0845 - val_accuracy: 0.9480 - val_loss: 0.1823
# Epoch 81/700
# 1634/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9690 - loss: 0.0850
# Epoch 81: val_loss improved from 0.18161 to 0.18098, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9702 - loss: 0.0843 - val_accuracy: 0.9482 - val_loss: 0.1810
# Epoch 82/700
# 1617/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9684 - loss: 0.0848
# Epoch 82: val_loss improved from 0.18098 to 0.18069, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9697 - loss: 0.0827 - val_accuracy: 0.9479 - val_loss: 0.1807
# Epoch 83/700
# 1626/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9710 - loss: 0.0794
# Epoch 83: val_loss did not improve from 0.18069
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9703 - loss: 0.0813 - val_accuracy: 0.9474 - val_loss: 0.1808
# Epoch 84/700
# 1627/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9721 - loss: 0.0779
# Epoch 84: val_loss improved from 0.18069 to 0.17995, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9720 - loss: 0.0790 - val_accuracy: 0.9472 - val_loss: 0.1799
# Epoch 85/700
# 1618/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9719 - loss: 0.0804
# Epoch 85: val_loss improved from 0.17995 to 0.17765, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9718 - loss: 0.0807 - val_accuracy: 0.9484 - val_loss: 0.1776
# Epoch 86/700
# 1622/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9719 - loss: 0.0794
# Epoch 86: val_loss improved from 0.17765 to 0.17557, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9722 - loss: 0.0784 - val_accuracy: 0.9478 - val_loss: 0.1756
# Epoch 87/700
# 1617/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9723 - loss: 0.0763
# Epoch 87: val_loss improved from 0.17557 to 0.17452, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9721 - loss: 0.0779 - val_accuracy: 0.9482 - val_loss: 0.1745
# Epoch 88/700
# 1626/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9728 - loss: 0.0760
# Epoch 88: val_loss did not improve from 0.17452
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9723 - loss: 0.0767 - val_accuracy: 0.9481 - val_loss: 0.1761
# Epoch 89/700
# 1623/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9718 - loss: 0.0771
# Epoch 89: val_loss improved from 0.17452 to 0.17435, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9727 - loss: 0.0762 - val_accuracy: 0.9486 - val_loss: 0.1743
# Epoch 90/700
# 1617/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9739 - loss: 0.0736
# Epoch 90: val_loss did not improve from 0.17435
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9720 - loss: 0.0762 - val_accuracy: 0.9478 - val_loss: 0.1750
# Epoch 91/700
# 1626/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9739 - loss: 0.0716
# Epoch 91: val_loss did not improve from 0.17435
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9725 - loss: 0.0754 - val_accuracy: 0.9474 - val_loss: 0.1756
# Epoch 92/700
# 1625/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9712 - loss: 0.0775
# Epoch 92: val_loss improved from 0.17435 to 0.17366, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9726 - loss: 0.0751 - val_accuracy: 0.9474 - val_loss: 0.1737
# Epoch 93/700
# 1641/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9712 - loss: 0.0786
# Epoch 93: val_loss improved from 0.17366 to 0.17310, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9723 - loss: 0.0748 - val_accuracy: 0.9467 - val_loss: 0.1731
# Epoch 94/700
# 1634/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9728 - loss: 0.0732
# Epoch 94: val_loss improved from 0.17310 to 0.17221, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9731 - loss: 0.0733 - val_accuracy: 0.9467 - val_loss: 0.1722
# Epoch 95/700
# 1626/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9744 - loss: 0.0725
# Epoch 95: val_loss improved from 0.17221 to 0.17077, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9739 - loss: 0.0721 - val_accuracy: 0.9474 - val_loss: 0.1708
# Epoch 96/700
# 1639/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9746 - loss: 0.0739
# Epoch 96: val_loss improved from 0.17077 to 0.16856, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9746 - loss: 0.0714 - val_accuracy: 0.9478 - val_loss: 0.1686
# Epoch 97/700
# 1625/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9755 - loss: 0.0704
# Epoch 97: val_loss did not improve from 0.16856
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9747 - loss: 0.0721 - val_accuracy: 0.9467 - val_loss: 0.1699
# Epoch 98/700
# 1642/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9747 - loss: 0.0702
# Epoch 98: val_loss did not improve from 0.16856
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9756 - loss: 0.0701 - val_accuracy: 0.9470 - val_loss: 0.1695
# Epoch 99/700
# 1620/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9730 - loss: 0.0693
# Epoch 99: val_loss did not improve from 0.16856
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9752 - loss: 0.0689 - val_accuracy: 0.9465 - val_loss: 0.1690
# Epoch 100/700
# 1638/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9757 - loss: 0.0683
# Epoch 100: val_loss improved from 0.16856 to 0.16758, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9749 - loss: 0.0681 - val_accuracy: 0.9474 - val_loss: 0.1676
# Epoch 101/700
# 1645/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9767 - loss: 0.0649
# Epoch 101: val_loss improved from 0.16758 to 0.16697, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9760 - loss: 0.0681 - val_accuracy: 0.9468 - val_loss: 0.1670
# Epoch 102/700
# 1625/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9755 - loss: 0.0680
# Epoch 102: val_loss improved from 0.16697 to 0.16560, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9747 - loss: 0.0684 - val_accuracy: 0.9474 - val_loss: 0.1656
# Epoch 103/700
# 1627/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9760 - loss: 0.0674
# Epoch 103: val_loss did not improve from 0.16560
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9769 - loss: 0.0655 - val_accuracy: 0.9463 - val_loss: 0.1659
# Epoch 104/700
# 1619/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9770 - loss: 0.0657
# Epoch 104: val_loss improved from 0.16560 to 0.16415, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9763 - loss: 0.0662 - val_accuracy: 0.9468 - val_loss: 0.1641
# Epoch 105/700
# 1633/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9770 - loss: 0.0670
# Epoch 105: val_loss did not improve from 0.16415
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9768 - loss: 0.0652 - val_accuracy: 0.9451 - val_loss: 0.1659
# Epoch 106/700
# 1633/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9786 - loss: 0.0598
# Epoch 106: val_loss improved from 0.16415 to 0.16319, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9769 - loss: 0.0637 - val_accuracy: 0.9471 - val_loss: 0.1632
# Epoch 107/700
# 1639/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9777 - loss: 0.0643
# Epoch 107: val_loss did not improve from 0.16319
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9769 - loss: 0.0641 - val_accuracy: 0.9469 - val_loss: 0.1633
# Epoch 108/700
# 1624/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9778 - loss: 0.0629
# Epoch 108: val_loss did not improve from 0.16319
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9772 - loss: 0.0639 - val_accuracy: 0.9456 - val_loss: 0.1649
# Epoch 109/700
# 1632/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9772 - loss: 0.0635
# Epoch 109: val_loss improved from 0.16319 to 0.16171, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9774 - loss: 0.0629 - val_accuracy: 0.9474 - val_loss: 0.1617
# Epoch 110/700
# 1641/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9776 - loss: 0.0633
# Epoch 110: val_loss did not improve from 0.16171
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9771 - loss: 0.0626 - val_accuracy: 0.9469 - val_loss: 0.1618
# Epoch 111/700
# 1640/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9766 - loss: 0.0634
# Epoch 111: val_loss did not improve from 0.16171
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9767 - loss: 0.0627 - val_accuracy: 0.9460 - val_loss: 0.1644
# Epoch 112/700
# 1641/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9793 - loss: 0.0597
# Epoch 112: val_loss improved from 0.16171 to 0.16062, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9786 - loss: 0.0599 - val_accuracy: 0.9465 - val_loss: 0.1606
# Epoch 113/700
# 1633/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9786 - loss: 0.0607
# Epoch 113: val_loss improved from 0.16062 to 0.16043, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9781 - loss: 0.0616 - val_accuracy: 0.9465 - val_loss: 0.1604
# Epoch 114/700
# 1637/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9792 - loss: 0.0602
# Epoch 114: val_loss did not improve from 0.16043
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9795 - loss: 0.0597 - val_accuracy: 0.9449 - val_loss: 0.1638
# Epoch 115/700
# 1621/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9789 - loss: 0.0609
# Epoch 115: val_loss did not improve from 0.16043
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9793 - loss: 0.0586 - val_accuracy: 0.9458 - val_loss: 0.1614
# Epoch 116/700
# 1617/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9793 - loss: 0.0585
# Epoch 116: val_loss did not improve from 0.16043
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9790 - loss: 0.0593 - val_accuracy: 0.9448 - val_loss: 0.1615
# Epoch 117/700
# 1639/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9792 - loss: 0.0598
# Epoch 117: val_loss improved from 0.16043 to 0.16031, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9796 - loss: 0.0582 - val_accuracy: 0.9447 - val_loss: 0.1603
# Epoch 118/700
# 1620/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9800 - loss: 0.0565
# Epoch 118: val_loss improved from 0.16031 to 0.15865, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9789 - loss: 0.0578 - val_accuracy: 0.9465 - val_loss: 0.1586
# Epoch 119/700
# 1621/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9800 - loss: 0.0588
# Epoch 119: val_loss did not improve from 0.15865
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9796 - loss: 0.0574 - val_accuracy: 0.9464 - val_loss: 0.1595
# Epoch 120/700
# 1636/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9812 - loss: 0.0552
# Epoch 120: val_loss did not improve from 0.15865
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9806 - loss: 0.0546 - val_accuracy: 0.9453 - val_loss: 0.1596
# Epoch 121/700
# 1621/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9784 - loss: 0.0574
# Epoch 121: val_loss did not improve from 0.15865
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9798 - loss: 0.0555 - val_accuracy: 0.9450 - val_loss: 0.1587
# Epoch 122/700
# 1618/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9806 - loss: 0.0545
# Epoch 122: val_loss did not improve from 0.15865
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9803 - loss: 0.0560 - val_accuracy: 0.9444 - val_loss: 0.1617
# Epoch 123/700
# 1621/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9805 - loss: 0.0568
# Epoch 123: val_loss did not improve from 0.15865
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9803 - loss: 0.0545 - val_accuracy: 0.9451 - val_loss: 0.1590
# Epoch 124/700
# 1626/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9817 - loss: 0.0518
# Epoch 124: val_loss improved from 0.15865 to 0.15781, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9814 - loss: 0.0538 - val_accuracy: 0.9459 - val_loss: 0.1578
# Epoch 125/700
# 1618/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9825 - loss: 0.0523
# Epoch 125: val_loss did not improve from 0.15781
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9812 - loss: 0.0525 - val_accuracy: 0.9456 - val_loss: 0.1581
# Epoch 126/700
# 1644/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9807 - loss: 0.0557
# Epoch 126: val_loss did not improve from 0.15781
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9809 - loss: 0.0530 - val_accuracy: 0.9448 - val_loss: 0.1580
# Epoch 127/700
# 1620/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9828 - loss: 0.0497
# Epoch 127: val_loss improved from 0.15781 to 0.15676, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9827 - loss: 0.0514 - val_accuracy: 0.9454 - val_loss: 0.1568
# Epoch 128/700
# 1626/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9818 - loss: 0.0519
# Epoch 128: val_loss did not improve from 0.15676
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9814 - loss: 0.0526 - val_accuracy: 0.9444 - val_loss: 0.1581
# Epoch 129/700
# 1622/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9821 - loss: 0.0507
# Epoch 129: val_loss did not improve from 0.15676
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9821 - loss: 0.0503 - val_accuracy: 0.9441 - val_loss: 0.1583
# Epoch 130/700
# 1636/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9846 - loss: 0.0449
# Epoch 130: val_loss did not improve from 0.15676
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9829 - loss: 0.0489 - val_accuracy: 0.9447 - val_loss: 0.1586
# Epoch 131/700
# 1619/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9835 - loss: 0.0494
# Epoch 131: val_loss did not improve from 0.15676
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9828 - loss: 0.0495 - val_accuracy: 0.9446 - val_loss: 0.1577
# Epoch 132/700
# 1634/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9839 - loss: 0.0484
# Epoch 132: val_loss did not improve from 0.15676
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9828 - loss: 0.0488 - val_accuracy: 0.9445 - val_loss: 0.1578
# Epoch 133/700
# 1616/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9820 - loss: 0.0486
# Epoch 133: val_loss did not improve from 0.15676
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9822 - loss: 0.0491 - val_accuracy: 0.9438 - val_loss: 0.1590
# Epoch 134/700
# 1642/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9814 - loss: 0.0505
# Epoch 134: val_loss did not improve from 0.15676
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9835 - loss: 0.0479 - val_accuracy: 0.9445 - val_loss: 0.1572
# Epoch 135/700
# 1633/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9815 - loss: 0.0479
# Epoch 135: val_loss did not improve from 0.15676
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9828 - loss: 0.0475 - val_accuracy: 0.9450 - val_loss: 0.1571
# Epoch 136/700
# 1617/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9841 - loss: 0.0458
# Epoch 136: val_loss did not improve from 0.15676
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9835 - loss: 0.0472 - val_accuracy: 0.9444 - val_loss: 0.1570
# Epoch 137/700
# 1637/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9836 - loss: 0.0463
# Epoch 137: val_loss did not improve from 0.15676
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9839 - loss: 0.0470 - val_accuracy: 0.9448 - val_loss: 0.1570
# Epoch 138/700
# 1630/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9830 - loss: 0.0494
# Epoch 138: val_loss improved from 0.15676 to 0.15672, saving model to best_mr_tcn.keras
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9835 - loss: 0.0451 - val_accuracy: 0.9442 - val_loss: 0.1567
# Epoch 139/700
# 1633/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9838 - loss: 0.0438
# Epoch 139: val_loss did not improve from 0.15672
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9841 - loss: 0.0464 - val_accuracy: 0.9444 - val_loss: 0.1568
# Epoch 140/700
# 1636/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9841 - loss: 0.0441
# Epoch 140: val_loss did not improve from 0.15672
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9837 - loss: 0.0454 - val_accuracy: 0.9437 - val_loss: 0.1575
# Epoch 141/700
# 1637/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9850 - loss: 0.0429
# Epoch 141: val_loss did not improve from 0.15672
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9839 - loss: 0.0444 - val_accuracy: 0.9436 - val_loss: 0.1569
# Epoch 142/700
# 1628/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9854 - loss: 0.0419
# Epoch 142: val_loss did not improve from 0.15672
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9845 - loss: 0.0442 - val_accuracy: 0.9433 - val_loss: 0.1590
# Epoch 143/700
# 1624/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9841 - loss: 0.0421
# Epoch 143: val_loss did not improve from 0.15672
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9848 - loss: 0.0425 - val_accuracy: 0.9439 - val_loss: 0.1570
# Epoch 144/700
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9851 - loss: 0.0425
# Epoch 144: val_loss did not improve from 0.15672
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9858 - loss: 0.0426 - val_accuracy: 0.9433 - val_loss: 0.1577
# Epoch 145/700
# 1614/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9872 - loss: 0.0385
# Epoch 145: val_loss did not improve from 0.15672
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9859 - loss: 0.0426 - val_accuracy: 0.9430 - val_loss: 0.1588
# Epoch 146/700
# 1637/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9851 - loss: 0.0424
# Epoch 146: val_loss did not improve from 0.15672
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9852 - loss: 0.0423 - val_accuracy: 0.9435 - val_loss: 0.1575
# Epoch 147/700
# 1639/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9876 - loss: 0.0380
# Epoch 147: val_loss did not improve from 0.15672
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9858 - loss: 0.0406 - val_accuracy: 0.9435 - val_loss: 0.1577
# Epoch 148/700
# 1638/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9868 - loss: 0.0383
# Epoch 148: val_loss did not improve from 0.15672
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9860 - loss: 0.0409 - val_accuracy: 0.9423 - val_loss: 0.1624
# Epoch 149/700
# 1641/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9855 - loss: 0.0442
# Epoch 149: val_loss did not improve from 0.15672
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9859 - loss: 0.0413 - val_accuracy: 0.9428 - val_loss: 0.1582
# Epoch 150/700
# 1629/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9853 - loss: 0.0399
# Epoch 150: val_loss did not improve from 0.15672
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9862 - loss: 0.0405 - val_accuracy: 0.9436 - val_loss: 0.1581
# Epoch 151/700
# 1631/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9853 - loss: 0.0403
# Epoch 151: val_loss did not improve from 0.15672
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9860 - loss: 0.0395 - val_accuracy: 0.9434 - val_loss: 0.1591
# Epoch 152/700
# 1633/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9857 - loss: 0.0379
# Epoch 152: val_loss did not improve from 0.15672
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9856 - loss: 0.0387 - val_accuracy: 0.9440 - val_loss: 0.1587
# Epoch 153/700
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9862 - loss: 0.0403
# Epoch 153: val_loss did not improve from 0.15672
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9859 - loss: 0.0400 - val_accuracy: 0.9428 - val_loss: 0.1598
# Epoch 154/700
# 1626/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9874 - loss: 0.0373
# Epoch 154: val_loss did not improve from 0.15672
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9872 - loss: 0.0381 - val_accuracy: 0.9426 - val_loss: 0.1608
# Epoch 155/700
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9871 - loss: 0.0393
# Epoch 155: val_loss did not improve from 0.15672
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9869 - loss: 0.0389 - val_accuracy: 0.9438 - val_loss: 0.1600
# Epoch 156/700
# 1645/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9864 - loss: 0.0360
# Epoch 156: val_loss did not improve from 0.15672
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9863 - loss: 0.0374 - val_accuracy: 0.9429 - val_loss: 0.1603
# Epoch 157/700
# 1644/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9854 - loss: 0.0405
# Epoch 157: val_loss did not improve from 0.15672
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9859 - loss: 0.0376 - val_accuracy: 0.9416 - val_loss: 0.1618
# Epoch 158/700
# 1633/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9878 - loss: 0.0347
# Epoch 158: val_loss did not improve from 0.15672
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9876 - loss: 0.0360 - val_accuracy: 0.9424 - val_loss: 0.1612
# Epoch 159/700
# 1631/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9881 - loss: 0.0349
# Epoch 159: val_loss did not improve from 0.15672
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9874 - loss: 0.0364 - val_accuracy: 0.9425 - val_loss: 0.1611
# Epoch 160/700
# 1636/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9889 - loss: 0.0357
# Epoch 160: val_loss did not improve from 0.15672
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9884 - loss: 0.0358 - val_accuracy: 0.9414 - val_loss: 0.1622
# Epoch 161/700
# 1640/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9877 - loss: 0.0359
# Epoch 161: val_loss did not improve from 0.15672
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9883 - loss: 0.0353 - val_accuracy: 0.9432 - val_loss: 0.1616
# Epoch 162/700
# 1631/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9880 - loss: 0.0358
# Epoch 162: val_loss did not improve from 0.15672
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9878 - loss: 0.0351 - val_accuracy: 0.9431 - val_loss: 0.1615
# Epoch 163/700
# 1633/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9880 - loss: 0.0347
# Epoch 163: val_loss did not improve from 0.15672
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9880 - loss: 0.0358 - val_accuracy: 0.9412 - val_loss: 0.1636
# Epoch 164/700
# 1629/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9869 - loss: 0.0383
# Epoch 164: val_loss did not improve from 0.15672
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9874 - loss: 0.0355 - val_accuracy: 0.9422 - val_loss: 0.1618
# Epoch 165/700
# 1624/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9886 - loss: 0.0326
# Epoch 165: val_loss did not improve from 0.15672
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9875 - loss: 0.0347 - val_accuracy: 0.9406 - val_loss: 0.1639
# Epoch 166/700
# 1635/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9876 - loss: 0.0340
# Epoch 166: val_loss did not improve from 0.15672
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 3s 2ms/step - accuracy: 0.9881 - loss: 0.0333 - val_accuracy: 0.9425 - val_loss: 0.1631
# Epoch 167/700
# 1645/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9883 - loss: 0.0320
# Epoch 167: val_loss did not improve from 0.15672
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9878 - loss: 0.0343 - val_accuracy: 0.9406 - val_loss: 0.1658
# Epoch 168/700
# 1638/1646 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9880 - loss: 0.0337
# Epoch 168: val_loss did not improve from 0.15672
# 1646/1646 ━━━━━━━━━━━━━━━━━━━━ 4s 2ms/step - accuracy: 0.9887 - loss: 0.0334 - val_accuracy: 0.9413 - val_loss: 0.1657

# %%
test_results = model.evaluate(X_test, y_test, verbose=0)

for name, val in zip(model.metrics_names, test_results):
    print(f"{name}: {val:.4f}")
# Out:
# loss: 0.2166
# compile_metrics: 0.9175

# %%
import matplotlib.pyplot as plt

plt.plot(history.history["loss"], label="train")
plt.plot(history.history["val_loss"], label="val")
plt.legend()
plt.title("Loss")
plt.show()

# %%
# ===== EVALUASI MODEL (TEST SET) =====

import numpy as np
from sklearn.metrics import roc_curve, confusion_matrix, classification_report

# 1. Ambil probabilitas output model
y_prob = model.predict(X_test).ravel()

# 2. Hitung ROC curve
fpr, tpr, thresholds = roc_curve(y_test, y_prob)

# 3. Hitung Youden Index
youden_index = tpr - fpr
best_threshold = thresholds[np.argmax(youden_index)]

print("Best threshold (Youden):", best_threshold)

# 4. Prediksi final menggunakan threshold Youden
y_pred = (y_prob >= best_threshold).astype(int)

# 5. Evaluasi
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))

print("\nClassification Report:")
print(classification_report(y_test, y_pred, target_names=["Normal", "Attack"]))
# Out:
# 773/773 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step
# Best threshold (Youden): 0.6504964
# Confusion Matrix:
# [[12354   813]
#  [ 1107 10460]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#       Normal       0.92      0.94      0.93     13167
#       Attack       0.93      0.90      0.92     11567
#
#     accuracy                           0.92     24734
#    macro avg       0.92      0.92      0.92     24734
# weighted avg       0.92      0.92      0.92     24734

# %%
y_pred = (y_prob >= best_threshold)

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred, target_names=["Normal","Attack"]))
# Out:
#               precision    recall  f1-score   support
#
#       Normal       0.92      0.94      0.93     13167
#       Attack       0.93      0.90      0.92     11567
#
#     accuracy                           0.92     24734
#    macro avg       0.92      0.92      0.92     24734
# weighted avg       0.92      0.92      0.92     24734

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import time
from sklearn.metrics import roc_curve, auc, confusion_matrix, classification_report

# 1. DEFINISI FUNGSI (Mesin Evaluasi)
def evaluate_iov_model(model, X_test, y_test):
    print("--- Memulai Proses Evaluasi ---")
    
    # Prediksi
    start_time = time.time()
    y_prob = model.predict(X_test).ravel()
    inference_time = (time.time() - start_time) / len(X_test)
    
    # Mencari Threshold Terbaik (Youden Index)
    fpr, tpr, thresholds = roc_curve(y_test, y_prob)
    youden_index = tpr - fpr
    best_threshold = thresholds[np.argmax(youden_index)]
    
    # Klasifikasi Berdasarkan Threshold
    y_pred = (y_prob >= best_threshold).astype(int)
    
    # Hitung Metrik
    cm = confusion_matrix(y_test, y_pred)
    tn, fp, fn, tp = cm.ravel()
    fpr_val = fp / (fp + tn)
    
    # VISUALISASI
    fig, ax = plt.subplots(1, 2, figsize=(15, 5))
    
    # Heatmap Confusion Matrix
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', ax=ax[0])
    ax[0].set_title('Confusion Matrix (Optimized Threshold)')
    ax[0].set_xlabel('Predicted')
    ax[0].set_ylabel('Actual')
    
    # ROC Curve
    ax[1].plot(fpr, tpr, label=f'AUC = {auc(fpr, tpr):.44f}')
    ax[1].plot([0, 1], [0, 1], 'k--')
    ax[1].set_title('ROC Curve')
    ax[1].legend()
    
    plt.show() # Ini akan memunculkan gambar
    
    # CETAK HASIL KE KONSOL
    print("\n" + "="*30)
    print(f"HASIL EVALUASI IDS (IoV)")
    print("="*30)
    print(f"Threshold Optimal : {best_threshold:.4f}")
    print(f"False Positive Rate: {fpr_val:.6f}")
    print(f"Inference Latency : {inference_time:.6f} s/sample")
    print("-" * 30)
    print(classification_report(y_test, y_pred, target_names=['Normal', 'Attack']))
    
    return best_threshold

# ==========================================
# 2. EKSEKUSI FUNGSI (Panggil di sini)
# ==========================================
# Ganti 'model_anda', 'X_test_anda', 'y_test_anda' 
# dengan nama variabel yang Anda miliki.

try:
    # Contoh: jika model Anda bernama 'global_model'
    best_thr = evaluate_iov_model(model, X_test, y_test)
except NameError as e:
    print(f"Error: {e}. Pastikan variabel model dan data Anda sudah didefinisikan sebelumnya.")
# Out:
# --- Memulai Proses Evaluasi ---
# 773/773 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# ==============================
# HASIL EVALUASI IDS (IoV)
# ==============================
# Threshold Optimal : 0.6505
# False Positive Rate: 0.061745
# Inference Latency : 0.000072 s/sample
# ------------------------------
#               precision    recall  f1-score   support
#
#       Normal       0.92      0.94      0.93     13167
#       Attack       0.93      0.90      0.92     11567
#
#     accuracy                           0.92     24734
#    macro avg       0.92      0.92      0.92     24734
# weighted avg       0.92      0.92      0.92     24734

# %%
from sklearn.metrics import confusion_matrix

# 1. Dapatkan prediksi dari model (berupa probabilitas)
y_prob = model.predict(X_test) 

# 2. Ubah probabilitas menjadi kelas (0 atau 1) 
# Gunakan threshold, misalnya 0.5 atau hasil Youden Index
y_pred = (y_prob > best_threshold).astype(int)

# 3. Munculkan Confusion Matrix
cm = confusion_matrix(y_test, y_pred)

# 4. Ekstrak TP, FP, TN, FN dari matriks
# Matriks sklearn memiliki format: [[TN, FP], [FN, TP]]
tn, fp, fn, tp = cm.ravel()

# 5. Cetak ke layar
print(f"--- Hasil Deteksi Serangan ---")
print(f"True Negatives (TN)  : {tn} (Trafik normal terdeteksi normal)")
print(f"False Positives (FP) : {fp} (ALARM PALSU - Normal dianggap serangan)")
print(f"False Negatives (FN) : {fn} (LOLOS - Serangan dianggap normal)")
print(f"True Positives (TP)  : {tp} (Berhasil mendeteksi serangan)")
# Out:
# 773/773 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# --- Hasil Deteksi Serangan ---
# True Negatives (TN)  : 12354 (Trafik normal terdeteksi normal)
# False Positives (FP) : 813 (ALARM PALSU - Normal dianggap serangan)
# False Negatives (FN) : 1108 (LOLOS - Serangan dianggap normal)
# True Positives (TP)  : 10459 (Berhasil mendeteksi serangan)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Reds', 
            xticklabels=['Normal', 'Attack'], 
            yticklabels=['Normal', 'Attack'])
plt.title('Confusion Matrix: Deteksi Serangan IoV')
plt.ylabel('Kondisi Aktual')
plt.xlabel('Prediksi Model')
plt.show()

# %% [markdown]
# batas

# %%
import numpy as np

y_prob = model.predict(X_test).ravel()      # probabilitas Attack
y_pred = (y_prob > best_threshold).astype(int)         # label prediksi (threshold default)
# Out:
# 773/773 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step

# %%
# Fungsi: deteksi overfitting dan stabilitas training.
import matplotlib.pyplot as plt

plt.figure()
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training vs Validation Loss')
plt.legend()
plt.show()

plt.figure()
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training vs Validation Accuracy')
plt.legend()
plt.show()

# %%
# Fungsi: melihat False Negative (serangan lolos).
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

cm = confusion_matrix(y_test, y_pred)

disp = ConfusionMatrixDisplay(
    confusion_matrix=cm,
    display_labels=["Normal", "Attack"]
)
disp.plot()
plt.title("Confusion Matrix")
plt.show()
# 📌 Interpretasi IDS

# FN (Attack → Normal) harus minimal

# FP tinggi → false alarm

# %%
# Fungsi: menilai kualitas deteksi Attack.
from sklearn.metrics import precision_recall_fscore_support

precision, recall, f1, _ = precision_recall_fscore_support(
    y_test, y_pred, average=None
)

labels = ["Normal", "Attack"]

plt.figure()
plt.bar(labels, precision, label="Precision")
plt.bar(labels, recall, bottom=precision, label="Recall")
plt.ylabel("Score")
plt.title("Precision & Recall per Class")
plt.legend()
plt.show()
# Fokus laporan: Recall kelas Attack

# %%
# Fungsi: evaluasi threshold-independent.
from sklearn.metrics import roc_curve, auc

fpr, tpr, _ = roc_curve(y_test, y_prob)
roc_auc = auc(fpr, tpr)

plt.figure()
plt.plot(fpr, tpr, label=f"AUC = {roc_auc:.4f}")
plt.plot([0,1], [0,1], linestyle="--")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve")
plt.legend()
plt.show()

# AUC mendekati 1 → IDS sangat kuat

# %%
# Lebih relevan dari ROC untuk IDS.
from sklearn.metrics import precision_recall_curve

prec, rec, _ = precision_recall_curve(y_test, y_prob)

plt.figure()
plt.plot(rec, prec)
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title("Precision–Recall Curve")
plt.show()

# %%
from sklearn.metrics import f1_score
import matplotlib.pyplot as plt
import numpy as np

# ==========================================
# ASUMSI:
# - y_prob SUDAH dihitung di evaluate_iov_model
# - best_thr didapat dari return fungsi
# ==========================================

# Gunakan ulang y_prob & y_test (TIDAK buat baru)
y_pred = (y_prob >= best_thr).astype(int)

# Hitung F1-score untuk threshold yang SAMA
f1 = f1_score(y_test, y_pred)

print("\n" + "="*30)
print("F1-SCORE (FOLLOW YOUDEN THRESHOLD)")
print("="*30)
print(f"Threshold digunakan : {best_thr:.4f}")
print(f"F1-score           : {f1:.6f}")
# Out:
# ==============================
# F1-SCORE (FOLLOW YOUDEN THRESHOLD)
# ==============================
# Threshold digunakan : 0.6505
# F1-score           : 0.915937

# %%
plt.figure(figsize=(6,4))
plt.scatter(best_thr, f1, color='red', zorder=5)
plt.axvline(best_thr, linestyle='--', label=f"Threshold = {best_thr:.4f}")

plt.text(
    best_thr, f1,
    f"({best_thr:.4f}, {f1:.4f})",
    ha='left', va='bottom'
)

plt.xlabel("Threshold")
plt.ylabel("F1-score")
plt.title("F1-score at Optimized Youden Threshold")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Fungsi: lihat separasi Normal vs Attack.
plt.figure()
plt.hist(y_prob[y_test == 1], bins=50, alpha=0.7, label="Attack")
plt.hist(y_prob[y_test == 0], bins=50, alpha=0.7, label="Normal")
plt.xlabel("Predicted Probability (Attack)")
plt.ylabel("Frequency")
plt.title("Prediction Confidence Distribution")
plt.legend()
plt.show()
# 📌 Distribusi terpisah jelas → model robust.

# %%
from sklearn.metrics import classification_report

print(classification_report(
    y_test, y_pred,
    target_names=["Normal", "Attack"]
))
# Out:
#               precision    recall  f1-score   support
#
#       Normal       0.92      0.94      0.93     13167
#       Attack       0.93      0.90      0.92     11567
#
#     accuracy                           0.92     24734
#    macro avg       0.92      0.92      0.92     24734
# weighted avg       0.92      0.92      0.92     24734

# %%
import numpy as np
from sklearn.metrics import confusion_matrix

def compute_ids_metrics(y_true, y_pred):
    """
    Compute IDS metrics:
    Accuracy, Precision, Recall, F1, FPR, FNR
    """

    # Confusion Matrix
    tn, fp, fn, tp = confusion_matrix(y_true, y_pred).ravel()

    # Basic metrics
    acc = (tp + tn) / (tp + tn + fp + fn)

    precision = tp / (tp + fp) if (tp + fp) > 0 else 0.0
    recall    = tp / (tp + fn) if (tp + fn) > 0 else 0.0

    f1 = (2 * precision * recall) / (precision + recall) if (precision + recall) > 0 else 0.0

    # IDS-specific metrics
    fpr = fp / (fp + tn) if (fp + tn) > 0 else 0.0
    fnr = fn / (fn + tp) if (fn + tp) > 0 else 0.0

    return {
        "TP": tp,
        "FP": fp,
        "TN": tn,
        "FN": fn,
        "Accuracy": acc,
        "Precision": precision,
        "Recall": recall,
        "F1-score": f1,
        "FPR": fpr,
        "FNR": fnr,
    }

# %%
# Hitung metrik IDS
metrics = compute_ids_metrics(y_test, y_pred)

for k, v in metrics.items():
    print(f"{k:10s}: {v:.6f}" if isinstance(v, float) else f"{k:10s}: {v}")
# Out:
# TP        : 10460
# FP        : 813
# TN        : 12354
# FN        : 1107
# Accuracy  : 0.922374
# Precision : 0.927881
# Recall    : 0.904297
# F1-score  : 0.915937
# FPR       : 0.061745
# FNR       : 0.095703

# %% [markdown]
# TP        : 10460
# FP        : 813
# TN        : 12354
# FN        : 1107
# Accuracy  : 0.922374
# Precision : 0.927881
# Recall    : 0.904297
# F1-score  : 0.915937
# FPR       : 0.061745
# FNR       : 0.095703
