# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import (
    Input, Conv1D, BatchNormalization,
    ReLU, Add, GlobalAveragePooling1D, Dense
)
from tensorflow.keras.models import Model
# Out:
# 2026-04-08 21:01:22.894952: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-04-08 21:01:22.905542: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1775656882.918190  117533 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1775656882.922213  117533 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1775656882.932860  117533 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1775656882.932876  117533 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1775656882.932877  117533 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1775656882.932878  117533 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-04-08 21:01:22.937115: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
pathload = "/home/dani/Documents/tugas akhir/TugasAkhirku2026/mrtcn_ids/Preprocessing/hasil/final/preprocessingimgsize64_s16/preprocessingimgsize64_s16.npz"
data = np.load(
    pathload,
    mmap_mode="r"   # penting: tidak load penuh ke RAM
)

print(data.files)
# Out:
# ['x_train', 'y_train', 'x_val', 'y_val', 'x_test', 'y_test']

# %%
data = np.load(
    pathload,
)

X_train = data["x_train"]
y_train = data["y_train"]
X_val   = data["x_val"]
y_val   = data["y_val"]
X_test  = data["x_test"]
y_test  = data["y_test"]

print(X_train.shape, y_train.shape)
print(X_val.shape, y_val.shape)
print(X_test.shape, y_test.shape)
# Out:
# (52661, 64, 64) (52661,)
# (22569, 64, 64) (22569,)
# (49472, 64, 64) (49472,)

# %%
np.unique(y_train, return_counts=True)
# Out:
# (array([0, 1]), array([24073, 28588]))

# %%
import numpy as np

# Fungsi untuk cek balance
def check_balance_binary(y):
    n_normal = np.sum(y == 0)
    n_attack = np.sum(y == 1)
    total = len(y)
    print(f"Total samples: {total}")
    print(f"Normal: {n_normal} ({n_normal/total*100:.2f}%)")
    print(f"Attack: {n_attack} ({n_attack/total*100:.2f}%)\n")

# Cek balance di masing-masing split
print("=== Train Set ===")
check_balance_binary(y_train)

print("=== Validation Set ===")
check_balance_binary(y_val)

print("=== Test Set ===")
check_balance_binary(y_test)
# Out:
# === Train Set ===
# Total samples: 52661
# Normal: 24073 (45.71%)
# Attack: 28588 (54.29%)
#
# === Validation Set ===
# Total samples: 22569
# Normal: 10317 (45.71%)
# Attack: 12252 (54.29%)
#
# === Test Set ===
# Total samples: 49472
# Normal: 27375 (55.33%)
# Attack: 22097 (44.67%)

# %%
def tcn_block(x, filters, kernel_size, dilation):
    shortcut = x

    x = Conv1D(filters, kernel_size,
               padding="causal",
               dilation_rate=dilation)(x)
    x = BatchNormalization()(x)
    x = ReLU()(x)

    x = Conv1D(filters, kernel_size,
               padding="causal",
               dilation_rate=dilation)(x)
    x = BatchNormalization()(x)

    if shortcut.shape[-1] != filters:
        shortcut = Conv1D(filters, 1, padding="same")(shortcut)

    x = Add()([x, shortcut])
    x = ReLU()(x)
    return x

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, Dropout, MaxPooling1D, Flatten, Dense

def build_mr_tcn(input_shape=(64, 64), dropout_rate=0.55):
    model = Sequential()

    # Conv1D #1
    model.add(Conv1D(
        filters=64,
        kernel_size=3,
        strides=1,
        dilation_rate=1,
        padding="same",
        activation="relu",
        input_shape=input_shape
    ))
    model.add(Dropout(dropout_rate))

    # Conv1D #2
    model.add(Conv1D(
        filters=64,
        kernel_size=3,
        strides=1,
        dilation_rate=2,
        padding="same",
        activation="relu"
    ))
    model.add(Dropout(dropout_rate))

    # Conv1D #3
    model.add(Conv1D(
        filters=64,
        kernel_size=3,
        strides=1,
        dilation_rate=4,
        padding="same",
        activation="relu"
    ))
    model.add(Dropout(dropout_rate))

    # MaxPooling
    model.add(MaxPooling1D(pool_size=8, strides=8))

    # Flatten
    model.add(Flatten())

    # Dropout
    model.add(Dropout(dropout_rate))

    # Linear → Sigmoid
    model.add(Dense(1, activation="sigmoid"))

    return model

# %%
model = build_mr_tcn()

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-5),
    loss="binary_crossentropy",
    metrics=["accuracy"]
)

model.summary()
# Out:
# /home/dani/miniconda3/envs/latihan1/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# I0000 00:00:1775656889.599795  117533 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 4144 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d (Conv1D)                 │ (None, 64, 64)         │        12,352 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_1 (Conv1D)               │ (None, 64, 64)         │        12,352 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 64, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_2 (Conv1D)               │ (None, 64, 64)         │        12,352 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 64, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d (MaxPooling1D)    │ (None, 8, 64)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │           513 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 37,569 (146.75 KB)
#  Trainable params: 37,569 (146.75 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

early_stop = EarlyStopping(
    monitor="val_loss",
    patience=30,
    restore_best_weights=True
)

checkpoint = ModelCheckpoint(
    "best_mr_tcn.keras",
    monitor="val_loss",
    save_best_only=True,
    verbose=1
)

# %%
history = model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=700,
    batch_size=64,
    callbacks=[early_stop, checkpoint]
)
# Out:
# Epoch 1/700
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1775656891.540253  117681 service.cc:152] XLA service 0x7be09c00b660 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1775656891.540273  117681 service.cc:160]   StreamExecutor device (0): NVIDIA GeForce RTX 3060 Laptop GPU, Compute Capability 8.6
# 2026-04-08 21:01:31.573217: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1775656891.732461  117681 cuda_dnn.cc:529] Loaded cuDNN version 91701
#  86/823 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - accuracy: 0.5189 - loss: 1.3493
# I0000 00:00:1775656893.501125  117681 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - accuracy: 0.5083 - loss: 1.1663
# Epoch 1: val_loss improved from None to 0.69957, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 7s 5ms/step - accuracy: 0.5045 - loss: 1.0467 - val_accuracy: 0.4650 - val_loss: 0.6996
# Epoch 2/700
# 800/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5086 - loss: 0.8562
# Epoch 2: val_loss improved from 0.69957 to 0.69328, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.5091 - loss: 0.8298 - val_accuracy: 0.4956 - val_loss: 0.6933
# Epoch 3/700
# 802/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5178 - loss: 0.7659
# Epoch 3: val_loss improved from 0.69328 to 0.69088, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.5156 - loss: 0.7585 - val_accuracy: 0.5403 - val_loss: 0.6909
# Epoch 4/700
# 810/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5208 - loss: 0.7363
# Epoch 4: val_loss improved from 0.69088 to 0.68939, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.5205 - loss: 0.7310 - val_accuracy: 0.5800 - val_loss: 0.6894
# Epoch 5/700
# 797/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5266 - loss: 0.7168
# Epoch 5: val_loss improved from 0.68939 to 0.68822, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.5269 - loss: 0.7126 - val_accuracy: 0.6160 - val_loss: 0.6882
# Epoch 6/700
# 802/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5354 - loss: 0.7023
# Epoch 6: val_loss improved from 0.68822 to 0.68664, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.5386 - loss: 0.6998 - val_accuracy: 0.6515 - val_loss: 0.6866
# Epoch 7/700
# 806/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5470 - loss: 0.6904
# Epoch 7: val_loss improved from 0.68664 to 0.68472, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.5497 - loss: 0.6878 - val_accuracy: 0.6773 - val_loss: 0.6847
# Epoch 8/700
# 797/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5584 - loss: 0.6823
# Epoch 8: val_loss improved from 0.68472 to 0.68270, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.5602 - loss: 0.6803 - val_accuracy: 0.7017 - val_loss: 0.6827
# Epoch 9/700
# 815/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5694 - loss: 0.6744
# Epoch 9: val_loss improved from 0.68270 to 0.67974, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.5760 - loss: 0.6713 - val_accuracy: 0.7189 - val_loss: 0.6797
# Epoch 10/700
# 797/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5801 - loss: 0.6654
# Epoch 10: val_loss improved from 0.67974 to 0.67589, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.5868 - loss: 0.6610 - val_accuracy: 0.7519 - val_loss: 0.6759
# Epoch 11/700
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5993 - loss: 0.6551
# Epoch 11: val_loss improved from 0.67589 to 0.67021, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.6089 - loss: 0.6493 - val_accuracy: 0.7661 - val_loss: 0.6702
# Epoch 12/700
# 802/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6240 - loss: 0.6383
# Epoch 12: val_loss improved from 0.67021 to 0.66328, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.6312 - loss: 0.6340 - val_accuracy: 0.7882 - val_loss: 0.6633
# Epoch 13/700
# 820/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6422 - loss: 0.6215
# Epoch 13: val_loss improved from 0.66328 to 0.65539, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.6500 - loss: 0.6174 - val_accuracy: 0.8046 - val_loss: 0.6554
# Epoch 14/700
# 816/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6742 - loss: 0.6014
# Epoch 14: val_loss improved from 0.65539 to 0.64408, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.6820 - loss: 0.5949 - val_accuracy: 0.8093 - val_loss: 0.6441
# Epoch 15/700
# 795/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6973 - loss: 0.5803
# Epoch 15: val_loss improved from 0.64408 to 0.63204, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7012 - loss: 0.5757 - val_accuracy: 0.8125 - val_loss: 0.6320
# Epoch 16/700
# 812/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7173 - loss: 0.5606
# Epoch 16: val_loss improved from 0.63204 to 0.61867, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7213 - loss: 0.5546 - val_accuracy: 0.8164 - val_loss: 0.6187
# Epoch 17/700
# 815/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7319 - loss: 0.5405
# Epoch 17: val_loss improved from 0.61867 to 0.60534, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7383 - loss: 0.5350 - val_accuracy: 0.8207 - val_loss: 0.6053
# Epoch 18/700
# 803/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7496 - loss: 0.5237
# Epoch 18: val_loss improved from 0.60534 to 0.59133, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7548 - loss: 0.5163 - val_accuracy: 0.8279 - val_loss: 0.5913
# Epoch 19/700
# 798/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7592 - loss: 0.5085
# Epoch 19: val_loss improved from 0.59133 to 0.58085, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7649 - loss: 0.5019 - val_accuracy: 0.8305 - val_loss: 0.5809
# Epoch 20/700
# 816/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7722 - loss: 0.4921
# Epoch 20: val_loss improved from 0.58085 to 0.57018, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7743 - loss: 0.4886 - val_accuracy: 0.8365 - val_loss: 0.5702
# Epoch 21/700
# 806/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7813 - loss: 0.4799
# Epoch 21: val_loss improved from 0.57018 to 0.55954, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7827 - loss: 0.4776 - val_accuracy: 0.8445 - val_loss: 0.5595
# Epoch 22/700
# 795/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7938 - loss: 0.4631
# Epoch 22: val_loss improved from 0.55954 to 0.55068, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7932 - loss: 0.4633 - val_accuracy: 0.8473 - val_loss: 0.5507
# Epoch 23/700
# 805/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7948 - loss: 0.4630
# Epoch 23: val_loss improved from 0.55068 to 0.54441, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.7976 - loss: 0.4591 - val_accuracy: 0.8488 - val_loss: 0.5444
# Epoch 24/700
# 808/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8028 - loss: 0.4506
# Epoch 24: val_loss improved from 0.54441 to 0.53623, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8031 - loss: 0.4495 - val_accuracy: 0.8543 - val_loss: 0.5362
# Epoch 25/700
# 811/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8057 - loss: 0.4428
# Epoch 25: val_loss improved from 0.53623 to 0.52924, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8064 - loss: 0.4418 - val_accuracy: 0.8571 - val_loss: 0.5292
# Epoch 26/700
# 817/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8100 - loss: 0.4393
# Epoch 26: val_loss improved from 0.52924 to 0.52221, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8114 - loss: 0.4367 - val_accuracy: 0.8607 - val_loss: 0.5222
# Epoch 27/700
# 801/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8144 - loss: 0.4321
# Epoch 27: val_loss improved from 0.52221 to 0.51846, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8156 - loss: 0.4302 - val_accuracy: 0.8612 - val_loss: 0.5185
# Epoch 28/700
# 820/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8160 - loss: 0.4241
# Epoch 28: val_loss improved from 0.51846 to 0.51163, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8185 - loss: 0.4226 - val_accuracy: 0.8653 - val_loss: 0.5116
# Epoch 29/700
# 813/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8195 - loss: 0.4228
# Epoch 29: val_loss improved from 0.51163 to 0.50705, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8219 - loss: 0.4181 - val_accuracy: 0.8679 - val_loss: 0.5071
# Epoch 30/700
# 796/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8232 - loss: 0.4135
# Epoch 30: val_loss improved from 0.50705 to 0.50256, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8236 - loss: 0.4130 - val_accuracy: 0.8687 - val_loss: 0.5026
# Epoch 31/700
# 813/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8255 - loss: 0.4074
# Epoch 31: val_loss improved from 0.50256 to 0.49634, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8291 - loss: 0.4035 - val_accuracy: 0.8722 - val_loss: 0.4963
# Epoch 32/700
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8270 - loss: 0.4045
# Epoch 32: val_loss improved from 0.49634 to 0.49248, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8285 - loss: 0.4032 - val_accuracy: 0.8748 - val_loss: 0.4925
# Epoch 33/700
# 806/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8306 - loss: 0.3991
# Epoch 33: val_loss improved from 0.49248 to 0.48927, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8335 - loss: 0.3958 - val_accuracy: 0.8756 - val_loss: 0.4893
# Epoch 34/700
# 812/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8354 - loss: 0.3930
# Epoch 34: val_loss improved from 0.48927 to 0.48396, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8355 - loss: 0.3910 - val_accuracy: 0.8782 - val_loss: 0.4840
# Epoch 35/700
# 816/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8362 - loss: 0.3890
# Epoch 35: val_loss improved from 0.48396 to 0.47829, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8360 - loss: 0.3875 - val_accuracy: 0.8817 - val_loss: 0.4783
# Epoch 36/700
# 803/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8354 - loss: 0.3890
# Epoch 36: val_loss improved from 0.47829 to 0.47561, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8376 - loss: 0.3843 - val_accuracy: 0.8805 - val_loss: 0.4756
# Epoch 37/700
# 801/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8394 - loss: 0.3779
# Epoch 37: val_loss improved from 0.47561 to 0.47223, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8404 - loss: 0.3782 - val_accuracy: 0.8820 - val_loss: 0.4722
# Epoch 38/700
# 819/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8444 - loss: 0.3763
# Epoch 38: val_loss improved from 0.47223 to 0.46614, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8443 - loss: 0.3741 - val_accuracy: 0.8867 - val_loss: 0.4661
# Epoch 39/700
# 808/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8471 - loss: 0.3675
# Epoch 39: val_loss improved from 0.46614 to 0.46188, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8467 - loss: 0.3681 - val_accuracy: 0.8881 - val_loss: 0.4619
# Epoch 40/700
# 808/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8456 - loss: 0.3686
# Epoch 40: val_loss improved from 0.46188 to 0.46010, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8449 - loss: 0.3689 - val_accuracy: 0.8886 - val_loss: 0.4601
# Epoch 41/700
# 809/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8486 - loss: 0.3677
# Epoch 41: val_loss improved from 0.46010 to 0.45491, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8489 - loss: 0.3630 - val_accuracy: 0.8918 - val_loss: 0.4549
# Epoch 42/700
# 805/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8520 - loss: 0.3616
# Epoch 42: val_loss improved from 0.45491 to 0.45185, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8518 - loss: 0.3586 - val_accuracy: 0.8912 - val_loss: 0.4519
# Epoch 43/700
# 808/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8507 - loss: 0.3564
# Epoch 43: val_loss improved from 0.45185 to 0.44974, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8495 - loss: 0.3580 - val_accuracy: 0.8916 - val_loss: 0.4497
# Epoch 44/700
# 800/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8491 - loss: 0.3552
# Epoch 44: val_loss improved from 0.44974 to 0.44579, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8530 - loss: 0.3519 - val_accuracy: 0.8931 - val_loss: 0.4458
# Epoch 45/700
# 803/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8528 - loss: 0.3505
# Epoch 45: val_loss improved from 0.44579 to 0.43981, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8549 - loss: 0.3490 - val_accuracy: 0.8962 - val_loss: 0.4398
# Epoch 46/700
# 820/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8546 - loss: 0.3462
# Epoch 46: val_loss improved from 0.43981 to 0.43907, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8559 - loss: 0.3453 - val_accuracy: 0.8954 - val_loss: 0.4391
# Epoch 47/700
# 801/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8577 - loss: 0.3449
# Epoch 47: val_loss improved from 0.43907 to 0.43445, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8581 - loss: 0.3433 - val_accuracy: 0.8965 - val_loss: 0.4345
# Epoch 48/700
# 810/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8544 - loss: 0.3445
# Epoch 48: val_loss improved from 0.43445 to 0.43435, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8573 - loss: 0.3422 - val_accuracy: 0.8956 - val_loss: 0.4344
# Epoch 49/700
# 795/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8574 - loss: 0.3411
# Epoch 49: val_loss improved from 0.43435 to 0.43040, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8602 - loss: 0.3379 - val_accuracy: 0.8970 - val_loss: 0.4304
# Epoch 50/700
# 816/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8662 - loss: 0.3287
# Epoch 50: val_loss improved from 0.43040 to 0.42656, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8622 - loss: 0.3323 - val_accuracy: 0.8983 - val_loss: 0.4266
# Epoch 51/700
# 816/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8608 - loss: 0.3357
# Epoch 51: val_loss improved from 0.42656 to 0.42417, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8615 - loss: 0.3332 - val_accuracy: 0.8992 - val_loss: 0.4242
# Epoch 52/700
# 816/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8599 - loss: 0.3342
# Epoch 52: val_loss improved from 0.42417 to 0.42110, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8629 - loss: 0.3306 - val_accuracy: 0.8996 - val_loss: 0.4211
# Epoch 53/700
# 817/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8616 - loss: 0.3295
# Epoch 53: val_loss improved from 0.42110 to 0.42019, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8624 - loss: 0.3303 - val_accuracy: 0.8995 - val_loss: 0.4202
# Epoch 54/700
# 809/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8636 - loss: 0.3277
# Epoch 54: val_loss improved from 0.42019 to 0.41660, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8660 - loss: 0.3245 - val_accuracy: 0.9011 - val_loss: 0.4166
# Epoch 55/700
# 807/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8673 - loss: 0.3218
# Epoch 55: val_loss improved from 0.41660 to 0.41520, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8668 - loss: 0.3219 - val_accuracy: 0.9015 - val_loss: 0.4152
# Epoch 56/700
# 798/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8679 - loss: 0.3223
# Epoch 56: val_loss improved from 0.41520 to 0.41263, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8685 - loss: 0.3214 - val_accuracy: 0.9026 - val_loss: 0.4126
# Epoch 57/700
# 813/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8694 - loss: 0.3170
# Epoch 57: val_loss improved from 0.41263 to 0.40926, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8693 - loss: 0.3171 - val_accuracy: 0.9035 - val_loss: 0.4093
# Epoch 58/700
# 819/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8672 - loss: 0.3191
# Epoch 58: val_loss improved from 0.40926 to 0.40765, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8694 - loss: 0.3163 - val_accuracy: 0.9032 - val_loss: 0.4076
# Epoch 59/700
# 822/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8710 - loss: 0.3141
# Epoch 59: val_loss improved from 0.40765 to 0.40554, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8711 - loss: 0.3140 - val_accuracy: 0.9036 - val_loss: 0.4055
# Epoch 60/700
# 800/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8732 - loss: 0.3128
# Epoch 60: val_loss improved from 0.40554 to 0.40434, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8741 - loss: 0.3131 - val_accuracy: 0.9039 - val_loss: 0.4043
# Epoch 61/700
# 816/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8725 - loss: 0.3091
# Epoch 61: val_loss improved from 0.40434 to 0.40161, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8726 - loss: 0.3107 - val_accuracy: 0.9051 - val_loss: 0.4016
# Epoch 62/700
# 808/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8725 - loss: 0.3086
# Epoch 62: val_loss did not improve from 0.40161
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8720 - loss: 0.3087 - val_accuracy: 0.9036 - val_loss: 0.4020
# Epoch 63/700
# 822/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8746 - loss: 0.3059
# Epoch 63: val_loss improved from 0.40161 to 0.39621, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8743 - loss: 0.3061 - val_accuracy: 0.9063 - val_loss: 0.3962
# Epoch 64/700
# 822/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8781 - loss: 0.2979
# Epoch 64: val_loss did not improve from 0.39621
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8753 - loss: 0.3021 - val_accuracy: 0.9046 - val_loss: 0.3964
# Epoch 65/700
# 795/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8717 - loss: 0.3095
# Epoch 65: val_loss improved from 0.39621 to 0.39479, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8743 - loss: 0.3042 - val_accuracy: 0.9053 - val_loss: 0.3948
# Epoch 66/700
# 817/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8791 - loss: 0.2984
# Epoch 66: val_loss improved from 0.39479 to 0.38989, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8779 - loss: 0.2989 - val_accuracy: 0.9074 - val_loss: 0.3899
# Epoch 67/700
# 802/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8789 - loss: 0.2993
# Epoch 67: val_loss improved from 0.38989 to 0.38987, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8780 - loss: 0.2993 - val_accuracy: 0.9069 - val_loss: 0.3899
# Epoch 68/700
# 810/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8765 - loss: 0.3015
# Epoch 68: val_loss improved from 0.38987 to 0.38905, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8771 - loss: 0.2998 - val_accuracy: 0.9065 - val_loss: 0.3891
# Epoch 69/700
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8810 - loss: 0.2915
# Epoch 69: val_loss improved from 0.38905 to 0.38783, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8790 - loss: 0.2962 - val_accuracy: 0.9064 - val_loss: 0.3878
# Epoch 70/700
# 802/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8806 - loss: 0.2936
# Epoch 70: val_loss improved from 0.38783 to 0.38453, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8803 - loss: 0.2946 - val_accuracy: 0.9074 - val_loss: 0.3845
# Epoch 71/700
# 815/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8786 - loss: 0.2941
# Epoch 71: val_loss improved from 0.38453 to 0.38295, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8790 - loss: 0.2944 - val_accuracy: 0.9071 - val_loss: 0.3829
# Epoch 72/700
# 801/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8797 - loss: 0.2950
# Epoch 72: val_loss improved from 0.38295 to 0.38180, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8795 - loss: 0.2930 - val_accuracy: 0.9078 - val_loss: 0.3818
# Epoch 73/700
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8813 - loss: 0.2860
# Epoch 73: val_loss improved from 0.38180 to 0.38027, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8809 - loss: 0.2903 - val_accuracy: 0.9081 - val_loss: 0.3803
# Epoch 74/700
# 821/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8784 - loss: 0.2954
# Epoch 74: val_loss did not improve from 0.38027
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8807 - loss: 0.2929 - val_accuracy: 0.9079 - val_loss: 0.3812
# Epoch 75/700
# 804/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8849 - loss: 0.2875
# Epoch 75: val_loss improved from 0.38027 to 0.37747, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8834 - loss: 0.2869 - val_accuracy: 0.9089 - val_loss: 0.3775
# Epoch 76/700
# 803/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8810 - loss: 0.2915
# Epoch 76: val_loss did not improve from 0.37747
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8822 - loss: 0.2882 - val_accuracy: 0.9064 - val_loss: 0.3793
# Epoch 77/700
# 808/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8815 - loss: 0.2863
# Epoch 77: val_loss improved from 0.37747 to 0.37434, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8833 - loss: 0.2832 - val_accuracy: 0.9085 - val_loss: 0.3743
# Epoch 78/700
# 798/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8835 - loss: 0.2873
# Epoch 78: val_loss did not improve from 0.37434
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8824 - loss: 0.2880 - val_accuracy: 0.9085 - val_loss: 0.3749
# Epoch 79/700
# 822/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8837 - loss: 0.2834
# Epoch 79: val_loss did not improve from 0.37434
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8827 - loss: 0.2858 - val_accuracy: 0.9070 - val_loss: 0.3756
# Epoch 80/700
# 803/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8843 - loss: 0.2824
# Epoch 80: val_loss improved from 0.37434 to 0.37404, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8850 - loss: 0.2821 - val_accuracy: 0.9074 - val_loss: 0.3740
# Epoch 81/700
# 818/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8845 - loss: 0.2836
# Epoch 81: val_loss improved from 0.37404 to 0.37302, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8841 - loss: 0.2834 - val_accuracy: 0.9072 - val_loss: 0.3730
# Epoch 82/700
# 808/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8859 - loss: 0.2846
# Epoch 82: val_loss improved from 0.37302 to 0.36819, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8868 - loss: 0.2802 - val_accuracy: 0.9091 - val_loss: 0.3682
# Epoch 83/700
# 800/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8902 - loss: 0.2773
# Epoch 83: val_loss did not improve from 0.36819
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8866 - loss: 0.2798 - val_accuracy: 0.9080 - val_loss: 0.3689
# Epoch 84/700
# 818/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8876 - loss: 0.2757
# Epoch 84: val_loss improved from 0.36819 to 0.36522, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8874 - loss: 0.2777 - val_accuracy: 0.9092 - val_loss: 0.3652
# Epoch 85/700
# 821/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8865 - loss: 0.2771
# Epoch 85: val_loss did not improve from 0.36522
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8872 - loss: 0.2754 - val_accuracy: 0.9082 - val_loss: 0.3658
# Epoch 86/700
# 822/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8857 - loss: 0.2765
# Epoch 86: val_loss improved from 0.36522 to 0.36399, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8873 - loss: 0.2766 - val_accuracy: 0.9087 - val_loss: 0.3640
# Epoch 87/700
# 807/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8875 - loss: 0.2747
# Epoch 87: val_loss improved from 0.36399 to 0.36146, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8873 - loss: 0.2734 - val_accuracy: 0.9090 - val_loss: 0.3615
# Epoch 88/700
# 816/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8872 - loss: 0.2771
# Epoch 88: val_loss did not improve from 0.36146
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8878 - loss: 0.2759 - val_accuracy: 0.9087 - val_loss: 0.3622
# Epoch 89/700
# 807/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8891 - loss: 0.2767
# Epoch 89: val_loss did not improve from 0.36146
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8892 - loss: 0.2752 - val_accuracy: 0.9081 - val_loss: 0.3631
# Epoch 90/700
# 815/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8909 - loss: 0.2682
# Epoch 90: val_loss improved from 0.36146 to 0.35933, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8906 - loss: 0.2688 - val_accuracy: 0.9086 - val_loss: 0.3593
# Epoch 91/700
# 817/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8902 - loss: 0.2673
# Epoch 91: val_loss improved from 0.35933 to 0.35663, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8894 - loss: 0.2728 - val_accuracy: 0.9101 - val_loss: 0.3566
# Epoch 92/700
# 803/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8894 - loss: 0.2685
# Epoch 92: val_loss did not improve from 0.35663
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8888 - loss: 0.2712 - val_accuracy: 0.9088 - val_loss: 0.3587
# Epoch 93/700
# 817/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8880 - loss: 0.2725
# Epoch 93: val_loss did not improve from 0.35663
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8889 - loss: 0.2702 - val_accuracy: 0.9063 - val_loss: 0.3616
# Epoch 94/700
# 799/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8879 - loss: 0.2756
# Epoch 94: val_loss did not improve from 0.35663
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8908 - loss: 0.2693 - val_accuracy: 0.9080 - val_loss: 0.3580
# Epoch 95/700
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8881 - loss: 0.2707
# Epoch 95: val_loss improved from 0.35663 to 0.35548, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8906 - loss: 0.2684 - val_accuracy: 0.9086 - val_loss: 0.3555
# Epoch 96/700
# 804/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8944 - loss: 0.2609
# Epoch 96: val_loss improved from 0.35548 to 0.35424, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8920 - loss: 0.2667 - val_accuracy: 0.9093 - val_loss: 0.3542
# Epoch 97/700
# 809/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8941 - loss: 0.2644
# Epoch 97: val_loss did not improve from 0.35424
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8923 - loss: 0.2662 - val_accuracy: 0.9081 - val_loss: 0.3552
# Epoch 98/700
# 797/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8926 - loss: 0.2633
# Epoch 98: val_loss improved from 0.35424 to 0.34986, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8938 - loss: 0.2615 - val_accuracy: 0.9098 - val_loss: 0.3499
# Epoch 99/700
# 795/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8965 - loss: 0.2614
# Epoch 99: val_loss did not improve from 0.34986
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8950 - loss: 0.2633 - val_accuracy: 0.9085 - val_loss: 0.3516
# Epoch 100/700
# 811/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8901 - loss: 0.2677
# Epoch 100: val_loss did not improve from 0.34986
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8917 - loss: 0.2659 - val_accuracy: 0.9094 - val_loss: 0.3502
# Epoch 101/700
# 798/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8934 - loss: 0.2603
# Epoch 101: val_loss did not improve from 0.34986
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8943 - loss: 0.2599 - val_accuracy: 0.9093 - val_loss: 0.3502
# Epoch 102/700
# 821/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8961 - loss: 0.2575
# Epoch 102: val_loss did not improve from 0.34986
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8949 - loss: 0.2625 - val_accuracy: 0.9086 - val_loss: 0.3519
# Epoch 103/700
# 811/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8965 - loss: 0.2613
# Epoch 103: val_loss improved from 0.34986 to 0.34985, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8962 - loss: 0.2600 - val_accuracy: 0.9087 - val_loss: 0.3499
# Epoch 104/700
# 820/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8934 - loss: 0.2604
# Epoch 104: val_loss improved from 0.34985 to 0.34872, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8931 - loss: 0.2616 - val_accuracy: 0.9095 - val_loss: 0.3487
# Epoch 105/700
# 798/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8933 - loss: 0.2618
# Epoch 105: val_loss improved from 0.34872 to 0.34861, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8944 - loss: 0.2605 - val_accuracy: 0.9090 - val_loss: 0.3486
# Epoch 106/700
# 822/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8955 - loss: 0.2547
# Epoch 106: val_loss improved from 0.34861 to 0.34759, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8941 - loss: 0.2593 - val_accuracy: 0.9093 - val_loss: 0.3476
# Epoch 107/700
# 814/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8986 - loss: 0.2547
# Epoch 107: val_loss did not improve from 0.34759
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8956 - loss: 0.2580 - val_accuracy: 0.9081 - val_loss: 0.3481
# Epoch 108/700
# 795/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8957 - loss: 0.2586
# Epoch 108: val_loss improved from 0.34759 to 0.34687, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8955 - loss: 0.2578 - val_accuracy: 0.9085 - val_loss: 0.3469
# Epoch 109/700
# 803/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8978 - loss: 0.2548
# Epoch 109: val_loss improved from 0.34687 to 0.34258, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8979 - loss: 0.2553 - val_accuracy: 0.9102 - val_loss: 0.3426
# Epoch 110/700
# 796/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8983 - loss: 0.2545
# Epoch 110: val_loss did not improve from 0.34258
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8969 - loss: 0.2564 - val_accuracy: 0.9076 - val_loss: 0.3451
# Epoch 111/700
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8986 - loss: 0.2514
# Epoch 111: val_loss did not improve from 0.34258
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8968 - loss: 0.2556 - val_accuracy: 0.9085 - val_loss: 0.3442
# Epoch 112/700
# 813/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8976 - loss: 0.2554
# Epoch 112: val_loss improved from 0.34258 to 0.34113, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8969 - loss: 0.2550 - val_accuracy: 0.9104 - val_loss: 0.3411
# Epoch 113/700
# 819/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8998 - loss: 0.2489
# Epoch 113: val_loss did not improve from 0.34113
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8979 - loss: 0.2524 - val_accuracy: 0.9091 - val_loss: 0.3416
# Epoch 114/700
# 818/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8960 - loss: 0.2549
# Epoch 114: val_loss improved from 0.34113 to 0.33906, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8978 - loss: 0.2542 - val_accuracy: 0.9105 - val_loss: 0.3391
# Epoch 115/700
# 815/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8976 - loss: 0.2543
# Epoch 115: val_loss did not improve from 0.33906
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8978 - loss: 0.2532 - val_accuracy: 0.9074 - val_loss: 0.3423
# Epoch 116/700
# 816/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8983 - loss: 0.2512
# Epoch 116: val_loss did not improve from 0.33906
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8976 - loss: 0.2527 - val_accuracy: 0.9090 - val_loss: 0.3398
# Epoch 117/700
# 814/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8991 - loss: 0.2469
# Epoch 117: val_loss improved from 0.33906 to 0.33859, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8976 - loss: 0.2509 - val_accuracy: 0.9096 - val_loss: 0.3386
# Epoch 118/700
# 807/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8996 - loss: 0.2495
# Epoch 118: val_loss improved from 0.33859 to 0.33803, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8983 - loss: 0.2513 - val_accuracy: 0.9098 - val_loss: 0.3380
# Epoch 119/700
# 821/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9001 - loss: 0.2488
# Epoch 119: val_loss improved from 0.33803 to 0.33799, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8995 - loss: 0.2509 - val_accuracy: 0.9093 - val_loss: 0.3380
# Epoch 120/700
# 800/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9005 - loss: 0.2481
# Epoch 120: val_loss improved from 0.33799 to 0.33614, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8986 - loss: 0.2502 - val_accuracy: 0.9107 - val_loss: 0.3361
# Epoch 121/700
# 820/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8999 - loss: 0.2484
# Epoch 121: val_loss did not improve from 0.33614
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8989 - loss: 0.2501 - val_accuracy: 0.9085 - val_loss: 0.3387
# Epoch 122/700
# 811/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9009 - loss: 0.2471
# Epoch 122: val_loss did not improve from 0.33614
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8998 - loss: 0.2480 - val_accuracy: 0.9087 - val_loss: 0.3363
# Epoch 123/700
# 796/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9019 - loss: 0.2470
# Epoch 123: val_loss improved from 0.33614 to 0.33600, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9022 - loss: 0.2464 - val_accuracy: 0.9078 - val_loss: 0.3360
# Epoch 124/700
# 803/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8996 - loss: 0.2488
# Epoch 124: val_loss improved from 0.33600 to 0.33252, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9005 - loss: 0.2473 - val_accuracy: 0.9105 - val_loss: 0.3325
# Epoch 125/700
# 822/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8993 - loss: 0.2511
# Epoch 125: val_loss did not improve from 0.33252
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.8998 - loss: 0.2477 - val_accuracy: 0.9090 - val_loss: 0.3347
# Epoch 126/700
# 820/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9012 - loss: 0.2443
# Epoch 126: val_loss did not improve from 0.33252
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9006 - loss: 0.2460 - val_accuracy: 0.9100 - val_loss: 0.3332
# Epoch 127/700
# 801/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9010 - loss: 0.2425
# Epoch 127: val_loss improved from 0.33252 to 0.33228, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9007 - loss: 0.2444 - val_accuracy: 0.9093 - val_loss: 0.3323
# Epoch 128/700
# 808/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9015 - loss: 0.2416
# Epoch 128: val_loss improved from 0.33228 to 0.33124, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9014 - loss: 0.2446 - val_accuracy: 0.9095 - val_loss: 0.3312
# Epoch 129/700
# 811/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9036 - loss: 0.2426
# Epoch 129: val_loss improved from 0.33124 to 0.32996, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9023 - loss: 0.2446 - val_accuracy: 0.9094 - val_loss: 0.3300
# Epoch 130/700
# 815/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9012 - loss: 0.2461
# Epoch 130: val_loss improved from 0.32996 to 0.32917, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9011 - loss: 0.2446 - val_accuracy: 0.9106 - val_loss: 0.3292
# Epoch 131/700
# 797/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9029 - loss: 0.2434
# Epoch 131: val_loss improved from 0.32917 to 0.32831, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9017 - loss: 0.2445 - val_accuracy: 0.9105 - val_loss: 0.3283
# Epoch 132/700
# 818/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9027 - loss: 0.2465
# Epoch 132: val_loss improved from 0.32831 to 0.32818, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9032 - loss: 0.2434 - val_accuracy: 0.9105 - val_loss: 0.3282
# Epoch 133/700
# 798/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9017 - loss: 0.2426
# Epoch 133: val_loss improved from 0.32818 to 0.32816, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9030 - loss: 0.2407 - val_accuracy: 0.9099 - val_loss: 0.3282
# Epoch 134/700
# 802/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9013 - loss: 0.2403
# Epoch 134: val_loss did not improve from 0.32816
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9018 - loss: 0.2421 - val_accuracy: 0.9100 - val_loss: 0.3294
# Epoch 135/700
# 816/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9030 - loss: 0.2407
# Epoch 135: val_loss improved from 0.32816 to 0.32769, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9031 - loss: 0.2396 - val_accuracy: 0.9105 - val_loss: 0.3277
# Epoch 136/700
# 807/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9039 - loss: 0.2371
# Epoch 136: val_loss improved from 0.32769 to 0.32679, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9036 - loss: 0.2411 - val_accuracy: 0.9109 - val_loss: 0.3268
# Epoch 137/700
# 797/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9040 - loss: 0.2408
# Epoch 137: val_loss improved from 0.32679 to 0.32597, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9030 - loss: 0.2411 - val_accuracy: 0.9110 - val_loss: 0.3260
# Epoch 138/700
# 821/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9037 - loss: 0.2405
# Epoch 138: val_loss did not improve from 0.32597
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9041 - loss: 0.2397 - val_accuracy: 0.9103 - val_loss: 0.3263
# Epoch 139/700
# 806/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9045 - loss: 0.2399
# Epoch 139: val_loss improved from 0.32597 to 0.32475, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9037 - loss: 0.2394 - val_accuracy: 0.9105 - val_loss: 0.3248
# Epoch 140/700
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9055 - loss: 0.2377
# Epoch 140: val_loss improved from 0.32475 to 0.32315, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9040 - loss: 0.2371 - val_accuracy: 0.9111 - val_loss: 0.3232
# Epoch 141/700
# 821/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9054 - loss: 0.2377
# Epoch 141: val_loss did not improve from 0.32315
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9044 - loss: 0.2387 - val_accuracy: 0.9102 - val_loss: 0.3244
# Epoch 142/700
# 809/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9054 - loss: 0.2364
# Epoch 142: val_loss improved from 0.32315 to 0.32251, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9045 - loss: 0.2372 - val_accuracy: 0.9111 - val_loss: 0.3225
# Epoch 143/700
# 802/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9026 - loss: 0.2402
# Epoch 143: val_loss did not improve from 0.32251
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9038 - loss: 0.2376 - val_accuracy: 0.9088 - val_loss: 0.3252
# Epoch 144/700
# 819/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9057 - loss: 0.2346
# Epoch 144: val_loss did not improve from 0.32251
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9051 - loss: 0.2344 - val_accuracy: 0.9094 - val_loss: 0.3232
# Epoch 145/700
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9033 - loss: 0.2404
# Epoch 145: val_loss improved from 0.32251 to 0.32211, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9048 - loss: 0.2375 - val_accuracy: 0.9102 - val_loss: 0.3221
# Epoch 146/700
# 800/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9046 - loss: 0.2364
# Epoch 146: val_loss did not improve from 0.32211
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9049 - loss: 0.2367 - val_accuracy: 0.9094 - val_loss: 0.3238
# Epoch 147/700
# 809/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9048 - loss: 0.2358
# Epoch 147: val_loss improved from 0.32211 to 0.32011, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9050 - loss: 0.2349 - val_accuracy: 0.9116 - val_loss: 0.3201
# Epoch 148/700
# 799/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9040 - loss: 0.2394
# Epoch 148: val_loss did not improve from 0.32011
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9057 - loss: 0.2355 - val_accuracy: 0.9106 - val_loss: 0.3207
# Epoch 149/700
# 814/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9056 - loss: 0.2354
# Epoch 149: val_loss improved from 0.32011 to 0.31992, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9054 - loss: 0.2352 - val_accuracy: 0.9116 - val_loss: 0.3199
# Epoch 150/700
# 802/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9056 - loss: 0.2328
# Epoch 150: val_loss did not improve from 0.31992
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9060 - loss: 0.2339 - val_accuracy: 0.9100 - val_loss: 0.3209
# Epoch 151/700
# 808/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9059 - loss: 0.2373
# Epoch 151: val_loss improved from 0.31992 to 0.31935, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9060 - loss: 0.2343 - val_accuracy: 0.9107 - val_loss: 0.3193
# Epoch 152/700
# 814/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9088 - loss: 0.2274
# Epoch 152: val_loss improved from 0.31935 to 0.31928, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9066 - loss: 0.2329 - val_accuracy: 0.9105 - val_loss: 0.3193
# Epoch 153/700
# 795/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9073 - loss: 0.2327
# Epoch 153: val_loss did not improve from 0.31928
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9077 - loss: 0.2326 - val_accuracy: 0.9098 - val_loss: 0.3193
# Epoch 154/700
# 812/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9076 - loss: 0.2336
# Epoch 154: val_loss improved from 0.31928 to 0.31839, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9055 - loss: 0.2329 - val_accuracy: 0.9104 - val_loss: 0.3184
# Epoch 155/700
# 794/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9024 - loss: 0.2351
# Epoch 155: val_loss improved from 0.31839 to 0.31682, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9061 - loss: 0.2318 - val_accuracy: 0.9109 - val_loss: 0.3168
# Epoch 156/700
# 817/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9080 - loss: 0.2305
# Epoch 156: val_loss did not improve from 0.31682
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9067 - loss: 0.2329 - val_accuracy: 0.9112 - val_loss: 0.3171
# Epoch 157/700
# 796/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9092 - loss: 0.2300
# Epoch 157: val_loss improved from 0.31682 to 0.31615, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9086 - loss: 0.2287 - val_accuracy: 0.9102 - val_loss: 0.3162
# Epoch 158/700
# 820/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9070 - loss: 0.2308
# Epoch 158: val_loss improved from 0.31615 to 0.31493, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9077 - loss: 0.2295 - val_accuracy: 0.9116 - val_loss: 0.3149
# Epoch 159/700
# 817/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9091 - loss: 0.2291
# Epoch 159: val_loss did not improve from 0.31493
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9086 - loss: 0.2296 - val_accuracy: 0.9105 - val_loss: 0.3149
# Epoch 160/700
# 795/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9057 - loss: 0.2333
# Epoch 160: val_loss did not improve from 0.31493
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9068 - loss: 0.2314 - val_accuracy: 0.9102 - val_loss: 0.3167
# Epoch 161/700
# 798/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9088 - loss: 0.2281
# Epoch 161: val_loss improved from 0.31493 to 0.31406, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9083 - loss: 0.2294 - val_accuracy: 0.9125 - val_loss: 0.3141
# Epoch 162/700
# 820/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9087 - loss: 0.2311
# Epoch 162: val_loss did not improve from 0.31406
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9079 - loss: 0.2304 - val_accuracy: 0.9126 - val_loss: 0.3146
# Epoch 163/700
# 797/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9103 - loss: 0.2274
# Epoch 163: val_loss improved from 0.31406 to 0.31369, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9090 - loss: 0.2286 - val_accuracy: 0.9125 - val_loss: 0.3137
# Epoch 164/700
# 816/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9076 - loss: 0.2272
# Epoch 164: val_loss did not improve from 0.31369
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9077 - loss: 0.2284 - val_accuracy: 0.9104 - val_loss: 0.3175
# Epoch 165/700
# 798/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9084 - loss: 0.2296
# Epoch 165: val_loss did not improve from 0.31369
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9079 - loss: 0.2296 - val_accuracy: 0.9122 - val_loss: 0.3146
# Epoch 166/700
# 822/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9103 - loss: 0.2241
# Epoch 166: val_loss improved from 0.31369 to 0.31300, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9094 - loss: 0.2264 - val_accuracy: 0.9122 - val_loss: 0.3130
# Epoch 167/700
# 802/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9062 - loss: 0.2312
# Epoch 167: val_loss improved from 0.31300 to 0.31126, saving model to best_mr_tcn.keras
# ...
# Epoch 641/700
# 799/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9445 - loss: 0.1413
# Epoch 641: val_loss improved from 0.20484 to 0.20484, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9437 - loss: 0.1423 - val_accuracy: 0.9420 - val_loss: 0.2048
# Epoch 642/700
# 801/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9438 - loss: 0.1419
# Epoch 642: val_loss improved from 0.20484 to 0.20442, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9441 - loss: 0.1423 - val_accuracy: 0.9422 - val_loss: 0.2044
# Epoch 643/700
# 819/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9460 - loss: 0.1382
# Epoch 643: val_loss did not improve from 0.20442
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9452 - loss: 0.1407 - val_accuracy: 0.9425 - val_loss: 0.2052
# Epoch 644/700
# 814/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9458 - loss: 0.1391
# Epoch 644: val_loss did not improve from 0.20442
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9446 - loss: 0.1420 - val_accuracy: 0.9412 - val_loss: 0.2055
# Epoch 645/700
# 811/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9436 - loss: 0.1402
# Epoch 645: val_loss did not improve from 0.20442
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9450 - loss: 0.1393 - val_accuracy: 0.9416 - val_loss: 0.2045
# Epoch 646/700
# 798/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9436 - loss: 0.1447
# Epoch 646: val_loss improved from 0.20442 to 0.20351, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9443 - loss: 0.1419 - val_accuracy: 0.9429 - val_loss: 0.2035
# Epoch 647/700
# 813/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9444 - loss: 0.1394
# Epoch 647: val_loss improved from 0.20351 to 0.20341, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9447 - loss: 0.1393 - val_accuracy: 0.9421 - val_loss: 0.2034
# Epoch 648/700
# 817/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9439 - loss: 0.1434
# Epoch 648: val_loss improved from 0.20341 to 0.20311, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9451 - loss: 0.1418 - val_accuracy: 0.9436 - val_loss: 0.2031
# Epoch 649/700
# 820/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9450 - loss: 0.1386
# Epoch 649: val_loss did not improve from 0.20311
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9441 - loss: 0.1412 - val_accuracy: 0.9418 - val_loss: 0.2050
# Epoch 650/700
# 820/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9463 - loss: 0.1397
# Epoch 650: val_loss did not improve from 0.20311
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9457 - loss: 0.1396 - val_accuracy: 0.9410 - val_loss: 0.2052
# Epoch 651/700
# 797/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9467 - loss: 0.1374
# Epoch 651: val_loss did not improve from 0.20311
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9450 - loss: 0.1393 - val_accuracy: 0.9418 - val_loss: 0.2038
# Epoch 652/700
# 808/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9434 - loss: 0.1438
# Epoch 652: val_loss did not improve from 0.20311
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9440 - loss: 0.1420 - val_accuracy: 0.9428 - val_loss: 0.2033
# Epoch 653/700
# 820/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9438 - loss: 0.1382
# Epoch 653: val_loss did not improve from 0.20311
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9442 - loss: 0.1404 - val_accuracy: 0.9426 - val_loss: 0.2037
# Epoch 654/700
# 795/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9450 - loss: 0.1416
# Epoch 654: val_loss did not improve from 0.20311
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9459 - loss: 0.1406 - val_accuracy: 0.9420 - val_loss: 0.2038
# Epoch 655/700
# 822/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9478 - loss: 0.1367
# Epoch 655: val_loss improved from 0.20311 to 0.20290, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9470 - loss: 0.1382 - val_accuracy: 0.9428 - val_loss: 0.2029
# Epoch 656/700
# 821/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9422 - loss: 0.1437
# Epoch 656: val_loss did not improve from 0.20290
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9440 - loss: 0.1403 - val_accuracy: 0.9421 - val_loss: 0.2039
# Epoch 657/700
# 822/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9465 - loss: 0.1386
# Epoch 657: val_loss did not improve from 0.20290
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9453 - loss: 0.1407 - val_accuracy: 0.9430 - val_loss: 0.2031
# Epoch 658/700
# 814/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9458 - loss: 0.1384
# Epoch 658: val_loss did not improve from 0.20290
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9447 - loss: 0.1403 - val_accuracy: 0.9416 - val_loss: 0.2032
# Epoch 659/700
# 814/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9463 - loss: 0.1372
# Epoch 659: val_loss improved from 0.20290 to 0.20244, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9454 - loss: 0.1390 - val_accuracy: 0.9428 - val_loss: 0.2024
# Epoch 660/700
# 807/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9449 - loss: 0.1429
# Epoch 660: val_loss did not improve from 0.20244
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9440 - loss: 0.1413 - val_accuracy: 0.9417 - val_loss: 0.2040
# Epoch 661/700
# 809/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9462 - loss: 0.1379
# Epoch 661: val_loss improved from 0.20244 to 0.20206, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9463 - loss: 0.1379 - val_accuracy: 0.9433 - val_loss: 0.2021
# Epoch 662/700
# 806/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9456 - loss: 0.1391
# Epoch 662: val_loss improved from 0.20206 to 0.20189, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9451 - loss: 0.1407 - val_accuracy: 0.9434 - val_loss: 0.2019
# Epoch 663/700
# 814/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9470 - loss: 0.1381
# Epoch 663: val_loss did not improve from 0.20189
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9466 - loss: 0.1384 - val_accuracy: 0.9424 - val_loss: 0.2026
# Epoch 664/700
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9456 - loss: 0.1360
# Epoch 664: val_loss improved from 0.20189 to 0.20166, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9449 - loss: 0.1387 - val_accuracy: 0.9438 - val_loss: 0.2017
# Epoch 665/700
# 803/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9456 - loss: 0.1383
# Epoch 665: val_loss did not improve from 0.20166
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9456 - loss: 0.1372 - val_accuracy: 0.9425 - val_loss: 0.2022
# Epoch 666/700
# 815/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9458 - loss: 0.1362
# Epoch 666: val_loss did not improve from 0.20166
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9449 - loss: 0.1397 - val_accuracy: 0.9424 - val_loss: 0.2031
# Epoch 667/700
# 821/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9451 - loss: 0.1402
# Epoch 667: val_loss did not improve from 0.20166
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9458 - loss: 0.1392 - val_accuracy: 0.9429 - val_loss: 0.2019
# Epoch 668/700
# 798/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9450 - loss: 0.1390
# Epoch 668: val_loss did not improve from 0.20166
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9462 - loss: 0.1392 - val_accuracy: 0.9428 - val_loss: 0.2017
# Epoch 669/700
# 812/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9477 - loss: 0.1358
# Epoch 669: val_loss improved from 0.20166 to 0.20029, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9463 - loss: 0.1377 - val_accuracy: 0.9429 - val_loss: 0.2003
# Epoch 670/700
# 818/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9469 - loss: 0.1371
# Epoch 670: val_loss improved from 0.20029 to 0.19929, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9461 - loss: 0.1366 - val_accuracy: 0.9431 - val_loss: 0.1993
# Epoch 671/700
# 810/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9454 - loss: 0.1402
# Epoch 671: val_loss improved from 0.19929 to 0.19902, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9454 - loss: 0.1395 - val_accuracy: 0.9444 - val_loss: 0.1990
# Epoch 672/700
# 822/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9473 - loss: 0.1361
# Epoch 672: val_loss did not improve from 0.19902
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9449 - loss: 0.1382 - val_accuracy: 0.9416 - val_loss: 0.2019
# Epoch 673/700
# 808/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9494 - loss: 0.1352
# Epoch 673: val_loss did not improve from 0.19902
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9481 - loss: 0.1375 - val_accuracy: 0.9438 - val_loss: 0.1994
# Epoch 674/700
# 811/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9452 - loss: 0.1397
# Epoch 674: val_loss did not improve from 0.19902
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9460 - loss: 0.1386 - val_accuracy: 0.9437 - val_loss: 0.2000
# Epoch 675/700
# 820/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9457 - loss: 0.1396
# Epoch 675: val_loss did not improve from 0.19902
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9452 - loss: 0.1394 - val_accuracy: 0.9424 - val_loss: 0.2018
# Epoch 676/700
# 799/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9451 - loss: 0.1400
# Epoch 676: val_loss did not improve from 0.19902
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9453 - loss: 0.1388 - val_accuracy: 0.9435 - val_loss: 0.2009
# Epoch 677/700
# 803/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9458 - loss: 0.1377
# Epoch 677: val_loss did not improve from 0.19902
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9457 - loss: 0.1385 - val_accuracy: 0.9423 - val_loss: 0.2012
# Epoch 678/700
# 818/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9438 - loss: 0.1384
# Epoch 678: val_loss did not improve from 0.19902
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9445 - loss: 0.1380 - val_accuracy: 0.9436 - val_loss: 0.2001
# Epoch 679/700
# 797/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9456 - loss: 0.1390
# Epoch 679: val_loss did not improve from 0.19902
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9464 - loss: 0.1377 - val_accuracy: 0.9431 - val_loss: 0.1993
# Epoch 680/700
# 806/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9454 - loss: 0.1389
# Epoch 680: val_loss did not improve from 0.19902
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9455 - loss: 0.1388 - val_accuracy: 0.9419 - val_loss: 0.2013
# Epoch 681/700
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9487 - loss: 0.1353
# Epoch 681: val_loss improved from 0.19902 to 0.19893, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9462 - loss: 0.1386 - val_accuracy: 0.9442 - val_loss: 0.1989
# Epoch 682/700
# 820/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9473 - loss: 0.1360
# Epoch 682: val_loss did not improve from 0.19893
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9461 - loss: 0.1376 - val_accuracy: 0.9425 - val_loss: 0.2005
# Epoch 683/700
# 811/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9469 - loss: 0.1382
# Epoch 683: val_loss did not improve from 0.19893
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9466 - loss: 0.1390 - val_accuracy: 0.9406 - val_loss: 0.2021
# Epoch 684/700
# 805/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9463 - loss: 0.1374
# Epoch 684: val_loss improved from 0.19893 to 0.19876, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9458 - loss: 0.1379 - val_accuracy: 0.9436 - val_loss: 0.1988
# Epoch 685/700
# 804/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9453 - loss: 0.1381
# Epoch 685: val_loss did not improve from 0.19876
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9457 - loss: 0.1400 - val_accuracy: 0.9436 - val_loss: 0.1994
# Epoch 686/700
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9496 - loss: 0.1336
# Epoch 686: val_loss did not improve from 0.19876
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9473 - loss: 0.1383 - val_accuracy: 0.9436 - val_loss: 0.1988
# Epoch 687/700
# 797/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9470 - loss: 0.1353
# Epoch 687: val_loss did not improve from 0.19876
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9471 - loss: 0.1351 - val_accuracy: 0.9424 - val_loss: 0.1991
# Epoch 688/700
# 814/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9460 - loss: 0.1371
# Epoch 688: val_loss did not improve from 0.19876
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9470 - loss: 0.1362 - val_accuracy: 0.9424 - val_loss: 0.1995
# Epoch 689/700
# 810/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9463 - loss: 0.1359
# Epoch 689: val_loss improved from 0.19876 to 0.19773, saving model to best_mr_tcn.keras
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9472 - loss: 0.1364 - val_accuracy: 0.9433 - val_loss: 0.1977
# Epoch 690/700
# 804/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9481 - loss: 0.1351
# Epoch 690: val_loss did not improve from 0.19773
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9474 - loss: 0.1360 - val_accuracy: 0.9414 - val_loss: 0.1996
# Epoch 691/700
# 809/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9457 - loss: 0.1379
# Epoch 691: val_loss did not improve from 0.19773
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9455 - loss: 0.1390 - val_accuracy: 0.9433 - val_loss: 0.1981
# Epoch 692/700
# 815/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9443 - loss: 0.1403
# Epoch 692: val_loss did not improve from 0.19773
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9450 - loss: 0.1412 - val_accuracy: 0.9425 - val_loss: 0.2003
# Epoch 693/700
# 809/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9475 - loss: 0.1353
# Epoch 693: val_loss did not improve from 0.19773
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9472 - loss: 0.1359 - val_accuracy: 0.9427 - val_loss: 0.2002
# Epoch 694/700
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9466 - loss: 0.1363
# Epoch 694: val_loss did not improve from 0.19773
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9457 - loss: 0.1387 - val_accuracy: 0.9439 - val_loss: 0.1996
# Epoch 695/700
# 813/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9468 - loss: 0.1350
# Epoch 695: val_loss did not improve from 0.19773
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - accuracy: 0.9463 - loss: 0.1356 - val_accuracy: 0.9424 - val_loss: 0.2003
# Epoch 696/700
# 822/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9482 - loss: 0.1365
# Epoch 696: val_loss did not improve from 0.19773
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9465 - loss: 0.1370 - val_accuracy: 0.9424 - val_loss: 0.1997
# Epoch 697/700
# 808/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9450 - loss: 0.1381
# Epoch 697: val_loss did not improve from 0.19773
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9461 - loss: 0.1358 - val_accuracy: 0.9421 - val_loss: 0.1988
# Epoch 698/700
# 813/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9452 - loss: 0.1383
# Epoch 698: val_loss did not improve from 0.19773
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9471 - loss: 0.1355 - val_accuracy: 0.9428 - val_loss: 0.1989
# Epoch 699/700
# 809/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9470 - loss: 0.1342
# Epoch 699: val_loss did not improve from 0.19773
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - accuracy: 0.9467 - loss: 0.1360 - val_accuracy: 0.9427 - val_loss: 0.1988
# Epoch 700/700
# 821/823 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9462 - loss: 0.1368
# Epoch 700: val_loss did not improve from 0.19773
# 823/823 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - accuracy: 0.9459 - loss: 0.1353 - val_accuracy: 0.9433 - val_loss: 0.1981

# %%
test_results = model.evaluate(X_test, y_test, verbose=0)

for name, val in zip(model.metrics_names, test_results):
    print(f"{name}: {val:.4f}")
# Out:
# loss: 0.3309
# compile_metrics: 0.8657

# %%
import matplotlib.pyplot as plt

plt.plot(history.history["loss"], label="train")
plt.plot(history.history["val_loss"], label="val")
plt.legend()
plt.title("Loss")
plt.show()

# %%
# ===== EVALUASI MODEL (TEST SET) =====

import numpy as np
from sklearn.metrics import roc_curve, confusion_matrix, classification_report

# 1. Ambil probabilitas output model
y_prob = model.predict(X_test).ravel()

# 2. Hitung ROC curve
fpr, tpr, thresholds = roc_curve(y_test, y_prob)

# 3. Hitung Youden Index
youden_index = tpr - fpr
best_threshold = thresholds[np.argmax(youden_index)]

print("Best threshold (Youden):", best_threshold)

# 4. Prediksi final menggunakan threshold Youden
y_pred = (y_prob >= best_threshold).astype(int)

# 5. Evaluasi
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))

print("\nClassification Report:")
print(classification_report(y_test, y_pred, target_names=["Normal", "Attack"]))
# Out:
# 1546/1546 ━━━━━━━━━━━━━━━━━━━━ 1s 808us/step
# Best threshold (Youden): 0.36816898
# Confusion Matrix:
# [[25315  2060]
#  [ 2927 19170]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#       Normal       0.90      0.92      0.91     27375
#       Attack       0.90      0.87      0.88     22097
#
#     accuracy                           0.90     49472
#    macro avg       0.90      0.90      0.90     49472
# weighted avg       0.90      0.90      0.90     49472

# %%
y_pred = (y_prob >= best_threshold)

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred, target_names=["Normal","Attack"]))
# Out:
#               precision    recall  f1-score   support
#
#       Normal       0.90      0.92      0.91     27375
#       Attack       0.90      0.87      0.88     22097
#
#     accuracy                           0.90     49472
#    macro avg       0.90      0.90      0.90     49472
# weighted avg       0.90      0.90      0.90     49472

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import time
from sklearn.metrics import roc_curve, auc, confusion_matrix, classification_report

# 1. DEFINISI FUNGSI (Mesin Evaluasi)
def evaluate_iov_model(model, X_test, y_test):
    print("--- Memulai Proses Evaluasi ---")
    
    # Prediksi
    start_time = time.time()
    y_prob = model.predict(X_test).ravel()
    inference_time = (time.time() - start_time) / len(X_test)
    
    # Mencari Threshold Terbaik (Youden Index)
    fpr, tpr, thresholds = roc_curve(y_test, y_prob)
    youden_index = tpr - fpr
    best_threshold = thresholds[np.argmax(youden_index)]
    
    # Klasifikasi Berdasarkan Threshold
    y_pred = (y_prob >= best_threshold).astype(int)
    
    # Hitung Metrik
    cm = confusion_matrix(y_test, y_pred)
    tn, fp, fn, tp = cm.ravel()
    fpr_val = fp / (fp + tn)
    
    # VISUALISASI
    fig, ax = plt.subplots(1, 2, figsize=(15, 5))
    
    # Heatmap Confusion Matrix
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', ax=ax[0])
    ax[0].set_title('Confusion Matrix (Optimized Threshold)')
    ax[0].set_xlabel('Predicted')
    ax[0].set_ylabel('Actual')
    
    # ROC Curve
    ax[1].plot(fpr, tpr, label=f'AUC = {auc(fpr, tpr):.44f}')
    ax[1].plot([0, 1], [0, 1], 'k--')
    ax[1].set_title('ROC Curve')
    ax[1].legend()
    
    plt.show() # Ini akan memunculkan gambar
    
    # CETAK HASIL KE KONSOL
    print("\n" + "="*30)
    print(f"HASIL EVALUASI IDS (IoV)")
    print("="*30)
    print(f"Threshold Optimal : {best_threshold:.4f}")
    print(f"False Positive Rate: {fpr_val:.6f}")
    print(f"Inference Latency : {inference_time:.6f} s/sample")
    print("-" * 30)
    print(classification_report(y_test, y_pred, target_names=['Normal', 'Attack']))
    
    return best_threshold

# ==========================================
# 2. EKSEKUSI FUNGSI (Panggil di sini)
# ==========================================
# Ganti 'model_anda', 'X_test_anda', 'y_test_anda' 
# dengan nama variabel yang Anda miliki.

try:
    # Contoh: jika model Anda bernama 'global_model'
    best_thr = evaluate_iov_model(model, X_test, y_test)
except NameError as e:
    print(f"Error: {e}. Pastikan variabel model dan data Anda sudah didefinisikan sebelumnya.")
# Out:
# --- Memulai Proses Evaluasi ---
# 1546/1546 ━━━━━━━━━━━━━━━━━━━━ 1s 844us/step
# ==============================
# HASIL EVALUASI IDS (IoV)
# ==============================
# Threshold Optimal : 0.3682
# False Positive Rate: 0.075251
# Inference Latency : 0.000039 s/sample
# ------------------------------
#               precision    recall  f1-score   support
#
#       Normal       0.90      0.92      0.91     27375
#       Attack       0.90      0.87      0.88     22097
#
#     accuracy                           0.90     49472
#    macro avg       0.90      0.90      0.90     49472
# weighted avg       0.90      0.90      0.90     49472

# %%
from sklearn.metrics import confusion_matrix

# 1. Dapatkan prediksi dari model (berupa probabilitas)
y_prob = model.predict(X_test) 

# 2. Ubah probabilitas menjadi kelas (0 atau 1) 
# Gunakan threshold, misalnya 0.5 atau hasil Youden Index
y_pred = (y_prob > best_threshold).astype(int)

# 3. Munculkan Confusion Matrix
cm = confusion_matrix(y_test, y_pred)

# 4. Ekstrak TP, FP, TN, FN dari matriks
# Matriks sklearn memiliki format: [[TN, FP], [FN, TP]]
tn, fp, fn, tp = cm.ravel()

# 5. Cetak ke layar
print(f"--- Hasil Deteksi Serangan ---")
print(f"True Negatives (TN)  : {tn} (Trafik normal terdeteksi normal)")
print(f"False Positives (FP) : {fp} (ALARM PALSU - Normal dianggap serangan)")
print(f"False Negatives (FN) : {fn} (LOLOS - Serangan dianggap normal)")
print(f"True Positives (TP)  : {tp} (Berhasil mendeteksi serangan)")
# Out:
# 1546/1546 ━━━━━━━━━━━━━━━━━━━━ 1s 635us/step
# --- Hasil Deteksi Serangan ---
# True Negatives (TN)  : 25315 (Trafik normal terdeteksi normal)
# False Positives (FP) : 2060 (ALARM PALSU - Normal dianggap serangan)
# False Negatives (FN) : 2928 (LOLOS - Serangan dianggap normal)
# True Positives (TP)  : 19169 (Berhasil mendeteksi serangan)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Reds', 
            xticklabels=['Normal', 'Attack'], 
            yticklabels=['Normal', 'Attack'])
plt.title('Confusion Matrix: Deteksi Serangan IoV')
plt.ylabel('Kondisi Aktual')
plt.xlabel('Prediksi Model')
plt.show()

# %% [markdown]
# batas

# %%
import numpy as np

y_prob = model.predict(X_test).ravel()      # probabilitas Attack
y_pred = (y_prob > best_threshold).astype(int)         # label prediksi (threshold default)
# Out:
# 1546/1546 ━━━━━━━━━━━━━━━━━━━━ 1s 648us/step

# %%
# Fungsi: deteksi overfitting dan stabilitas training.
import matplotlib.pyplot as plt

plt.figure()
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training vs Validation Loss')
plt.legend()
plt.show()

plt.figure()
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training vs Validation Accuracy')
plt.legend()
plt.show()

# %%
# Fungsi: melihat False Negative (serangan lolos).
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

cm = confusion_matrix(y_test, y_pred)

disp = ConfusionMatrixDisplay(
    confusion_matrix=cm,
    display_labels=["Normal", "Attack"]
)
disp.plot()
plt.title("Confusion Matrix")
plt.show()
# 📌 Interpretasi IDS

# FN (Attack → Normal) harus minimal

# FP tinggi → false alarm

# %%
# Fungsi: menilai kualitas deteksi Attack.
from sklearn.metrics import precision_recall_fscore_support

precision, recall, f1, _ = precision_recall_fscore_support(
    y_test, y_pred, average=None
)

labels = ["Normal", "Attack"]

plt.figure()
plt.bar(labels, precision, label="Precision")
plt.bar(labels, recall, bottom=precision, label="Recall")
plt.ylabel("Score")
plt.title("Precision & Recall per Class")
plt.legend()
plt.show()
# Fokus laporan: Recall kelas Attack

# %%
# Fungsi: evaluasi threshold-independent.
from sklearn.metrics import roc_curve, auc

fpr, tpr, _ = roc_curve(y_test, y_prob)
roc_auc = auc(fpr, tpr)

plt.figure()
plt.plot(fpr, tpr, label=f"AUC = {roc_auc:.4f}")
plt.plot([0,1], [0,1], linestyle="--")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve")
plt.legend()
plt.show()

# AUC mendekati 1 → IDS sangat kuat

# %%
# Lebih relevan dari ROC untuk IDS.
from sklearn.metrics import precision_recall_curve

prec, rec, _ = precision_recall_curve(y_test, y_prob)

plt.figure()
plt.plot(rec, prec)
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title("Precision–Recall Curve")
plt.show()

# %%
from sklearn.metrics import f1_score
import matplotlib.pyplot as plt
import numpy as np

# ==========================================
# ASUMSI:
# - y_prob SUDAH dihitung di evaluate_iov_model
# - best_thr didapat dari return fungsi
# ==========================================

# Gunakan ulang y_prob & y_test (TIDAK buat baru)
y_pred = (y_prob >= best_thr).astype(int)

# Hitung F1-score untuk threshold yang SAMA
f1 = f1_score(y_test, y_pred)

print("\n" + "="*30)
print("F1-SCORE (FOLLOW YOUDEN THRESHOLD)")
print("="*30)
print(f"Threshold digunakan : {best_thr:.4f}")
print(f"F1-score           : {f1:.6f}")
# Out:
# ==============================
# F1-SCORE (FOLLOW YOUDEN THRESHOLD)
# ==============================
# Threshold digunakan : 0.3682
# F1-score           : 0.884899

# %%
plt.figure(figsize=(6,4))
plt.scatter(best_thr, f1, color='red', zorder=5)
plt.axvline(best_thr, linestyle='--', label=f"Threshold = {best_thr:.4f}")

plt.text(
    best_thr, f1,
    f"({best_thr:.4f}, {f1:.4f})",
    ha='left', va='bottom'
)

plt.xlabel("Threshold")
plt.ylabel("F1-score")
plt.title("F1-score at Optimized Youden Threshold")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Fungsi: lihat separasi Normal vs Attack.
plt.figure()
plt.hist(y_prob[y_test == 1], bins=50, alpha=0.7, label="Attack")
plt.hist(y_prob[y_test == 0], bins=50, alpha=0.7, label="Normal")
plt.xlabel("Predicted Probability (Attack)")
plt.ylabel("Frequency")
plt.title("Prediction Confidence Distribution")
plt.legend()
plt.show()
# 📌 Distribusi terpisah jelas → model robust.

# %%
from sklearn.metrics import classification_report

print(classification_report(
    y_test, y_pred,
    target_names=["Normal", "Attack"]
))
# Out:
#               precision    recall  f1-score   support
#
#       Normal       0.90      0.92      0.91     27375
#       Attack       0.90      0.87      0.88     22097
#
#     accuracy                           0.90     49472
#    macro avg       0.90      0.90      0.90     49472
# weighted avg       0.90      0.90      0.90     49472

# %%
import numpy as np
from sklearn.metrics import confusion_matrix

def compute_ids_metrics(y_true, y_pred):
    """
    Compute IDS metrics:
    Accuracy, Precision, Recall, F1, FPR, FNR
    """

    # Confusion Matrix
    tn, fp, fn, tp = confusion_matrix(y_true, y_pred).ravel()

    # Basic metrics
    acc = (tp + tn) / (tp + tn + fp + fn)

    precision = tp / (tp + fp) if (tp + fp) > 0 else 0.0
    recall    = tp / (tp + fn) if (tp + fn) > 0 else 0.0

    f1 = (2 * precision * recall) / (precision + recall) if (precision + recall) > 0 else 0.0

    # IDS-specific metrics
    fpr = fp / (fp + tn) if (fp + tn) > 0 else 0.0
    fnr = fn / (fn + tp) if (fn + tp) > 0 else 0.0

    return {
        "TP": tp,
        "FP": fp,
        "TN": tn,
        "FN": fn,
        "Accuracy": acc,
        "Precision": precision,
        "Recall": recall,
        "F1-score": f1,
        "FPR": fpr,
        "FNR": fnr,
    }

# %%
# Hitung metrik IDS
metrics = compute_ids_metrics(y_test, y_pred)

for k, v in metrics.items():
    print(f"{k:10s}: {v:.6f}" if isinstance(v, float) else f"{k:10s}: {v}")
# Out:
# TP        : 19170
# FP        : 2060
# TN        : 25315
# FN        : 2927
# Accuracy  : 0.899196
# Precision : 0.902967
# Recall    : 0.867539
# F1-score  : 0.884899
# FPR       : 0.075251
# FNR       : 0.132461

# %% [markdown]
# HASIL DARI MRCTN-AE W64 S64 D0.00

# %% [markdown]
# TP        : 19170
# FP        : 2060
# TN        : 25315
# FN        : 2927
# Accuracy  : 0.899196
# Precision : 0.902967
# Recall    : 0.867539
# F1-score  : 0.884899
# FPR       : 0.075251
# FNR       : 0.132461
