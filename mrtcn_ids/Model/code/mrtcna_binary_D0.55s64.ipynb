# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.layers import (
    Input, Conv1D, BatchNormalization,
    ReLU, Add, GlobalAveragePooling1D, Dense
)
from tensorflow.keras.models import Model
# Out:
# 2025-12-31 12:53:26.567411: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2025-12-31 12:53:26.577796: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1767160406.589589  378939 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1767160406.593688  378939 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1767160406.603216  378939 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1767160406.603231  378939 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1767160406.603232  378939 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1767160406.603233  378939 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2025-12-31 12:53:26.606048: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# !free -h
# Out:
#                total        used        free      shared  buff/cache   available
# Mem:            31Gi       7.0Gi        17Gi       617Mi       8.1Gi        24Gi
# Swap:           14Gi       2.1Gi        12Gi

# %%
# %whos
# Out:
# Variable                 Type        Data/Info
# ----------------------------------------------
# Add                      type        <class 'keras.src.layers.merging.add.Add'>
# BatchNormalization       type        <class 'keras.src.layers.<...>tion.BatchNormalization'>
# Conv1D                   type        <class 'keras.src.layers.<...>olutional.conv1d.Conv1D'>
# Dense                    type        <class 'keras.src.layers.core.dense.Dense'>
# GlobalAveragePooling1D   type        <class 'keras.src.layers.<...>.GlobalAveragePooling1D'>
# Input                    function    <function Input at 0x7516865e1b20>
# Model                    type        <class 'keras.src.models.model.Model'>
# ReLU                     type        <class 'keras.src.layers.activations.relu.ReLU'>
# np                       module      <module 'numpy' from '/ho<...>kages/numpy/__init__.py'>
# tf                       module      <module 'tensorflow' from<...>/tensorflow/__init__.py'>

# %%
data = np.load(
    "preprocessingW64S64binaryfloat32/tow_ids_binary_preprocessedW64S64.npz",
    mmap_mode="r"   # penting: tidak load penuh ke RAM
)

print(data.files)
# Out:
# ['x_train', 'y_train', 'x_val', 'y_val', 'x_test', 'y_test']

# %%
data = np.load("preprocessingW64S64binaryfloat32/tow_ids_binary_preprocessedW64S64.npz")

X_train = data["x_train"]
y_train = data["y_train"]
X_val   = data["x_val"]
y_val   = data["y_val"]
X_test  = data["x_test"]
y_test  = data["y_test"]

print(X_train.shape, y_train.shape)
print(X_val.shape, y_val.shape)
print(X_test.shape, y_test.shape)
# Out:
# (13165, 64, 64) (13165,)
# (5643, 64, 64) (5643,)
# (12368, 64, 64) (12368,)

# %%
np.unique(y_train, return_counts=True)
# Out:
# (array([0, 1]), array([6011, 7154]))

# %%
import numpy as np

# Fungsi untuk cek balance
def check_balance_binary(y):
    n_normal = np.sum(y == 0)
    n_attack = np.sum(y == 1)
    total = len(y)
    print(f"Total samples: {total}")
    print(f"Normal: {n_normal} ({n_normal/total*100:.2f}%)")
    print(f"Attack: {n_attack} ({n_attack/total*100:.2f}%)\n")

# Cek balance di masing-masing split
print("=== Train Set ===")
check_balance_binary(y_train)

print("=== Validation Set ===")
check_balance_binary(y_val)

print("=== Test Set ===")
check_balance_binary(y_test)
# Out:
# === Train Set ===
# Total samples: 13165
# Normal: 6011 (45.66%)
# Attack: 7154 (54.34%)
#
# === Validation Set ===
# Total samples: 5643
# Normal: 2576 (45.65%)
# Attack: 3067 (54.35%)
#
# === Test Set ===
# Total samples: 12368
# Normal: 6846 (55.35%)
# Attack: 5522 (44.65%)

# %%
def tcn_block(x, filters, kernel_size, dilation):
    shortcut = x

    x = Conv1D(filters, kernel_size,
               padding="causal",
               dilation_rate=dilation)(x)
    x = BatchNormalization()(x)
    x = ReLU()(x)

    x = Conv1D(filters, kernel_size,
               padding="causal",
               dilation_rate=dilation)(x)
    x = BatchNormalization()(x)

    if shortcut.shape[-1] != filters:
        shortcut = Conv1D(filters, 1, padding="same")(shortcut)

    x = Add()([x, shortcut])
    x = ReLU()(x)
    return x

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, Dropout, MaxPooling1D, Flatten, Dense

def build_mr_tcn(input_shape=(64, 64), dropout_rate=0.55):
    model = Sequential()

    # Conv1D #1
    model.add(Conv1D(
        filters=64,
        kernel_size=3,
        strides=1,
        dilation_rate=1,
        padding="same",
        activation="relu",
        input_shape=input_shape
    ))
    model.add(Dropout(dropout_rate))

    # Conv1D #2
    model.add(Conv1D(
        filters=64,
        kernel_size=3,
        strides=1,
        dilation_rate=2,
        padding="same",
        activation="relu"
    ))
    model.add(Dropout(dropout_rate))

    # Conv1D #3
    model.add(Conv1D(
        filters=64,
        kernel_size=3,
        strides=1,
        dilation_rate=4,
        padding="same",
        activation="relu"
    ))
    model.add(Dropout(dropout_rate))

    # MaxPooling
    model.add(MaxPooling1D(pool_size=8, strides=8))

    # Flatten
    model.add(Flatten())

    # Dropout
    model.add(Dropout(dropout_rate))

    # Linear → Sigmoid
    model.add(Dense(1, activation="sigmoid"))

    return model

# %%
model = build_mr_tcn()

model.compile(
    optimizer=tf.keras.optimizers.Adam(learning_rate=1e-5),
    loss="binary_crossentropy",
    metrics=["accuracy"]
)

model.summary()
# Out:
# /home/dani/miniconda3/envs/latihan1/lib/python3.12/site-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# I0000 00:00:1767160409.707121  378939 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 4136 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d (Conv1D)                 │ (None, 64, 64)         │        12,352 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 64, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_1 (Conv1D)               │ (None, 64, 64)         │        12,352 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 64, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_2 (Conv1D)               │ (None, 64, 64)         │        12,352 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 64, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d (MaxPooling1D)    │ (None, 8, 64)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 1)              │           513 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 37,569 (146.75 KB)
#  Trainable params: 37,569 (146.75 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint

early_stop = EarlyStopping(
    monitor="val_loss",
    patience=30,
    restore_best_weights=True
)

checkpoint = ModelCheckpoint(
    "best_mr_tcn.keras",
    monitor="val_loss",
    save_best_only=True,
    verbose=1
)

# %%
history = model.fit(
    X_train, y_train,
    validation_data=(X_val, y_val),
    epochs=700,
    batch_size=64,
    callbacks=[early_stop, checkpoint]
)
# Out:
# Epoch 1/700
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1767160411.164591  379252 service.cc:152] XLA service 0x7514cc00d670 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1767160411.164606  379252 service.cc:160]   StreamExecutor device (0): NVIDIA GeForce RTX 3060 Laptop GPU, Compute Capability 8.6
# 2025-12-31 12:53:31.197438: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1767160411.345890  379252 cuda_dnn.cc:529] Loaded cuDNN version 91200
#  83/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5109 - loss: 1.2450
# I0000 00:00:1767160413.168284  379252 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.5100 - loss: 1.1994
# Epoch 1: val_loss improved from None to 0.69595, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 6s 15ms/step - accuracy: 0.5081 - loss: 1.1392 - val_accuracy: 0.4841 - val_loss: 0.6960
# Epoch 2/700
# 199/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4983 - loss: 1.0330
# Epoch 2: val_loss improved from 0.69595 to 0.69529, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5007 - loss: 0.9992 - val_accuracy: 0.4811 - val_loss: 0.6953
# Epoch 3/700
# 204/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4943 - loss: 0.9461
# Epoch 3: val_loss improved from 0.69529 to 0.69390, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4936 - loss: 0.9348 - val_accuracy: 0.4960 - val_loss: 0.6939
# Epoch 4/700
# 204/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5034 - loss: 0.8956
# Epoch 4: val_loss improved from 0.69390 to 0.69310, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5025 - loss: 0.8884 - val_accuracy: 0.5040 - val_loss: 0.6931
# Epoch 5/700
# 191/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5074 - loss: 0.8605
# Epoch 5: val_loss improved from 0.69310 to 0.69233, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4988 - loss: 0.8551 - val_accuracy: 0.5171 - val_loss: 0.6923
# Epoch 6/700
# 202/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.4992 - loss: 0.8310
# Epoch 6: val_loss improved from 0.69233 to 0.69171, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.4967 - loss: 0.8284 - val_accuracy: 0.5274 - val_loss: 0.6917
# Epoch 7/700
# 198/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5058 - loss: 0.8036
# Epoch 7: val_loss improved from 0.69171 to 0.69120, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5026 - loss: 0.8040 - val_accuracy: 0.5362 - val_loss: 0.6912
# Epoch 8/700
# 194/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5039 - loss: 0.7889
# Epoch 8: val_loss improved from 0.69120 to 0.69074, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5070 - loss: 0.7840 - val_accuracy: 0.5426 - val_loss: 0.6907
# Epoch 9/700
# 193/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5026 - loss: 0.7823
# Epoch 9: val_loss improved from 0.69074 to 0.69036, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5019 - loss: 0.7785 - val_accuracy: 0.5501 - val_loss: 0.6904
# Epoch 10/700
# 195/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5022 - loss: 0.7658
# Epoch 10: val_loss improved from 0.69036 to 0.69011, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5049 - loss: 0.7634 - val_accuracy: 0.5563 - val_loss: 0.6901
# Epoch 11/700
# 205/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5083 - loss: 0.7533
# Epoch 11: val_loss improved from 0.69011 to 0.68983, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5117 - loss: 0.7489 - val_accuracy: 0.5632 - val_loss: 0.6898
# Epoch 12/700
# 182/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5113 - loss: 0.7456
# Epoch 12: val_loss improved from 0.68983 to 0.68945, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5138 - loss: 0.7433 - val_accuracy: 0.5733 - val_loss: 0.6895
# Epoch 13/700
# 189/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5074 - loss: 0.7430
# Epoch 13: val_loss improved from 0.68945 to 0.68920, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5082 - loss: 0.7384 - val_accuracy: 0.5797 - val_loss: 0.6892
# Epoch 14/700
# 179/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5291 - loss: 0.7252
# Epoch 14: val_loss improved from 0.68920 to 0.68886, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5243 - loss: 0.7265 - val_accuracy: 0.5889 - val_loss: 0.6889
# Epoch 15/700
# 186/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5147 - loss: 0.7305
# Epoch 15: val_loss improved from 0.68886 to 0.68850, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5130 - loss: 0.7302 - val_accuracy: 0.5954 - val_loss: 0.6885
# Epoch 16/700
# 184/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5269 - loss: 0.7185
# Epoch 16: val_loss improved from 0.68850 to 0.68820, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5255 - loss: 0.7165 - val_accuracy: 0.6018 - val_loss: 0.6882
# Epoch 17/700
# 194/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5178 - loss: 0.7199
# Epoch 17: val_loss improved from 0.68820 to 0.68791, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5226 - loss: 0.7162 - val_accuracy: 0.6078 - val_loss: 0.6879
# Epoch 18/700
# 195/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5195 - loss: 0.7206
# Epoch 18: val_loss improved from 0.68791 to 0.68758, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5208 - loss: 0.7171 - val_accuracy: 0.6165 - val_loss: 0.6876
# Epoch 19/700
# 204/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5307 - loss: 0.7112
# Epoch 19: val_loss improved from 0.68758 to 0.68728, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5308 - loss: 0.7092 - val_accuracy: 0.6229 - val_loss: 0.6873
# Epoch 20/700
# 182/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5295 - loss: 0.7066
# Epoch 20: val_loss improved from 0.68728 to 0.68695, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5252 - loss: 0.7092 - val_accuracy: 0.6259 - val_loss: 0.6870
# Epoch 21/700
# 185/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5326 - loss: 0.7039
# Epoch 21: val_loss improved from 0.68695 to 0.68663, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5286 - loss: 0.7049 - val_accuracy: 0.6323 - val_loss: 0.6866
# Epoch 22/700
# 183/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5198 - loss: 0.7071
# Epoch 22: val_loss improved from 0.68663 to 0.68643, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5290 - loss: 0.7049 - val_accuracy: 0.6383 - val_loss: 0.6864
# Epoch 23/700
# 199/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5436 - loss: 0.6935
# Epoch 23: val_loss improved from 0.68643 to 0.68597, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5331 - loss: 0.6991 - val_accuracy: 0.6378 - val_loss: 0.6860
# Epoch 24/700
# 204/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5458 - loss: 0.6965
# Epoch 24: val_loss improved from 0.68597 to 0.68563, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5385 - loss: 0.6977 - val_accuracy: 0.6419 - val_loss: 0.6856
# Epoch 25/700
# 186/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5406 - loss: 0.6946
# Epoch 25: val_loss improved from 0.68563 to 0.68533, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5453 - loss: 0.6927 - val_accuracy: 0.6521 - val_loss: 0.6853
# Epoch 26/700
# 205/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5439 - loss: 0.6931
# Epoch 26: val_loss improved from 0.68533 to 0.68494, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5461 - loss: 0.6927 - val_accuracy: 0.6489 - val_loss: 0.6849
# Epoch 27/700
# 181/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5526 - loss: 0.6903
# Epoch 27: val_loss improved from 0.68494 to 0.68453, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5540 - loss: 0.6893 - val_accuracy: 0.6523 - val_loss: 0.6845
# Epoch 28/700
# 196/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5586 - loss: 0.6844
# Epoch 28: val_loss improved from 0.68453 to 0.68412, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5550 - loss: 0.6858 - val_accuracy: 0.6525 - val_loss: 0.6841
# Epoch 29/700
# 204/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5548 - loss: 0.6874
# Epoch 29: val_loss improved from 0.68412 to 0.68377, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5557 - loss: 0.6863 - val_accuracy: 0.6543 - val_loss: 0.6838
# Epoch 30/700
# 205/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5530 - loss: 0.6855
# Epoch 30: val_loss improved from 0.68377 to 0.68333, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5547 - loss: 0.6860 - val_accuracy: 0.6580 - val_loss: 0.6833
# Epoch 31/700
# 179/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5588 - loss: 0.6852
# Epoch 31: val_loss improved from 0.68333 to 0.68284, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5603 - loss: 0.6836 - val_accuracy: 0.6599 - val_loss: 0.6828
# Epoch 32/700
# 197/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5632 - loss: 0.6807
# Epoch 32: val_loss improved from 0.68284 to 0.68240, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5598 - loss: 0.6811 - val_accuracy: 0.6642 - val_loss: 0.6824
# Epoch 33/700
# 188/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5670 - loss: 0.6749
# Epoch 33: val_loss improved from 0.68240 to 0.68187, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5670 - loss: 0.6762 - val_accuracy: 0.6624 - val_loss: 0.6819
# Epoch 34/700
# 192/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5700 - loss: 0.6748
# Epoch 34: val_loss improved from 0.68187 to 0.68132, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5701 - loss: 0.6762 - val_accuracy: 0.6672 - val_loss: 0.6813
# Epoch 35/700
# 201/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5867 - loss: 0.6713
# Epoch 35: val_loss improved from 0.68132 to 0.68070, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5803 - loss: 0.6724 - val_accuracy: 0.6757 - val_loss: 0.6807
# Epoch 36/700
# 192/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5869 - loss: 0.6691
# Epoch 36: val_loss improved from 0.68070 to 0.68004, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5796 - loss: 0.6709 - val_accuracy: 0.6835 - val_loss: 0.6800
# Epoch 37/700
# 182/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5762 - loss: 0.6726
# Epoch 37: val_loss improved from 0.68004 to 0.67931, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5780 - loss: 0.6711 - val_accuracy: 0.6821 - val_loss: 0.6793
# Epoch 38/700
# 200/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5715 - loss: 0.6724
# Epoch 38: val_loss improved from 0.67931 to 0.67871, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5799 - loss: 0.6693 - val_accuracy: 0.6920 - val_loss: 0.6787
# Epoch 39/700
# 200/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5869 - loss: 0.6664
# Epoch 39: val_loss improved from 0.67871 to 0.67798, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5869 - loss: 0.6661 - val_accuracy: 0.7002 - val_loss: 0.6780
# Epoch 40/700
# 196/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5896 - loss: 0.6632
# Epoch 40: val_loss improved from 0.67798 to 0.67713, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5970 - loss: 0.6621 - val_accuracy: 0.7026 - val_loss: 0.6771
# Epoch 41/700
# 203/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5976 - loss: 0.6624
# Epoch 41: val_loss improved from 0.67713 to 0.67626, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5990 - loss: 0.6609 - val_accuracy: 0.7049 - val_loss: 0.6763
# Epoch 42/700
# 203/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.5981 - loss: 0.6601
# Epoch 42: val_loss improved from 0.67626 to 0.67533, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.5952 - loss: 0.6595 - val_accuracy: 0.7078 - val_loss: 0.6753
# Epoch 43/700
# 202/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6016 - loss: 0.6595
# Epoch 43: val_loss improved from 0.67533 to 0.67426, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6067 - loss: 0.6559 - val_accuracy: 0.7044 - val_loss: 0.6743
# Epoch 44/700
# 194/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6104 - loss: 0.6526
# Epoch 44: val_loss improved from 0.67426 to 0.67325, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6088 - loss: 0.6529 - val_accuracy: 0.7106 - val_loss: 0.6732
# Epoch 45/700
# 198/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6061 - loss: 0.6518
# Epoch 45: val_loss improved from 0.67325 to 0.67229, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6072 - loss: 0.6510 - val_accuracy: 0.7205 - val_loss: 0.6723
# Epoch 46/700
# 204/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6127 - loss: 0.6486
# Epoch 46: val_loss improved from 0.67229 to 0.67110, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6155 - loss: 0.6477 - val_accuracy: 0.7282 - val_loss: 0.6711
# Epoch 47/700
# 193/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6284 - loss: 0.6446
# Epoch 47: val_loss improved from 0.67110 to 0.66966, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6232 - loss: 0.6426 - val_accuracy: 0.7308 - val_loss: 0.6697
# Epoch 48/700
# 198/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6255 - loss: 0.6398
# Epoch 48: val_loss improved from 0.66966 to 0.66833, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6269 - loss: 0.6399 - val_accuracy: 0.7384 - val_loss: 0.6683
# Epoch 49/700
# 188/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6307 - loss: 0.6386
# Epoch 49: val_loss improved from 0.66833 to 0.66670, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6326 - loss: 0.6353 - val_accuracy: 0.7404 - val_loss: 0.6667
# Epoch 50/700
# 181/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6414 - loss: 0.6309
# Epoch 50: val_loss improved from 0.66670 to 0.66520, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6381 - loss: 0.6324 - val_accuracy: 0.7459 - val_loss: 0.6652
# Epoch 51/700
# 200/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6397 - loss: 0.6295
# Epoch 51: val_loss improved from 0.66520 to 0.66374, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6428 - loss: 0.6285 - val_accuracy: 0.7558 - val_loss: 0.6637
# Epoch 52/700
# 187/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6387 - loss: 0.6293
# Epoch 52: val_loss improved from 0.66374 to 0.66183, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6440 - loss: 0.6268 - val_accuracy: 0.7578 - val_loss: 0.6618
# Epoch 53/700
# 199/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6501 - loss: 0.6206
# Epoch 53: val_loss improved from 0.66183 to 0.66002, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6488 - loss: 0.6212 - val_accuracy: 0.7615 - val_loss: 0.6600
# Epoch 54/700
# 201/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6600 - loss: 0.6166
# Epoch 54: val_loss improved from 0.66002 to 0.65809, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6566 - loss: 0.6171 - val_accuracy: 0.7673 - val_loss: 0.6581
# Epoch 55/700
# 198/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6589 - loss: 0.6179
# Epoch 55: val_loss improved from 0.65809 to 0.65611, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6561 - loss: 0.6158 - val_accuracy: 0.7762 - val_loss: 0.6561
# Epoch 56/700
# 192/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6735 - loss: 0.6082
# Epoch 56: val_loss improved from 0.65611 to 0.65401, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6725 - loss: 0.6080 - val_accuracy: 0.7838 - val_loss: 0.6540
# Epoch 57/700
# 184/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6691 - loss: 0.6048
# Epoch 57: val_loss improved from 0.65401 to 0.65171, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6655 - loss: 0.6060 - val_accuracy: 0.7856 - val_loss: 0.6517
# Epoch 58/700
# 203/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6673 - loss: 0.6061
# Epoch 58: val_loss improved from 0.65171 to 0.64948, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6740 - loss: 0.6033 - val_accuracy: 0.7897 - val_loss: 0.6495
# Epoch 59/700
# 183/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6748 - loss: 0.6005
# Epoch 59: val_loss improved from 0.64948 to 0.64721, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6816 - loss: 0.5970 - val_accuracy: 0.7932 - val_loss: 0.6472
# Epoch 60/700
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6868 - loss: 0.5899
# Epoch 60: val_loss improved from 0.64721 to 0.64480, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6881 - loss: 0.5900 - val_accuracy: 0.7983 - val_loss: 0.6448
# Epoch 61/700
# 190/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6877 - loss: 0.5940
# Epoch 61: val_loss improved from 0.64480 to 0.64185, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6981 - loss: 0.5863 - val_accuracy: 0.7989 - val_loss: 0.6419
# Epoch 62/700
# 200/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6938 - loss: 0.5848
# Epoch 62: val_loss improved from 0.64185 to 0.63903, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.6993 - loss: 0.5794 - val_accuracy: 0.8015 - val_loss: 0.6390
# Epoch 63/700
# 188/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7004 - loss: 0.5750
# Epoch 63: val_loss improved from 0.63903 to 0.63656, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7006 - loss: 0.5764 - val_accuracy: 0.8047 - val_loss: 0.6366
# Epoch 64/700
# 201/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.6964 - loss: 0.5754
# Epoch 64: val_loss improved from 0.63656 to 0.63385, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7011 - loss: 0.5724 - val_accuracy: 0.8079 - val_loss: 0.6338
# Epoch 65/700
# 205/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7151 - loss: 0.5659
# Epoch 65: val_loss improved from 0.63385 to 0.63092, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7136 - loss: 0.5653 - val_accuracy: 0.8107 - val_loss: 0.6309
# Epoch 66/700
# 197/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7095 - loss: 0.5669
# Epoch 66: val_loss improved from 0.63092 to 0.62774, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7161 - loss: 0.5628 - val_accuracy: 0.8118 - val_loss: 0.6277
# Epoch 67/700
# 186/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7205 - loss: 0.5533
# Epoch 67: val_loss improved from 0.62774 to 0.62458, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7158 - loss: 0.5588 - val_accuracy: 0.8136 - val_loss: 0.6246
# Epoch 68/700
# 196/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7277 - loss: 0.5496
# Epoch 68: val_loss improved from 0.62458 to 0.62200, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7297 - loss: 0.5496 - val_accuracy: 0.8166 - val_loss: 0.6220
# Epoch 69/700
# 190/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7324 - loss: 0.5487
# Epoch 69: val_loss improved from 0.62200 to 0.61877, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7345 - loss: 0.5473 - val_accuracy: 0.8189 - val_loss: 0.6188
# Epoch 70/700
# 204/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7306 - loss: 0.5423
# Epoch 70: val_loss improved from 0.61877 to 0.61553, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7319 - loss: 0.5429 - val_accuracy: 0.8196 - val_loss: 0.6155
# Epoch 71/700
# 185/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7463 - loss: 0.5356
# Epoch 71: val_loss improved from 0.61553 to 0.61185, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7436 - loss: 0.5364 - val_accuracy: 0.8210 - val_loss: 0.6118
# Epoch 72/700
# 193/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7448 - loss: 0.5302
# Epoch 72: val_loss improved from 0.61185 to 0.60897, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7438 - loss: 0.5320 - val_accuracy: 0.8219 - val_loss: 0.6090
# Epoch 73/700
# 189/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7527 - loss: 0.5222
# Epoch 73: val_loss improved from 0.60897 to 0.60546, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7512 - loss: 0.5263 - val_accuracy: 0.8251 - val_loss: 0.6055
# Epoch 74/700
# 191/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7539 - loss: 0.5235
# Epoch 74: val_loss improved from 0.60546 to 0.60262, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7500 - loss: 0.5234 - val_accuracy: 0.8263 - val_loss: 0.6026
# Epoch 75/700
# 201/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7550 - loss: 0.5187
# Epoch 75: val_loss improved from 0.60262 to 0.59982, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7531 - loss: 0.5201 - val_accuracy: 0.8274 - val_loss: 0.5998
# Epoch 76/700
# 189/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7450 - loss: 0.5204
# Epoch 76: val_loss improved from 0.59982 to 0.59628, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7547 - loss: 0.5162 - val_accuracy: 0.8304 - val_loss: 0.5963
# Epoch 77/700
# 202/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7585 - loss: 0.5096
# Epoch 77: val_loss improved from 0.59628 to 0.59237, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7600 - loss: 0.5101 - val_accuracy: 0.8313 - val_loss: 0.5924
# Epoch 78/700
# 194/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7619 - loss: 0.5133
# Epoch 78: val_loss improved from 0.59237 to 0.59008, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7619 - loss: 0.5120 - val_accuracy: 0.8325 - val_loss: 0.5901
# Epoch 79/700
# 186/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7654 - loss: 0.5010
# Epoch 79: val_loss improved from 0.59008 to 0.58786, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7634 - loss: 0.5058 - val_accuracy: 0.8316 - val_loss: 0.5879
# Epoch 80/700
# 194/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7691 - loss: 0.5003
# Epoch 80: val_loss improved from 0.58786 to 0.58483, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7656 - loss: 0.5021 - val_accuracy: 0.8343 - val_loss: 0.5848
# Epoch 81/700
# 205/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7616 - loss: 0.5061
# Epoch 81: val_loss improved from 0.58483 to 0.58149, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7725 - loss: 0.4967 - val_accuracy: 0.8361 - val_loss: 0.5815
# Epoch 82/700
# 189/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7746 - loss: 0.4962
# Epoch 82: val_loss improved from 0.58149 to 0.57907, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7693 - loss: 0.4959 - val_accuracy: 0.8371 - val_loss: 0.5791
# Epoch 83/700
# 202/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7721 - loss: 0.4937
# Epoch 83: val_loss improved from 0.57907 to 0.57545, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7712 - loss: 0.4944 - val_accuracy: 0.8394 - val_loss: 0.5754
# Epoch 84/700
# 182/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7716 - loss: 0.4925
# Epoch 84: val_loss improved from 0.57545 to 0.57299, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7733 - loss: 0.4893 - val_accuracy: 0.8407 - val_loss: 0.5730
# Epoch 85/700
# 185/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7773 - loss: 0.4882
# Epoch 85: val_loss improved from 0.57299 to 0.56979, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7776 - loss: 0.4849 - val_accuracy: 0.8418 - val_loss: 0.5698
# Epoch 86/700
# 195/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7784 - loss: 0.4805
# Epoch 86: val_loss improved from 0.56979 to 0.56784, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7821 - loss: 0.4811 - val_accuracy: 0.8428 - val_loss: 0.5678
# Epoch 87/700
# 196/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7877 - loss: 0.4772
# Epoch 87: val_loss improved from 0.56784 to 0.56553, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7795 - loss: 0.4797 - val_accuracy: 0.8432 - val_loss: 0.5655
# Epoch 88/700
# 200/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7903 - loss: 0.4687
# Epoch 88: val_loss improved from 0.56553 to 0.56293, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7848 - loss: 0.4750 - val_accuracy: 0.8442 - val_loss: 0.5629
# Epoch 89/700
# 196/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7816 - loss: 0.4827
# Epoch 89: val_loss improved from 0.56293 to 0.56024, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7859 - loss: 0.4735 - val_accuracy: 0.8472 - val_loss: 0.5602
# Epoch 90/700
# 199/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7875 - loss: 0.4700
# Epoch 90: val_loss improved from 0.56024 to 0.55826, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7873 - loss: 0.4712 - val_accuracy: 0.8465 - val_loss: 0.5583
# Epoch 91/700
# 199/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7885 - loss: 0.4683
# Epoch 91: val_loss improved from 0.55826 to 0.55607, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7862 - loss: 0.4708 - val_accuracy: 0.8478 - val_loss: 0.5561
# Epoch 92/700
# 181/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8008 - loss: 0.4611
# Epoch 92: val_loss improved from 0.55607 to 0.55375, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7927 - loss: 0.4640 - val_accuracy: 0.8492 - val_loss: 0.5537
# Epoch 93/700
# 186/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7893 - loss: 0.4678
# Epoch 93: val_loss improved from 0.55375 to 0.55122, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7950 - loss: 0.4598 - val_accuracy: 0.8499 - val_loss: 0.5512
# Epoch 94/700
# 189/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7933 - loss: 0.4565
# Epoch 94: val_loss improved from 0.55122 to 0.54894, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7942 - loss: 0.4579 - val_accuracy: 0.8497 - val_loss: 0.5489
# Epoch 95/700
# 200/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7970 - loss: 0.4620
# Epoch 95: val_loss improved from 0.54894 to 0.54621, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7980 - loss: 0.4586 - val_accuracy: 0.8540 - val_loss: 0.5462
# Epoch 96/700
# 190/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7955 - loss: 0.4591
# Epoch 96: val_loss improved from 0.54621 to 0.54463, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.7958 - loss: 0.4561 - val_accuracy: 0.8531 - val_loss: 0.5446
# Epoch 97/700
# 203/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8058 - loss: 0.4447
# Epoch 97: val_loss improved from 0.54463 to 0.54211, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8002 - loss: 0.4513 - val_accuracy: 0.8549 - val_loss: 0.5421
# Epoch 98/700
# 195/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8017 - loss: 0.4542
# Epoch 98: val_loss improved from 0.54211 to 0.54012, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8017 - loss: 0.4488 - val_accuracy: 0.8558 - val_loss: 0.5401
# Epoch 99/700
# 200/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8030 - loss: 0.4487
# Epoch 99: val_loss improved from 0.54012 to 0.53799, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8044 - loss: 0.4482 - val_accuracy: 0.8570 - val_loss: 0.5380
# Epoch 100/700
# 204/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8000 - loss: 0.4498
# Epoch 100: val_loss improved from 0.53799 to 0.53618, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8071 - loss: 0.4431 - val_accuracy: 0.8575 - val_loss: 0.5362
# Epoch 101/700
# 197/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8016 - loss: 0.4475
# Epoch 101: val_loss improved from 0.53618 to 0.53468, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8048 - loss: 0.4445 - val_accuracy: 0.8575 - val_loss: 0.5347
# Epoch 102/700
# 198/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.7986 - loss: 0.4508
# Epoch 102: val_loss improved from 0.53468 to 0.53216, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8047 - loss: 0.4442 - val_accuracy: 0.8620 - val_loss: 0.5322
# Epoch 103/700
# 204/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8088 - loss: 0.4391
# Epoch 103: val_loss improved from 0.53216 to 0.52994, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8103 - loss: 0.4358 - val_accuracy: 0.8623 - val_loss: 0.5299
# Epoch 104/700
# 200/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8049 - loss: 0.4398
# Epoch 104: val_loss improved from 0.52994 to 0.52762, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8083 - loss: 0.4365 - val_accuracy: 0.8644 - val_loss: 0.5276
# Epoch 105/700
# 191/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8170 - loss: 0.4288
# Epoch 105: val_loss improved from 0.52762 to 0.52557, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8128 - loss: 0.4365 - val_accuracy: 0.8659 - val_loss: 0.5256
# Epoch 106/700
# 182/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8083 - loss: 0.4345
# Epoch 106: val_loss improved from 0.52557 to 0.52444, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8103 - loss: 0.4339 - val_accuracy: 0.8660 - val_loss: 0.5244
# Epoch 107/700
# 184/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8026 - loss: 0.4386
# Epoch 107: val_loss improved from 0.52444 to 0.52363, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8125 - loss: 0.4300 - val_accuracy: 0.8651 - val_loss: 0.5236
# Epoch 108/700
# 196/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8164 - loss: 0.4277
# Epoch 108: val_loss improved from 0.52363 to 0.52220, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8144 - loss: 0.4293 - val_accuracy: 0.8673 - val_loss: 0.5222
# Epoch 109/700
# 183/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8073 - loss: 0.4378
# Epoch 109: val_loss improved from 0.52220 to 0.51783, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8166 - loss: 0.4263 - val_accuracy: 0.8705 - val_loss: 0.5178
# Epoch 110/700
# 194/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8154 - loss: 0.4252
# Epoch 110: val_loss did not improve from 0.51783
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8109 - loss: 0.4285 - val_accuracy: 0.8687 - val_loss: 0.5183
# Epoch 111/700
# 190/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8166 - loss: 0.4210
# Epoch 111: val_loss improved from 0.51783 to 0.51731, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8150 - loss: 0.4255 - val_accuracy: 0.8678 - val_loss: 0.5173
# Epoch 112/700
# 196/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8149 - loss: 0.4297
# Epoch 112: val_loss improved from 0.51731 to 0.51456, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8169 - loss: 0.4240 - val_accuracy: 0.8710 - val_loss: 0.5146
# Epoch 113/700
# 189/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8235 - loss: 0.4150
# Epoch 113: val_loss improved from 0.51456 to 0.51428, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8186 - loss: 0.4212 - val_accuracy: 0.8696 - val_loss: 0.5143
# Epoch 114/700
# 187/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8213 - loss: 0.4183
# Epoch 114: val_loss improved from 0.51428 to 0.51123, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8168 - loss: 0.4202 - val_accuracy: 0.8733 - val_loss: 0.5112
# Epoch 115/700
# 190/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8247 - loss: 0.4127
# Epoch 115: val_loss improved from 0.51123 to 0.51010, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8226 - loss: 0.4174 - val_accuracy: 0.8736 - val_loss: 0.5101
# Epoch 116/700
# 197/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8233 - loss: 0.4114
# Epoch 116: val_loss improved from 0.51010 to 0.50755, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8229 - loss: 0.4116 - val_accuracy: 0.8744 - val_loss: 0.5076
# Epoch 117/700
# 201/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8234 - loss: 0.4146
# Epoch 117: val_loss improved from 0.50755 to 0.50642, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8241 - loss: 0.4128 - val_accuracy: 0.8747 - val_loss: 0.5064
# Epoch 118/700
# 201/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8300 - loss: 0.4070
# Epoch 118: val_loss improved from 0.50642 to 0.50474, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8243 - loss: 0.4116 - val_accuracy: 0.8754 - val_loss: 0.5047
# Epoch 119/700
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8255 - loss: 0.4114
# Epoch 119: val_loss improved from 0.50474 to 0.50291, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8252 - loss: 0.4097 - val_accuracy: 0.8761 - val_loss: 0.5029
# Epoch 120/700
# 203/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8218 - loss: 0.4140
# Epoch 120: val_loss did not improve from 0.50291
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8248 - loss: 0.4113 - val_accuracy: 0.8749 - val_loss: 0.5032
# Epoch 121/700
# 186/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8300 - loss: 0.4088
# Epoch 121: val_loss improved from 0.50291 to 0.50080, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8260 - loss: 0.4131 - val_accuracy: 0.8768 - val_loss: 0.5008
# Epoch 122/700
# 196/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8262 - loss: 0.4069
# Epoch 122: val_loss improved from 0.50080 to 0.49840, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8298 - loss: 0.4056 - val_accuracy: 0.8779 - val_loss: 0.4984
# Epoch 123/700
# 180/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8189 - loss: 0.4192
# Epoch 123: val_loss improved from 0.49840 to 0.49837, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8248 - loss: 0.4097 - val_accuracy: 0.8781 - val_loss: 0.4984
# Epoch 124/700
# 191/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8260 - loss: 0.4062
# Epoch 124: val_loss improved from 0.49837 to 0.49628, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8284 - loss: 0.4038 - val_accuracy: 0.8784 - val_loss: 0.4963
# Epoch 125/700
# 190/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8241 - loss: 0.4078
# Epoch 125: val_loss improved from 0.49628 to 0.49441, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8261 - loss: 0.4021 - val_accuracy: 0.8799 - val_loss: 0.4944
# Epoch 126/700
# 193/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8356 - loss: 0.3936
# Epoch 126: val_loss improved from 0.49441 to 0.49371, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8316 - loss: 0.3980 - val_accuracy: 0.8777 - val_loss: 0.4937
# Epoch 127/700
# 181/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8316 - loss: 0.3950
# Epoch 127: val_loss improved from 0.49371 to 0.49180, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8333 - loss: 0.3968 - val_accuracy: 0.8795 - val_loss: 0.4918
# Epoch 128/700
# 183/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8261 - loss: 0.4071
# Epoch 128: val_loss improved from 0.49180 to 0.48999, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8309 - loss: 0.3980 - val_accuracy: 0.8816 - val_loss: 0.4900
# Epoch 129/700
# 200/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8315 - loss: 0.3926
# Epoch 129: val_loss improved from 0.48999 to 0.48958, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8297 - loss: 0.3976 - val_accuracy: 0.8802 - val_loss: 0.4896
# Epoch 130/700
# 196/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8261 - loss: 0.4007
# Epoch 130: val_loss improved from 0.48958 to 0.48790, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8317 - loss: 0.3951 - val_accuracy: 0.8807 - val_loss: 0.4879
# Epoch 131/700
# 194/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8336 - loss: 0.3956
# Epoch 131: val_loss improved from 0.48790 to 0.48753, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8345 - loss: 0.3926 - val_accuracy: 0.8802 - val_loss: 0.4875
# Epoch 132/700
# 204/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8335 - loss: 0.3914
# Epoch 132: val_loss improved from 0.48753 to 0.48526, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8329 - loss: 0.3939 - val_accuracy: 0.8811 - val_loss: 0.4853
# Epoch 133/700
# 189/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8311 - loss: 0.3962
# Epoch 133: val_loss improved from 0.48526 to 0.48501, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8321 - loss: 0.3939 - val_accuracy: 0.8809 - val_loss: 0.4850
# Epoch 134/700
# 187/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8366 - loss: 0.3937
# Epoch 134: val_loss improved from 0.48501 to 0.48252, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8364 - loss: 0.3913 - val_accuracy: 0.8839 - val_loss: 0.4825
# Epoch 135/700
# 185/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8380 - loss: 0.3891
# Epoch 135: val_loss did not improve from 0.48252
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8362 - loss: 0.3886 - val_accuracy: 0.8816 - val_loss: 0.4828
# Epoch 136/700
# 201/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8333 - loss: 0.3916
# Epoch 136: val_loss improved from 0.48252 to 0.48033, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8349 - loss: 0.3922 - val_accuracy: 0.8839 - val_loss: 0.4803
# Epoch 137/700
# 187/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8289 - loss: 0.3959
# Epoch 137: val_loss improved from 0.48033 to 0.48028, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8331 - loss: 0.3900 - val_accuracy: 0.8827 - val_loss: 0.4803
# Epoch 138/700
# 185/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8268 - loss: 0.3961
# Epoch 138: val_loss improved from 0.48028 to 0.48001, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8321 - loss: 0.3908 - val_accuracy: 0.8829 - val_loss: 0.4800
# Epoch 139/700
# 198/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8429 - loss: 0.3782
# Epoch 139: val_loss improved from 0.48001 to 0.47800, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8375 - loss: 0.3835 - val_accuracy: 0.8832 - val_loss: 0.4780
# Epoch 140/700
# 187/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8421 - loss: 0.3730
# Epoch 140: val_loss improved from 0.47800 to 0.47567, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8380 - loss: 0.3806 - val_accuracy: 0.8869 - val_loss: 0.4757
# Epoch 141/700
# 183/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8290 - loss: 0.3868
# Epoch 141: val_loss improved from 0.47567 to 0.47444, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8359 - loss: 0.3836 - val_accuracy: 0.8862 - val_loss: 0.4744
# Epoch 142/700
# 196/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8387 - loss: 0.3854
# Epoch 142: val_loss did not improve from 0.47444
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8395 - loss: 0.3814 - val_accuracy: 0.8848 - val_loss: 0.4746
# Epoch 143/700
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8342 - loss: 0.3862
# Epoch 143: val_loss did not improve from 0.47444
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8372 - loss: 0.3834 - val_accuracy: 0.8841 - val_loss: 0.4746
# Epoch 144/700
# 195/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8400 - loss: 0.3785
# Epoch 144: val_loss improved from 0.47444 to 0.47081, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8395 - loss: 0.3791 - val_accuracy: 0.8876 - val_loss: 0.4708
# Epoch 145/700
# 187/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8429 - loss: 0.3749
# Epoch 145: val_loss did not improve from 0.47081
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8417 - loss: 0.3770 - val_accuracy: 0.8859 - val_loss: 0.4709
# Epoch 146/700
# 200/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8374 - loss: 0.3851
# Epoch 146: val_loss improved from 0.47081 to 0.47047, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8376 - loss: 0.3811 - val_accuracy: 0.8859 - val_loss: 0.4705
# Epoch 147/700
# 203/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8422 - loss: 0.3730
# Epoch 147: val_loss improved from 0.47047 to 0.46775, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8432 - loss: 0.3733 - val_accuracy: 0.8889 - val_loss: 0.4677
# Epoch 148/700
# 188/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8471 - loss: 0.3643
# Epoch 148: val_loss did not improve from 0.46775
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8425 - loss: 0.3706 - val_accuracy: 0.8876 - val_loss: 0.4679
# Epoch 149/700
# 202/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8444 - loss: 0.3687
# Epoch 149: val_loss improved from 0.46775 to 0.46602, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8431 - loss: 0.3725 - val_accuracy: 0.8878 - val_loss: 0.4660
# Epoch 150/700
# 194/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8409 - loss: 0.3677
# Epoch 150: val_loss improved from 0.46602 to 0.46443, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8425 - loss: 0.3711 - val_accuracy: 0.8887 - val_loss: 0.4644
# Epoch 151/700
# 189/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8424 - loss: 0.3729
# Epoch 151: val_loss improved from 0.46443 to 0.46369, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8452 - loss: 0.3692 - val_accuracy: 0.8892 - val_loss: 0.4637
# Epoch 152/700
# 183/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8466 - loss: 0.3632
# Epoch 152: val_loss improved from 0.46369 to 0.46264, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8459 - loss: 0.3687 - val_accuracy: 0.8894 - val_loss: 0.4626
# Epoch 153/700
# 177/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8409 - loss: 0.3728
# Epoch 153: val_loss improved from 0.46264 to 0.46192, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8460 - loss: 0.3698 - val_accuracy: 0.8898 - val_loss: 0.4619
# Epoch 154/700
# 201/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8506 - loss: 0.3613
# Epoch 154: val_loss improved from 0.46192 to 0.45910, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8442 - loss: 0.3662 - val_accuracy: 0.8898 - val_loss: 0.4591
# Epoch 155/700
# 182/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8497 - loss: 0.3566
# Epoch 155: val_loss did not improve from 0.45910
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8460 - loss: 0.3655 - val_accuracy: 0.8898 - val_loss: 0.4593
# Epoch 156/700
# 196/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8442 - loss: 0.3687
# Epoch 156: val_loss improved from 0.45910 to 0.45832, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8459 - loss: 0.3646 - val_accuracy: 0.8915 - val_loss: 0.4583
# Epoch 157/700
# 198/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8452 - loss: 0.3632
# Epoch 157: val_loss improved from 0.45832 to 0.45657, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8457 - loss: 0.3626 - val_accuracy: 0.8910 - val_loss: 0.4566
# Epoch 158/700
# 188/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8521 - loss: 0.3573
# Epoch 158: val_loss improved from 0.45657 to 0.45510, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8508 - loss: 0.3589 - val_accuracy: 0.8912 - val_loss: 0.4551
# Epoch 159/700
# 200/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8467 - loss: 0.3542
# Epoch 159: val_loss improved from 0.45510 to 0.45433, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8452 - loss: 0.3605 - val_accuracy: 0.8907 - val_loss: 0.4543
# Epoch 160/700
# 194/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8506 - loss: 0.3655
# Epoch 160: val_loss improved from 0.45433 to 0.45218, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8517 - loss: 0.3611 - val_accuracy: 0.8921 - val_loss: 0.4522
# Epoch 161/700
# 189/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8515 - loss: 0.3596
# Epoch 161: val_loss improved from 0.45218 to 0.45049, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8501 - loss: 0.3625 - val_accuracy: 0.8930 - val_loss: 0.4505
# Epoch 162/700
# 200/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.8470 - loss: 0.3622
# Epoch 162: val_loss did not improve from 0.45049
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.8488 - loss: 0.3599 - val_accuracy: 0.8926 - val_loss: 0.4507
# Epoch 163/700
# ...
# Epoch 641/700
# 205/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9223 - loss: 0.1949
# Epoch 641: val_loss improved from 0.27921 to 0.27915, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9225 - loss: 0.1918 - val_accuracy: 0.9133 - val_loss: 0.2791
# Epoch 642/700
# 190/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9216 - loss: 0.1955
# Epoch 642: val_loss improved from 0.27915 to 0.27872, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9224 - loss: 0.1940 - val_accuracy: 0.9126 - val_loss: 0.2787
# Epoch 643/700
# 199/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9224 - loss: 0.1955
# Epoch 643: val_loss did not improve from 0.27872
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9219 - loss: 0.1962 - val_accuracy: 0.9125 - val_loss: 0.2789
# Epoch 644/700
# 198/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9233 - loss: 0.1925
# Epoch 644: val_loss improved from 0.27872 to 0.27836, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9216 - loss: 0.1953 - val_accuracy: 0.9125 - val_loss: 0.2784
# Epoch 645/700
# 179/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9267 - loss: 0.1822
# Epoch 645: val_loss did not improve from 0.27836
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9233 - loss: 0.1922 - val_accuracy: 0.9119 - val_loss: 0.2797
# Epoch 646/700
# 192/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9252 - loss: 0.1905
# Epoch 646: val_loss did not improve from 0.27836
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9234 - loss: 0.1949 - val_accuracy: 0.9114 - val_loss: 0.2804
# Epoch 647/700
# 192/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9143 - loss: 0.2041
# Epoch 647: val_loss did not improve from 0.27836
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9183 - loss: 0.1958 - val_accuracy: 0.9121 - val_loss: 0.2800
# Epoch 648/700
# 188/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9263 - loss: 0.1890
# Epoch 648: val_loss did not improve from 0.27836
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9231 - loss: 0.1961 - val_accuracy: 0.9126 - val_loss: 0.2790
# Epoch 649/700
# 188/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9224 - loss: 0.1936
# Epoch 649: val_loss did not improve from 0.27836
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9224 - loss: 0.1931 - val_accuracy: 0.9130 - val_loss: 0.2792
# Epoch 650/700
# 184/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9242 - loss: 0.1909
# Epoch 650: val_loss did not improve from 0.27836
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9212 - loss: 0.1939 - val_accuracy: 0.9125 - val_loss: 0.2793
# Epoch 651/700
# 188/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9186 - loss: 0.1982
# Epoch 651: val_loss did not improve from 0.27836
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9213 - loss: 0.1961 - val_accuracy: 0.9125 - val_loss: 0.2795
# Epoch 652/700
# 202/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9228 - loss: 0.1961
# Epoch 652: val_loss did not improve from 0.27836
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9241 - loss: 0.1935 - val_accuracy: 0.9123 - val_loss: 0.2789
# Epoch 653/700
# 195/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9191 - loss: 0.2041
# Epoch 653: val_loss did not improve from 0.27836
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9227 - loss: 0.1955 - val_accuracy: 0.9117 - val_loss: 0.2786
# Epoch 654/700
# 187/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9210 - loss: 0.1895
# Epoch 654: val_loss did not improve from 0.27836
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9224 - loss: 0.1913 - val_accuracy: 0.9121 - val_loss: 0.2787
# Epoch 655/700
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9216 - loss: 0.1936
# Epoch 655: val_loss did not improve from 0.27836
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9215 - loss: 0.1931 - val_accuracy: 0.9117 - val_loss: 0.2788
# Epoch 656/700
# 194/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9227 - loss: 0.1877
# Epoch 656: val_loss improved from 0.27836 to 0.27805, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9224 - loss: 0.1925 - val_accuracy: 0.9123 - val_loss: 0.2780
# Epoch 657/700
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9199 - loss: 0.1982
# Epoch 657: val_loss did not improve from 0.27805
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9208 - loss: 0.1967 - val_accuracy: 0.9117 - val_loss: 0.2785
# Epoch 658/700
# 204/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9240 - loss: 0.2011
# Epoch 658: val_loss improved from 0.27805 to 0.27781, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9237 - loss: 0.1969 - val_accuracy: 0.9125 - val_loss: 0.2778
# Epoch 659/700
# 195/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9222 - loss: 0.1917
# Epoch 659: val_loss improved from 0.27781 to 0.27771, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9243 - loss: 0.1907 - val_accuracy: 0.9123 - val_loss: 0.2777
# Epoch 660/700
# 196/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9210 - loss: 0.1893
# Epoch 660: val_loss did not improve from 0.27771
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9205 - loss: 0.1922 - val_accuracy: 0.9114 - val_loss: 0.2785
# Epoch 661/700
# 181/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9213 - loss: 0.1990
# Epoch 661: val_loss did not improve from 0.27771
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9224 - loss: 0.1940 - val_accuracy: 0.9112 - val_loss: 0.2793
# Epoch 662/700
# 194/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9181 - loss: 0.2041
# Epoch 662: val_loss did not improve from 0.27771
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9220 - loss: 0.1947 - val_accuracy: 0.9114 - val_loss: 0.2791
# Epoch 663/700
# 197/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9214 - loss: 0.1953
# Epoch 663: val_loss did not improve from 0.27771
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9234 - loss: 0.1933 - val_accuracy: 0.9114 - val_loss: 0.2799
# Epoch 664/700
# 187/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9268 - loss: 0.1908
# Epoch 664: val_loss did not improve from 0.27771
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9259 - loss: 0.1924 - val_accuracy: 0.9121 - val_loss: 0.2783
# Epoch 665/700
# 181/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9242 - loss: 0.1891
# Epoch 665: val_loss did not improve from 0.27771
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9220 - loss: 0.1934 - val_accuracy: 0.9125 - val_loss: 0.2783
# Epoch 666/700
# 202/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9216 - loss: 0.1920
# Epoch 666: val_loss improved from 0.27771 to 0.27622, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9219 - loss: 0.1891 - val_accuracy: 0.9141 - val_loss: 0.2762
# Epoch 667/700
# 181/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9214 - loss: 0.1959
# Epoch 667: val_loss did not improve from 0.27622
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9246 - loss: 0.1911 - val_accuracy: 0.9114 - val_loss: 0.2788
# Epoch 668/700
# 190/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9243 - loss: 0.1921
# Epoch 668: val_loss did not improve from 0.27622
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9252 - loss: 0.1894 - val_accuracy: 0.9128 - val_loss: 0.2762
# Epoch 669/700
# 185/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9251 - loss: 0.1929
# Epoch 669: val_loss did not improve from 0.27622
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9234 - loss: 0.1928 - val_accuracy: 0.9121 - val_loss: 0.2770
# Epoch 670/700
# 200/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9248 - loss: 0.1827
# Epoch 670: val_loss did not improve from 0.27622
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9215 - loss: 0.1910 - val_accuracy: 0.9117 - val_loss: 0.2774
# Epoch 671/700
# 200/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9233 - loss: 0.1956
# Epoch 671: val_loss did not improve from 0.27622
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9237 - loss: 0.1929 - val_accuracy: 0.9119 - val_loss: 0.2772
# Epoch 672/700
# 204/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9237 - loss: 0.1942
# Epoch 672: val_loss did not improve from 0.27622
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9214 - loss: 0.1942 - val_accuracy: 0.9126 - val_loss: 0.2767
# Epoch 673/700
# 190/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9233 - loss: 0.1887
# Epoch 673: val_loss did not improve from 0.27622
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9220 - loss: 0.1935 - val_accuracy: 0.9121 - val_loss: 0.2778
# Epoch 674/700
# 203/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9294 - loss: 0.1786
# Epoch 674: val_loss did not improve from 0.27622
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9257 - loss: 0.1853 - val_accuracy: 0.9123 - val_loss: 0.2770
# Epoch 675/700
# 203/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9249 - loss: 0.1904
# Epoch 675: val_loss did not improve from 0.27622
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9237 - loss: 0.1906 - val_accuracy: 0.9125 - val_loss: 0.2765
# Epoch 676/700
# 183/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9195 - loss: 0.1987
# Epoch 676: val_loss did not improve from 0.27622
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9222 - loss: 0.1914 - val_accuracy: 0.9112 - val_loss: 0.2780
# Epoch 677/700
# 195/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9236 - loss: 0.1960
# Epoch 677: val_loss did not improve from 0.27622
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9246 - loss: 0.1930 - val_accuracy: 0.9112 - val_loss: 0.2777
# Epoch 678/700
# 190/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9214 - loss: 0.1934
# Epoch 678: val_loss did not improve from 0.27622
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9232 - loss: 0.1928 - val_accuracy: 0.9123 - val_loss: 0.2767
# Epoch 679/700
# 183/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9256 - loss: 0.1859
# Epoch 679: val_loss improved from 0.27622 to 0.27564, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9236 - loss: 0.1877 - val_accuracy: 0.9119 - val_loss: 0.2756
# Epoch 680/700
# 191/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9268 - loss: 0.1896
# Epoch 680: val_loss did not improve from 0.27564
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9271 - loss: 0.1879 - val_accuracy: 0.9119 - val_loss: 0.2759
# Epoch 681/700
# 192/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9224 - loss: 0.1930
# Epoch 681: val_loss improved from 0.27564 to 0.27551, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9251 - loss: 0.1888 - val_accuracy: 0.9123 - val_loss: 0.2755
# Epoch 682/700
# 202/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9275 - loss: 0.1829
# Epoch 682: val_loss improved from 0.27551 to 0.27476, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9246 - loss: 0.1882 - val_accuracy: 0.9130 - val_loss: 0.2748
# Epoch 683/700
# 181/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9241 - loss: 0.1842
# Epoch 683: val_loss improved from 0.27476 to 0.27389, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9245 - loss: 0.1859 - val_accuracy: 0.9128 - val_loss: 0.2739
# Epoch 684/700
# 182/206 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - accuracy: 0.9269 - loss: 0.1895
# Epoch 684: val_loss did not improve from 0.27389
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9251 - loss: 0.1889 - val_accuracy: 0.9123 - val_loss: 0.2746
# Epoch 685/700
# 196/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9243 - loss: 0.1868
# Epoch 685: val_loss did not improve from 0.27389
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9260 - loss: 0.1867 - val_accuracy: 0.9121 - val_loss: 0.2756
# Epoch 686/700
# 198/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9201 - loss: 0.1947
# Epoch 686: val_loss did not improve from 0.27389
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9218 - loss: 0.1910 - val_accuracy: 0.9109 - val_loss: 0.2769
# Epoch 687/700
# 204/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9283 - loss: 0.1834
# Epoch 687: val_loss did not improve from 0.27389
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9291 - loss: 0.1817 - val_accuracy: 0.9121 - val_loss: 0.2742
# Epoch 688/700
# 185/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9317 - loss: 0.1796
# Epoch 688: val_loss did not improve from 0.27389
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9267 - loss: 0.1873 - val_accuracy: 0.9123 - val_loss: 0.2740
# Epoch 689/700
# 186/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9284 - loss: 0.1793
# Epoch 689: val_loss improved from 0.27389 to 0.27374, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9246 - loss: 0.1875 - val_accuracy: 0.9123 - val_loss: 0.2737
# Epoch 690/700
# 182/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9282 - loss: 0.1821
# Epoch 690: val_loss did not improve from 0.27374
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9274 - loss: 0.1866 - val_accuracy: 0.9116 - val_loss: 0.2745
# Epoch 691/700
# 187/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9243 - loss: 0.1915
# Epoch 691: val_loss improved from 0.27374 to 0.27346, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9262 - loss: 0.1868 - val_accuracy: 0.9121 - val_loss: 0.2735
# Epoch 692/700
# 203/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9228 - loss: 0.1901
# Epoch 692: val_loss improved from 0.27346 to 0.27251, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9265 - loss: 0.1830 - val_accuracy: 0.9128 - val_loss: 0.2725
# Epoch 693/700
# 193/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9256 - loss: 0.1877
# Epoch 693: val_loss did not improve from 0.27251
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9260 - loss: 0.1867 - val_accuracy: 0.9121 - val_loss: 0.2734
# Epoch 694/700
# 200/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9249 - loss: 0.1895
# Epoch 694: val_loss improved from 0.27251 to 0.27242, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9269 - loss: 0.1878 - val_accuracy: 0.9130 - val_loss: 0.2724
# Epoch 695/700
# 195/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9269 - loss: 0.1863
# Epoch 695: val_loss did not improve from 0.27242
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9242 - loss: 0.1880 - val_accuracy: 0.9130 - val_loss: 0.2737
# Epoch 696/700
# 189/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9259 - loss: 0.1824
# Epoch 696: val_loss did not improve from 0.27242
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9228 - loss: 0.1870 - val_accuracy: 0.9128 - val_loss: 0.2742
# Epoch 697/700
# 198/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9278 - loss: 0.1850
# Epoch 697: val_loss did not improve from 0.27242
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9258 - loss: 0.1874 - val_accuracy: 0.9121 - val_loss: 0.2748
# Epoch 698/700
# 182/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9258 - loss: 0.1819
# Epoch 698: val_loss did not improve from 0.27242
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9254 - loss: 0.1841 - val_accuracy: 0.9125 - val_loss: 0.2728
# Epoch 699/700
# 190/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9250 - loss: 0.1850
# Epoch 699: val_loss improved from 0.27242 to 0.27235, saving model to best_mr_tcn.keras
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9218 - loss: 0.1893 - val_accuracy: 0.9130 - val_loss: 0.2724
# Epoch 700/700
# 203/206 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - accuracy: 0.9243 - loss: 0.1889
# Epoch 700: val_loss did not improve from 0.27235
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9236 - loss: 0.1878 - val_accuracy: 0.9130 - val_loss: 0.2733

# %%
test_results = model.evaluate(X_test, y_test, verbose=0)

for name, val in zip(model.metrics_names, test_results):
    print(f"{name}: {val:.4f}")
# Out:
# loss: 0.3912
# compile_metrics: 0.8401

# %%
import matplotlib.pyplot as plt

plt.plot(history.history["loss"], label="train")
plt.plot(history.history["val_loss"], label="val")
plt.legend()
plt.title("Loss")
plt.show()

# %%
# ===== EVALUASI MODEL (TEST SET) =====

import numpy as np
from sklearn.metrics import roc_curve, confusion_matrix, classification_report

# 1. Ambil probabilitas output model
y_prob = model.predict(X_test).ravel()

# 2. Hitung ROC curve
fpr, tpr, thresholds = roc_curve(y_test, y_prob)

# 3. Hitung Youden Index
youden_index = tpr - fpr
best_threshold = thresholds[np.argmax(youden_index)]

print("Best threshold (Youden):", best_threshold)

# 4. Prediksi final menggunakan threshold Youden
y_pred = (y_prob >= best_threshold).astype(int)

# 5. Evaluasi
print("Confusion Matrix:")
print(confusion_matrix(y_test, y_pred))

print("\nClassification Report:")
print(classification_report(y_test, y_pred, target_names=["Normal", "Attack"]))
# Out:
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# Best threshold (Youden): 0.3762876
# Confusion Matrix:
# [[6045  801]
#  [ 869 4653]]
#
# Classification Report:
#               precision    recall  f1-score   support
#
#       Normal       0.87      0.88      0.88      6846
#       Attack       0.85      0.84      0.85      5522
#
#     accuracy                           0.86     12368
#    macro avg       0.86      0.86      0.86     12368
# weighted avg       0.86      0.86      0.86     12368

# %%
y_pred = (y_prob >= best_threshold)

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred, target_names=["Normal","Attack"]))
# Out:
#               precision    recall  f1-score   support
#
#       Normal       0.87      0.88      0.88      6846
#       Attack       0.85      0.84      0.85      5522
#
#     accuracy                           0.86     12368
#    macro avg       0.86      0.86      0.86     12368
# weighted avg       0.86      0.86      0.86     12368

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import time
from sklearn.metrics import roc_curve, auc, confusion_matrix, classification_report

# 1. DEFINISI FUNGSI (Mesin Evaluasi)
def evaluate_iov_model(model, X_test, y_test):
    print("--- Memulai Proses Evaluasi ---")
    
    # Prediksi
    start_time = time.time()
    y_prob = model.predict(X_test).ravel()
    inference_time = (time.time() - start_time) / len(X_test)
    
    # Mencari Threshold Terbaik (Youden Index)
    fpr, tpr, thresholds = roc_curve(y_test, y_prob)
    youden_index = tpr - fpr
    best_threshold = thresholds[np.argmax(youden_index)]
    
    # Klasifikasi Berdasarkan Threshold
    y_pred = (y_prob >= best_threshold).astype(int)
    
    # Hitung Metrik
    cm = confusion_matrix(y_test, y_pred)
    tn, fp, fn, tp = cm.ravel()
    fpr_val = fp / (fp + tn)
    
    # VISUALISASI
    fig, ax = plt.subplots(1, 2, figsize=(15, 5))
    
    # Heatmap Confusion Matrix
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', ax=ax[0])
    ax[0].set_title('Confusion Matrix (Optimized Threshold)')
    ax[0].set_xlabel('Predicted')
    ax[0].set_ylabel('Actual')
    
    # ROC Curve
    ax[1].plot(fpr, tpr, label=f'AUC = {auc(fpr, tpr):.44f}')
    ax[1].plot([0, 1], [0, 1], 'k--')
    ax[1].set_title('ROC Curve')
    ax[1].legend()
    
    plt.show() # Ini akan memunculkan gambar
    
    # CETAK HASIL KE KONSOL
    print("\n" + "="*30)
    print(f"HASIL EVALUASI IDS (IoV)")
    print("="*30)
    print(f"Threshold Optimal : {best_threshold:.4f}")
    print(f"False Positive Rate: {fpr_val:.6f}")
    print(f"Inference Latency : {inference_time:.6f} s/sample")
    print("-" * 30)
    print(classification_report(y_test, y_pred, target_names=['Normal', 'Attack']))
    
    return best_threshold

# ==========================================
# 2. EKSEKUSI FUNGSI (Panggil di sini)
# ==========================================
# Ganti 'model_anda', 'X_test_anda', 'y_test_anda' 
# dengan nama variabel yang Anda miliki.

try:
    # Contoh: jika model Anda bernama 'global_model'
    best_thr = evaluate_iov_model(model, X_test, y_test)
except NameError as e:
    print(f"Error: {e}. Pastikan variabel model dan data Anda sudah didefinisikan sebelumnya.")
# Out:
# --- Memulai Proses Evaluasi ---
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 0s 744us/step
# ==============================
# HASIL EVALUASI IDS (IoV)
# ==============================
# Threshold Optimal : 0.3763
# False Positive Rate: 0.117003
# Inference Latency : 0.000039 s/sample
# ------------------------------
#               precision    recall  f1-score   support
#
#       Normal       0.87      0.88      0.88      6846
#       Attack       0.85      0.84      0.85      5522
#
#     accuracy                           0.86     12368
#    macro avg       0.86      0.86      0.86     12368
# weighted avg       0.86      0.86      0.86     12368

# %%
from sklearn.metrics import confusion_matrix

# 1. Dapatkan prediksi dari model (berupa probabilitas)
y_prob = model.predict(X_test) 

# 2. Ubah probabilitas menjadi kelas (0 atau 1) 
# Gunakan threshold, misalnya 0.5 atau hasil Youden Index
y_pred = (y_prob > best_threshold).astype(int)

# 3. Munculkan Confusion Matrix
cm = confusion_matrix(y_test, y_pred)

# 4. Ekstrak TP, FP, TN, FN dari matriks
# Matriks sklearn memiliki format: [[TN, FP], [FN, TP]]
tn, fp, fn, tp = cm.ravel()

# 5. Cetak ke layar
print(f"--- Hasil Deteksi Serangan ---")
print(f"True Negatives (TN)  : {tn} (Trafik normal terdeteksi normal)")
print(f"False Positives (FP) : {fp} (ALARM PALSU - Normal dianggap serangan)")
print(f"False Negatives (FN) : {fn} (LOLOS - Serangan dianggap normal)")
print(f"True Positives (TP)  : {tp} (Berhasil mendeteksi serangan)")
# Out:
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 0s 724us/step
# --- Hasil Deteksi Serangan ---
# True Negatives (TN)  : 6045 (Trafik normal terdeteksi normal)
# False Positives (FP) : 801 (ALARM PALSU - Normal dianggap serangan)
# False Negatives (FN) : 870 (LOLOS - Serangan dianggap normal)
# True Positives (TP)  : 4652 (Berhasil mendeteksi serangan)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(6, 5))
sns.heatmap(cm, annot=True, fmt='d', cmap='Reds', 
            xticklabels=['Normal', 'Attack'], 
            yticklabels=['Normal', 'Attack'])
plt.title('Confusion Matrix: Deteksi Serangan IoV')
plt.ylabel('Kondisi Aktual')
plt.xlabel('Prediksi Model')
plt.show()

# %% [markdown]
# batas

# %%
import numpy as np

y_prob = model.predict(X_test).ravel()      # probabilitas Attack
y_pred = (y_prob > best_threshold).astype(int)         # label prediksi (threshold default)
# Out:
# 387/387 ━━━━━━━━━━━━━━━━━━━━ 0s 783us/step

# %%
# Fungsi: deteksi overfitting dan stabilitas training.
import matplotlib.pyplot as plt

plt.figure()
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.title('Training vs Validation Loss')
plt.legend()
plt.show()

plt.figure()
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('Training vs Validation Accuracy')
plt.legend()
plt.show()

# %%
# Fungsi: melihat False Negative (serangan lolos).
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

cm = confusion_matrix(y_test, y_pred)

disp = ConfusionMatrixDisplay(
    confusion_matrix=cm,
    display_labels=["Normal", "Attack"]
)
disp.plot()
plt.title("Confusion Matrix")
plt.show()
# 📌 Interpretasi IDS

# FN (Attack → Normal) harus minimal

# FP tinggi → false alarm

# %%
# Fungsi: menilai kualitas deteksi Attack.
from sklearn.metrics import precision_recall_fscore_support

precision, recall, f1, _ = precision_recall_fscore_support(
    y_test, y_pred, average=None
)

labels = ["Normal", "Attack"]

plt.figure()
plt.bar(labels, precision, label="Precision")
plt.bar(labels, recall, bottom=precision, label="Recall")
plt.ylabel("Score")
plt.title("Precision & Recall per Class")
plt.legend()
plt.show()
# Fokus laporan: Recall kelas Attack

# %%
# Fungsi: evaluasi threshold-independent.
from sklearn.metrics import roc_curve, auc

fpr, tpr, _ = roc_curve(y_test, y_prob)
roc_auc = auc(fpr, tpr)

plt.figure()
plt.plot(fpr, tpr, label=f"AUC = {roc_auc:.4f}")
plt.plot([0,1], [0,1], linestyle="--")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.title("ROC Curve")
plt.legend()
plt.show()

# AUC mendekati 1 → IDS sangat kuat

# %%
# Lebih relevan dari ROC untuk IDS.
from sklearn.metrics import precision_recall_curve

prec, rec, _ = precision_recall_curve(y_test, y_prob)

plt.figure()
plt.plot(rec, prec)
plt.xlabel("Recall")
plt.ylabel("Precision")
plt.title("Precision–Recall Curve")
plt.show()

# %%
from sklearn.metrics import f1_score
import matplotlib.pyplot as plt
import numpy as np

# ==========================================
# ASUMSI:
# - y_prob SUDAH dihitung di evaluate_iov_model
# - best_thr didapat dari return fungsi
# ==========================================

# Gunakan ulang y_prob & y_test (TIDAK buat baru)
y_pred = (y_prob >= best_thr).astype(int)

# Hitung F1-score untuk threshold yang SAMA
f1 = f1_score(y_test, y_pred)

print("\n" + "="*30)
print("F1-SCORE (FOLLOW YOUDEN THRESHOLD)")
print("="*30)
print(f"Threshold digunakan : {best_thr:.4f}")
print(f"F1-score           : {f1:.6f}")
# Out:
# ==============================
# F1-SCORE (FOLLOW YOUDEN THRESHOLD)
# ==============================
# Threshold digunakan : 0.3763
# F1-score           : 0.847850

# %%
plt.figure(figsize=(6,4))
plt.scatter(best_thr, f1, color='red', zorder=5)
plt.axvline(best_thr, linestyle='--', label=f"Threshold = {best_thr:.4f}")

plt.text(
    best_thr, f1,
    f"({best_thr:.4f}, {f1:.4f})",
    ha='left', va='bottom'
)

plt.xlabel("Threshold")
plt.ylabel("F1-score")
plt.title("F1-score at Optimized Youden Threshold")
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
# Fungsi: lihat separasi Normal vs Attack.
plt.figure()
plt.hist(y_prob[y_test == 1], bins=50, alpha=0.7, label="Attack")
plt.hist(y_prob[y_test == 0], bins=50, alpha=0.7, label="Normal")
plt.xlabel("Predicted Probability (Attack)")
plt.ylabel("Frequency")
plt.title("Prediction Confidence Distribution")
plt.legend()
plt.show()
# 📌 Distribusi terpisah jelas → model robust.

# %%
from sklearn.metrics import classification_report

print(classification_report(
    y_test, y_pred,
    target_names=["Normal", "Attack"]
))
# Out:
#               precision    recall  f1-score   support
#
#       Normal       0.87      0.88      0.88      6846
#       Attack       0.85      0.84      0.85      5522
#
#     accuracy                           0.86     12368
#    macro avg       0.86      0.86      0.86     12368
# weighted avg       0.86      0.86      0.86     12368

# %%
import numpy as np
from sklearn.metrics import confusion_matrix

def compute_ids_metrics(y_true, y_pred):
    """
    Compute IDS metrics exactly as defined in the paper:
    Acc, F1, FPR, FNR
    """

    # Confusion Matrix
    tn, fp, fn, tp = confusion_matrix(y_true, y_pred).ravel()

    # Metrics (paper definitions)
    acc = (tp + tn) / (tp + tn + fp + fn)
    f1  = (2 * tp) / (2 * tp + fp + fn)
    fpr = fp / (fp + tn) if (fp + tn) > 0 else 0.0
    fnr = fn / (fn + tp) if (fn + tp) > 0 else 0.0

    return {
        "TP": tp,
        "FP": fp,
        "TN": tn,
        "FN": fn,
        "Accuracy": acc,
        "F1-score": f1,
        "FPR": fpr,
        "FNR": fnr,
        "FNR": fnr,
    }

# %%
# Hitung metrik IDS
metrics = compute_ids_metrics(y_test, y_pred)

for k, v in metrics.items():
    print(f"{k:10s}: {v:.6f}" if isinstance(v, float) else f"{k:10s}: {v}")
# Out:
# TP        : 4653
# FP        : 801
# TN        : 6045
# FN        : 869
# Accuracy  : 0.864974
# F1-score  : 0.847850
# FPR       : 0.117003
# FNR       : 0.157371

# %% [markdown]
# HASIL DARI MRCTN-AE W64 S64 D0.00

# %%
# %whos
# Out:
# Variable                          Type                      Data/Info
# ---------------------------------------------------------------------
# Add                               type                      <class 'keras.src.layers.merging.add.Add'>
# BatchNormalization                type                      <class 'keras.src.layers.<...>tion.BatchNormalization'>
# ConfusionMatrixDisplay            type                      <class 'sklearn.metrics._<...>.ConfusionMatrixDisplay'>
# Conv1D                            type                      <class 'keras.src.layers.<...>olutional.conv1d.Conv1D'>
# Dense                             type                      <class 'keras.src.layers.core.dense.Dense'>
# Dropout                           type                      <class 'keras.src.layers.<...>ization.dropout.Dropout'>
# EarlyStopping                     type                      <class 'keras.src.callbac<...>_stopping.EarlyStopping'>
# Flatten                           type                      <class 'keras.src.layers.<...>shaping.flatten.Flatten'>
# GlobalAveragePooling1D            type                      <class 'keras.src.layers.<...>.GlobalAveragePooling1D'>
# Input                             function                  <function Input at 0x7516865e1b20>
# MaxPooling1D                      type                      <class 'keras.src.layers.<...>_pooling1d.MaxPooling1D'>
# Model                             type                      <class 'keras.src.models.model.Model'>
# ModelCheckpoint                   type                      <class 'keras.src.callbac<...>ckpoint.ModelCheckpoint'>
# ReLU                              type                      <class 'keras.src.layers.activations.relu.ReLU'>
# Sequential                        type                      <class 'keras.src.models.sequential.Sequential'>
# X_test                            ndarray                   12368x64x64: 50659328 elems, type `float32`, 202637312 bytes (193.25 Mb)
# X_train                           ndarray                   13165x64x64: 53923840 elems, type `float32`, 215695360 bytes (205.703125 Mb)
# X_val                             ndarray                   5643x64x64: 23113728 elems, type `float32`, 92454912 bytes (88.171875 Mb)
# auc                               function                  <function auc at 0x7515c935a020>
# best_thr                          float32                   0.3762876
# best_threshold                    float32                   0.3762876
# build_mr_tcn                      function                  <function build_mr_tcn at 0x75171943f7e0>
# check_balance_binary              function                  <function check_balance_binary at 0x751632fb11c0>
# checkpoint                        ModelCheckpoint           <keras.src.callbacks.mode<...>object at 0x751632f3f320>
# classification_report             function                  <function classification_<...>report at 0x7515c933b600>
# cm                                ndarray                   2x2: 4 elems, type `int64`, 32 bytes
# compute_ids_metrics               function                  <function compute_ids_metrics at 0x751570110ea0>
# confusion_matrix                  function                  <function confusion_matrix at 0x7515c933a2a0>
# data                              NpzFile                   NpzFile 'preprocessingW64<...>, x_val, y_val, x_test...
# disp                              ConfusionMatrixDisplay    <sklearn.metrics._plot.co<...>object at 0x7515b733d7c0>
# early_stop                        EarlyStopping             <keras.src.callbacks.earl<...>object at 0x751633ff5730>
# evaluate_iov_model                function                  <function evaluate_iov_model at 0x751601fe2840>
# f1                                float                     0.8478498542274052
# f1_score                          function                  <function f1_score at 0x7515c933aa20>
# fn                                int64                     870
# fp                                int64                     801
# fpr                               ndarray                   2430: 2430 elems, type `float64`, 19440 bytes
# history                           History                   <keras.src.callbacks.hist<...>object at 0x751701c8d310>
# k                                 str                       FNR
# labels                            list                      n=2
# metrics                           dict                      n=8
# model                             Sequential                <Sequential name=sequential, built=True>
# name                              str                       compile_metrics
# np                                module                    <module 'numpy' from '/ho<...>kages/numpy/__init__.py'>
# plt                               module                    <module 'matplotlib.pyplo<...>es/matplotlib/pyplot.py'>
# prec                              ndarray                   12363: 12363 elems, type `float64`, 98904 bytes
# precision                         ndarray                   2: 2 elems, type `float64`, 16 bytes
# precision_recall_curve            function                  <function precision_recal<...>_curve at 0x7515c935a700>
# precision_recall_fscore_support   function                  <function precision_recal<...>upport at 0x7515c933af20>
# rec                               ndarray                   12363: 12363 elems, type `float64`, 98904 bytes
# recall                            ndarray                   2: 2 elems, type `float64`, 16 bytes
# roc_auc                           float                     0.9365099557153428
# roc_curve                         function                  <function roc_curve at 0x7515c935a840>
# sns                               module                    <module 'seaborn' from '/<...>ges/seaborn/__init__.py'>
# tcn_block                         function                  <function tcn_block at 0x751632fb13a0>
# test_results                      list                      n=2
# tf                                module                    <module 'tensorflow' from<...>/tensorflow/__init__.py'>
# thresholds                        ndarray                   2430: 2430 elems, type `float32`, 9720 bytes
# time                              module                    <module 'time' (built-in)>
# tn                                int64                     6045
# tp                                int64                     4652
# tpr                               ndarray                   2430: 2430 elems, type `float64`, 19440 bytes
# v                                 float64                   0.15737051792828685
# val                               float                     0.8400711417198181
# y_pred                            ndarray                   12368: 12368 elems, type `int64`, 98944 bytes
# y_prob                            ndarray                   12368: 12368 elems, type `float32`, 49472 bytes
# y_test                            ndarray                   12368: 12368 elems, type `int64`, 98944 bytes
# y_train                           ndarray                   13165: 13165 elems, type `int64`, 105320 bytes (102.8515625 kb)
# y_val                             ndarray                   5643: 5643 elems, type `int64`, 45144 bytes
# youden_index                      ndarray                   2430: 2430 elems, type `float64`, 19440 bytes

# %%
# !free -h
# Out:
#                total        used        free      shared  buff/cache   available
# Mem:            31Gi       8.5Gi        15Gi       724Mi       8.2Gi        22Gi
# Swap:           14Gi       2.1Gi        12Gi
