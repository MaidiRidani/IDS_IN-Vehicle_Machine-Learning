# %%
import numpy as np
import os
import gc
import time
import matplotlib.pyplot as plt
import seaborn as sns

import tensorflow as tf
from tensorflow.keras import layers, models

from sklearn.metrics import (
    confusion_matrix,
    classification_report,
    roc_curve,
    auc,
    precision_recall_curve,
    f1_score
)

import pandas as pd
import time
from tensorflow.keras.callbacks import Callback, EarlyStopping, ModelCheckpoint
from tensorflow.keras.callbacks import ReduceLROnPlateau, CSVLogger
# Out:
# 2026-05-30 11:45:29.855278: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-05-30 11:45:29.944794: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1780116329.986190   44063 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1780116329.996945   44063 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1780116330.072909   44063 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1780116330.072932   44063 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1780116330.072935   44063 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1780116330.072938   44063 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-05-30 11:45:30.083821: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
Load_Path = "/home/dani/Documents/tugas akhir/TugasAkhir/codeTugasAkhirku2026/tow_ids/Preprocessing/Preprocessingbaru/imgsize128lv1/norm/dwt/"
ukuran = 64

# %%
train_data = np.load(os.path.join(Load_Path, "tow_ids_train_dwt.npz"))
test_data  = np.load(os.path.join(Load_Path, "tow_ids_test_dwt.npz"))
validation_data = np.load(os.path.join(Load_Path, "tow_ids_eval_dwt.npz"))

X_train = train_data["X"]
y_train = train_data["y"]

X_val = validation_data["X"]
y_val = validation_data["y"]

X_test  = test_data["X"]
y_test  = test_data["y"]

print(X_train.shape, y_train.shape)
print(X_val.shape, y_val.shape)
print(X_test.shape, y_test.shape)
# Out:
# (6582, 64, 64, 3) (6582,)
# (2821, 64, 64, 3) (2821,)
# (6184, 64, 64, 3) (6184,)

# %%
print("Train label distribution:", np.unique(y_train, return_counts=True))
print("Test label distribution :", np.unique(y_test, return_counts=True))
print("Validation label distribution :", np.unique(y_val, return_counts=True))

print("Min value:", X_train.min())
print("Max value:", X_train.max())
# Out:
# Train label distribution: (array([0, 1]), array([3137, 3445]))
# Test label distribution : (array([0, 1]), array([3296, 2888]))
# Validation label distribution : (array([0, 1]), array([ 887, 1934]))
# Min value: -0.43898103
# Max value: 2.4145703

# %%
import tensorflow as tf
from tensorflow.keras import layers, models


def composite_conv(x, filters, kernel_size):
    x = layers.Conv2D(
        filters,
        kernel_size,
        padding="same",
        use_bias=False
    )(x)

    x = layers.BatchNormalization()(x)

    x = layers.ReLU()(x)

    return x


def SE_block(x, ratio=16):
    channels = x.shape[-1]

    se = layers.GlobalAveragePooling2D()(x)

    se = layers.Dense(
        max(channels // ratio, 4),
        activation="relu"
    )(se)

    se = layers.Dense(
        channels,
        activation="sigmoid"
    )(se)

    se = layers.Reshape((1, 1, channels))(se)

    out = layers.Multiply()([x, se])

    return out


def DPDB_block(x, filters, pool=True):
    shortcut = x

    h = composite_conv(x, filters // 2, (1, 3))

    v = composite_conv(x, filters // 2, (3, 1))

    concat = layers.Concatenate()([h, v])

    fusion = composite_conv(concat, filters, (1, 1))

    fusion = SE_block(fusion)

    if pool:
        fusion = layers.MaxPooling2D((2, 2))(fusion)

    shortcut = layers.Conv2D(
        filters,
        (1, 1),
        padding="same",
        use_bias=False
    )(shortcut)

    shortcut = layers.BatchNormalization()(shortcut)

    if pool:
        shortcut = layers.MaxPooling2D((2, 2))(shortcut)

    out = layers.Add()([fusion, shortcut])

    out = layers.ReLU()(out)

    return out


input_layer = layers.Input(shape=(ukuran, ukuran, 3))

x = composite_conv(input_layer, 16, (1, 3))

x = composite_conv(x, 16, (3, 1))

x = DPDB_block(x, 32, pool=True)

x = DPDB_block(x, 64, pool=False)

x = composite_conv(x, 48, (1, 1))

x = layers.GlobalAveragePooling2D()(x)

x = layers.Dense(
    64,
    activation="relu"
)(x)

x = layers.Dropout(0.5)(x)

output_layer = layers.Dense(
    1,
    activation="sigmoid"
)(x)

model = models.Model(
    inputs=input_layer,
    outputs=output_layer
)

model.compile(

    optimizer=tf.keras.optimizers.AdamW(
        learning_rate=1e-4,
        weight_decay=1e-5
    ),

    loss=tf.keras.losses.BinaryFocalCrossentropy(
        apply_class_balancing=True,
        alpha=0.75,
        gamma=2.0
    ),

    metrics=[

        tf.keras.metrics.BinaryAccuracy(
            name="accuracy"
        ),

        tf.keras.metrics.Precision(
            name="precision"
        ),

        tf.keras.metrics.Recall(
            name="recall"
        ),

        tf.keras.metrics.AUC(
            name="auc"
        ),

        tf.keras.metrics.AUC(
            curve="PR",
            name="pr_auc"
        )
    ]
)

model.summary()
# Out:
# I0000 00:00:1780116334.199244   44063 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 4144 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3060 Laptop GPU, pci bus id: 0000:01:00.0, compute capability: 8.6
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer         │ (None, 64, 64, 3) │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d (Conv2D)     │ (None, 64, 64,    │        144 │ input_layer[0][0] │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalization │ (None, 64, 64,    │         64 │ conv2d[0][0]      │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu (ReLU)        │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_1 (Conv2D)   │ (None, 64, 64,    │        768 │ re_lu[0][0]       │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │         64 │ conv2d_1[0][0]    │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_1 (ReLU)      │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_2 (Conv2D)   │ (None, 64, 64,    │        768 │ re_lu_1[0][0]     │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_3 (Conv2D)   │ (None, 64, 64,    │        768 │ re_lu_1[0][0]     │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │         64 │ conv2d_2[0][0]    │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │         64 │ conv2d_3[0][0]    │
# │ (BatchNormalizatio… │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_2 (ReLU)      │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_3 (ReLU)      │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 16)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate         │ (None, 64, 64,    │          0 │ re_lu_2[0][0],    │
# │ (Concatenate)       │ 32)               │            │ re_lu_3[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_4 (Conv2D)   │ (None, 64, 64,    │      1,024 │ concatenate[0][0] │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        128 │ conv2d_4[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_4 (ReLU)      │ (None, 64, 64,    │          0 │ batch_normalizat… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 32)        │          0 │ re_lu_4[0][0]     │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense (Dense)       │ (None, 4)         │        132 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_1 (Dense)     │ (None, 32)        │        160 │ dense[0][0]       │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape (Reshape)   │ (None, 1, 1, 32)  │          0 │ dense_1[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_5 (Conv2D)   │ (None, 64, 64,    │        512 │ re_lu_1[0][0]     │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply (Multiply) │ (None, 64, 64,    │          0 │ re_lu_4[0][0],    │
# │                     │ 32)               │            │ reshape[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 64, 64,    │        128 │ conv2d_5[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d       │ (None, 32, 32,    │          0 │ multiply[0][0]    │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ max_pooling2d_1     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │ (MaxPooling2D)      │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add (Add)           │ (None, 32, 32,    │          0 │ max_pooling2d[0]… │
# │                     │ 32)               │            │ max_pooling2d_1[… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_5 (ReLU)      │ (None, 32, 32,    │          0 │ add[0][0]         │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_6 (Conv2D)   │ (None, 32, 32,    │      3,072 │ re_lu_5[0][0]     │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_7 (Conv2D)   │ (None, 32, 32,    │      3,072 │ re_lu_5[0][0]     │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        128 │ conv2d_6[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        128 │ conv2d_7[0][0]    │
# │ (BatchNormalizatio… │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_6 (ReLU)      │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_7 (ReLU)      │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 32)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ concatenate_1       │ (None, 32, 32,    │          0 │ re_lu_6[0][0],    │
# │ (Concatenate)       │ 64)               │            │ re_lu_7[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_8 (Conv2D)   │ (None, 32, 32,    │      4,096 │ concatenate_1[0]… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ conv2d_8[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_8 (ReLU)      │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 64)        │          0 │ re_lu_8[0][0]     │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_2 (Dense)     │ (None, 4)         │        260 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_3 (Dense)     │ (None, 64)        │        320 │ dense_2[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ reshape_1 (Reshape) │ (None, 1, 1, 64)  │          0 │ dense_3[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_9 (Conv2D)   │ (None, 32, 32,    │      2,048 │ re_lu_5[0][0]     │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multiply_1          │ (None, 32, 32,    │          0 │ re_lu_8[0][0],    │
# │ (Multiply)          │ 64)               │            │ reshape_1[0][0]   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        256 │ conv2d_9[0][0]    │
# │ (BatchNormalizatio… │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_1 (Add)         │ (None, 32, 32,    │          0 │ multiply_1[0][0], │
# │                     │ 64)               │            │ batch_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_9 (ReLU)      │ (None, 32, 32,    │          0 │ add_1[0][0]       │
# │                     │ 64)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv2d_10 (Conv2D)  │ (None, 32, 32,    │      3,072 │ re_lu_9[0][0]     │
# │                     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 32, 32,    │        192 │ conv2d_10[0][0]   │
# │ (BatchNormalizatio… │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ re_lu_10 (ReLU)     │ (None, 32, 32,    │          0 │ batch_normalizat… │
# │                     │ 48)               │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 48)        │          0 │ re_lu_10[0][0]    │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_4 (Dense)     │ (None, 64)        │      3,136 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout (Dropout)   │ (None, 64)        │          0 │ dense_4[0][0]     │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_5 (Dense)     │ (None, 1)         │         65 │ dropout[0][0]     │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 24,889 (97.22 KB)
#  Trainable params: 24,153 (94.35 KB)
#  Non-trainable params: 736 (2.88 KB)

# %%
print("TensorFlow version:", tf.__version__)
print("GPU available:", tf.config.list_physical_devices('GPU'))

tf.debugging.set_log_device_placement(True)
# Out:
# TensorFlow version: 2.19.1
# GPU available: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
class TrainingLogger(Callback):

    def on_train_begin(self, logs=None):
        print("\nTraining started")
        print("-"*70)
        print("{:<8} {:<12} {:<12} {:<12} {:<12}".format(
            "Epoch","Loss","Accuracy","Val_Loss","Val_Acc"))
        print("-"*70)

    def on_epoch_end(self, epoch, logs=None):

        print("{:<8} {:<12.4f} {:<12.4f} {:<12.4f} {:<12.4f}".format(
            epoch+1,
            logs["loss"],
            logs["accuracy"],
            logs["val_loss"],
            logs["val_accuracy"]
        ))

# %%
checkpoint = ModelCheckpoint(
    "best_model_tow_idsIMGSIZE64.keras",
    monitor="val_accuracy",
    save_best_only=True,
    verbose=0
)

# %%
print("\nDataset summary")
print("-"*40)
print("Train samples :", X_train.shape[0])
print("Test samples  :", X_test.shape[0])
print("Validation samples  :", X_val.shape[0])
print("Image shape   :", X_train.shape[1:])
print("Batch size    :", 32)
print("Epochs        :", 50)
print("-"*40)
# Out:
# Dataset summary
# ----------------------------------------
# Train samples : 6582
# Test samples  : 6184
# Validation samples  : 2821
# Image shape   : (64, 64, 3)
# Batch size    : 32
# Epochs        : 50
# ----------------------------------------

# %%
history = model.fit(
    X_train, y_train,
    epochs=50,
    batch_size=32,
    validation_data=(X_val, y_val),
    verbose=1,
    callbacks=[checkpoint]
    
)
# Out:
# Epoch 1/50
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1780116339.041514   44206 service.cc:152] XLA service 0x7fa01003c2c0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1780116339.041539   44206 service.cc:160]   StreamExecutor device (0): NVIDIA GeForce RTX 3060 Laptop GPU, Compute Capability 8.6
# 2026-05-30 11:45:39.185153: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# I0000 00:00:1780116339.969173   44206 cuda_dnn.cc:529] Loaded cuDNN version 91701
#  15/206 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.4994 - auc: 0.4840 - loss: 0.1107 - pr_auc: 0.4915 - precision: 0.5344 - recall: 0.4878
# I0000 00:00:1780116347.631277   44206 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 27s 72ms/step - accuracy: 0.5653 - auc: 0.6108 - loss: 0.0763 - pr_auc: 0.6217 - precision: 0.5555 - recall: 0.8485 - val_accuracy: 0.6856 - val_auc: 0.7726 - val_loss: 0.0607 - val_pr_auc: 0.9147 - val_precision: 0.6856 - val_recall: 1.0000
# Epoch 2/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.6466 - auc: 0.8106 - loss: 0.0568 - pr_auc: 0.8353 - precision: 0.6053 - recall: 0.9338 - val_accuracy: 0.6898 - val_auc: 0.8894 - val_loss: 0.0456 - val_pr_auc: 0.9570 - val_precision: 0.6892 - val_recall: 0.9974
# Epoch 3/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.7341 - auc: 0.8956 - loss: 0.0463 - pr_auc: 0.9163 - precision: 0.6767 - recall: 0.9419 - val_accuracy: 0.8972 - val_auc: 0.9520 - val_loss: 0.0386 - val_pr_auc: 0.9812 - val_precision: 0.9152 - val_recall: 0.9369
# Epoch 4/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.7867 - auc: 0.9286 - loss: 0.0396 - pr_auc: 0.9447 - precision: 0.7304 - recall: 0.9390 - val_accuracy: 0.9043 - val_auc: 0.9548 - val_loss: 0.0366 - val_pr_auc: 0.9822 - val_precision: 0.9338 - val_recall: 0.9261
# Epoch 5/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.8288 - auc: 0.9463 - loss: 0.0346 - pr_auc: 0.9582 - precision: 0.7789 - recall: 0.9396 - val_accuracy: 0.9181 - val_auc: 0.9625 - val_loss: 0.0304 - val_pr_auc: 0.9851 - val_precision: 0.9437 - val_recall: 0.9364
# Epoch 6/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.8554 - auc: 0.9528 - loss: 0.0321 - pr_auc: 0.9636 - precision: 0.8126 - recall: 0.9405 - val_accuracy: 0.8788 - val_auc: 0.9646 - val_loss: 0.0262 - val_pr_auc: 0.9861 - val_precision: 0.8748 - val_recall: 0.9607
# Epoch 7/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.8768 - auc: 0.9656 - loss: 0.0278 - pr_auc: 0.9734 - precision: 0.8358 - recall: 0.9515 - val_accuracy: 0.9096 - val_auc: 0.9672 - val_loss: 0.0260 - val_pr_auc: 0.9873 - val_precision: 0.9221 - val_recall: 0.9483
# Epoch 8/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.9046 - auc: 0.9721 - loss: 0.0251 - pr_auc: 0.9789 - precision: 0.8771 - recall: 0.9509 - val_accuracy: 0.8011 - val_auc: 0.9696 - val_loss: 0.0267 - val_pr_auc: 0.9883 - val_precision: 0.7831 - val_recall: 0.9819
# Epoch 9/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.9184 - auc: 0.9776 - loss: 0.0224 - pr_auc: 0.9834 - precision: 0.8940 - recall: 0.9576 - val_accuracy: 0.8114 - val_auc: 0.9722 - val_loss: 0.0253 - val_pr_auc: 0.9893 - val_precision: 0.7926 - val_recall: 0.9819
# Epoch 10/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 3s 13ms/step - accuracy: 0.9309 - auc: 0.9835 - loss: 0.0195 - pr_auc: 0.9878 - precision: 0.9091 - recall: 0.9643 - val_accuracy: 0.9093 - val_auc: 0.9761 - val_loss: 0.0209 - val_pr_auc: 0.9908 - val_precision: 0.9085 - val_recall: 0.9648
# Epoch 11/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.9483 - auc: 0.9871 - loss: 0.0170 - pr_auc: 0.9907 - precision: 0.9355 - recall: 0.9681 - val_accuracy: 0.9061 - val_auc: 0.9786 - val_loss: 0.0198 - val_pr_auc: 0.9913 - val_precision: 0.8995 - val_recall: 0.9716
# Epoch 12/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.9497 - auc: 0.9885 - loss: 0.0156 - pr_auc: 0.9920 - precision: 0.9361 - recall: 0.9701 - val_accuracy: 0.9213 - val_auc: 0.9805 - val_loss: 0.0186 - val_pr_auc: 0.9921 - val_precision: 0.9213 - val_recall: 0.9679
# Epoch 13/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.9529 - auc: 0.9890 - loss: 0.0150 - pr_auc: 0.9922 - precision: 0.9409 - recall: 0.9710 - val_accuracy: 0.9493 - val_auc: 0.9831 - val_loss: 0.0194 - val_pr_auc: 0.9933 - val_precision: 0.9676 - val_recall: 0.9581
# Epoch 14/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.9593 - auc: 0.9910 - loss: 0.0136 - pr_auc: 0.9936 - precision: 0.9504 - recall: 0.9730 - val_accuracy: 0.9390 - val_auc: 0.9819 - val_loss: 0.0185 - val_pr_auc: 0.9926 - val_precision: 0.9454 - val_recall: 0.9669
# Epoch 15/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.9616 - auc: 0.9920 - loss: 0.0126 - pr_auc: 0.9943 - precision: 0.9514 - recall: 0.9765 - val_accuracy: 0.9525 - val_auc: 0.9826 - val_loss: 0.0239 - val_pr_auc: 0.9929 - val_precision: 0.9823 - val_recall: 0.9478
# Epoch 16/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.9625 - auc: 0.9921 - loss: 0.0127 - pr_auc: 0.9944 - precision: 0.9540 - recall: 0.9753 - val_accuracy: 0.9525 - val_auc: 0.9839 - val_loss: 0.0243 - val_pr_auc: 0.9936 - val_precision: 0.9849 - val_recall: 0.9452
# Epoch 17/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.9667 - auc: 0.9926 - loss: 0.0119 - pr_auc: 0.9948 - precision: 0.9593 - recall: 0.9779 - val_accuracy: 0.9029 - val_auc: 0.9828 - val_loss: 0.0195 - val_pr_auc: 0.9928 - val_precision: 0.8889 - val_recall: 0.9809
# Epoch 18/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.9669 - auc: 0.9937 - loss: 0.0112 - pr_auc: 0.9953 - precision: 0.9596 - recall: 0.9779 - val_accuracy: 0.9234 - val_auc: 0.9848 - val_loss: 0.0393 - val_pr_auc: 0.9938 - val_precision: 0.9937 - val_recall: 0.8940
# Epoch 19/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.9687 - auc: 0.9947 - loss: 0.0104 - pr_auc: 0.9961 - precision: 0.9623 - recall: 0.9785 - val_accuracy: 0.9472 - val_auc: 0.9852 - val_loss: 0.0175 - val_pr_auc: 0.9938 - val_precision: 0.9547 - val_recall: 0.9690
# Epoch 20/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.9713 - auc: 0.9946 - loss: 0.0102 - pr_auc: 0.9962 - precision: 0.9646 - recall: 0.9811 - val_accuracy: 0.9397 - val_auc: 0.9836 - val_loss: 0.0314 - val_pr_auc: 0.9930 - val_precision: 0.9884 - val_recall: 0.9230
# Epoch 21/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.9725 - auc: 0.9953 - loss: 0.0095 - pr_auc: 0.9964 - precision: 0.9690 - recall: 0.9788 - val_accuracy: 0.9266 - val_auc: 0.9825 - val_loss: 0.0180 - val_pr_auc: 0.9924 - val_precision: 0.9206 - val_recall: 0.9772
# Epoch 22/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.9701 - auc: 0.9957 - loss: 0.0093 - pr_auc: 0.9967 - precision: 0.9624 - recall: 0.9811 - val_accuracy: 0.9443 - val_auc: 0.9824 - val_loss: 0.0273 - val_pr_auc: 0.9924 - val_precision: 0.9831 - val_recall: 0.9349
# Epoch 23/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.9761 - auc: 0.9959 - loss: 0.0087 - pr_auc: 0.9970 - precision: 0.9716 - recall: 0.9832 - val_accuracy: 0.9206 - val_auc: 0.9840 - val_loss: 0.0391 - val_pr_auc: 0.9931 - val_precision: 0.9914 - val_recall: 0.8919
# Epoch 24/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.9751 - auc: 0.9961 - loss: 0.0089 - pr_auc: 0.9970 - precision: 0.9697 - recall: 0.9832 - val_accuracy: 0.9156 - val_auc: 0.9747 - val_loss: 0.0379 - val_pr_auc: 0.9877 - val_precision: 0.9753 - val_recall: 0.8997
# Epoch 25/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.9769 - auc: 0.9970 - loss: 0.0079 - pr_auc: 0.9977 - precision: 0.9725 - recall: 0.9837 - val_accuracy: 0.7178 - val_auc: 0.9812 - val_loss: 0.1371 - val_pr_auc: 0.9917 - val_precision: 0.9974 - val_recall: 0.5900
# Epoch 26/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.9754 - auc: 0.9968 - loss: 0.0081 - pr_auc: 0.9976 - precision: 0.9713 - recall: 0.9820 - val_accuracy: 0.9412 - val_auc: 0.9813 - val_loss: 0.0289 - val_pr_auc: 0.9911 - val_precision: 0.9794 - val_recall: 0.9338
# Epoch 27/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.9771 - auc: 0.9973 - loss: 0.0073 - pr_auc: 0.9980 - precision: 0.9722 - recall: 0.9843 - val_accuracy: 0.9387 - val_auc: 0.9817 - val_loss: 0.0205 - val_pr_auc: 0.9916 - val_precision: 0.9499 - val_recall: 0.9612
# Epoch 28/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.9755 - auc: 0.9967 - loss: 0.0079 - pr_auc: 0.9976 - precision: 0.9689 - recall: 0.9849 - val_accuracy: 0.6019 - val_auc: 0.9615 - val_loss: 0.1980 - val_pr_auc: 0.9823 - val_precision: 0.9988 - val_recall: 0.4199
# Epoch 29/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.9799 - auc: 0.9977 - loss: 0.0067 - pr_auc: 0.9983 - precision: 0.9732 - recall: 0.9890 - val_accuracy: 0.9178 - val_auc: 0.9754 - val_loss: 0.0369 - val_pr_auc: 0.9886 - val_precision: 0.9770 - val_recall: 0.9012
# Epoch 30/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 3s 14ms/step - accuracy: 0.9790 - auc: 0.9969 - loss: 0.0075 - pr_auc: 0.9977 - precision: 0.9739 - recall: 0.9864 - val_accuracy: 0.6696 - val_auc: 0.9854 - val_loss: 0.1756 - val_pr_auc: 0.9938 - val_precision: 1.0000 - val_recall: 0.5181
# Epoch 31/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9786 - auc: 0.9977 - loss: 0.0070 - pr_auc: 0.9982 - precision: 0.9720 - recall: 0.9875 - val_accuracy: 0.7547 - val_auc: 0.9694 - val_loss: 0.1163 - val_pr_auc: 0.9862 - val_precision: 0.9929 - val_recall: 0.6468
# Epoch 32/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9810 - auc: 0.9980 - loss: 0.0064 - pr_auc: 0.9984 - precision: 0.9767 - recall: 0.9872 - val_accuracy: 0.8841 - val_auc: 0.9661 - val_loss: 0.0529 - val_pr_auc: 0.9836 - val_precision: 0.9707 - val_recall: 0.8568
# Epoch 33/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9804 - auc: 0.9984 - loss: 0.0061 - pr_auc: 0.9986 - precision: 0.9762 - recall: 0.9866 - val_accuracy: 0.8440 - val_auc: 0.9791 - val_loss: 0.0857 - val_pr_auc: 0.9907 - val_precision: 0.9954 - val_recall: 0.7761
# Epoch 34/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9796 - auc: 0.9985 - loss: 0.0058 - pr_auc: 0.9987 - precision: 0.9734 - recall: 0.9881 - val_accuracy: 0.7813 - val_auc: 0.9732 - val_loss: 0.1153 - val_pr_auc: 0.9879 - val_precision: 0.9955 - val_recall: 0.6841
# Epoch 35/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9786 - auc: 0.9981 - loss: 0.0063 - pr_auc: 0.9985 - precision: 0.9728 - recall: 0.9866 - val_accuracy: 0.6179 - val_auc: 0.9601 - val_loss: 0.2390 - val_pr_auc: 0.9816 - val_precision: 0.9977 - val_recall: 0.4436
# Epoch 36/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9830 - auc: 0.9986 - loss: 0.0054 - pr_auc: 0.9988 - precision: 0.9785 - recall: 0.9893 - val_accuracy: 0.9266 - val_auc: 0.9776 - val_loss: 0.0280 - val_pr_auc: 0.9896 - val_precision: 0.9605 - val_recall: 0.9312
# Epoch 37/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9819 - auc: 0.9982 - loss: 0.0059 - pr_auc: 0.9985 - precision: 0.9754 - recall: 0.9904 - val_accuracy: 0.8866 - val_auc: 0.9686 - val_loss: 0.0550 - val_pr_auc: 0.9851 - val_precision: 0.9770 - val_recall: 0.8547
# Epoch 38/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9830 - auc: 0.9988 - loss: 0.0052 - pr_auc: 0.9990 - precision: 0.9766 - recall: 0.9913 - val_accuracy: 0.7926 - val_auc: 0.9666 - val_loss: 0.1115 - val_pr_auc: 0.9850 - val_precision: 0.9934 - val_recall: 0.7022
# Epoch 39/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.9819 - auc: 0.9986 - loss: 0.0055 - pr_auc: 0.9988 - precision: 0.9762 - recall: 0.9896 - val_accuracy: 0.9266 - val_auc: 0.9808 - val_loss: 0.0201 - val_pr_auc: 0.9915 - val_precision: 0.9285 - val_recall: 0.9674
# Epoch 40/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9850 - auc: 0.9990 - loss: 0.0045 - pr_auc: 0.9992 - precision: 0.9796 - recall: 0.9919 - val_accuracy: 0.8564 - val_auc: 0.9807 - val_loss: 0.0792 - val_pr_auc: 0.9915 - val_precision: 0.9955 - val_recall: 0.7942
# Epoch 41/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.9871 - auc: 0.9991 - loss: 0.0046 - pr_auc: 0.9992 - precision: 0.9841 - recall: 0.9913 - val_accuracy: 0.5374 - val_auc: 0.9659 - val_loss: 0.3797 - val_pr_auc: 0.9842 - val_precision: 0.9984 - val_recall: 0.3257
# Epoch 42/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9862 - auc: 0.9993 - loss: 0.0041 - pr_auc: 0.9994 - precision: 0.9805 - recall: 0.9933 - val_accuracy: 0.8681 - val_auc: 0.9697 - val_loss: 0.0754 - val_pr_auc: 0.9859 - val_precision: 0.9851 - val_recall: 0.8201
# Epoch 43/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.9868 - auc: 0.9993 - loss: 0.0041 - pr_auc: 0.9994 - precision: 0.9827 - recall: 0.9922 - val_accuracy: 0.7671 - val_auc: 0.9742 - val_loss: 0.1435 - val_pr_auc: 0.9883 - val_precision: 0.9953 - val_recall: 0.6634
# Epoch 44/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.9860 - auc: 0.9991 - loss: 0.0044 - pr_auc: 0.9993 - precision: 0.9813 - recall: 0.9922 - val_accuracy: 0.8554 - val_auc: 0.9781 - val_loss: 0.0874 - val_pr_auc: 0.9899 - val_precision: 0.9923 - val_recall: 0.7952
# Epoch 45/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.9865 - auc: 0.9991 - loss: 0.0043 - pr_auc: 0.9993 - precision: 0.9825 - recall: 0.9919 - val_accuracy: 0.8543 - val_auc: 0.9610 - val_loss: 0.0834 - val_pr_auc: 0.9827 - val_precision: 0.9841 - val_recall: 0.8004
# Epoch 46/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 3s 15ms/step - accuracy: 0.9869 - auc: 0.9993 - loss: 0.0039 - pr_auc: 0.9994 - precision: 0.9816 - recall: 0.9936 - val_accuracy: 0.9383 - val_auc: 0.9846 - val_loss: 0.0197 - val_pr_auc: 0.9933 - val_precision: 0.9431 - val_recall: 0.9685
# Epoch 47/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.9903 - auc: 0.9995 - loss: 0.0033 - pr_auc: 0.9996 - precision: 0.9873 - recall: 0.9942 - val_accuracy: 0.8720 - val_auc: 0.9561 - val_loss: 0.0729 - val_pr_auc: 0.9787 - val_precision: 0.9640 - val_recall: 0.8449
# Epoch 48/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.9891 - auc: 0.9995 - loss: 0.0034 - pr_auc: 0.9996 - precision: 0.9859 - recall: 0.9933 - val_accuracy: 0.8093 - val_auc: 0.9464 - val_loss: 0.1305 - val_pr_auc: 0.9755 - val_precision: 0.9781 - val_recall: 0.7384
# Epoch 49/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.9865 - auc: 0.9994 - loss: 0.0038 - pr_auc: 0.9995 - precision: 0.9811 - recall: 0.9933 - val_accuracy: 0.6849 - val_auc: 0.9657 - val_loss: 0.2522 - val_pr_auc: 0.9841 - val_precision: 0.9962 - val_recall: 0.5424
# Epoch 50/50
# 206/206 ━━━━━━━━━━━━━━━━━━━━ 3s 16ms/step - accuracy: 0.9885 - auc: 0.9995 - loss: 0.0035 - pr_auc: 0.9995 - precision: 0.9845 - recall: 0.9936 - val_accuracy: 0.6714 - val_auc: 0.9578 - val_loss: 0.2666 - val_pr_auc: 0.9811 - val_precision: 0.9951 - val_recall: 0.5233

# %%
# =========================
# CELL 1
# =========================

import numpy as np
from sklearn.metrics import roc_curve

# prediksi probabilitas
y_prob = model.predict(X_test).ravel()

# label asli
y_true = y_test

# =========================
# EVALUASI DEFAULT THRESHOLD 0.5
# =========================

default_threshold = 0.5
y_pred_default = (y_prob >= default_threshold).astype(int)

# =========================
# CARI THRESHOLD TERBAIK
# =========================
# strategi:
# cari threshold dengan F1 tertinggi

thresholds = np.arange(0.1, 0.91, 0.01)

best_threshold = 0.5
best_f1 = 0

for th in thresholds:

    y_pred_temp = (y_prob >= th).astype(int)

    TP = np.sum((y_true == 1) & (y_pred_temp == 1))
    TN = np.sum((y_true == 0) & (y_pred_temp == 0))
    FP = np.sum((y_true == 0) & (y_pred_temp == 1))
    FN = np.sum((y_true == 1) & (y_pred_temp == 0))

    precision = TP / (TP + FP + 1e-12)
    recall = TP / (TP + FN + 1e-12)

    f1 = 2 * precision * recall / (precision + recall + 1e-12)

    if f1 > best_f1:
        best_f1 = f1
        best_threshold = th

print("Best Threshold:", best_threshold)
print("Best F1 Score :", best_f1)

# prediksi final threshold terbaik
y_pred_best = (y_prob >= best_threshold).astype(int)
# Out:
# 194/194 ━━━━━━━━━━━━━━━━━━━━ 4s 15ms/step
# Best Threshold: 0.2799999999999999
# Best F1 Score : 0.8818004607473291

# %%
# =========================
# CELL 2
# =========================

from sklearn.metrics import confusion_matrix

# ===== DEFAULT 0.5 =====
cm_default = confusion_matrix(y_true, y_pred_default)

TN_d, FP_d, FN_d, TP_d = cm_default.ravel()

print("=== Confusion Matrix (Threshold = 0.5) ===")
print(cm_default)

# ===== BEST THRESHOLD =====
cm_best = confusion_matrix(y_true, y_pred_best)

TN_b, FP_b, FN_b, TP_b = cm_best.ravel()

print("\n=== Confusion Matrix (Best Threshold) ===")
print(cm_best)
# Out:
# === Confusion Matrix (Threshold = 0.5) ===
# [[3219   77]
#  [ 752 2136]]
#
# === Confusion Matrix (Best Threshold) ===
# [[3029  267]
#  [ 400 2488]]

# %%
# =========================
# CELL 3
# =========================

def calculate_metrics(TN, FP, FN, TP):

    accuracy = (TP + TN) / (TP + TN + FP + FN)

    precision = TP / (TP + FP + 1e-12)

    recall = TP / (TP + FN + 1e-12)

    f1 = 2 * precision * recall / (precision + recall + 1e-12)

    FPR = FP / (FP + TN + 1e-12)

    FNR = FN / (FN + TP + 1e-12)

    return accuracy, precision, recall, f1, FPR, FNR


# ===== DEFAULT =====
metrics_default = calculate_metrics(TN_d, FP_d, FN_d, TP_d)

# ===== BEST =====
metrics_best = calculate_metrics(TN_b, FP_b, FN_b, TP_b)

# %%
# =========================
# CELL 4
# =========================

metric_names = [
    "Accuracy",
    "Precision",
    "Recall",
    "F1-score",
    "FPR",
    "FNR"
]

print("========================================")
print("THRESHOLD = 0.5")
print("========================================")

for name, value in zip(metric_names, metrics_default):
    print(f"{name:10}: {value:.6f}")

print("\n")

print("========================================")
print(f"BEST THRESHOLD = {best_threshold:.2f}")
print("========================================")

for name, value in zip(metric_names, metrics_best):
    print(f"{name:10}: {value:.6f}")
# Out:
# ========================================
# THRESHOLD = 0.5
# ========================================
# Accuracy  : 0.865944
# Precision : 0.965206
# Recall    : 0.739612
# F1-score  : 0.837483
# FPR       : 0.023362
# FNR       : 0.260388
#
#
# ========================================
# BEST THRESHOLD = 0.28
# ========================================
# Accuracy  : 0.892141
# Precision : 0.903085
# Recall    : 0.861496
# F1-score  : 0.881800
# FPR       : 0.081007
# FNR       : 0.138504

# %%
# =========================
# CELL 5
# =========================

import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

fpr, tpr, _ = roc_curve(y_true, y_prob)

roc_auc = auc(fpr, tpr)

plt.figure(figsize=(6,6))

plt.plot(fpr, tpr, label="AUC = %0.4f" % roc_auc)

plt.plot([0,1],[0,1],'--')

plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")

plt.title("ROC Curve")

plt.legend()

plt.grid(True)

plt.show()
